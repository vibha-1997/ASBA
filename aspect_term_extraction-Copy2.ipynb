# %%
import xml.etree.ElementTree as ET
import nltk

def get_list(path):
    tree=ET.parse(path)
    root = tree.getroot()
    text_list = []
    id_list=[]
    new_list=[]
    sentences_list=[]
    opinion_list = []
    for review in root.findall('sentence'):
        print(review)
        text_string=""
        opinion_inner_list=[]
        #or sent in review.findall('./sentences/sentence'):
        #print(sent)
        ids=review.attrib['id']
        print(ids)
        id_list.append(ids)
        text_string= text_string+ " "+ review.find('text').text
        new_list.append(ids)
        sentences_list.append(review.find('text').text)
#             new_list.append(sent.find('text').text)
        
#         text_list.append(text_string)
#         for opinion in review.findall('./Opinions/Opinion'):
#             opinion_dict = {
#                 opinion.get('category').replace('#','_'): opinion.get('polarity')
#             }
#             opinion_inner_list.append(opinion_dict)
#         opinion_list.append(opinion_inner_list)
    return text_list,opinion_list,new_list,sentences_list
train_text_list,train_opinion_list,new_list,sentences_list = get_list("/home/vibha/Laptops_Train.xml")
# Out:
# <Element 'sentence' at 0x7f0ae7701250>
# 2339
# <Element 'sentence' at 0x7f0ae7701390>
# 812
# <Element 'sentence' at 0x7f0ae7701410>
# 1316
# <Element 'sentence' at 0x7f0ae7701590>
# 2328
# <Element 'sentence' at 0x7f0ae7701610>
# 2193
# <Element 'sentence' at 0x7f0ae7701690>
# 2005
# <Element 'sentence' at 0x7f0ae7701850>
# 2789
# <Element 'sentence' at 0x7f0ae7701950>
# 425
# <Element 'sentence' at 0x7f0ae77019d0>
# 76
# <Element 'sentence' at 0x7f0ae7701b90>
# 747
# <Element 'sentence' at 0x7f0ae7701c10>
# 80
# <Element 'sentence' at 0x7f0ae7701d10>
# 796
# <Element 'sentence' at 0x7f0ae7701d90>
# 917
# <Element 'sentence' at 0x7f0ae7701f10>
# 1788
# <Element 'sentence' at 0x7f0ae7701fd0>
# 338
# <Element 'sentence' at 0x7f0ae760a190>
# 1630
# <Element 'sentence' at 0x7f0ae760a290>
# 38
# <Element 'sentence' at 0x7f0ae760a3d0>
# 337
# <Element 'sentence' at 0x7f0ae760a5d0>
# 1505
# <Element 'sentence' at 0x7f0ae760a650>
# 263
# <Element 'sentence' at 0x7f0ae760a6d0>
# 1227
# <Element 'sentence' at 0x7f0ae760a750>
# 1019
# <Element 'sentence' at 0x7f0ae760a7d0>
# 1158
# <Element 'sentence' at 0x7f0ae760a850>
# 1168
# <Element 'sentence' at 0x7f0ae760a8d0>
# 2568
# <Element 'sentence' at 0x7f0ae760a9d0>
# 295
# <Element 'sentence' at 0x7f0ae760aad0>
# 951
# <Element 'sentence' at 0x7f0ae760ab50>
# 2759
# <Element 'sentence' at 0x7f0ae760ac50>
# 2055
# <Element 'sentence' at 0x7f0ae760acd0>
# 2980
# <Element 'sentence' at 0x7f0ae760add0>
# 2454
# <Element 'sentence' at 0x7f0ae760ae50>
# 1054
# <Element 'sentence' at 0x7f0ae760af50>
# 743
# <Element 'sentence' at 0x7f0ae76170d0>
# 1155
# <Element 'sentence' at 0x7f0ae7617190>
# 2587
# <Element 'sentence' at 0x7f0ae7617290>
# 2202
# <Element 'sentence' at 0x7f0ae7617390>
# 2799
# <Element 'sentence' at 0x7f0ae7617410>
# 2227
# <Element 'sentence' at 0x7f0ae7617550>
# 2241
# <Element 'sentence' at 0x7f0ae7617610>
# 92
# <Element 'sentence' at 0x7f0ae7617710>
# 1204
# <Element 'sentence' at 0x7f0ae7617810>
# 2026
# <Element 'sentence' at 0x7f0ae7617890>
# 535
# <Element 'sentence' at 0x7f0ae7617910>
# 478
# <Element 'sentence' at 0x7f0ae7617990>
# 1690
# <Element 'sentence' at 0x7f0ae7617a10>
# 1789
# <Element 'sentence' at 0x7f0ae7617a90>
# 250
# <Element 'sentence' at 0x7f0ae7617b10>
# 325
# <Element 'sentence' at 0x7f0ae7617c10>
# 324
# <Element 'sentence' at 0x7f0ae7617c90>
# 1574
# <Element 'sentence' at 0x7f0ae7617dd0>
# 1005
# <Element 'sentence' at 0x7f0ae7617e50>
# 989
# <Element 'sentence' at 0x7f0ae7617ed0>
# 3073
# <Element 'sentence' at 0x7f0ae7624050>
# 1254
# <Element 'sentence' at 0x7f0ae7624150>
# 810
# <Element 'sentence' at 0x7f0ae7624250>
# 1346
# <Element 'sentence' at 0x7f0ae76242d0>
# 2383
# <Element 'sentence' at 0x7f0ae7624350>
# 130
# <Element 'sentence' at 0x7f0ae7624450>
# 1253
# <Element 'sentence' at 0x7f0ae76244d0>
# 839
# <Element 'sentence' at 0x7f0ae76245d0>
# 1473
# <Element 'sentence' at 0x7f0ae7624650>
# 782
# <Element 'sentence' at 0x7f0ae76246d0>
# 696
# <Element 'sentence' at 0x7f0ae76247d0>
# 2878
# <Element 'sentence' at 0x7f0ae7624850>
# 226
# <Element 'sentence' at 0x7f0ae76248d0>
# 1652
# <Element 'sentence' at 0x7f0ae7624950>
# 1030
# <Element 'sentence' at 0x7f0ae7624a50>
# 1425
# <Element 'sentence' at 0x7f0ae7624c50>
# 2861
# <Element 'sentence' at 0x7f0ae7624cd0>
# 661
# <Element 'sentence' at 0x7f0ae7624e50>
# 997
# <Element 'sentence' at 0x7f0ae7624fd0>
# 192
# <Element 'sentence' at 0x7f0ae7637090>
# 463
# <Element 'sentence' at 0x7f0ae76371d0>
# 2866
# <Element 'sentence' at 0x7f0ae7637250>
# 935
# <Element 'sentence' at 0x7f0ae76372d0>
# 1193
# <Element 'sentence' at 0x7f0ae76373d0>
# 2192
# <Element 'sentence' at 0x7f0ae7637450>
# 147
# <Element 'sentence' at 0x7f0ae7637590>
# 1433
# <Element 'sentence' at 0x7f0ae7637690>
# 1669
# <Element 'sentence' at 0x7f0ae7637790>
# 2462
# <Element 'sentence' at 0x7f0ae7637890>
# 2719
# <Element 'sentence' at 0x7f0ae7637990>
# 1224
# <Element 'sentence' at 0x7f0ae7637a90>
# 588
# <Element 'sentence' at 0x7f0ae7637b10>
# 2492
# <Element 'sentence' at 0x7f0ae7637c10>
# 1541
# <Element 'sentence' at 0x7f0ae7637d50>
# 3060
# <Element 'sentence' at 0x7f0ae7637ed0>
# 915
# <Element 'sentence' at 0x7f0ae7637fd0>
# 2050
# <Element 'sentence' at 0x7f0ae75cb110>
# 460
# <Element 'sentence' at 0x7f0ae75cb250>
# 1954
# <Element 'sentence' at 0x7f0ae75cb2d0>
# 1728
# <Element 'sentence' at 0x7f0ae75cb350>
# 620
# <Element 'sentence' at 0x7f0ae75cb3d0>
# 2423
# <Element 'sentence' at 0x7f0ae75cb490>
# 1781
# <Element 'sentence' at 0x7f0ae75cb510>
# 645
# <Element 'sentence' at 0x7f0ae75cb590>
# 2
# <Element 'sentence' at 0x7f0ae75cb650>
# 1524
# <Element 'sentence' at 0x7f0ae75cb750>
# 2472
# <Element 'sentence' at 0x7f0ae75cb7d0>
# 803
# <Element 'sentence' at 0x7f0ae75cb8d0>
# 2225
# <Element 'sentence' at 0x7f0ae75cb9d0>
# 2644
# <Element 'sentence' at 0x7f0ae75cbbd0>
# 1365
# <Element 'sentence' at 0x7f0ae75cbcd0>
# 1555
# <Element 'sentence' at 0x7f0ae75cbd50>
# 2199
# <Element 'sentence' at 0x7f0ae75cbdd0>
# 72
# <Element 'sentence' at 0x7f0ae75cbe50>
# 1151
# <Element 'sentence' at 0x7f0ae75cbed0>
# 2033
# <Element 'sentence' at 0x7f0ae75cbfd0>
# 2113
# <Element 'sentence' at 0x7f0ae75db090>
# 2271
# <Element 'sentence' at 0x7f0ae75db210>
# 1307
# <Element 'sentence' at 0x7f0ae75db290>
# 2186
# <Element 'sentence' at 0x7f0ae75db310>
# 103
# <Element 'sentence' at 0x7f0ae75db450>
# 1875
# <Element 'sentence' at 0x7f0ae75db4d0>
# 1359
# <Element 'sentence' at 0x7f0ae75db550>
# 2483
# <Element 'sentence' at 0x7f0ae75db5d0>
# 2945
# <Element 'sentence' at 0x7f0ae75db650>
# 197
# <Element 'sentence' at 0x7f0ae75db6d0>
# 1149
# <Element 'sentence' at 0x7f0ae75db7d0>
# 163
# <Element 'sentence' at 0x7f0ae75db850>
# 900
# <Element 'sentence' at 0x7f0ae75db950>
# 1649
# <Element 'sentence' at 0x7f0ae75dba50>
# 2972
# <Element 'sentence' at 0x7f0ae75dbad0>
# 446
# <Element 'sentence' at 0x7f0ae75dbbd0>
# 1912
# <Element 'sentence' at 0x7f0ae75dbd50>
# 2752
# <Element 'sentence' at 0x7f0ae75dbe90>
# 270
# <Element 'sentence' at 0x7f0ae75dbf10>
# 2646
# <Element 'sentence' at 0x7f0ae75dbf90>
# 886
# <Element 'sentence' at 0x7f0ae75ea050>
# 2381
# <Element 'sentence' at 0x7f0ae75ea150>
# 404
# <Element 'sentence' at 0x7f0ae75ea250>
# 2772
# <Element 'sentence' at 0x7f0ae75ea2d0>
# 407
# <Element 'sentence' at 0x7f0ae75ea3d0>
# 699
# <Element 'sentence' at 0x7f0ae75ea450>
# 1034
# <Element 'sentence' at 0x7f0ae75ea4d0>
# 1731
# <Element 'sentence' at 0x7f0ae75ea650>
# 1863
# <Element 'sentence' at 0x7f0ae75ea6d0>
# 1186
# <Element 'sentence' at 0x7f0ae75ea810>
# 1029
# <Element 'sentence' at 0x7f0ae75ea890>
# 1014
# <Element 'sentence' at 0x7f0ae75ea910>
# 2470
# <Element 'sentence' at 0x7f0ae75eaad0>
# 331
# <Element 'sentence' at 0x7f0ae75ead10>
# 1073
# <Element 'sentence' at 0x7f0ae75ead90>
# 2788
# <Element 'sentence' at 0x7f0ae75eae10>
# 1057
# <Element 'sentence' at 0x7f0ae75eaed0>
# 1095
# <Element 'sentence' at 0x7f0ae75f6050>
# 210
# <Element 'sentence' at 0x7f0ae75f60d0>
# 1718
# <Element 'sentence' at 0x7f0ae75f6210>
# 2770
# <Element 'sentence' at 0x7f0ae75f6290>
# 642
# <Element 'sentence' at 0x7f0ae75f6310>
# 471
# <Element 'sentence' at 0x7f0ae75f6390>
# 2923
# <Element 'sentence' at 0x7f0ae75f6490>
# 3027
# <Element 'sentence' at 0x7f0ae75f6590>
# 654
# <Element 'sentence' at 0x7f0ae75f66d0>
# 1340
# <Element 'sentence' at 0x7f0ae75f6750>
# 2638
# <Element 'sentence' at 0x7f0ae75f67d0>
# 2099
# <Element 'sentence' at 0x7f0ae75f6850>
# 58
# <Element 'sentence' at 0x7f0ae75f68d0>
# 2716
# <Element 'sentence' at 0x7f0ae75f6950>
# 2317
# <Element 'sentence' at 0x7f0ae75f69d0>
# 1110
# <Element 'sentence' at 0x7f0ae75f6ad0>
# 1488
# <Element 'sentence' at 0x7f0ae75f6c10>
# 488
# <Element 'sentence' at 0x7f0ae75f6d10>
# 1289
# <Element 'sentence' at 0x7f0ae75f6e90>
# 2985
# <Element 'sentence' at 0x7f0ae75f6f90>
# 2145
# <Element 'sentence' at 0x7f0ae7605050>
# 1573
# <Element 'sentence' at 0x7f0ae7605150>
# 1928
# <Element 'sentence' at 0x7f0ae7605290>
# 704
# <Element 'sentence' at 0x7f0ae7605310>
# 1099
# <Element 'sentence' at 0x7f0ae7605410>
# 1347
# <Element 'sentence' at 0x7f0ae7605510>
# 1408
# <Element 'sentence' at 0x7f0ae7605610>
# 1374
# <Element 'sentence' at 0x7f0ae76057d0>
# 34
# <Element 'sentence' at 0x7f0ae7605850>
# 2864
# <Element 'sentence' at 0x7f0ae7605990>
# 815
# <Element 'sentence' at 0x7f0ae7605a10>
# 2801
# <Element 'sentence' at 0x7f0ae7605a90>
# 1568
# <Element 'sentence' at 0x7f0ae7605b10>
# 30
# <Element 'sentence' at 0x7f0ae7605c10>
# 362
# <Element 'sentence' at 0x7f0ae7605c90>
# 619
# <Element 'sentence' at 0x7f0ae7605d10>
# 708
# <Element 'sentence' at 0x7f0ae7605d90>
# 167
# <Element 'sentence' at 0x7f0ae7605e10>
# 474
# <Element 'sentence' at 0x7f0ae7605f50>
# 1563
# <Element 'sentence' at 0x7f0ae7605fd0>
# 172
# <Element 'sentence' at 0x7f0ae7652090>
# 1396
# <Element 'sentence' at 0x7f0ae7652110>
# 156
# <Element 'sentence' at 0x7f0ae7652250>
# 2095
# <Element 'sentence' at 0x7f0ae7652350>
# 46
# <Element 'sentence' at 0x7f0ae76523d0>
# 418
# <Element 'sentence' at 0x7f0ae7652450>
# 1722
# <Element 'sentence' at 0x7f0ae7652510>
# 2004
# <Element 'sentence' at 0x7f0ae76526d0>
# 2296
# <Element 'sentence' at 0x7f0ae76527d0>
# 1514
# <Element 'sentence' at 0x7f0ae7652850>
# 2699
# <Element 'sentence' at 0x7f0ae76528d0>
# 524
# <Element 'sentence' at 0x7f0ae7652950>
# 155
# <Element 'sentence' at 0x7f0ae76529d0>
# 493
# <Element 'sentence' at 0x7f0ae7652b10>
# 902
# <Element 'sentence' at 0x7f0ae7652c10>
# 2433
# <Element 'sentence' at 0x7f0ae7652d10>
# 1675
# <Element 'sentence' at 0x7f0ae7652e50>
# 3000
# <Element 'sentence' at 0x7f0ae7652ed0>
# 954
# <Element 'sentence' at 0x7f0ae7652f50>
# 609
# <Element 'sentence' at 0x7f0ae765e0d0>
# 50
# <Element 'sentence' at 0x7f0ae765e150>
# 1265
# <Element 'sentence' at 0x7f0ae765e1d0>
# 2150
# <Element 'sentence' at 0x7f0ae765e250>
# 1777
# <Element 'sentence' at 0x7f0ae765e2d0>
# 296
# <Element 'sentence' at 0x7f0ae765e410>
# 1585
# <Element 'sentence' at 0x7f0ae765e490>
# 2444
# <Element 'sentence' at 0x7f0ae765e510>
# 2335
# <Element 'sentence' at 0x7f0ae765e610>
# 1635
# <Element 'sentence' at 0x7f0ae765e690>
# 1661
# <Element 'sentence' at 0x7f0ae765e710>
# 2416
# <Element 'sentence' at 0x7f0ae765e810>
# 1471
# <Element 'sentence' at 0x7f0ae765e910>
# 1388
# <Element 'sentence' at 0x7f0ae765e990>
# 715
# <Element 'sentence' at 0x7f0ae765ea50>
# 1901
# <Element 'sentence' at 0x7f0ae765ead0>
# 1427
# <Element 'sentence' at 0x7f0ae765ec50>
# 2389
# <Element 'sentence' at 0x7f0ae765ed10>
# 2667
# <Element 'sentence' at 0x7f0ae765edd0>
# 1618
# <Element 'sentence' at 0x7f0ae765ee50>
# 1460
# <Element 'sentence' at 0x7f0ae765eed0>
# 2964
# <Element 'sentence' at 0x7f0ae765ef50>
# 911
# <Element 'sentence' at 0x7f0ae766b0d0>
# 2001
# <Element 'sentence' at 0x7f0ae766b2d0>
# 2465
# <Element 'sentence' at 0x7f0ae766b450>
# 2331
# <Element 'sentence' at 0x7f0ae766b550>
# 599
# <Element 'sentence' at 0x7f0ae766b6d0>
# 823
# <Element 'sentence' at 0x7f0ae766b810>
# 3006
# <Element 'sentence' at 0x7f0ae766b950>
# 1861
# <Element 'sentence' at 0x7f0ae766b9d0>
# 1301
# <Element 'sentence' at 0x7f0ae766ba50>
# 788
# <Element 'sentence' at 0x7f0ae766bad0>
# 2056
# <Element 'sentence' at 0x7f0ae766bb50>
# 825
# <Element 'sentence' at 0x7f0ae766bbd0>
# 1823
# <Element 'sentence' at 0x7f0ae766bc50>
# 2439
# <Element 'sentence' at 0x7f0ae766bcd0>
# 2941
# <Element 'sentence' at 0x7f0ae766bdd0>
# 2776
# <Element 'sentence' at 0x7f0ae766bf10>
# 1686
# <Element 'sentence' at 0x7f0ae7678050>
# 2091
# <Element 'sentence' at 0x7f0ae7678150>
# 727
# <Element 'sentence' at 0x7f0ae76781d0>
# 3001
# <Element 'sentence' at 0x7f0ae7678290>
# 1259
# <Element 'sentence' at 0x7f0ae7678390>
# 2938
# <Element 'sentence' at 0x7f0ae76784d0>
# 2574
# <Element 'sentence' at 0x7f0ae76785d0>
# 2351
# <Element 'sentence' at 0x7f0ae76786d0>
# 526
# <Element 'sentence' at 0x7f0ae76787d0>
# 2891
# <Element 'sentence' at 0x7f0ae7678850>
# 2717
# <Element 'sentence' at 0x7f0ae76788d0>
# 3020
# <Element 'sentence' at 0x7f0ae7678a10>
# 2541
# <Element 'sentence' at 0x7f0ae7678b50>
# 1069
# <Element 'sentence' at 0x7f0ae7678d50>
# 1553
# <Element 'sentence' at 0x7f0ae7678ed0>
# 355
# <Element 'sentence' at 0x7f0ae7678f50>
# 602
# <Element 'sentence' at 0x7f0ae7678fd0>
# 2502
# <Element 'sentence' at 0x7f0ae7686090>
# 2874
# <Element 'sentence' at 0x7f0ae7686190>
# 2385
# <Element 'sentence' at 0x7f0ae7686310>
# 198
# <Element 'sentence' at 0x7f0ae7686390>
# 211
# <Element 'sentence' at 0x7f0ae7686410>
# 1654
# <Element 'sentence' at 0x7f0ae7686550>
# 3058
# <Element 'sentence' at 0x7f0ae7686710>
# 1937
# <Element 'sentence' at 0x7f0ae76868d0>
# 104
# <Element 'sentence' at 0x7f0ae76869d0>
# 419
# <Element 'sentence' at 0x7f0ae7686a50>
# 630
# <Element 'sentence' at 0x7f0ae7686ad0>
# 694
# <Element 'sentence' at 0x7f0ae7686b50>
# 189
# <Element 'sentence' at 0x7f0ae7686bd0>
# 2616
# <Element 'sentence' at 0x7f0ae7686c50>
# 1417
# <Element 'sentence' at 0x7f0ae7686e50>
# 1045
# <Element 'sentence' at 0x7f0ae7686ed0>
# 2886
# <Element 'sentence' at 0x7f0ae7595050>
# 2124
# <Element 'sentence' at 0x7f0ae7595190>
# 260
# <Element 'sentence' at 0x7f0ae7595290>
# 1296
# <Element 'sentence' at 0x7f0ae7595310>
# 1172
# <Element 'sentence' at 0x7f0ae7595410>
# 2283
# <Element 'sentence' at 0x7f0ae75954d0>
# 2221
# <Element 'sentence' at 0x7f0ae7595690>
# 2480
# <Element 'sentence' at 0x7f0ae7595710>
# 386
# <Element 'sentence' at 0x7f0ae7595810>
# 1357
# <Element 'sentence' at 0x7f0ae7595910>
# 185
# <Element 'sentence' at 0x7f0ae7595990>
# 2605
# <Element 'sentence' at 0x7f0ae7595a90>
# 717
# <Element 'sentence' at 0x7f0ae7595b10>
# 2369
# <Element 'sentence' at 0x7f0ae7595b90>
# 2579
# <Element 'sentence' at 0x7f0ae7595c10>
# 1742
# <Element 'sentence' at 0x7f0ae7595d50>
# 2578
# <Element 'sentence' at 0x7f0ae7595e90>
# 33
# <Element 'sentence' at 0x7f0ae7595f10>
# 942
# <Element 'sentence' at 0x7f0ae75a2050>
# 2740
# <Element 'sentence' at 0x7f0ae75a2150>
# 311
# <Element 'sentence' at 0x7f0ae75a2250>
# 2402
# <Element 'sentence' at 0x7f0ae75a22d0>
# 13
# <Element 'sentence' at 0x7f0ae75a2410>
# 1852
# <Element 'sentence' at 0x7f0ae75a2510>
# 2708
# <Element 'sentence' at 0x7f0ae75a2650>
# 1566
# <Element 'sentence' at 0x7f0ae75a2790>
# 2053
# <Element 'sentence' at 0x7f0ae75a2810>
# 540
# <Element 'sentence' at 0x7f0ae75a2910>
# 878
# <Element 'sentence' at 0x7f0ae75a2a10>
# 2639
# <Element 'sentence' at 0x7f0ae75a2a90>
# 2388
# <Element 'sentence' at 0x7f0ae75a2b90>
# 1940
# <Element 'sentence' at 0x7f0ae75a2c10>
# 3074
# <Element 'sentence' at 0x7f0ae75a2d50>
# 1510
# <Element 'sentence' at 0x7f0ae75a2dd0>
# 2457
# <Element 'sentence' at 0x7f0ae75a2e50>
# 2534
# <Element 'sentence' at 0x7f0ae75a2f50>
# 2185
# <Element 'sentence' at 0x7f0ae75ae110>
# 2632
# <Element 'sentence' at 0x7f0ae75ae210>
# 1772
# <Element 'sentence' at 0x7f0ae75ae290>
# 2675
# <Element 'sentence' at 0x7f0ae75ae3d0>
# 1096
# <Element 'sentence' at 0x7f0ae75ae490>
# 2371
# <Element 'sentence' at 0x7f0ae75ae4d0>
# 2458
# <Element 'sentence' at 0x7f0ae75ae550>
# 2650
# <Element 'sentence' at 0x7f0ae75ae5d0>
# 392
# <Element 'sentence' at 0x7f0ae75ae6d0>
# 1551
# <Element 'sentence' at 0x7f0ae75ae7d0>
# 2698
# <Element 'sentence' at 0x7f0ae75ae8d0>
# 2427
# <Element 'sentence' at 0x7f0ae75ae950>
# 1849
# <Element 'sentence' at 0x7f0ae75ae9d0>
# 340
# <Element 'sentence' at 0x7f0ae75aead0>
# 2918
# <Element 'sentence' at 0x7f0ae75aec10>
# 2939
# <Element 'sentence' at 0x7f0ae75aed50>
# 1958
# <Element 'sentence' at 0x7f0ae75aee90>
# 358
# <Element 'sentence' at 0x7f0ae75aef90>
# 2064
# <Element 'sentence' at 0x7f0ae75be050>
# 1355
# <Element 'sentence' at 0x7f0ae75be150>
# 3021
# <Element 'sentence' at 0x7f0ae75be250>
# 2415
# <Element 'sentence' at 0x7f0ae75be350>
# 2730
# <Element 'sentence' at 0x7f0ae75be3d0>
# 2297
# <Element 'sentence' at 0x7f0ae75be450>
# 2060
# <Element 'sentence' at 0x7f0ae75be4d0>
# 2739
# <Element 'sentence' at 0x7f0ae75be550>
# 2696
# <Element 'sentence' at 0x7f0ae75be610>
# 1352
# <Element 'sentence' at 0x7f0ae75be6d0>
# 1827
# <Element 'sentence' at 0x7f0ae75be750>
# 2916
# <Element 'sentence' at 0x7f0ae75be890>
# 2074
# <Element 'sentence' at 0x7f0ae75be910>
# 229
# <Element 'sentence' at 0x7f0ae75be990>
# 4
# <Element 'sentence' at 0x7f0ae75bead0>
# 2260
# <Element 'sentence' at 0x7f0ae75bebd0>
# 199
# <Element 'sentence' at 0x7f0ae75bec50>
# 1376
# <Element 'sentence' at 0x7f0ae75bed90>
# 936
# <Element 'sentence' at 0x7f0ae75beed0>
# 1627
# <Element 'sentence' at 0x7f0ae75bef50>
# 2323
# <Element 'sentence' at 0x7f0ae754a0d0>
# 1804
# <Element 'sentence' at 0x7f0ae754a1d0>
# 595
# <Element 'sentence' at 0x7f0ae754a250>
# 1426
# <Element 'sentence' at 0x7f0ae754a350>
# 2216
# <Element 'sentence' at 0x7f0ae754a3d0>
# 1590
# <Element 'sentence' at 0x7f0ae754a490>
# 1486
# <Element 'sentence' at 0x7f0ae754a510>
# 138
# <Element 'sentence' at 0x7f0ae754a610>
# 1192
# <Element 'sentence' at 0x7f0ae754a750>
# 1439
# <Element 'sentence' at 0x7f0ae754a7d0>
# 449
# <Element 'sentence' at 0x7f0ae754a890>
# 137
# <Element 'sentence' at 0x7f0ae754a910>
# 1691
# <Element 'sentence' at 0x7f0ae754aa50>
# 877
# <Element 'sentence' at 0x7f0ae754aad0>
# 537
# <Element 'sentence' at 0x7f0ae754abd0>
# 541
# <Element 'sentence' at 0x7f0ae754ad10>
# 1291
# <Element 'sentence' at 0x7f0ae754ad90>
# 924
# <Element 'sentence' at 0x7f0ae754ae10>
# 3043
# <Element 'sentence' at 0x7f0ae754af10>
# 505
# <Element 'sentence' at 0x7f0ae7556090>
# 431
# <Element 'sentence' at 0x7f0ae7556110>
# 569
# <Element 'sentence' at 0x7f0ae7556250>
# 3081
# <Element 'sentence' at 0x7f0ae7556390>
# 308
# <Element 'sentence' at 0x7f0ae7556510>
# 2796
# <Element 'sentence' at 0x7f0ae7556610>
# 2333
# <Element 'sentence' at 0x7f0ae7556710>
# 3049
# <Element 'sentence' at 0x7f0ae75568d0>
# 2660
# <Element 'sentence' at 0x7f0ae75569d0>
# 206
# <Element 'sentence' at 0x7f0ae7556ad0>
# 2138
# <Element 'sentence' at 0x7f0ae7556c10>
# 2737
# <Element 'sentence' at 0x7f0ae7556c90>
# 2392
# <Element 'sentence' at 0x7f0ae7556d90>
# 10
# <Element 'sentence' at 0x7f0ae7556e10>
# 85
# <Element 'sentence' at 0x7f0ae7556e90>
# 9
# <Element 'sentence' at 0x7f0ae7556f90>
# 1218
# <Element 'sentence' at 0x7f0ae7567090>
# 1867
# <Element 'sentence' at 0x7f0ae7567250>
# 2377
# <Element 'sentence' at 0x7f0ae7567390>
# 2438
# <Element 'sentence' at 0x7f0ae7567410>
# 136
# <Element 'sentence' at 0x7f0ae7567490>
# 2928
# <Element 'sentence' at 0x7f0ae7567590>
# 258
# <Element 'sentence' at 0x7f0ae7567610>
# 2811
# <Element 'sentence' at 0x7f0ae7567790>
# 2137
# <Element 'sentence' at 0x7f0ae7567890>
# 1256
# <Element 'sentence' at 0x7f0ae7567990>
# 1770
# <Element 'sentence' at 0x7f0ae7567b10>
# 2270
# <Element 'sentence' at 0x7f0ae7567c50>
# 1424
# <Element 'sentence' at 0x7f0ae7567d90>
# 2843
# <Element 'sentence' at 0x7f0ae7567e90>
# 1239
# <Element 'sentence' at 0x7f0ae7567f50>
# 2471
# <Element 'sentence' at 0x7f0ae75750d0>
# 1240
# <Element 'sentence' at 0x7f0ae7575150>
# 2550
# <Element 'sentence' at 0x7f0ae7575290>
# 455
# <Element 'sentence' at 0x7f0ae75753d0>
# 641
# <Element 'sentence' at 0x7f0ae7575450>
# 2197
# <Element 'sentence' at 0x7f0ae75754d0>
# 1462
# <Element 'sentence' at 0x7f0ae7575550>
# 949
# <Element 'sentence' at 0x7f0ae7575610>
# 2924
# <Element 'sentence' at 0x7f0ae7575690>
# 2496
# <Element 'sentence' at 0x7f0ae75757d0>
# 1089
# <Element 'sentence' at 0x7f0ae75758d0>
# 713
# <Element 'sentence' at 0x7f0ae7575a10>
# 490
# <Element 'sentence' at 0x7f0ae7575b50>
# 957
# <Element 'sentence' at 0x7f0ae7575bd0>
# 2844
# <Element 'sentence' at 0x7f0ae7575c50>
# 2422
# <Element 'sentence' at 0x7f0ae7575d90>
# 2540
# <Element 'sentence' at 0x7f0ae7575ed0>
# 2018
# <Element 'sentence' at 0x7f0ae7575fd0>
# 800
# <Element 'sentence' at 0x7f0ae7581090>
# 2566
# <Element 'sentence' at 0x7f0ae7581110>
# 1683
# <Element 'sentence' at 0x7f0ae7581190>
# 2022
# <Element 'sentence' at 0x7f0ae7581290>
# 709
# <Element 'sentence' at 0x7f0ae7581310>
# 1191
# <Element 'sentence' at 0x7f0ae7581450>
# 1950
# <Element 'sentence' at 0x7f0ae75814d0>
# 2007
# <Element 'sentence' at 0x7f0ae7581550>
# 777
# <Element 'sentence' at 0x7f0ae7581650>
# 2775
# <Element 'sentence' at 0x7f0ae7581750>
# 1145
# <Element 'sentence' at 0x7f0ae75817d0>
# 1844
# <Element 'sentence' at 0x7f0ae75818d0>
# 1989
# <Element 'sentence' at 0x7f0ae7581990>
# 2147
# <Element 'sentence' at 0x7f0ae7581a50>
# 1068
# <Element 'sentence' at 0x7f0ae7581c10>
# 2030
# <Element 'sentence' at 0x7f0ae7581d10>
# 2586
# <Element 'sentence' at 0x7f0ae7581d90>
# 128
# <Element 'sentence' at 0x7f0ae7581e90>
# 2822
# <Element 'sentence' at 0x7f0ae7581f10>
# 1561
# <Element 'sentence' at 0x7f0ae750e090>
# 1890
# <Element 'sentence' at 0x7f0ae750e190>
# 2435
# <Element 'sentence' at 0x7f0ae750e290>
# 826
# <Element 'sentence' at 0x7f0ae750e310>
# 2166
# <Element 'sentence' at 0x7f0ae750e410>
# 739
# <Element 'sentence' at 0x7f0ae750e490>
# 371
# <Element 'sentence' at 0x7f0ae750e510>
# 2969
# <Element 'sentence' at 0x7f0ae750e610>
# 896
# <Element 'sentence' at 0x7f0ae750e690>
# 824
# <Element 'sentence' at 0x7f0ae750e790>
# 2896
# <Element 'sentence' at 0x7f0ae750e810>
# 2754
# <Element 'sentence' at 0x7f0ae750e950>
# 309
# <Element 'sentence' at 0x7f0ae750ea50>
# 816
# <Element 'sentence' at 0x7f0ae750ead0>
# 16
# <Element 'sentence' at 0x7f0ae750ec10>
# 1984
# <Element 'sentence' at 0x7f0ae750edd0>
# 837
# <Element 'sentence' at 0x7f0ae750ee90>
# 1588
# <Element 'sentence' at 0x7f0ae750ef10>
# 2943
# <Element 'sentence' at 0x7f0ae751c050>
# 2410
# <Element 'sentence' at 0x7f0ae751c0d0>
# 2889
# <Element 'sentence' at 0x7f0ae751c190>
# 1839
# <Element 'sentence' at 0x7f0ae751c290>
# 1375
# <Element 'sentence' at 0x7f0ae751c3d0>
# 899
# <Element 'sentence' at 0x7f0ae751c4d0>
# 2897
# <Element 'sentence' at 0x7f0ae751c550>
# 2858
# <Element 'sentence' at 0x7f0ae751c690>
# 1338
# <Element 'sentence' at 0x7f0ae751c790>
# 2962
# <Element 'sentence' at 0x7f0ae751c990>
# 1785
# <Element 'sentence' at 0x7f0ae751ca10>
# 2110
# <Element 'sentence' at 0x7f0ae751cb10>
# 2201
# <Element 'sentence' at 0x7f0ae751cb90>
# 139
# <Element 'sentence' at 0x7f0ae751cc10>
# 2582
# <Element 'sentence' at 0x7f0ae751cc90>
# 35
# <Element 'sentence' at 0x7f0ae751cd90>
# 1041
# <Element 'sentence' at 0x7f0ae751ced0>
# 1219
# <Element 'sentence' at 0x7f0ae751cf50>
# 231
# <Element 'sentence' at 0x7f0ae751cfd0>
# 728
# <Element 'sentence' at 0x7f0ae7529090>
# 1934
# <Element 'sentence' at 0x7f0ae7529110>
# 1040
# <Element 'sentence' at 0x7f0ae7529210>
# 178
# <Element 'sentence' at 0x7f0ae7529290>
# 379
# <Element 'sentence' at 0x7f0ae75293d0>
# 2358
# <Element 'sentence' at 0x7f0ae7529450>
# 1757
# <Element 'sentence' at 0x7f0ae75295d0>
# 220
# <Element 'sentence' at 0x7f0ae75296d0>
# 2790
# <Element 'sentence' at 0x7f0ae7529750>
# 2370
# <Element 'sentence' at 0x7f0ae75297d0>
# 2919
# <Element 'sentence' at 0x7f0ae75298d0>
# 698
# <Element 'sentence' at 0x7f0ae7529a10>
# 1336
# <Element 'sentence' at 0x7f0ae7529b50>
# 797
# <Element 'sentence' at 0x7f0ae7529bd0>
# 2758
# <Element 'sentence' at 0x7f0ae7529c50>
# 146
# <Element 'sentence' at 0x7f0ae7529d10>
# 432
# <Element 'sentence' at 0x7f0ae7529dd0>
# 1969
# <Element 'sentence' at 0x7f0ae7529ed0>
# 2549
# <Element 'sentence' at 0x7f0ae7529fd0>
# 269
# <Element 'sentence' at 0x7f0ae75370d0>
# 469
# <Element 'sentence' at 0x7f0ae7537210>
# 2974
# <Element 'sentence' at 0x7f0ae7537310>
# 835
# <Element 'sentence' at 0x7f0ae7537410>
# 1898
# <Element 'sentence' at 0x7f0ae7537490>
# 1962
# <Element 'sentence' at 0x7f0ae7537590>
# 306
# <Element 'sentence' at 0x7f0ae7537610>
# 2838
# <Element 'sentence' at 0x7f0ae7537690>
# 1666
# <Element 'sentence' at 0x7f0ae7537710>
# 2876
# <Element 'sentence' at 0x7f0ae7537850>
# 2141
# <Element 'sentence' at 0x7f0ae7537950>
# 3040
# <Element 'sentence' at 0x7f0ae75379d0>
# 2034
# <Element 'sentence' at 0x7f0ae7537ad0>
# 2798
# <Element 'sentence' at 0x7f0ae7537b50>
# 1382
# <Element 'sentence' at 0x7f0ae7537bd0>
# 2905
# <Element 'sentence' at 0x7f0ae7537c50>
# 2669
# <Element 'sentence' at 0x7f0ae7537d50>
# 2895
# <Element 'sentence' at 0x7f0ae7537e90>
# 2181
# <Element 'sentence' at 0x7f0ae7537f90>
# 1529
# <Element 'sentence' at 0x7f0ae7543110>
# 2002
# <Element 'sentence' at 0x7f0ae7543190>
# 1752
# <Element 'sentence' at 0x7f0ae7543290>
# 672
# <Element 'sentence' at 0x7f0ae7543350>
# 695
# <Element 'sentence' at 0x7f0ae7543490>
# 2291
# <Element 'sentence' at 0x7f0ae7543590>
# 2183
# <Element 'sentence' at 0x7f0ae7543610>
# 658
# <Element 'sentence' at 0x7f0ae7543690>
# 2286
# <Element 'sentence' at 0x7f0ae7543710>
# 2481
# <Element 'sentence' at 0x7f0ae7543810>
# 1584
# <Element 'sentence' at 0x7f0ae7543890>
# 1893
# <Element 'sentence' at 0x7f0ae7543990>
# 2649
# <Element 'sentence' at 0x7f0ae7543b90>
# 783
# <Element 'sentence' at 0x7f0ae7543c10>
# 1889
# <Element 'sentence' at 0x7f0ae7543c90>
# 3072
# <Element 'sentence' at 0x7f0ae7543e10>
# 1196
# <Element 'sentence' at 0x7f0ae7543f10>
# 761
# <Element 'sentence' at 0x7f0ae74d2050>
# 1736
# <Element 'sentence' at 0x7f0ae74d20d0>
# 813
# <Element 'sentence' at 0x7f0ae74d2150>
# 1735
# <Element 'sentence' at 0x7f0ae74d21d0>
# 2096
# <Element 'sentence' at 0x7f0ae74d2310>
# 633
# <Element 'sentence' at 0x7f0ae74d2390>
# 714
# <Element 'sentence' at 0x7f0ae74d2490>
# 1404
# <Element 'sentence' at 0x7f0ae74d2510>
# 862
# <Element 'sentence' at 0x7f0ae74d2590>
# 1023
# <Element 'sentence' at 0x7f0ae74d2610>
# 827
# <Element 'sentence' at 0x7f0ae74d2690>
# 923
# <Element 'sentence' at 0x7f0ae74d2710>
# 1973
# <Element 'sentence' at 0x7f0ae74d27d0>
# 2304
# <Element 'sentence' at 0x7f0ae74d2a10>
# 1313
# <Element 'sentence' at 0x7f0ae74d2a90>
# 2276
# <Element 'sentence' at 0x7f0ae74d2c90>
# 3054
# <Element 'sentence' at 0x7f0ae74d2d10>
# 1953
# <Element 'sentence' at 0x7f0ae74d2e10>
# 2755
# <Element 'sentence' at 0x7f0ae74d2f90>
# 184
# <Element 'sentence' at 0x7f0ae74df050>
# 622
# <Element 'sentence' at 0x7f0ae74df0d0>
# 744
# <Element 'sentence' at 0x7f0ae74df250>
# 1281
# <Element 'sentence' at 0x7f0ae74df2d0>
# 1963
# <Element 'sentence' at 0x7f0ae74df3d0>
# 70
# <Element 'sentence' at 0x7f0ae74df4d0>
# 1611
# <Element 'sentence' at 0x7f0ae74df550>
# 2342
# <Element 'sentence' at 0x7f0ae74df5d0>
# 151
# <Element 'sentence' at 0x7f0ae74df710>
# 1319
# <Element 'sentence' at 0x7f0ae74df790>
# 2850
# <Element 'sentence' at 0x7f0ae74df810>
# 2556
# <Element 'sentence' at 0x7f0ae74df890>
# 1734
# <Element 'sentence' at 0x7f0ae74df990>
# 1617
# <Element 'sentence' at 0x7f0ae74dfad0>
# 912
# <Element 'sentence' at 0x7f0ae74dfb50>
# 1476
# <Element 'sentence' at 0x7f0ae74dfc90>
# 1623
# <Element 'sentence' at 0x7f0ae74dfe50>
# 451
# <Element 'sentence' at 0x7f0ae74dff90>
# 1544
# <Element 'sentence' at 0x7f0ae74ec050>
# 149
# <Element 'sentence' at 0x7f0ae74ec0d0>
# 1222
# <Element 'sentence' at 0x7f0ae74ec150>
# 2956
# <Element 'sentence' at 0x7f0ae74ec250>
# 720
# <Element 'sentence' at 0x7f0ae74ec450>
# 740
# <Element 'sentence' at 0x7f0ae74ec510>
# 2442
# <Element 'sentence' at 0x7f0ae74ec5d0>
# 2125
# <Element 'sentence' at 0x7f0ae74ec650>
# 2564
# <Element 'sentence' at 0x7f0ae74ec750>
# 3016
# <Element 'sentence' at 0x7f0ae74ec890>
# 806
# <Element 'sentence' at 0x7f0ae74ec910>
# 2778
# <Element 'sentence' at 0x7f0ae74eca50>
# 2174
# <Element 'sentence' at 0x7f0ae74ecb50>
# 157
# <Element 'sentence' at 0x7f0ae74ecbd0>
# 1522
# <Element 'sentence' at 0x7f0ae74ecc50>
# 2535
# <Element 'sentence' at 0x7f0ae74eccd0>
# 1378
# <Element 'sentence' at 0x7f0ae74ecdd0>
# 2999
# <Element 'sentence' at 0x7f0ae74eced0>
# 1930
# <Element 'sentence' at 0x7f0ae74ecf50>
# 222
# <Element 'sentence' at 0x7f0ae74f8090>
# 2802
# <Element 'sentence' at 0x7f0ae74f8110>
# 1512
# <Element 'sentence' at 0x7f0ae74f8190>
# 1189
# <Element 'sentence' at 0x7f0ae74f8290>
# 1356
# <Element 'sentence' at 0x7f0ae74f8310>
# 2070
# <Element 'sentence' at 0x7f0ae74f8410>
# 2076
# <Element 'sentence' at 0x7f0ae74f8510>
# 603
# <Element 'sentence' at 0x7f0ae74f85d0>
# 1513
# <Element 'sentence' at 0x7f0ae74f8650>
# 1787
# <Element 'sentence' at 0x7f0ae74f86d0>
# 930
# <Element 'sentence' at 0x7f0ae74f8750>
# 612
# <Element 'sentence' at 0x7f0ae74f8890>
# 470
# <Element 'sentence' at 0x7f0ae74f8910>
# 1320
# <Element 'sentence' at 0x7f0ae74f8990>
# 2706
# <Element 'sentence' at 0x7f0ae74f8ad0>
# 2997
# <Element 'sentence' at 0x7f0ae74f8b50>
# 2954
# <Element 'sentence' at 0x7f0ae74f8c90>
# 1874
# <Element 'sentence' at 0x7f0ae74f8dd0>
# 2834
# <Element 'sentence' at 0x7f0ae74f8e50>
# 1546
# <Element 'sentence' at 0x7f0ae74f8f50>
# 1939
# <Element 'sentence' at 0x7f0ae74f8fd0>
# 2840
# <Element 'sentence' at 0x7f0ae7506090>
# 484
# <Element 'sentence' at 0x7f0ae7506110>
# 2003
# <Element 'sentence' at 0x7f0ae7506210>
# 1180
# <Element 'sentence' at 0x7f0ae7506350>
# 875
# <Element 'sentence' at 0x7f0ae75063d0>
# 809
# <Element 'sentence' at 0x7f0ae75064d0>
# 799
# <Element 'sentence' at 0x7f0ae7506610>
# 1668
# <Element 'sentence' at 0x7f0ae7506750>
# 274
# <Element 'sentence' at 0x7f0ae7506850>
# 2128
# <Element 'sentence' at 0x7f0ae7506990>
# 2237
# <Element 'sentence' at 0x7f0ae7506a10>
# 2456
# <Element 'sentence' at 0x7f0ae7506b50>
# 353
# <Element 'sentence' at 0x7f0ae7506c90>
# 2290
# <Element 'sentence' at 0x7f0ae7506e10>
# 1121
# <Element 'sentence' at 0x7f0ae7506e90>
# 134
# <Element 'sentence' at 0x7f0ae7506f10>
# 347
# <Element 'sentence' at 0x7f0ae7493050>
# 1813
# <Element 'sentence' at 0x7f0ae74930d0>
# 655
# <Element 'sentence' at 0x7f0ae74931d0>
# 2510
# <Element 'sentence' at 0x7f0ae7493310>
# 1615
# <Element 'sentence' at 0x7f0ae7493390>
# 844
# <Element 'sentence' at 0x7f0ae7493410>
# 884
# <Element 'sentence' at 0x7f0ae7493510>
# 2785
# <Element 'sentence' at 0x7f0ae7493610>
# 2443
# <Element 'sentence' at 0x7f0ae7493750>
# 81
# <Element 'sentence' at 0x7f0ae7493850>
# 89
# <Element 'sentence' at 0x7f0ae74938d0>
# 2114
# <Element 'sentence' at 0x7f0ae74939d0>
# 1670
# <Element 'sentence' at 0x7f0ae7493a50>
# 764
# <Element 'sentence' at 0x7f0ae7493b50>
# 525
# <Element 'sentence' at 0x7f0ae7493bd0>
# 435
# <Element 'sentence' at 0x7f0ae7493cd0>
# 914
# <Element 'sentence' at 0x7f0ae7493dd0>
# 177
# <Element 'sentence' at 0x7f0ae7493e50>
# 1776
# <Element 'sentence' at 0x7f0ae7493f90>
# 330
# <Element 'sentence' at 0x7f0ae749f050>
# 865
# <Element 'sentence' at 0x7f0ae749f0d0>
# 1791
# <Element 'sentence' at 0x7f0ae749f150>
# 549
# <Element 'sentence' at 0x7f0ae749f210>
# 1212
# <Element 'sentence' at 0x7f0ae749f310>
# 2169
# <Element 'sentence' at 0x7f0ae749f390>
# 2845
# <Element 'sentence' at 0x7f0ae749f4d0>
# 756
# <Element 'sentence' at 0x7f0ae749f5d0>
# 2600
# <Element 'sentence' at 0x7f0ae749f710>
# 2327
# <Element 'sentence' at 0x7f0ae749f790>
# 3012
# <Element 'sentence' at 0x7f0ae749f850>
# 1696
# <Element 'sentence' at 0x7f0ae749f990>
# 1479
# <Element 'sentence' at 0x7f0ae749fa90>
# 2909
# <Element 'sentence' at 0x7f0ae749fc10>
# 2937
# <Element 'sentence' at 0x7f0ae749fcd0>
# 1784
# <Element 'sentence' at 0x7f0ae749fd90>
# 453
# <Element 'sentence' at 0x7f0ae74ab210>
# 439
# <Element 'sentence' at 0x7f0ae74ab290>
# 2925
# <Element 'sentence' at 0x7f0ae74ab310>
# 929
# <Element 'sentence' at 0x7f0ae74ab390>
# 2804
# <Element 'sentence' at 0x7f0ae74ab410>
# 2077
# <Element 'sentence' at 0x7f0ae74ab550>
# 2622
# <Element 'sentence' at 0x7f0ae74ab6d0>
# 1093
# <Element 'sentence' at 0x7f0ae74ab790>
# 225
# <Element 'sentence' at 0x7f0ae74ab810>
# 1100
# <Element 'sentence' at 0x7f0ae74ab8d0>
# 2523
# <Element 'sentence' at 0x7f0ae74ab910>
# 970
# <Element 'sentence' at 0x7f0ae74aba50>
# 1935
# <Element 'sentence' at 0x7f0ae74abad0>
# 11
# <Element 'sentence' at 0x7f0ae74abb90>
# 2569
# <Element 'sentence' at 0x7f0ae74abc10>
# 3010
# <Element 'sentence' at 0x7f0ae74abc90>
# 1634
# <Element 'sentence' at 0x7f0ae74abd10>
# 2414
# <Element 'sentence' at 0x7f0ae74abdd0>
# 832
# <Element 'sentence' at 0x7f0ae74abf10>
# 1205
# <Element 'sentence' at 0x7f0ae74abf90>
# 1064
# <Element 'sentence' at 0x7f0ae74ba150>
# 2037
# <Element 'sentence' at 0x7f0ae74ba210>
# 1429
# <Element 'sentence' at 0x7f0ae74ba290>
# 2130
# <Element 'sentence' at 0x7f0ae74ba390>
# 2626
# <Element 'sentence' at 0x7f0ae74ba510>
# 1671
# <Element 'sentence' at 0x7f0ae74ba590>
# 1315
# <Element 'sentence' at 0x7f0ae74ba690>
# 2756
# <Element 'sentence' at 0x7f0ae74ba790>
# 548
# <Element 'sentence' at 0x7f0ae74ba850>
# 1446
# <Element 'sentence' at 0x7f0ae74ba950>
# 168
# <Element 'sentence' at 0x7f0ae74baa10>
# 922
# <Element 'sentence' at 0x7f0ae74bab10>
# 2797
# <Element 'sentence' at 0x7f0ae74bac10>
# 2863
# <Element 'sentence' at 0x7f0ae74bad50>
# 638
# <Element 'sentence' at 0x7f0ae74badd0>
# 2642
# <Element 'sentence' at 0x7f0ae74bae50>
# 1000
# <Element 'sentence' at 0x7f0ae74baed0>
# 200
# <Element 'sentence' at 0x7f0ae74baf50>
# 2887
# <Element 'sentence' at 0x7f0ae74bafd0>
# 993
# <Element 'sentence' at 0x7f0ae74c6090>
# 2464
# <Element 'sentence' at 0x7f0ae74c6110>
# 1667
# <Element 'sentence' at 0x7f0ae74c6190>
# 416
# <Element 'sentence' at 0x7f0ae74c6210>
# 2041
# <Element 'sentence' at 0x7f0ae74c6290>
# 240
# <Element 'sentence' at 0x7f0ae74c6390>
# 2135
# <Element 'sentence' at 0x7f0ae74c6410>
# 1393
# <Element 'sentence' at 0x7f0ae74c6510>
# 2259
# <Element 'sentence' at 0x7f0ae74c6590>
# 1080
# <Element 'sentence' at 0x7f0ae74c6710>
# 2695
# <Element 'sentence' at 0x7f0ae74c6790>
# 1506
# <Element 'sentence' at 0x7f0ae74c6810>
# 1837
# <Element 'sentence' at 0x7f0ae74c6890>
# 532
# <Element 'sentence' at 0x7f0ae74c6990>
# 3047
# <Element 'sentence' at 0x7f0ae74c6a90>
# 921
# <Element 'sentence' at 0x7f0ae74c6b10>
# 1733
# <Element 'sentence' at 0x7f0ae74c6c50>
# 2907
# <Element 'sentence' at 0x7f0ae74c6cd0>
# 1178
# <Element 'sentence' at 0x7f0ae74c6d50>
# 2265
# <Element 'sentence' at 0x7f0ae74c6dd0>
# 119
# <Element 'sentence' at 0x7f0ae74c6e50>
# 68
# <Element 'sentence' at 0x7f0ae74c6ed0>
# 2746
# <Element 'sentence' at 0x7f0ae74c6f50>
# 282
# <Element 'sentence' at 0x7f0ae74c6fd0>
# 1532
# <Element 'sentence' at 0x7f0ae7454110>
# 2800
# <Element 'sentence' at 0x7f0ae7454190>
# 1042
# <Element 'sentence' at 0x7f0ae7454210>
# 640
# <Element 'sentence' at 0x7f0ae7454350>
# 2238
# <Element 'sentence' at 0x7f0ae7454450>
# 1907
# <Element 'sentence' at 0x7f0ae74544d0>
# 78
# <Element 'sentence' at 0x7f0ae7454550>
# 891
# <Element 'sentence' at 0x7f0ae74545d0>
# 692
# <Element 'sentence' at 0x7f0ae7454650>
# 1580
# <Element 'sentence' at 0x7f0ae7454790>
# 2817
# <Element 'sentence' at 0x7f0ae7454810>
# 273
# <Element 'sentence' at 0x7f0ae7454950>
# 2679
# <Element 'sentence' at 0x7f0ae7454a10>
# 415
# <Element 'sentence' at 0x7f0ae7454ad0>
# 2046
# <Element 'sentence' at 0x7f0ae7454b90>
# 2450
# <Element 'sentence' at 0x7f0ae7454c10>
# 2170
# <Element 'sentence' at 0x7f0ae7454d90>
# 2624
# <Element 'sentence' at 0x7f0ae7454e90>
# 1822
# <Element 'sentence' at 0x7f0ae7454f10>
# 2374
# <Element 'sentence' at 0x7f0ae7454f90>
# 1896
# <Element 'sentence' at 0x7f0ae7462050>
# 341
# <Element 'sentence' at 0x7f0ae74620d0>
# 2245
# <Element 'sentence' at 0x7f0ae7462150>
# 1569
# <Element 'sentence' at 0x7f0ae7462250>
# 3064
# <Element 'sentence' at 0x7f0ae7462350>
# 2953
# <Element 'sentence' at 0x7f0ae7462450>
# 2129
# <Element 'sentence' at 0x7f0ae7462550>
# 2075
# <Element 'sentence' at 0x7f0ae7462690>
# 2180
# <Element 'sentence' at 0x7f0ae7462710>
# 1362
# <Element 'sentence' at 0x7f0ae7462790>
# 2710
# <Element 'sentence' at 0x7f0ae74628d0>
# 1373
# <Element 'sentence' at 0x7f0ae7462a90>
# 1370
# <Element 'sentence' at 0x7f0ae7462bd0>
# 1697
# <Element 'sentence' at 0x7f0ae7462c90>
# 276
# <Element 'sentence' at 0x7f0ae7462d10>
# 1287
# <Element 'sentence' at 0x7f0ae7462dd0>
# 1929
# <Element 'sentence' at 0x7f0ae7462e50>
# 2365
# <Element 'sentence' at 0x7f0ae7462ed0>
# 412
# <Element 'sentence' at 0x7f0ae7462f50>
# 2742
# <Element 'sentence' at 0x7f0ae746f050>
# 1758
# <Element 'sentence' at 0x7f0ae746f150>
# 1257
# <Element 'sentence' at 0x7f0ae746f1d0>
# 1908
# <Element 'sentence' at 0x7f0ae746f250>
# 842
# <Element 'sentence' at 0x7f0ae746f350>
# 931
# <Element 'sentence' at 0x7f0ae746f490>
# 863
# <Element 'sentence' at 0x7f0ae746f510>
# 2151
# <Element 'sentence' at 0x7f0ae746f590>
# 36
# <Element 'sentence' at 0x7f0ae746f690>
# 2967
# <Element 'sentence' at 0x7f0ae746f790>
# 1732
# <Element 'sentence' at 0x7f0ae746f890>
# 1800
# <Element 'sentence' at 0x7f0ae746f910>
# 1063
# <Element 'sentence' at 0x7f0ae746fa10>
# 2615
# <Element 'sentence' at 0x7f0ae746fa90>
# 271
# <Element 'sentence' at 0x7f0ae746fbd0>
# 2478
# <Element 'sentence' at 0x7f0ae746fd50>
# 523
# <Element 'sentence' at 0x7f0ae746fe90>
# 1657
# <Element 'sentence' at 0x7f0ae746ff50>
# 1674
# <Element 'sentence' at 0x7f0ae747b110>
# 472
# <Element 'sentence' at 0x7f0ae747b190>
# 1143
# <Element 'sentence' at 0x7f0ae747b290>
# 2618
# <Element 'sentence' at 0x7f0ae747b310>
# 1708
# <Element 'sentence' at 0x7f0ae747b390>
# 2771
# <Element 'sentence' at 0x7f0ae747b410>
# 2375
# <Element 'sentence' at 0x7f0ae747b490>
# 203
# <Element 'sentence' at 0x7f0ae747b510>
# 123
# <Element 'sentence' at 0x7f0ae747b590>
# 2927
# <Element 'sentence' at 0x7f0ae747b6d0>
# 916
# <Element 'sentence' at 0x7f0ae747b750>
# 2750
# <Element 'sentence' at 0x7f0ae747b810>
# 1137
# <Element 'sentence' at 0x7f0ae747b890>
# 2993
# <Element 'sentence' at 0x7f0ae747b9d0>
# 2453
# <Element 'sentence' at 0x7f0ae747bad0>
# 2661
# <Element 'sentence' at 0x7f0ae747bb50>
# 2590
# <Element 'sentence' at 0x7f0ae747bbd0>
# 515
# <Element 'sentence' at 0x7f0ae747bd10>
# 2321
# <Element 'sentence' at 0x7f0ae747bd90>
# 2282
# <Element 'sentence' at 0x7f0ae747be10>
# 1135
# <Element 'sentence' at 0x7f0ae747be90>
# 1577
# <Element 'sentence' at 0x7f0ae747bf10>
# 2572
# <Element 'sentence' at 0x7f0ae740a050>
# 2387
# <Element 'sentence' at 0x7f0ae740a190>
# 2517
# <Element 'sentence' at 0x7f0ae740a290>
# 1967
# <Element 'sentence' at 0x7f0ae740a310>
# 990
# <Element 'sentence' at 0x7f0ae740a450>
# 1414
# <Element 'sentence' at 0x7f0ae740a590>
# 664
# <Element 'sentence' at 0x7f0ae740a610>
# 2484
# <Element 'sentence' at 0x7f0ae740a690>
# 903
# <Element 'sentence' at 0x7f0ae740a790>
# 1609
# <Element 'sentence' at 0x7f0ae740a810>
# 2354
# <Element 'sentence' at 0x7f0ae740a890>
# 2979
# <Element 'sentence' at 0x7f0ae740a910>
# 1759
# <Element 'sentence' at 0x7f0ae740a990>
# 975
# <Element 'sentence' at 0x7f0ae740aa10>
# 2931
# <Element 'sentence' at 0x7f0ae740aa90>
# 2700
# <Element 'sentence' at 0x7f0ae740ab10>
# 1482
# <Element 'sentence' at 0x7f0ae740ab90>
# 1602
# <Element 'sentence' at 0x7f0ae740ac90>
# 1233
# <Element 'sentence' at 0x7f0ae740ad10>
# 2231
# <Element 'sentence' at 0x7f0ae740aed0>
# 2828
# <Element 'sentence' at 0x7f0ae740afd0>
# 121
# <Element 'sentence' at 0x7f0ae7416090>
# 2744
# <Element 'sentence' at 0x7f0ae7416110>
# 1824
# <Element 'sentence' at 0x7f0ae7416210>
# 2460
# <Element 'sentence' at 0x7f0ae7416350>
# 2500
# <Element 'sentence' at 0x7f0ae7416450>
# 600
# <Element 'sentence' at 0x7f0ae74164d0>
# 497
# <Element 'sentence' at 0x7f0ae7416550>
# 241
# <Element 'sentence' at 0x7f0ae74165d0>
# 557
# <Element 'sentence' at 0x7f0ae7416650>
# 677
# <Element 'sentence' at 0x7f0ae7416750>
# 531
# <Element 'sentence' at 0x7f0ae74167d0>
# 1367
# <Element 'sentence' at 0x7f0ae7416850>
# 2094
# <Element 'sentence' at 0x7f0ae74168d0>
# 1252
# <Element 'sentence' at 0x7f0ae74169d0>
# 3007
# <Element 'sentence' at 0x7f0ae7416ad0>
# 1650
# <Element 'sentence' at 0x7f0ae7416bd0>
# 1229
# <Element 'sentence' at 0x7f0ae7416c50>
# 399
# <Element 'sentence' at 0x7f0ae7416cd0>
# 1037
# <Element 'sentence' at 0x7f0ae7416d90>
# 1620
# <Element 'sentence' at 0x7f0ae7416ed0>
# 1035
# <Element 'sentence' at 0x7f0ae7416f50>
# 201
# <Element 'sentence' at 0x7f0ae7416fd0>
# 285
# <Element 'sentence' at 0x7f0ae7427110>
# 1260
# <Element 'sentence' at 0x7f0ae7427190>
# 3035
# <Element 'sentence' at 0x7f0ae74272d0>
# 840
# <Element 'sentence' at 0x7f0ae7427350>
# 2511
# <Element 'sentence' at 0x7f0ae74274d0>
# 895
# <Element 'sentence' at 0x7f0ae7427550>
# 2275
# <Element 'sentence' at 0x7f0ae7427610>
# 1342
# <Element 'sentence' at 0x7f0ae74276d0>
# 1124
# <Element 'sentence' at 0x7f0ae74277d0>
# 781
# <Element 'sentence' at 0x7f0ae74278d0>
# 2987
# <Element 'sentence' at 0x7f0ae74279d0>
# 2133
# <Element 'sentence' at 0x7f0ae7427ad0>
# 131
# <Element 'sentence' at 0x7f0ae7427b50>
# 1364
# <Element 'sentence' at 0x7f0ae7427c10>
# 2787
# <Element 'sentence' at 0x7f0ae7427d90>
# 948
# <Element 'sentence' at 0x7f0ae7427ed0>
# 2049
# <Element 'sentence' at 0x7f0ae7427fd0>
# 558
# <Element 'sentence' at 0x7f0ae7435090>
# 1059
# <Element 'sentence' at 0x7f0ae7435110>
# 767
# <Element 'sentence' at 0x7f0ae7435190>
# 1990
# <Element 'sentence' at 0x7f0ae7435210>
# 2366
# <Element 'sentence' at 0x7f0ae7435290>
# 2988
# <Element 'sentence' at 0x7f0ae7435390>
# 1385
# <Element 'sentence' at 0x7f0ae7435490>
# 1646
# <Element 'sentence' at 0x7f0ae7435610>
# 88
# <Element 'sentence' at 0x7f0ae7435690>
# 1270
# <Element 'sentence' at 0x7f0ae7435710>
# 1834
# <Element 'sentence' at 0x7f0ae7435790>
# 1451
# <Element 'sentence' at 0x7f0ae7435810>
# 55
# <Element 'sentence' at 0x7f0ae7435890>
# 2505
# <Element 'sentence' at 0x7f0ae74359d0>
# 768
# <Element 'sentence' at 0x7f0ae7435ad0>
# 2559
# <Element 'sentence' at 0x7f0ae7435b50>
# 242
# <Element 'sentence' at 0x7f0ae7435bd0>
# 2998
# <Element 'sentence' at 0x7f0ae7435c50>
# 2341
# <Element 'sentence' at 0x7f0ae7435cd0>
# 2908
# <Element 'sentence' at 0x7f0ae7435d50>
# 214
# <Element 'sentence' at 0x7f0ae7435e90>
# 1263
# <Element 'sentence' at 0x7f0ae7435f90>
# 650
# <Element 'sentence' at 0x7f0ae7441050>
# 2703
# <Element 'sentence' at 0x7f0ae74410d0>
# 142
# <Element 'sentence' at 0x7f0ae74411d0>
# 2947
# <Element 'sentence' at 0x7f0ae74412d0>
# 66
# <Element 'sentence' at 0x7f0ae7441350>
# 2020
# <Element 'sentence' at 0x7f0ae7441450>
# 2451
# <Element 'sentence' at 0x7f0ae7441550>
# 605
# <Element 'sentence' at 0x7f0ae74415d0>
# 314
# <Element 'sentence' at 0x7f0ae7441710>
# 2777
# <Element 'sentence' at 0x7f0ae7441850>
# 1085
# <Element 'sentence' at 0x7f0ae7441950>
# 1906
# <Element 'sentence' at 0x7f0ae7441a50>
# 124
# <Element 'sentence' at 0x7f0ae7441b50>
# 2816
# <Element 'sentence' at 0x7f0ae7441bd0>
# 1900
# <Element 'sentence' at 0x7f0ae7441c50>
# 732
# <Element 'sentence' at 0x7f0ae7441d90>
# 3011
# <Element 'sentence' at 0x7f0ae7441f10>
# 485
# <Element 'sentence' at 0x7f0ae7441f90>
# 1842
# <Element 'sentence' at 0x7f0ae73cd0d0>
# 238
# <Element 'sentence' at 0x7f0ae73cd150>
# 205
# <Element 'sentence' at 0x7f0ae73cd290>
# 1955
# <Element 'sentence' at 0x7f0ae73cd310>
# 1160
# <Element 'sentence' at 0x7f0ae73cd3d0>
# 2989
# <Element 'sentence' at 0x7f0ae73cd450>
# 1398
# <Element 'sentence' at 0x7f0ae73cd590>
# 1372
# <Element 'sentence' at 0x7f0ae73cd790>
# 467
# <Element 'sentence' at 0x7f0ae73cd810>
# 1400
# <Element 'sentence' at 0x7f0ae73cd950>
# 47
# <Element 'sentence' at 0x7f0ae73cd9d0>
# 1066
# <Element 'sentence' at 0x7f0ae73cdad0>
# 1607
# <Element 'sentence' at 0x7f0ae73cdb50>
# 910
# <Element 'sentence' at 0x7f0ae73cdbd0>
# 2379
# <Element 'sentence' at 0x7f0ae73cdc50>
# 361
# <Element 'sentence' at 0x7f0ae73cdcd0>
# 344
# <Element 'sentence' at 0x7f0ae73cde90>
# 1368
# <Element 'sentence' at 0x7f0ae73cdf10>
# 2038
# <Element 'sentence' at 0x7f0ae73cdf90>
# 1673
# <Element 'sentence' at 0x7f0ae73db050>
# 2871
# <Element 'sentence' at 0x7f0ae73db150>
# 2530
# <Element 'sentence' at 0x7f0ae73db1d0>
# 1603
# <Element 'sentence' at 0x7f0ae73db250>
# 381
# <Element 'sentence' at 0x7f0ae73db2d0>
# 312
# <Element 'sentence' at 0x7f0ae73db550>
# 2795
# <Element 'sentence' at 0x7f0ae73db650>
# 1865
# <Element 'sentence' at 0x7f0ae73db7d0>
# 1681
# <Element 'sentence' at 0x7f0ae73db850>
# 2973
# <Element 'sentence' at 0x7f0ae73db9d0>
# 2612
# <Element 'sentence' at 0x7f0ae73dbb10>
# 1864
# <Element 'sentence' at 0x7f0ae73dbb90>
# 2629
# <Element 'sentence' at 0x7f0ae73dbc10>
# 2207
# <Element 'sentence' at 0x7f0ae73dbc90>
# 249
# <Element 'sentence' at 0x7f0ae73dbd10>
# 1283
# <Element 'sentence' at 0x7f0ae73dbe50>
# 1423
# <Element 'sentence' at 0x7f0ae73dbf90>
# 288
# <Element 'sentence' at 0x7f0ae73e8050>
# 256
# <Element 'sentence' at 0x7f0ae73e80d0>
# 2280
# <Element 'sentence' at 0x7f0ae73e8150>
# 322
# <Element 'sentence' at 0x7f0ae73e81d0>
# 1072
# <Element 'sentence' at 0x7f0ae73e82d0>
# 2826
# <Element 'sentence' at 0x7f0ae73e8350>
# 1390
# <Element 'sentence' at 0x7f0ae73e83d0>
# 1739
# <Element 'sentence' at 0x7f0ae73e8510>
# 2419
# <Element 'sentence' at 0x7f0ae73e8610>
# 785
# <Element 'sentence' at 0x7f0ae73e8690>
# 82
# <Element 'sentence' at 0x7f0ae73e8710>
# 1549
# <Element 'sentence' at 0x7f0ae73e8810>
# 2086
# <Element 'sentence' at 0x7f0ae73e8990>
# 300
# <Element 'sentence' at 0x7f0ae73e8c10>
# 262
# <Element 'sentence' at 0x7f0ae73e8c90>
# 2521
# <Element 'sentence' at 0x7f0ae73e8d10>
# 2284
# <Element 'sentence' at 0x7f0ae73e8d90>
# 851
# <Element 'sentence' at 0x7f0ae73e8e90>
# 1008
# <Element 'sentence' at 0x7f0ae73e8f90>
# 2261
# <Element 'sentence' at 0x7f0ae73f5110>
# 2793
# <Element 'sentence' at 0x7f0ae73f5190>
# 291
# <Element 'sentence' at 0x7f0ae73f5290>
# 1185
# <Element 'sentence' at 0x7f0ae73f5310>
# 1719
# <Element 'sentence' at 0x7f0ae73f53d0>
# 391
# <Element 'sentence' at 0x7f0ae73f5590>
# 1595
# <Element 'sentence' at 0x7f0ae73f5790>
# 1150
# <Element 'sentence' at 0x7f0ae73f5810>
# 2362
# <Element 'sentence' at 0x7f0ae73f58d0>
# 116
# <Element 'sentence' at 0x7f0ae73f5a10>
# 2119
# <Element 'sentence' at 0x7f0ae73f5ad0>
# 2647
# <Element 'sentence' at 0x7f0ae73f5bd0>
# 2108
# <Element 'sentence' at 0x7f0ae73f5c50>
# 789
# <Element 'sentence' at 0x7f0ae73f5cd0>
# 570
# <Element 'sentence' at 0x7f0ae73f5d50>
# 980
# <Element 'sentence' at 0x7f0ae73f5e50>
# 668
# <Element 'sentence' at 0x7f0ae73f5f90>
# 1106
# <Element 'sentence' at 0x7f0ae74050d0>
# 140
# <Element 'sentence' at 0x7f0ae74051d0>
# 1418
# <Element 'sentence' at 0x7f0ae74052d0>
# 539
# <Element 'sentence' at 0x7f0ae7405350>
# 621
# <Element 'sentence' at 0x7f0ae7405450>
# 2360
# <Element 'sentence' at 0x7f0ae74055d0>
# 2397
# <Element 'sentence' at 0x7f0ae7405650>
# 2449
# <Element 'sentence' at 0x7f0ae74056d0>
# 1126
# <Element 'sentence' at 0x7f0ae7405850>
# 1745
# <Element 'sentence' at 0x7f0ae7405a10>
# 2205
# <Element 'sentence' at 0x7f0ae7405a90>
# 1065
# <Element 'sentence' at 0x7f0ae7405b10>
# 987
# <Element 'sentence' at 0x7f0ae7405bd0>
# 363
# <Element 'sentence' at 0x7f0ae7405c10>
# 1276
# <Element 'sentence' at 0x7f0ae7405c90>
# 2911
# <Element 'sentence' at 0x7f0ae7405d10>
# 2714
# <Element 'sentence' at 0x7f0ae7405d90>
# 2900
# <Element 'sentence' at 0x7f0ae7405e10>
# 2177
# <Element 'sentence' at 0x7f0ae7405e90>
# 164
# <Element 'sentence' at 0x7f0ae7405f10>
# 39
# <Element 'sentence' at 0x7f0ae7391050>
# 3019
# <Element 'sentence' at 0x7f0ae7391190>
# 1517
# <Element 'sentence' at 0x7f0ae7391210>
# 1090
# <Element 'sentence' at 0x7f0ae73912d0>
# 1678
# <Element 'sentence' at 0x7f0ae7391350>
# 2469
# <Element 'sentence' at 0x7f0ae7391450>
# 2429
# <Element 'sentence' at 0x7f0ae73914d0>
# 1986
# <Element 'sentence' at 0x7f0ae7391610>
# 1088
# <Element 'sentence' at 0x7f0ae7391790>
# 678
# <Element 'sentence' at 0x7f0ae73918d0>
# 417
# <Element 'sentence' at 0x7f0ae7391950>
# 625
# <Element 'sentence' at 0x7f0ae7391a10>
# 2035
# <Element 'sentence' at 0x7f0ae7391b50>
# 636
# <Element 'sentence' at 0x7f0ae7391bd0>
# 1808
# <Element 'sentence' at 0x7f0ae7391c50>
# 1921
# <Element 'sentence' at 0x7f0ae7391d50>
# 1872
# <Element 'sentence' at 0x7f0ae7391e50>
# 1413
# <Element 'sentence' at 0x7f0ae7391f90>
# 369
# <Element 'sentence' at 0x7f0ae739e050>
# 321
# <Element 'sentence' at 0x7f0ae739e0d0>
# 2636
# <Element 'sentence' at 0x7f0ae739e1d0>
# 357
# <Element 'sentence' at 0x7f0ae739e310>
# 1230
# <Element 'sentence' at 0x7f0ae739e390>
# 1006
# <Element 'sentence' at 0x7f0ae739e410>
# 3075
# <Element 'sentence' at 0x7f0ae739e510>
# 216
# <Element 'sentence' at 0x7f0ae739e590>
# 3045
# <Element 'sentence' at 0x7f0ae739e6d0>
# 1688
# <Element 'sentence' at 0x7f0ae739e750>
# 2098
# <Element 'sentence' at 0x7f0ae739e7d0>
# 1877
# <Element 'sentence' at 0x7f0ae739e850>
# 129
# <Element 'sentence' at 0x7f0ae739e8d0>
# 235
# <Element 'sentence' at 0x7f0ae739ea10>
# 3055
# <Element 'sentence' at 0x7f0ae739eb50>
# 2865
# <Element 'sentence' at 0x7f0ae739ec50>
# 1300
# <Element 'sentence' at 0x7f0ae739ecd0>
# 1197
# <Element 'sentence' at 0x7f0ae739edd0>
# 2538
# <Element 'sentence' at 0x7f0ae739ee50>
# 1403
# <Element 'sentence' at 0x7f0ae739eed0>
# 2676
# <Element 'sentence' at 0x7f0ae739efd0>
# 75
# <Element 'sentence' at 0x7f0ae73ab090>
# 2319
# <Element 'sentence' at 0x7f0ae73ab150>
# 452
# <Element 'sentence' at 0x7f0ae73ab350>
# 2498
# <Element 'sentence' at 0x7f0ae73ab450>
# 2515
# <Element 'sentence' at 0x7f0ae73ab550>
# 2320
# <Element 'sentence' at 0x7f0ae73ab650>
# 2051
# <Element 'sentence' at 0x7f0ae73ab6d0>
# 1017
# <Element 'sentence' at 0x7f0ae73ab750>
# 971
# <Element 'sentence' at 0x7f0ae73ab7d0>
# 3083
# <Element 'sentence' at 0x7f0ae73ab8d0>
# 1687
# <Element 'sentence' at 0x7f0ae73ab950>
# 2593
# <Element 'sentence' at 0x7f0ae73aba50>
# 1507
# <Element 'sentence' at 0x7f0ae73abad0>
# 336
# <Element 'sentence' at 0x7f0ae73abb90>
# 2391
# <Element 'sentence' at 0x7f0ae73abc50>
# 786
# <Element 'sentence' at 0x7f0ae73abcd0>
# 1616
# <Element 'sentence' at 0x7f0ae73abdd0>
# 1062
# <Element 'sentence' at 0x7f0ae73abed0>
# 1982
# <Element 'sentence' at 0x7f0ae73abf50>
# 2704
# <Element 'sentence' at 0x7f0ae73ba090>
# 2930
# <Element 'sentence' at 0x7f0ae73ba110>
# 343
# <Element 'sentence' at 0x7f0ae73ba190>
# 1152
# <Element 'sentence' at 0x7f0ae73ba2d0>
# 1868
# <Element 'sentence' at 0x7f0ae73ba350>
# 1353
# <Element 'sentence' at 0x7f0ae73ba410>
# 977
# <Element 'sentence' at 0x7f0ae73ba490>
# 2747
# <Element 'sentence' at 0x7f0ae73ba5d0>
# 2102
# <Element 'sentence' at 0x7f0ae73ba650>
# 967
# <Element 'sentence' at 0x7f0ae73ba750>
# 1774
# <Element 'sentence' at 0x7f0ae73ba7d0>
# 1685
# <Element 'sentence' at 0x7f0ae73ba890>
# 932
# <Element 'sentence' at 0x7f0ae73ba910>
# 2501
# <Element 'sentence' at 0x7f0ae73baa10>
# 1873
# <Element 'sentence' at 0x7f0ae73baa90>
# 1753
# <Element 'sentence' at 0x7f0ae73bab50>
# 892
# <Element 'sentence' at 0x7f0ae73babd0>
# 1241
# <Element 'sentence' at 0x7f0ae73bac50>
# 135
# <Element 'sentence' at 0x7f0ae73bacd0>
# 1801
# <Element 'sentence' at 0x7f0ae73bae10>
# 2902
# <Element 'sentence' at 0x7f0ae73baf50>
# 2062
# <Element 'sentence' at 0x7f0ae73bafd0>
# 2656
# <Element 'sentence' at 0x7f0ae73c7110>
# 652
# <Element 'sentence' at 0x7f0ae73c7210>
# 170
# <Element 'sentence' at 0x7f0ae73c7310>
# 665
# <Element 'sentence' at 0x7f0ae73c7390>
# 787
# <Element 'sentence' at 0x7f0ae73c7410>
# 814
# <Element 'sentence' at 0x7f0ae73c7490>
# 2047
# <Element 'sentence' at 0x7f0ae73c7590>
# 3039
# <Element 'sentence' at 0x7f0ae73c7610>
# 1371
# <Element 'sentence' at 0x7f0ae73c76d0>
# 2666
# <Element 'sentence' at 0x7f0ae73c7790>
# 741
# <Element 'sentence' at 0x7f0ae73c7890>
# 1748
# <Element 'sentence' at 0x7f0ae73c79d0>
# 774
# <Element 'sentence' at 0x7f0ae73c7a50>
# 2246
# <Element 'sentence' at 0x7f0ae73c7bd0>
# 1055
# <Element 'sentence' at 0x7f0ae73c7c50>
# 401
# <Element 'sentence' at 0x7f0ae73c7cd0>
# 2032
# <Element 'sentence' at 0x7f0ae73c7e50>
# 1780
# <Element 'sentence' at 0x7f0ae73c7ed0>
# 150
# <Element 'sentence' at 0x7f0ae7354050>
# 1581
# <Element 'sentence' at 0x7f0ae73540d0>
# 302
# <Element 'sentence' at 0x7f0ae73541d0>
# 204
# <Element 'sentence' at 0x7f0ae73542d0>
# 2080
# <Element 'sentence' at 0x7f0ae7354510>
# 964
# <Element 'sentence' at 0x7f0ae73545d0>
# 2780
# <Element 'sentence' at 0x7f0ae7354710>
# 1105
# <Element 'sentence' at 0x7f0ae7354810>
# 1484
# <Element 'sentence' at 0x7f0ae7354910>
# 17
# <Element 'sentence' at 0x7f0ae7354990>
# 2506
# ...
# 1235
# <Element 'sentence' at 0x7f0ae6f3ba10>
# 1773
# <Element 'sentence' at 0x7f0ae6f3ba90>
# 1854
# <Element 'sentence' at 0x7f0ae6f3bb10>
# 1511
# <Element 'sentence' at 0x7f0ae6f3bc10>
# 563
# <Element 'sentence' at 0x7f0ae6f3bd10>
# 2668
# <Element 'sentence' at 0x7f0ae6f3be10>
# 1535
# <Element 'sentence' at 0x7f0ae6f3bfd0>
# 2991
# <Element 'sentence' at 0x7f0ae6f48110>
# 132
# <Element 'sentence' at 0x7f0ae6f48210>
# 1011
# <Element 'sentence' at 0x7f0ae6f48290>
# 466
# <Element 'sentence' at 0x7f0ae6f48310>
# 208
# <Element 'sentence' at 0x7f0ae6f48410>
# 2314
# <Element 'sentence' at 0x7f0ae6f48510>
# 2552
# <Element 'sentence' at 0x7f0ae6f48590>
# 634
# <Element 'sentence' at 0x7f0ae6f48690>
# 1926
# <Element 'sentence' at 0x7f0ae6f48810>
# 880
# <Element 'sentence' at 0x7f0ae6f48890>
# 721
# <Element 'sentence' at 0x7f0ae6f48910>
# 2849
# <Element 'sentence' at 0x7f0ae6f48990>
# 360
# <Element 'sentence' at 0x7f0ae6f48a50>
# 1572
# <Element 'sentence' at 0x7f0ae6f48ad0>
# 247
# <Element 'sentence' at 0x7f0ae6f48b50>
# 2417
# <Element 'sentence' at 0x7f0ae6f48c50>
# 1715
# <Element 'sentence' at 0x7f0ae6f48cd0>
# 500
# <Element 'sentence' at 0x7f0ae6f48e10>
# 859
# <Element 'sentence' at 0x7f0ae6f48f10>
# 1504
# <Element 'sentence' at 0x7f0ae6ed6090>
# 2474
# <Element 'sentence' at 0x7f0ae6ed6110>
# 158
# <Element 'sentence' at 0x7f0ae6ed6210>
# 2421
# <Element 'sentence' at 0x7f0ae6ed6290>
# 2567
# <Element 'sentence' at 0x7f0ae6ed6310>
# 1961
# <Element 'sentence' at 0x7f0ae6ed63d0>
# 2879
# <Element 'sentence' at 0x7f0ae6ed64d0>
# 946
# <Element 'sentence' at 0x7f0ae6ed6550>
# 1565
# <Element 'sentence' at 0x7f0ae6ed6650>
# 2854
# <Element 'sentence' at 0x7f0ae6ed6750>
# 2585
# <Element 'sentence' at 0x7f0ae6ed68d0>
# 2692
# <Element 'sentence' at 0x7f0ae6ed6a50>
# 1146
# <Element 'sentence' at 0x7f0ae6ed6ad0>
# 413
# <Element 'sentence' at 0x7f0ae6ed6b50>
# 2634
# <Element 'sentence' at 0x7f0ae6ed6bd0>
# 2232
# <Element 'sentence' at 0x7f0ae6ed6c50>
# 3018
# <Element 'sentence' at 0x7f0ae6ed6d50>
# 49
# <Element 'sentence' at 0x7f0ae6ed6e50>
# 2614
# <Element 'sentence' at 0x7f0ae6ed6ed0>
# 981
# <Element 'sentence' at 0x7f0ae6ed6f50>
# 259
# <Element 'sentence' at 0x7f0ae6ee3090>
# 2774
# <Element 'sentence' at 0x7f0ae6ee3110>
# 2256
# <Element 'sentence' at 0x7f0ae6ee3190>
# 1550
# <Element 'sentence' at 0x7f0ae6ee3210>
# 1721
# <Element 'sentence' at 0x7f0ae6ee3290>
# 2146
# <Element 'sentence' at 0x7f0ae6ee33d0>
# 1399
# <Element 'sentence' at 0x7f0ae6ee34d0>
# 2400
# <Element 'sentence' at 0x7f0ae6ee3610>
# 1917
# <Element 'sentence' at 0x7f0ae6ee3690>
# 1302
# <Element 'sentence' at 0x7f0ae6ee3790>
# 2815
# <Element 'sentence' at 0x7f0ae6ee3810>
# 534
# <Element 'sentence' at 0x7f0ae6ee3950>
# 429
# <Element 'sentence' at 0x7f0ae6ee3a50>
# 978
# <Element 'sentence' at 0x7f0ae6ee3ad0>
# 2301
# <Element 'sentence' at 0x7f0ae6ee3bd0>
# 2087
# <Element 'sentence' at 0x7f0ae6ee3c50>
# 2378
# <Element 'sentence' at 0x7f0ae6ee3d50>
# 2722
# <Element 'sentence' at 0x7f0ae6ee3ed0>
# 1058
# <Element 'sentence' at 0x7f0ae6eef090>
# 2252
# <Element 'sentence' at 0x7f0ae6eef1d0>
# 2781
# <Element 'sentence' at 0x7f0ae6eef2d0>
# 927
# <Element 'sentence' at 0x7f0ae6eef3d0>
# 2293
# <Element 'sentence' at 0x7f0ae6eef450>
# 424
# <Element 'sentence' at 0x7f0ae6eef4d0>
# 2316
# <Element 'sentence' at 0x7f0ae6eef550>
# 2008
# <Element 'sentence' at 0x7f0ae6eef5d0>
# 1726
# <Element 'sentence' at 0x7f0ae6eef650>
# 2779
# <Element 'sentence' at 0x7f0ae6eef6d0>
# 2955
# <Element 'sentence' at 0x7f0ae6eef7d0>
# 2697
# <Element 'sentence' at 0x7f0ae6eef950>
# 1575
# <Element 'sentence' at 0x7f0ae6eef9d0>
# 1007
# <Element 'sentence' at 0x7f0ae6eefa50>
# 979
# <Element 'sentence' at 0x7f0ae6eefad0>
# 2357
# <Element 'sentence' at 0x7f0ae6eefbd0>
# 1087
# <Element 'sentence' at 0x7f0ae6eefcd0>
# 2529
# <Element 'sentence' at 0x7f0ae6eefdd0>
# 2111
# <Element 'sentence' at 0x7f0ae6eefed0>
# 71
# <Element 'sentence' at 0x7f0ae6eeff50>
# 1619
# <Element 'sentence' at 0x7f0ae6eeffd0>
# 400
# <Element 'sentence' at 0x7f0ae6efc190>
# 2628
# <Element 'sentence' at 0x7f0ae6efc210>
# 2212
# <Element 'sentence' at 0x7f0ae6efc310>
# 2153
# <Element 'sentence' at 0x7f0ae6efc410>
# 212
# <Element 'sentence' at 0x7f0ae6efc4d0>
# 443
# <Element 'sentence' at 0x7f0ae6efc5d0>
# 511
# <Element 'sentence' at 0x7f0ae6efc650>
# 194
# <Element 'sentence' at 0x7f0ae6efc750>
# 2620
# <Element 'sentence' at 0x7f0ae6efc850>
# 1593
# <Element 'sentence' at 0x7f0ae6efc8d0>
# 83
# <Element 'sentence' at 0x7f0ae6efc950>
# 1299
# <Element 'sentence' at 0x7f0ae6efca50>
# 366
# <Element 'sentence' at 0x7f0ae6efcb50>
# 2686
# <Element 'sentence' at 0x7f0ae6efcc50>
# 368
# <Element 'sentence' at 0x7f0ae6efccd0>
# 784
# <Element 'sentence' at 0x7f0ae6efcdd0>
# 647
# <Element 'sentence' at 0x7f0ae6efce50>
# 1496
# <Element 'sentence' at 0x7f0ae6e8b050>
# 2602
# <Element 'sentence' at 0x7f0ae6e8b190>
# 1450
# <Element 'sentence' at 0x7f0ae6e8b310>
# 1410
# <Element 'sentence' at 0x7f0ae6e8b410>
# 688
# <Element 'sentence' at 0x7f0ae6e8b490>
# 2097
# <Element 'sentence' at 0x7f0ae6e8b590>
# 527
# <Element 'sentence' at 0x7f0ae6e8b610>
# 2665
# <Element 'sentence' at 0x7f0ae6e8b690>
# 1795
# <Element 'sentence' at 0x7f0ae6e8b790>
# 2230
# <Element 'sentence' at 0x7f0ae6e8b810>
# 114
# <Element 'sentence' at 0x7f0ae6e8b890>
# 2224
# <Element 'sentence' at 0x7f0ae6e8b910>
# 3033
# <Element 'sentence' at 0x7f0ae6e8b990>
# 1614
# <Element 'sentence' at 0x7f0ae6e8bad0>
# 1003
# <Element 'sentence' at 0x7f0ae6e8bb50>
# 1392
# <Element 'sentence' at 0x7f0ae6e8bc50>
# 680
# <Element 'sentence' at 0x7f0ae6e8bcd0>
# 436
# <Element 'sentence' at 0x7f0ae6e8bd50>
# 697
# <Element 'sentence' at 0x7f0ae6e8bed0>
# 1159
# <Element 'sentence' at 0x7f0ae6e8bfd0>
# 2757
# <Element 'sentence' at 0x7f0ae6e991d0>
# 232
# <Element 'sentence' at 0x7f0ae6e99250>
# 2122
# <Element 'sentence' at 0x7f0ae6e992d0>
# 1508
# <Element 'sentence' at 0x7f0ae6e99350>
# 278
# <Element 'sentence' at 0x7f0ae6e99450>
# 2783
# <Element 'sentence' at 0x7f0ae6e99550>
# 327
# <Element 'sentence' at 0x7f0ae6e99650>
# 2731
# <Element 'sentence' at 0x7f0ae6e997d0>
# 218
# <Element 'sentence' at 0x7f0ae6e99850>
# 5
# <Element 'sentence' at 0x7f0ae6e998d0>
# 1749
# <Element 'sentence' at 0x7f0ae6e99ad0>
# 820
# <Element 'sentence' at 0x7f0ae6e99b50>
# 245
# <Element 'sentence' at 0x7f0ae6e99c50>
# 1979
# <Element 'sentence' at 0x7f0ae6e99cd0>
# 202
# <Element 'sentence' at 0x7f0ae6e99d50>
# 1142
# <Element 'sentence' at 0x7f0ae6e99ed0>
# 1211
# <Element 'sentence' at 0x7f0ae6e99f90>
# 2294
# <Element 'sentence' at 0x7f0ae6ea5050>
# 1583
# <Element 'sentence' at 0x7f0ae6ea50d0>
# 2372
# <Element 'sentence' at 0x7f0ae6ea5150>
# 1438
# <Element 'sentence' at 0x7f0ae6ea5390>
# 1949
# <Element 'sentence' at 0x7f0ae6ea5410>
# 2663
# <Element 'sentence' at 0x7f0ae6ea5490>
# 952
# <Element 'sentence' at 0x7f0ae6ea5590>
# 1858
# <Element 'sentence' at 0x7f0ae6ea5690>
# 2235
# <Element 'sentence' at 0x7f0ae6ea5810>
# 2825
# <Element 'sentence' at 0x7f0ae6ea5890>
# 514
# <Element 'sentence' at 0x7f0ae6ea5910>
# 1048
# <Element 'sentence' at 0x7f0ae6ea5c10>
# 1729
# <Element 'sentence' at 0x7f0ae6ea5cd0>
# 1904
# <Element 'sentence' at 0x7f0ae6ea5d50>
# 1182
# <Element 'sentence' at 0x7f0ae6ea5e50>
# 2455
# <Element 'sentence' at 0x7f0ae6ea5f90>
# 1213
# <Element 'sentence' at 0x7f0ae6eb5090>
# 1394
# <Element 'sentence' at 0x7f0ae6eb5150>
# 1924
# <Element 'sentence' at 0x7f0ae6eb5290>
# 2268
# <Element 'sentence' at 0x7f0ae6eb5350>
# 2171
# <Element 'sentence' at 0x7f0ae6eb5490>
# 790
# <Element 'sentence' at 0x7f0ae6eb5510>
# 552
# <Element 'sentence' at 0x7f0ae6eb5710>
# 1859
# <Element 'sentence' at 0x7f0ae6eb57d0>
# 2589
# <Element 'sentence' at 0x7f0ae6eb5850>
# 2643
# <Element 'sentence' at 0x7f0ae6eb58d0>
# 733
# <Element 'sentence' at 0x7f0ae6eb59d0>
# 870
# <Element 'sentence' at 0x7f0ae6eb5a50>
# 1910
# <Element 'sentence' at 0x7f0ae6eb5ad0>
# 2029
# <Element 'sentence' at 0x7f0ae6eb5b50>
# 2242
# <Element 'sentence' at 0x7f0ae6eb5c90>
# 2085
# <Element 'sentence' at 0x7f0ae6eb5d90>
# 543
# <Element 'sentence' at 0x7f0ae6eb5e90>
# 925
# <Element 'sentence' at 0x7f0ae6eb5f90>
# 724
# <Element 'sentence' at 0x7f0ae6ec2050>
# 2139
# <Element 'sentence' at 0x7f0ae6ec20d0>
# 1771
# <Element 'sentence' at 0x7f0ae6ec2210>
# 383
# <Element 'sentence' at 0x7f0ae6ec22d0>
# 2355
# <Element 'sentence' at 0x7f0ae6ec2350>
# 2200
# <Element 'sentence' at 0x7f0ae6ec23d0>
# 723
# <Element 'sentence' at 0x7f0ae6ec2450>
# 2043
# <Element 'sentence' at 0x7f0ae6ec24d0>
# 2258
# <Element 'sentence' at 0x7f0ae6ec25d0>
# 1960
# <Element 'sentence' at 0x7f0ae6ec2710>
# 2006
# <Element 'sentence' at 0x7f0ae6ec2790>
# 2223
# <Element 'sentence' at 0x7f0ae6ec2890>
# 23
# <Element 'sentence' at 0x7f0ae6ec29d0>
# 2711
# <Element 'sentence' at 0x7f0ae6ec2b50>
# 1899
# <Element 'sentence' at 0x7f0ae6ec2bd0>
# 495
# <Element 'sentence' at 0x7f0ae6ec2c50>
# 1606
# <Element 'sentence' at 0x7f0ae6ec2dd0>
# 1018
# <Element 'sentence' at 0x7f0ae6ec2ed0>
# 1761
# <Element 'sentence' at 0x7f0ae6ec2f50>
# 554
# <Element 'sentence' at 0x7f0ae6ec2fd0>
# 2728
# <Element 'sentence' at 0x7f0ae6e4e110>
# 1964
# <Element 'sentence' at 0x7f0ae6e4e250>
# 2808
# <Element 'sentence' at 0x7f0ae6e4e510>
# 775
# <Element 'sentence' at 0x7f0ae6e4e610>
# 2424
# <Element 'sentence' at 0x7f0ae6e4e710>
# 1689
# <Element 'sentence' at 0x7f0ae6e4e810>
# 1894
# <Element 'sentence' at 0x7f0ae6e4e890>
# 1078
# <Element 'sentence' at 0x7f0ae6e4e990>
# 1492
# <Element 'sentence' at 0x7f0ae6e4ead0>
# 808
# <Element 'sentence' at 0x7f0ae6e4ebd0>
# 1472
# <Element 'sentence' at 0x7f0ae6e4ecd0>
# 1038
# <Element 'sentence' at 0x7f0ae6e4ee10>
# 818
# <Element 'sentence' at 0x7f0ae6e4ee90>
# 861
# <Element 'sentence' at 0x7f0ae6e4ef10>
# 544
# <Element 'sentence' at 0x7f0ae6e5c090>
# 1959
# <Element 'sentence' at 0x7f0ae6e5c190>
# 315
# <Element 'sentence' at 0x7f0ae6e5c290>
# 2573
# <Element 'sentence' at 0x7f0ae6e5c450>
# 1996
# <Element 'sentence' at 0x7f0ae6e5c550>
# 509
# <Element 'sentence' at 0x7f0ae6e5c5d0>
# 1600
# <Element 'sentence' at 0x7f0ae6e5c710>
# 719
# <Element 'sentence' at 0x7f0ae6e5c890>
# 141
# <Element 'sentence' at 0x7f0ae6e5c9d0>
# 1920
# <Element 'sentence' at 0x7f0ae6e5ca50>
# 760
# <Element 'sentence' at 0x7f0ae6e5cb10>
# 193
# <Element 'sentence' at 0x7f0ae6e5cbd0>
# 1016
# <Element 'sentence' at 0x7f0ae6e5cc50>
# 507
# <Element 'sentence' at 0x7f0ae6e5ccd0>
# 1255
# <Element 'sentence' at 0x7f0ae6e5cdd0>
# 667
# <Element 'sentence' at 0x7f0ae6e5cf10>
# 1992
# <Element 'sentence' at 0x7f0ae6e6a090>
# 2430
# <Element 'sentence' at 0x7f0ae6e6a190>
# 2406
# <Element 'sentence' at 0x7f0ae6e6a210>
# 1021
# <Element 'sentence' at 0x7f0ae6e6a350>
# 1209
# <Element 'sentence' at 0x7f0ae6e6a3d0>
# 1701
# <Element 'sentence' at 0x7f0ae6e6a4d0>
# 2570
# <Element 'sentence' at 0x7f0ae6e6a550>
# 287
# <Element 'sentence' at 0x7f0ae6e6a5d0>
# 681
# <Element 'sentence' at 0x7f0ae6e6a650>
# 866
# <Element 'sentence' at 0x7f0ae6e6a6d0>
# 1248
# <Element 'sentence' at 0x7f0ae6e6a790>
# 2857
# <Element 'sentence' at 0x7f0ae6e6a810>
# 266
# <Element 'sentence' at 0x7f0ae6e6a8d0>
# 811
# <Element 'sentence' at 0x7f0ae6e6a9d0>
# 2693
# <Element 'sentence' at 0x7f0ae6e6aa50>
# 504
# <Element 'sentence' at 0x7f0ae6e6ab50>
# 1845
# <Element 'sentence' at 0x7f0ae6e6ac50>
# 434
# <Element 'sentence' at 0x7f0ae6e6acd0>
# 2479
# <Element 'sentence' at 0x7f0ae6e6ae50>
# 1407
# <Element 'sentence' at 0x7f0ae6e6af50>
# 1113
# <Element 'sentence' at 0x7f0ae6e750d0>
# 1976
# <Element 'sentence' at 0x7f0ae6e75150>
# 1643
# <Element 'sentence' at 0x7f0ae6e751d0>
# 2431
# <Element 'sentence' at 0x7f0ae6e752d0>
# 905
# <Element 'sentence' at 0x7f0ae6e753d0>
# 2196
# <Element 'sentence' at 0x7f0ae6e754d0>
# 1878
# <Element 'sentence' at 0x7f0ae6e75650>
# 758
# <Element 'sentence' at 0x7f0ae6e75790>
# 1131
# <Element 'sentence' at 0x7f0ae6e758d0>
# 2052
# <Element 'sentence' at 0x7f0ae6e75950>
# 1295
# <Element 'sentence' at 0x7f0ae6e75a90>
# 112
# <Element 'sentence' at 0x7f0ae6e75b90>
# 2123
# <Element 'sentence' at 0x7f0ae6e75c50>
# 190
# <Element 'sentence' at 0x7f0ae6e75d10>
# 2459
# <Element 'sentence' at 0x7f0ae6e75d90>
# 1665
# <Element 'sentence' at 0x7f0ae6e75e10>
# 1101
# <Element 'sentence' at 0x7f0ae6e75f50>
# 1948
# <Element 'sentence' at 0x7f0ae6e81050>
# 2340
# <Element 'sentence' at 0x7f0ae6e81110>
# 115
# <Element 'sentence' at 0x7f0ae6e81250>
# 196
# <Element 'sentence' at 0x7f0ae6e812d0>
# 2332
# <Element 'sentence' at 0x7f0ae6e813d0>
# 2687
# <Element 'sentence' at 0x7f0ae6e81450>
# 2633
# <Element 'sentence' at 0x7f0ae6e814d0>
# 845
# <Element 'sentence' at 0x7f0ae6e815d0>
# 1741
# <Element 'sentence' at 0x7f0ae6e81650>
# 2914
# <Element 'sentence' at 0x7f0ae6e81750>
# 2318
# <Element 'sentence' at 0x7f0ae6e81850>
# 153
# <Element 'sentence' at 0x7f0ae6e81950>
# 3071
# <Element 'sentence' at 0x7f0ae6e819d0>
# 1415
# <Element 'sentence' at 0x7f0ae6e81ad0>
# 2946
# <Element 'sentence' at 0x7f0ae6e81bd0>
# 1380
# <Element 'sentence' at 0x7f0ae6e81c50>
# 833
# <Element 'sentence' at 0x7f0ae6e81d50>
# 2285
# <Element 'sentence' at 0x7f0ae6e81dd0>
# 2148
# <Element 'sentence' at 0x7f0ae6e81e50>
# 2106
# <Element 'sentence' at 0x7f0ae6e81f90>
# 2595
# <Element 'sentence' at 0x7f0ae6e100d0>
# 584
# <Element 'sentence' at 0x7f0ae6e10150>
# 2244
# <Element 'sentence' at 0x7f0ae6e101d0>
# 1966
# <Element 'sentence' at 0x7f0ae6e102d0>
# 991
# <Element 'sentence' at 0x7f0ae6e10350>
# 617
# <Element 'sentence' at 0x7f0ae6e10450>
# 2168
# <Element 'sentence' at 0x7f0ae6e10550>
# 1765
# <Element 'sentence' at 0x7f0ae6e10690>
# 778
# <Element 'sentence' at 0x7f0ae6e107d0>
# 1215
# <Element 'sentence' at 0x7f0ae6e10850>
# 195
# <Element 'sentence' at 0x7f0ae6e108d0>
# 1
# <Element 'sentence' at 0x7f0ae6e10990>
# 1707
# <Element 'sentence' at 0x7f0ae6e10ad0>
# 530
# <Element 'sentence' at 0x7f0ae6e10b50>
# 2553
# <Element 'sentence' at 0x7f0ae6e10c90>
# 1485
# <Element 'sentence' at 0x7f0ae6e10dd0>
# 666
# <Element 'sentence' at 0x7f0ae6e10e50>
# 2672
# <Element 'sentence' at 0x7f0ae6e10f50>
# 1258
# <Element 'sentence' at 0x7f0ae6e1c110>
# 375
# <Element 'sentence' at 0x7f0ae6e1c190>
# 63
# <Element 'sentence' at 0x7f0ae6e1c290>
# 3048
# <Element 'sentence' at 0x7f0ae6e1c3d0>
# 1552
# <Element 'sentence' at 0x7f0ae6e1c4d0>
# 2598
# <Element 'sentence' at 0x7f0ae6e1c550>
# 2112
# <Element 'sentence' at 0x7f0ae6e1c690>
# 461
# <Element 'sentence' at 0x7f0ae6e1c710>
# 2823
# <Element 'sentence' at 0x7f0ae6e1c810>
# 2249
# <Element 'sentence' at 0x7f0ae6e1c890>
# 1582
# <Element 'sentence' at 0x7f0ae6e1ca10>
# 1141
# <Element 'sentence' at 0x7f0ae6e1ca90>
# 2140
# <Element 'sentence' at 0x7f0ae6e1cb90>
# 1786
# <Element 'sentence' at 0x7f0ae6e1cc10>
# 2023
# <Element 'sentence' at 0x7f0ae6e1cc90>
# 351
# <Element 'sentence' at 0x7f0ae6e1cd10>
# 1389
# <Element 'sentence' at 0x7f0ae6e1cd90>
# 2545
# <Element 'sentence' at 0x7f0ae6e1ce10>
# 908
# <Element 'sentence' at 0x7f0ae6e1cf10>
# 867
# <Element 'sentence' at 0x7f0ae6e1cf90>
# 2898
# <Element 'sentence' at 0x7f0ae6e270d0>
# 29
# <Element 'sentence' at 0x7f0ae6e27210>
# 2561
# <Element 'sentence' at 0x7f0ae6e27390>
# 2376
# <Element 'sentence' at 0x7f0ae6e27410>
# 1560
# <Element 'sentence' at 0x7f0ae6e27490>
# 2461
# <Element 'sentence' at 0x7f0ae6e27510>
# 1039
# <Element 'sentence' at 0x7f0ae6e27610>
# 1519
# <Element 'sentence' at 0x7f0ae6e27690>
# 2380
# <Element 'sentence' at 0x7f0ae6e277d0>
# 2172
# <Element 'sentence' at 0x7f0ae6e27850>
# 349
# <Element 'sentence' at 0x7f0ae6e27950>
# 2255
# <Element 'sentence' at 0x7f0ae6e279d0>
# 1309
# <Element 'sentence' at 0x7f0ae6e27b10>
# 2299
# <Element 'sentence' at 0x7f0ae6e27bd0>
# 712
# <Element 'sentence' at 0x7f0ae6e27d10>
# 872
# <Element 'sentence' at 0x7f0ae6e27d90>
# 1109
# <Element 'sentence' at 0x7f0ae6e27e10>
# 389
# <Element 'sentence' at 0x7f0ae6e27e90>
# 506
# <Element 'sentence' at 0x7f0ae6e27f90>
# 1175
# <Element 'sentence' at 0x7f0ae6e360d0>
# 1049
# <Element 'sentence' at 0x7f0ae6e361d0>
# 233
# <Element 'sentence' at 0x7f0ae6e36250>
# 265
# <Element 'sentence' at 0x7f0ae6e36350>
# 394
# <Element 'sentence' at 0x7f0ae6e36510>
# 152
# <Element 'sentence' at 0x7f0ae6e36610>
# 143
# <Element 'sentence' at 0x7f0ae6e366d0>
# 1656
# <Element 'sentence' at 0x7f0ae6e36750>
# 1402
# <Element 'sentence' at 0x7f0ae6e367d0>
# 1284
# <Element 'sentence' at 0x7f0ae6e368d0>
# 1317
# <Element 'sentence' at 0x7f0ae6e36950>
# 1636
# <Element 'sentence' at 0x7f0ae6e369d0>
# 409
# <Element 'sentence' at 0x7f0ae6e36a50>
# 2131
# <Element 'sentence' at 0x7f0ae6e36ad0>
# 2228
# <Element 'sentence' at 0x7f0ae6e36b50>
# 1797
# <Element 'sentence' at 0x7f0ae6e36c50>
# 2272
# <Element 'sentence' at 0x7f0ae6e36ed0>
# 479
# <Element 'sentence' at 0x7f0ae6e36f50>
# 2657
# <Element 'sentence' at 0x7f0ae6e36fd0>
# 618
# <Element 'sentence' at 0x7f0ae6e44090>
# 1207
# <Element 'sentence' at 0x7f0ae6e44150>
# 848
# <Element 'sentence' at 0x7f0ae6e44290>
# 734
# <Element 'sentence' at 0x7f0ae6e44390>
# 230
# <Element 'sentence' at 0x7f0ae6e44410>
# 2194
# <Element 'sentence' at 0x7f0ae6e44490>
# 611
# <Element 'sentence' at 0x7f0ae6e44510>
# 1195
# <Element 'sentence' at 0x7f0ae6e44590>
# 2893
# <Element 'sentence' at 0x7f0ae6e44610>
# 1712
# <Element 'sentence' at 0x7f0ae6e44690>
# 2982

# %%
import xml.etree.ElementTree as ET
import nltk

def get_list(path):
    tree=ET.parse(path)
    root = tree.getroot()
    text_list = []
    id_list=[]
    new_list=[]
    sentences_list=[]
    opinion_list = []
    for review in root.findall('sentence'):
        print(review)
        text_string=""
        opinion_inner_list=[]
        #or sent in review.findall('./sentences/sentence'):
        #print(sent)
        ids=review.attrib['id']
        print(ids)
        id_list.append(ids)
        text_string= text_string+ " "+ review.find('text').text
        new_list.append(ids)
        sentences_list.append(review.find('text').text)
#             new_list.append(sent.find('text').text)
        
#         text_list.append(text_string)
#         for opinion in review.findall('./Opinions/Opinion'):
#             opinion_dict = {
#                 opinion.get('category').replace('#','_'): opinion.get('polarity')
#             }
#             opinion_inner_list.append(opinion_dict)
#         opinion_list.append(opinion_inner_list)
    return text_list,opinion_list,new_list,sentences_list
train_text_list,train_opinion_list,new_list,sentences_list = get_list("/home/vibha/Laptops_Train.xml")
# Out:
# <Element 'sentence' at 0x7f0ae6e44a90>
# 2339
# <Element 'sentence' at 0x7f0ae6e44bd0>
# 812
# <Element 'sentence' at 0x7f0ae6e44c50>
# 1316
# <Element 'sentence' at 0x7f0ae6e44dd0>
# 2328
# <Element 'sentence' at 0x7f0ae6e44e50>
# 2193
# <Element 'sentence' at 0x7f0ae6e44ed0>
# 2005
# <Element 'sentence' at 0x7f0ae6dcc0d0>
# 2789
# <Element 'sentence' at 0x7f0ae6dcc1d0>
# 425
# <Element 'sentence' at 0x7f0ae6dcc250>
# 76
# <Element 'sentence' at 0x7f0ae6dcc410>
# 747
# <Element 'sentence' at 0x7f0ae6dcc490>
# 80
# <Element 'sentence' at 0x7f0ae6dcc590>
# 796
# <Element 'sentence' at 0x7f0ae6dcc610>
# 917
# <Element 'sentence' at 0x7f0ae6dcc790>
# 1788
# <Element 'sentence' at 0x7f0ae6dcc850>
# 338
# <Element 'sentence' at 0x7f0ae6dcc9d0>
# 1630
# <Element 'sentence' at 0x7f0ae6dccad0>
# 38
# <Element 'sentence' at 0x7f0ae6dccc10>
# 337
# <Element 'sentence' at 0x7f0ae6dcce10>
# 1505
# <Element 'sentence' at 0x7f0ae6dcce90>
# 263
# <Element 'sentence' at 0x7f0ae6dccf10>
# 1227
# <Element 'sentence' at 0x7f0ae6dccf90>
# 1019
# <Element 'sentence' at 0x7f0ae6de1050>
# 1158
# <Element 'sentence' at 0x7f0ae6de10d0>
# 1168
# <Element 'sentence' at 0x7f0ae6de1150>
# 2568
# <Element 'sentence' at 0x7f0ae6de1250>
# 295
# <Element 'sentence' at 0x7f0ae6de1350>
# 951
# <Element 'sentence' at 0x7f0ae6de13d0>
# 2759
# <Element 'sentence' at 0x7f0ae6de14d0>
# 2055
# <Element 'sentence' at 0x7f0ae6de1550>
# 2980
# <Element 'sentence' at 0x7f0ae6de1650>
# 2454
# <Element 'sentence' at 0x7f0ae6de16d0>
# 1054
# <Element 'sentence' at 0x7f0ae6de17d0>
# 743
# <Element 'sentence' at 0x7f0ae6de1910>
# 1155
# <Element 'sentence' at 0x7f0ae6de19d0>
# 2587
# <Element 'sentence' at 0x7f0ae6de1ad0>
# 2202
# <Element 'sentence' at 0x7f0ae6de1bd0>
# 2799
# <Element 'sentence' at 0x7f0ae6de1c50>
# 2227
# <Element 'sentence' at 0x7f0ae6de1d90>
# 2241
# <Element 'sentence' at 0x7f0ae6de1e50>
# 92
# <Element 'sentence' at 0x7f0ae6de1f50>
# 1204
# <Element 'sentence' at 0x7f0ae6dec090>
# 2026
# <Element 'sentence' at 0x7f0ae6dec110>
# 535
# <Element 'sentence' at 0x7f0ae6dec190>
# 478
# <Element 'sentence' at 0x7f0ae6dec210>
# 1690
# <Element 'sentence' at 0x7f0ae6dec290>
# 1789
# <Element 'sentence' at 0x7f0ae6dec310>
# 250
# <Element 'sentence' at 0x7f0ae6dec390>
# 325
# <Element 'sentence' at 0x7f0ae6dec490>
# 324
# <Element 'sentence' at 0x7f0ae6dec510>
# 1574
# <Element 'sentence' at 0x7f0ae6dec650>
# 1005
# <Element 'sentence' at 0x7f0ae6dec6d0>
# 989
# <Element 'sentence' at 0x7f0ae6dec750>
# 3073
# <Element 'sentence' at 0x7f0ae6dec890>
# 1254
# <Element 'sentence' at 0x7f0ae6dec990>
# 810
# <Element 'sentence' at 0x7f0ae6deca90>
# 1346
# <Element 'sentence' at 0x7f0ae6decb10>
# 2383
# <Element 'sentence' at 0x7f0ae6decb90>
# 130
# <Element 'sentence' at 0x7f0ae6decc90>
# 1253
# <Element 'sentence' at 0x7f0ae6decd10>
# 839
# <Element 'sentence' at 0x7f0ae6dece10>
# 1473
# <Element 'sentence' at 0x7f0ae6dece90>
# 782
# <Element 'sentence' at 0x7f0ae6decf10>
# 696
# <Element 'sentence' at 0x7f0ae6e00050>
# 2878
# <Element 'sentence' at 0x7f0ae6e000d0>
# 226
# <Element 'sentence' at 0x7f0ae6e00150>
# 1652
# <Element 'sentence' at 0x7f0ae6e001d0>
# 1030
# <Element 'sentence' at 0x7f0ae6e002d0>
# 1425
# <Element 'sentence' at 0x7f0ae6e004d0>
# 2861
# <Element 'sentence' at 0x7f0ae6e00550>
# 661
# <Element 'sentence' at 0x7f0ae6e006d0>
# 997
# <Element 'sentence' at 0x7f0ae6e00850>
# 192
# <Element 'sentence' at 0x7f0ae6e008d0>
# 463
# <Element 'sentence' at 0x7f0ae6e00a10>
# 2866
# <Element 'sentence' at 0x7f0ae6e00a90>
# 935
# <Element 'sentence' at 0x7f0ae6e00b10>
# 1193
# <Element 'sentence' at 0x7f0ae6e00c10>
# 2192
# <Element 'sentence' at 0x7f0ae6e00c90>
# 147
# <Element 'sentence' at 0x7f0ae6e00dd0>
# 1433
# <Element 'sentence' at 0x7f0ae6e00ed0>
# 1669
# <Element 'sentence' at 0x7f0ae6e00fd0>
# 2462
# <Element 'sentence' at 0x7f0ae6d8e110>
# 2719
# <Element 'sentence' at 0x7f0ae6d8e210>
# 1224
# <Element 'sentence' at 0x7f0ae6d8e310>
# 588
# <Element 'sentence' at 0x7f0ae6d8e390>
# 2492
# <Element 'sentence' at 0x7f0ae6d8e490>
# 1541
# <Element 'sentence' at 0x7f0ae6d8e5d0>
# 3060
# <Element 'sentence' at 0x7f0ae6d8e750>
# 915
# <Element 'sentence' at 0x7f0ae6d8e850>
# 2050
# <Element 'sentence' at 0x7f0ae6d8e950>
# 460
# <Element 'sentence' at 0x7f0ae6d8ea90>
# 1954
# <Element 'sentence' at 0x7f0ae6d8eb10>
# 1728
# <Element 'sentence' at 0x7f0ae6d8eb90>
# 620
# <Element 'sentence' at 0x7f0ae6d8ec10>
# 2423
# <Element 'sentence' at 0x7f0ae6d8ecd0>
# 1781
# <Element 'sentence' at 0x7f0ae6d8ed50>
# 645
# <Element 'sentence' at 0x7f0ae6d8edd0>
# 2
# <Element 'sentence' at 0x7f0ae6d8ee90>
# 1524
# <Element 'sentence' at 0x7f0ae6d8efd0>
# 2472
# <Element 'sentence' at 0x7f0ae6d9a090>
# 803
# <Element 'sentence' at 0x7f0ae6d9a190>
# 2225
# <Element 'sentence' at 0x7f0ae6d9a290>
# 2644
# <Element 'sentence' at 0x7f0ae6d9a490>
# 1365
# <Element 'sentence' at 0x7f0ae6d9a590>
# 1555
# <Element 'sentence' at 0x7f0ae6d9a610>
# 2199
# <Element 'sentence' at 0x7f0ae6d9a690>
# 72
# <Element 'sentence' at 0x7f0ae6d9a710>
# 1151
# <Element 'sentence' at 0x7f0ae6d9a790>
# 2033
# <Element 'sentence' at 0x7f0ae6d9a890>
# 2113
# <Element 'sentence' at 0x7f0ae6d9a910>
# 2271
# <Element 'sentence' at 0x7f0ae6d9aa90>
# 1307
# <Element 'sentence' at 0x7f0ae6d9ab10>
# 2186
# <Element 'sentence' at 0x7f0ae6d9ab90>
# 103
# <Element 'sentence' at 0x7f0ae6d9acd0>
# 1875
# <Element 'sentence' at 0x7f0ae6d9ad50>
# 1359
# <Element 'sentence' at 0x7f0ae6d9add0>
# 2483
# <Element 'sentence' at 0x7f0ae6d9ae50>
# 2945
# <Element 'sentence' at 0x7f0ae6d9aed0>
# 197
# <Element 'sentence' at 0x7f0ae6d9af50>
# 1149
# <Element 'sentence' at 0x7f0ae6da9090>
# 163
# <Element 'sentence' at 0x7f0ae6da9110>
# 900
# <Element 'sentence' at 0x7f0ae6da9210>
# 1649
# <Element 'sentence' at 0x7f0ae6da9310>
# 2972
# <Element 'sentence' at 0x7f0ae6da9390>
# 446
# <Element 'sentence' at 0x7f0ae6da9490>
# 1912
# <Element 'sentence' at 0x7f0ae6da9610>
# 2752
# <Element 'sentence' at 0x7f0ae6da9750>
# 270
# <Element 'sentence' at 0x7f0ae6da97d0>
# 2646
# <Element 'sentence' at 0x7f0ae6da9850>
# 886
# <Element 'sentence' at 0x7f0ae6da98d0>
# 2381
# <Element 'sentence' at 0x7f0ae6da99d0>
# 404
# <Element 'sentence' at 0x7f0ae6da9ad0>
# 2772
# <Element 'sentence' at 0x7f0ae6da9b50>
# 407
# <Element 'sentence' at 0x7f0ae6da9c50>
# 699
# <Element 'sentence' at 0x7f0ae6da9cd0>
# 1034
# <Element 'sentence' at 0x7f0ae6da9d50>
# 1731
# <Element 'sentence' at 0x7f0ae6da9ed0>
# 1863
# <Element 'sentence' at 0x7f0ae6da9f50>
# 1186
# <Element 'sentence' at 0x7f0ae6db70d0>
# 1029
# <Element 'sentence' at 0x7f0ae6db7150>
# 1014
# <Element 'sentence' at 0x7f0ae6db71d0>
# 2470
# <Element 'sentence' at 0x7f0ae6db7390>
# 331
# <Element 'sentence' at 0x7f0ae6db75d0>
# 1073
# <Element 'sentence' at 0x7f0ae6db7650>
# 2788
# <Element 'sentence' at 0x7f0ae6db76d0>
# 1057
# <Element 'sentence' at 0x7f0ae6db7790>
# 1095
# <Element 'sentence' at 0x7f0ae6db78d0>
# 210
# <Element 'sentence' at 0x7f0ae6db7950>
# 1718
# <Element 'sentence' at 0x7f0ae6db7a90>
# 2770
# <Element 'sentence' at 0x7f0ae6db7b10>
# 642
# <Element 'sentence' at 0x7f0ae6db7b90>
# 471
# <Element 'sentence' at 0x7f0ae6db7c10>
# 2923
# <Element 'sentence' at 0x7f0ae6db7d10>
# 3027
# <Element 'sentence' at 0x7f0ae6db7e10>
# 654
# <Element 'sentence' at 0x7f0ae6db7f50>
# 1340
# <Element 'sentence' at 0x7f0ae6db7fd0>
# 2638
# <Element 'sentence' at 0x7f0ae6dc4090>
# 2099
# <Element 'sentence' at 0x7f0ae6dc4110>
# 58
# <Element 'sentence' at 0x7f0ae6dc4190>
# 2716
# <Element 'sentence' at 0x7f0ae6dc4210>
# 2317
# <Element 'sentence' at 0x7f0ae6dc4290>
# 1110
# <Element 'sentence' at 0x7f0ae6dc4390>
# 1488
# <Element 'sentence' at 0x7f0ae6dc44d0>
# 488
# <Element 'sentence' at 0x7f0ae6dc45d0>
# 1289
# <Element 'sentence' at 0x7f0ae6dc4750>
# 2985
# <Element 'sentence' at 0x7f0ae6dc4850>
# 2145
# <Element 'sentence' at 0x7f0ae6dc48d0>
# 1573
# <Element 'sentence' at 0x7f0ae6dc49d0>
# 1928
# <Element 'sentence' at 0x7f0ae6dc4b10>
# 704
# <Element 'sentence' at 0x7f0ae6dc4b90>
# 1099
# <Element 'sentence' at 0x7f0ae6dc4c90>
# 1347
# <Element 'sentence' at 0x7f0ae6dc4d90>
# 1408
# <Element 'sentence' at 0x7f0ae6dc4e90>
# 1374
# <Element 'sentence' at 0x7f0ae6d52090>
# 34
# <Element 'sentence' at 0x7f0ae6d52110>
# 2864
# <Element 'sentence' at 0x7f0ae6d52250>
# 815
# <Element 'sentence' at 0x7f0ae6d522d0>
# 2801
# <Element 'sentence' at 0x7f0ae6d52350>
# 1568
# <Element 'sentence' at 0x7f0ae6d523d0>
# 30
# <Element 'sentence' at 0x7f0ae6d524d0>
# 362
# <Element 'sentence' at 0x7f0ae6d52550>
# 619
# <Element 'sentence' at 0x7f0ae6d525d0>
# 708
# <Element 'sentence' at 0x7f0ae6d52650>
# 167
# <Element 'sentence' at 0x7f0ae6d526d0>
# 474
# <Element 'sentence' at 0x7f0ae6d52810>
# 1563
# <Element 'sentence' at 0x7f0ae6d52890>
# 172
# <Element 'sentence' at 0x7f0ae6d52910>
# 1396
# <Element 'sentence' at 0x7f0ae6d52990>
# 156
# <Element 'sentence' at 0x7f0ae6d52ad0>
# 2095
# <Element 'sentence' at 0x7f0ae6d52bd0>
# 46
# <Element 'sentence' at 0x7f0ae6d52c50>
# 418
# <Element 'sentence' at 0x7f0ae6d52cd0>
# 1722
# <Element 'sentence' at 0x7f0ae6d52d90>
# 2004
# <Element 'sentence' at 0x7f0ae6d52f50>
# 2296
# <Element 'sentence' at 0x7f0ae6d5f090>
# 1514
# <Element 'sentence' at 0x7f0ae6d5f110>
# 2699
# <Element 'sentence' at 0x7f0ae6d5f190>
# 524
# <Element 'sentence' at 0x7f0ae6d5f210>
# 155
# <Element 'sentence' at 0x7f0ae6d5f290>
# 493
# <Element 'sentence' at 0x7f0ae6d5f3d0>
# 902
# <Element 'sentence' at 0x7f0ae6d5f4d0>
# 2433
# <Element 'sentence' at 0x7f0ae6d5f5d0>
# 1675
# <Element 'sentence' at 0x7f0ae6d5f710>
# 3000
# <Element 'sentence' at 0x7f0ae6d5f790>
# 954
# <Element 'sentence' at 0x7f0ae6d5f810>
# 609
# <Element 'sentence' at 0x7f0ae6d5f910>
# 50
# <Element 'sentence' at 0x7f0ae6d5f990>
# 1265
# <Element 'sentence' at 0x7f0ae6d5fa10>
# 2150
# <Element 'sentence' at 0x7f0ae6d5fa90>
# 1777
# <Element 'sentence' at 0x7f0ae6d5fb10>
# 296
# <Element 'sentence' at 0x7f0ae6d5fc50>
# 1585
# <Element 'sentence' at 0x7f0ae6d5fcd0>
# 2444
# <Element 'sentence' at 0x7f0ae6d5fd50>
# 2335
# <Element 'sentence' at 0x7f0ae6d5fe50>
# 1635
# <Element 'sentence' at 0x7f0ae6d5fed0>
# 1661
# <Element 'sentence' at 0x7f0ae6d5ff50>
# 2416
# <Element 'sentence' at 0x7f0ae6d6b090>
# 1471
# <Element 'sentence' at 0x7f0ae6d6b190>
# 1388
# <Element 'sentence' at 0x7f0ae6d6b210>
# 715
# <Element 'sentence' at 0x7f0ae6d6b2d0>
# 1901
# <Element 'sentence' at 0x7f0ae6d6b350>
# 1427
# <Element 'sentence' at 0x7f0ae6d6b4d0>
# 2389
# <Element 'sentence' at 0x7f0ae6d6b590>
# 2667
# <Element 'sentence' at 0x7f0ae6d6b650>
# 1618
# <Element 'sentence' at 0x7f0ae6d6b6d0>
# 1460
# <Element 'sentence' at 0x7f0ae6d6b750>
# 2964
# <Element 'sentence' at 0x7f0ae6d6b7d0>
# 911
# <Element 'sentence' at 0x7f0ae6d6b910>
# 2001
# <Element 'sentence' at 0x7f0ae6d6bb10>
# 2465
# <Element 'sentence' at 0x7f0ae6d6bc90>
# 2331
# <Element 'sentence' at 0x7f0ae6d6bd90>
# 599
# <Element 'sentence' at 0x7f0ae6d6bf10>
# 823
# <Element 'sentence' at 0x7f0ae6d7a090>
# 3006
# <Element 'sentence' at 0x7f0ae6d7a1d0>
# 1861
# <Element 'sentence' at 0x7f0ae6d7a250>
# 1301
# <Element 'sentence' at 0x7f0ae6d7a2d0>
# 788
# <Element 'sentence' at 0x7f0ae6d7a350>
# 2056
# <Element 'sentence' at 0x7f0ae6d7a3d0>
# 825
# <Element 'sentence' at 0x7f0ae6d7a450>
# 1823
# <Element 'sentence' at 0x7f0ae6d7a4d0>
# 2439
# <Element 'sentence' at 0x7f0ae6d7a550>
# 2941
# <Element 'sentence' at 0x7f0ae6d7a650>
# 2776
# <Element 'sentence' at 0x7f0ae6d7a790>
# 1686
# <Element 'sentence' at 0x7f0ae6d7a890>
# 2091
# <Element 'sentence' at 0x7f0ae6d7a990>
# 727
# <Element 'sentence' at 0x7f0ae6d7aa10>
# 3001
# <Element 'sentence' at 0x7f0ae6d7aad0>
# 1259
# <Element 'sentence' at 0x7f0ae6d7abd0>
# 2938
# <Element 'sentence' at 0x7f0ae6d7ad10>
# 2574
# <Element 'sentence' at 0x7f0ae6d7ae10>
# 2351
# <Element 'sentence' at 0x7f0ae6d7af10>
# 526
# <Element 'sentence' at 0x7f0ae6d88050>
# 2891
# <Element 'sentence' at 0x7f0ae6d880d0>
# 2717
# <Element 'sentence' at 0x7f0ae6d88150>
# 3020
# <Element 'sentence' at 0x7f0ae6d88290>
# 2541
# <Element 'sentence' at 0x7f0ae6d883d0>
# 1069
# <Element 'sentence' at 0x7f0ae6d885d0>
# 1553
# <Element 'sentence' at 0x7f0ae6d88750>
# 355
# <Element 'sentence' at 0x7f0ae6d887d0>
# 602
# <Element 'sentence' at 0x7f0ae6d88850>
# 2502
# <Element 'sentence' at 0x7f0ae6d888d0>
# 2874
# <Element 'sentence' at 0x7f0ae6d889d0>
# 2385
# <Element 'sentence' at 0x7f0ae6d88b50>
# 198
# <Element 'sentence' at 0x7f0ae6d88bd0>
# 211
# <Element 'sentence' at 0x7f0ae6d88c50>
# 1654
# <Element 'sentence' at 0x7f0ae6d88d90>
# 3058
# <Element 'sentence' at 0x7f0ae6d88f50>
# 1937
# <Element 'sentence' at 0x7f0ae6d14150>
# 104
# <Element 'sentence' at 0x7f0ae6d14250>
# 419
# <Element 'sentence' at 0x7f0ae6d142d0>
# 630
# <Element 'sentence' at 0x7f0ae6d14350>
# 694
# <Element 'sentence' at 0x7f0ae6d143d0>
# 189
# <Element 'sentence' at 0x7f0ae6d14450>
# 2616
# <Element 'sentence' at 0x7f0ae6d144d0>
# 1417
# <Element 'sentence' at 0x7f0ae6d146d0>
# 1045
# <Element 'sentence' at 0x7f0ae6d14750>
# 2886
# <Element 'sentence' at 0x7f0ae6d14890>
# 2124
# <Element 'sentence' at 0x7f0ae6d149d0>
# 260
# <Element 'sentence' at 0x7f0ae6d14ad0>
# 1296
# <Element 'sentence' at 0x7f0ae6d14b50>
# 1172
# <Element 'sentence' at 0x7f0ae6d14c50>
# 2283
# <Element 'sentence' at 0x7f0ae6d14d10>
# 2221
# <Element 'sentence' at 0x7f0ae6d14ed0>
# 2480
# <Element 'sentence' at 0x7f0ae6d14f50>
# 386
# <Element 'sentence' at 0x7f0ae6d24110>
# 1357
# <Element 'sentence' at 0x7f0ae6d24210>
# 185
# <Element 'sentence' at 0x7f0ae6d24290>
# 2605
# <Element 'sentence' at 0x7f0ae6d24390>
# 717
# <Element 'sentence' at 0x7f0ae6d24410>
# 2369
# <Element 'sentence' at 0x7f0ae6d24490>
# 2579
# <Element 'sentence' at 0x7f0ae6d24510>
# 1742
# <Element 'sentence' at 0x7f0ae6d24650>
# 2578
# <Element 'sentence' at 0x7f0ae6d24790>
# 33
# <Element 'sentence' at 0x7f0ae6d24810>
# 942
# <Element 'sentence' at 0x7f0ae6d24910>
# 2740
# <Element 'sentence' at 0x7f0ae6d24a10>
# 311
# <Element 'sentence' at 0x7f0ae6d24b10>
# 2402
# <Element 'sentence' at 0x7f0ae6d24b90>
# 13
# <Element 'sentence' at 0x7f0ae6d24cd0>
# 1852
# <Element 'sentence' at 0x7f0ae6d24dd0>
# 2708
# <Element 'sentence' at 0x7f0ae6d24f10>
# 1566
# <Element 'sentence' at 0x7f0ae6d31090>
# 2053
# <Element 'sentence' at 0x7f0ae6d31110>
# 540
# <Element 'sentence' at 0x7f0ae6d31210>
# 878
# <Element 'sentence' at 0x7f0ae6d31310>
# 2639
# <Element 'sentence' at 0x7f0ae6d31390>
# 2388
# <Element 'sentence' at 0x7f0ae6d31490>
# 1940
# <Element 'sentence' at 0x7f0ae6d31510>
# 3074
# <Element 'sentence' at 0x7f0ae6d31650>
# 1510
# <Element 'sentence' at 0x7f0ae6d316d0>
# 2457
# <Element 'sentence' at 0x7f0ae6d31750>
# 2534
# <Element 'sentence' at 0x7f0ae6d31850>
# 2185
# <Element 'sentence' at 0x7f0ae6d319d0>
# 2632
# <Element 'sentence' at 0x7f0ae6d31ad0>
# 1772
# <Element 'sentence' at 0x7f0ae6d31b50>
# 2675
# <Element 'sentence' at 0x7f0ae6d31c90>
# 1096
# <Element 'sentence' at 0x7f0ae6d31d50>
# 2371
# <Element 'sentence' at 0x7f0ae6d31d90>
# 2458
# <Element 'sentence' at 0x7f0ae6d31e10>
# 2650
# <Element 'sentence' at 0x7f0ae6d31e90>
# 392
# <Element 'sentence' at 0x7f0ae6d31f90>
# 1551
# <Element 'sentence' at 0x7f0ae6d3d0d0>
# 2698
# <Element 'sentence' at 0x7f0ae6d3d1d0>
# 2427
# <Element 'sentence' at 0x7f0ae6d3d250>
# 1849
# <Element 'sentence' at 0x7f0ae6d3d2d0>
# 340
# <Element 'sentence' at 0x7f0ae6d3d3d0>
# 2918
# <Element 'sentence' at 0x7f0ae6d3d510>
# 2939
# <Element 'sentence' at 0x7f0ae6d3d650>
# 1958
# <Element 'sentence' at 0x7f0ae6d3d790>
# 358
# <Element 'sentence' at 0x7f0ae6d3d890>
# 2064
# <Element 'sentence' at 0x7f0ae6d3d910>
# 1355
# <Element 'sentence' at 0x7f0ae6d3da10>
# 3021
# <Element 'sentence' at 0x7f0ae6d3db10>
# 2415
# <Element 'sentence' at 0x7f0ae6d3dc10>
# 2730
# <Element 'sentence' at 0x7f0ae6d3dc90>
# 2297
# <Element 'sentence' at 0x7f0ae6d3dd10>
# 2060
# <Element 'sentence' at 0x7f0ae6d3dd90>
# 2739
# <Element 'sentence' at 0x7f0ae6d3de10>
# 2696
# <Element 'sentence' at 0x7f0ae6d3ded0>
# 1352
# <Element 'sentence' at 0x7f0ae6d3df90>
# 1827
# <Element 'sentence' at 0x7f0ae6cca050>
# 2916
# <Element 'sentence' at 0x7f0ae6cca190>
# 2074
# <Element 'sentence' at 0x7f0ae6cca210>
# 229
# <Element 'sentence' at 0x7f0ae6cca290>
# 4
# <Element 'sentence' at 0x7f0ae6cca3d0>
# 2260
# <Element 'sentence' at 0x7f0ae6cca4d0>
# 199
# <Element 'sentence' at 0x7f0ae6cca550>
# 1376
# <Element 'sentence' at 0x7f0ae6cca690>
# 936
# <Element 'sentence' at 0x7f0ae6cca7d0>
# 1627
# <Element 'sentence' at 0x7f0ae6cca850>
# 2323
# <Element 'sentence' at 0x7f0ae6cca990>
# 1804
# <Element 'sentence' at 0x7f0ae6ccaa90>
# 595
# <Element 'sentence' at 0x7f0ae6ccab10>
# 1426
# <Element 'sentence' at 0x7f0ae6ccac10>
# 2216
# <Element 'sentence' at 0x7f0ae6ccac90>
# 1590
# <Element 'sentence' at 0x7f0ae6ccad50>
# 1486
# <Element 'sentence' at 0x7f0ae6ccadd0>
# 138
# <Element 'sentence' at 0x7f0ae6ccaed0>
# 1192
# <Element 'sentence' at 0x7f0ae6cd6050>
# 1439
# <Element 'sentence' at 0x7f0ae6cd60d0>
# 449
# <Element 'sentence' at 0x7f0ae6cd6190>
# 137
# <Element 'sentence' at 0x7f0ae6cd6210>
# 1691
# <Element 'sentence' at 0x7f0ae6cd6350>
# 877
# <Element 'sentence' at 0x7f0ae6cd63d0>
# 537
# <Element 'sentence' at 0x7f0ae6cd64d0>
# 541
# <Element 'sentence' at 0x7f0ae6cd6610>
# 1291
# <Element 'sentence' at 0x7f0ae6cd6690>
# 924
# <Element 'sentence' at 0x7f0ae6cd6710>
# 3043
# <Element 'sentence' at 0x7f0ae6cd6810>
# 505
# <Element 'sentence' at 0x7f0ae6cd6950>
# 431
# <Element 'sentence' at 0x7f0ae6cd69d0>
# 569
# <Element 'sentence' at 0x7f0ae6cd6b10>
# 3081
# <Element 'sentence' at 0x7f0ae6cd6c50>
# 308
# <Element 'sentence' at 0x7f0ae6cd6d90>
# 2796
# <Element 'sentence' at 0x7f0ae6cd6e90>
# 2333
# <Element 'sentence' at 0x7f0ae6cd6f90>
# 3049
# <Element 'sentence' at 0x7f0ae6ce3190>
# 2660
# <Element 'sentence' at 0x7f0ae6ce3290>
# 206
# <Element 'sentence' at 0x7f0ae6ce3390>
# 2138
# <Element 'sentence' at 0x7f0ae6ce34d0>
# 2737
# <Element 'sentence' at 0x7f0ae6ce3550>
# 2392
# <Element 'sentence' at 0x7f0ae6ce3650>
# 10
# <Element 'sentence' at 0x7f0ae6ce36d0>
# 85
# <Element 'sentence' at 0x7f0ae6ce3750>
# 9
# <Element 'sentence' at 0x7f0ae6ce3850>
# 1218
# <Element 'sentence' at 0x7f0ae6ce3910>
# 1867
# <Element 'sentence' at 0x7f0ae6ce3ad0>
# 2377
# <Element 'sentence' at 0x7f0ae6ce3c10>
# 2438
# <Element 'sentence' at 0x7f0ae6ce3c90>
# 136
# <Element 'sentence' at 0x7f0ae6ce3d10>
# 2928
# <Element 'sentence' at 0x7f0ae6ce3e10>
# 258
# <Element 'sentence' at 0x7f0ae6ce3e90>
# 2811
# <Element 'sentence' at 0x7f0ae6cf1050>
# 2137
# <Element 'sentence' at 0x7f0ae6cf1150>
# 1256
# <Element 'sentence' at 0x7f0ae6cf1250>
# 1770
# <Element 'sentence' at 0x7f0ae6cf13d0>
# 2270
# <Element 'sentence' at 0x7f0ae6cf1510>
# 1424
# <Element 'sentence' at 0x7f0ae6cf1650>
# 2843
# <Element 'sentence' at 0x7f0ae6cf1750>
# 1239
# <Element 'sentence' at 0x7f0ae6cf1810>
# 2471
# <Element 'sentence' at 0x7f0ae6cf1950>
# 1240
# <Element 'sentence' at 0x7f0ae6cf19d0>
# 2550
# <Element 'sentence' at 0x7f0ae6cf1b10>
# 455
# <Element 'sentence' at 0x7f0ae6cf1c50>
# 641
# <Element 'sentence' at 0x7f0ae6cf1cd0>
# 2197
# <Element 'sentence' at 0x7f0ae6cf1d50>
# 1462
# <Element 'sentence' at 0x7f0ae6cf1dd0>
# 949
# <Element 'sentence' at 0x7f0ae6cf1e90>
# 2924
# <Element 'sentence' at 0x7f0ae6cf1f10>
# 2496
# <Element 'sentence' at 0x7f0ae6cfd090>
# 1089
# <Element 'sentence' at 0x7f0ae6cfd190>
# 713
# <Element 'sentence' at 0x7f0ae6cfd2d0>
# 490
# <Element 'sentence' at 0x7f0ae6cfd410>
# 957
# <Element 'sentence' at 0x7f0ae6cfd490>
# 2844
# <Element 'sentence' at 0x7f0ae6cfd510>
# 2422
# <Element 'sentence' at 0x7f0ae6cfd650>
# 2540
# <Element 'sentence' at 0x7f0ae6cfd790>
# 2018
# <Element 'sentence' at 0x7f0ae6cfd890>
# 800
# <Element 'sentence' at 0x7f0ae6cfd910>
# 2566
# <Element 'sentence' at 0x7f0ae6cfd990>
# 1683
# <Element 'sentence' at 0x7f0ae6cfda10>
# 2022
# <Element 'sentence' at 0x7f0ae6cfdb10>
# 709
# <Element 'sentence' at 0x7f0ae6cfdb90>
# 1191
# <Element 'sentence' at 0x7f0ae6cfdcd0>
# 1950
# <Element 'sentence' at 0x7f0ae6cfdd50>
# 2007
# <Element 'sentence' at 0x7f0ae6cfddd0>
# 777
# <Element 'sentence' at 0x7f0ae6cfded0>
# 2775
# <Element 'sentence' at 0x7f0ae6cfdfd0>
# 1145
# <Element 'sentence' at 0x7f0ae6c8a090>
# 1844
# <Element 'sentence' at 0x7f0ae6c8a190>
# 1989
# <Element 'sentence' at 0x7f0ae6c8a250>
# 2147
# <Element 'sentence' at 0x7f0ae6c8a310>
# 1068
# <Element 'sentence' at 0x7f0ae6c8a4d0>
# 2030
# <Element 'sentence' at 0x7f0ae6c8a5d0>
# 2586
# <Element 'sentence' at 0x7f0ae6c8a650>
# 128
# <Element 'sentence' at 0x7f0ae6c8a750>
# 2822
# <Element 'sentence' at 0x7f0ae6c8a7d0>
# 1561
# <Element 'sentence' at 0x7f0ae6c8a910>
# 1890
# <Element 'sentence' at 0x7f0ae6c8aa10>
# 2435
# <Element 'sentence' at 0x7f0ae6c8ab10>
# 826
# <Element 'sentence' at 0x7f0ae6c8ab90>
# 2166
# <Element 'sentence' at 0x7f0ae6c8ac90>
# 739
# <Element 'sentence' at 0x7f0ae6c8ad10>
# 371
# <Element 'sentence' at 0x7f0ae6c8ad90>
# 2969
# <Element 'sentence' at 0x7f0ae6c8ae90>
# 896
# <Element 'sentence' at 0x7f0ae6c8af10>
# 824
# <Element 'sentence' at 0x7f0ae6c97050>
# 2896
# <Element 'sentence' at 0x7f0ae6c970d0>
# 2754
# <Element 'sentence' at 0x7f0ae6c97210>
# 309
# <Element 'sentence' at 0x7f0ae6c97310>
# 816
# <Element 'sentence' at 0x7f0ae6c97390>
# 16
# <Element 'sentence' at 0x7f0ae6c974d0>
# 1984
# <Element 'sentence' at 0x7f0ae6c97690>
# 837
# <Element 'sentence' at 0x7f0ae6c97750>
# 1588
# <Element 'sentence' at 0x7f0ae6c977d0>
# 2943
# <Element 'sentence' at 0x7f0ae6c978d0>
# 2410
# <Element 'sentence' at 0x7f0ae6c97950>
# 2889
# <Element 'sentence' at 0x7f0ae6c97a10>
# 1839
# <Element 'sentence' at 0x7f0ae6c97b10>
# 1375
# <Element 'sentence' at 0x7f0ae6c97c50>
# 899
# <Element 'sentence' at 0x7f0ae6c97d50>
# 2897
# <Element 'sentence' at 0x7f0ae6c97dd0>
# 2858
# <Element 'sentence' at 0x7f0ae6c97f10>
# 1338
# <Element 'sentence' at 0x7f0ae6ca5050>
# 2962
# <Element 'sentence' at 0x7f0ae6ca5250>
# 1785
# <Element 'sentence' at 0x7f0ae6ca52d0>
# 2110
# <Element 'sentence' at 0x7f0ae6ca53d0>
# 2201
# <Element 'sentence' at 0x7f0ae6ca5450>
# 139
# <Element 'sentence' at 0x7f0ae6ca54d0>
# 2582
# <Element 'sentence' at 0x7f0ae6ca5550>
# 35
# <Element 'sentence' at 0x7f0ae6ca5650>
# 1041
# <Element 'sentence' at 0x7f0ae6ca5790>
# 1219
# <Element 'sentence' at 0x7f0ae6ca5810>
# 231
# <Element 'sentence' at 0x7f0ae6ca5890>
# 728
# <Element 'sentence' at 0x7f0ae6ca5910>
# 1934
# <Element 'sentence' at 0x7f0ae6ca5990>
# 1040
# <Element 'sentence' at 0x7f0ae6ca5a90>
# 178
# <Element 'sentence' at 0x7f0ae6ca5b10>
# 379
# <Element 'sentence' at 0x7f0ae6ca5c50>
# 2358
# <Element 'sentence' at 0x7f0ae6ca5cd0>
# 1757
# <Element 'sentence' at 0x7f0ae6ca5e50>
# 220
# <Element 'sentence' at 0x7f0ae6ca5f50>
# 2790
# <Element 'sentence' at 0x7f0ae6ca5fd0>
# 2370
# <Element 'sentence' at 0x7f0ae6cb0090>
# 2919
# <Element 'sentence' at 0x7f0ae6cb0190>
# 698
# <Element 'sentence' at 0x7f0ae6cb02d0>
# 1336
# <Element 'sentence' at 0x7f0ae6cb0410>
# 797
# <Element 'sentence' at 0x7f0ae6cb0490>
# 2758
# <Element 'sentence' at 0x7f0ae6cb0510>
# 146
# <Element 'sentence' at 0x7f0ae6cb05d0>
# 432
# <Element 'sentence' at 0x7f0ae6cb0690>
# 1969
# <Element 'sentence' at 0x7f0ae6cb0790>
# 2549
# <Element 'sentence' at 0x7f0ae6cb0890>
# 269
# <Element 'sentence' at 0x7f0ae6cb0950>
# 469
# <Element 'sentence' at 0x7f0ae6cb0a90>
# 2974
# <Element 'sentence' at 0x7f0ae6cb0b90>
# 835
# <Element 'sentence' at 0x7f0ae6cb0c90>
# 1898
# <Element 'sentence' at 0x7f0ae6cb0d10>
# 1962
# <Element 'sentence' at 0x7f0ae6cb0e10>
# 306
# <Element 'sentence' at 0x7f0ae6cb0e90>
# 2838
# <Element 'sentence' at 0x7f0ae6cb0f10>
# 1666
# <Element 'sentence' at 0x7f0ae6cb0f90>
# 2876
# <Element 'sentence' at 0x7f0ae6cbd110>
# 2141
# <Element 'sentence' at 0x7f0ae6cbd210>
# 3040
# <Element 'sentence' at 0x7f0ae6cbd290>
# 2034
# <Element 'sentence' at 0x7f0ae6cbd390>
# 2798
# <Element 'sentence' at 0x7f0ae6cbd410>
# 1382
# <Element 'sentence' at 0x7f0ae6cbd490>
# 2905
# <Element 'sentence' at 0x7f0ae6cbd510>
# 2669
# <Element 'sentence' at 0x7f0ae6cbd610>
# 2895
# <Element 'sentence' at 0x7f0ae6cbd750>
# 2181
# <Element 'sentence' at 0x7f0ae6cbd850>
# 1529
# <Element 'sentence' at 0x7f0ae6cbd990>
# 2002
# <Element 'sentence' at 0x7f0ae6cbda10>
# 1752
# <Element 'sentence' at 0x7f0ae6cbdb10>
# 672
# <Element 'sentence' at 0x7f0ae6cbdbd0>
# 695
# <Element 'sentence' at 0x7f0ae6cbdd10>
# 2291
# <Element 'sentence' at 0x7f0ae6cbde10>
# 2183
# <Element 'sentence' at 0x7f0ae6cbde90>
# 658
# <Element 'sentence' at 0x7f0ae6cbdf10>
# 2286
# <Element 'sentence' at 0x7f0ae6cbdf90>
# 2481
# <Element 'sentence' at 0x7f0ae6c4b0d0>
# 1584
# <Element 'sentence' at 0x7f0ae6c4b150>
# 1893
# <Element 'sentence' at 0x7f0ae6c4b250>
# 2649
# <Element 'sentence' at 0x7f0ae6c4b450>
# 783
# <Element 'sentence' at 0x7f0ae6c4b4d0>
# 1889
# <Element 'sentence' at 0x7f0ae6c4b550>
# 3072
# <Element 'sentence' at 0x7f0ae6c4b6d0>
# 1196
# <Element 'sentence' at 0x7f0ae6c4b7d0>
# 761
# <Element 'sentence' at 0x7f0ae6c4b8d0>
# 1736
# <Element 'sentence' at 0x7f0ae6c4b950>
# 813
# <Element 'sentence' at 0x7f0ae6c4b9d0>
# 1735
# <Element 'sentence' at 0x7f0ae6c4ba50>
# 2096
# <Element 'sentence' at 0x7f0ae6c4bb90>
# 633
# <Element 'sentence' at 0x7f0ae6c4bc10>
# 714
# <Element 'sentence' at 0x7f0ae6c4bd10>
# 1404
# <Element 'sentence' at 0x7f0ae6c4bd90>
# 862
# <Element 'sentence' at 0x7f0ae6c4be10>
# 1023
# <Element 'sentence' at 0x7f0ae6c4be90>
# 827
# <Element 'sentence' at 0x7f0ae6c4bf10>
# 923
# <Element 'sentence' at 0x7f0ae6c4bf90>
# 1973
# <Element 'sentence' at 0x7f0ae6c58090>
# 2304
# <Element 'sentence' at 0x7f0ae6c582d0>
# 1313
# <Element 'sentence' at 0x7f0ae6c58350>
# 2276
# <Element 'sentence' at 0x7f0ae6c58550>
# 3054
# <Element 'sentence' at 0x7f0ae6c585d0>
# 1953
# <Element 'sentence' at 0x7f0ae6c586d0>
# 2755
# <Element 'sentence' at 0x7f0ae6c58850>
# 184
# <Element 'sentence' at 0x7f0ae6c588d0>
# 622
# <Element 'sentence' at 0x7f0ae6c58950>
# 744
# <Element 'sentence' at 0x7f0ae6c58ad0>
# 1281
# <Element 'sentence' at 0x7f0ae6c58b50>
# 1963
# <Element 'sentence' at 0x7f0ae6c58c50>
# 70
# <Element 'sentence' at 0x7f0ae6c58d50>
# 1611
# <Element 'sentence' at 0x7f0ae6c58dd0>
# 2342
# <Element 'sentence' at 0x7f0ae6c58e50>
# 151
# <Element 'sentence' at 0x7f0ae6c58f90>
# 1319
# <Element 'sentence' at 0x7f0ae6c65050>
# 2850
# <Element 'sentence' at 0x7f0ae6c650d0>
# 2556
# <Element 'sentence' at 0x7f0ae6c65150>
# 1734
# <Element 'sentence' at 0x7f0ae6c65250>
# 1617
# <Element 'sentence' at 0x7f0ae6c65390>
# 912
# <Element 'sentence' at 0x7f0ae6c65410>
# 1476
# <Element 'sentence' at 0x7f0ae6c65550>
# 1623
# <Element 'sentence' at 0x7f0ae6c65710>
# 451
# <Element 'sentence' at 0x7f0ae6c65850>
# 1544
# <Element 'sentence' at 0x7f0ae6c658d0>
# 149
# <Element 'sentence' at 0x7f0ae6c65950>
# 1222
# <Element 'sentence' at 0x7f0ae6c659d0>
# 2956
# <Element 'sentence' at 0x7f0ae6c65ad0>
# 720
# <Element 'sentence' at 0x7f0ae6c65cd0>
# 740
# <Element 'sentence' at 0x7f0ae6c65d90>
# 2442
# <Element 'sentence' at 0x7f0ae6c65e50>
# 2125
# <Element 'sentence' at 0x7f0ae6c65ed0>
# 2564
# <Element 'sentence' at 0x7f0ae6c65fd0>
# 3016
# <Element 'sentence' at 0x7f0ae6c72150>
# 806
# <Element 'sentence' at 0x7f0ae6c721d0>
# 2778
# <Element 'sentence' at 0x7f0ae6c72310>
# 2174
# <Element 'sentence' at 0x7f0ae6c72410>
# 157
# <Element 'sentence' at 0x7f0ae6c72490>
# 1522
# <Element 'sentence' at 0x7f0ae6c72510>
# 2535
# <Element 'sentence' at 0x7f0ae6c72590>
# 1378
# <Element 'sentence' at 0x7f0ae6c72690>
# 2999
# <Element 'sentence' at 0x7f0ae6c72790>
# 1930
# <Element 'sentence' at 0x7f0ae6c72810>
# 222
# <Element 'sentence' at 0x7f0ae6c72910>
# 2802
# <Element 'sentence' at 0x7f0ae6c72990>
# 1512
# <Element 'sentence' at 0x7f0ae6c72a10>
# 1189
# <Element 'sentence' at 0x7f0ae6c72b10>
# 1356
# <Element 'sentence' at 0x7f0ae6c72b90>
# 2070
# <Element 'sentence' at 0x7f0ae6c72c90>
# 2076
# <Element 'sentence' at 0x7f0ae6c72d90>
# 603
# <Element 'sentence' at 0x7f0ae6c72e50>
# 1513
# <Element 'sentence' at 0x7f0ae6c72ed0>
# 1787
# <Element 'sentence' at 0x7f0ae6c72f50>
# 930
# <Element 'sentence' at 0x7f0ae6c72fd0>
# 612
# <Element 'sentence' at 0x7f0ae6c7e150>
# 470
# <Element 'sentence' at 0x7f0ae6c7e1d0>
# 1320
# <Element 'sentence' at 0x7f0ae6c7e250>
# 2706
# <Element 'sentence' at 0x7f0ae6c7e390>
# 2997
# <Element 'sentence' at 0x7f0ae6c7e410>
# 2954
# <Element 'sentence' at 0x7f0ae6c7e550>
# 1874
# <Element 'sentence' at 0x7f0ae6c7e690>
# 2834
# <Element 'sentence' at 0x7f0ae6c7e710>
# 1546
# <Element 'sentence' at 0x7f0ae6c7e810>
# 1939
# <Element 'sentence' at 0x7f0ae6c7e890>
# 2840
# <Element 'sentence' at 0x7f0ae6c7e910>
# 484
# <Element 'sentence' at 0x7f0ae6c7e990>
# 2003
# <Element 'sentence' at 0x7f0ae6c7ea90>
# 1180
# <Element 'sentence' at 0x7f0ae6c7ebd0>
# 875
# <Element 'sentence' at 0x7f0ae6c7ec50>
# 809
# <Element 'sentence' at 0x7f0ae6c7ed50>
# 799
# <Element 'sentence' at 0x7f0ae6c7ee90>
# 1668
# <Element 'sentence' at 0x7f0ae6c7efd0>
# 274
# <Element 'sentence' at 0x7f0ae6c0d110>
# 2128
# <Element 'sentence' at 0x7f0ae6c0d250>
# 2237
# <Element 'sentence' at 0x7f0ae6c0d2d0>
# 2456
# <Element 'sentence' at 0x7f0ae6c0d410>
# 353
# <Element 'sentence' at 0x7f0ae6c0d550>
# 2290
# <Element 'sentence' at 0x7f0ae6c0d6d0>
# 1121
# <Element 'sentence' at 0x7f0ae6c0d750>
# 134
# <Element 'sentence' at 0x7f0ae6c0d7d0>
# 347
# <Element 'sentence' at 0x7f0ae6c0d8d0>
# 1813
# <Element 'sentence' at 0x7f0ae6c0d950>
# 655
# <Element 'sentence' at 0x7f0ae6c0da50>
# 2510
# <Element 'sentence' at 0x7f0ae6c0db90>
# 1615
# <Element 'sentence' at 0x7f0ae6c0dc10>
# 844
# <Element 'sentence' at 0x7f0ae6c0dc90>
# 884
# <Element 'sentence' at 0x7f0ae6c0dd90>
# 2785
# <Element 'sentence' at 0x7f0ae6c0de90>
# 2443
# <Element 'sentence' at 0x7f0ae6c0dfd0>
# 81
# <Element 'sentence' at 0x7f0ae6c1a110>
# 89
# <Element 'sentence' at 0x7f0ae6c1a190>
# 2114
# <Element 'sentence' at 0x7f0ae6c1a290>
# 1670
# <Element 'sentence' at 0x7f0ae6c1a310>
# 764
# <Element 'sentence' at 0x7f0ae6c1a410>
# 525
# <Element 'sentence' at 0x7f0ae6c1a490>
# 435
# <Element 'sentence' at 0x7f0ae6c1a590>
# 914
# <Element 'sentence' at 0x7f0ae6c1a690>
# 177
# <Element 'sentence' at 0x7f0ae6c1a710>
# 1776
# <Element 'sentence' at 0x7f0ae6c1a850>
# 330
# <Element 'sentence' at 0x7f0ae6c1a8d0>
# 865
# <Element 'sentence' at 0x7f0ae6c1a950>
# 1791
# <Element 'sentence' at 0x7f0ae6c1a9d0>
# 549
# <Element 'sentence' at 0x7f0ae6c1aa90>
# 1212
# <Element 'sentence' at 0x7f0ae6c1ab90>
# 2169
# <Element 'sentence' at 0x7f0ae6c1ac10>
# 2845
# <Element 'sentence' at 0x7f0ae6c1ad50>
# 756
# <Element 'sentence' at 0x7f0ae6c1ae50>
# 2600
# <Element 'sentence' at 0x7f0ae6c1af90>
# 2327
# <Element 'sentence' at 0x7f0ae6c25050>
# 3012
# <Element 'sentence' at 0x7f0ae6c25110>
# 1696
# <Element 'sentence' at 0x7f0ae6c25250>
# 1479
# <Element 'sentence' at 0x7f0ae6c25350>
# 2909
# <Element 'sentence' at 0x7f0ae6c254d0>
# 2937
# <Element 'sentence' at 0x7f0ae6c25590>
# 1784
# <Element 'sentence' at 0x7f0ae6c25650>
# 453
# <Element 'sentence' at 0x7f0ae6c25a90>
# 439
# <Element 'sentence' at 0x7f0ae6c25b10>
# 2925
# <Element 'sentence' at 0x7f0ae6c25b90>
# 929
# <Element 'sentence' at 0x7f0ae6c25c10>
# 2804
# <Element 'sentence' at 0x7f0ae6c25c90>
# 2077
# <Element 'sentence' at 0x7f0ae6c25dd0>
# 2622
# <Element 'sentence' at 0x7f0ae6c25f50>
# 1093
# <Element 'sentence' at 0x7f0ae6c34050>
# 225
# <Element 'sentence' at 0x7f0ae6c340d0>
# 1100
# <Element 'sentence' at 0x7f0ae6c34190>
# 2523
# <Element 'sentence' at 0x7f0ae6c341d0>
# 970
# <Element 'sentence' at 0x7f0ae6c34310>
# 1935
# <Element 'sentence' at 0x7f0ae6c34390>
# 11
# <Element 'sentence' at 0x7f0ae6c34450>
# 2569
# <Element 'sentence' at 0x7f0ae6c344d0>
# 3010
# <Element 'sentence' at 0x7f0ae6c34550>
# 1634
# <Element 'sentence' at 0x7f0ae6c345d0>
# 2414
# <Element 'sentence' at 0x7f0ae6c34690>
# 832
# <Element 'sentence' at 0x7f0ae6c347d0>
# 1205
# <Element 'sentence' at 0x7f0ae6c34850>
# 1064
# <Element 'sentence' at 0x7f0ae6c349d0>
# 2037
# <Element 'sentence' at 0x7f0ae6c34a90>
# 1429
# <Element 'sentence' at 0x7f0ae6c34b10>
# 2130
# <Element 'sentence' at 0x7f0ae6c34c10>
# 2626
# <Element 'sentence' at 0x7f0ae6c34d90>
# 1671
# <Element 'sentence' at 0x7f0ae6c34e10>
# 1315
# <Element 'sentence' at 0x7f0ae6c34f10>
# 2756
# <Element 'sentence' at 0x7f0ae6c41050>
# 548
# <Element 'sentence' at 0x7f0ae6c41110>
# 1446
# <Element 'sentence' at 0x7f0ae6c41210>
# 168
# <Element 'sentence' at 0x7f0ae6c412d0>
# 922
# <Element 'sentence' at 0x7f0ae6c413d0>
# 2797
# <Element 'sentence' at 0x7f0ae6c414d0>
# 2863
# <Element 'sentence' at 0x7f0ae6c41610>
# 638
# <Element 'sentence' at 0x7f0ae6c41690>
# 2642
# <Element 'sentence' at 0x7f0ae6c41710>
# 1000
# <Element 'sentence' at 0x7f0ae6c41790>
# 200
# <Element 'sentence' at 0x7f0ae6c41810>
# 2887
# <Element 'sentence' at 0x7f0ae6c41890>
# 993
# <Element 'sentence' at 0x7f0ae6c41910>
# 2464
# <Element 'sentence' at 0x7f0ae6c41990>
# 1667
# <Element 'sentence' at 0x7f0ae6c41a10>
# 416
# <Element 'sentence' at 0x7f0ae6c41a90>
# 2041
# <Element 'sentence' at 0x7f0ae6c41b10>
# 240
# <Element 'sentence' at 0x7f0ae6c41c10>
# 2135
# <Element 'sentence' at 0x7f0ae6c41c90>
# 1393
# <Element 'sentence' at 0x7f0ae6c41d90>
# 2259
# <Element 'sentence' at 0x7f0ae6c41e10>
# 1080
# <Element 'sentence' at 0x7f0ae6c41f90>
# 2695
# <Element 'sentence' at 0x7f0ae6bcc050>
# 1506
# <Element 'sentence' at 0x7f0ae6bcc0d0>
# 1837
# <Element 'sentence' at 0x7f0ae6bcc150>
# 532
# <Element 'sentence' at 0x7f0ae6bcc250>
# 3047
# <Element 'sentence' at 0x7f0ae6bcc350>
# 921
# <Element 'sentence' at 0x7f0ae6bcc3d0>
# 1733
# <Element 'sentence' at 0x7f0ae6bcc510>
# 2907
# <Element 'sentence' at 0x7f0ae6bcc590>
# 1178
# <Element 'sentence' at 0x7f0ae6bcc610>
# 2265
# <Element 'sentence' at 0x7f0ae6bcc690>
# 119
# <Element 'sentence' at 0x7f0ae6bcc710>
# 68
# <Element 'sentence' at 0x7f0ae6bcc790>
# 2746
# <Element 'sentence' at 0x7f0ae6bcc810>
# 282
# <Element 'sentence' at 0x7f0ae6bcc890>
# 1532
# <Element 'sentence' at 0x7f0ae6bcc990>
# 2800
# <Element 'sentence' at 0x7f0ae6bcca10>
# 1042
# <Element 'sentence' at 0x7f0ae6bcca90>
# 640
# <Element 'sentence' at 0x7f0ae6bccbd0>
# 2238
# <Element 'sentence' at 0x7f0ae6bcccd0>
# 1907
# <Element 'sentence' at 0x7f0ae6bccd50>
# 78
# <Element 'sentence' at 0x7f0ae6bccdd0>
# 891
# <Element 'sentence' at 0x7f0ae6bcce50>
# 692
# <Element 'sentence' at 0x7f0ae6bcced0>
# 1580
# <Element 'sentence' at 0x7f0ae6bda050>
# 2817
# <Element 'sentence' at 0x7f0ae6bda0d0>
# 273
# <Element 'sentence' at 0x7f0ae6bda210>
# 2679
# <Element 'sentence' at 0x7f0ae6bda2d0>
# 415
# <Element 'sentence' at 0x7f0ae6bda390>
# 2046
# <Element 'sentence' at 0x7f0ae6bda450>
# 2450
# <Element 'sentence' at 0x7f0ae6bda4d0>
# 2170
# <Element 'sentence' at 0x7f0ae6bda650>
# 2624
# <Element 'sentence' at 0x7f0ae6bda750>
# 1822
# <Element 'sentence' at 0x7f0ae6bda7d0>
# 2374
# <Element 'sentence' at 0x7f0ae6bda850>
# 1896
# <Element 'sentence' at 0x7f0ae6bda8d0>
# 341
# <Element 'sentence' at 0x7f0ae6bda950>
# 2245
# <Element 'sentence' at 0x7f0ae6bda9d0>
# 1569
# <Element 'sentence' at 0x7f0ae6bdaad0>
# 3064
# <Element 'sentence' at 0x7f0ae6bdabd0>
# 2953
# <Element 'sentence' at 0x7f0ae6bdacd0>
# 2129
# <Element 'sentence' at 0x7f0ae6bdadd0>
# 2075
# <Element 'sentence' at 0x7f0ae6bdaf10>
# 2180
# <Element 'sentence' at 0x7f0ae6bdaf90>
# 1362
# <Element 'sentence' at 0x7f0ae6be7050>
# 2710
# <Element 'sentence' at 0x7f0ae6be7190>
# 1373
# <Element 'sentence' at 0x7f0ae6be7350>
# 1370
# <Element 'sentence' at 0x7f0ae6be7490>
# 1697
# <Element 'sentence' at 0x7f0ae6be7550>
# 276
# <Element 'sentence' at 0x7f0ae6be75d0>
# 1287
# <Element 'sentence' at 0x7f0ae6be7690>
# 1929
# <Element 'sentence' at 0x7f0ae6be7710>
# 2365
# <Element 'sentence' at 0x7f0ae6be7790>
# 412
# <Element 'sentence' at 0x7f0ae6be7810>
# 2742
# <Element 'sentence' at 0x7f0ae6be78d0>
# 1758
# <Element 'sentence' at 0x7f0ae6be79d0>
# 1257
# <Element 'sentence' at 0x7f0ae6be7a50>
# 1908
# <Element 'sentence' at 0x7f0ae6be7ad0>
# 842
# <Element 'sentence' at 0x7f0ae6be7bd0>
# 931
# <Element 'sentence' at 0x7f0ae6be7d10>
# 863
# <Element 'sentence' at 0x7f0ae6be7d90>
# 2151
# <Element 'sentence' at 0x7f0ae6be7e10>
# 36
# <Element 'sentence' at 0x7f0ae6be7f10>
# 2967
# <Element 'sentence' at 0x7f0ae6bf3050>
# 1732
# <Element 'sentence' at 0x7f0ae6bf3150>
# 1800
# <Element 'sentence' at 0x7f0ae6bf31d0>
# 1063
# <Element 'sentence' at 0x7f0ae6bf32d0>
# 2615
# <Element 'sentence' at 0x7f0ae6bf3350>
# 271
# <Element 'sentence' at 0x7f0ae6bf3490>
# 2478
# <Element 'sentence' at 0x7f0ae6bf3610>
# 523
# <Element 'sentence' at 0x7f0ae6bf3750>
# 1657
# <Element 'sentence' at 0x7f0ae6bf3810>
# 1674
# <Element 'sentence' at 0x7f0ae6bf3990>
# 472
# <Element 'sentence' at 0x7f0ae6bf3a10>
# 1143
# <Element 'sentence' at 0x7f0ae6bf3b10>
# 2618
# <Element 'sentence' at 0x7f0ae6bf3b90>
# 1708
# <Element 'sentence' at 0x7f0ae6bf3c10>
# 2771
# <Element 'sentence' at 0x7f0ae6bf3c90>
# 2375
# <Element 'sentence' at 0x7f0ae6bf3d10>
# 203
# <Element 'sentence' at 0x7f0ae6bf3d90>
# 123
# <Element 'sentence' at 0x7f0ae6bf3e10>
# 2927
# <Element 'sentence' at 0x7f0ae6bf3f50>
# 916
# <Element 'sentence' at 0x7f0ae6bf3fd0>
# 2750
# <Element 'sentence' at 0x7f0ae6c030d0>
# 1137
# <Element 'sentence' at 0x7f0ae6c03150>
# 2993
# <Element 'sentence' at 0x7f0ae6c03290>
# 2453
# <Element 'sentence' at 0x7f0ae6c03390>
# 2661
# <Element 'sentence' at 0x7f0ae6c03410>
# 2590
# <Element 'sentence' at 0x7f0ae6c03490>
# 515
# <Element 'sentence' at 0x7f0ae6c035d0>
# 2321
# <Element 'sentence' at 0x7f0ae6c03650>
# 2282
# <Element 'sentence' at 0x7f0ae6c036d0>
# 1135
# <Element 'sentence' at 0x7f0ae6c03750>
# 1577
# <Element 'sentence' at 0x7f0ae6c037d0>
# 2572
# <Element 'sentence' at 0x7f0ae6c038d0>
# 2387
# <Element 'sentence' at 0x7f0ae6c03a10>
# 2517
# <Element 'sentence' at 0x7f0ae6c03b10>
# 1967
# <Element 'sentence' at 0x7f0ae6c03b90>
# 990
# <Element 'sentence' at 0x7f0ae6c03cd0>
# 1414
# <Element 'sentence' at 0x7f0ae6c03e10>
# 664
# <Element 'sentence' at 0x7f0ae6c03e90>
# 2484
# <Element 'sentence' at 0x7f0ae6c03f10>
# 903
# <Element 'sentence' at 0x7f0ae6b90050>
# 1609
# <Element 'sentence' at 0x7f0ae6b900d0>
# 2354
# <Element 'sentence' at 0x7f0ae6b90150>
# 2979
# <Element 'sentence' at 0x7f0ae6b901d0>
# 1759
# <Element 'sentence' at 0x7f0ae6b90250>
# 975
# <Element 'sentence' at 0x7f0ae6b902d0>
# 2931
# <Element 'sentence' at 0x7f0ae6b90350>
# 2700
# <Element 'sentence' at 0x7f0ae6b903d0>
# 1482
# <Element 'sentence' at 0x7f0ae6b90450>
# 1602
# <Element 'sentence' at 0x7f0ae6b90550>
# 1233
# <Element 'sentence' at 0x7f0ae6b905d0>
# 2231
# <Element 'sentence' at 0x7f0ae6b90790>
# 2828
# <Element 'sentence' at 0x7f0ae6b90890>
# 121
# <Element 'sentence' at 0x7f0ae6b90910>
# 2744
# <Element 'sentence' at 0x7f0ae6b90990>
# 1824
# <Element 'sentence' at 0x7f0ae6b90a90>
# 2460
# <Element 'sentence' at 0x7f0ae6b90bd0>
# 2500
# <Element 'sentence' at 0x7f0ae6b90cd0>
# 600
# <Element 'sentence' at 0x7f0ae6b90d50>
# 497
# <Element 'sentence' at 0x7f0ae6b90dd0>
# 241
# <Element 'sentence' at 0x7f0ae6b90e50>
# 557
# <Element 'sentence' at 0x7f0ae6b90ed0>
# 677
# <Element 'sentence' at 0x7f0ae6b90fd0>
# 531
# <Element 'sentence' at 0x7f0ae6b9d090>
# 1367
# <Element 'sentence' at 0x7f0ae6b9d110>
# 2094
# <Element 'sentence' at 0x7f0ae6b9d190>
# 1252
# <Element 'sentence' at 0x7f0ae6b9d290>
# 3007
# <Element 'sentence' at 0x7f0ae6b9d390>
# 1650
# <Element 'sentence' at 0x7f0ae6b9d490>
# 1229
# <Element 'sentence' at 0x7f0ae6b9d510>
# 399
# <Element 'sentence' at 0x7f0ae6b9d590>
# 1037
# <Element 'sentence' at 0x7f0ae6b9d650>
# 1620
# <Element 'sentence' at 0x7f0ae6b9d790>
# 1035
# <Element 'sentence' at 0x7f0ae6b9d810>
# 201
# <Element 'sentence' at 0x7f0ae6b9d890>
# 285
# <Element 'sentence' at 0x7f0ae6b9d990>
# 1260
# <Element 'sentence' at 0x7f0ae6b9da10>
# 3035
# <Element 'sentence' at 0x7f0ae6b9db50>
# 840
# <Element 'sentence' at 0x7f0ae6b9dbd0>
# 2511
# <Element 'sentence' at 0x7f0ae6b9dd50>
# 895
# <Element 'sentence' at 0x7f0ae6b9ddd0>
# 2275
# <Element 'sentence' at 0x7f0ae6b9de90>
# 1342
# <Element 'sentence' at 0x7f0ae6b9df50>
# 1124
# <Element 'sentence' at 0x7f0ae6bab090>
# 781
# <Element 'sentence' at 0x7f0ae6bab190>
# 2987
# <Element 'sentence' at 0x7f0ae6bab290>
# 2133
# <Element 'sentence' at 0x7f0ae6bab390>
# 131
# <Element 'sentence' at 0x7f0ae6bab410>
# 1364
# <Element 'sentence' at 0x7f0ae6bab4d0>
# 2787
# <Element 'sentence' at 0x7f0ae6bab650>
# 948
# <Element 'sentence' at 0x7f0ae6bab790>
# 2049
# <Element 'sentence' at 0x7f0ae6bab890>
# 558
# <Element 'sentence' at 0x7f0ae6bab910>
# 1059
# <Element 'sentence' at 0x7f0ae6bab990>
# 767
# <Element 'sentence' at 0x7f0ae6baba10>
# 1990
# <Element 'sentence' at 0x7f0ae6baba90>
# 2366
# <Element 'sentence' at 0x7f0ae6babb10>
# 2988
# <Element 'sentence' at 0x7f0ae6babc10>
# 1385
# <Element 'sentence' at 0x7f0ae6babd10>
# 1646
# <Element 'sentence' at 0x7f0ae6babe90>
# 88
# <Element 'sentence' at 0x7f0ae6babf10>
# 1270
# <Element 'sentence' at 0x7f0ae6babf90>
# 1834
# <Element 'sentence' at 0x7f0ae6bb9050>
# 1451
# <Element 'sentence' at 0x7f0ae6bb90d0>
# 55
# <Element 'sentence' at 0x7f0ae6bb9150>
# 2505
# <Element 'sentence' at 0x7f0ae6bb9290>
# 768
# <Element 'sentence' at 0x7f0ae6bb9390>
# 2559
# <Element 'sentence' at 0x7f0ae6bb9410>
# 242
# <Element 'sentence' at 0x7f0ae6bb9490>
# 2998
# <Element 'sentence' at 0x7f0ae6bb9510>
# 2341
# <Element 'sentence' at 0x7f0ae6bb9590>
# 2908
# <Element 'sentence' at 0x7f0ae7332790>
# 214
# <Element 'sentence' at 0x7f0ae6bb9750>
# 1263
# <Element 'sentence' at 0x7f0ae6bb9850>
# 650
# <Element 'sentence' at 0x7f0ae6bb98d0>
# 2703
# <Element 'sentence' at 0x7f0ae6bb9950>
# 142
# <Element 'sentence' at 0x7f0ae6bb9a50>
# 2947
# <Element 'sentence' at 0x7f0ae6bb9b50>
# 66
# <Element 'sentence' at 0x7f0ae6bb9bd0>
# 2020
# <Element 'sentence' at 0x7f0ae6bb9cd0>
# 2451
# <Element 'sentence' at 0x7f0ae6bb9dd0>
# 605
# <Element 'sentence' at 0x7f0ae6bb9e50>
# 314
# <Element 'sentence' at 0x7f0ae6bb9f90>
# 2777
# <Element 'sentence' at 0x7f0ae6bc5110>
# 1085
# <Element 'sentence' at 0x7f0ae6bc5210>
# 1906
# <Element 'sentence' at 0x7f0ae6bc5310>
# 124
# <Element 'sentence' at 0x7f0ae6bc5410>
# 2816
# <Element 'sentence' at 0x7f0ae6bc5490>
# 1900
# <Element 'sentence' at 0x7f0ae6bc5510>
# 732
# <Element 'sentence' at 0x7f0ae6bc5650>
# 3011
# <Element 'sentence' at 0x7f0ae6bc57d0>
# 485
# <Element 'sentence' at 0x7f0ae6bc5850>
# 1842
# <Element 'sentence' at 0x7f0ae6bc5950>
# 238
# <Element 'sentence' at 0x7f0ae6bc59d0>
# 205
# <Element 'sentence' at 0x7f0ae6bc5b10>
# 1955
# <Element 'sentence' at 0x7f0ae6bc5b90>
# 1160
# <Element 'sentence' at 0x7f0ae6bc5c50>
# 2989
# <Element 'sentence' at 0x7f0ae6bc5cd0>
# 1398
# <Element 'sentence' at 0x7f0ae6bc5e10>
# 1372
# <Element 'sentence' at 0x7f0ae6b51050>
# 467
# <Element 'sentence' at 0x7f0ae6b510d0>
# 1400
# <Element 'sentence' at 0x7f0ae6b51210>
# 47
# <Element 'sentence' at 0x7f0ae6b51290>
# 1066
# <Element 'sentence' at 0x7f0ae6b51390>
# 1607
# <Element 'sentence' at 0x7f0ae6b51410>
# 910
# <Element 'sentence' at 0x7f0ae6b51490>
# 2379
# <Element 'sentence' at 0x7f0ae6b51510>
# 361
# <Element 'sentence' at 0x7f0ae6b51590>
# 344
# <Element 'sentence' at 0x7f0ae6b51750>
# 1368
# <Element 'sentence' at 0x7f0ae6b517d0>
# 2038
# <Element 'sentence' at 0x7f0ae6b51850>
# 1673
# <Element 'sentence' at 0x7f0ae6b518d0>
# 2871
# <Element 'sentence' at 0x7f0ae6b519d0>
# 2530
# <Element 'sentence' at 0x7f0ae6b51a50>
# 1603
# <Element 'sentence' at 0x7f0ae6b51ad0>
# 381
# <Element 'sentence' at 0x7f0ae6b51b50>
# 312
# <Element 'sentence' at 0x7f0ae6b51dd0>
# 2795
# <Element 'sentence' at 0x7f0ae6b51ed0>
# 1865
# <Element 'sentence' at 0x7f0ae6b62090>
# 1681
# <Element 'sentence' at 0x7f0ae6b62110>
# 2973
# <Element 'sentence' at 0x7f0ae6b62290>
# 2612
# <Element 'sentence' at 0x7f0ae6b623d0>
# 1864
# <Element 'sentence' at 0x7f0ae6b62450>
# 2629
# <Element 'sentence' at 0x7f0ae6b624d0>
# 2207
# <Element 'sentence' at 0x7f0ae6b62550>
# 249
# <Element 'sentence' at 0x7f0ae6b625d0>
# 1283
# <Element 'sentence' at 0x7f0ae6b62710>
# 1423
# <Element 'sentence' at 0x7f0ae6b62850>
# 288
# <Element 'sentence' at 0x7f0ae6b628d0>
# 256
# <Element 'sentence' at 0x7f0ae6b62950>
# 2280
# <Element 'sentence' at 0x7f0ae6b629d0>
# 322
# <Element 'sentence' at 0x7f0ae6b62a50>
# 1072
# <Element 'sentence' at 0x7f0ae6b62b50>
# 2826
# <Element 'sentence' at 0x7f0ae6b62bd0>
# 1390
# <Element 'sentence' at 0x7f0ae6b62c50>
# 1739
# <Element 'sentence' at 0x7f0ae6b62d90>
# 2419
# <Element 'sentence' at 0x7f0ae6b62e90>
# 785
# <Element 'sentence' at 0x7f0ae6b62f10>
# 82
# <Element 'sentence' at 0x7f0ae6b62f90>
# 1549
# <Element 'sentence' at 0x7f0ae6b6e0d0>
# 2086
# <Element 'sentence' at 0x7f0ae6b6e250>
# 300
# <Element 'sentence' at 0x7f0ae6b6e4d0>
# 262
# <Element 'sentence' at 0x7f0ae6b6e550>
# 2521
# <Element 'sentence' at 0x7f0ae6b6e5d0>
# 2284
# <Element 'sentence' at 0x7f0ae6b6e650>
# 851
# <Element 'sentence' at 0x7f0ae6b6e750>
# 1008
# <Element 'sentence' at 0x7f0ae6b6e850>
# 2261
# <Element 'sentence' at 0x7f0ae6b6e990>
# 2793
# <Element 'sentence' at 0x7f0ae6b6ea10>
# 291
# <Element 'sentence' at 0x7f0ae6b6eb10>
# 1185
# <Element 'sentence' at 0x7f0ae6b6eb90>
# 1719
# <Element 'sentence' at 0x7f0ae6b6ec50>
# 391
# <Element 'sentence' at 0x7f0ae6b6ee10>
# 1595
# <Element 'sentence' at 0x7f0ae6b7b050>
# 1150
# <Element 'sentence' at 0x7f0ae6b7b0d0>
# 2362
# <Element 'sentence' at 0x7f0ae6b7b190>
# 116
# <Element 'sentence' at 0x7f0ae6b7b2d0>
# 2119
# <Element 'sentence' at 0x7f0ae6b7b390>
# 2647
# <Element 'sentence' at 0x7f0ae6b7b490>
# 2108
# <Element 'sentence' at 0x7f0ae6b7b510>
# 789
# <Element 'sentence' at 0x7f0ae6b7b590>
# 570
# <Element 'sentence' at 0x7f0ae6b7b610>
# 980
# <Element 'sentence' at 0x7f0ae6b7b710>
# 668
# <Element 'sentence' at 0x7f0ae6b7b850>
# 1106
# <Element 'sentence' at 0x7f0ae6b7b950>
# 140
# <Element 'sentence' at 0x7f0ae6b7ba50>
# 1418
# <Element 'sentence' at 0x7f0ae6b7bb50>
# 539
# <Element 'sentence' at 0x7f0ae6b7bbd0>
# 621
# <Element 'sentence' at 0x7f0ae6b7bcd0>
# 2360
# <Element 'sentence' at 0x7f0ae6b7be50>
# 2397
# <Element 'sentence' at 0x7f0ae6b7bed0>
# 2449
# <Element 'sentence' at 0x7f0ae6b7bf50>
# 1126
# <Element 'sentence' at 0x7f0ae6b88110>
# 1745
# <Element 'sentence' at 0x7f0ae6b882d0>
# 2205
# <Element 'sentence' at 0x7f0ae6b88350>
# 1065
# <Element 'sentence' at 0x7f0ae6b883d0>
# 987
# <Element 'sentence' at 0x7f0ae6b88490>
# 363
# <Element 'sentence' at 0x7f0ae6b884d0>
# 1276
# <Element 'sentence' at 0x7f0ae6b88550>
# 2911
# <Element 'sentence' at 0x7f0ae6b885d0>
# 2714
# <Element 'sentence' at 0x7f0ae6b88650>
# 2900
# <Element 'sentence' at 0x7f0ae6b886d0>
# 2177
# <Element 'sentence' at 0x7f0ae6b88750>
# 164
# <Element 'sentence' at 0x7f0ae6b887d0>
# 39
# <Element 'sentence' at 0x7f0ae6b888d0>
# 3019
# <Element 'sentence' at 0x7f0ae6b88a10>
# 1517
# <Element 'sentence' at 0x7f0ae6b88a90>
# 1090
# <Element 'sentence' at 0x7f0ae6b88b50>
# 1678
# <Element 'sentence' at 0x7f0ae6b88bd0>
# 2469
# <Element 'sentence' at 0x7f0ae6b88cd0>
# 2429
# <Element 'sentence' at 0x7f0ae6b88d50>
# 1986
# <Element 'sentence' at 0x7f0ae6b88e90>
# 1088
# <Element 'sentence' at 0x7f0ae6b15050>
# 678
# <Element 'sentence' at 0x7f0ae6b15190>
# 417
# <Element 'sentence' at 0x7f0ae6b15210>
# 625
# <Element 'sentence' at 0x7f0ae6b152d0>
# 2035
# <Element 'sentence' at 0x7f0ae6b15410>
# 636
# <Element 'sentence' at 0x7f0ae6b15490>
# 1808
# <Element 'sentence' at 0x7f0ae6b15510>
# 1921
# <Element 'sentence' at 0x7f0ae6b15610>
# 1872
# <Element 'sentence' at 0x7f0ae6b15710>
# 1413
# <Element 'sentence' at 0x7f0ae6b15850>
# 369
# <Element 'sentence' at 0x7f0ae6b158d0>
# 321
# <Element 'sentence' at 0x7f0ae6b15950>
# 2636
# <Element 'sentence' at 0x7f0ae6b15a50>
# 357
# <Element 'sentence' at 0x7f0ae6b15b90>
# 1230
# <Element 'sentence' at 0x7f0ae6b15c10>
# 1006
# <Element 'sentence' at 0x7f0ae6b15c90>
# 3075
# <Element 'sentence' at 0x7f0ae6b15d90>
# 216
# <Element 'sentence' at 0x7f0ae6b15e10>
# 3045
# <Element 'sentence' at 0x7f0ae6b15f50>
# 1688
# <Element 'sentence' at 0x7f0ae6b15fd0>
# 2098
# <Element 'sentence' at 0x7f0ae6b23090>
# 1877
# <Element 'sentence' at 0x7f0ae6b23110>
# 129
# <Element 'sentence' at 0x7f0ae6b23190>
# 235
# <Element 'sentence' at 0x7f0ae6b232d0>
# 3055
# <Element 'sentence' at 0x7f0ae6b23410>
# 2865
# <Element 'sentence' at 0x7f0ae6b23510>
# 1300
# <Element 'sentence' at 0x7f0ae6b23590>
# 1197
# <Element 'sentence' at 0x7f0ae6b23690>
# 2538
# <Element 'sentence' at 0x7f0ae6b23710>
# 1403
# <Element 'sentence' at 0x7f0ae6b23790>
# 2676
# <Element 'sentence' at 0x7f0ae6b23890>
# 75
# <Element 'sentence' at 0x7f0ae6b23910>
# 2319
# <Element 'sentence' at 0x7f0ae6b239d0>
# 452
# <Element 'sentence' at 0x7f0ae6b23bd0>
# 2498
# <Element 'sentence' at 0x7f0ae6b23cd0>
# 2515
# <Element 'sentence' at 0x7f0ae6b23dd0>
# 2320
# <Element 'sentence' at 0x7f0ae6b23ed0>
# 2051
# <Element 'sentence' at 0x7f0ae6b23f50>
# 1017
# <Element 'sentence' at 0x7f0ae6b23fd0>
# 971
# <Element 'sentence' at 0x7f0ae6b2f090>
# 3083
# <Element 'sentence' at 0x7f0ae6b2f190>
# 1687
# <Element 'sentence' at 0x7f0ae6b2f210>
# 2593
# <Element 'sentence' at 0x7f0ae6b2f310>
# 1507
# <Element 'sentence' at 0x7f0ae6b2f390>
# 336
# <Element 'sentence' at 0x7f0ae6b2f450>
# 2391
# <Element 'sentence' at 0x7f0ae6b2f510>
# 786
# <Element 'sentence' at 0x7f0ae6b2f590>
# 1616
# <Element 'sentence' at 0x7f0ae6b2f690>
# 1062
# <Element 'sentence' at 0x7f0ae6b2f790>
# 1982
# <Element 'sentence' at 0x7f0ae6b2f810>
# 2704
# <Element 'sentence' at 0x7f0ae6b2f910>
# 2930
# <Element 'sentence' at 0x7f0ae6b2f990>
# 343
# <Element 'sentence' at 0x7f0ae6b2fa10>
# 1152
# <Element 'sentence' at 0x7f0ae6b2fb50>
# 1868
# <Element 'sentence' at 0x7f0ae6b2fbd0>
# 1353
# <Element 'sentence' at 0x7f0ae6b2fc90>
# 977
# <Element 'sentence' at 0x7f0ae6b2fd10>
# 2747
# <Element 'sentence' at 0x7f0ae6b2fe50>
# 2102
# <Element 'sentence' at 0x7f0ae6b2fed0>
# 967
# <Element 'sentence' at 0x7f0ae6b2ffd0>
# 1774
# <Element 'sentence' at 0x7f0ae6b3c090>
# 1685
# <Element 'sentence' at 0x7f0ae6b3c150>
# 932
# <Element 'sentence' at 0x7f0ae6b3c1d0>
# 2501
# <Element 'sentence' at 0x7f0ae6b3c2d0>
# 1873
# <Element 'sentence' at 0x7f0ae6b3c350>
# 1753
# <Element 'sentence' at 0x7f0ae6b3c410>
# 892
# <Element 'sentence' at 0x7f0ae6b3c490>
# 1241
# <Element 'sentence' at 0x7f0ae6b3c510>
# 135
# <Element 'sentence' at 0x7f0ae6b3c590>
# 1801
# <Element 'sentence' at 0x7f0ae6b3c6d0>
# 2902
# <Element 'sentence' at 0x7f0ae6b3c810>
# 2062
# <Element 'sentence' at 0x7f0ae6b3c890>
# 2656
# <Element 'sentence' at 0x7f0ae6b3c990>
# 652
# <Element 'sentence' at 0x7f0ae6b3ca90>
# 170
# <Element 'sentence' at 0x7f0ae6b3cb90>
# 665
# <Element 'sentence' at 0x7f0ae6b3cc10>
# 787
# <Element 'sentence' at 0x7f0ae6b3cc90>
# 814
# <Element 'sentence' at 0x7f0ae6b3cd10>
# 2047
# <Element 'sentence' at 0x7f0ae6b3ce10>
# 3039
# <Element 'sentence' at 0x7f0ae6b3ce90>
# 1371
# <Element 'sentence' at 0x7f0ae6b3cf50>
# 2666
# <Element 'sentence' at 0x7f0ae6aca050>
# 741
# <Element 'sentence' at 0x7f0ae6aca150>
# 1748
# <Element 'sentence' at 0x7f0ae6aca290>
# 774
# <Element 'sentence' at 0x7f0ae6aca310>
# 2246
# <Element 'sentence' at 0x7f0ae6aca490>
# 1055
# <Element 'sentence' at 0x7f0ae6aca510>
# 401
# <Element 'sentence' at 0x7f0ae6aca590>
# 2032
# <Element 'sentence' at 0x7f0ae6aca710>
# 1780
# <Element 'sentence' at 0x7f0ae6aca790>
# 150
# <Element 'sentence' at 0x7f0ae6aca8d0>
# 1581
# <Element 'sentence' at 0x7f0ae6aca950>
# 302
# <Element 'sentence' at 0x7f0ae6acaa50>
# 204
# <Element 'sentence' at 0x7f0ae6acab50>
# 2080
# <Element 'sentence' at 0x7f0ae6acad90>
# 964
# <Element 'sentence' at 0x7f0ae6acae50>
# 2780
# <Element 'sentence' at 0x7f0ae6acaf90>
# 1105
# <Element 'sentence' at 0x7f0ae6ad70d0>
# 1484
# <Element 'sentence' at 0x7f0ae6ad71d0>
# 17
# <Element 'sentence' at 0x7f0ae6ad7250>
# 2506
# ...
# 1235
# <Element 'sentence' at 0x7f0ae72b60d0>
# 1773
# <Element 'sentence' at 0x7f0ae72b6150>
# 1854
# <Element 'sentence' at 0x7f0ae72b61d0>
# 1511
# <Element 'sentence' at 0x7f0ae72b62d0>
# 563
# <Element 'sentence' at 0x7f0ae72b6410>
# 2668
# <Element 'sentence' at 0x7f0ae72b6510>
# 1535
# <Element 'sentence' at 0x7f0ae72b66d0>
# 2991
# <Element 'sentence' at 0x7f0ae72b67d0>
# 132
# <Element 'sentence' at 0x7f0ae72b68d0>
# 1011
# <Element 'sentence' at 0x7f0ae72b6950>
# 466
# <Element 'sentence' at 0x7f0ae72b69d0>
# 208
# <Element 'sentence' at 0x7f0ae72b6ad0>
# 2314
# <Element 'sentence' at 0x7f0ae72b6bd0>
# 2552
# <Element 'sentence' at 0x7f0ae72b6c50>
# 634
# <Element 'sentence' at 0x7f0ae72b6d50>
# 1926
# <Element 'sentence' at 0x7f0ae72b6ed0>
# 880
# <Element 'sentence' at 0x7f0ae72b6f50>
# 721
# <Element 'sentence' at 0x7f0ae72b6fd0>
# 2849
# <Element 'sentence' at 0x7f0ae726c090>
# 360
# <Element 'sentence' at 0x7f0ae726c150>
# 1572
# <Element 'sentence' at 0x7f0ae726c1d0>
# 247
# <Element 'sentence' at 0x7f0ae726c250>
# 2417
# <Element 'sentence' at 0x7f0ae726c350>
# 1715
# <Element 'sentence' at 0x7f0ae726c3d0>
# 500
# <Element 'sentence' at 0x7f0ae726c510>
# 859
# <Element 'sentence' at 0x7f0ae726c610>
# 1504
# <Element 'sentence' at 0x7f0ae726c7d0>
# 2474
# <Element 'sentence' at 0x7f0ae726c850>
# 158
# <Element 'sentence' at 0x7f0ae726c950>
# 2421
# <Element 'sentence' at 0x7f0ae726ca10>
# 2567
# <Element 'sentence' at 0x7f0ae726ca90>
# 1961
# <Element 'sentence' at 0x7f0ae726cb50>
# 2879
# <Element 'sentence' at 0x7f0ae726cc90>
# 946
# <Element 'sentence' at 0x7f0ae726cd10>
# 1565
# <Element 'sentence' at 0x7f0ae726ce10>
# 2854
# <Element 'sentence' at 0x7f0ae726cf50>
# 2585
# <Element 'sentence' at 0x7f0ae72770d0>
# 2692
# <Element 'sentence' at 0x7f0ae7277290>
# 1146
# <Element 'sentence' at 0x7f0ae7277310>
# 413
# <Element 'sentence' at 0x7f0ae7277390>
# 2634
# <Element 'sentence' at 0x7f0ae7277410>
# 2232
# <Element 'sentence' at 0x7f0ae7277490>
# 3018
# <Element 'sentence' at 0x7f0ae7277590>
# 49
# <Element 'sentence' at 0x7f0ae7277690>
# 2614
# <Element 'sentence' at 0x7f0ae7277710>
# 981
# <Element 'sentence' at 0x7f0ae7277790>
# 259
# <Element 'sentence' at 0x7f0ae7277890>
# 2774
# <Element 'sentence' at 0x7f0ae7277910>
# 2256
# <Element 'sentence' at 0x7f0ae7277990>
# 1550
# <Element 'sentence' at 0x7f0ae7277a10>
# 1721
# <Element 'sentence' at 0x7f0ae7277a90>
# 2146
# <Element 'sentence' at 0x7f0ae7277c10>
# 1399
# <Element 'sentence' at 0x7f0ae7277d10>
# 2400
# <Element 'sentence' at 0x7f0ae7277e90>
# 1917
# <Element 'sentence' at 0x7f0ae7277f10>
# 1302
# <Element 'sentence' at 0x7f0ae7287050>
# 2815
# <Element 'sentence' at 0x7f0ae72870d0>
# 534
# <Element 'sentence' at 0x7f0ae7287210>
# 429
# <Element 'sentence' at 0x7f0ae7287350>
# 978
# <Element 'sentence' at 0x7f0ae72873d0>
# 2301
# <Element 'sentence' at 0x7f0ae72874d0>
# 2087
# <Element 'sentence' at 0x7f0ae7287550>
# 2378
# <Element 'sentence' at 0x7f0ae7287650>
# 2722
# <Element 'sentence' at 0x7f0ae72877d0>
# 1058
# <Element 'sentence' at 0x7f0ae7287950>
# 2252
# <Element 'sentence' at 0x7f0ae7287a90>
# 2781
# <Element 'sentence' at 0x7f0ae7287b90>
# 927
# <Element 'sentence' at 0x7f0ae7287c90>
# 2293
# <Element 'sentence' at 0x7f0ae7287d10>
# 424
# <Element 'sentence' at 0x7f0ae7287d90>
# 2316
# <Element 'sentence' at 0x7f0ae7287e10>
# 2008
# <Element 'sentence' at 0x7f0ae7287e90>
# 1726
# <Element 'sentence' at 0x7f0ae7287f10>
# 2779
# <Element 'sentence' at 0x7f0ae7287f90>
# 2955
# <Element 'sentence' at 0x7f0ae72210d0>
# 2697
# <Element 'sentence' at 0x7f0ae7221250>
# 1575
# <Element 'sentence' at 0x7f0ae72212d0>
# 1007
# <Element 'sentence' at 0x7f0ae7221350>
# 979
# <Element 'sentence' at 0x7f0ae7221410>
# 2357
# <Element 'sentence' at 0x7f0ae7221510>
# 1087
# <Element 'sentence' at 0x7f0ae7221610>
# 2529
# <Element 'sentence' at 0x7f0ae7221710>
# 2111
# <Element 'sentence' at 0x7f0ae7221810>
# 71
# <Element 'sentence' at 0x7f0ae7221850>
# 1619
# <Element 'sentence' at 0x7f0ae7221910>
# 400
# <Element 'sentence' at 0x7f0ae7221a90>
# 2628
# <Element 'sentence' at 0x7f0ae7221b10>
# 2212
# <Element 'sentence' at 0x7f0ae7221c10>
# 2153
# <Element 'sentence' at 0x7f0ae7221d10>
# 212
# <Element 'sentence' at 0x7f0ae7221dd0>
# 443
# <Element 'sentence' at 0x7f0ae7221ed0>
# 511
# <Element 'sentence' at 0x7f0ae7221f50>
# 194
# <Element 'sentence' at 0x7f0ae722e090>
# 2620
# <Element 'sentence' at 0x7f0ae722e190>
# 1593
# <Element 'sentence' at 0x7f0ae722e210>
# 83
# <Element 'sentence' at 0x7f0ae722e290>
# 1299
# <Element 'sentence' at 0x7f0ae722e3d0>
# 366
# <Element 'sentence' at 0x7f0ae722e4d0>
# 2686
# <Element 'sentence' at 0x7f0ae722e610>
# 368
# <Element 'sentence' at 0x7f0ae722e690>
# 784
# <Element 'sentence' at 0x7f0ae722e790>
# 647
# <Element 'sentence' at 0x7f0ae722e810>
# 1496
# <Element 'sentence' at 0x7f0ae722e9d0>
# 2602
# <Element 'sentence' at 0x7f0ae722eb50>
# 1450
# <Element 'sentence' at 0x7f0ae722ecd0>
# 1410
# <Element 'sentence' at 0x7f0ae722edd0>
# 688
# <Element 'sentence' at 0x7f0ae722ee50>
# 2097
# <Element 'sentence' at 0x7f0ae722ef50>
# 527
# <Element 'sentence' at 0x7f0ae722efd0>
# 2665
# <Element 'sentence' at 0x7f0ae71e2090>
# 1795
# <Element 'sentence' at 0x7f0ae71e2190>
# 2230
# <Element 'sentence' at 0x7f0ae71e2210>
# 114
# <Element 'sentence' at 0x7f0ae71e2290>
# 2224
# <Element 'sentence' at 0x7f0ae71e2310>
# 3033
# <Element 'sentence' at 0x7f0ae71e2390>
# 1614
# <Element 'sentence' at 0x7f0ae71e24d0>
# 1003
# <Element 'sentence' at 0x7f0ae71e2550>
# 1392
# <Element 'sentence' at 0x7f0ae71e2650>
# 680
# <Element 'sentence' at 0x7f0ae71e26d0>
# 436
# <Element 'sentence' at 0x7f0ae71e2750>
# 697
# <Element 'sentence' at 0x7f0ae71e28d0>
# 1159
# <Element 'sentence' at 0x7f0ae71e29d0>
# 2757
# <Element 'sentence' at 0x7f0ae71e2bd0>
# 232
# <Element 'sentence' at 0x7f0ae71e2c50>
# 2122
# <Element 'sentence' at 0x7f0ae71e2cd0>
# 1508
# <Element 'sentence' at 0x7f0ae71e2d50>
# 278
# <Element 'sentence' at 0x7f0ae71e2e50>
# 2783
# <Element 'sentence' at 0x7f0ae71e2f50>
# 327
# <Element 'sentence' at 0x7f0ae71ff090>
# 2731
# <Element 'sentence' at 0x7f0ae71ff210>
# 218
# <Element 'sentence' at 0x7f0ae71ff290>
# 5
# <Element 'sentence' at 0x7f0ae71ff310>
# 1749
# <Element 'sentence' at 0x7f0ae71ff550>
# 820
# <Element 'sentence' at 0x7f0ae71ff5d0>
# 245
# <Element 'sentence' at 0x7f0ae71ff6d0>
# 1979
# <Element 'sentence' at 0x7f0ae71ff750>
# 202
# <Element 'sentence' at 0x7f0ae71ff810>
# 1142
# <Element 'sentence' at 0x7f0ae71ff950>
# 1211
# <Element 'sentence' at 0x7f0ae71ffa10>
# 2294
# <Element 'sentence' at 0x7f0ae71ffa90>
# 1583
# <Element 'sentence' at 0x7f0ae71ffb10>
# 2372
# <Element 'sentence' at 0x7f0ae71ffb90>
# 1438
# <Element 'sentence' at 0x7f0ae71ffdd0>
# 1949
# <Element 'sentence' at 0x7f0ae71ffe90>
# 2663
# <Element 'sentence' at 0x7f0ae71fff10>
# 952
# <Element 'sentence' at 0x7f0ae718c050>
# 1858
# <Element 'sentence' at 0x7f0ae718c150>
# 2235
# <Element 'sentence' at 0x7f0ae718c310>
# 2825
# <Element 'sentence' at 0x7f0ae718c390>
# 514
# <Element 'sentence' at 0x7f0ae718c410>
# 1048
# <Element 'sentence' at 0x7f0ae718c710>
# 1729
# <Element 'sentence' at 0x7f0ae718c7d0>
# 1904
# <Element 'sentence' at 0x7f0ae718c850>
# 1182
# <Element 'sentence' at 0x7f0ae718c950>
# 2455
# <Element 'sentence' at 0x7f0ae718ca90>
# 1213
# <Element 'sentence' at 0x7f0ae718cb50>
# 1394
# <Element 'sentence' at 0x7f0ae718cc10>
# 1924
# <Element 'sentence' at 0x7f0ae718cd50>
# 2268
# <Element 'sentence' at 0x7f0ae718ce10>
# 2171
# <Element 'sentence' at 0x7f0ae718cf50>
# 790
# <Element 'sentence' at 0x7f0ae718cfd0>
# 552
# <Element 'sentence' at 0x7f0ae71a9210>
# 1859
# <Element 'sentence' at 0x7f0ae71a92d0>
# 2589
# <Element 'sentence' at 0x7f0ae71a9350>
# 2643
# <Element 'sentence' at 0x7f0ae71a93d0>
# 733
# <Element 'sentence' at 0x7f0ae71a94d0>
# 870
# <Element 'sentence' at 0x7f0ae71a9550>
# 1910
# <Element 'sentence' at 0x7f0ae71a95d0>
# 2029
# <Element 'sentence' at 0x7f0ae71a9650>
# 2242
# <Element 'sentence' at 0x7f0ae71a9790>
# 2085
# <Element 'sentence' at 0x7f0ae71a9890>
# 543
# <Element 'sentence' at 0x7f0ae71a99d0>
# 925
# <Element 'sentence' at 0x7f0ae71a9ad0>
# 724
# <Element 'sentence' at 0x7f0ae71a9b50>
# 2139
# <Element 'sentence' at 0x7f0ae71a9bd0>
# 1771
# <Element 'sentence' at 0x7f0ae71a9d10>
# 383
# <Element 'sentence' at 0x7f0ae71a9dd0>
# 2355
# <Element 'sentence' at 0x7f0ae71a9e50>
# 2200
# <Element 'sentence' at 0x7f0ae71a9ed0>
# 723
# <Element 'sentence' at 0x7f0ae71a9f50>
# 2043
# <Element 'sentence' at 0x7f0ae71a9f90>
# 2258
# <Element 'sentence' at 0x7f0ae71b7110>
# 1960
# <Element 'sentence' at 0x7f0ae71b7250>
# 2006
# <Element 'sentence' at 0x7f0ae71b72d0>
# 2223
# <Element 'sentence' at 0x7f0ae71b73d0>
# 23
# <Element 'sentence' at 0x7f0ae71b7510>
# 2711
# <Element 'sentence' at 0x7f0ae71b7690>
# 1899
# <Element 'sentence' at 0x7f0ae71b7710>
# 495
# <Element 'sentence' at 0x7f0ae71b7790>
# 1606
# <Element 'sentence' at 0x7f0ae71b7910>
# 1018
# <Element 'sentence' at 0x7f0ae71b7a10>
# 1761
# <Element 'sentence' at 0x7f0ae71b7ad0>
# 554
# <Element 'sentence' at 0x7f0ae71b7b50>
# 2728
# <Element 'sentence' at 0x7f0ae71b7c50>
# 1964
# <Element 'sentence' at 0x7f0ae71b7d90>
# 2808
# <Element 'sentence' at 0x7f0ae71c3090>
# 775
# <Element 'sentence' at 0x7f0ae71c3190>
# 2424
# <Element 'sentence' at 0x7f0ae71c3290>
# 1689
# <Element 'sentence' at 0x7f0ae71c3390>
# 1894
# <Element 'sentence' at 0x7f0ae71c3410>
# 1078
# <Element 'sentence' at 0x7f0ae71c3510>
# 1492
# <Element 'sentence' at 0x7f0ae71c3650>
# 808
# <Element 'sentence' at 0x7f0ae71c3750>
# 1472
# <Element 'sentence' at 0x7f0ae71c3850>
# 1038
# <Element 'sentence' at 0x7f0ae71c3990>
# 818
# <Element 'sentence' at 0x7f0ae71c39d0>
# 861
# <Element 'sentence' at 0x7f0ae71c3a90>
# 544
# <Element 'sentence' at 0x7f0ae71c3bd0>
# 1959
# <Element 'sentence' at 0x7f0ae71c3cd0>
# 315
# <Element 'sentence' at 0x7f0ae71c3dd0>
# 2573
# <Element 'sentence' at 0x7f0ae71c3fd0>
# 1996
# <Element 'sentence' at 0x7f0ae7151110>
# 509
# <Element 'sentence' at 0x7f0ae7151190>
# 1600
# <Element 'sentence' at 0x7f0ae7151310>
# 719
# <Element 'sentence' at 0x7f0ae7151490>
# 141
# <Element 'sentence' at 0x7f0ae71515d0>
# 1920
# <Element 'sentence' at 0x7f0ae7151650>
# 760
# <Element 'sentence' at 0x7f0ae7151710>
# 193
# <Element 'sentence' at 0x7f0ae71517d0>
# 1016
# <Element 'sentence' at 0x7f0ae7151850>
# 507
# <Element 'sentence' at 0x7f0ae71518d0>
# 1255
# <Element 'sentence' at 0x7f0ae71519d0>
# 667
# <Element 'sentence' at 0x7f0ae7151b10>
# 1992
# <Element 'sentence' at 0x7f0ae7151c50>
# 2430
# <Element 'sentence' at 0x7f0ae7151d50>
# 2406
# <Element 'sentence' at 0x7f0ae7151dd0>
# 1021
# <Element 'sentence' at 0x7f0ae7151f10>
# 1209
# <Element 'sentence' at 0x7f0ae7151f90>
# 1701
# <Element 'sentence' at 0x7f0ae715e0d0>
# 2570
# <Element 'sentence' at 0x7f0ae715e150>
# 287
# <Element 'sentence' at 0x7f0ae715e210>
# 681
# <Element 'sentence' at 0x7f0ae715e290>
# 866
# <Element 'sentence' at 0x7f0ae715e310>
# 1248
# <Element 'sentence' at 0x7f0ae715e410>
# 2857
# <Element 'sentence' at 0x7f0ae715e450>
# 266
# <Element 'sentence' at 0x7f0ae715e510>
# 811
# <Element 'sentence' at 0x7f0ae715e610>
# 2693
# <Element 'sentence' at 0x7f0ae715e690>
# 504
# <Element 'sentence' at 0x7f0ae715e790>
# 1845
# <Element 'sentence' at 0x7f0ae715e890>
# 434
# <Element 'sentence' at 0x7f0ae715e910>
# 2479
# <Element 'sentence' at 0x7f0ae715ea90>
# 1407
# <Element 'sentence' at 0x7f0ae715eb90>
# 1113
# <Element 'sentence' at 0x7f0ae715ed10>
# 1976
# <Element 'sentence' at 0x7f0ae715ed50>
# 1643
# <Element 'sentence' at 0x7f0ae715edd0>
# 2431
# <Element 'sentence' at 0x7f0ae715eed0>
# 905
# <Element 'sentence' at 0x7f0ae715efd0>
# 2196
# <Element 'sentence' at 0x7f0ae716b110>
# 1878
# <Element 'sentence' at 0x7f0ae716b290>
# 758
# <Element 'sentence' at 0x7f0ae716b3d0>
# 1131
# <Element 'sentence' at 0x7f0ae716b510>
# 2052
# <Element 'sentence' at 0x7f0ae716b590>
# 1295
# <Element 'sentence' at 0x7f0ae716b6d0>
# 112
# <Element 'sentence' at 0x7f0ae716b7d0>
# 2123
# <Element 'sentence' at 0x7f0ae716b890>
# 190
# <Element 'sentence' at 0x7f0ae716b950>
# 2459
# <Element 'sentence' at 0x7f0ae716b9d0>
# 1665
# <Element 'sentence' at 0x7f0ae716ba50>
# 1101
# <Element 'sentence' at 0x7f0ae716bb90>
# 1948
# <Element 'sentence' at 0x7f0ae716bc50>
# 2340
# <Element 'sentence' at 0x7f0ae716bd10>
# 115
# <Element 'sentence' at 0x7f0ae716be90>
# 196
# <Element 'sentence' at 0x7f0ae716bf10>
# 2332
# <Element 'sentence' at 0x7f0ae7179050>
# 2687
# <Element 'sentence' at 0x7f0ae71790d0>
# 2633
# <Element 'sentence' at 0x7f0ae7179150>
# 845
# <Element 'sentence' at 0x7f0ae7179250>
# 1741
# <Element 'sentence' at 0x7f0ae71792d0>
# 2914
# <Element 'sentence' at 0x7f0ae7179410>
# 2318
# <Element 'sentence' at 0x7f0ae7179510>
# 153
# <Element 'sentence' at 0x7f0ae7179610>
# 3071
# <Element 'sentence' at 0x7f0ae7179690>
# 1415
# <Element 'sentence' at 0x7f0ae7179790>
# 2946
# <Element 'sentence' at 0x7f0ae7179890>
# 1380
# <Element 'sentence' at 0x7f0ae7179910>
# 833
# <Element 'sentence' at 0x7f0ae7179a10>
# 2285
# <Element 'sentence' at 0x7f0ae7179a90>
# 2148
# <Element 'sentence' at 0x7f0ae7179b10>
# 2106
# <Element 'sentence' at 0x7f0ae7179c50>
# 2595
# <Element 'sentence' at 0x7f0ae7179d50>
# 584
# <Element 'sentence' at 0x7f0ae7179dd0>
# 2244
# <Element 'sentence' at 0x7f0ae7179e50>
# 1966
# <Element 'sentence' at 0x7f0ae7179f50>
# 991
# <Element 'sentence' at 0x7f0ae7179fd0>
# 617
# <Element 'sentence' at 0x7f0ae7186110>
# 2168
# <Element 'sentence' at 0x7f0ae7186250>
# 1765
# <Element 'sentence' at 0x7f0ae7186390>
# 778
# <Element 'sentence' at 0x7f0ae71864d0>
# 1215
# <Element 'sentence' at 0x7f0ae7186550>
# 195
# <Element 'sentence' at 0x7f0ae71865d0>
# 1
# <Element 'sentence' at 0x7f0ae7186690>
# 1707
# <Element 'sentence' at 0x7f0ae71867d0>
# 530
# <Element 'sentence' at 0x7f0ae7186850>
# 2553
# <Element 'sentence' at 0x7f0ae7186990>
# 1485
# <Element 'sentence' at 0x7f0ae7186ad0>
# 666
# <Element 'sentence' at 0x7f0ae7186b50>
# 2672
# <Element 'sentence' at 0x7f0ae7186c50>
# 1258
# <Element 'sentence' at 0x7f0ae7186dd0>
# 375
# <Element 'sentence' at 0x7f0ae7186e50>
# 63
# <Element 'sentence' at 0x7f0ae7186f50>
# 3048
# <Element 'sentence' at 0x7f0ae71120d0>
# 1552
# <Element 'sentence' at 0x7f0ae71121d0>
# 2598
# <Element 'sentence' at 0x7f0ae7112250>
# 2112
# <Element 'sentence' at 0x7f0ae7112390>
# 461
# <Element 'sentence' at 0x7f0ae7112410>
# 2823
# <Element 'sentence' at 0x7f0ae7112510>
# 2249
# <Element 'sentence' at 0x7f0ae7112590>
# 1582
# <Element 'sentence' at 0x7f0ae7112710>
# 1141
# <Element 'sentence' at 0x7f0ae7112790>
# 2140
# <Element 'sentence' at 0x7f0ae7112890>
# 1786
# <Element 'sentence' at 0x7f0ae7112910>
# 2023
# <Element 'sentence' at 0x7f0ae7112990>
# 351
# <Element 'sentence' at 0x7f0ae7112a10>
# 1389
# <Element 'sentence' at 0x7f0ae7112a90>
# 2545
# <Element 'sentence' at 0x7f0ae7112b10>
# 908
# <Element 'sentence' at 0x7f0ae7112c10>
# 867
# <Element 'sentence' at 0x7f0ae7112c90>
# 2898
# <Element 'sentence' at 0x7f0ae7112d90>
# 29
# <Element 'sentence' at 0x7f0ae7112ed0>
# 2561
# <Element 'sentence' at 0x7f0ae71210d0>
# 2376
# <Element 'sentence' at 0x7f0ae7121150>
# 1560
# <Element 'sentence' at 0x7f0ae71211d0>
# 2461
# <Element 'sentence' at 0x7f0ae7121250>
# 1039
# <Element 'sentence' at 0x7f0ae7121350>
# 1519
# <Element 'sentence' at 0x7f0ae71213d0>
# 2380
# <Element 'sentence' at 0x7f0ae7121510>
# 2172
# <Element 'sentence' at 0x7f0ae7121590>
# 349
# <Element 'sentence' at 0x7f0ae7121690>
# 2255
# <Element 'sentence' at 0x7f0ae7121710>
# 1309
# <Element 'sentence' at 0x7f0ae7121850>
# 2299
# <Element 'sentence' at 0x7f0ae7121910>
# 712
# <Element 'sentence' at 0x7f0ae7121a50>
# 872
# <Element 'sentence' at 0x7f0ae7121ad0>
# 1109
# <Element 'sentence' at 0x7f0ae7121b50>
# 389
# <Element 'sentence' at 0x7f0ae7121bd0>
# 506
# <Element 'sentence' at 0x7f0ae7121d10>
# 1175
# <Element 'sentence' at 0x7f0ae7121e10>
# 1049
# <Element 'sentence' at 0x7f0ae7121f10>
# 233
# <Element 'sentence' at 0x7f0ae7121f90>
# 265
# <Element 'sentence' at 0x7f0ae71310d0>
# 394
# <Element 'sentence' at 0x7f0ae7131290>
# 152
# <Element 'sentence' at 0x7f0ae7131390>
# 143
# <Element 'sentence' at 0x7f0ae7131450>
# 1656
# <Element 'sentence' at 0x7f0ae71314d0>
# 1402
# <Element 'sentence' at 0x7f0ae7131550>
# 1284
# <Element 'sentence' at 0x7f0ae7131650>
# 1317
# <Element 'sentence' at 0x7f0ae71316d0>
# 1636
# <Element 'sentence' at 0x7f0ae7131750>
# 409
# <Element 'sentence' at 0x7f0ae71317d0>
# 2131
# <Element 'sentence' at 0x7f0ae7131850>
# 2228
# <Element 'sentence' at 0x7f0ae71318d0>
# 1797
# <Element 'sentence' at 0x7f0ae7131990>
# 2272
# <Element 'sentence' at 0x7f0ae7131c50>
# 479
# <Element 'sentence' at 0x7f0ae7131cd0>
# 2657
# <Element 'sentence' at 0x7f0ae7131d50>
# 618
# <Element 'sentence' at 0x7f0ae7131dd0>
# 1207
# <Element 'sentence' at 0x7f0ae7131ed0>
# 848
# <Element 'sentence' at 0x7f0ae70cb050>
# 734
# <Element 'sentence' at 0x7f0ae70cb150>
# 230
# <Element 'sentence' at 0x7f0ae70cb1d0>
# 2194
# <Element 'sentence' at 0x7f0ae70cb250>
# 611
# <Element 'sentence' at 0x7f0ae70cb2d0>
# 1195
# <Element 'sentence' at 0x7f0ae70cb350>
# 2893
# <Element 'sentence' at 0x7f0ae70cb3d0>
# 1712
# <Element 'sentence' at 0x7f0ae70cb450>
# 2982

# %%
sentences_list
# Out:
# ['I charge it at night and skip taking the cord with me because of the good battery life.',
#  'I bought a HP Pavilion DV4-1222nr laptop and have had so many problems with the computer.',
#  'The tech guy then said the service center does not do 1-to-1 exchange and I have to direct my concern to the "sales" team, which is the retail shop which I bought my netbook from.',
#  'I investigated netbooks and saw the Toshiba NB305-N410BL.',
#  'The other day I had a presentation to do for a seminar at a large conference in town- lots of people, little time to prep and have to set up a computer to a projector, etc.',
#  'it is of high quality, has a killer GUI, is extremely stable, is highly expandable, is bundled with lots of very good applications, is easy to use, and is absolutely gorgeous.',
#  'Easy to start up and does not overheat as much as other laptops.',
#  'Sad very SAD.',
#  'I even got my teenage son one, because of the features that it offers, like, iChat, Photobooth, garage band and more!',
#  "Needless to say a PC that can't support a cell phone is less than useless!",
#  'Great laptop that offers many great features!',
#  'they have done absolutely nothing to fix the computer problem.',
#  u'\xa0One night I turned the freaking thing off after using it, the next day I turn it on, no GUI, screen all dark, power light steady, hard drive light steady and not flashing as it usually does.',
#  "Still pretty pricey, but I've been putting off money for a while as a little Macbook Fund, and finally got to use it.",
#  'My only disappointment with the 13" model is that they\'re the only ones in the MacBook Pro line up without an i5 or i7 processor and dual graphics cards, however the trade-off is that you achieve a longer battery life (of about 2 more hours).',
#  'I took it back for an Asus and same thing- blue screen which required me to remove the battery to reset.',
#  'In the shop, these MacBooks are encased in a soft rubber enclosure - so you will never know about the razor edge until you buy it, get it home, break the seal and use it (very clever con).',
#  "However, the multi-touch gestures and large tracking area make having an external mouse unnecessary (unless you're gaming).",
#  'Plus it is small and reasonably light so I can take it with me to and from work.',
#  'I HATE this one.',
#  'They were totally unconcerned that the computer was not correctly repaired in the first place.',
#  'Toshiba does not send any one out unless you have paid extra to have the on site repair done.',
#  'Oh, boy!',
#  'But while this is one big advantage (as you may know from the company s recent commercials) there are other things to consider before going with Apple.',
#  'I love the way the entire suite of software works together.',
#  'The speed is incredible and I am more than satisfied.',
#  "on the bright side at least I wasn't without my laptop for long this time!",
#  'This laptop meets every expectation and Windows 7 is great!',
#  "That's how frustrating it was.",
#  'I can barely use any usb devices because they will not stay connected properly.',
#  'The one down side to it is that when I play a certin game on here, it tends to freeze up sometimes, but thats the only bad thing about this computer.',
#  '-No backlit keyboard, but not an issue for me.',
#  'When I finally had everything running with all my software installed I plugged in my droid to recharge and the system crashed.',
#  "I can't even turn it off.",
#  'One suggestion I do have, is to not bother getting Microsoft office for the mac expecting it will work just like you knew it to on a PC.',
#  "Pairing it with an iPhone is a pure pleasure - talk about painless syncing - used to take me forever - now it's a snap.",
#  'I shopped around before buying.',
#  'I also got the added bonus of a 30" HD Monitor, which really helps to extend my screen and keep my eyes fresh!',
#  'Would do business again.',
#  'The machine is slow to boot up and occasionally crashes completely.',
#  'After paying several hundred dollars for this service, it is frustrating that you cannot get help after hours.',
#  'I have had the luxury (sarcasm) of owning 2 of these laptops.',
#  'What a waste.',
#  'It was a total Dhell experience that I will never repeat.',
#  'There are a few flaws as well that I noticed.',
#  'Completely worth every single penny dime and nickel.',
#  'I tried to upgrade it to a newer version a couple of months ago and I still have the same problem.',
#  "I did have to replace the battery once, but that was only a couple months ago and it's been working perfect ever since.",
#  ":) In the past four years I've had it I have never once gotten a virus.",
#  'I love the operating system and the preloaded software.',
#  "They were great in handling this problem, and I'm looking forward in purchasing additonal products from them in the future.",
#  "I've tried going back to XL but there still problems.",
#  'The best thing about this laptop is the price along with some of the newer features.',
#  'After numerous attempts of trying (including setting the clock in BIOS setup directly), I gave up(I am a techie).',
#  'YOU WILL NOT BE ABLE TO TALK TO AN AMERICAN WARRANTY SERVICE IS OUT OF COUNTRY.',
#  'But it may be potentially hundreds or thousands in the near future.',
#  'Has met or exceeded my needs for a compact travel device.',
#  'but now i have realized its a problem with this brand.',
#  'It cannot save the correct date and time I set.',
#  'I sent it back to Toshiba twice they covered it under the  warranty.',
#  "And this isn't just my one experine.",
#  'They sent me a replacement part and without informing me are requiring that I return it within 15 days or contact them and let them know the broken part will be returned later.',
#  'I was looking for a mac which is portable and has all the features that I was looking for.',
#  'I would highly recommend this one to my friends',
#  'I honestly love my mac, thats why I am a self proclaimed mac addict.',
#  'And these are some reasons you should get a macbook pro.',
#  'Also kinda loud when the fan was running.',
#  'In desparation, I called their Customer Service number and was told that my warranty had expired (2 days old) and that the priviledge of talking to a technician would cost me ("have your credit card ready").',
#  'I purchased this laptop while on a business trip to keep up with my email.',
#  'There also seemed to be a problem with the hard disc as certain times windows loads but claims to not be able to find any drivers or files.',
#  'Drivers updated ok but the BIOS update froze the system up and the computer shut down.',
#  '-they lost my laptop for a month',
#  'Spent 2 hours on phone with HP Technical Support.',
#  'This is my second laptop,and it is head and shoulders above my first.',
#  'at first!',
#  'Speaking of the browser, it too has problems.',
#  "I think just going from PC to Mac has gotten me totally spoiled and I can't imagine ever going back.",
#  'The keyboard is too slick.',
#  'Nightly my computer defrags itself and runs a virus scan.',
#  "It's like 9 punds, but if you can look past it, it's GREAT!",
#  "It's just as fast with one program open as it is with sixteen open.",
#  'Still under warrenty so called Toshiba, no help at all.',
#  'I was happy with My purchase of a Toshiba Satellite L305D-S5934 laptop until it came time to have it repaired under the Toshiba Warranty.',
#  'I LOVE IT!',
#  'Amazing Quality!',
#  'The fact that you can spend over $100 on just a webcam underscores the value of this machine.',
#  'I mainly use it for email, internet, and managing personal files (pics, vids, etc.).',
#  'A month or so ago, the freaking motherboard just died.',
#  'The system it comes with does not work properly, so when trying to fix the problems with it it started not working at all.',
#  'Then after 4 or so months the charger stopped working so I was forced to go out and buy new hardware just to keep this computer running.',
#  'I took it back to Best Buy where they were so helpful and immediately gave me a new one.',
#  'If you had PC for four years I can almost gaurentee that something would of gone wrong by now, maybe even forcing you to replace your entire computer.',
#  '*2 weeks after giving the computer for repair*-Called headquarters, they report that they have not looked at it yet but it is "on the top of the stack".',
#  'This machine delivers.',
#  'Then 2 of my nephews were going into music and both fell in love with the MacBook Pro.',
#  'I complain again...',
#  'This laptop is insane!!!',
#  'If a website ever freezes (which is rare), its really easy to force quit.',
#  'It does run a little warm but that is a negligible concern.',
#  "It rarely works and when it does it's incredibly slow.",
#  'I also enjoy the fact that my MacBook Pro laptop allows me to run Windows 7 on it by using the VMWare program.',
#  "It's so much easier to navigate through the operating system, to find files, and it runs a lot faster!",
#  'Purchased a Toshiba Lap top it worked good until just after the warrenty went out.',
#  'I always swore by PCs and would never consider a MAC.',
#  'what an elegant, wonderful machine.',
#  'This is now my 3rd MacBook Pro and I really honestly love it!',
#  'for 2 months.',
#  'I wanted to purchase the extended warranty and they refused, because they knew it was trouble.',
#  'Do you ever think HP would do that? NEVER!',
#  'We upgraded the memory to four gigabytes in order to take advantage of the performace increase in speed.',
#  "It's not like I have used for half a year and then complained about it.",
#  'Still trying to learn how to use it.',
#  'The reality was, it heated up very quickly, and took way too long to do simple things, like opening my Documents folder.',
#  'I bought the netbook because it was smaller and lighter for me to carry around.',
#  'The Genius at the Apple store advised me that there was nothing about my use of the computer that caused this failure.',
#  "We'll save our money to replace it with a Mac again!",
#  'Thank you for your great product!',
#  'this company truely does make horrible products and doesnt seem to because they are certain things like this "never" happen...',
#  'I had always used PCs and been constantly frustrated by the crashing and the poorly designed operating systems that were never very intuitive.',
#  'Sorry Toshiba, but 1st impressions do count for something.',
#  'Then, within 5 months, the charger crapped out on me.',
#  'And if you have a iphone or ipod touch you can connect and download songs to it at high speed.',
#  'Overall this laptop is great.',
#  'I love the glass touchpad.',
#  u'\xa0 I continued to take the computer in AGAIN and they replaced the hard drive and mother board yet again.',
#  'I am using the external speaker- sound is good.',
#  'The Apple MC371LL/A 2.4Ghz 15.4-inch MacBook Pro Notebook is a horrible waste of money.',
#  'Ok, this is probably the best laptop series ever devised by Apple.',
#  'As of a couple weeks ago the middle portion of the laptop from top to bottom,,,about 4 inches across is hardly visible.',
#  'still testing the battery life as i thought it would be better, but am very happy with the upgrade.',
#  'Then HP sends it back to me with the hardware screwed up, not able to connect.',
#  "I just hope the reputation that Toshiba has is true and I won't have to worry about a crash.",
#  "Oh yeah, don't forget the expensive shipping to and from HP.",
#  'I would recommend anyone to buy from pcconnection express.',
#  'Good luck.',
#  'Everything is so easy to use, Mac software is just so much simpler than Microsoft software.',
#  u'\xa0 My favorite by far, although the most expensive, was my Sony.',
#  'And if you do a lot of writing, editing is a problem since there is no  forward delete  key.',
#  'Also I typed faster then then letters would show and it got to be realy annoying.',
#  'As an owner of a Toshiba Satalite laptop computer things you should know before you buy.',
#  'Its ease of use and the top service from Apple- be it their phone assistance or bellying up to the genius bar- cannot be beat.',
#  "It has a 10 hour battery life when you're doing web browsing and word editing, making it perfect for the classroom or office, and in terms of gaming and movie playing it'll have a battery life of just over 5 hours.",
#  'I shipped out on Saturday, July 17.',
#  "I bought it for really cheap also and it's AMAZING.",
#  'Acer has set me up with FREE recovery discs, when they are available since I asked.',
#  'I also purchased Office Max\'s "Max Assurance" with the "no lemon" clause.',
#  "If you find yourself in the market for a new laptop (and have the money) don't exclude looking at the MBPs.",
#  'I eventually did the migration from my iMac backup disc which uses USB.',
#  'Those things are very important - vital even!',
#  '-They say it will take "up to two weeks".',
#  "I didn't like one thing about it.",
#  'The battery life seems to be very good, and have had no issues with it.',
#  'Enabling the battery timer is useless.',
#  'Temperatures on the outside were alright but i did not track in Core Processing Unit temperatures.',
#  'Yeah, to you.',
#  'I got a mac as my HS graduation gift.',
#  'I have now had it for 1.5 months and love it.',
#  "It turned out it's not really a problem to have a Mac.",
#  'Page just disapeared after you got yahoo or downloaded something.',
#  'Images can be multi-selected and viewed swiftly or in slideshow mode.',
#  'Going to bring it to service today.',
#  'There is no need to purchase virus protection for Mac, which saves me a lot of time and money.',
#  'But we had paid for bluetooth, and there was none.',
#  'So, I paid a visit to LG notebook service center at Alexandra Road, hoping they can make the hinge tighter.',
#  'My daughter uses it for games, email, facebook, pictures and music.',
#  'Laptop is to be used like a Netbook.',
#  'It is always reliable, never bugged and responds well.',
#  'After about a week I finally got it back and was told that the motherboard had failed and so they installed a new motherboard.',
#  'Trying to balance all of my roles leaves very little time for me to do anything, so I want to manage my time I do have to be the most efficient.',
#  'It was slow, locked up, and also had hardware replaced after only 2 months!',
#  'they had to replace the motherboard in April',
#  'Yes, the computer was light weight, less expensive than the average laptop, and was pretty self explantory in use.',
#  'Also, if you need to talk to a representive at Microsoft, there is a charge, which I believe is robbery, since you are charged enormous amounts for a very badly designed system, which most people would have went with XP if they could.',
#  'There is a little indent to help open it - but good luck with that.',
#  'I love WIndows 7 which is a vast improvment over Vista.',
#  u'\xa0 Also, I have alot of trouble with it getting very hot, and not even sitting on anything to make it hot.',
#  'It Was a great deal after all.',
#  'This mac is great!',
#  'Keyboard is great, very quiet for all the typing that I do.',
#  'I grew up in a design family so it only made sense.',
#  'Gave phonenumber.',
#  'It would take up too much time to do reaearch for my papers and I would be up hours-just because the computer was too slow.',
#  'Oh my goodness-I am not a happy camper.',
#  "Dell's customer disservice is an insult to it's customers who pay good money for shoddy products.",
#  "I'd recommend this laptop to anyone!",
#  "Yet, HP won't do anything about the problem.",
#  "i'm returning mine",
#  'It had a cooling system malfunction after 10 minutes of general use, and would not move past this error.',
#  "I can render AVCHD movies with little effort, which was a problem for most pc's unless you had a quad core I7.",
#  "It's a bummer and one out of five is being kind.",
#  'This is what they told me: It heats up, and that is the reason we no longer call them laptops, and simply categorize them as portables.',
#  'After talking it over with the very knowledgeable sales associate, I chose the MacBook Pro over the white MacBook.',
#  "If you really want a bang-up system and don't need to run Windows applications, go with an Apple;",
#  "You won't have to spend gobs of money on some inefficient virus program that needs to be updated every month and that constantly drains your wallet.",
#  'This laptop is fast and you will literally learn all you can do with this dynamo by just watching the online tutorials.',
#  'One of them seems to have worked.',
#  'Which I still use and have hooked up to my TV.',
#  'The problem I had with this unit was unresolvable.',
#  'It weighed like seven pounds or something like that.',
#  '2 months later, the battery went.',
#  'You may need to special order a bag.',
#  "It's color is even cool.",
#  'and it has blue screen crashed on me twice.',
#  u'\xa0 Another two weeks later and it was back in my possession.',
#  'keys are all in weird places and is way too large for the way it is designed.',
#  'I\'ve owned every "Pro" model Apple laptop for the last 8 years, this is BY FAR the WORST one I\'ve ever had.',
#  'We purchase the Dell XPS several years ago for my home business.',
#  'Have purchased many products over the years from MacConnection and this transaction, like all the others, we smoothly with no problems.',
#  'I would recommend anyone to buy from pcconnection express.',
#  'Yes, a Mac is much more money than the average laptop out there, but there is no comparison in style, speed and just cool factor.',
#  'He gave me this PC about 3 years ago and up to this point im still sitting here using it.',
#  "I'm pleased.",
#  'The keyboard feels good and I type just fine on it.',
#  'With a healthy pessimism, I took the machine home and tried to find a flaw.',
#  'Shiny  This Laptop is the Best of the best!',
#  'I thought the white Mac computers looked dirty too quicly where you use the mousepad and where you place your hands when typing.',
#  "And not to mention after using it for a few months or so, the battery will slowly less and less hold a charge until you can't leave it unplugged for more than 5 minutes without the thing dying.",
#  "Don't waste their money, save it and but a mac.",
#  'Money and time well spent!',
#  u'\xa0 Gradually the freezing screen evolved into a screen that froze in weird shapes.',
#  "BEST BUY - 5 STARS + + + (sales, service, respect for old men who aren't familiar with the technology) DELL COMPUTERS - 3 stars DELL SUPPORT - owes a me a couple",
#  'Good laptop for the money.',
#  'I like the laptop overall.',
#  'I now travel with this laptop and my work PC.',
#  u'\xa0 I am however pleased that it is still hanging in there.',
#  'Both my husband and I have this model Toshiba.',
#  "no complaints with their desktop, and maybe because it just sits on your desktop, and you don't carry it around, which could jar the hard drive, or the motherboard.",
#  'Yes, they cost more, but they more than make up for it in speed, construction quality, and longevity.',
#  'Since I keyboard over 100 wpm, I look for a unit that has a comfortble keyboard (no keys sticking or lagging, strange configuration of "extra key", etc.',
#  ') I also tried the touch pad and compared it to other netbooks in the store.',
#  'It absolutely is more expensive than most PC laptops, but the ease of use, security, and minimal problems that have arisen make it well worth the pricetag.',
#  u'\xa0 It gets stuck all of the time you use it, and you have to keep tapping on it to get it to work.',
#  'lots of preloaded software.',
#  u'\xa0 Sony, Acer, Dell, Packard Bell and Toshiba.',
#  'and then, a guy came out to serve me instead.',
#  'Breaking within 1 year of purchase and speaking to 4+ people to report the damaged part will be returned late!',
#  'Have returned that laptop unused.',
#  u'\xa0 Will probably never buy a HP again.',
#  'I got tired of buying laptops and having them stop working after a year.',
#  'I should have been more observant.',
#  'I wish it had a webcam though, then it would be perfect!',
#  'My favorite part of this computer is that it has a vga port so I can connect it to a bigger screen.',
#  'Another thing I might add is the battery life is excellent.',
#  'One drawback, I wish the keys were backlit.',
#  'When the buyer returned it Wal Mart just boxed it, taped it shut  resold it as new.',
#  'What a great little laptop.',
#  'Acer was no help and Garmin could not determine the problem(after spending about 2 hours with me), so I returned it and purchased a Toshiba R700 that seems even nicer and I was able to load all of my software with no problem.',
#  'I wish the volume could be louder and the mouse didnt break after only a month.',
#  'I play a lot of casual games online, and the touchpad is very responsive.',
#  "Granted, it's still a very new laptop but in comparison to my previous laptops and desktops, my Mac boots up noticeably quicker.",
#  'It caught a virus that completely wiped out my hard drive in a matter of hours.',
#  'WOULD PAY MORE FOR IT IF I HAD TOO!',
#  "Couldn't keep a page up you were working on!",
#  "It is everything I'd hoped it would be from a look and feel standpoint, but somehow a bit more sturdy.",
#  'the only fact i dont like about apples is they generally use safari and i dont use safari but after i install Mozzilla firfox i love every single bit about it.',
#  'The Bluetooth was not there at all, and the fingerprint reader driver would be there, but the software would hang after installation was 1/2 way done.',
#  'Great battery, speed, display.',
#  'I would not recommend this product to anyone.',
#  'I like to use it at the race track to handiecap the horse races.',
#  "I was given a Mac as a birthday present and couldn't be happier with it 3 years later.",
#  'The delivery was fast, and I would not hesitate to purchase this laptop again.',
#  "I've been impressed with the battery life and the performance for such a small amount of memory.",
#  'do a quick search on the internet see if im the only one.',
#  "I'm extremely happy with my purchase as I now have the portable power I have been looking for.",
#  "It's applications are terrific, including the replacements for Microsoft office.",
#  'they improved nothing else such as Resolution, appearance, cooling system, graphics card, etc.',
#  'I got it back and my built-in webcam and built-in mic were shorting out anytime I touched the lid, (mind you this was my means of communication with my fiance who was deployed) but I suffered thru it and would constandly have to reset the computer to be able to use my cam and mic anytime they went out.',
#  'Is this partially due to the fact that it is running Windows Vista?',
#  'You might think, I am new in this game, but I am a gadget lover, and have had more than 2 dozens laptops in the past 15 years, and none gets this hot, that fast.',
#  'I was informed that I need to call some 0900 number first.',
#  'I really wanted a Mac over a pc because I used a Mac in high school.',
#  '1) Payed $2200 for a "premium" laptop',
#  'I BOUGHT THEM FOR MY COLLEGE AGE GRANDCHILDREN AND THESE MACS ARE TOTALLY RELIABLE AND SUPPORT THEIR CLASS WORK 100% OF THE TIME.',
#  u'\xa0 The board has a bad connector with the power supply and shortly after warrenty expires the power supply will start having issues.',
#  'Do not purchase this laptop.',
#  'My dad has one of the very first Toshibas ever made, yes its abit slow now but still works well and i hooked to my ethernet!',
#  'Mostly I love the drag and drop feature.',
#  'oh yeah, and if the fancy webcam breaks guess who you have to send it to to get it fixed?',
#  'She brought out 2 other identical netbooks and still insist that "It is like that one".',
#  'I ordered through MacMall, which saved me the sales tax I would have incurred buying locally.',
#  'Very fast and efficient!',
#  'Of course, I also have several great software packages that came for free including iWork, GarageBand, and iMovie.',
#  'Being virus-resistant is a huge plus.',
#  'The screen is very large and crystal clear with amazing colors and resolution.',
#  'After a little more than a year of owning my MacBook Pro, the monitor has completely died.',
#  'In my house, HP is a nasty word.',
#  'The brand of iTunes has just become ingrained in our lexicon now, but keep in mind that Apple started it all.',
#  'By the way teachers, they offer a discount which helps!',
#  'now he mows yards so he can earn the money for the wireless internet.',
#  'I still see the benefits of a PC when I do not know how to do something on my mac.',
#  'Size: I know 13 is small (especially for a desktop replacement) but with an external monitor, who cares.',
#  "Additional caveat: the base installation comes with some Toshiba-specific software that may or may not be to a user's liking.",
#  'It is held in place magnetically.',
#  u'\xa0 Taking it back to Best Buy I found that a tiny plastic piece inside had broken (manuf issue).',
#  'It has no camera but, I can always buy and install one easy.',
#  'The display is incredibly bright, much brighter than my PowerBook and very crisp.',
#  'We were PC users.',
#  'The AMD Turin processor seems to always perform so much better than Intel.',
#  u'\xa0 After that the said it was under warranty.',
#  'The start menu is not the easiest thing to navigate due to the stacking.',
#  'Only thing I would want to add to this is an internal bluray read/write drive.',
#  'This computer was awful, I would never recomend it to another person.',
#  "The service tech said he had tried to duplicate the damage and wasn't able to recreate it therefore it had to be their defect.",
#  'The tech store I purchased this from sent it back,,,,,eventually I got a new or repaired machine approximately 3 weeks later.',
#  'I loved it then, but unfortunately it was before the days of wireless internet.',
#  'Really like the textured surface which shows no fingerprints.',
#  'I WILL NEVER AGAIN buy another Acer, not will I buy Gateway, or eMachine as they are all from the same company.',
#  'The screen is bright and the keyboard is nice;',
#  'I look forward to years of use, it has held up well over the years and it fits my needs very well.',
#  'Im very happy with this computer!',
#  'But the machine is awesome and iLife is great and I love Snow Leopard X.',
#  'High price tag, however.',
#  'I thought learning the Mac OS would be hard, but it is easily picked up if you are familiar with a PC.',
#  'My kids have to take their PCs in once a year to have them "de-bugged".',
#  'I had static in the output, and I had to reduce the sound output quality to "FM" as opposed to the default "CD.',
#  u'It was a laugh\xa0 too!',
#  'Since I purchased my Toshiba netbook, I have been very pleased with it, I have a laptob and a desktop.',
#  'I bought my macbook a few months ago and it has been my baby ever since.',
#  'That is how it is able to function better than any other PC.',
#  'I custom ordered the machine from HP and could NOT understand the techie due to his accent.',
#  'It is easy to use and lightweight.',
#  'I went to Toshiba online help and found some suggestions to fix it.',
#  'It is a bit heavy.',
#  u'\xa0 after trying to get some help he disconnected on me.',
#  'They also have a longer service life than other computers (I have several friends who still use the older Apple PowerBooks).',
#  'If you check you will find the same notebook with the above missing ports and a dual core AMD or Intel processor.',
#  'This laptop is a great price and has a sleek look.',
#  'I especially like the keyboard which has chiclet type keys.',
#  'Small screen somewhat limiting but great for travel.',
#  'One of the primary reasons why I purchased an IPad was to store photographs so that I could show to my customers.',
#  'Runs Hot  I thought we were paying for quality in our decision to buy an Apple product.',
#  'For the not so good, I got the stock screen - which is VERY glossy.',
#  'The gray color was a good choice.',
#  'This was the second computer and brand bought that day.',
#  'Buy this.',
#  'VERY disappointing:',
#  'I love this product because it is Toshiba and its 15.6".',
#  'I would like to have volume buttons rather than the adjustment that is on the front.',
#  'This is my first computer purchase',
#  'People know what they are talking about and they have pride in the product that they are selling.',
#  'The processor a AMD Semprom at 2.1 ghz is a bummer it does not have the power for HD or heavy computing.',
#  'Would HIGHLY recommend this netbook though.',
#  'I have had several machines over the years, both for personal and business use.',
#  'I bought a protector for my key pad and it works great :)',
#  'The magnetic plug-in power charging power cord is great (I even put it to the test by accident)- excellent innovation!',
#  'Well i got this computer from Best Buy and I have had nothing but problems I bought the computer with a virus.....',
#  'It seems they could have updated XP and done without creating Vista.',
#  u'\xa0 It is easy to use, fast and has great graphics for the money.',
#  'I decided I wanted a laptop so I went into the BBY store.',
#  'I like how the Mac OS is so simple and easy to use.',
#  "While Apple's saving grace is the fact that they at least stand behind their products, and their support is great, it would be nice if their products were more reliable to justify the premium.",
#  "In the three years I've had my MacBook Pro, I have never had a virus on my computer, and I do a lot of work on the internet.",
#  'I was ready to take it back for a refund, but the Geek Squad camed through and pointed me in the right direction to get it fixed.',
#  'I have had laptops in the past and I thought why not give these small netbooks a try.',
#  "It can't get any better.",
#  "All the problems I have had with PC's are solved with a Mac: the issue of overheating-my Dell was always overheating and not working properly or simply shutting off, and the issue of viruses and contaminants-my HP completely quit working within2 years of purchasing it, with no inexpensive way of fixing it.",
#  'only good thing is the graphics quality.',
#  'The other lock-up problems are from a myriad of causes, the most common being a corrupted version of Appleworks which can render the browser useless.',
#  'In short I would never buy a Compaq again.',
#  'I love the 15" MacBook Pro.',
#  'breaks easily.',
#  'The paint wears off easily due to the keyboard being farther back than usual.',
#  "That's right, no power, absolutely NOTHING.",
#  'I had purchased it from a major electronics store and took it to their service department to find out what the problem was.',
#  "The store honored their warrenty and made the comment that they don't even recommend the HP brand because of the problems with their warrentys.",
#  'But I was wrong.',
#  'NO good.',
#  'I always use a backup hard disk to store important files at all times.',
#  "They sent out the box right away for me to send in my computer, they paid postage and whatnot, but when I got my computer back it still wasn't running right, and now my CD drive wasn't reading anything!",
#  "I bought this laptop Was the worst Laptop I've ever bought.",
#  'But the screen size is not that bad for email and web browsing.',
#  'Once I removed all the software the laptop loads in 15-20 seconds.',
#  "On my PowerBook G4 I would never use the trackpad I would use an external mouse because I didn't like the trackpad.",
#  "This computer doesn't do that well with certain games it can't play some and it becomes too hot while playing games.",
#  'Obviously one of the most important features of any computer is the "human interface.',
#  'Yeah, of course smarty pants "fix it now")Software - Compared to the early 2011 edition I did see inbuilt applications crashing and it prompted me to send the report to Apple (which I promptly did).',
#  'The body is a bit cheaply made so it will be interesting to see how long it holds up.',
#  'The i5 blows my desktop out of the water when it comes to rendering videos.',
#  "With a mac you don't have to worry about antivirus software or firewall, it's so wonderful.",
#  'For the use it was purchased for it is a good Laptop.',
#  'Am very glad I bought it, great netbook, low price.',
#  'Obviously, this Macbook is P-E-R-F-E-C-T for me because it does exactly what I need in an easy-to-function way.',
#  'Worth the investment and truly a fine piece of equipment.',
#  'The Apple team also assists you very nicely when choosing which computer is right for you :)',
#  'Summary: Dont buy HP.',
#  "I think part of the problem with this computer is Vista, yet I know Vista isn't the entire issue because my latest purchase was my Acer and it also has Vista (I should have waited the few months to get the next operating system).",
#  'The video chat is the only thing that is iffy about it but im sure once they unpdate the next version on the macbook book the quality of it will be better.',
#  "You'll need to upgrade and pay a little more for them.",
#  'it is hard to fix and makes it a hassle to own one.',
#  'That whole experience was just ridiculous we sent it in and after they told us that we had to pay $175 to fix it we were like we will just by a portable mouse which would be way cheaper but they refused to send the laptop back until we paid the $175 and it was fixed.',
#  'Macs are designed for the "frontal lobe challenged" people out there.',
#  'Fan vents to the side, so no cooling pad needed, great feature!',
#  "i use my mac all the time, i love the software, the way it takes a short time to load things, how easy it is to use and most of all how you don't have to worry about viruses.",
#  'Wasted me at least 8 hours of installation time.',
#  'It has far exceeded my expectations for power, storage, and abilitiy.',
#  'A great feature is the spotlight search: one can search for documents by simply typing a keyword, rather than parsing tens of file folders for a document.',
#  "My wireless system would not recognize Windows 7 and I couldn't get online to find out why.",
#  'I am enjoying it and the quality it provides is great!',
#  'It is the worst laptop ever',
#  'Suffice it to say, my MacBook Pro keeps me going with its long battery life and blazing speed.',
#  "I'm not going to lie, I've never really liked the Acer brand in general.",
#  'The OS is also very user friendly, even for those that switch from a PC, with a little practice you can take full advantage of this OS!',
#  'iTunes is a handy music-management program, and it is essential for anyone with an iPod.',
#  '-I give up on my data, I just want a computer reasonably fast...',
#  'Would buy 100 more of these if I could.',
#  u'\xa0 while it was barely a bargin in the begining, i would never purchase another dell and would not recomend the dell brand to others.',
#  'it was shooting sparks!',
#  'Great product.',
#  'Mac is not made for gaming.',
#  "Well I spilled something on it and they replaced it with this model, which gets hot and the battery doesn't make it through 1 DVD.",
#  "I've had to call Apple support to set up my new printer and have had wonderful experiences with helpful, english speaking (from Vancouver) techs that walked me through the processes to help me.",
#  'But Sony said we could send it back and be charged for adding the bluetooth an additional seventy something dollars.',
#  u'\xa0 By this time I was regretting ever SEEING this machine on the shelf!',
#  "Toshiba is a great brand, even though I haven't had it for a long time, I am very happy with it!",
#  'I need graphic power to run my Adobe Creative apps efficiently.',
#  'the programs are esay to use and are quick to process this computer works like a charm.',
#  'The materials that came with the computer did not include the right # anywhere.',
#  'So when you do call to complain about the hunk of metal you get the joy of speaking with a bunch of people you cant understand.',
#  'That day!',
#  '" For one, I noticed that from turning on my mac to logging on only took about 25 seconds.',
#  'It does not even have the software to play a dvd now.',
#  'My brother is a computer wiz and would laugh at me because he used an Apple.',
#  'Tech support tells me the latter problem is a power supply problem and have offered to fix it if it happens again.',
#  "Since I never really got to use this, I can't comment on anything except what went wrong after trying 2 of them.",
#  'Buyers beware.',
#  'HOW DOES THE POWER SUPPLY NOT WORK!!!',
#  'Sells for the same as a netbook without sacrificing size.',
#  u"\xa0 I'll rather be out of date then spend more money on toshiba.",
#  u'\xa0 upon giving them the serial number the first thing I was told, was that it was out of warranty and I could pay to have it repaired.',
#  'Windows XP SP2 caused many problems on the computer, so I had to remove it.',
#  'Love it.',
#  'I reloaded with Windows 7 Ultimate, and the Bluetooth and Fingerprint reader (software) would not load.',
#  'None of the techs at HP knew what they were doing.',
#  'Oh, it is such a great piece of equipment.',
#  'this is my second one and the same problem, bad video card  unreliable overall, this will be my second time returning this laptop back to best buy.',
#  'I use that alot on my desktop, so I am adjusting to not having it.',
#  "With awesome graphics and assuring security, it's perfect!",
#  'Laptop was in new condition and operational, but for the audio problem when 1st sent for repair.',
#  "I was disappointed when I realized that the keyboard doesn't light up on this model.",
#  'This machine was a horrible experience.',
#  'It runs perfectly.',
#  'Very dissappointed becase I have had toshibas for years, and never a issue.',
#  'If you have any creativity in you do yourself a favor and get a mac!',
#  'The laptop was very easy to set up.',
#  'Congratulations Asus for creating one big piece of dump which is my laptop.',
#  u'\xa0 Sometimes the screen even goes black on this computer.',
#  'I would definitely recommend checking out this laptop if you are in the market for one.',
#  'I recommend for word processing and internet users.',
#  "Since I've had this computer I've only used the trackpad because it is so nice and smooth.",
#  u'\xa0 When the computer has been on for several minutes, it will occasionaly just go off by itself.',
#  "A longer battery life would have been great - but it meets it's spec quite easily.",
#  "Who couldn't love a DVD burner, 80-gigabyte HD, and fairly new graphics chip? As I soon discovered, though, there is a reason for which similarly-configured Sony and Toshiba machines cost more: they use higher-quality components that are faster, better-configured, and end up lasting a lot longer.",
#  'falls into the case.',
#  'This is something i would deffinately reccomend to someone.',
#  'Its fast and another thing I like is that it has three USB ports.',
#  'Mac computers automatically "defrag" each time you start your computer.',
#  'That is my only complaint!',
#  'The salesman talked us into this computer away from another we were looking at and we have had nothing but problems with software problems and just not happy with it.',
#  'That system is fixed.',
#  'The computer itself was fast, ran smoothly, and had no problems.',
#  'One of the smartest thing I did was take my time to compare laptops before making my purchase.',
#  'Like the price and operation.',
#  'The brand is tarnished in my heart.',
#  "This is likely due to poor grounding and isolation between the components, and I'm hoping that it can be fixed with a ground loop isolator, but I still expected better product quality for this price range.",
#  'Honestly, this is absolutely wonderful.',
#  "I 'have had it for about a 1 1/2 and yes I have had an issue with it one month out of warranty.",
#  'I really wish I had done this years ago.',
#  'Well, maybe I was just very unlucky.',
#  "For example, when my husband turns the light out while I'm on the computer.",
#  'Once open, the leading edge is razor sharp.',
#  'Loaded with bloatware.',
#  'If you buy, pray you dont have major prolems.',
#  "Don't get me wrong, I am no Microsoft hater, I've just managed to turn into a much bigger Apple fan because of this machine.",
#  'HP refused to give me a new one and Wal Mart refused to take it back.',
#  'Within 3 weeks the same issues started happening AGAIN.',
#  "Maximum sound isn't nearly as loud as it should be.",
#  "Well, they don't care a bunch.",
#  'I loaded windows 7 via Bootcamp and it works flawlessly!',
#  'I have never had to shut down the computer unexpectedly and the computer has never froze on me.',
#  'Great Laptop for the price, works well with action pack games.',
#  'Although the price is higher then Dell laptops, the Macbooks are worth the dough.',
#  'Recommended to people as their first laptop.',
#  'I would recomend this acer to parents and grandparents it can really help them in school.',
#  'I would not recommend this to anyone wanting a notebook expecting the performance of a Desktop it does not meet the expectations.',
#  'The Macbook arrived in a nice twin packing and sealed in the box, all the functions works great.',
#  'So what if the laptops/mobile phones look chic and cool? The after sales support is terrible.',
#  'they have not sent a new one nor called.',
#  'I would easly reccomend this laptop to a friend.',
#  'I hate the display screen and I have done everything I could do the change it.',
#  'I spent alot of money on this product and its been a nightmare.',
#  'I also like the acer arcade but these were reallythe only two things I liked about this laptop.',
#  'Have not yet needed any customer support with this yet so to me that is a great thing, which is leaps and bounds ahead of PC in my opinion.',
#  'Thinking about returning it',
#  "I gave it to my daughter because I just hated the screen, hated that it had no cd drive to at least play cd's when I wanted to listen to music and do schoolwork.",
#  'It runs very quiet too which is a plus.',
#  'but it  has a major design flaw.',
#  u'\xa0 I took the laptop home and not even a month later, I began to have problems with it.',
#  'It was heavy,bulky, and hard to carry because of the size.',
#  'That was my first Apple product and since then I have been incredibly happy with every product of theirs I have bought.',
#  'i tried turning it done but it did nothing.',
#  'It is super fast, and always loads.',
#  'The games included are very good games.',
#  'this computer will last you at least 7 years, thats an amazing life spanned an electronic.',
#  "I bought mine from Apple Store the day it was released as Amazon didn't have it yet.",
#  'I had something else go wrong and they said it had to be in good working order to be able to buy the warranty.',
#  'the whole experiece is horrible so save up and buy a better laptop.',
#  'I just bought this laptop 3 days ago.',
#  'I am very pleased with my purchase!',
#  'Sometimes you really have to tap the pad to get it to worki',
#  "It's super fast and a great value for the price!",
#  "Three, the mac book has advantages over pcs' with linux based os there is very 'few problems with system performance when it comes to a mac.",
#  'A mac is very easy to use and it simply makes sense.',
#  "Of course, eMachines cannot be made entirely to blame for this computer's woes;",
#  'however, I may have inadvertently thrown out one of the batteries with the shipping carton.',
#  'Love it so far.',
#  'It is so much easier to use',
#  'There is no need to open a program first and the cliick open or import.',
#  'In short, you could say your mac could become your best friend (no intention of replacing Rover your dog).',
#  'It was a bad experience but i played down its importance.',
#  'Meets my needs perfectly and is light enough for this senior to carry without affecting my arthritis.',
#  "It is so nice not to worry about that and the extra expense that comes along with the necessary virus protection on PC's.",
#  'The Notebook PC,Toshiba Qosmio is the best gift my father could have ever gotten me.',
#  'Three weeks after I bought the netbook, the screen quit working.',
#  'The processor screams, and because of the unique way that Apple OSX 16 functions, most of the graphics are routed through the hardware rather than the software.',
#  'I am currently out of town and called to inform them the broken part would be returned when I got back in town.',
#  'Returned laptop for a 4th repair and it came back but now would lock up and randomly reboot frequently making the laptop unusable.',
#  'I wanted something that had a new Intel Core processors and HDMI port so that we could hook it up directly to our TV.',
#  'The Apple will run Internet Explorer, but at an amazingly slow rate.',
#  "With today's company fighting over marketshare, its a shame that ASUS can get away with the inept staff answering thephone.",
#  "Other than that I don't have one complaint in the world!",
#  u'\xa0 The computer is so slow, even after paying staples the extra money to speed it up.',
#  'I feel that enough people have Macs these days and that companies need to start making things more compatable than they used to be.',
#  'The price premium is a little much, but when you start looking at the features it is worth the added cash.',
#  '*5 weeks after giving the computer for repair*-Apple offers to send replacement after they receive the old computer.',
#  "I can't say enough of how satisfied I am with their product and help aftermarket.",
#  'My computer was one of the best in the school compared to my fellow classmates.',
#  'I bought for my son in the 2nd grade.',
#  'This has happened three times so far.',
#  u"\xa0  I'm a professional consultant, and a client needed work on her machine.",
#  "compresses itself and you can't use it.",
#  'Microsoft word was not on it andI had to buy it seperately.',
#  'it has 3 usb ports, 1 sd memory card reader and an sd memory car expansion.',
#  'Who knows what will happen later on when they dismantle the whole damn thing?  So, I said I wanted a new set.',
#  'I connect a LaCie 2Big external drive via the firewire 800 interface, which is useful for Time Machine.',
#  'If you already own a 2009, 2010, or early 2011 model, you should wait until the next update.',
#  'My Toshiba did not have sound on everything, just certain things.',
#  'I am overall very pleased with my toshiba satellite, I like the extra features, I love the windows 7 home premium.',
#  'So, I must say I am not a happy camper.',
#  '-Called MacHouse Amsterdam to ask for a temporary replacement, no answer.',
#  'The Aspire wont even boot past the Acer screen with a Droid (I have tried both Motorola and HTC) plugged into the USB port.',
#  'I bought it during the recent Comex IT show.',
#  'The battery life was shorter than expected.',
#  'It fires up in the morning in less than 30 seconds and I have never had any issues with it freezing.',
#  'It doesnt overheat or make any loud noises.',
#  'Look up recipes and keep it on the kitchen counter while I cook.',
#  'The keyboard is top notch.',
#  'Do you think the shop will give me a new set?? It will NOT!',
#  'I have had nothing but problems since the day I took it out of the box!',
#  'My Macbook was worth (after 3 years of use!) $375.',
#  "It drives me crazy when I want to download a game or something of that nature and I can't play it because its not compatable with the software.",
#  'The online tutorial videos make it super easy to learn if you have always used a PC.',
#  'Bought this gateway M-50 or 150 early 2007.',
#  'The image is great, and the soud is excelent.',
#  "With a MAC computer I have more free time as I don't have to wait for windows to boot up or shut down and all the viruses associated with windows.",
#  'It was very easy to just pick up and use-- It did not take long to get used to the Mac OS.',
#  'This netbook is a perfect supplementary computer to another laptop or desktop (my wife and I have another laptop), or if you are a user who uses the computer for simple tasks.',
#  'With all the goodies inside this machine, it is a value.',
#  'I took it back for a full refund.',
#  'It is well worth the money it cost, Very good investment.',
#  'Upgrading from Windows 7 Starter, thru Windows 7 Home Premium, to Windows 7 Professional was a snap;',
#  'This computer had exactly the specifications I needed.',
#  'Overall, still a very nice machine.',
#  'Where you click and hold and drag it picture, link, etc to where you want it.',
#  'My kids (and dogs) destroyed two power cords by pulling on them.',
# ...
#  'In my opinion it was not as user friendly as I expected either.',
#  'The technical service for dell is so 3rd world it might as well not even bother.',
#  "The graphics were awful and the warranty isn't even worth the cheap payment on the computer.",
#  'and if u did.',
#  "I've had the MacBook Pro 15 for about three weeks, and it really is a great computer.",
#  "They gave me a hard time yet again, but their was a malfunction in the battery itself, it didn't die.",
#  'It was definelty a smart move.',
#  "I'm excited to learn more about what this powerful machine has to offer and encourage others to do the same.",
#  'Apparently they are defective since they are not securely attached.',
#  'but other then that I would give this product a 4 in hafe stars.',
#  'Sure hope Best Buy will replace it asap.',
#  'I babyed the heck out of it and i still do.',
#  'Handles all my basic media needs easily.',
#  'Just what the doctor ordered.',
#  "If you don't feel comfortable doing it yourself, just buy the case and be happy, plus it looks nice, I bought the white one from Best Buy.",
#  'The reaction of Toshiba is there is nothing you can do about it so just sit back and except the fact that you are powerless and it is mind over matter.',
#  'you can find many laptops with the same performance and even better with lower price, but you cannot find the look, easy, applications, and the experience in mac.',
#  'Excellent speed for processing data.',
#  "All in all, I'm incredibly dissatisfied with this laptop, and with HP as a whole.",
#  'I am not happy at all with the product I purchased.',
#  'When you call tech support you were routed to someone who was in another country and did not know what they were doing.',
#  'It has come into good use for my finances, scheduling, my parents business expenses, and it is definitely amazing for gaming.',
#  'I was taught to use Photoshop and was amazed.',
#  "It's A MAC!!",
#  'It was weird.',
#  'I can hardly wait to see whats around the next corner.',
#  'the apple pro notebook will not let you down.',
#  '4gb of ram...',
#  'I did a review on it, its awesome.',
#  u'\xa0 Before we got this laptop, had\xa0a\xa0compaq pasaro\xa0for 5 years with no problems.',
#  'I tried out another Mac for a few months before buying this one and it is a great machine.',
#  'Somehow the system clock got messed up after reboot.',
#  'the only problem is that i had to add 1 gb RAM, the computer was kinda slow.',
#  'With the macbook pro it comes with freesecuritysoftware to protect it from viruses and other intrusive things from downloads and internet surfing or emails.',
#  'The computer could have been shipped by Priority Mail through the USPS for the same cost and arrived by Noon on Tue.',
#  'I visited the Apple Store and was impressed with the 17-inch MacBook Pro.',
#  "The driver updates don't fix the issue, very frustrating.",
#  'I will never go back to Windows!',
#  'Do your research on this issue.',
#  'Looking to take my video and photo editing to the next level, I decided to purchase the MBP 15in Intel Core i5 after reading consumer reviews as well as professional reviews of this laptop.',
#  'It doesnt work worth a damn.',
#  'HP Pavilion DV9000 Notebook PC      When I first got this computer, it really rocked.',
#  'It works really well.',
#  "It has happened again and I'm being told that it's $175.",
#  'Bigger HD, better graphics card, and a bid HD.',
#  'Lord HAVE MERCY!',
#  'The built in camera is very useful when chatting with other techs in remote buildings on our campus.',
#  'No big deal.',
#  'Mine came at $1,700 w/o a DVD burner (!).',
#  "The DVD burner broke after burning 3 DVD'd during that time!",
#  "It works fine with our wireless and they've had not problems.",
#  'But you must get the 15 inch.',
#  'i will be returning it and switching brands when i get to best buy.',
#  'Product support very poor as each phone call costs me long distan',
#  'Overall the computer is very easy to use, the screen is perfect, great computer, my daughter loves.',
#  u'\xa0 The casing of the power cord fried and shocked my husband when he pulled it out of the socket.',
#  'It does not keep internet signals no matter where you bring it.',
#  'apple is one of the best computer companies in the country.',
#  'PLEASE MAKE THESE!',
#  'Frustrated I hung up and tried to call back 3 days later to be told that it takes 2-3 days for turnaround time.',
#  'After the first few months, the computer started crashing about every week.',
#  'My son and his family have a hard time financially because he is self-employed so the family had no computer of any kind, and kyle the oldest child is 12 and really need something to help him in school.',
#  "It's a great product for a great price!",
#  'Again, the same problem, the right speaker did not work.',
#  'But see the macbook pro is different because it may have a huge price tag but it comes with the full software that you would actually need and most of it has free future updates.',
#  'Before i bought my new i5, I did my research for about 2 weeks and determined to move for HP to Apple for reliability, dependable, and long lasting operations.',
#  'Dell wanted to charge us for everything everytime I called them with a problem.',
#  'THIS HAS BEEN NOTHING BUT A HEADACHE SINCE WE PURCHASED IT.',
#  u'i have\xa0had my dell latitude for almost three years.',
#  'May be better for the occasional web surfer.',
#  'and the multiple page viewer ( allows you to press one button to see every separate page currently opened at the same time in one screen) are great for those who are working non stop or just shopping online.',
#  'This was the 3rd day and part still had not been shipped.',
#  'Obviously we both got new Macs.',
#  'My Iphone synced right up just like a person would expect, unlike the PCs in our lives.',
#  'That being said after 2 weeks of owning every time I start it up now it gives me a black screen for 5-8 seconds stating pxe-e61 media test error check cable.',
#  "It's fun to take to a bookstore, sit in the coffee shop area, sign in to WiFi and look up book reviews of books I might buy.",
#  'Not super fancy, but not super expensive either.',
#  'Keyboard good sized and wasy to use.',
#  'HP said it was out of warranty.',
#  '-Stay away from Apple, or hope you laptop does not break down.',
#  "It's a great prodcut to handle basic computing needs.",
#  'I never had this kind of quality issue with Dell (not to say Dell is that great), not with a brand new laptop.',
#  'wonderful features.',
#  'the laptop was really good and it goes really fast just the way i thought it would of run.',
#  'I had to call HP and ask for a recovery disk because the computer does not come with one and completely redo it all.',
#  'Im glad that it has such great features in it.',
#  "it's just a great toy to have around.",
#  'I like those programs better than Office and you can save your files to be completely compatible with the Office programs as well.',
#  'Great wifi too.',
#  'WHEN TYPING, LETTERS AND SPACES ARE FREQUENTLY OMITTED REQUIRING THE USER TO REDO MANY WORDS AND SENTENCES.',
#  u'\xa0 Only a few days after I received the computer back, the screen froze again.',
#  'It is not ideal for children because of the temp.',
#  'sounds like a typewriter, but if you can get past that, this is a great laptop for a little money!',
#  u'\xa0 When this happened I would have to completely power off my computer and restart it.',
#  'Although i do believe that Windows operating system may be to fault for some of the problems.',
#  'Great OS, fabulous improvements to the existing line bumping up the processor speed and adding the thunderbolt port.',
#  'I or my dad paid over twenty four hundred dollars for everything.',
#  u'\xa0 The lcd screen stopped working on mine after 10 months.',
#  'That includes transferring my music and movies.',
#  'Images are crisp and clean.',
#  'Took that one home, same thing.',
#  "I'm going back to PC.",
#  'Great, quick laptop for the money.',
#  'although its windows vista compared to windows xp sucks.',
#  u'\xa0 We have had numerous problems with Vista, such as Adobe Flash player just quits and has to be uninstalled and then reinsalled, Internet Explore just quits and you lose whatever you were working on, also, the same Windows update has appeared on this computer since we got it and has been updated probably 400 times, the same update.',
#  'The Dell mini was the first Dell product that I had ever purchased.',
#  'with the switch being at the top you need to memorize the key combination rather than just flicking a switch.',
#  'My Mac has gone from being a trusted friend to an adversary.',
#  'One more tip, please purchase this model and get a 4GB stick of RAM to save you $10',
#  'By week two, my laptop had overheated and was completely dead even though I did not use it too much.',
#  'And it is impossible to get them back in.',
#  'My last laptop gave me a constant battle even though it was also completely new.',
#  'I have been a mac user since the mid 90s.',
#  'It has bein into the shop to get a new hardrive 2 times and to fix the touch control buttons on the keyboard!',
#  u'\xa0 After the bad experience with this computer went back to compaq.',
#  'Finally after months of research the discovered that they mailed it to a Walmart and there probably would be no way to find the box.',
#  "It doesn't heat up like my old laptop.",
#  'I always have used a tower home PC and jumped to the laptop and have been very satisfied with its performance.',
#  "It's solid.",
#  'Before I got my macbook, I owned a Dell laptop.',
#  'This laptop is the most amazing little peice of machinery I have owned outside of the Iphone.',
#  'The computer runs very fast with no problems and the iLife software that comes with it (iPhoto, iMovie, iWeb, iTunes, GarageBand) is all very helpful as well.',
#  'At first it worked well for a month or so then the system board failed and I send it in to toshiba some complaints and three weeks later I then receive my laptop back only to discover that it still has the same problem so now I have to send it back again to get it fixed again.',
#  u'\xa0 Until I bought the Dell, I thought you just looked for what you wanted (size, software, options, hardware) and purchase the best deal you could find.',
#  "I don't know how I could ever live without my Qousmio.",
#  'It has plenty of memory, lots of hard drive, and great graphics.',
#  "It didn't take me long to get switched over to the Mac computer programs and navigation - it's been just fine and like the way this laptop functions much better.",
#  u'\xa0 It lasted for many years of travel, kids and abuse and if I fired it up today, it would work.',
#  'been a PC user for many, many years.',
#  'I have never had any issues or problems with my MacBook Pro so far, and it is still as fast as it was when I first bought it.',
#  'It freezes, and it always shows that there is an error, so I have to restart it a few times every time I use it.',
#  "However, my girlfriend realized that the netbook's hinge is a bit loose (when you open or close the LCD).",
#  'My problem was with DELL Customer Service.',
#  'There are so many things wrong with this product, it just makes me want to set my self on fire!',
#  u'It is not even a year old yet, so I would\xa0definitely not recommend it to anyone.',
#  'Amazing machine.',
#  "I don't do any high tech stuff on it, just write papers, check mail, and sometimes play games, so I can't reccomend it if you are in the computer field.",
#  "Newegg's RMA service was great as always, I contacted them late Friday night, and they issued me an RMA number and a PrePaid UPS shipping label the very next morning on Saturday.",
#  "I'm very impressed.",
#  'Dell sucks',
#  'Design: very durable.',
#  'It is easy to go from one keyboard to another.',
#  'I spoke to 4 different people and was told they needed to transfer me to a 5th person!',
#  'The Mac Book Pro performs flawlessly.',
#  'Has a 5-6 hour battery life.',
#  "My ONLY issues are: 1) the screen/video resolution won't increase to a higher resolution then 1024 x 60",
#  'I run Dreamweaver, Final Cut Pro 7, Photoshop, Safari, Firefox, MSN Messenger and a few other applications constantly at the same time.',
#  'I have owned many computers and laptops.',
#  'I recently purchased the mini and absolutely love it!',
#  'Does a great job with video shot on a Canon 5D MKII.',
#  u'\xa0 I was told by many  that it was a great computer, but we got one of these, and it worked  great for one year, and as soon as the warrenty was up, then it got  really bad.',
#  'Ive had to call tech support many times.',
#  'The Apple applications (ex.iPhoto) are fun, easy, and really cool to use (unlike the competition)!',
#  'Yes, I have it on the highest available setting.',
#  'Not to mention it has shit gigs.',
#  'Hieroglyphics are quite common.',
#  'This worked just fine.',
#  'I paid for extra memory and the 17-inch screen, as well as the top of the line DVD and CD burners.',
#  'Its pretty fast and does not have hiccups while I am using it for web browsing, uploading photos, watching movies (720p) on occasion and creating presentations.',
#  'I was so happy with my new Mac.',
#  "Quality Display  I love HP,, it's the only computer/printer we will buy.",
#  'Despite the inconvenient weight, I opted for the 12 cell battery.',
#  'My MacBook is faster than any comparable PC.',
#  'The case is carved out of a single block of aluminum.',
#  "I'm very happy with this machine!",
#  'I do not recommend this company or their products!!!!',
#  'I like this machine because its very lightweight...',
#  u'\xa0    First it burned or fused the power adapter plug.',
#  'the features are great, the only thing it needs is better speakers.',
#  'It was still working, but there was nothing on the screen.',
#  'I bought this laptop and found its TAB is not functioning.',
#  u'\xa0 Toshiba is aware of the issue but unless the extended warrenty is bought Toshiba will do nothing about it.',
#  'HP said I had done the damage.',
#  '-Called headquarters again, they report that TFT panel is broken, should be fixed by the end of the week (week 3).',
#  'Navigation through the computer is far superior compared to Windows operating systems, as well.',
#  'I would recommend this product.',
#  'If I had to buy another computer, I would most definetly buy an acer one computer.',
#  'The screen is framed by half- to a full-inch margin that is obviously unnecessary, reduces the screen size and increases the bulk.',
#  'Though the picture, video, and music software is nowhere close to professional grade software Im used to (CS5) but does the job for beginner and even intermediate media designers.',
#  'I previously owned an HP desktop and a Dell laptop.',
#  'Everything else just install and go.',
#  u'\xa0 This thing is a lemon.',
#  'My laptop is almost 2yrs old and I have never had any problems with it.',
#  'All the customers that come in hate Dell.',
#  'We now own two of these, identical.',
#  "I've already recommended this laptop to a friend who eye'd the computer when I took it out of my bag.",
#  'I enjoy very much my new Toshiba, purchased specifially for attending online schooling.',
#  "Once you go Mac, you can't go back!",
#  'I brought this laptop last friday, and originally it worked fantastic.',
#  'The much lauded combined touch pad and clicker is a nightmare.',
#  'The Unibody construction is solid, sleek and beautiful.',
#  "They're easy, fun, powerful and will last a long time.",
#  'I WANT MY L505-s5988 BACK!',
#  'I let my friend borrow it, and she knows nothing about computers, and she used it with ease.',
#  'This MacBook is an outstanding product with great value.',
#  'If that is the case for you, I would suggest a pull-behind solution when looking at cases.',
#  'I had to re-install Windows within two weeks of the purchase and soon discovered cracks in the screen hinges.',
#  'A SECOND PROBLEM INVOLVES THE BATTERY WHICH IS ADVERTISED AS HAVING A STORAGE LIFE OF 11 HOURS BUT WHEN FULLY CHARGED SHOWS ONLY 7 HOURS OF SERVICE.',
#  'and plenty of storage with 250 gb(though I will upgrade this and the ram..)',
#  ...]

# %%
contractions = {
"ain't": "am not / are not",
"aren't": "are not / am not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he had / he would",
"he'd've": "he would have",
"he'll": "he shall / he will",
"he'll've": "he shall have / he will have",
"he's": "he has / he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how has / how is",
"i'd": "I had / I would",
"i'd've": "I would have",
"i'll": "I shall / I will",
"i'll've": "I shall have / I will have",
"i'm": "I am",
"i've": "I have",
"isn't": "is not",
"it'd": "it had / it would",
"it'd've": "it would have",
"it'll": "it shall / it will",
"it'll've": "it shall have / it will have",
"it's": "it has / it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she had / she would",
"she'd've": "she would have",
"she'll": "she shall / she will",
"she'll've": "she shall have / she will have",
"she's": "she has / she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as / so is",
"that'd": "that would / that had",
"that'd've": "that would have",
"that's": "that has / that is",
"there'd": "there had / there would",
"there'd've": "there would have",
"there's": "there has / there is",
"they'd": "they had / they would",
"they'd've": "they would have",
"they'll": "they shall / they will",
"they'll've": "they shall have / they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we had / we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what shall / what will",
"what'll've": "what shall have / what will have",
"what're": "what are",
"what's": "what has / what is",
"what've": "what have",
"when's": "when has / when is",
"when've": "when have",
"where'd": "where did",
"where's": "where has / where is",
"where've": "where have",
"who'll": "who shall / who will",
"who'll've": "who shall have / who will have",
"who's": "who has / who is",
"who've": "who have",
"why's": "why has / why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you had / you would",
"you'd've": "you would have",
"you'll": "you shall / you will",
"you'll've": "you shall have / you will have",
"you're": "you are",
"you've": "you have",
"here's":"here is"
}

# %%
#text="What's the best way to ensure this?"
a=[]
for i in sentences_list:
    for word in i.split():
        if word.lower() in contractions:
            i = i.replace(word,contractions[word.lower()])
            #print(i)
    a.append(i)
for i in a:
    print(i)
new_list=a
# Out:
# I charge it at night and skip taking the cord with me because of the good battery life.
# I bought a HP Pavilion DV4-1222nr laptop and have had so many problems with the computer.
# The tech guy then said the service center does not do 1-to-1 exchange and I have to direct my concern to the "sales" team, which is the retail shop which I bought my netbook from.
# I investigated netbooks and saw the Toshiba NB305-N410BL.
# The other day I had a presentation to do for a seminar at a large conference in town- lots of people, little time to prep and have to set up a computer to a projector, etc.
# it is of high quality, has a killer GUI, is extremely stable, is highly expandable, is bundled with lots of very good applications, is easy to use, and is absolutely gorgeous.
# Easy to start up and does not overheat as much as other laptops.
# Sad very SAD.
# I even got my teenage son one, because of the features that it offers, like, iChat, Photobooth, garage band and more!
# Needless to say a PC that cannot support a cell phone is less than useless!
# Great laptop that offers many great features!
# they have done absolutely nothing to fix the computer problem.
#  One night I turned the freaking thing off after using it, the next day I turn it on, no GUI, screen all dark, power light steady, hard drive light steady and not flashing as it usually does.
# Still pretty pricey, but I have been putting off money for a while as a little Macbook Fund, and finally got to use it.
# My only disappointment with the 13" model is that they are the only ones in the MacBook Pro line up without an i5 or i7 processor and dual graphics cards, however the trade-off is that you achieve a longer battery life (of about 2 more hours).
# I took it back for an Asus and same thing- blue screen which required me to remove the battery to reset.
# In the shop, these MacBooks are encased in a soft rubber enclosure - so you will never know about the razor edge until you buy it, get it home, break the seal and use it (very clever con).
# However, the multi-touch gestures and large tracking area make having an external mouse unnecessary (unless you are gaming).
# Plus it is small and reasonably light so I can take it with me to and from work.
# I HATE this one.
# They were totally unconcerned that the computer was not correctly repaired in the first place.
# Toshiba does not send any one out unless you have paid extra to have the on site repair done.
# Oh, boy!
# But while this is one big advantage (as you may know from the company s recent commercials) there are other things to consider before going with Apple.
# I love the way the entire suite of software works together.
# The speed is incredible and I am more than satisfied.
# on the bright side at least I was not without my laptop for long this time!
# This laptop meets every expectation and Windows 7 is great!
# that has / that is how frustrating it was.
# I can barely use any usb devices because they will not stay connected properly.
# The one down side to it is that when I play a certin game on here, it tends to freeze up sometimes, but thats the only bad thing about this computer.
# -No backlit keyboard, but not an issue for me.
# When I finally had everything running with all my software installed I plugged in my droid to recharge and the system crashed.
# I cannot even turn it off.
# One suggestion I do have, is to not bother getting Microsoft office for the mac expecting it will work just like you knew it to on a PC.
# Pairing it with an iPhone is a pure pleasure - talk about painless syncing - used to take me forever - now it has / it is a snap.
# I shopped around before buying.
# I also got the added bonus of a 30" HD Monitor, which really helps to extend my screen and keep my eyes fresh!
# Would do business again.
# The machine is slow to boot up and occasionally crashes completely.
# After paying several hundred dollars for this service, it is frustrating that you cannot get help after hours.
# I have had the luxury (sarcasm) of owning 2 of these laptops.
# What a waste.
# It was a total Dhell experience that I will never repeat.
# There are a few flaws as well that I noticed.
# Completely worth every single penny dime and nickel.
# I tried to upgrade it to a newer version a couple of months ago and I still have the same problem.
# I did have to replace the battery once, but that was only a couple months ago and it has / it is been working perfect ever since.
# :) In the past four years I have had it I have never once gotten a virus.
# I love the operating system and the preloaded software.
# They were great in handling this problem, and I am looking forward in purchasing additonal products from them in the future.
# I have tried going back to XL but there still problems.
# The best thing about this laptop is the price along with some of the newer features.
# After numerous attempts of trying (including setting the clock in BIOS setup directly), I gave up(I am a techie).
# YOU WILL NOT BE ABLE TO TALK TO AN AMERICAN WARRANTY SERVICE IS OUT OF COUNTRY.
# But it may be potentially hundreds or thousands in the near future.
# Has met or exceeded my needs for a compact travel device.
# but now i have realized its a problem with this brand.
# It cannot save the correct date and time I set.
# I sent it back to Toshiba twice they covered it under the  warranty.
# And this is not just my one experine.
# They sent me a replacement part and without informing me are requiring that I return it within 15 days or contact them and let them know the broken part will be returned later.
# I was looking for a mac which is portable and has all the features that I was looking for.
# I would highly recommend this one to my friends
# I honestly love my mac, thats why I am a self proclaimed mac addict.
# And these are some reasons you should get a macbook pro.
# Also kinda loud when the fan was running.
# In desparation, I called their Customer Service number and was told that my warranty had expired (2 days old) and that the priviledge of talking to a technician would cost me ("have your credit card ready").
# I purchased this laptop while on a business trip to keep up with my email.
# There also seemed to be a problem with the hard disc as certain times windows loads but claims to not be able to find any drivers or files.
# Drivers updated ok but the BIOS update froze the system up and the computer shut down.
# -they lost my laptop for a month
# Spent 2 hours on phone with HP Technical Support.
# This is my second laptop,and it is head and shoulders above my first.
# at first!
# Speaking of the browser, it too has problems.
# I think just going from PC to Mac has gotten me totally spoiled and I cannot imagine ever going back.
# The keyboard is too slick.
# Nightly my computer defrags itself and runs a virus scan.
# it has / it is like 9 punds, but if you can look past it, it has / it is GREAT!
# it has / it is just as fast with one program open as it is with sixteen open.
# Still under warrenty so called Toshiba, no help at all.
# I was happy with My purchase of a Toshiba Satellite L305D-S5934 laptop until it came time to have it repaired under the Toshiba Warranty.
# I LOVE IT!
# Amazing Quality!
# The fact that you can spend over $100 on just a webcam underscores the value of this machine.
# I mainly use it for email, internet, and managing personal files (pics, vids, etc.).
# A month or so ago, the freaking motherboard just died.
# The system it comes with does not work properly, so when trying to fix the problems with it it started not working at all.
# Then after 4 or so months the charger stopped working so I was forced to go out and buy new hardware just to keep this computer running.
# I took it back to Best Buy where they were so helpful and immediately gave me a new one.
# If you had PC for four years I can almost gaurentee that something would of gone wrong by now, maybe even forcing you to replace your entire computer.
# *2 weeks after giving the computer for repair*-Called headquarters, they report that they have not looked at it yet but it is "on the top of the stack".
# This machine delivers.
# Then 2 of my nephews were going into music and both fell in love with the MacBook Pro.
# I complain again...
# This laptop is insane!!!
# If a website ever freezes (which is rare), its really easy to force quit.
# It does run a little warm but that is a negligible concern.
# It rarely works and when it does it has / it is incredibly slow.
# I also enjoy the fact that my MacBook Pro laptop allows me to run Windows 7 on it by using the VMWare program.
# it has / it is so much easier to navigate through the operating system, to find files, and it runs a lot faster!
# Purchased a Toshiba Lap top it worked good until just after the warrenty went out.
# I always swore by PCs and would never consider a MAC.
# what an elegant, wonderful machine.
# This is now my 3rd MacBook Pro and I really honestly love it!
# for 2 months.
# I wanted to purchase the extended warranty and they refused, because they knew it was trouble.
# Do you ever think HP would do that? NEVER!
# We upgraded the memory to four gigabytes in order to take advantage of the performace increase in speed.
# it has / it is not like I have used for half a year and then complained about it.
# Still trying to learn how to use it.
# The reality was, it heated up very quickly, and took way too long to do simple things, like opening my Documents folder.
# I bought the netbook because it was smaller and lighter for me to carry around.
# The Genius at the Apple store advised me that there was nothing about my use of the computer that caused this failure.
# we will save our money to replace it with a Mac again!
# Thank you for your great product!
# this company truely does make horrible products and doesnt seem to because they are certain things like this "never" happen...
# I had always used PCs and been constantly frustrated by the crashing and the poorly designed operating systems that were never very intuitive.
# Sorry Toshiba, but 1st impressions do count for something.
# Then, within 5 months, the charger crapped out on me.
# And if you have a iphone or ipod touch you can connect and download songs to it at high speed.
# Overall this laptop is great.
# I love the glass touchpad.
#   I continued to take the computer in AGAIN and they replaced the hard drive and mother board yet again.
# I am using the external speaker- sound is good.
# The Apple MC371LL/A 2.4Ghz 15.4-inch MacBook Pro Notebook is a horrible waste of money.
# Ok, this is probably the best laptop series ever devised by Apple.
# As of a couple weeks ago the middle portion of the laptop from top to bottom,,,about 4 inches across is hardly visible.
# still testing the battery life as i thought it would be better, but am very happy with the upgrade.
# Then HP sends it back to me with the hardware screwed up, not able to connect.
# I just hope the reputation that Toshiba has is true and I will not have to worry about a crash.
# Oh yeah, do not forget the expensive shipping to and from HP.
# I would recommend anyone to buy from pcconnection express.
# Good luck.
# Everything is so easy to use, Mac software is just so much simpler than Microsoft software.
#   My favorite by far, although the most expensive, was my Sony.
# And if you do a lot of writing, editing is a problem since there is no  forward delete  key.
# Also I typed faster then then letters would show and it got to be realy annoying.
# As an owner of a Toshiba Satalite laptop computer things you should know before you buy.
# Its ease of use and the top service from Apple- be it their phone assistance or bellying up to the genius bar- cannot be beat.
# It has a 10 hour battery life when you are doing web browsing and word editing, making it perfect for the classroom or office, and in terms of gaming and movie playing it shall / it will have a battery life of just over 5 hours.
# I shipped out on Saturday, July 17.
# I bought it for really cheap also and it has / it is AMAZING.
# Acer has set me up with FREE recovery discs, when they are available since I asked.
# I also purchased Office Max's "Max Assurance" with the "no lemon" clause.
# If you find yourself in the market for a new laptop (and have the money) do not exclude looking at the MBPs.
# I eventually did the migration from my iMac backup disc which uses USB.
# Those things are very important - vital even!
# -They say it will take "up to two weeks".
# I did not like one thing about it.
# The battery life seems to be very good, and have had no issues with it.
# Enabling the battery timer is useless.
# Temperatures on the outside were alright but i did not track in Core Processing Unit temperatures.
# Yeah, to you.
# I got a mac as my HS graduation gift.
# I have now had it for 1.5 months and love it.
# It turned out it has / it is not really a problem to have a Mac.
# Page just disapeared after you got yahoo or downloaded something.
# Images can be multi-selected and viewed swiftly or in slideshow mode.
# Going to bring it to service today.
# There is no need to purchase virus protection for Mac, which saves me a lot of time and money.
# But we had paid for bluetooth, and there was none.
# So, I paid a visit to LG notebook service center at Alexandra Road, hoping they can make the hinge tighter.
# My daughter uses it for games, email, facebook, pictures and music.
# Laptop is to be used like a Netbook.
# It is always reliable, never bugged and responds well.
# After about a week I finally got it back and was told that the motherboard had failed and so they installed a new motherboard.
# Trying to balance all of my roles leaves very little time for me to do anything, so I want to manage my time I do have to be the most efficient.
# It was slow, locked up, and also had hardware replaced after only 2 months!
# they had to replace the motherboard in April
# Yes, the computer was light weight, less expensive than the average laptop, and was pretty self explantory in use.
# Also, if you need to talk to a representive at Microsoft, there is a charge, which I believe is robbery, since you are charged enormous amounts for a very badly designed system, which most people would have went with XP if they could.
# There is a little indent to help open it - but good luck with that.
# I love WIndows 7 which is a vast improvment over Vista.
#   Also, I have alot of trouble with it getting very hot, and not even sitting on anything to make it hot.
# It Was a great deal after all.
# This mac is great!
# Keyboard is great, very quiet for all the typing that I do.
# I grew up in a design family so it only made sense.
# Gave phonenumber.
# It would take up too much time to do reaearch for my papers and I would be up hours-just because the computer was too slow.
# Oh my goodness-I am not a happy camper.
# Dell's customer disservice is an insult to it has / it is customers who pay good money for shoddy products.
# I had / I would recommend this laptop to anyone!
# Yet, HP will not do anything about the problem.
# I am returning mine
# It had a cooling system malfunction after 10 minutes of general use, and would not move past this error.
# I can render AVCHD movies with little effort, which was a problem for most pc's unless you had a quad core I7.
# it has / it is a bummer and one out of five is being kind.
# This is what they told me: It heats up, and that is the reason we no longer call them laptops, and simply categorize them as portables.
# After talking it over with the very knowledgeable sales associate, I chose the MacBook Pro over the white MacBook.
# If you really want a bang-up system and do not need to run Windows applications, go with an Apple;
# You will not have to spend gobs of money on some inefficient virus program that needs to be updated every month and that constantly drains your wallet.
# This laptop is fast and you will literally learn all you can do with this dynamo by just watching the online tutorials.
# One of them seems to have worked.
# Which I still use and have hooked up to my TV.
# The problem I had with this unit was unresolvable.
# It weighed like seven pounds or something like that.
# 2 months later, the battery went.
# You may need to special order a bag.
# it has / it is color is even cool.
# and it has blue screen crashed on me twice.
#   Another two weeks later and it was back in my possession.
# keys are all in weird places and is way too large for the way it is designed.
# I have owned every "Pro" model Apple laptop for the last 8 years, this is BY FAR the WORST one I have ever had.
# We purchase the Dell XPS several years ago for my home business.
# Have purchased many products over the years from MacConnection and this transaction, like all the others, we smoothly with no problems.
# I would recommend anyone to buy from pcconnection express.
# Yes, a Mac is much more money than the average laptop out there, but there is no comparison in style, speed and just cool factor.
# He gave me this PC about 3 years ago and up to this point im still sitting here using it.
# I am pleased.
# The keyboard feels good and I type just fine on it.
# With a healthy pessimism, I took the machine home and tried to find a flaw.
# Shiny  This Laptop is the Best of the best!
# I thought the white Mac computers looked dirty too quicly where you use the mousepad and where you place your hands when typing.
# And not to mention after using it for a few months or so, the battery will slowly less and less hold a charge until you cannot leave it unplugged for more than 5 minutes without the thing dying.
# do not waste their money, save it and but a mac.
# Money and time well spent!
#   Gradually the freezing screen evolved into a screen that froze in weird shapes.
# BEST BUY - 5 STARS + + + (sales, service, respect for old men who are not / am not familiar with the technology) DELL COMPUTERS - 3 stars DELL SUPPORT - owes a me a couple
# Good laptop for the money.
# I like the laptop overall.
# I now travel with this laptop and my work PC.
#   I am however pleased that it is still hanging in there.
# Both my husband and I have this model Toshiba.
# no complaints with their desktop, and maybe because it just sits on your desktop, and you do not carry it around, which could jar the hard drive, or the motherboard.
# Yes, they cost more, but they more than make up for it in speed, construction quality, and longevity.
# Since I keyboard over 100 wpm, I look for a unit that has a comfortble keyboard (no keys sticking or lagging, strange configuration of "extra key", etc.
# ) I also tried the touch pad and compared it to other netbooks in the store.
# It absolutely is more expensive than most PC laptops, but the ease of use, security, and minimal problems that have arisen make it well worth the pricetag.
#   It gets stuck all of the time you use it, and you have to keep tapping on it to get it to work.
# lots of preloaded software.
#   Sony, Acer, Dell, Packard Bell and Toshiba.
# and then, a guy came out to serve me instead.
# Breaking within 1 year of purchase and speaking to 4+ people to report the damaged part will be returned late!
# Have returned that laptop unused.
#   Will probably never buy a HP again.
# I got tired of buying laptops and having them stop working after a year.
# I should have been more observant.
# I wish it had a webcam though, then it would be perfect!
# My favorite part of this computer is that it has a vga port so I can connect it to a bigger screen.
# Another thing I might add is the battery life is excellent.
# One drawback, I wish the keys were backlit.
# When the buyer returned it Wal Mart just boxed it, taped it shut  resold it as new.
# What a great little laptop.
# Acer was no help and Garmin could not determine the problem(after spending about 2 hours with me), so I returned it and purchased a Toshiba R700 that seems even nicer and I was able to load all of my software with no problem.
# I wish the volume could be louder and the mouse didnt break after only a month.
# I play a lot of casual games online, and the touchpad is very responsive.
# Granted, it has / it is still a very new laptop but in comparison to my previous laptops and desktops, my Mac boots up noticeably quicker.
# It caught a virus that completely wiped out my hard drive in a matter of hours.
# WOULD PAY MORE FOR IT IF I HAD TOO!
# could not keep a page up you were working on!
# It is everything I had / I would hoped it would be from a look and feel standpoint, but somehow a bit more sturdy.
# the only fact i dont like about apples is they generally use safari and i dont use safari but after i install Mozzilla firfox i love every single bit about it.
# The Bluetooth was not there at all, and the fingerprint reader driver would be there, but the software would hang after installation was 1/2 way done.
# Great battery, speed, display.
# I would not recommend this product to anyone.
# I like to use it at the race track to handiecap the horse races.
# I was given a Mac as a birthday present and could not be happier with it 3 years later.
# The delivery was fast, and I would not hesitate to purchase this laptop again.
# I have been impressed with the battery life and the performance for such a small amount of memory.
# do a quick search on the internet see if im the only one.
# I am extremely happy with my purchase as I now have the portable power I have been looking for.
# it has / it is applications are terrific, including the replacements for Microsoft office.
# they improved nothing else such as Resolution, appearance, cooling system, graphics card, etc.
# I got it back and my built-in webcam and built-in mic were shorting out anytime I touched the lid, (mind you this was my means of communication with my fiance who was deployed) but I suffered thru it and would constandly have to reset the computer to be able to use my cam and mic anytime they went out.
# Is this partially due to the fact that it is running Windows Vista?
# You might think, I am new in this game, but I am a gadget lover, and have had more than 2 dozens laptops in the past 15 years, and none gets this hot, that fast.
# I was informed that I need to call some 0900 number first.
# I really wanted a Mac over a pc because I used a Mac in high school.
# 1) Payed $2200 for a "premium" laptop
# I BOUGHT THEM FOR MY COLLEGE AGE GRANDCHILDREN AND THESE MACS ARE TOTALLY RELIABLE AND SUPPORT THEIR CLASS WORK 100% OF THE TIME.
#   The board has a bad connector with the power supply and shortly after warrenty expires the power supply will start having issues.
# Do not purchase this laptop.
# My dad has one of the very first Toshibas ever made, yes its abit slow now but still works well and i hooked to my ethernet!
# Mostly I love the drag and drop feature.
# oh yeah, and if the fancy webcam breaks guess who you have to send it to to get it fixed?
# She brought out 2 other identical netbooks and still insist that "It is like that one".
# I ordered through MacMall, which saved me the sales tax I would have incurred buying locally.
# Very fast and efficient!
# Of course, I also have several great software packages that came for free including iWork, GarageBand, and iMovie.
# Being virus-resistant is a huge plus.
# The screen is very large and crystal clear with amazing colors and resolution.
# After a little more than a year of owning my MacBook Pro, the monitor has completely died.
# In my house, HP is a nasty word.
# The brand of iTunes has just become ingrained in our lexicon now, but keep in mind that Apple started it all.
# By the way teachers, they offer a discount which helps!
# now he mows yards so he can earn the money for the wireless internet.
# I still see the benefits of a PC when I do not know how to do something on my mac.
# Size: I know 13 is small (especially for a desktop replacement) but with an external monitor, who cares.
# Additional caveat: the base installation comes with some Toshiba-specific software that may or may not be to a user's liking.
# It is held in place magnetically.
#   Taking it back to Best Buy I found that a tiny plastic piece inside had broken (manuf issue).
# It has no camera but, I can always buy and install one easy.
# The display is incredibly bright, much brighter than my PowerBook and very crisp.
# We were PC users.
# The AMD Turin processor seems to always perform so much better than Intel.
#   After that the said it was under warranty.
# The start menu is not the easiest thing to navigate due to the stacking.
# Only thing I would want to add to this is an internal bluray read/write drive.
# This computer was awful, I would never recomend it to another person.
# The service tech said he had tried to duplicate the damage and was not able to recreate it therefore it had to be their defect.
# The tech store I purchased this from sent it back,,,,,eventually I got a new or repaired machine approximately 3 weeks later.
# I loved it then, but unfortunately it was before the days of wireless internet.
# Really like the textured surface which shows no fingerprints.
# I WILL NEVER AGAIN buy another Acer, not will I buy Gateway, or eMachine as they are all from the same company.
# The screen is bright and the keyboard is nice;
# I look forward to years of use, it has held up well over the years and it fits my needs very well.
# Im very happy with this computer!
# But the machine is awesome and iLife is great and I love Snow Leopard X.
# High price tag, however.
# I thought learning the Mac OS would be hard, but it is easily picked up if you are familiar with a PC.
# My kids have to take their PCs in once a year to have them "de-bugged".
# I had static in the output, and I had to reduce the sound output quality to "FM" as opposed to the default "CD.
# It was a laugh  too!
# Since I purchased my Toshiba netbook, I have been very pleased with it, I have a laptob and a desktop.
# I bought my macbook a few months ago and it has been my baby ever since.
# That is how it is able to function better than any other PC.
# I custom ordered the machine from HP and could NOT understand the techie due to his accent.
# It is easy to use and lightweight.
# I went to Toshiba online help and found some suggestions to fix it.
# It is a bit heavy.
#   after trying to get some help he disconnected on me.
# They also have a longer service life than other computers (I have several friends who still use the older Apple PowerBooks).
# If you check you will find the same notebook with the above missing ports and a dual core AMD or Intel processor.
# This laptop is a great price and has a sleek look.
# I especially like the keyboard which has chiclet type keys.
# Small screen somewhat limiting but great for travel.
# One of the primary reasons why I purchased an IPad was to store photographs so that I could show to my customers.
# Runs Hot  I thought we were paying for quality in our decision to buy an Apple product.
# For the not so good, I got the stock screen - which is VERY glossy.
# The gray color was a good choice.
# This was the second computer and brand bought that day.
# Buy this.
# VERY disappointing:
# I love this product because it is Toshiba and its 15.6".
# I would like to have volume buttons rather than the adjustment that is on the front.
# This is my first computer purchase
# People know what they are talking about and they have pride in the product that they are selling.
# The processor a AMD Semprom at 2.1 ghz is a bummer it does not have the power for HD or heavy computing.
# Would HIGHLY recommend this netbook though.
# I have had several machines over the years, both for personal and business use.
# I bought a protector for my key pad and it works great :)
# The magnetic plug-in power charging power cord is great (I even put it to the test by accident)- excellent innovation!
# Well i got this computer from Best Buy and I have had nothing but problems I bought the computer with a virus.....
# It seems they could have updated XP and done without creating Vista.
#   It is easy to use, fast and has great graphics for the money.
# I decided I wanted a laptop so I went into the BBY store.
# I like how the Mac OS is so simple and easy to use.
# While Apple's saving grace is the fact that they at least stand behind their products, and their support is great, it would be nice if their products were more reliable to justify the premium.
# In the three years I have had my MacBook Pro, I have never had a virus on my computer, and I do a lot of work on the internet.
# I was ready to take it back for a refund, but the Geek Squad camed through and pointed me in the right direction to get it fixed.
# I have had laptops in the past and I thought why not give these small netbooks a try.
# It cannot get any better.
# All the problems I have had with PC's are solved with a Mac: the issue of overheating-my Dell was always overheating and not working properly or simply shutting off, and the issue of viruses and contaminants-my HP completely quit working within2 years of purchasing it, with no inexpensive way of fixing it.
# only good thing is the graphics quality.
# The other lock-up problems are from a myriad of causes, the most common being a corrupted version of Appleworks which can render the browser useless.
# In short I would never buy a Compaq again.
# I love the 15" MacBook Pro.
# breaks easily.
# The paint wears off easily due to the keyboard being farther back than usual.
# that has / that is right, no power, absolutely NOTHING.
# I had purchased it from a major electronics store and took it to their service department to find out what the problem was.
# The store honored their warrenty and made the comment that they do not even recommend the HP brand because of the problems with their warrentys.
# But I was wrong.
# NO good.
# I always use a backup hard disk to store important files at all times.
# They sent out the box right away for me to send in my computer, they paid postage and whatnot, but when I got my computer back it still was not running right, and now my CD drive was not reading anything!
# I bought this laptop Was the worst Laptop I have ever bought.
# But the screen size is not that bad for email and web browsing.
# Once I removed all the software the laptop loads in 15-20 seconds.
# On my PowerBook G4 I would never use the trackpad I would use an external mouse because I did not like the trackpad.
# This computer does not do that well with certain games it cannot play some and it becomes too hot while playing games.
# Obviously one of the most important features of any computer is the "human interface.
# Yeah, of course smarty pants "fix it now")Software - Compared to the early 2011 edition I did see inbuilt applications crashing and it prompted me to send the report to Apple (which I promptly did).
# The body is a bit cheaply made so it will be interesting to see how long it holds up.
# The i5 blows my desktop out of the water when it comes to rendering videos.
# With a mac you do not have to worry about antivirus software or firewall, it has / it is so wonderful.
# For the use it was purchased for it is a good Laptop.
# Am very glad I bought it, great netbook, low price.
# Obviously, this Macbook is P-E-R-F-E-C-T for me because it does exactly what I need in an easy-to-function way.
# Worth the investment and truly a fine piece of equipment.
# The Apple team also assists you very nicely when choosing which computer is right for you :)
# Summary: Dont buy HP.
# I think part of the problem with this computer is Vista, yet I know Vista is not the entire issue because my latest purchase was my Acer and it also has Vista (I should have waited the few months to get the next operating system).
# The video chat is the only thing that is iffy about it but im sure once they unpdate the next version on the macbook book the quality of it will be better.
# you shall / you will need to upgrade and pay a little more for them.
# it is hard to fix and makes it a hassle to own one.
# That whole experience was just ridiculous we sent it in and after they told us that we had to pay $175 to fix it we were like we will just by a portable mouse which would be way cheaper but they refused to send the laptop back until we paid the $175 and it was fixed.
# Macs are designed for the "frontal lobe challenged" people out there.
# Fan vents to the side, so no cooling pad needed, great feature!
# i use my mac all the time, i love the software, the way it takes a short time to load things, how easy it is to use and most of all how you do not have to worry about viruses.
# Wasted me at least 8 hours of installation time.
# It has far exceeded my expectations for power, storage, and abilitiy.
# A great feature is the spotlight search: one can search for documents by simply typing a keyword, rather than parsing tens of file folders for a document.
# My wireless system would not recognize Windows 7 and I could not get online to find out why.
# I am enjoying it and the quality it provides is great!
# It is the worst laptop ever
# Suffice it to say, my MacBook Pro keeps me going with its long battery life and blazing speed.
# I am not going to lie, I have never really liked the Acer brand in general.
# The OS is also very user friendly, even for those that switch from a PC, with a little practice you can take full advantage of this OS!
# iTunes is a handy music-management program, and it is essential for anyone with an iPod.
# -I give up on my data, I just want a computer reasonably fast...
# Would buy 100 more of these if I could.
#   while it was barely a bargin in the begining, i would never purchase another dell and would not recomend the dell brand to others.
# it was shooting sparks!
# Great product.
# Mac is not made for gaming.
# Well I spilled something on it and they replaced it with this model, which gets hot and the battery does not make it through 1 DVD.
# I have had to call Apple support to set up my new printer and have had wonderful experiences with helpful, english speaking (from Vancouver) techs that walked me through the processes to help me.
# But Sony said we could send it back and be charged for adding the bluetooth an additional seventy something dollars.
#   By this time I was regretting ever SEEING this machine on the shelf!
# Toshiba is a great brand, even though I have not had it for a long time, I am very happy with it!
# I need graphic power to run my Adobe Creative apps efficiently.
# the programs are esay to use and are quick to process this computer works like a charm.
# The materials that came with the computer did not include the right # anywhere.
# So when you do call to complain about the hunk of metal you get the joy of speaking with a bunch of people you cant understand.
# That day!
# " For one, I noticed that from turning on my mac to logging on only took about 25 seconds.
# It does not even have the software to play a dvd now.
# My brother is a computer wiz and would laugh at me because he used an Apple.
# Tech support tells me the latter problem is a power supply problem and have offered to fix it if it happens again.
# Since I never really got to use this, I cannot comment on anything except what went wrong after trying 2 of them.
# Buyers beware.
# HOW DOES THE POWER SUPPLY NOT WORK!!!
# Sells for the same as a netbook without sacrificing size.
#   I shall / I will rather be out of date then spend more money on toshiba.
#   upon giving them the serial number the first thing I was told, was that it was out of warranty and I could pay to have it repaired.
# Windows XP SP2 caused many problems on the computer, so I had to remove it.
# Love it.
# I reloaded with Windows 7 Ultimate, and the Bluetooth and Fingerprint reader (software) would not load.
# None of the techs at HP knew what they were doing.
# Oh, it is such a great piece of equipment.
# this is my second one and the same problem, bad video card  unreliable overall, this will be my second time returning this laptop back to best buy.
# I use that alot on my desktop, so I am adjusting to not having it.
# With awesome graphics and assuring security, it has / it is perfect!
# Laptop was in new condition and operational, but for the audio problem when 1st sent for repair.
# I was disappointed when I realized that the keyboard does not light up on this model.
# This machine was a horrible experience.
# It runs perfectly.
# Very dissappointed becase I have had toshibas for years, and never a issue.
# If you have any creativity in you do yourself a favor and get a mac!
# The laptop was very easy to set up.
# Congratulations Asus for creating one big piece of dump which is my laptop.
#   Sometimes the screen even goes black on this computer.
# I would definitely recommend checking out this laptop if you are in the market for one.
# I recommend for word processing and internet users.
# Since I have had this computer I have only used the trackpad because it is so nice and smooth.
#   When the computer has been on for several minutes, it will occasionaly just go off by itself.
# A longer battery life would have been great - but it meets it has / it is spec quite easily.
# Who could not love a DVD burner, 80-gigabyte HD, and fairly new graphics chip? As I soon discovered, though, there is a reason for which similarly-configured Sony and Toshiba machines cost more: they use higher-quality components that are faster, better-configured, and end up lasting a lot longer.
# falls into the case.
# This is something i would deffinately reccomend to someone.
# Its fast and another thing I like is that it has three USB ports.
# Mac computers automatically "defrag" each time you start your computer.
# That is my only complaint!
# The salesman talked us into this computer away from another we were looking at and we have had nothing but problems with software problems and just not happy with it.
# That system is fixed.
# The computer itself was fast, ran smoothly, and had no problems.
# One of the smartest thing I did was take my time to compare laptops before making my purchase.
# Like the price and operation.
# The brand is tarnished in my heart.
# This is likely due to poor grounding and isolation between the components, and I am hoping that it can be fixed with a ground loop isolator, but I still expected better product quality for this price range.
# Honestly, this is absolutely wonderful.
# I 'have had it for about a 1 1/2 and yes I have had an issue with it one month out of warranty.
# I really wish I had done this years ago.
# Well, maybe I was just very unlucky.
# For example, when my husband turns the light out while I am on the computer.
# Once open, the leading edge is razor sharp.
# Loaded with bloatware.
# If you buy, pray you dont have major prolems.
# do not get me wrong, I am no Microsoft hater, I have just managed to turn into a much bigger Apple fan because of this machine.
# HP refused to give me a new one and Wal Mart refused to take it back.
# Within 3 weeks the same issues started happening AGAIN.
# Maximum sound is not nearly as loud as it should be.
# Well, they do not care a bunch.
# I loaded windows 7 via Bootcamp and it works flawlessly!
# I have never had to shut down the computer unexpectedly and the computer has never froze on me.
# Great Laptop for the price, works well with action pack games.
# Although the price is higher then Dell laptops, the Macbooks are worth the dough.
# Recommended to people as their first laptop.
# I would recomend this acer to parents and grandparents it can really help them in school.
# I would not recommend this to anyone wanting a notebook expecting the performance of a Desktop it does not meet the expectations.
# The Macbook arrived in a nice twin packing and sealed in the box, all the functions works great.
# So what if the laptops/mobile phones look chic and cool? The after sales support is terrible.
# they have not sent a new one nor called.
# I would easly reccomend this laptop to a friend.
# I hate the display screen and I have done everything I could do the change it.
# I spent alot of money on this product and its been a nightmare.
# I also like the acer arcade but these were reallythe only two things I liked about this laptop.
# Have not yet needed any customer support with this yet so to me that is a great thing, which is leaps and bounds ahead of PC in my opinion.
# Thinking about returning it
# I gave it to my daughter because I just hated the screen, hated that it had no cd drive to at least play cd's when I wanted to listen to music and do schoolwork.
# It runs very quiet too which is a plus.
# but it  has a major design flaw.
#   I took the laptop home and not even a month later, I began to have problems with it.
# It was heavy,bulky, and hard to carry because of the size.
# That was my first Apple product and since then I have been incredibly happy with every product of theirs I have bought.
# i tried turning it done but it did nothing.
# It is super fast, and always loads.
# The games included are very good games.
# this computer will last you at least 7 years, thats an amazing life spanned an electronic.
# I bought mine from Apple Store the day it was released as Amazon did not have it yet.
# I had something else go wrong and they said it had to be in good working order to be able to buy the warranty.
# the whole experiece is horrible so save up and buy a better laptop.
# I just bought this laptop 3 days ago.
# I am very pleased with my purchase!
# Sometimes you really have to tap the pad to get it to worki
# it has / it is super fast and a great value for the price!
# Three, the mac book has advantages over pcs' with linux based os there is very 'few problems with system performance when it comes to a mac.
# A mac is very easy to use and it simply makes sense.
# Of course, eMachines cannot be made entirely to blame for this computer's woes;
# however, I may have inadvertently thrown out one of the batteries with the shipping carton.
# Love it so far.
# It is so much easier to use
# There is no need to open a program first and the cliick open or import.
# In short, you could say your mac could become your best friend (no intention of replacing Rover your dog).
# It was a bad experience but i played down its importance.
# Meets my needs perfectly and is light enough for this senior to carry without affecting my arthritis.
# It is so nice not to worry about that and the extra expense that comes along with the necessary virus protection on PC's.
# The Notebook PC,Toshiba Qosmio is the best gift my father could have ever gotten me.
# Three weeks after I bought the netbook, the screen quit working.
# The processor screams, and because of the unique way that Apple OSX 16 functions, most of the graphics are routed through the hardware rather than the software.
# I am currently out of town and called to inform them the broken part would be returned when I got back in town.
# Returned laptop for a 4th repair and it came back but now would lock up and randomly reboot frequently making the laptop unusable.
# I wanted something that had a new Intel Core processors and HDMI port so that we could hook it up directly to our TV.
# The Apple will run Internet Explorer, but at an amazingly slow rate.
# With today's company fighting over marketshare, its a shame that ASUS can get away with the inept staff answering thephone.
# Other than that I do not have one complaint in the world!
#   The computer is so slow, even after paying staples the extra money to speed it up.
# I feel that enough people have Macs these days and that companies need to start making things more compatable than they used to be.
# The price premium is a little much, but when you start looking at the features it is worth the added cash.
# *5 weeks after giving the computer for repair*-Apple offers to send replacement after they receive the old computer.
# I cannot say enough of how satisfied I am with their product and help aftermarket.
# My computer was one of the best in the school compared to my fellow classmates.
# I bought for my son in the 2nd grade.
# This has happened three times so far.
#    I am a professional consultant, and a client needed work on her machine.
# compresses itself and you cannot use it.
# Microsoft word was not on it andI had to buy it seperately.
# it has 3 usb ports, 1 sd memory card reader and an sd memory car expansion.
# Who knows what will happen later on when they dismantle the whole damn thing?  So, I said I wanted a new set.
# I connect a LaCie 2Big external drive via the firewire 800 interface, which is useful for Time Machine.
# If you already own a 2009, 2010, or early 2011 model, you should wait until the next update.
# My Toshiba did not have sound on everything, just certain things.
# I am overall very pleased with my toshiba satellite, I like the extra features, I love the windows 7 home premium.
# So, I must say I am not a happy camper.
# -Called MacHouse Amsterdam to ask for a temporary replacement, no answer.
# The Aspire wont even boot past the Acer screen with a Droid (I have tried both Motorola and HTC) plugged into the USB port.
# I bought it during the recent Comex IT show.
# The battery life was shorter than expected.
# It fires up in the morning in less than 30 seconds and I have never had any issues with it freezing.
# It doesnt overheat or make any loud noises.
# Look up recipes and keep it on the kitchen counter while I cook.
# The keyboard is top notch.
# Do you think the shop will give me a new set?? It will NOT!
# I have had nothing but problems since the day I took it out of the box!
# My Macbook was worth (after 3 years of use!) $375.
# It drives me crazy when I want to download a game or something of that nature and I cannot play it because its not compatable with the software.
# The online tutorial videos make it super easy to learn if you have always used a PC.
# Bought this gateway M-50 or 150 early 2007.
# The image is great, and the soud is excelent.
# With a MAC computer I have more free time as I do not have to wait for windows to boot up or shut down and all the viruses associated with windows.
# It was very easy to just pick up and use-- It did not take long to get used to the Mac OS.
# This netbook is a perfect supplementary computer to another laptop or desktop (my wife and I have another laptop), or if you are a user who uses the computer for simple tasks.
# With all the goodies inside this machine, it is a value.
# I took it back for a full refund.
# It is well worth the money it cost, Very good investment.
# Upgrading from Windows 7 Starter, thru Windows 7 Home Premium, to Windows 7 Professional was a snap;
# This computer had exactly the specifications I needed.
# Overall, still a very nice machine.
# Where you click and hold and drag it picture, link, etc to where you want it.
# My kids (and dogs) destroyed two power cords by pulling on them.
# I had upgraded my old MacBook to Lion, so I kind of knew what I was getting, but had not been able to enjoy some of the awesome new multi-touch features.
# I had this computer for one month and had to send it in for repair.
# The screen is a little glary, and I hated the clicking buttons, but I got used to them.
# Not to mention, the battery life is absolutely amazing.
# I realize that not every unit has this issue, but the ones that do cannot be repaired.
# I have had a Mac for 6 years and will not go back to PC.
# i love to use it it is esay and light.
# Windows also shuts the computer down for no reason without warning.
# not using wired lan not sure what thats about.
# After about another month I had to send it in AGAIN to Acer for repairs.
# The macbook rarely requires a hard reboot.
# I LOVE it!
# The #1 reason that is always repeated.
# Now for the hardware problems.
# Unfortunately, that is not the case.
# Anyways I bought this two months ago and when I first brought it home it kept giving me a message about a vibration in the hard drive and it is putting it temporaly in save zone.
# it has / it is fast and has excellent battery life.
# it has / it is face and depanable.
# No Viruses!
# I am just really happy that I waited to buy, because this thing kicks a$$!
#   The Hewitt Packard Pavillion dv6700 was my first laptop, before this I had a Dell desktop that I loved.
# Apple care included.
# It was an all around waste of money for me.
# I worked in IT retail sales before.
# Features like the font are very block-like and old school.
# It has everything you need to get the job done.
# It is loaded with programs that is of no good for the average user, that makes it run way to slow.
# I feel that it was poorly put together, because once in a while different plastic pieces would come off of it.
# it cant fuction well with lots of webpages open at once.
# Finally, I should note that I took the 2GB RAM stick from my old EeePC and installed it before I even powered on for the first time.
# This laptop has left me with a HORRIBLE taste in my mouth for Acer brand products.
# its not bad just VERY VERY annoying.
# Well, maybe more like week one.
# ...
# I tell everyone that I know, friends, family and enemies this is the absolute worst computer i have ever used.
# Overall : Poor, Features: Average, Performance: Poor, Battery Life: Excellent, Price-Value: Poor
# Otherwise, I love it!
# Having someone give you a quick tour of how to's is the best.
# I have recently converted back to a mac and I could not be happier!
# Microsoft seems to be unable to keep up with repairs for the multitude of windows problems.
# At 16 months it started shutting off after only 5 or 10 minutes.
#   They basically told me that the machine would be problem free now.
# I paid about 18000 for this laptop because of all the bells and whistles and it kept crapping out on me.
# The graphics are stunning.
# (I found a 2GB stick for a bit under $50) Nice and portable and definitely a decent enough system to keep you entertained while sitting in the airplane for a couple of hours, or at the hotel taking care of some last minute details and documents.
# after much effort and 10 days ASUS replaced itThe WiFi is very weak.
# You can call HP and they want you to buy more software to fix it.
# It has been plagued with problems since the day i turned it on.
# this computer is a little more expensive than any pc but it will last you longer and it worth every penny.
# It is easy to navigate and update programs.
# The laptop is gorgeous.
# it has / it is more expensive but well worth it in the long run.
# I am making the switch and finding that my biggest problem is trying to do things the 'old' way - and Apple does, indeed, have the better idea.
# I have had hp desktop for over 4 yrs now and not one days goes by that i do not regret buying it.
# HP did not fix it.
# , Applications respond immediately (not like the tired MS applications).
# All in all, a very disappointing experience except that I learned how good the Geek Squad is and also Customer Service.
# Now, I guess, I shall / I will have to unload my M6809 on some poor, hapless soul.
# The only drawback for me is how dirty the screen gets, and rather quickly too.
# The laptop is very lightweight, can easily carry around in a knapsack full of text books and it barely adds any weight.
# Seems to slow down occassionally but can run many applications (ie Internet tabs, programs, etc) simultaneously.
#   The problems started with just the screen freezing.
# Taking it anywhere was a pain!
# I also did not like the loud noises it made or how the bottom of the computer would get really hot.
# I had in the past a Dell laptop and they sent me the items it needed or they sent a repair technician to my house to fix it.
# I previously owned a Toshiba and it only lasted about 2 years.
# I cannot imagine my life without it anymore!
# defective software.
# This computer was so challenging to carry and handle.
# Cords coming out the right for power plus cords coming out front for headphones/mic plus network connection on left make for a very messy setup with cords going every direction.
# Unless you want to be inconvenienced with a non working power supply which you cannot find a replacement for because they made the attachment so small.
# It is much faster than my desktop which is a Core2 Quad running at 2.83 GHz.
# It is good to know that I can mobilize without having to worry about the battery life.
# I baby my electronics so I know for a fact it was defective and not anything that I did to it.
# The screen is nice, side view angles are pretty good.
# The fact that the screen reacts to the lighting around you is an added luxury-when you are working around others in dark areas and want privacy or do not want to bother them with bright lighting, it is very convenient to have a darker, softer lit screen.
# 3 weeks went by and the computer keeps crashing and will not open any applications.
# Not to mention sometimes the whole charger unit will decide not to work entirely.
# Looks nice, but has a horribly cheap feel.
# I would recommend not buying this product.
# its more like a snail crawl.
# I have other computers that get strong signals that do not drop in places that this "net"book loses its signal.
# The feel of this is better than the Toshiba, too.
# I would recommend this laptop to anyone looking to get a new laptop who is willing to spend a little more money to get great quality!
# I upgraded the memory and replaced the base Windows 7 Starter to Win 7 Home, and it runs just fine.
# I am not sure if it was the drive itself, however;
# So I called, AGAIN.
# Also, one of the users mentioned how the edges on the macbook is sharp, if you have money to spend on one of the incase shells, it does not seem to be a problem.
# It is easy to use, its keyboard easily accommodates large hands, and its weight is fantasic.
# Called Acer many times, they want me to pay the shipping to ship it to their repair center - I was very disappointed since it is a brand new computer!
# I was constantly having to roll back the computer after doing updates.
# Stay away from Envy.
# -got it back 3 months later
# I have had to send in my laptop three times to get it fixed.
# When I turned it on, nothing.
# I should have checked this before I installed my applications.
# The battery is really long.
# Anyway, in early July of this year, the DVD burner stopped working, and the computer stared having issues with power supply.
# Had some trouble finding a case that it would fit in.
# The 17 in Macbook Pro has been a wonderful addition.
# This computer that I have has had issues with the keyboard where it lost half the keyboard functions.
# 1st time they got it working the next 5 month they had me send it in.
# Comes with iMovie;
# I just love my Mac!
# I can not even read what I am writing half of the time.
# MACS ARE AMAZING!!!
# My hp G60-244dx died after only 16 months.
# They freeze all the time.
# this one, in my opinion, might be a lemon!
# The book is useless.
# COMPUTER HAS BEEN AT SERVICE FACILITY MORE THAN IN MY HANDS.
# This laptop is very large and barely fits in any carrying cases.
# When I called Sony the Customer Service was Great.
#   even though I had the receipt in front of me proving it still had 2 months left on the warranty.
# I sent it to them to fix in perfect condition but for what was wrong with it.
# It is a much more streamlined system for adding programs, using the internet, and doing other things everyone does on a computer.
# My computer froze on several occasion, had buttons that randomely would fall off and even had moments when the computer would refuse to turn on at all.
# Not even safe mode boots.
# Which was way too much money.
# To those thinking about switching, do it and do not look back!
# This is an over-sized, 18-inch laptop.
# I had to pay $100 for a universal charger for this cheap $300 laptop.
# The powerpoint opened seamlessly in the apple and the mac hooked up to the projector so easily it was almost scary.
# 1.You can not change your desktop background (window's 7 starter does NOT support that function).
# Took me 11 hours, 3 trips to different FedEx offices, and brutal conversations with 14 of the worse IT support technicians in the world.
# Then after 4 or so months the charger stopped working so I was forced to go out and buy new hardware just to keep this computer running.
# One year of trying to fix the computer by myself, with help of friends, and even help from computer experts I have given up on trying to fix it.
# As usual at customer service center, she asked me to hold for a moment while she went to the back-office and compare it with other same model netbooks and discussed it with her colleague (I could see them).
# The screen gets smeary and dusty very quickly and it has / it is very noticeable.
# It all just makes sense.
# 2) Blue screen first month
# I love it so much.
# I got it for Christmas, and I was so excited to set it up!
# Strengths:Well-shaped Weaknesses:A bad videocard!
# You cannot even get a satellite card which is why I bought to begin with.
# I use it now more than I even thought I would.
# The battery life, before the battery completely died of course, left much to be desired.
# Do yourself a favor, this is not a fake story trying to hurt alienware...
# It is a REAL touchpad, not the toy I saw in other brands.
# It has worked fine.
# The most amazing part to me as a PC user is the startup and shutdown times - and the fact that you very rarely have to restart the thing.
# Long story, but after many calls to various  offices, I was told that no one can override the depot and that managers  do not take phone calls or e/mails.
# I can throw anything at it (and I do), Pictures, video editing, schoolwork.
# Price and purpose is awesome!
# Wonderful zooming.
# The screen is huge and coloful, but no LED backlighting.
# the two of us use it regularly.
# In all honesty, if someone is looking for a quality laptop and willing to pay a little more money for a normal sized laptop than a cheaper and less impressive laptop, then do not buy this computer.
# Everything about this computer is easy to use.
#   After paying over $1000 for this computer, it was not worth it.
#   Worse, for the price I could get a *netbook* that outperforms this machine.
# Very happy with my 7th Toshiba laptop!
# My wife recently purchased an Apple MacBook Pro and our granddaughter fell in love with it and asked for one for her birthday.
# It had most of the features and all of the power that I wanted to replace my desktop machine.
# Keyboard was also very nice and had a solid feel.
# I will only buy apple laptops from now on.
# I would definitely suggest this laptop!
# It did not have all the features I expected it to have.
# Just a bunch of idiots who has / who is English as a 5th language is forced at best.
# No luck, although I waited for hours on the phone-Visited MacHouse, they stated the their call center is down due to too many phonecalls (difficult to believe).
# There is a backlit keyboard which is perfect for typing in the dark.
# It has a lot of memory and a great battery life.
# I spoke with a service rep at Micro Center and his girlfriend is having the same problem with her power adapter, so it has / it is not just an isolated incident!!!
# They had me send in the machine last April returned it to me in May with no documentation on what was done it anything.
# 5) Cut my losses and sold it for parts
# All I can say is W-O-W.
# I love this program, it is superior to windows movie maker.
# Which is what I did, check out my ACER 5517!
# He has replaced his hard drive twice and (of course) has had to pay for antivirus software every year.
# This purchase opened me to the world of Macbooks, and I am impressed with the intuition of the design, the beauty of the product, and the excellent technological advances associated with it.
# I have loved this since i took it out of the box.
# The price is great for this model, I only plan on using it for media in the entertainment room.
# It seemed to be a very nice laptop except I was not able to load my Garmin GPS software or Microsoft Office 2003.
# But, like I said before, the only reason I do not currently have a Mac laptop is because all of their laptops are too pricey.
# I have also had to have the keyboard replaced at my expense.
# I had the staff telling me older version did not make the fan noise cause it is a "different" computer.
# Was very much worth the price i paid.
# So far, so good.
# Even out of warranty!
# A tip for people looking into this computer: DO NOT BUY IT save up a bit more money and buy a computer that will last.
# This is a great little computer for the price.
# This comes in very handy for me as an educator.
# Crisp screen, great battery life, and plenty of storage.
#   it has / it is a long and tirring process that after a while it seems like their game plan was to wear you out so you would want to give up on contacting them.
# All apple associates are always wiling to help you out with anything, no matter when you purchased the computer and how many years passed.
# I was waiting for this model to be released since January, and have been holding off on buying a Macbook Pro until the new model came out.
# I will never buy another HP computer.
# So i would not reccomend anyone buying this computer
# You will regret it if you buy any dell.
# i think that anyone looking for a good durrable laptop then this is the way to go.
# Also, my sister got the exact same laptop (since they were so cheap) and after 8 months, the screen split in half just from everyday use.
# It started out getting hot after only a few months.
# The Toshiba Satellite has been more than I expected for the price.
# I had to adjust my mousepad sensitivity, because it is very sensitive.
# I wish iWork or MS Office came with the Mac, but MS Office does not even come with most pc laptops.
# To my mind much more usable than the toy called an IPad.
# It allows me to do everything I need from a computer and more.
# The best thing is even while doing almost ten or twenty things at once, it never slows down.
# Keyboard is plastic and spongey feeling.
# , which Apple does not offer, is why I bought my MacBook at Best Buy.
# previous laptops were pc's, still have them, but the mac osx is a clean and smooth operating system.
# The computer is a dream come true.
# i also love having the extra calculator number set up on the keyboard which most laptops do not have.
# I am glad I made the choice to switch and buy this MAC.
# Because he said that the hinge is under the motherboard and they have to dismantle the whole thing before it can be tightened.
# You can do it all on this bad boy but the main thing this netbook was desinged for was surfing the web and boy o boy does it ever.
# I love my Apple, it is quick and easy to use.
# I took it to the shop and they said It would cost too much to repair it.
# did not expect to repair it at once!
# It is quiet and a real joy to watch work.
# With notes saying they replaced the hard drive.
# The laptop is relatively simple to use, though I bought  Macs for Dummies,  which is well worth $2
# cannot close the 2nd HDD bay since there are brackets you have to break off (even then, it still does not shut) That could be a major flaw for the dual HDD user.
# From the start, when you open the box you see a completely different class of machine.
# No tutorials on the display.
# The leather carrying case, keyboard and mouse arrived in two days from Memphis warehouse.
# The touch pad is among the best.
# Very very disappointed!
# If you are a person like me, more on the creative side, the mac has something for you too.
# I had to have these computers in my school.
# Thus, when you carry it at a slanted angle, the screen will "topple" or "slide" down, if you understand what I mean.
# Again.
# To this day, there are NONE.
# i setup my password last night with the password on my other computer.
# it is an amazing image and it too is holding up quite nicely to little hands grabbing the back of my laptop.
# first i have been searching for long time before i decided to get mac.
# it has / it is now all commodity hardware.
# We also use Paralles so we can run virtual machines of Windows XP Professional, Windows 7 Home Premium, Windows Server Enterprise 2003, and Windows Server 2008 Enterprise.
# I was so excited when my dad said i could get a new laptop for my birthday.
# We purchased this as a back up computer after our more expensive HP needed to be repaired.
# -They reported that the computer is in their headquarters.
# bought notebook 07/2009.
# How Toshiba handles the repair seems to vary, some folks  indicate that they were charged for even an intial fix, others had the  repair done 5 times.
# I would like to use a different operating system altogether.
# All of them were Windows machines.
# Well, I had completed the presentation in powerpoint the night before on my PC, but took the Apple to the conference.
# The latest and mightiest Macbook pro 17-inch was bought by my university on the 30th of June 2009.
# I have a business website and every time I have to change something I have to go to the public library to use a PC.
# I paid about the same for my Toshiba as I did for the compaq a few years back.
# This was an update from an early MacBook Pro.
# I think I might rather suffer for something that is simple to fix in my opinion.

# %%
new_list
# Out:
# ['I charge it at night and skip taking the cord with me because of the good battery life.',
#  'I bought a HP Pavilion DV4-1222nr laptop and have had so many problems with the computer.',
#  'The tech guy then said the service center does not do 1-to-1 exchange and I have to direct my concern to the "sales" team, which is the retail shop which I bought my netbook from.',
#  'I investigated netbooks and saw the Toshiba NB305-N410BL.',
#  'The other day I had a presentation to do for a seminar at a large conference in town- lots of people, little time to prep and have to set up a computer to a projector, etc.',
#  'it is of high quality, has a killer GUI, is extremely stable, is highly expandable, is bundled with lots of very good applications, is easy to use, and is absolutely gorgeous.',
#  'Easy to start up and does not overheat as much as other laptops.',
#  'Sad very SAD.',
#  'I even got my teenage son one, because of the features that it offers, like, iChat, Photobooth, garage band and more!',
#  'Needless to say a PC that cannot support a cell phone is less than useless!',
#  'Great laptop that offers many great features!',
#  'they have done absolutely nothing to fix the computer problem.',
#  u'\xa0One night I turned the freaking thing off after using it, the next day I turn it on, no GUI, screen all dark, power light steady, hard drive light steady and not flashing as it usually does.',
#  'Still pretty pricey, but I have been putting off money for a while as a little Macbook Fund, and finally got to use it.',
#  'My only disappointment with the 13" model is that they are the only ones in the MacBook Pro line up without an i5 or i7 processor and dual graphics cards, however the trade-off is that you achieve a longer battery life (of about 2 more hours).',
#  'I took it back for an Asus and same thing- blue screen which required me to remove the battery to reset.',
#  'In the shop, these MacBooks are encased in a soft rubber enclosure - so you will never know about the razor edge until you buy it, get it home, break the seal and use it (very clever con).',
#  'However, the multi-touch gestures and large tracking area make having an external mouse unnecessary (unless you are gaming).',
#  'Plus it is small and reasonably light so I can take it with me to and from work.',
#  'I HATE this one.',
#  'They were totally unconcerned that the computer was not correctly repaired in the first place.',
#  'Toshiba does not send any one out unless you have paid extra to have the on site repair done.',
#  'Oh, boy!',
#  'But while this is one big advantage (as you may know from the company s recent commercials) there are other things to consider before going with Apple.',
#  'I love the way the entire suite of software works together.',
#  'The speed is incredible and I am more than satisfied.',
#  'on the bright side at least I was not without my laptop for long this time!',
#  'This laptop meets every expectation and Windows 7 is great!',
#  'that has / that is how frustrating it was.',
#  'I can barely use any usb devices because they will not stay connected properly.',
#  'The one down side to it is that when I play a certin game on here, it tends to freeze up sometimes, but thats the only bad thing about this computer.',
#  '-No backlit keyboard, but not an issue for me.',
#  'When I finally had everything running with all my software installed I plugged in my droid to recharge and the system crashed.',
#  'I cannot even turn it off.',
#  'One suggestion I do have, is to not bother getting Microsoft office for the mac expecting it will work just like you knew it to on a PC.',
#  'Pairing it with an iPhone is a pure pleasure - talk about painless syncing - used to take me forever - now it has / it is a snap.',
#  'I shopped around before buying.',
#  'I also got the added bonus of a 30" HD Monitor, which really helps to extend my screen and keep my eyes fresh!',
#  'Would do business again.',
#  'The machine is slow to boot up and occasionally crashes completely.',
#  'After paying several hundred dollars for this service, it is frustrating that you cannot get help after hours.',
#  'I have had the luxury (sarcasm) of owning 2 of these laptops.',
#  'What a waste.',
#  'It was a total Dhell experience that I will never repeat.',
#  'There are a few flaws as well that I noticed.',
#  'Completely worth every single penny dime and nickel.',
#  'I tried to upgrade it to a newer version a couple of months ago and I still have the same problem.',
#  'I did have to replace the battery once, but that was only a couple months ago and it has / it is been working perfect ever since.',
#  ':) In the past four years I have had it I have never once gotten a virus.',
#  'I love the operating system and the preloaded software.',
#  'They were great in handling this problem, and I am looking forward in purchasing additonal products from them in the future.',
#  'I have tried going back to XL but there still problems.',
#  'The best thing about this laptop is the price along with some of the newer features.',
#  'After numerous attempts of trying (including setting the clock in BIOS setup directly), I gave up(I am a techie).',
#  'YOU WILL NOT BE ABLE TO TALK TO AN AMERICAN WARRANTY SERVICE IS OUT OF COUNTRY.',
#  'But it may be potentially hundreds or thousands in the near future.',
#  'Has met or exceeded my needs for a compact travel device.',
#  'but now i have realized its a problem with this brand.',
#  'It cannot save the correct date and time I set.',
#  'I sent it back to Toshiba twice they covered it under the  warranty.',
#  'And this is not just my one experine.',
#  'They sent me a replacement part and without informing me are requiring that I return it within 15 days or contact them and let them know the broken part will be returned later.',
#  'I was looking for a mac which is portable and has all the features that I was looking for.',
#  'I would highly recommend this one to my friends',
#  'I honestly love my mac, thats why I am a self proclaimed mac addict.',
#  'And these are some reasons you should get a macbook pro.',
#  'Also kinda loud when the fan was running.',
#  'In desparation, I called their Customer Service number and was told that my warranty had expired (2 days old) and that the priviledge of talking to a technician would cost me ("have your credit card ready").',
#  'I purchased this laptop while on a business trip to keep up with my email.',
#  'There also seemed to be a problem with the hard disc as certain times windows loads but claims to not be able to find any drivers or files.',
#  'Drivers updated ok but the BIOS update froze the system up and the computer shut down.',
#  '-they lost my laptop for a month',
#  'Spent 2 hours on phone with HP Technical Support.',
#  'This is my second laptop,and it is head and shoulders above my first.',
#  'at first!',
#  'Speaking of the browser, it too has problems.',
#  'I think just going from PC to Mac has gotten me totally spoiled and I cannot imagine ever going back.',
#  'The keyboard is too slick.',
#  'Nightly my computer defrags itself and runs a virus scan.',
#  'it has / it is like 9 punds, but if you can look past it, it has / it is GREAT!',
#  'it has / it is just as fast with one program open as it is with sixteen open.',
#  'Still under warrenty so called Toshiba, no help at all.',
#  'I was happy with My purchase of a Toshiba Satellite L305D-S5934 laptop until it came time to have it repaired under the Toshiba Warranty.',
#  'I LOVE IT!',
#  'Amazing Quality!',
#  'The fact that you can spend over $100 on just a webcam underscores the value of this machine.',
#  'I mainly use it for email, internet, and managing personal files (pics, vids, etc.).',
#  'A month or so ago, the freaking motherboard just died.',
#  'The system it comes with does not work properly, so when trying to fix the problems with it it started not working at all.',
#  'Then after 4 or so months the charger stopped working so I was forced to go out and buy new hardware just to keep this computer running.',
#  'I took it back to Best Buy where they were so helpful and immediately gave me a new one.',
#  'If you had PC for four years I can almost gaurentee that something would of gone wrong by now, maybe even forcing you to replace your entire computer.',
#  '*2 weeks after giving the computer for repair*-Called headquarters, they report that they have not looked at it yet but it is "on the top of the stack".',
#  'This machine delivers.',
#  'Then 2 of my nephews were going into music and both fell in love with the MacBook Pro.',
#  'I complain again...',
#  'This laptop is insane!!!',
#  'If a website ever freezes (which is rare), its really easy to force quit.',
#  'It does run a little warm but that is a negligible concern.',
#  'It rarely works and when it does it has / it is incredibly slow.',
#  'I also enjoy the fact that my MacBook Pro laptop allows me to run Windows 7 on it by using the VMWare program.',
#  'it has / it is so much easier to navigate through the operating system, to find files, and it runs a lot faster!',
#  'Purchased a Toshiba Lap top it worked good until just after the warrenty went out.',
#  'I always swore by PCs and would never consider a MAC.',
#  'what an elegant, wonderful machine.',
#  'This is now my 3rd MacBook Pro and I really honestly love it!',
#  'for 2 months.',
#  'I wanted to purchase the extended warranty and they refused, because they knew it was trouble.',
#  'Do you ever think HP would do that? NEVER!',
#  'We upgraded the memory to four gigabytes in order to take advantage of the performace increase in speed.',
#  'it has / it is not like I have used for half a year and then complained about it.',
#  'Still trying to learn how to use it.',
#  'The reality was, it heated up very quickly, and took way too long to do simple things, like opening my Documents folder.',
#  'I bought the netbook because it was smaller and lighter for me to carry around.',
#  'The Genius at the Apple store advised me that there was nothing about my use of the computer that caused this failure.',
#  'we will save our money to replace it with a Mac again!',
#  'Thank you for your great product!',
#  'this company truely does make horrible products and doesnt seem to because they are certain things like this "never" happen...',
#  'I had always used PCs and been constantly frustrated by the crashing and the poorly designed operating systems that were never very intuitive.',
#  'Sorry Toshiba, but 1st impressions do count for something.',
#  'Then, within 5 months, the charger crapped out on me.',
#  'And if you have a iphone or ipod touch you can connect and download songs to it at high speed.',
#  'Overall this laptop is great.',
#  'I love the glass touchpad.',
#  u'\xa0 I continued to take the computer in AGAIN and they replaced the hard drive and mother board yet again.',
#  'I am using the external speaker- sound is good.',
#  'The Apple MC371LL/A 2.4Ghz 15.4-inch MacBook Pro Notebook is a horrible waste of money.',
#  'Ok, this is probably the best laptop series ever devised by Apple.',
#  'As of a couple weeks ago the middle portion of the laptop from top to bottom,,,about 4 inches across is hardly visible.',
#  'still testing the battery life as i thought it would be better, but am very happy with the upgrade.',
#  'Then HP sends it back to me with the hardware screwed up, not able to connect.',
#  'I just hope the reputation that Toshiba has is true and I will not have to worry about a crash.',
#  'Oh yeah, do not forget the expensive shipping to and from HP.',
#  'I would recommend anyone to buy from pcconnection express.',
#  'Good luck.',
#  'Everything is so easy to use, Mac software is just so much simpler than Microsoft software.',
#  u'\xa0 My favorite by far, although the most expensive, was my Sony.',
#  'And if you do a lot of writing, editing is a problem since there is no  forward delete  key.',
#  'Also I typed faster then then letters would show and it got to be realy annoying.',
#  'As an owner of a Toshiba Satalite laptop computer things you should know before you buy.',
#  'Its ease of use and the top service from Apple- be it their phone assistance or bellying up to the genius bar- cannot be beat.',
#  'It has a 10 hour battery life when you are doing web browsing and word editing, making it perfect for the classroom or office, and in terms of gaming and movie playing it shall / it will have a battery life of just over 5 hours.',
#  'I shipped out on Saturday, July 17.',
#  'I bought it for really cheap also and it has / it is AMAZING.',
#  'Acer has set me up with FREE recovery discs, when they are available since I asked.',
#  'I also purchased Office Max\'s "Max Assurance" with the "no lemon" clause.',
#  'If you find yourself in the market for a new laptop (and have the money) do not exclude looking at the MBPs.',
#  'I eventually did the migration from my iMac backup disc which uses USB.',
#  'Those things are very important - vital even!',
#  '-They say it will take "up to two weeks".',
#  'I did not like one thing about it.',
#  'The battery life seems to be very good, and have had no issues with it.',
#  'Enabling the battery timer is useless.',
#  'Temperatures on the outside were alright but i did not track in Core Processing Unit temperatures.',
#  'Yeah, to you.',
#  'I got a mac as my HS graduation gift.',
#  'I have now had it for 1.5 months and love it.',
#  'It turned out it has / it is not really a problem to have a Mac.',
#  'Page just disapeared after you got yahoo or downloaded something.',
#  'Images can be multi-selected and viewed swiftly or in slideshow mode.',
#  'Going to bring it to service today.',
#  'There is no need to purchase virus protection for Mac, which saves me a lot of time and money.',
#  'But we had paid for bluetooth, and there was none.',
#  'So, I paid a visit to LG notebook service center at Alexandra Road, hoping they can make the hinge tighter.',
#  'My daughter uses it for games, email, facebook, pictures and music.',
#  'Laptop is to be used like a Netbook.',
#  'It is always reliable, never bugged and responds well.',
#  'After about a week I finally got it back and was told that the motherboard had failed and so they installed a new motherboard.',
#  'Trying to balance all of my roles leaves very little time for me to do anything, so I want to manage my time I do have to be the most efficient.',
#  'It was slow, locked up, and also had hardware replaced after only 2 months!',
#  'they had to replace the motherboard in April',
#  'Yes, the computer was light weight, less expensive than the average laptop, and was pretty self explantory in use.',
#  'Also, if you need to talk to a representive at Microsoft, there is a charge, which I believe is robbery, since you are charged enormous amounts for a very badly designed system, which most people would have went with XP if they could.',
#  'There is a little indent to help open it - but good luck with that.',
#  'I love WIndows 7 which is a vast improvment over Vista.',
#  u'\xa0 Also, I have alot of trouble with it getting very hot, and not even sitting on anything to make it hot.',
#  'It Was a great deal after all.',
#  'This mac is great!',
#  'Keyboard is great, very quiet for all the typing that I do.',
#  'I grew up in a design family so it only made sense.',
#  'Gave phonenumber.',
#  'It would take up too much time to do reaearch for my papers and I would be up hours-just because the computer was too slow.',
#  'Oh my goodness-I am not a happy camper.',
#  "Dell's customer disservice is an insult to it has / it is customers who pay good money for shoddy products.",
#  'I had / I would recommend this laptop to anyone!',
#  'Yet, HP will not do anything about the problem.',
#  'I am returning mine',
#  'It had a cooling system malfunction after 10 minutes of general use, and would not move past this error.',
#  "I can render AVCHD movies with little effort, which was a problem for most pc's unless you had a quad core I7.",
#  'it has / it is a bummer and one out of five is being kind.',
#  'This is what they told me: It heats up, and that is the reason we no longer call them laptops, and simply categorize them as portables.',
#  'After talking it over with the very knowledgeable sales associate, I chose the MacBook Pro over the white MacBook.',
#  'If you really want a bang-up system and do not need to run Windows applications, go with an Apple;',
#  'You will not have to spend gobs of money on some inefficient virus program that needs to be updated every month and that constantly drains your wallet.',
#  'This laptop is fast and you will literally learn all you can do with this dynamo by just watching the online tutorials.',
#  'One of them seems to have worked.',
#  'Which I still use and have hooked up to my TV.',
#  'The problem I had with this unit was unresolvable.',
#  'It weighed like seven pounds or something like that.',
#  '2 months later, the battery went.',
#  'You may need to special order a bag.',
#  'it has / it is color is even cool.',
#  'and it has blue screen crashed on me twice.',
#  u'\xa0 Another two weeks later and it was back in my possession.',
#  'keys are all in weird places and is way too large for the way it is designed.',
#  'I have owned every "Pro" model Apple laptop for the last 8 years, this is BY FAR the WORST one I have ever had.',
#  'We purchase the Dell XPS several years ago for my home business.',
#  'Have purchased many products over the years from MacConnection and this transaction, like all the others, we smoothly with no problems.',
#  'I would recommend anyone to buy from pcconnection express.',
#  'Yes, a Mac is much more money than the average laptop out there, but there is no comparison in style, speed and just cool factor.',
#  'He gave me this PC about 3 years ago and up to this point im still sitting here using it.',
#  'I am pleased.',
#  'The keyboard feels good and I type just fine on it.',
#  'With a healthy pessimism, I took the machine home and tried to find a flaw.',
#  'Shiny  This Laptop is the Best of the best!',
#  'I thought the white Mac computers looked dirty too quicly where you use the mousepad and where you place your hands when typing.',
#  'And not to mention after using it for a few months or so, the battery will slowly less and less hold a charge until you cannot leave it unplugged for more than 5 minutes without the thing dying.',
#  'do not waste their money, save it and but a mac.',
#  'Money and time well spent!',
#  u'\xa0 Gradually the freezing screen evolved into a screen that froze in weird shapes.',
#  'BEST BUY - 5 STARS + + + (sales, service, respect for old men who are not / am not familiar with the technology) DELL COMPUTERS - 3 stars DELL SUPPORT - owes a me a couple',
#  'Good laptop for the money.',
#  'I like the laptop overall.',
#  'I now travel with this laptop and my work PC.',
#  u'\xa0 I am however pleased that it is still hanging in there.',
#  'Both my husband and I have this model Toshiba.',
#  'no complaints with their desktop, and maybe because it just sits on your desktop, and you do not carry it around, which could jar the hard drive, or the motherboard.',
#  'Yes, they cost more, but they more than make up for it in speed, construction quality, and longevity.',
#  'Since I keyboard over 100 wpm, I look for a unit that has a comfortble keyboard (no keys sticking or lagging, strange configuration of "extra key", etc.',
#  ') I also tried the touch pad and compared it to other netbooks in the store.',
#  'It absolutely is more expensive than most PC laptops, but the ease of use, security, and minimal problems that have arisen make it well worth the pricetag.',
#  u'\xa0 It gets stuck all of the time you use it, and you have to keep tapping on it to get it to work.',
#  'lots of preloaded software.',
#  u'\xa0 Sony, Acer, Dell, Packard Bell and Toshiba.',
#  'and then, a guy came out to serve me instead.',
#  'Breaking within 1 year of purchase and speaking to 4+ people to report the damaged part will be returned late!',
#  'Have returned that laptop unused.',
#  u'\xa0 Will probably never buy a HP again.',
#  'I got tired of buying laptops and having them stop working after a year.',
#  'I should have been more observant.',
#  'I wish it had a webcam though, then it would be perfect!',
#  'My favorite part of this computer is that it has a vga port so I can connect it to a bigger screen.',
#  'Another thing I might add is the battery life is excellent.',
#  'One drawback, I wish the keys were backlit.',
#  'When the buyer returned it Wal Mart just boxed it, taped it shut  resold it as new.',
#  'What a great little laptop.',
#  'Acer was no help and Garmin could not determine the problem(after spending about 2 hours with me), so I returned it and purchased a Toshiba R700 that seems even nicer and I was able to load all of my software with no problem.',
#  'I wish the volume could be louder and the mouse didnt break after only a month.',
#  'I play a lot of casual games online, and the touchpad is very responsive.',
#  'Granted, it has / it is still a very new laptop but in comparison to my previous laptops and desktops, my Mac boots up noticeably quicker.',
#  'It caught a virus that completely wiped out my hard drive in a matter of hours.',
#  'WOULD PAY MORE FOR IT IF I HAD TOO!',
#  'could not keep a page up you were working on!',
#  'It is everything I had / I would hoped it would be from a look and feel standpoint, but somehow a bit more sturdy.',
#  'the only fact i dont like about apples is they generally use safari and i dont use safari but after i install Mozzilla firfox i love every single bit about it.',
#  'The Bluetooth was not there at all, and the fingerprint reader driver would be there, but the software would hang after installation was 1/2 way done.',
#  'Great battery, speed, display.',
#  'I would not recommend this product to anyone.',
#  'I like to use it at the race track to handiecap the horse races.',
#  'I was given a Mac as a birthday present and could not be happier with it 3 years later.',
#  'The delivery was fast, and I would not hesitate to purchase this laptop again.',
#  'I have been impressed with the battery life and the performance for such a small amount of memory.',
#  'do a quick search on the internet see if im the only one.',
#  'I am extremely happy with my purchase as I now have the portable power I have been looking for.',
#  'it has / it is applications are terrific, including the replacements for Microsoft office.',
#  'they improved nothing else such as Resolution, appearance, cooling system, graphics card, etc.',
#  'I got it back and my built-in webcam and built-in mic were shorting out anytime I touched the lid, (mind you this was my means of communication with my fiance who was deployed) but I suffered thru it and would constandly have to reset the computer to be able to use my cam and mic anytime they went out.',
#  'Is this partially due to the fact that it is running Windows Vista?',
#  'You might think, I am new in this game, but I am a gadget lover, and have had more than 2 dozens laptops in the past 15 years, and none gets this hot, that fast.',
#  'I was informed that I need to call some 0900 number first.',
#  'I really wanted a Mac over a pc because I used a Mac in high school.',
#  '1) Payed $2200 for a "premium" laptop',
#  'I BOUGHT THEM FOR MY COLLEGE AGE GRANDCHILDREN AND THESE MACS ARE TOTALLY RELIABLE AND SUPPORT THEIR CLASS WORK 100% OF THE TIME.',
#  u'\xa0 The board has a bad connector with the power supply and shortly after warrenty expires the power supply will start having issues.',
#  'Do not purchase this laptop.',
#  'My dad has one of the very first Toshibas ever made, yes its abit slow now but still works well and i hooked to my ethernet!',
#  'Mostly I love the drag and drop feature.',
#  'oh yeah, and if the fancy webcam breaks guess who you have to send it to to get it fixed?',
#  'She brought out 2 other identical netbooks and still insist that "It is like that one".',
#  'I ordered through MacMall, which saved me the sales tax I would have incurred buying locally.',
#  'Very fast and efficient!',
#  'Of course, I also have several great software packages that came for free including iWork, GarageBand, and iMovie.',
#  'Being virus-resistant is a huge plus.',
#  'The screen is very large and crystal clear with amazing colors and resolution.',
#  'After a little more than a year of owning my MacBook Pro, the monitor has completely died.',
#  'In my house, HP is a nasty word.',
#  'The brand of iTunes has just become ingrained in our lexicon now, but keep in mind that Apple started it all.',
#  'By the way teachers, they offer a discount which helps!',
#  'now he mows yards so he can earn the money for the wireless internet.',
#  'I still see the benefits of a PC when I do not know how to do something on my mac.',
#  'Size: I know 13 is small (especially for a desktop replacement) but with an external monitor, who cares.',
#  "Additional caveat: the base installation comes with some Toshiba-specific software that may or may not be to a user's liking.",
#  'It is held in place magnetically.',
#  u'\xa0 Taking it back to Best Buy I found that a tiny plastic piece inside had broken (manuf issue).',
#  'It has no camera but, I can always buy and install one easy.',
#  'The display is incredibly bright, much brighter than my PowerBook and very crisp.',
#  'We were PC users.',
#  'The AMD Turin processor seems to always perform so much better than Intel.',
#  u'\xa0 After that the said it was under warranty.',
#  'The start menu is not the easiest thing to navigate due to the stacking.',
#  'Only thing I would want to add to this is an internal bluray read/write drive.',
#  'This computer was awful, I would never recomend it to another person.',
#  'The service tech said he had tried to duplicate the damage and was not able to recreate it therefore it had to be their defect.',
#  'The tech store I purchased this from sent it back,,,,,eventually I got a new or repaired machine approximately 3 weeks later.',
#  'I loved it then, but unfortunately it was before the days of wireless internet.',
#  'Really like the textured surface which shows no fingerprints.',
#  'I WILL NEVER AGAIN buy another Acer, not will I buy Gateway, or eMachine as they are all from the same company.',
#  'The screen is bright and the keyboard is nice;',
#  'I look forward to years of use, it has held up well over the years and it fits my needs very well.',
#  'Im very happy with this computer!',
#  'But the machine is awesome and iLife is great and I love Snow Leopard X.',
#  'High price tag, however.',
#  'I thought learning the Mac OS would be hard, but it is easily picked up if you are familiar with a PC.',
#  'My kids have to take their PCs in once a year to have them "de-bugged".',
#  'I had static in the output, and I had to reduce the sound output quality to "FM" as opposed to the default "CD.',
#  u'It was a laugh\xa0 too!',
#  'Since I purchased my Toshiba netbook, I have been very pleased with it, I have a laptob and a desktop.',
#  'I bought my macbook a few months ago and it has been my baby ever since.',
#  'That is how it is able to function better than any other PC.',
#  'I custom ordered the machine from HP and could NOT understand the techie due to his accent.',
#  'It is easy to use and lightweight.',
#  'I went to Toshiba online help and found some suggestions to fix it.',
#  'It is a bit heavy.',
#  u'\xa0 after trying to get some help he disconnected on me.',
#  'They also have a longer service life than other computers (I have several friends who still use the older Apple PowerBooks).',
#  'If you check you will find the same notebook with the above missing ports and a dual core AMD or Intel processor.',
#  'This laptop is a great price and has a sleek look.',
#  'I especially like the keyboard which has chiclet type keys.',
#  'Small screen somewhat limiting but great for travel.',
#  'One of the primary reasons why I purchased an IPad was to store photographs so that I could show to my customers.',
#  'Runs Hot  I thought we were paying for quality in our decision to buy an Apple product.',
#  'For the not so good, I got the stock screen - which is VERY glossy.',
#  'The gray color was a good choice.',
#  'This was the second computer and brand bought that day.',
#  'Buy this.',
#  'VERY disappointing:',
#  'I love this product because it is Toshiba and its 15.6".',
#  'I would like to have volume buttons rather than the adjustment that is on the front.',
#  'This is my first computer purchase',
#  'People know what they are talking about and they have pride in the product that they are selling.',
#  'The processor a AMD Semprom at 2.1 ghz is a bummer it does not have the power for HD or heavy computing.',
#  'Would HIGHLY recommend this netbook though.',
#  'I have had several machines over the years, both for personal and business use.',
#  'I bought a protector for my key pad and it works great :)',
#  'The magnetic plug-in power charging power cord is great (I even put it to the test by accident)- excellent innovation!',
#  'Well i got this computer from Best Buy and I have had nothing but problems I bought the computer with a virus.....',
#  'It seems they could have updated XP and done without creating Vista.',
#  u'\xa0 It is easy to use, fast and has great graphics for the money.',
#  'I decided I wanted a laptop so I went into the BBY store.',
#  'I like how the Mac OS is so simple and easy to use.',
#  "While Apple's saving grace is the fact that they at least stand behind their products, and their support is great, it would be nice if their products were more reliable to justify the premium.",
#  'In the three years I have had my MacBook Pro, I have never had a virus on my computer, and I do a lot of work on the internet.',
#  'I was ready to take it back for a refund, but the Geek Squad camed through and pointed me in the right direction to get it fixed.',
#  'I have had laptops in the past and I thought why not give these small netbooks a try.',
#  'It cannot get any better.',
#  "All the problems I have had with PC's are solved with a Mac: the issue of overheating-my Dell was always overheating and not working properly or simply shutting off, and the issue of viruses and contaminants-my HP completely quit working within2 years of purchasing it, with no inexpensive way of fixing it.",
#  'only good thing is the graphics quality.',
#  'The other lock-up problems are from a myriad of causes, the most common being a corrupted version of Appleworks which can render the browser useless.',
#  'In short I would never buy a Compaq again.',
#  'I love the 15" MacBook Pro.',
#  'breaks easily.',
#  'The paint wears off easily due to the keyboard being farther back than usual.',
#  'that has / that is right, no power, absolutely NOTHING.',
#  'I had purchased it from a major electronics store and took it to their service department to find out what the problem was.',
#  'The store honored their warrenty and made the comment that they do not even recommend the HP brand because of the problems with their warrentys.',
#  'But I was wrong.',
#  'NO good.',
#  'I always use a backup hard disk to store important files at all times.',
#  'They sent out the box right away for me to send in my computer, they paid postage and whatnot, but when I got my computer back it still was not running right, and now my CD drive was not reading anything!',
#  'I bought this laptop Was the worst Laptop I have ever bought.',
#  'But the screen size is not that bad for email and web browsing.',
#  'Once I removed all the software the laptop loads in 15-20 seconds.',
#  'On my PowerBook G4 I would never use the trackpad I would use an external mouse because I did not like the trackpad.',
#  'This computer does not do that well with certain games it cannot play some and it becomes too hot while playing games.',
#  'Obviously one of the most important features of any computer is the "human interface.',
#  'Yeah, of course smarty pants "fix it now")Software - Compared to the early 2011 edition I did see inbuilt applications crashing and it prompted me to send the report to Apple (which I promptly did).',
#  'The body is a bit cheaply made so it will be interesting to see how long it holds up.',
#  'The i5 blows my desktop out of the water when it comes to rendering videos.',
#  'With a mac you do not have to worry about antivirus software or firewall, it has / it is so wonderful.',
#  'For the use it was purchased for it is a good Laptop.',
#  'Am very glad I bought it, great netbook, low price.',
#  'Obviously, this Macbook is P-E-R-F-E-C-T for me because it does exactly what I need in an easy-to-function way.',
#  'Worth the investment and truly a fine piece of equipment.',
#  'The Apple team also assists you very nicely when choosing which computer is right for you :)',
#  'Summary: Dont buy HP.',
#  'I think part of the problem with this computer is Vista, yet I know Vista is not the entire issue because my latest purchase was my Acer and it also has Vista (I should have waited the few months to get the next operating system).',
#  'The video chat is the only thing that is iffy about it but im sure once they unpdate the next version on the macbook book the quality of it will be better.',
#  'you shall / you will need to upgrade and pay a little more for them.',
#  'it is hard to fix and makes it a hassle to own one.',
#  'That whole experience was just ridiculous we sent it in and after they told us that we had to pay $175 to fix it we were like we will just by a portable mouse which would be way cheaper but they refused to send the laptop back until we paid the $175 and it was fixed.',
#  'Macs are designed for the "frontal lobe challenged" people out there.',
#  'Fan vents to the side, so no cooling pad needed, great feature!',
#  'i use my mac all the time, i love the software, the way it takes a short time to load things, how easy it is to use and most of all how you do not have to worry about viruses.',
#  'Wasted me at least 8 hours of installation time.',
#  'It has far exceeded my expectations for power, storage, and abilitiy.',
#  'A great feature is the spotlight search: one can search for documents by simply typing a keyword, rather than parsing tens of file folders for a document.',
#  'My wireless system would not recognize Windows 7 and I could not get online to find out why.',
#  'I am enjoying it and the quality it provides is great!',
#  'It is the worst laptop ever',
#  'Suffice it to say, my MacBook Pro keeps me going with its long battery life and blazing speed.',
#  'I am not going to lie, I have never really liked the Acer brand in general.',
#  'The OS is also very user friendly, even for those that switch from a PC, with a little practice you can take full advantage of this OS!',
#  'iTunes is a handy music-management program, and it is essential for anyone with an iPod.',
#  '-I give up on my data, I just want a computer reasonably fast...',
#  'Would buy 100 more of these if I could.',
#  u'\xa0 while it was barely a bargin in the begining, i would never purchase another dell and would not recomend the dell brand to others.',
#  'it was shooting sparks!',
#  'Great product.',
#  'Mac is not made for gaming.',
#  'Well I spilled something on it and they replaced it with this model, which gets hot and the battery does not make it through 1 DVD.',
#  'I have had to call Apple support to set up my new printer and have had wonderful experiences with helpful, english speaking (from Vancouver) techs that walked me through the processes to help me.',
#  'But Sony said we could send it back and be charged for adding the bluetooth an additional seventy something dollars.',
#  u'\xa0 By this time I was regretting ever SEEING this machine on the shelf!',
#  'Toshiba is a great brand, even though I have not had it for a long time, I am very happy with it!',
#  'I need graphic power to run my Adobe Creative apps efficiently.',
#  'the programs are esay to use and are quick to process this computer works like a charm.',
#  'The materials that came with the computer did not include the right # anywhere.',
#  'So when you do call to complain about the hunk of metal you get the joy of speaking with a bunch of people you cant understand.',
#  'That day!',
#  '" For one, I noticed that from turning on my mac to logging on only took about 25 seconds.',
#  'It does not even have the software to play a dvd now.',
#  'My brother is a computer wiz and would laugh at me because he used an Apple.',
#  'Tech support tells me the latter problem is a power supply problem and have offered to fix it if it happens again.',
#  'Since I never really got to use this, I cannot comment on anything except what went wrong after trying 2 of them.',
#  'Buyers beware.',
#  'HOW DOES THE POWER SUPPLY NOT WORK!!!',
#  'Sells for the same as a netbook without sacrificing size.',
#  u'\xa0 I shall / I will rather be out of date then spend more money on toshiba.',
#  u'\xa0 upon giving them the serial number the first thing I was told, was that it was out of warranty and I could pay to have it repaired.',
#  'Windows XP SP2 caused many problems on the computer, so I had to remove it.',
#  'Love it.',
#  'I reloaded with Windows 7 Ultimate, and the Bluetooth and Fingerprint reader (software) would not load.',
#  'None of the techs at HP knew what they were doing.',
#  'Oh, it is such a great piece of equipment.',
#  'this is my second one and the same problem, bad video card  unreliable overall, this will be my second time returning this laptop back to best buy.',
#  'I use that alot on my desktop, so I am adjusting to not having it.',
#  'With awesome graphics and assuring security, it has / it is perfect!',
#  'Laptop was in new condition and operational, but for the audio problem when 1st sent for repair.',
#  'I was disappointed when I realized that the keyboard does not light up on this model.',
#  'This machine was a horrible experience.',
#  'It runs perfectly.',
#  'Very dissappointed becase I have had toshibas for years, and never a issue.',
#  'If you have any creativity in you do yourself a favor and get a mac!',
#  'The laptop was very easy to set up.',
#  'Congratulations Asus for creating one big piece of dump which is my laptop.',
#  u'\xa0 Sometimes the screen even goes black on this computer.',
#  'I would definitely recommend checking out this laptop if you are in the market for one.',
#  'I recommend for word processing and internet users.',
#  'Since I have had this computer I have only used the trackpad because it is so nice and smooth.',
#  u'\xa0 When the computer has been on for several minutes, it will occasionaly just go off by itself.',
#  'A longer battery life would have been great - but it meets it has / it is spec quite easily.',
#  'Who could not love a DVD burner, 80-gigabyte HD, and fairly new graphics chip? As I soon discovered, though, there is a reason for which similarly-configured Sony and Toshiba machines cost more: they use higher-quality components that are faster, better-configured, and end up lasting a lot longer.',
#  'falls into the case.',
#  'This is something i would deffinately reccomend to someone.',
#  'Its fast and another thing I like is that it has three USB ports.',
#  'Mac computers automatically "defrag" each time you start your computer.',
#  'That is my only complaint!',
#  'The salesman talked us into this computer away from another we were looking at and we have had nothing but problems with software problems and just not happy with it.',
#  'That system is fixed.',
#  'The computer itself was fast, ran smoothly, and had no problems.',
#  'One of the smartest thing I did was take my time to compare laptops before making my purchase.',
#  'Like the price and operation.',
#  'The brand is tarnished in my heart.',
#  'This is likely due to poor grounding and isolation between the components, and I am hoping that it can be fixed with a ground loop isolator, but I still expected better product quality for this price range.',
#  'Honestly, this is absolutely wonderful.',
#  "I 'have had it for about a 1 1/2 and yes I have had an issue with it one month out of warranty.",
#  'I really wish I had done this years ago.',
#  'Well, maybe I was just very unlucky.',
#  'For example, when my husband turns the light out while I am on the computer.',
#  'Once open, the leading edge is razor sharp.',
#  'Loaded with bloatware.',
#  'If you buy, pray you dont have major prolems.',
#  'do not get me wrong, I am no Microsoft hater, I have just managed to turn into a much bigger Apple fan because of this machine.',
#  'HP refused to give me a new one and Wal Mart refused to take it back.',
#  'Within 3 weeks the same issues started happening AGAIN.',
#  'Maximum sound is not nearly as loud as it should be.',
#  'Well, they do not care a bunch.',
#  'I loaded windows 7 via Bootcamp and it works flawlessly!',
#  'I have never had to shut down the computer unexpectedly and the computer has never froze on me.',
#  'Great Laptop for the price, works well with action pack games.',
#  'Although the price is higher then Dell laptops, the Macbooks are worth the dough.',
#  'Recommended to people as their first laptop.',
#  'I would recomend this acer to parents and grandparents it can really help them in school.',
#  'I would not recommend this to anyone wanting a notebook expecting the performance of a Desktop it does not meet the expectations.',
#  'The Macbook arrived in a nice twin packing and sealed in the box, all the functions works great.',
#  'So what if the laptops/mobile phones look chic and cool? The after sales support is terrible.',
#  'they have not sent a new one nor called.',
#  'I would easly reccomend this laptop to a friend.',
#  'I hate the display screen and I have done everything I could do the change it.',
#  'I spent alot of money on this product and its been a nightmare.',
#  'I also like the acer arcade but these were reallythe only two things I liked about this laptop.',
#  'Have not yet needed any customer support with this yet so to me that is a great thing, which is leaps and bounds ahead of PC in my opinion.',
#  'Thinking about returning it',
#  "I gave it to my daughter because I just hated the screen, hated that it had no cd drive to at least play cd's when I wanted to listen to music and do schoolwork.",
#  'It runs very quiet too which is a plus.',
#  'but it  has a major design flaw.',
#  u'\xa0 I took the laptop home and not even a month later, I began to have problems with it.',
#  'It was heavy,bulky, and hard to carry because of the size.',
#  'That was my first Apple product and since then I have been incredibly happy with every product of theirs I have bought.',
#  'i tried turning it done but it did nothing.',
#  'It is super fast, and always loads.',
#  'The games included are very good games.',
#  'this computer will last you at least 7 years, thats an amazing life spanned an electronic.',
#  'I bought mine from Apple Store the day it was released as Amazon did not have it yet.',
#  'I had something else go wrong and they said it had to be in good working order to be able to buy the warranty.',
#  'the whole experiece is horrible so save up and buy a better laptop.',
#  'I just bought this laptop 3 days ago.',
#  'I am very pleased with my purchase!',
#  'Sometimes you really have to tap the pad to get it to worki',
#  'it has / it is super fast and a great value for the price!',
#  "Three, the mac book has advantages over pcs' with linux based os there is very 'few problems with system performance when it comes to a mac.",
#  'A mac is very easy to use and it simply makes sense.',
#  "Of course, eMachines cannot be made entirely to blame for this computer's woes;",
#  'however, I may have inadvertently thrown out one of the batteries with the shipping carton.',
#  'Love it so far.',
#  'It is so much easier to use',
#  'There is no need to open a program first and the cliick open or import.',
#  'In short, you could say your mac could become your best friend (no intention of replacing Rover your dog).',
#  'It was a bad experience but i played down its importance.',
#  'Meets my needs perfectly and is light enough for this senior to carry without affecting my arthritis.',
#  "It is so nice not to worry about that and the extra expense that comes along with the necessary virus protection on PC's.",
#  'The Notebook PC,Toshiba Qosmio is the best gift my father could have ever gotten me.',
#  'Three weeks after I bought the netbook, the screen quit working.',
#  'The processor screams, and because of the unique way that Apple OSX 16 functions, most of the graphics are routed through the hardware rather than the software.',
#  'I am currently out of town and called to inform them the broken part would be returned when I got back in town.',
#  'Returned laptop for a 4th repair and it came back but now would lock up and randomly reboot frequently making the laptop unusable.',
#  'I wanted something that had a new Intel Core processors and HDMI port so that we could hook it up directly to our TV.',
#  'The Apple will run Internet Explorer, but at an amazingly slow rate.',
#  "With today's company fighting over marketshare, its a shame that ASUS can get away with the inept staff answering thephone.",
#  'Other than that I do not have one complaint in the world!',
#  u'\xa0 The computer is so slow, even after paying staples the extra money to speed it up.',
#  'I feel that enough people have Macs these days and that companies need to start making things more compatable than they used to be.',
#  'The price premium is a little much, but when you start looking at the features it is worth the added cash.',
#  '*5 weeks after giving the computer for repair*-Apple offers to send replacement after they receive the old computer.',
#  'I cannot say enough of how satisfied I am with their product and help aftermarket.',
#  'My computer was one of the best in the school compared to my fellow classmates.',
#  'I bought for my son in the 2nd grade.',
#  'This has happened three times so far.',
#  u'\xa0  I am a professional consultant, and a client needed work on her machine.',
#  'compresses itself and you cannot use it.',
#  'Microsoft word was not on it andI had to buy it seperately.',
#  'it has 3 usb ports, 1 sd memory card reader and an sd memory car expansion.',
#  'Who knows what will happen later on when they dismantle the whole damn thing?  So, I said I wanted a new set.',
#  'I connect a LaCie 2Big external drive via the firewire 800 interface, which is useful for Time Machine.',
#  'If you already own a 2009, 2010, or early 2011 model, you should wait until the next update.',
#  'My Toshiba did not have sound on everything, just certain things.',
#  'I am overall very pleased with my toshiba satellite, I like the extra features, I love the windows 7 home premium.',
#  'So, I must say I am not a happy camper.',
#  '-Called MacHouse Amsterdam to ask for a temporary replacement, no answer.',
#  'The Aspire wont even boot past the Acer screen with a Droid (I have tried both Motorola and HTC) plugged into the USB port.',
#  'I bought it during the recent Comex IT show.',
#  'The battery life was shorter than expected.',
#  'It fires up in the morning in less than 30 seconds and I have never had any issues with it freezing.',
#  'It doesnt overheat or make any loud noises.',
#  'Look up recipes and keep it on the kitchen counter while I cook.',
#  'The keyboard is top notch.',
#  'Do you think the shop will give me a new set?? It will NOT!',
#  'I have had nothing but problems since the day I took it out of the box!',
#  'My Macbook was worth (after 3 years of use!) $375.',
#  'It drives me crazy when I want to download a game or something of that nature and I cannot play it because its not compatable with the software.',
#  'The online tutorial videos make it super easy to learn if you have always used a PC.',
#  'Bought this gateway M-50 or 150 early 2007.',
#  'The image is great, and the soud is excelent.',
#  'With a MAC computer I have more free time as I do not have to wait for windows to boot up or shut down and all the viruses associated with windows.',
#  'It was very easy to just pick up and use-- It did not take long to get used to the Mac OS.',
#  'This netbook is a perfect supplementary computer to another laptop or desktop (my wife and I have another laptop), or if you are a user who uses the computer for simple tasks.',
#  'With all the goodies inside this machine, it is a value.',
#  'I took it back for a full refund.',
#  'It is well worth the money it cost, Very good investment.',
# ...
#  'The technical service for dell is so 3rd world it might as well not even bother.',
#  'The graphics were awful and the warranty is not even worth the cheap payment on the computer.',
#  'and if u did.',
#  'I have had the MacBook Pro 15 for about three weeks, and it really is a great computer.',
#  'They gave me a hard time yet again, but their was a malfunction in the battery itself, it did not die.',
#  'It was definelty a smart move.',
#  'I am excited to learn more about what this powerful machine has to offer and encourage others to do the same.',
#  'Apparently they are defective since they are not securely attached.',
#  'but other then that I would give this product a 4 in hafe stars.',
#  'Sure hope Best Buy will replace it asap.',
#  'I babyed the heck out of it and i still do.',
#  'Handles all my basic media needs easily.',
#  'Just what the doctor ordered.',
#  'If you do not feel comfortable doing it yourself, just buy the case and be happy, plus it looks nice, I bought the white one from Best Buy.',
#  'The reaction of Toshiba is there is nothing you can do about it so just sit back and except the fact that you are powerless and it is mind over matter.',
#  'you can find many laptops with the same performance and even better with lower price, but you cannot find the look, easy, applications, and the experience in mac.',
#  'Excellent speed for processing data.',
#  'All in all, I am incredibly dissatisfied with this laptop, and with HP as a whole.',
#  'I am not happy at all with the product I purchased.',
#  'When you call tech support you were routed to someone who was in another country and did not know what they were doing.',
#  'It has come into good use for my finances, scheduling, my parents business expenses, and it is definitely amazing for gaming.',
#  'I was taught to use Photoshop and was amazed.',
#  'it has / it is A MAC!!',
#  'It was weird.',
#  'I can hardly wait to see whats around the next corner.',
#  'the apple pro notebook will not let you down.',
#  '4gb of ram...',
#  'I did a review on it, its awesome.',
#  u'\xa0 Before we got this laptop, had\xa0a\xa0compaq pasaro\xa0for 5 years with no problems.',
#  'I tried out another Mac for a few months before buying this one and it is a great machine.',
#  'Somehow the system clock got messed up after reboot.',
#  'the only problem is that i had to add 1 gb RAM, the computer was kinda slow.',
#  'With the macbook pro it comes with freesecuritysoftware to protect it from viruses and other intrusive things from downloads and internet surfing or emails.',
#  'The computer could have been shipped by Priority Mail through the USPS for the same cost and arrived by Noon on Tue.',
#  'I visited the Apple Store and was impressed with the 17-inch MacBook Pro.',
#  'The driver updates do not fix the issue, very frustrating.',
#  'I will never go back to Windows!',
#  'Do your research on this issue.',
#  'Looking to take my video and photo editing to the next level, I decided to purchase the MBP 15in Intel Core i5 after reading consumer reviews as well as professional reviews of this laptop.',
#  'It doesnt work worth a damn.',
#  'HP Pavilion DV9000 Notebook PC      When I first got this computer, it really rocked.',
#  'It works really well.',
#  'It has happened again and I am being told that it has / it is $175.',
#  'Bigger HD, better graphics card, and a bid HD.',
#  'Lord HAVE MERCY!',
#  'The built in camera is very useful when chatting with other techs in remote buildings on our campus.',
#  'No big deal.',
#  'Mine came at $1,700 w/o a DVD burner (!).',
#  "The DVD burner broke after burning 3 DVD'd during that time!",
#  'It works fine with our wireless and they have had not problems.',
#  'But you must get the 15 inch.',
#  'i will be returning it and switching brands when i get to best buy.',
#  'Product support very poor as each phone call costs me long distan',
#  'Overall the computer is very easy to use, the screen is perfect, great computer, my daughter loves.',
#  u'\xa0 The casing of the power cord fried and shocked my husband when he pulled it out of the socket.',
#  'It does not keep internet signals no matter where you bring it.',
#  'apple is one of the best computer companies in the country.',
#  'PLEASE MAKE THESE!',
#  'Frustrated I hung up and tried to call back 3 days later to be told that it takes 2-3 days for turnaround time.',
#  'After the first few months, the computer started crashing about every week.',
#  'My son and his family have a hard time financially because he is self-employed so the family had no computer of any kind, and kyle the oldest child is 12 and really need something to help him in school.',
#  'it has / it is a great product for a great price!',
#  'Again, the same problem, the right speaker did not work.',
#  'But see the macbook pro is different because it may have a huge price tag but it comes with the full software that you would actually need and most of it has free future updates.',
#  'Before i bought my new i5, I did my research for about 2 weeks and determined to move for HP to Apple for reliability, dependable, and long lasting operations.',
#  'Dell wanted to charge us for everything everytime I called them with a problem.',
#  'THIS HAS BEEN NOTHING BUT A HEADACHE SINCE WE PURCHASED IT.',
#  u'i have\xa0had my dell latitude for almost three years.',
#  'May be better for the occasional web surfer.',
#  'and the multiple page viewer ( allows you to press one button to see every separate page currently opened at the same time in one screen) are great for those who are working non stop or just shopping online.',
#  'This was the 3rd day and part still had not been shipped.',
#  'Obviously we both got new Macs.',
#  'My Iphone synced right up just like a person would expect, unlike the PCs in our lives.',
#  'That being said after 2 weeks of owning every time I start it up now it gives me a black screen for 5-8 seconds stating pxe-e61 media test error check cable.',
#  'it has / it is fun to take to a bookstore, sit in the coffee shop area, sign in to WiFi and look up book reviews of books I might buy.',
#  'Not super fancy, but not super expensive either.',
#  'Keyboard good sized and wasy to use.',
#  'HP said it was out of warranty.',
#  '-Stay away from Apple, or hope you laptop does not break down.',
#  'it has / it is a great prodcut to handle basic computing needs.',
#  'I never had this kind of quality issue with Dell (not to say Dell is that great), not with a brand new laptop.',
#  'wonderful features.',
#  'the laptop was really good and it goes really fast just the way i thought it would of run.',
#  'I had to call HP and ask for a recovery disk because the computer does not come with one and completely redo it all.',
#  'Im glad that it has such great features in it.',
#  'it has / it is just a great toy to have around.',
#  'I like those programs better than Office and you can save your files to be completely compatible with the Office programs as well.',
#  'Great wifi too.',
#  'WHEN TYPING, LETTERS AND SPACES ARE FREQUENTLY OMITTED REQUIRING THE USER TO REDO MANY WORDS AND SENTENCES.',
#  u'\xa0 Only a few days after I received the computer back, the screen froze again.',
#  'It is not ideal for children because of the temp.',
#  'sounds like a typewriter, but if you can get past that, this is a great laptop for a little money!',
#  u'\xa0 When this happened I would have to completely power off my computer and restart it.',
#  'Although i do believe that Windows operating system may be to fault for some of the problems.',
#  'Great OS, fabulous improvements to the existing line bumping up the processor speed and adding the thunderbolt port.',
#  'I or my dad paid over twenty four hundred dollars for everything.',
#  u'\xa0 The lcd screen stopped working on mine after 10 months.',
#  'That includes transferring my music and movies.',
#  'Images are crisp and clean.',
#  'Took that one home, same thing.',
#  'I am going back to PC.',
#  'Great, quick laptop for the money.',
#  'although its windows vista compared to windows xp sucks.',
#  u'\xa0 We have had numerous problems with Vista, such as Adobe Flash player just quits and has to be uninstalled and then reinsalled, Internet Explore just quits and you lose whatever you were working on, also, the same Windows update has appeared on this computer since we got it and has been updated probably 400 times, the same update.',
#  'The Dell mini was the first Dell product that I had ever purchased.',
#  'with the switch being at the top you need to memorize the key combination rather than just flicking a switch.',
#  'My Mac has gone from being a trusted friend to an adversary.',
#  'One more tip, please purchase this model and get a 4GB stick of RAM to save you $10',
#  'By week two, my laptop had overheated and was completely dead even though I did not use it too much.',
#  'And it is impossible to get them back in.',
#  'My last laptop gave me a constant battle even though it was also completely new.',
#  'I have been a mac user since the mid 90s.',
#  'It has bein into the shop to get a new hardrive 2 times and to fix the touch control buttons on the keyboard!',
#  u'\xa0 After the bad experience with this computer went back to compaq.',
#  'Finally after months of research the discovered that they mailed it to a Walmart and there probably would be no way to find the box.',
#  'It does not heat up like my old laptop.',
#  'I always have used a tower home PC and jumped to the laptop and have been very satisfied with its performance.',
#  'it has / it is solid.',
#  'Before I got my macbook, I owned a Dell laptop.',
#  'This laptop is the most amazing little peice of machinery I have owned outside of the Iphone.',
#  'The computer runs very fast with no problems and the iLife software that comes with it (iPhoto, iMovie, iWeb, iTunes, GarageBand) is all very helpful as well.',
#  'At first it worked well for a month or so then the system board failed and I send it in to toshiba some complaints and three weeks later I then receive my laptop back only to discover that it still has the same problem so now I have to send it back again to get it fixed again.',
#  u'\xa0 Until I bought the Dell, I thought you just looked for what you wanted (size, software, options, hardware) and purchase the best deal you could find.',
#  'I do not know how I could ever live without my Qousmio.',
#  'It has plenty of memory, lots of hard drive, and great graphics.',
#  'It did not take me long to get switched over to the Mac computer programs and navigation - it has / it is been just fine and like the way this laptop functions much better.',
#  u'\xa0 It lasted for many years of travel, kids and abuse and if I fired it up today, it would work.',
#  'been a PC user for many, many years.',
#  'I have never had any issues or problems with my MacBook Pro so far, and it is still as fast as it was when I first bought it.',
#  'It freezes, and it always shows that there is an error, so I have to restart it a few times every time I use it.',
#  "However, my girlfriend realized that the netbook's hinge is a bit loose (when you open or close the LCD).",
#  'My problem was with DELL Customer Service.',
#  'There are so many things wrong with this product, it just makes me want to set my self on fire!',
#  u'It is not even a year old yet, so I would\xa0definitely not recommend it to anyone.',
#  'Amazing machine.',
#  'I do not do any high tech stuff on it, just write papers, check mail, and sometimes play games, so I cannot reccomend it if you are in the computer field.',
#  "Newegg's RMA service was great as always, I contacted them late Friday night, and they issued me an RMA number and a PrePaid UPS shipping label the very next morning on Saturday.",
#  'I am very impressed.',
#  'Dell sucks',
#  'Design: very durable.',
#  'It is easy to go from one keyboard to another.',
#  'I spoke to 4 different people and was told they needed to transfer me to a 5th person!',
#  'The Mac Book Pro performs flawlessly.',
#  'Has a 5-6 hour battery life.',
#  'My ONLY issues are: 1) the screen/video resolution will not increase to a higher resolution then 1024 x 60',
#  'I run Dreamweaver, Final Cut Pro 7, Photoshop, Safari, Firefox, MSN Messenger and a few other applications constantly at the same time.',
#  'I have owned many computers and laptops.',
#  'I recently purchased the mini and absolutely love it!',
#  'Does a great job with video shot on a Canon 5D MKII.',
#  u'\xa0 I was told by many  that it was a great computer, but we got one of these, and it worked  great for one year, and as soon as the warrenty was up, then it got  really bad.',
#  'Ive had to call tech support many times.',
#  'The Apple applications (ex.iPhoto) are fun, easy, and really cool to use (unlike the competition)!',
#  'Yes, I have it on the highest available setting.',
#  'Not to mention it has shit gigs.',
#  'Hieroglyphics are quite common.',
#  'This worked just fine.',
#  'I paid for extra memory and the 17-inch screen, as well as the top of the line DVD and CD burners.',
#  'Its pretty fast and does not have hiccups while I am using it for web browsing, uploading photos, watching movies (720p) on occasion and creating presentations.',
#  'I was so happy with my new Mac.',
#  'Quality Display  I love HP,, it has / it is the only computer/printer we will buy.',
#  'Despite the inconvenient weight, I opted for the 12 cell battery.',
#  'My MacBook is faster than any comparable PC.',
#  'The case is carved out of a single block of aluminum.',
#  'I am very happy with this machine!',
#  'I do not recommend this company or their products!!!!',
#  'I like this machine because its very lightweight...',
#  u'\xa0    First it burned or fused the power adapter plug.',
#  'the features are great, the only thing it needs is better speakers.',
#  'It was still working, but there was nothing on the screen.',
#  'I bought this laptop and found its TAB is not functioning.',
#  u'\xa0 Toshiba is aware of the issue but unless the extended warrenty is bought Toshiba will do nothing about it.',
#  'HP said I had done the damage.',
#  '-Called headquarters again, they report that TFT panel is broken, should be fixed by the end of the week (week 3).',
#  'Navigation through the computer is far superior compared to Windows operating systems, as well.',
#  'I would recommend this product.',
#  'If I had to buy another computer, I would most definetly buy an acer one computer.',
#  'The screen is framed by half- to a full-inch margin that is obviously unnecessary, reduces the screen size and increases the bulk.',
#  'Though the picture, video, and music software is nowhere close to professional grade software Im used to (CS5) but does the job for beginner and even intermediate media designers.',
#  'I previously owned an HP desktop and a Dell laptop.',
#  'Everything else just install and go.',
#  u'\xa0 This thing is a lemon.',
#  'My laptop is almost 2yrs old and I have never had any problems with it.',
#  'All the customers that come in hate Dell.',
#  'We now own two of these, identical.',
#  "I have already recommended this laptop to a friend who eye'd the computer when I took it out of my bag.",
#  'I enjoy very much my new Toshiba, purchased specifially for attending online schooling.',
#  'Once you go Mac, you cannot go back!',
#  'I brought this laptop last friday, and originally it worked fantastic.',
#  'The much lauded combined touch pad and clicker is a nightmare.',
#  'The Unibody construction is solid, sleek and beautiful.',
#  'they are easy, fun, powerful and will last a long time.',
#  'I WANT MY L505-s5988 BACK!',
#  'I let my friend borrow it, and she knows nothing about computers, and she used it with ease.',
#  'This MacBook is an outstanding product with great value.',
#  'If that is the case for you, I would suggest a pull-behind solution when looking at cases.',
#  'I had to re-install Windows within two weeks of the purchase and soon discovered cracks in the screen hinges.',
#  'A SECOND PROBLEM INVOLVES THE BATTERY WHICH IS ADVERTISED AS HAVING A STORAGE LIFE OF 11 HOURS BUT WHEN FULLY CHARGED SHOWS ONLY 7 HOURS OF SERVICE.',
#  'and plenty of storage with 250 gb(though I will upgrade this and the ram..)',
#  ...]

# %%
import re
import pandas as pd
import nltk
from nltk import word_tokenize
print(a)
# Out:
# /home/vibha/miniconda2/lib/python2.7/site-packages/pandas/_libs/__init__.py:4: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from .tslib import iNaT, NaT, Timestamp, Timedelta, OutOfBoundsDatetime
# /home/vibha/miniconda2/lib/python2.7/site-packages/pandas/__init__.py:26: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import (hashtable as _hashtable,
# /home/vibha/miniconda2/lib/python2.7/site-packages/pandas/core/dtypes/common.py:6: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import algos, lib
# /home/vibha/miniconda2/lib/python2.7/site-packages/pandas/core/util/hashing.py:7: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import hashing, tslib
# /home/vibha/miniconda2/lib/python2.7/site-packages/pandas/core/indexes/base.py:7: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import (lib, index as libindex, tslib as libts,
# /home/vibha/miniconda2/lib/python2.7/site-packages/pandas/tseries/offsets.py:21: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   import pandas._libs.tslibs.offsets as liboffsets
# /home/vibha/miniconda2/lib/python2.7/site-packages/pandas/core/ops.py:16: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import algos as libalgos, ops as libops
# /home/vibha/miniconda2/lib/python2.7/site-packages/pandas/core/indexes/interval.py:32: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs.interval import (
# /home/vibha/miniconda2/lib/python2.7/site-packages/pandas/core/internals.py:14: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import internals as libinternals
# /home/vibha/miniconda2/lib/python2.7/site-packages/pandas/core/sparse/array.py:33: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   import pandas._libs.sparse as splib
# /home/vibha/miniconda2/lib/python2.7/site-packages/pandas/core/window.py:36: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   import pandas._libs.window as _window
# /home/vibha/miniconda2/lib/python2.7/site-packages/pandas/core/groupby/groupby.py:68: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import (lib, reduction,
# /home/vibha/miniconda2/lib/python2.7/site-packages/pandas/core/reshape/reshape.py:30: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import algos as _algos, reshape as _reshape
# /home/vibha/miniconda2/lib/python2.7/site-packages/pandas/io/parsers.py:45: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   import pandas._libs.parsers as parsers
# ['I charge it at night and skip taking the cord with me because of the good battery life.', 'I bought a HP Pavilion DV4-1222nr laptop and have had so many problems with the computer.', 'The tech guy then said the service center does not do 1-to-1 exchange and I have to direct my concern to the "sales" team, which is the retail shop which I bought my netbook from.', 'I investigated netbooks and saw the Toshiba NB305-N410BL.', 'The other day I had a presentation to do for a seminar at a large conference in town- lots of people, little time to prep and have to set up a computer to a projector, etc.', 'it is of high quality, has a killer GUI, is extremely stable, is highly expandable, is bundled with lots of very good applications, is easy to use, and is absolutely gorgeous.', 'Easy to start up and does not overheat as much as other laptops.', 'Sad very SAD.', 'I even got my teenage son one, because of the features that it offers, like, iChat, Photobooth, garage band and more!', 'Needless to say a PC that cannot support a cell phone is less than useless!', 'Great laptop that offers many great features!', 'they have done absolutely nothing to fix the computer problem.', u'\xa0One night I turned the freaking thing off after using it, the next day I turn it on, no GUI, screen all dark, power light steady, hard drive light steady and not flashing as it usually does.', 'Still pretty pricey, but I have been putting off money for a while as a little Macbook Fund, and finally got to use it.', 'My only disappointment with the 13" model is that they are the only ones in the MacBook Pro line up without an i5 or i7 processor and dual graphics cards, however the trade-off is that you achieve a longer battery life (of about 2 more hours).', 'I took it back for an Asus and same thing- blue screen which required me to remove the battery to reset.', 'In the shop, these MacBooks are encased in a soft rubber enclosure - so you will never know about the razor edge until you buy it, get it home, break the seal and use it (very clever con).', 'However, the multi-touch gestures and large tracking area make having an external mouse unnecessary (unless you are gaming).', 'Plus it is small and reasonably light so I can take it with me to and from work.', 'I HATE this one.', 'They were totally unconcerned that the computer was not correctly repaired in the first place.', 'Toshiba does not send any one out unless you have paid extra to have the on site repair done.', 'Oh, boy!', 'But while this is one big advantage (as you may know from the company s recent commercials) there are other things to consider before going with Apple.', 'I love the way the entire suite of software works together.', 'The speed is incredible and I am more than satisfied.', 'on the bright side at least I was not without my laptop for long this time!', 'This laptop meets every expectation and Windows 7 is great!', 'that has / that is how frustrating it was.', 'I can barely use any usb devices because they will not stay connected properly.', 'The one down side to it is that when I play a certin game on here, it tends to freeze up sometimes, but thats the only bad thing about this computer.', '-No backlit keyboard, but not an issue for me.', 'When I finally had everything running with all my software installed I plugged in my droid to recharge and the system crashed.', 'I cannot even turn it off.', 'One suggestion I do have, is to not bother getting Microsoft office for the mac expecting it will work just like you knew it to on a PC.', 'Pairing it with an iPhone is a pure pleasure - talk about painless syncing - used to take me forever - now it has / it is a snap.', 'I shopped around before buying.', 'I also got the added bonus of a 30" HD Monitor, which really helps to extend my screen and keep my eyes fresh!', 'Would do business again.', 'The machine is slow to boot up and occasionally crashes completely.', 'After paying several hundred dollars for this service, it is frustrating that ...
# /home/vibha/miniconda2/lib/python2.7/site-packages/pandas/io/pytables.py:50: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from pandas._libs import algos, lib, writers as libwriters

# %%
for i in a[:30]:
    
    sen=i
    sen = [re.sub(r"[^a-zA-Z0-9]+", ' ', k) for k in sen.split("\n")]
    sen2=sen
    print(sen2)
    import os
    p=os.popen("echo '"+sen2[0]+"'~/stanford-parser-2012-11-12/stanfordtemp.txt")
    print(p)
    parser_out = os.popen("~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt")
    print(parser_out)
    
    for relation in parser_out:
        
        print(relation)
        #tr+=relation
# Out:
# ['I charge it at night and skip taking the cord with me because of the good battery life ']
# <open file "echo 'I charge it at night and skip taking the cord with me because of the good battery life '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c0bc0ed0>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c096f1e0>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['I bought a HP Pavilion DV4 1222nr laptop and have had so many problems with the computer ']
# <open file "echo 'I bought a HP Pavilion DV4 1222nr laptop and have had so many problems with the computer '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f270>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c0bc0ed0>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['The tech guy then said the service center does not do 1 to 1 exchange and I have to direct my concern to the sales team which is the retail shop which I bought my netbook from ']
# <open file "echo 'The tech guy then said the service center does not do 1 to 1 exchange and I have to direct my concern to the sales team which is the retail shop which I bought my netbook from '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f300>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c096f270>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['I investigated netbooks and saw the Toshiba NB305 N410BL ']
# <open file "echo 'I investigated netbooks and saw the Toshiba NB305 N410BL '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c0bc0ed0>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c096f300>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['The other day I had a presentation to do for a seminar at a large conference in town lots of people little time to prep and have to set up a computer to a projector etc ']
# <open file "echo 'The other day I had a presentation to do for a seminar at a large conference in town lots of people little time to prep and have to set up a computer to a projector etc '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f150>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c0bc0ed0>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['it is of high quality has a killer GUI is extremely stable is highly expandable is bundled with lots of very good applications is easy to use and is absolutely gorgeous ']
# <open file "echo 'it is of high quality has a killer GUI is extremely stable is highly expandable is bundled with lots of very good applications is easy to use and is absolutely gorgeous '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f1e0>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c096f150>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['Easy to start up and does not overheat as much as other laptops ']
# <open file "echo 'Easy to start up and does not overheat as much as other laptops '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c0bc0ed0>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c096f1e0>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['Sad very SAD ']
# <open file "echo 'Sad very SAD '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f270>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c0bc0ed0>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['I even got my teenage son one because of the features that it offers like iChat Photobooth garage band and more ']
# <open file "echo 'I even got my teenage son one because of the features that it offers like iChat Photobooth garage band and more '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f300>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c096f270>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['Needless to say a PC that cannot support a cell phone is less than useless ']
# <open file "echo 'Needless to say a PC that cannot support a cell phone is less than useless '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c0bc0ed0>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c096f300>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['Great laptop that offers many great features ']
# <open file "echo 'Great laptop that offers many great features '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f150>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c0bc0ed0>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['they have done absolutely nothing to fix the computer problem ']
# <open file "echo 'they have done absolutely nothing to fix the computer problem '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f1e0>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c096f150>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# [u' One night I turned the freaking thing off after using it the next day I turn it on no GUI screen all dark power light steady hard drive light steady and not flashing as it usually does ']
# <open file "echo ' One night I turned the freaking thing off after using it the next day I turn it on no GUI screen all dark power light steady hard drive light steady and not flashing as it usually does '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c0bc0ed0>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c096f1e0>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['Still pretty pricey but I have been putting off money for a while as a little Macbook Fund and finally got to use it ']
# <open file "echo 'Still pretty pricey but I have been putting off money for a while as a little Macbook Fund and finally got to use it '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f270>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c0bc0ed0>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['My only disappointment with the 13 model is that they are the only ones in the MacBook Pro line up without an i5 or i7 processor and dual graphics cards however the trade off is that you achieve a longer battery life of about 2 more hours ']
# <open file "echo 'My only disappointment with the 13 model is that they are the only ones in the MacBook Pro line up without an i5 or i7 processor and dual graphics cards however the trade off is that you achieve a longer battery life of about 2 more hours '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f300>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c096f270>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['I took it back for an Asus and same thing blue screen which required me to remove the battery to reset ']
# <open file "echo 'I took it back for an Asus and same thing blue screen which required me to remove the battery to reset '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f150>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c096f300>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['In the shop these MacBooks are encased in a soft rubber enclosure so you will never know about the razor edge until you buy it get it home break the seal and use it very clever con ']
# <open file "echo 'In the shop these MacBooks are encased in a soft rubber enclosure so you will never know about the razor edge until you buy it get it home break the seal and use it very clever con '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c0bc0ed0>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c096f150>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['However the multi touch gestures and large tracking area make having an external mouse unnecessary unless you are gaming ']
# <open file "echo 'However the multi touch gestures and large tracking area make having an external mouse unnecessary unless you are gaming '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f1e0>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c0bc0ed0>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['Plus it is small and reasonably light so I can take it with me to and from work ']
# <open file "echo 'Plus it is small and reasonably light so I can take it with me to and from work '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f390>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c096f1e0>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['I HATE this one ']
# <open file "echo 'I HATE this one '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c0bc0ed0>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c096f390>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['They were totally unconcerned that the computer was not correctly repaired in the first place ']
# <open file "echo 'They were totally unconcerned that the computer was not correctly repaired in the first place '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f300>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c0bc0ed0>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['Toshiba does not send any one out unless you have paid extra to have the on site repair done ']
# <open file "echo 'Toshiba does not send any one out unless you have paid extra to have the on site repair done '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f150>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c096f300>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['Oh boy ']
# <open file "echo 'Oh boy '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c0bc0ed0>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c096f150>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['But while this is one big advantage as you may know from the company s recent commercials there are other things to consider before going with Apple ']
# <open file "echo 'But while this is one big advantage as you may know from the company s recent commercials there are other things to consider before going with Apple '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f1e0>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c0bc0ed0>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['I love the way the entire suite of software works together ']
# <open file "echo 'I love the way the entire suite of software works together '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f390>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c096f1e0>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['The speed is incredible and I am more than satisfied ']
# <open file "echo 'The speed is incredible and I am more than satisfied '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f300>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c0bc0ed0>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['on the bright side at least I was not without my laptop for long this time ']
# <open file "echo 'on the bright side at least I was not without my laptop for long this time '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f390>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c096f300>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['This laptop meets every expectation and Windows 7 is great ']
# <open file "echo 'This laptop meets every expectation and Windows 7 is great '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c0bc0ed0>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c096f390>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['that has that is how frustrating it was ']
# <open file "echo 'that has that is how frustrating it was '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f150>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c0bc0ed0>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)
#
#
#
# ['I can barely use any usb devices because they will not stay connected properly ']
# <open file "echo 'I can barely use any usb devices because they will not stay connected properly '~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7fa2c096f270>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7fa2c096f150>
# (ROOT
#
#   (S
#
#     (NP (DT The) (JJ spicy) (NN tuna) (NN roll))
#
#     (VP (VBD was)
#
#       (ADJP (JJ amazing)))))
#
#
#
# det(roll-4, The-1)
#
# amod(roll-4, spicy-2)
#
# nn(roll-4, tuna-3)
#
# nsubj(amazing-6, roll-4)
#
# cop(amazing-6, was-5)
#
# root(ROOT-0, amazing-6)

# %%
head_word=['I',
 'laptop',
 'problems',
 'computer',
 'it',
 'night',
 'cord',
 'me',
 'life',
 'guy',
 'center',
 'exchange',
 'concern',
 'team',
 'shop',
 'netbook',
 'netbooks',
 'NB305-N410BL',
 'day',
 'presentation',
 'seminar',
 'lots',
 'conference',
 'town',
 'people',
 'time',
 'etc.',
 'projector',
 'quality',
 'GUI',
 'applications',
 'laptops',
 'one',
 'features',
 'more',
 'iChat',
 'Photobooth',
 'band',
 'PC',
 'phone',
 'they',
 'nothing',
 'problem',
 'thing',
 'dark',
 'light',
 'money',
 'while',
 'Fund',
 'disappointment',
 'model',
 'ones',
 'line',
 'processor',
 'cards',
 'trade-off',
 'you',
 'hours',
 'screen',
 'battery',
 'MacBooks',
 'enclosure',
 'edge',
 'seal',
 'con',
 'area',
 'mouse',
 'gaming',
 'work',
 'They',
 'place',
 'Toshiba',
 'repair',
 'this',
 'advantage',
 'company',
 'commercials',
 'there',
 'things',
 'Apple',
 'way',
 'suite',
 'software',
 'speed',
 'side',
 'Windows',
 'expectation',
 'That',
 'devices',
 'game',
 'here',
 'keyboard',
 'issue']

# %%
from stanfordcorenlp import StanfordCoreNLP

nlp = StanfordCoreNLP(r'/home/vibha/stanford-corenlp-full-2018-10-05')

# %%
head_word=[]

# %%
from nltk.tree import Tree


def find_noun_phrases(tree):
    return [subtree for subtree in tree.subtrees(lambda t: t.label()=='NP')]

def find_head_of_np(np):
    noun_tags = ['NN', 'NNS', 'NNP', 'NNPS']
    top_level_trees = [np[i] for i in range(len(np)) if type(np[i]) is Tree]
    ## search for a top-level noun
    top_level_nouns = [t for t in top_level_trees if t.label() in noun_tags]
    if len(top_level_nouns) > 0:
        ## if you find some, pick the rightmost one, just 'cause
        return top_level_nouns[-1][0]
    else:
        ## search for a top-level np
        top_level_nps = [t for t in top_level_trees if t.label()=='NP']
        if len(top_level_nps) > 0:
            ## if you find some, pick the head of the rightmost one, just 'cause
            return find_head_of_np(top_level_nps[-1])
        else:
            ## search for any noun
            nouns = [p[0] for p in np.pos() if p[1] in noun_tags]
            if len(nouns) > 0:
                ## if you find some, pick the rightmost one, just 'cause
                return nouns[-1]
            else:
                ## return the rightmost word, just 'cause
                return np.leaves()[-1]
            
#print(examples[0])
#tree=Tree.fromstring(example)
for i in new_list[:100]:
    i=i.encode('utf-8')
    t=nlp.parse(i)
    
    examples = [str(t)]
    print(examples)
    tree=nlp.parse(sentence)
    for example in examples:
        print(example)

        tree = Tree.fromstring(example)
        for np in find_noun_phrases(tree):
       
            print(" ".join(np.leaves()))
            head = find_head_of_np(np)
            if(head not in head_word):
                print(head)
                head_word.append(head)
# Out:
# ['(ROOT\n  (S\n    (NP (PRP I))\n    (VP\n      (VP (VBP charge)\n        (NP (PRP it))\n        (PP (IN at)\n          (NP (NN night))))\n      (CC and)\n      (VP (VB skip)\n        (S\n          (VP (VBG taking)\n            (NP (DT the) (NN cord))\n            (PP (IN with)\n              (NP (PRP me)))\n            (PP (IN because)\n              (PP (IN of)\n                (NP (DT the) (JJ good) (NN battery) (NN life))))))))\n    (. .)))']
# (ROOT
#   (S
#     (NP (PRP I))
#     (VP
#       (VP (VBP charge)
#         (NP (PRP it))
#         (PP (IN at)
#           (NP (NN night))))
#       (CC and)
#       (VP (VB skip)
#         (S
#           (VP (VBG taking)
#             (NP (DT the) (NN cord))
#             (PP (IN with)
#               (NP (PRP me)))
#             (PP (IN because)
#               (PP (IN of)
#                 (NP (DT the) (JJ good) (NN battery) (NN life))))))))
#     (. .)))
# I
# it
# night
# the cord
# me
# the good battery life
# ['(ROOT\n  (S\n    (NP (PRP I))\n    (VP\n      (VP (VBD bought)\n        (NP (DT a) (NNP HP) (NNP Pavilion) (NN DV4-1222nr) (NN laptop)))\n      (CC and)\n      (VP (VB have)\n        (VP (VBN had)\n          (NP\n            (NP\n              (ADJP (RB so) (JJ many))\n              (NNS problems))\n            (PP (IN with)\n              (NP (DT the) (NN computer)))))))\n    (. .)))']
# (ROOT
#   (S
#     (NP (PRP I))
#     (VP
#       (VP (VBD bought)
#         (NP (DT a) (NNP HP) (NNP Pavilion) (NN DV4-1222nr) (NN laptop)))
#       (CC and)
#       (VP (VB have)
#         (VP (VBN had)
#           (NP
#             (NP
#               (ADJP (RB so) (JJ many))
#               (NNS problems))
#             (PP (IN with)
#               (NP (DT the) (NN computer)))))))
#     (. .)))
# I
# a HP Pavilion DV4-1222nr laptop
# so many problems with the computer
# so many problems
# the computer
# ["(ROOT\n  (S\n    (NP (DT The) (NN tech) (NN guy))\n    (ADVP (RB then))\n    (VP (VBD said)\n      (SBAR\n        (S\n          (S\n            (NP (DT the) (NN service) (NN center))\n            (VP (VBZ does) (RB not)\n              (VP (VB do)\n                (NP (JJ 1-to-1) (NN exchange)))))\n          (CC and)\n          (S\n            (NP (PRP I))\n            (VP (VBP have)\n              (S\n                (VP (TO to)\n                  (VP (VB direct)\n                    (NP (PRP$ my) (NN concern))\n                    (PP (TO to)\n                      (NP\n                        (NP (DT the) (`` ``)\n                          (NP (NNS sales))\n                          ('' '') (NN team))\n                        (, ,)\n                        (SBAR\n                          (WHNP (WDT which))\n                          (S\n                            (VP (VBZ is)\n                              (NP\n                                (NP (DT the) (JJ retail) (NN shop))\n                                (SBAR\n                                  (WHNP (WDT which))\n                                  (S\n                                    (NP (PRP I))\n                                    (VP (VBD bought)\n                                      (NP (PRP$ my) (NN netbook))\n                                      (PP (IN from)))))))))))))))))))\n    (. .)))"]
# (ROOT
#   (S
#     (NP (DT The) (NN tech) (NN guy))
#     (ADVP (RB then))
#     (VP (VBD said)
#       (SBAR
#         (S
#           (S
#             (NP (DT the) (NN service) (NN center))
#             (VP (VBZ does) (RB not)
#               (VP (VB do)
#                 (NP (JJ 1-to-1) (NN exchange)))))
#           (CC and)
#           (S
#             (NP (PRP I))
#             (VP (VBP have)
#               (S
#                 (VP (TO to)
#                   (VP (VB direct)
#                     (NP (PRP$ my) (NN concern))
#                     (PP (TO to)
#                       (NP
#                         (NP (DT the) (`` ``)
#                           (NP (NNS sales))
#                           ('' '') (NN team))
#                         (, ,)
#                         (SBAR
#                           (WHNP (WDT which))
#                           (S
#                             (VP (VBZ is)
#                               (NP
#                                 (NP (DT the) (JJ retail) (NN shop))
#                                 (SBAR
#                                   (WHNP (WDT which))
#                                   (S
#                                     (NP (PRP I))
#                                     (VP (VBD bought)
#                                       (NP (PRP$ my) (NN netbook))
#                                       (PP (IN from)))))))))))))))))))
#     (. .)))
# The tech guy
# the service center
# 1-to-1 exchange
# I
# my concern
# the `` sales '' team , which is the retail shop which I bought my netbook from
# the `` sales '' team
# sales
# the retail shop which I bought my netbook from
# the retail shop
# I
# my netbook
# ['(ROOT\n  (S\n    (NP (PRP I))\n    (VP\n      (VP (VBD investigated)\n        (NP (NNS netbooks)))\n      (CC and)\n      (VP (VBD saw)\n        (NP (DT the) (NNP Toshiba) (NN NB305-N410BL))))\n    (. .)))']
# (ROOT
#   (S
#     (NP (PRP I))
#     (VP
#       (VP (VBD investigated)
#         (NP (NNS netbooks)))
#       (CC and)
#       (VP (VBD saw)
#         (NP (DT the) (NNP Toshiba) (NN NB305-N410BL))))
#     (. .)))
# I
# netbooks
# the Toshiba NB305-N410BL
# ['(ROOT\n  (S\n    (NP (DT The) (JJ other) (NN day) (CD I))\n    (VP\n      (VP (VBD had)\n        (NP (DT a) (NN presentation)\n          (S\n            (VP (TO to)\n              (VP (VB do)\n                (PP (IN for)\n                  (NP (DT a) (NN seminar)))\n                (PP (IN at)\n                  (NP\n                    (NP\n                      (NP (DT a) (JJ large) (NN conference))\n                      (PP (IN in)\n                        (NP (NN town))))\n                    (: -)\n                    (NP\n                      (NP (NNS lots))\n                      (PP (IN of)\n                        (NP (NNS people))))\n                    (, ,)))\n                (NP-TMP (JJ little) (NN time))\n                (PP (TO to)\n                  (NP (NN prep))))))))\n      (CC and)\n      (VP (VBP have)\n        (S\n          (VP (TO to)\n            (VP (VB set)\n              (PRT (RP up))\n              (NP (DT a) (NN computer))\n              (PP (TO to)\n                (NP\n                  (NP (DT a) (NN projector))\n                  (, ,)\n                  (NP (FW etc.)))))))))\n    (. .)))']
# (ROOT
#   (S
#     (NP (DT The) (JJ other) (NN day) (CD I))
#     (VP
#       (VP (VBD had)
#         (NP (DT a) (NN presentation)
#           (S
#             (VP (TO to)
#               (VP (VB do)
#                 (PP (IN for)
#                   (NP (DT a) (NN seminar)))
#                 (PP (IN at)
#                   (NP
#                     (NP
#                       (NP (DT a) (JJ large) (NN conference))
#                       (PP (IN in)
#                         (NP (NN town))))
#                     (: -)
#                     (NP
#                       (NP (NNS lots))
#                       (PP (IN of)
#                         (NP (NNS people))))
#                     (, ,)))
#                 (NP-TMP (JJ little) (NN time))
#                 (PP (TO to)
#                   (NP (NN prep))))))))
#       (CC and)
#       (VP (VBP have)
#         (S
#           (VP (TO to)
#             (VP (VB set)
#               (PRT (RP up))
#               (NP (DT a) (NN computer))
#               (PP (TO to)
#                 (NP
#                   (NP (DT a) (NN projector))
#                   (, ,)
#                   (NP (FW etc.)))))))))
#     (. .)))
# The other day I
# a presentation to do for a seminar at a large conference in town - lots of people , little time to prep
# a seminar
# a large conference in town - lots of people ,
# a large conference in town
# a large conference
# town
# lots of people
# lots
# people
# prep
# a computer
# a projector , etc.
# a projector
# etc.
# ['(ROOT\n  (S\n    (NP (PRP it))\n    (VP\n      (VP (VBZ is)\n        (PP (IN of)\n          (NP (JJ high) (NN quality))))\n      (, ,)\n      (VP (VBZ has)\n        (NP (DT a) (NN killer) (NNP GUI)))\n      (, ,)\n      (VP (VBZ is)\n        (ADJP (RB extremely) (JJ stable)))\n      (, ,)\n      (VP (VBZ is)\n        (ADJP (RB highly) (JJ expandable)))\n      (, ,)\n      (VP (VBZ is)\n        (VP (VBN bundled)\n          (PP (IN with)\n            (NP\n              (NP (NNS lots))\n              (PP (IN of)\n                (NP\n                  (ADJP (RB very) (JJ good))\n                  (NNS applications)))))))\n      (, ,)\n      (VP (VBZ is)\n        (ADJP (JJ easy)\n          (S\n            (VP (TO to)\n              (VP (VB use))))))\n      (, ,)\n      (CC and)\n      (VP (VBZ is)\n        (ADJP (RB absolutely) (JJ gorgeous))))\n    (. .)))']
# (ROOT
#   (S
#     (NP (PRP it))
#     (VP
#       (VP (VBZ is)
#         (PP (IN of)
#           (NP (JJ high) (NN quality))))
#       (, ,)
#       (VP (VBZ has)
#         (NP (DT a) (NN killer) (NNP GUI)))
#       (, ,)
#       (VP (VBZ is)
#         (ADJP (RB extremely) (JJ stable)))
#       (, ,)
#       (VP (VBZ is)
#         (ADJP (RB highly) (JJ expandable)))
#       (, ,)
#       (VP (VBZ is)
#         (VP (VBN bundled)
#           (PP (IN with)
#             (NP
#               (NP (NNS lots))
#               (PP (IN of)
#                 (NP
#                   (ADJP (RB very) (JJ good))
#                   (NNS applications)))))))
#       (, ,)
#       (VP (VBZ is)
#         (ADJP (JJ easy)
#           (S
#             (VP (TO to)
#               (VP (VB use))))))
#       (, ,)
#       (CC and)
#       (VP (VBZ is)
#         (ADJP (RB absolutely) (JJ gorgeous))))
#     (. .)))
# it
# high quality
# a killer GUI
# lots of very good applications
# lots
# very good applications
# ['(ROOT\n  (S\n    (NP (NNP Easy))\n    (VP (TO to)\n      (VP\n        (VP (VB start)\n          (PRT (RP up)))\n        (CC and)\n        (VP (VBZ does) (RB not)\n          (VP (VB overheat)\n            (NP\n              (NP\n                (QP (RB as) (JJ much)))\n              (PP (IN as)\n                (NP (JJ other) (NNS laptops))))))))\n    (. .)))']
# (ROOT
#   (S
#     (NP (NNP Easy))
#     (VP (TO to)
#       (VP
#         (VP (VB start)
#           (PRT (RP up)))
#         (CC and)
#         (VP (VBZ does) (RB not)
#           (VP (VB overheat)
#             (NP
#               (NP
#                 (QP (RB as) (JJ much)))
#               (PP (IN as)
#                 (NP (JJ other) (NNS laptops))))))))
#     (. .)))
# Easy
# as much as other laptops
# as much
# other laptops
# ['(ROOT\n  (S\n    (NP (JJ Sad))\n    (ADJP (RB very) (JJ SAD))\n    (. .)))']
# (ROOT
#   (S
#     (NP (JJ Sad))
#     (ADJP (RB very) (JJ SAD))
#     (. .)))
# Sad
# ['(ROOT\n  (S\n    (NP (PRP I))\n    (ADVP (RB even))\n    (VP (VBD got)\n      (NP (PRP$ my) (JJ teenage) (NN son))\n      (NP-TMP (CD one))\n      (, ,)\n      (PP (IN because) (IN of)\n        (NP\n          (NP (DT the) (NNS features))\n          (SBAR (IN that)\n            (S\n              (NP (PRP it))\n              (VP (VBZ offers) (, ,)\n                (PP (IN like))\n                (, ,)\n                (NP\n                  (NP (NNP iChat))\n                  (, ,)\n                  (NP (NNP Photobooth))\n                  (, ,)\n                  (NP (NN garage) (NN band))\n                  (CC and)\n                  (NP (JJR more)))))))))\n    (. !)))']
# (ROOT
#   (S
#     (NP (PRP I))
#     (ADVP (RB even))
#     (VP (VBD got)
#       (NP (PRP$ my) (JJ teenage) (NN son))
#       (NP-TMP (CD one))
#       (, ,)
#       (PP (IN because) (IN of)
#         (NP
#           (NP (DT the) (NNS features))
#           (SBAR (IN that)
#             (S
#               (NP (PRP it))
#               (VP (VBZ offers) (, ,)
#                 (PP (IN like))
#                 (, ,)
#                 (NP
#                   (NP (NNP iChat))
#                   (, ,)
#                   (NP (NNP Photobooth))
#                   (, ,)
#                   (NP (NN garage) (NN band))
#                   (CC and)
#                   (NP (JJR more)))))))))
#     (. !)))
# I
# my teenage son
# the features that it offers , like , iChat , Photobooth , garage band and more
# the features
# it
# iChat , Photobooth , garage band and more
# iChat
# Photobooth
# garage band
# more
# ['(ROOT\n  (ADJP (JJ Needless)\n    (S\n      (VP (TO to)\n        (VP (VB say)\n          (NP\n            (NP (DT a) (NN PC))\n            (SBAR\n              (WHNP (WDT that))\n              (S\n                (VP (MD can) (RB not)\n                  (VP (VB support)\n                    (SBAR\n                      (S\n                        (NP (DT a) (NN cell) (NN phone))\n                        (VP (VBZ is)\n                          (ADJP\n                            (ADVP (JJR less) (IN than))\n                            (JJ useless)))))))))))))\n    (. !)))']
# (ROOT
#   (ADJP (JJ Needless)
#     (S
#       (VP (TO to)
#         (VP (VB say)
#           (NP
#             (NP (DT a) (NN PC))
#             (SBAR
#               (WHNP (WDT that))
#               (S
#                 (VP (MD can) (RB not)
#                   (VP (VB support)
#                     (SBAR
#                       (S
#                         (NP (DT a) (NN cell) (NN phone))
#                         (VP (VBZ is)
#                           (ADJP
#                             (ADVP (JJR less) (IN than))
#                             (JJ useless)))))))))))))
#     (. !)))
# a PC that can not support a cell phone is less than useless
# a PC
# a cell phone
# ['(ROOT\n  (FRAG\n    (NP\n      (NP (JJ Great) (NN laptop))\n      (SBAR\n        (WHNP (WDT that))\n        (S\n          (VP (VBZ offers)\n            (NP (JJ many) (JJ great) (NNS features))))))\n    (. !)))']
# (ROOT
#   (FRAG
#     (NP
#       (NP (JJ Great) (NN laptop))
#       (SBAR
#         (WHNP (WDT that))
#         (S
#           (VP (VBZ offers)
#             (NP (JJ many) (JJ great) (NNS features))))))
#     (. !)))
# Great laptop that offers many great features
# Great laptop
# many great features
# ['(ROOT\n  (S\n    (NP (PRP they))\n    (VP (VBP have)\n      (VP (VBN done)\n        (NP (RB absolutely) (NN nothing)\n          (S\n            (VP (TO to)\n              (VP (VB fix)\n                (NP (DT the) (NN computer) (NN problem))))))))\n    (. .)))']
# (ROOT
#   (S
#     (NP (PRP they))
#     (VP (VBP have)
#       (VP (VBN done)
#         (NP (RB absolutely) (NN nothing)
#           (S
#             (VP (TO to)
#               (VP (VB fix)
#                 (NP (DT the) (NN computer) (NN problem))))))))
#     (. .)))
# they
# absolutely nothing to fix the computer problem
# the computer problem
# ['(ROOT\n  (S\n    (S\n      (NP-TMP (CD One) (NN night))\n      (NP (PRP I))\n      (VP (VBD turned)\n        (NP\n          (NP (DT the) (VBG freaking) (NN thing))\n          (ADVP (IN off)))\n        (PP (IN after)\n          (S\n            (VP (VBG using)\n              (NP (PRP it)))))))\n    (, ,)\n    (NP (DT the) (JJ next) (NN day) (CD I))\n    (VP (VBP turn)\n      (NP (PRP it))\n      (PP (IN on))\n      (, ,)\n      (NP\n        (NP (DT no) (NNP GUI))\n        (, ,)\n        (VP (NN screen)\n          (NP\n            (NP (DT all) (JJ dark))\n            (, ,)\n            (NP\n              (NP (NN power) (JJ light) (JJ steady) (, ,) (JJ hard) (NN drive) (NN light))\n              (UCP\n                (ADJP (JJ steady))\n                (CC and)\n                (VP (RB not) (VBG flashing)\n                  (SBAR (IN as)\n                    (S\n                      (NP (PRP it))\n                      (ADVP (RB usually))\n                      (VP (VBZ does)))))))))))\n    (. .)))']
# (ROOT
#   (S
#     (S
#       (NP-TMP (CD One) (NN night))
#       (NP (PRP I))
#       (VP (VBD turned)
#         (NP
#           (NP (DT the) (VBG freaking) (NN thing))
#           (ADVP (IN off)))
#         (PP (IN after)
#           (S
#             (VP (VBG using)
#               (NP (PRP it)))))))
#     (, ,)
#     (NP (DT the) (JJ next) (NN day) (CD I))
#     (VP (VBP turn)
#       (NP (PRP it))
#       (PP (IN on))
#       (, ,)
#       (NP
#         (NP (DT no) (NNP GUI))
#         (, ,)
#         (VP (NN screen)
#           (NP
#             (NP (DT all) (JJ dark))
#             (, ,)
#             (NP
#               (NP (NN power) (JJ light) (JJ steady) (, ,) (JJ hard) (NN drive) (NN light))
#               (UCP
#                 (ADJP (JJ steady))
#                 (CC and)
#                 (VP (RB not) (VBG flashing)
#                   (SBAR (IN as)
#                     (S
#                       (NP (PRP it))
#                       (ADVP (RB usually))
#                       (VP (VBZ does)))))))))))
#     (. .)))
# I
# the freaking thing off
# thing
# the freaking thing
# it
# the next day I
# it
# no GUI , screen all dark , power light steady , hard drive light steady and not flashing as it usually does
# no GUI
# all dark , power light steady , hard drive light steady and not flashing as it usually does
# light
# all dark
# dark
# power light steady , hard drive light steady and not flashing as it usually does
# power light steady , hard drive light
# it
# ['(ROOT\n  (S\n    (S\n      (ADJP (RB Still) (RB pretty) (JJ pricey)))\n    (, ,)\n    (S (CC but)\n      (NP (PRP I))\n      (VP\n        (VP (VBP have)\n          (VP (VBN been)\n            (VP (VBG putting)\n              (PRT (RP off))\n              (NP\n                (NP (NN money))\n                (PP (IN for)\n                  (NP\n                    (NP (DT a) (NN while))\n                    (PP (IN as)\n                      (NP (DT a) (JJ little) (NNP Macbook) (NNP Fund)))))))))\n        (, ,)\n        (CC and)\n        (VP\n          (ADVP (RB finally))\n          (VBD got)\n          (S\n            (VP (TO to)\n              (VP (VB use)\n                (NP (PRP it))))))))\n    (. .)))']
# (ROOT
#   (S
#     (S
#       (ADJP (RB Still) (RB pretty) (JJ pricey)))
#     (, ,)
#     (S (CC but)
#       (NP (PRP I))
#       (VP
#         (VP (VBP have)
#           (VP (VBN been)
#             (VP (VBG putting)
#               (PRT (RP off))
#               (NP
#                 (NP (NN money))
#                 (PP (IN for)
#                   (NP
#                     (NP (DT a) (NN while))
#                     (PP (IN as)
#                       (NP (DT a) (JJ little) (NNP Macbook) (NNP Fund)))))))))
#         (, ,)
#         (CC and)
#         (VP
#           (ADVP (RB finally))
#           (VBD got)
#           (S
#             (VP (TO to)
#               (VP (VB use)
#                 (NP (PRP it))))))))
#     (. .)))
# I
# money for a while as a little Macbook Fund
# money
# money
# a while as a little Macbook Fund
# while
# a while
# a little Macbook Fund
# Fund
# it
# ["(ROOT\n  (S\n    (S\n      (NP\n        (NP (PRP$ My) (JJ only) (NN disappointment))\n        (PP (IN with)\n          (NP (DT the) (CD 13) ('' '') (NN model))))\n      (VP (VBZ is)\n        (SBAR (IN that)\n          (S\n            (NP (PRP they))\n            (VP (VBP are)\n              (NP\n                (NP (DT the) (JJ only) (NNS ones))\n                (PP (IN in)\n                  (NP (DT the) (NNP MacBook) (FW Pro) (NN line))))\n              (ADVP (RB up)\n                (PP (IN without)\n                  (NP\n                    (NP (DT an) (NN i5)\n                      (CC or)\n                      (NN i7) (NN processor))\n                    (CC and)\n                    (NP (JJ dual) (NNS graphics) (NNS cards)))\n                  (, ,)\n                  (ADVP (RB however)))))))))\n    (NP (DT the) (NN trade-off))\n    (VP (VBZ is)\n      (SBAR (IN that)\n        (S\n          (NP (PRP you))\n          (VP (VBP achieve)\n            (NP\n              (NP (DT a)\n                (ADJP (JJR longer) (NN battery))\n                (NN life))\n              (PRN (-LRB- -LRB-)\n                (NP\n                  (QP (IN of) (RB about) (CD 2) (JJR more))\n                  (NNS hours))\n                (-RRB- -RRB-)))))))\n    (. .)))"]
# (ROOT
#   (S
#     (S
#       (NP
#         (NP (PRP$ My) (JJ only) (NN disappointment))
#         (PP (IN with)
#           (NP (DT the) (CD 13) ('' '') (NN model))))
#       (VP (VBZ is)
#         (SBAR (IN that)
#           (S
#             (NP (PRP they))
#             (VP (VBP are)
#               (NP
#                 (NP (DT the) (JJ only) (NNS ones))
#                 (PP (IN in)
#                   (NP (DT the) (NNP MacBook) (FW Pro) (NN line))))
#               (ADVP (RB up)
#                 (PP (IN without)
#                   (NP
#                     (NP (DT an) (NN i5)
#                       (CC or)
#                       (NN i7) (NN processor))
#                     (CC and)
#                     (NP (JJ dual) (NNS graphics) (NNS cards)))
#                   (, ,)
#                   (ADVP (RB however)))))))))
#     (NP (DT the) (NN trade-off))
#     (VP (VBZ is)
#       (SBAR (IN that)
#         (S
#           (NP (PRP you))
#           (VP (VBP achieve)
#             (NP
#               (NP (DT a)
#                 (ADJP (JJR longer) (NN battery))
#                 (NN life))
#               (PRN (-LRB- -LRB-)
#                 (NP
#                   (QP (IN of) (RB about) (CD 2) (JJR more))
#                   (NNS hours))
#                 (-RRB- -RRB-)))))))
#     (. .)))
# My only disappointment with the 13 '' model
# disappointment
# My only disappointment
# the 13 '' model
# model
# they
# the only ones in the MacBook Pro line
# ones
# the only ones
# the MacBook Pro line
# line
# an i5 or i7 processor and dual graphics cards
# cards
# an i5 or i7 processor
# processor
# dual graphics cards
# the trade-off
# trade-off
# you
# you
# a longer battery life -LRB- of about 2 more hours -RRB-
# a longer battery life
# of about 2 more hours
# hours
# ['(ROOT\n  (S\n    (NP (PRP I))\n    (VP\n      (VP (VBD took)\n        (NP (PRP it))\n        (PRT (RP back))\n        (PP (IN for)\n          (NP\n            (NP (DT an) (NNP Asus))\n            (CC and)\n            (NP (JJ same) (NN thing)))))\n      (: -)\n      (NP\n        (NP (JJ blue) (NN screen))\n        (SBAR\n          (WHNP (WDT which))\n          (S\n            (VP (VBD required)\n              (S\n                (NP (PRP me))\n                (VP (TO to)\n                  (VP (VB remove)\n                    (NP (DT the) (NN battery)\n                      (S\n                        (VP (TO to)\n                          (VP (VB reset)))))))))))))\n    (. .)))']
# (ROOT
#   (S
#     (NP (PRP I))
#     (VP
#       (VP (VBD took)
#         (NP (PRP it))
#         (PRT (RP back))
#         (PP (IN for)
#           (NP
#             (NP (DT an) (NNP Asus))
#             (CC and)
#             (NP (JJ same) (NN thing)))))
#       (: -)
#       (NP
#         (NP (JJ blue) (NN screen))
#         (SBAR
#           (WHNP (WDT which))
#           (S
#             (VP (VBD required)
#               (S
#                 (NP (PRP me))
#                 (VP (TO to)
#                   (VP (VB remove)
#                     (NP (DT the) (NN battery)
#                       (S
#                         (VP (TO to)
#                           (VP (VB reset)))))))))))))
#     (. .)))
# I
# it
# an Asus and same thing
# an Asus
# Asus
# same thing
# blue screen which required me to remove the battery to reset
# screen
# blue screen
# me
# the battery to reset
# battery
# ['(ROOT\n  (S\n    (PP (IN In)\n      (NP (DT the) (NN shop)))\n    (, ,)\n    (NP (DT these) (NNS MacBooks))\n    (VP (VBP are)\n      (VP (VBN encased)\n        (PP (IN in)\n          (NP (DT a) (JJ soft) (NN rubber) (NN enclosure)))\n        (: -)\n        (SBAR (IN so)\n          (S\n            (NP (PRP you))\n            (VP (MD will)\n              (ADVP (RB never))\n              (VP\n                (VP (VB know)\n                  (PP (IN about)\n                    (NP (DT the) (NN razor) (NN edge)))\n                  (SBAR (IN until)\n                    (S\n                      (NP (PRP you))\n                      (VP (VBP buy)\n                        (NP (PRP it))))))\n                (, ,)\n                (VP (VB get)\n                  (NP (PRP it))\n                  (ADVP (RB home)))\n                (, ,)\n                (VP (VB break)\n                  (NP (DT the) (NN seal)))\n                (CC and)\n                (VP (VB use)\n                  (NP (PRP it))\n                  (PRN (-LRB- -LRB-)\n                    (NP (RB very) (JJ clever) (NN con))\n                    (-RRB- -RRB-)))))))))\n    (. .)))']
# (ROOT
#   (S
#     (PP (IN In)
#       (NP (DT the) (NN shop)))
#     (, ,)
#     (NP (DT these) (NNS MacBooks))
#     (VP (VBP are)
#       (VP (VBN encased)
#         (PP (IN in)
#           (NP (DT a) (JJ soft) (NN rubber) (NN enclosure)))
#         (: -)
#         (SBAR (IN so)
#           (S
#             (NP (PRP you))
#             (VP (MD will)
#               (ADVP (RB never))
#               (VP
#                 (VP (VB know)
#                   (PP (IN about)
#                     (NP (DT the) (NN razor) (NN edge)))
#                   (SBAR (IN until)
#                     (S
#                       (NP (PRP you))
#                       (VP (VBP buy)
#                         (NP (PRP it))))))
#                 (, ,)
#                 (VP (VB get)
#                   (NP (PRP it))
#                   (ADVP (RB home)))
#                 (, ,)
#                 (VP (VB break)
#                   (NP (DT the) (NN seal)))
#                 (CC and)
#                 (VP (VB use)
#                   (NP (PRP it))
#                   (PRN (-LRB- -LRB-)
#                     (NP (RB very) (JJ clever) (NN con))
#                     (-RRB- -RRB-)))))))))
#     (. .)))
# the shop
# these MacBooks
# MacBooks
# a soft rubber enclosure
# enclosure
# you
# the razor edge
# edge
# you
# it
# it
# the seal
# seal
# it
# very clever con
# con
# ['(ROOT\n  (S\n    (ADVP (RB However))\n    (, ,)\n    (NP (DT the) (JJ multi-touch) (NNS gestures)\n      (CC and)\n      (JJ large) (NN tracking) (NN area))\n    (VP (VBP make)\n      (S\n        (VP (VBG having)\n          (NP\n            (NP (DT an) (JJ external) (NN mouse))\n            (ADJP\n              (ADJP (JJ unnecessary))\n              (PRN (-LRB- -LRB-)\n                (SBAR (IN unless)\n                  (S\n                    (NP (PRP you))\n                    (VP (VBP are)\n                      (NP (NN gaming)))))\n                (-RRB- -RRB-)))))))\n    (. .)))']
# (ROOT
#   (S
#     (ADVP (RB However))
#     (, ,)
#     (NP (DT the) (JJ multi-touch) (NNS gestures)
#       (CC and)
#       (JJ large) (NN tracking) (NN area))
#     (VP (VBP make)
#       (S
#         (VP (VBG having)
#           (NP
#             (NP (DT an) (JJ external) (NN mouse))
#             (ADJP
#               (ADJP (JJ unnecessary))
#               (PRN (-LRB- -LRB-)
#                 (SBAR (IN unless)
#                   (S
#                     (NP (PRP you))
#                     (VP (VBP are)
#                       (NP (NN gaming)))))
#                 (-RRB- -RRB-)))))))
#     (. .)))
# the multi-touch gestures and large tracking area
# area
# an external mouse unnecessary -LRB- unless you are gaming -RRB-
# mouse
# an external mouse
# you
# gaming
# gaming
# ['(ROOT\n  (S (CC Plus)\n    (NP (PRP it))\n    (VP (VBZ is)\n      (ADJP\n        (ADJP (JJ small))\n        (CC and)\n        (ADJP (RB reasonably) (JJ light)))\n      (SBAR (IN so)\n        (S\n          (NP (PRP I))\n          (VP (MD can)\n            (VP (VB take)\n              (NP (PRP it))\n              (PP (IN with)\n                (NP (PRP me)))\n              (PP (TO to)\n                (CC and)\n                (IN from)\n                (NP (NN work))))))))\n    (. .)))']
# (ROOT
#   (S (CC Plus)
#     (NP (PRP it))
#     (VP (VBZ is)
#       (ADJP
#         (ADJP (JJ small))
#         (CC and)
#         (ADJP (RB reasonably) (JJ light)))
#       (SBAR (IN so)
#         (S
#           (NP (PRP I))
#           (VP (MD can)
#             (VP (VB take)
#               (NP (PRP it))
#               (PP (IN with)
#                 (NP (PRP me)))
#               (PP (TO to)
#                 (CC and)
#                 (IN from)
#                 (NP (NN work))))))))
#     (. .)))
# it
# I
# it
# me
# work
# work
# ['(ROOT\n  (S\n    (NP (PRP I))\n    (VP (VBP HATE)\n      (NP (DT this) (CD one)))\n    (. .)))']
# (ROOT
#   (S
#     (NP (PRP I))
#     (VP (VBP HATE)
#       (NP (DT this) (CD one)))
#     (. .)))
# I
# this one
# one
# ['(ROOT\n  (S\n    (NP (PRP They))\n    (VP (VBD were)\n      (ADJP (RB totally) (JJ unconcerned))\n      (SBAR (IN that)\n        (S\n          (NP (DT the) (NN computer))\n          (VP (VBD was) (RB not)\n            (VP\n              (ADVP (RB correctly))\n              (VBN repaired)\n              (PP (IN in)\n                (NP (DT the) (JJ first) (NN place))))))))\n    (. .)))']
# (ROOT
#   (S
#     (NP (PRP They))
#     (VP (VBD were)
#       (ADJP (RB totally) (JJ unconcerned))
#       (SBAR (IN that)
#         (S
#           (NP (DT the) (NN computer))
#           (VP (VBD was) (RB not)
#             (VP
#               (ADVP (RB correctly))
#               (VBN repaired)
#               (PP (IN in)
#                 (NP (DT the) (JJ first) (NN place))))))))
#     (. .)))
# They
# They
# the computer
# the first place
# place
# ['(ROOT\n  (S\n    (NP (NNP Toshiba))\n    (VP (VBZ does) (RB not)\n      (VP (VB send)\n        (NP (DT any))\n        (ADVP\n          (NP (CD one))\n          (IN out))\n        (SBAR (IN unless)\n          (S\n            (NP (PRP you))\n            (VP (VBP have)\n              (VP (VBN paid)\n                (ADJP (JJ extra)\n                  (S\n                    (VP (TO to)\n                      (VP (VB have)\n                        (NP (DT the)\n                          (ADJP (IN on))\n                          (NN site) (NN repair))\n                        (VP (VBN done))))))))))))\n    (. .)))']
# (ROOT
#   (S
#     (NP (NNP Toshiba))
#     (VP (VBZ does) (RB not)
#       (VP (VB send)
#         (NP (DT any))
#         (ADVP
#           (NP (CD one))
#           (IN out))
#         (SBAR (IN unless)
#           (S
#             (NP (PRP you))
#             (VP (VBP have)
#               (VP (VBN paid)
#                 (ADJP (JJ extra)
#                   (S
#                     (VP (TO to)
#                       (VP (VB have)
#                         (NP (DT the)
#                           (ADJP (IN on))
#                           (NN site) (NN repair))
#                         (VP (VBN done))))))))))))
#     (. .)))
# Toshiba
# Toshiba
# any
# any
# one
# you
# the on site repair
# repair
# ['(ROOT\n  (FRAG\n    (INTJ (UH Oh))\n    (, ,)\n    (NP (NN boy))\n    (. !)))']
# (ROOT
#   (FRAG
#     (INTJ (UH Oh))
#     (, ,)
#     (NP (NN boy))
#     (. !)))
# boy
# boy
# ['(ROOT\n  (S (CC But)\n    (SBAR (IN while)\n      (S\n        (NP (DT this))\n        (VP (VBZ is)\n          (NP (CD one) (JJ big) (NN advantage)))))\n    (PRN (-LRB- -LRB-)\n      (SBAR (IN as)\n        (S\n          (NP (PRP you))\n          (VP (MD may)\n            (VP (VB know)\n              (PP (IN from)\n                (NP\n                  (NP (DT the) (NN company))\n                  (SBAR\n                    (S\n                      (VP (VBZ s)\n                        (NP (JJ recent) (NNS commercials)))))))))))\n      (-RRB- -RRB-))\n    (NP (EX there))\n    (VP (VBP are)\n      (NP (JJ other) (NNS things)\n        (S\n          (VP (TO to)\n            (VP (VB consider)\n              (PP (IN before)\n                (S\n                  (VP (VBG going)\n                    (PP (IN with)\n                      (NP (NNP Apple)))))))))))\n    (. .)))']
# (ROOT
#   (S (CC But)
#     (SBAR (IN while)
#       (S
#         (NP (DT this))
#         (VP (VBZ is)
#           (NP (CD one) (JJ big) (NN advantage)))))
#     (PRN (-LRB- -LRB-)
#       (SBAR (IN as)
#         (S
#           (NP (PRP you))
#           (VP (MD may)
#             (VP (VB know)
#               (PP (IN from)
#                 (NP
#                   (NP (DT the) (NN company))
#                   (SBAR
#                     (S
#                       (VP (VBZ s)
#                         (NP (JJ recent) (NNS commercials)))))))))))
#       (-RRB- -RRB-))
#     (NP (EX there))
#     (VP (VBP are)
#       (NP (JJ other) (NNS things)
#         (S
#           (VP (TO to)
#             (VP (VB consider)
#               (PP (IN before)
#                 (S
#                   (VP (VBG going)
#                     (PP (IN with)
#                       (NP (NNP Apple)))))))))))
#     (. .)))
# this
# this
# one big advantage
# advantage
# you
# the company s recent commercials
# company
# the company
# recent commercials
# commercials
# there
# there
# other things to consider before going with Apple
# things
# Apple
# Apple
# ['(ROOT\n  (S\n    (NP (PRP I))\n    (VP (VBP love)\n      (NP\n        (NP (DT the) (NN way))\n        (SBAR\n          (S\n            (NP\n              (NP (DT the) (JJ entire) (NN suite))\n              (PP (IN of)\n                (NP (NN software))))\n            (VP (VBZ works)\n              (ADVP (RB together)))))))\n    (. .)))']
# (ROOT
#   (S
#     (NP (PRP I))
#     (VP (VBP love)
#       (NP
#         (NP (DT the) (NN way))
#         (SBAR
#           (S
#             (NP
#               (NP (DT the) (JJ entire) (NN suite))
#               (PP (IN of)
#                 (NP (NN software))))
#             (VP (VBZ works)
#               (ADVP (RB together)))))))
#     (. .)))
# I
# the way the entire suite of software works together
# way
# the way
# the entire suite of software
# suite
# the entire suite
# software
# software
# ['(ROOT\n  (S\n    (S\n      (NP (DT The) (NN speed))\n      (VP (VBZ is)\n        (ADJP (JJ incredible))))\n    (CC and)\n    (S\n      (NP (PRP I))\n      (VP (VBP am)\n        (ADJP\n          (ADVP (JJR more) (IN than))\n          (JJ satisfied))))\n    (. .)))']
# (ROOT
#   (S
#     (S
#       (NP (DT The) (NN speed))
#       (VP (VBZ is)
#         (ADJP (JJ incredible))))
#     (CC and)
#     (S
#       (NP (PRP I))
#       (VP (VBP am)
#         (ADJP
#           (ADVP (JJR more) (IN than))
#           (JJ satisfied))))
#     (. .)))
# The speed
# speed
# I
# ['(ROOT\n  (S\n    (PP (IN on)\n      (NP\n        (NP (DT the) (JJ bright) (NN side))\n        (ADVP (IN at) (JJS least))))\n    (NP (PRP I))\n    (VP (VBD was) (RB not)\n      (PP (IN without)\n        (NP\n          (NP (PRP$ my) (NN laptop))\n          (PP (IN for)\n            (NP (RB long) (DT this) (NN time))))))\n    (. !)))']
# (ROOT
#   (S
#     (PP (IN on)
#       (NP
#         (NP (DT the) (JJ bright) (NN side))
#         (ADVP (IN at) (JJS least))))
#     (NP (PRP I))
#     (VP (VBD was) (RB not)
#       (PP (IN without)
#         (NP
#           (NP (PRP$ my) (NN laptop))
#           (PP (IN for)
#             (NP (RB long) (DT this) (NN time))))))
#     (. !)))
# the bright side at least
# side
# the bright side
# I
# my laptop for long this time
# my laptop
# long this time
# time
# ['(ROOT\n  (S\n    (NP (DT This) (NN laptop))\n    (VP (VBZ meets)\n      (SBAR\n        (S\n          (NP\n            (NP (DT every) (NN expectation))\n            (CC and)\n            (NP (NNP Windows) (CD 7)))\n          (VP (VBZ is)\n            (ADJP (JJ great))))))\n    (. !)))']
# (ROOT
#   (S
#     (NP (DT This) (NN laptop))
#     (VP (VBZ meets)
#       (SBAR
#         (S
#           (NP
#             (NP (DT every) (NN expectation))
#             (CC and)
#             (NP (NNP Windows) (CD 7)))
#           (VP (VBZ is)
#             (ADJP (JJ great))))))
#     (. !)))
# This laptop
# every expectation and Windows 7
# Windows
# every expectation
# expectation
# Windows 7
# ['(ROOT\n  (FRAG\n    (S\n      (NP (WDT that))\n      (VP (VBZ has)))\n    (: /)\n    (FRAG\n      (NP\n        (NP (DT that))\n        (SBAR\n          (S\n            (VP (VBZ is)\n              (SBAR\n                (WHADVP (WRB how))\n                (S\n                  (VP (VBG frustrating)\n                    (NP (PRP it)))))))))\n      (X (VBD was)))\n    (. .)))']
# (ROOT
#   (FRAG
#     (S
#       (NP (WDT that))
#       (VP (VBZ has)))
#     (: /)
#     (FRAG
#       (NP
#         (NP (DT that))
#         (SBAR
#           (S
#             (VP (VBZ is)
#               (SBAR
#                 (WHADVP (WRB how))
#                 (S
#                   (VP (VBG frustrating)
#                     (NP (PRP it)))))))))
#       (X (VBD was)))
#     (. .)))
# that
# that
# that is how frustrating it
# that
# it
# ['(ROOT\n  (S\n    (NP (PRP I))\n    (VP (MD can)\n      (ADVP (RB barely))\n      (VP (VB use)\n        (NP (DT any) (NN usb) (NNS devices))\n        (SBAR (IN because)\n          (S\n            (NP (PRP they))\n            (VP (MD will) (RB not)\n              (VP (VB stay)\n                (ADJP (JJ connected))\n                (ADVP (RB properly))))))))\n    (. .)))']
# (ROOT
#   (S
#     (NP (PRP I))
#     (VP (MD can)
#       (ADVP (RB barely))
#       (VP (VB use)
#         (NP (DT any) (NN usb) (NNS devices))
#         (SBAR (IN because)
#           (S
#             (NP (PRP they))
#             (VP (MD will) (RB not)
#               (VP (VB stay)
#                 (ADJP (JJ connected))
#                 (ADVP (RB properly))))))))
#     (. .)))
# I
# any usb devices
# devices
# they
# ['(ROOT\n  (S\n    (NP\n      (NP (DT The)\n        (ADVP\n          (NP (CD one))\n          (IN down))\n        (NN side))\n      (PP (TO to)\n        (NP (PRP it))))\n    (VP (VBZ is)\n      (SBAR (IN that)\n        (S\n          (SBAR\n            (WHADVP (WRB when))\n            (S\n              (NP (PRP I))\n              (VP (VBP play)\n                (NP\n                  (NP (DT a) (NN certin) (NN game))\n                  (PP (IN on)\n                    (NP (RB here)))))))\n          (, ,)\n          (NP (PRP it))\n          (VP\n            (VP (VBZ tends)\n              (S\n                (VP (TO to)\n                  (VP (VB freeze)\n                    (PRT (RP up))\n                    (ADVP (RB sometimes))))))\n            (, ,)\n            (CC but)\n            (VP (VBZ thats)\n              (NP (DT the) (RB only) (JJ bad) (NN thing))\n              (PP (IN about)\n                (NP (DT this) (NN computer))))))))\n    (. .)))']
# (ROOT
#   (S
#     (NP
#       (NP (DT The)
#         (ADVP
#           (NP (CD one))
#           (IN down))
#         (NN side))
#       (PP (TO to)
#         (NP (PRP it))))
#     (VP (VBZ is)
#       (SBAR (IN that)
#         (S
#           (SBAR
#             (WHADVP (WRB when))
#             (S
#               (NP (PRP I))
#               (VP (VBP play)
#                 (NP
#                   (NP (DT a) (NN certin) (NN game))
#                   (PP (IN on)
#                     (NP (RB here)))))))
#           (, ,)
#           (NP (PRP it))
#           (VP
#             (VP (VBZ tends)
#               (S
#                 (VP (TO to)
#                   (VP (VB freeze)
#                     (PRT (RP up))
#                     (ADVP (RB sometimes))))))
#             (, ,)
#             (CC but)
#             (VP (VBZ thats)
#               (NP (DT the) (RB only) (JJ bad) (NN thing))
#               (PP (IN about)
#                 (NP (DT this) (NN computer))))))))
#     (. .)))
# The one down side to it
# The one down side
# one
# it
# I
# a certin game on here
# game
# a certin game
# here
# here
# it
# the only bad thing
# this computer
# ['(ROOT\n  (PRN (: -)\n    (FRAG\n      (PP\n        (NP (UH No))\n        (PP\n          (NP\n            (NP\n              (NP (JJ backlit) (NN keyboard))\n              (, ,)\n              (ADVP (CC but)))\n            (ADVP (RB not)\n              (NP (DT an) (NN issue))))\n          (PP (IN for))))\n      (NP (PRP me)))\n    (. .)))']
# (ROOT
#   (PRN (: -)
#     (FRAG
#       (PP
#         (NP (UH No))
#         (PP
#           (NP
#             (NP
#               (NP (JJ backlit) (NN keyboard))
#               (, ,)
#               (ADVP (CC but)))
#             (ADVP (RB not)
#               (NP (DT an) (NN issue))))
#           (PP (IN for))))
#       (NP (PRP me)))
#     (. .)))
# No
# No
# backlit keyboard , but not an issue
# keyboard
# backlit keyboard , but
# backlit keyboard
# an issue
# issue
# me
# ['(ROOT\n  (S\n    (S\n      (SBAR\n        (WHADVP (WRB When))\n        (S\n          (NP (PRP I))\n          (ADVP (RB finally))\n          (VP (VBD had)\n            (NP (NN everything))\n            (S\n              (VP (VBG running)\n                (PP (IN with)\n                  (NP (DT all)))\n                (NP\n                  (NP (PRP$ my) (NN software))\n                  (VP (VBN installed))))))))\n      (NP (PRP I))\n      (VP (VBD plugged)\n        (PP (IN in)\n          (NP (PRP$ my) (NN droid)\n            (S\n              (VP (TO to)\n                (VP (VB recharge))))))))\n    (CC and)\n    (S\n      (NP (DT the) (NN system))\n      (VP (VBD crashed)))\n    (. .)))']
# (ROOT
#   (S
#     (S
#       (SBAR
#         (WHADVP (WRB When))
#         (S
#           (NP (PRP I))
#           (ADVP (RB finally))
#           (VP (VBD had)
#             (NP (NN everything))
#             (S
#               (VP (VBG running)
#                 (PP (IN with)
#                   (NP (DT all)))
#                 (NP
#                   (NP (PRP$ my) (NN software))
#                   (VP (VBN installed))))))))
#       (NP (PRP I))
#       (VP (VBD plugged)
#         (PP (IN in)
#           (NP (PRP$ my) (NN droid)
#             (S
#               (VP (TO to)
#                 (VP (VB recharge))))))))
#     (CC and)
#     (S
#       (NP (DT the) (NN system))
#       (VP (VBD crashed)))
#     (. .)))
# I
# everything
# everything
# all
# all
# my software installed
# my software
# I
# my droid to recharge
# droid
# the system
# system
# ['(ROOT\n  (S\n    (NP (PRP I))\n    (VP (MD can) (RB not)\n      (ADVP (RB even))\n      (VP (VB turn)\n        (NP (PRP it))\n        (PRT (RP off))))\n    (. .)))']
# (ROOT
#   (S
#     (NP (PRP I))
#     (VP (MD can) (RB not)
#       (ADVP (RB even))
#       (VP (VB turn)
#         (NP (PRP it))
#         (PRT (RP off))))
#     (. .)))
# I
# it
# ['(ROOT\n  (S\n    (NP (CD One) (NN suggestion))\n    (PRN\n      (S\n        (NP (PRP I))\n        (VP (VBP do)\n          (VP (VB have))))\n      (, ,))\n    (VP (VBZ is)\n      (S\n        (VP (TO to) (RB not)\n          (VP (VB bother)\n            (S\n              (VP (VBG getting)\n                (NP (NNP Microsoft) (NN office))\n                (PP (IN for)\n                  (S\n                    (NP (DT the) (NN mac))\n                    (VP (VBG expecting)\n                      (SBAR\n                        (S\n                          (NP (PRP it))\n                          (VP (MD will)\n                            (VP (VB work)\n                              (SBAR (RB just) (IN like)\n                                (S\n                                  (NP (PRP you))\n                                  (VP (VBD knew)\n                                    (NP (PRP it))\n                                    (PP (TO to))\n                                    (PP (IN on)\n                                      (NP (DT a) (NN PC)))))))))))))))))))\n    (. .)))']
# (ROOT
#   (S
#     (NP (CD One) (NN suggestion))
#     (PRN
#       (S
#         (NP (PRP I))
#         (VP (VBP do)
#           (VP (VB have))))
#       (, ,))
#     (VP (VBZ is)
#       (S
#         (VP (TO to) (RB not)
#           (VP (VB bother)
#             (S
#               (VP (VBG getting)
#                 (NP (NNP Microsoft) (NN office))
#                 (PP (IN for)
#                   (S
#                     (NP (DT the) (NN mac))
#                     (VP (VBG expecting)
#                       (SBAR
#                         (S
#                           (NP (PRP it))
#                           (VP (MD will)
#                             (VP (VB work)
#                               (SBAR (RB just) (IN like)
#                                 (S
#                                   (NP (PRP you))
#                                   (VP (VBD knew)
#                                     (NP (PRP it))
#                                     (PP (TO to))
#                                     (PP (IN on)
#                                       (NP (DT a) (NN PC)))))))))))))))))))
#     (. .)))
# One suggestion
# suggestion
# I
# Microsoft office
# office
# the mac
# mac
# it
# you
# it
# a PC
# ['(ROOT\n  (S\n    (S\n      (VP (VBG Pairing)\n        (NP (PRP it))\n        (SBAR (IN with)\n          (S\n            (NP (DT an) (NNP iPhone))\n            (VP (VBZ is)\n              (NP\n                (NP (DT a) (JJ pure) (NN pleasure))\n                (PRN (: -)\n                  (S\n                    (VP (VB talk)\n                      (PP (IN about)\n                        (NP (JJ painless) (NN syncing)))))\n                  (: -))\n                (VP (VBN used)\n                  (S\n                    (VP (TO to)\n                      (VP (VB take)\n                        (NP (PRP me))\n                        (ADVP (RB forever))))))))))))\n    (PRN (: -)\n      (S\n        (ADVP (RB now))\n        (NP (PRP it))\n        (VP (VBZ has)))\n      (: /))\n    (NP (PRP it))\n    (VP (VBZ is)\n      (NP (DT a) (NN snap)))\n    (. .)))']
# (ROOT
#   (S
#     (S
#       (VP (VBG Pairing)
#         (NP (PRP it))
#         (SBAR (IN with)
#           (S
#             (NP (DT an) (NNP iPhone))
#             (VP (VBZ is)
#               (NP
#                 (NP (DT a) (JJ pure) (NN pleasure))
#                 (PRN (: -)
#                   (S
#                     (VP (VB talk)
#                       (PP (IN about)
#                         (NP (JJ painless) (NN syncing)))))
#                   (: -))
#                 (VP (VBN used)
#                   (S
#                     (VP (TO to)
#                       (VP (VB take)
#                         (NP (PRP me))
#                         (ADVP (RB forever))))))))))))
#     (PRN (: -)
#       (S
#         (ADVP (RB now))
#         (NP (PRP it))
#         (VP (VBZ has)))
#       (: /))
#     (NP (PRP it))
#     (VP (VBZ is)
#       (NP (DT a) (NN snap)))
#     (. .)))
# it
# an iPhone
# iPhone
# a pure pleasure - talk about painless syncing - used to take me forever
# pleasure
# a pure pleasure
# painless syncing
# syncing
# me
# it
# it
# a snap
# snap
# ['(ROOT\n  (S\n    (NP (PRP I))\n    (VP (VBD shopped)\n      (PRT (RP around))\n      (PP (IN before)\n        (S\n          (VP (VBG buying)))))\n    (. .)))']
# (ROOT
#   (S
#     (NP (PRP I))
#     (VP (VBD shopped)
#       (PRT (RP around))
#       (PP (IN before)
#         (S
#           (VP (VBG buying)))))
#     (. .)))
# I
# ["(ROOT\n  (S\n    (NP (PRP I))\n    (ADVP (RB also))\n    (VP (VBD got)\n      (S\n        (NP\n          (NP (DT the) (VBN added) (NN bonus))\n          (PP (IN of)\n            (NP (DT a) (CD 30) ('' '') (NN HD)))))\n      (NP-TMP\n        (NP (NNP Monitor))\n        (, ,)\n        (SBAR\n          (WHNP (WDT which))\n          (S\n            (ADVP (RB really))\n            (VP (VBZ helps)\n              (S\n                (VP (TO to)\n                  (VP\n                    (VP (VB extend)\n                      (NP (PRP$ my) (NN screen)))\n                    (CC and)\n                    (VP (VB keep)\n                      (S\n                        (NP (PRP$ my) (NNS eyes))\n                        (ADJP (JJ fresh))))))))))))\n    (. !)))"]
# (ROOT
#   (S
#     (NP (PRP I))
#     (ADVP (RB also))
#     (VP (VBD got)
#       (S
#         (NP
#           (NP (DT the) (VBN added) (NN bonus))
#           (PP (IN of)
#             (NP (DT a) (CD 30) ('' '') (NN HD)))))
#       (NP-TMP
#         (NP (NNP Monitor))
#         (, ,)
#         (SBAR
#           (WHNP (WDT which))
#           (S
#             (ADVP (RB really))
#             (VP (VBZ helps)
#               (S
#                 (VP (TO to)
#                   (VP
#                     (VP (VB extend)
#                       (NP (PRP$ my) (NN screen)))
#                     (CC and)
#                     (VP (VB keep)
#                       (S
#                         (NP (PRP$ my) (NNS eyes))
#                         (ADJP (JJ fresh))))))))))))
#     (. !)))
# I
# the added bonus of a 30 '' HD
# bonus
# the added bonus
# a 30 '' HD
# HD
# Monitor
# Monitor
# my screen
# my eyes
# eyes
# ['(ROOT\n  (S\n    (VP (MD Would)\n      (VP (VB do)\n        (NP (NN business))\n        (ADVP (RB again))))\n    (. .)))']
# (ROOT
#   (S
#     (VP (MD Would)
#       (VP (VB do)
#         (NP (NN business))
#         (ADVP (RB again))))
#     (. .)))
# business
# business
# ['(ROOT\n  (S\n    (NP (DT The) (NN machine))\n    (VP (VBZ is)\n      (NP\n        (ADJP (JJ slow)\n          (PP (TO to)\n            (NP\n              (NP (NN boot))\n              (ADVP (RB up)\n                (CC and)\n                (RB occasionally)))))\n        (NNS crashes))\n      (ADVP (RB completely)))\n    (. .)))']
# (ROOT
#   (S
#     (NP (DT The) (NN machine))
#     (VP (VBZ is)
#       (NP
#         (ADJP (JJ slow)
#           (PP (TO to)
#             (NP
#               (NP (NN boot))
#               (ADVP (RB up)
#                 (CC and)
#                 (RB occasionally)))))
#         (NNS crashes))
#       (ADVP (RB completely)))
#     (. .)))
# The machine
# machine
# slow to boot up and occasionally crashes
# crashes
# boot up and occasionally
# boot
# boot
# ...
# (ROOT
#   (S
#     (NP
#       (NP (DT The) (NN fact))
#       (SBAR (IN that)
#         (S
#           (NP (PRP you))
#           (VP (MD can)
#             (VP (VB spend)
#               (PP (IN over)
#                 (NP
#                   (NP ($ $) (CD 100))
#                   (PP (IN on)
#                     (NP (RB just) (DT a) (NN webcam))))))))))
#     (VP (VBZ underscores)
#       (NP
#         (NP (DT the) (NN value))
#         (PP (IN of)
#           (NP (DT this) (NN machine)))))
#     (. .)))
# The fact that you can spend over $ 100 on just a webcam
# fact
# The fact
# you
# $ 100 on just a webcam
# 100
# $ 100
# just a webcam
# webcam
# the value of this machine
# value
# the value
# this machine
# ['(ROOT\n  (S\n    (NP (PRP I))\n    (ADVP (RB mainly))\n    (VP (VBP use)\n      (NP (PRP it))\n      (PP (IN for)\n        (NP\n          (NP (NN email))\n          (, ,)\n          (NP (NN internet))\n          (, ,)\n          (CC and)\n          (NP\n            (NP (VBG managing) (JJ personal) (NNS files))\n            (PRN (-LRB- -LRB-)\n              (NP (NNS pics) (, ,) (NNS vids) (, ,) (FW etc.))\n              (-RRB- -RRB-))))))\n    (. .)))']
# (ROOT
#   (S
#     (NP (PRP I))
#     (ADVP (RB mainly))
#     (VP (VBP use)
#       (NP (PRP it))
#       (PP (IN for)
#         (NP
#           (NP (NN email))
#           (, ,)
#           (NP (NN internet))
#           (, ,)
#           (CC and)
#           (NP
#             (NP (VBG managing) (JJ personal) (NNS files))
#             (PRN (-LRB- -LRB-)
#               (NP (NNS pics) (, ,) (NNS vids) (, ,) (FW etc.))
#               (-RRB- -RRB-))))))
#     (. .)))
# I
# it
# email , internet , and managing personal files -LRB- pics , vids , etc. -RRB-
# email
# internet
# internet
# managing personal files -LRB- pics , vids , etc. -RRB-
# managing personal files
# pics , vids , etc.
# vids
# ['(ROOT\n  (S\n    (S\n      (UCP\n        (NP-TMP (DT A) (NN month))\n        (CC or)\n        (ADVP (RB so) (RB ago))))\n    (, ,)\n    (S\n      (NP (DT the) (VBG freaking) (NN motherboard))\n      (ADVP (RB just))\n      (VP (VBD died)))\n    (. .)))']
# (ROOT
#   (S
#     (S
#       (UCP
#         (NP-TMP (DT A) (NN month))
#         (CC or)
#         (ADVP (RB so) (RB ago))))
#     (, ,)
#     (S
#       (NP (DT the) (VBG freaking) (NN motherboard))
#       (ADVP (RB just))
#       (VP (VBD died)))
#     (. .)))
# the freaking motherboard
# motherboard
# ['(ROOT\n  (S\n    (S\n      (NP\n        (NP (DT The) (NN system))\n        (SBAR\n          (S\n            (NP (PRP it))\n            (VP (VBZ comes)\n              (PP (IN with))))))\n      (VP (VBZ does) (RB not)\n        (VP (VB work)\n          (ADVP (RB properly)))))\n    (, ,) (RB so)\n    (S\n      (SBAR\n        (WHADVP (WRB when))\n        (S\n          (VP (VBG trying)\n            (S\n              (VP (TO to)\n                (VP (VB fix)\n                  (NP (DT the) (NNS problems))\n                  (PP (IN with)\n                    (NP (PRP it)))))))))\n      (NP (PRP it))\n      (VP (VBD started)\n        (S (RB not)\n          (VP (VBG working)\n            (ADVP (IN at) (DT all))))))\n    (. .)))']
# (ROOT
#   (S
#     (S
#       (NP
#         (NP (DT The) (NN system))
#         (SBAR
#           (S
#             (NP (PRP it))
#             (VP (VBZ comes)
#               (PP (IN with))))))
#       (VP (VBZ does) (RB not)
#         (VP (VB work)
#           (ADVP (RB properly)))))
#     (, ,) (RB so)
#     (S
#       (SBAR
#         (WHADVP (WRB when))
#         (S
#           (VP (VBG trying)
#             (S
#               (VP (TO to)
#                 (VP (VB fix)
#                   (NP (DT the) (NNS problems))
#                   (PP (IN with)
#                     (NP (PRP it)))))))))
#       (NP (PRP it))
#       (VP (VBD started)
#         (S (RB not)
#           (VP (VBG working)
#             (ADVP (IN at) (DT all))))))
#     (. .)))
# The system it comes with
# The system
# it
# the problems
# it
# it
# ['(ROOT\n  (S (RB Then)\n    (PP (IN after)\n      (NP\n        (QP (CD 4)\n          (CC or)\n          (RB so))\n        (NNS months)))\n    (NP (DT the) (NN charger))\n    (VP (VBD stopped)\n      (S\n        (VP (VBG working)\n          (SBAR (RB so)\n            (S\n              (NP (PRP I))\n              (VP (VBD was)\n                (VP (VBN forced)\n                  (S\n                    (VP (TO to)\n                      (VP\n                        (VP (VB go)\n                          (PRT (RP out)))\n                        (CC and)\n                        (VP (VB buy)\n                          (NP (JJ new) (NN hardware))\n                          (ADVP (RB just))\n                          (S\n                            (VP (TO to)\n                              (VP (VB keep)\n                                (NP (DT this) (NN computer) (NN running))))))))))))))))\n    (. .)))']
# (ROOT
#   (S (RB Then)
#     (PP (IN after)
#       (NP
#         (QP (CD 4)
#           (CC or)
#           (RB so))
#         (NNS months)))
#     (NP (DT the) (NN charger))
#     (VP (VBD stopped)
#       (S
#         (VP (VBG working)
#           (SBAR (RB so)
#             (S
#               (NP (PRP I))
#               (VP (VBD was)
#                 (VP (VBN forced)
#                   (S
#                     (VP (TO to)
#                       (VP
#                         (VP (VB go)
#                           (PRT (RP out)))
#                         (CC and)
#                         (VP (VB buy)
#                           (NP (JJ new) (NN hardware))
#                           (ADVP (RB just))
#                           (S
#                             (VP (TO to)
#                               (VP (VB keep)
#                                 (NP (DT this) (NN computer) (NN running))))))))))))))))
#     (. .)))
# 4 or so months
# the charger
# charger
# I
# new hardware
# hardware
# this computer running
# running
# ['(ROOT\n  (S\n    (NP (PRP I))\n    (VP\n      (VP (VBD took)\n        (SBAR\n          (S\n            (NP (PRP it))\n            (ADVP (RB back)\n              (PP (TO to)\n                (NP (JJS Best))))\n            (VP (VB Buy)\n              (SBAR\n                (WHADVP (WRB where))\n                (S\n                  (NP (PRP they))\n                  (VP (VBD were)\n                    (ADJP (RB so) (JJ helpful)))))))))\n      (CC and)\n      (ADVP (RB immediately))\n      (VP (VBD gave)\n        (NP (PRP me))\n        (NP (DT a) (JJ new) (CD one))))\n    (. .)))']
# (ROOT
#   (S
#     (NP (PRP I))
#     (VP
#       (VP (VBD took)
#         (SBAR
#           (S
#             (NP (PRP it))
#             (ADVP (RB back)
#               (PP (TO to)
#                 (NP (JJS Best))))
#             (VP (VB Buy)
#               (SBAR
#                 (WHADVP (WRB where))
#                 (S
#                   (NP (PRP they))
#                   (VP (VBD were)
#                     (ADJP (RB so) (JJ helpful)))))))))
#       (CC and)
#       (ADVP (RB immediately))
#       (VP (VBD gave)
#         (NP (PRP me))
#         (NP (DT a) (JJ new) (CD one))))
#     (. .)))
# I
# it
# Best
# Best
# they
# me
# a new one
# ['(ROOT\n  (S\n    (SBAR (IN If)\n      (S\n        (NP (PRP you))\n        (VP (VBD had)\n          (NP\n            (NP (NN PC))\n            (PP (IN for)\n              (NP (CD four) (NNS years)))))))\n    (NP (PRP I))\n    (VP (MD can)\n      (ADVP (RB almost))\n      (VP (VB gaurentee)\n        (SBAR (IN that)\n          (S\n            (NP (NN something))\n            (VP (MD would)\n              (PP (IN of))\n              (VP (VBN gone)\n                (ADVP (JJ wrong)\n                  (PP (IN by)\n                    (ADVP (RB now))))\n                (, ,)\n                (ADVP (RB maybe) (RB even)\n                  (S\n                    (VP (VBG forcing)\n                      (S\n                        (NP (PRP you))\n                        (VP (TO to)\n                          (VP (VB replace)\n                            (NP (PRP$ your) (JJ entire) (NN computer))))))))))))))\n    (. .)))']
# (ROOT
#   (S
#     (SBAR (IN If)
#       (S
#         (NP (PRP you))
#         (VP (VBD had)
#           (NP
#             (NP (NN PC))
#             (PP (IN for)
#               (NP (CD four) (NNS years)))))))
#     (NP (PRP I))
#     (VP (MD can)
#       (ADVP (RB almost))
#       (VP (VB gaurentee)
#         (SBAR (IN that)
#           (S
#             (NP (NN something))
#             (VP (MD would)
#               (PP (IN of))
#               (VP (VBN gone)
#                 (ADVP (JJ wrong)
#                   (PP (IN by)
#                     (ADVP (RB now))))
#                 (, ,)
#                 (ADVP (RB maybe) (RB even)
#                   (S
#                     (VP (VBG forcing)
#                       (S
#                         (NP (PRP you))
#                         (VP (TO to)
#                           (VP (VB replace)
#                             (NP (PRP$ your) (JJ entire) (NN computer))))))))))))))
#     (. .)))
# you
# PC for four years
# PC
# four years
# I
# something
# something
# you
# your entire computer
# ["(ROOT\n  (S\n    (SBAR\n      (X (SYM *))\n      (S\n        (S\n          (PP\n            (NP (CD 2) (NNS weeks))\n            (IN after)\n            (S\n              (VP (VBG giving)\n                (S\n                  (NP\n                    (NP (DT the) (NN computer))\n                    (PP (IN for)\n                      (NP (NN repair))))\n                  (VP\n                    (X (SYM *))\n                    (: -)\n                    (VP (VBN Called)\n                      (NP (NN headquarters))))))))\n          (, ,)\n          (NP (PRP they))\n          (VP (VBP report)\n            (SBAR (IN that)\n              (S\n                (NP (PRP they))\n                (VP (VBP have) (RB not)\n                  (VP (VBN looked)\n                    (PP (IN at)\n                      (NP (PRP it)))\n                    (ADVP (RB yet))))))))\n        (CC but)\n        (S\n          (NP (PRP it))\n          (VP (VBZ is) (`` ``)\n            (PP (IN on)\n              (NP\n                (NP (DT the) (NN top))\n                (PP (IN of)\n                  (NP (DT the)))))))))\n    (VP (VBP stack) ('' ''))\n    (. .)))"]
# (ROOT
#   (S
#     (SBAR
#       (X (SYM *))
#       (S
#         (S
#           (PP
#             (NP (CD 2) (NNS weeks))
#             (IN after)
#             (S
#               (VP (VBG giving)
#                 (S
#                   (NP
#                     (NP (DT the) (NN computer))
#                     (PP (IN for)
#                       (NP (NN repair))))
#                   (VP
#                     (X (SYM *))
#                     (: -)
#                     (VP (VBN Called)
#                       (NP (NN headquarters))))))))
#           (, ,)
#           (NP (PRP they))
#           (VP (VBP report)
#             (SBAR (IN that)
#               (S
#                 (NP (PRP they))
#                 (VP (VBP have) (RB not)
#                   (VP (VBN looked)
#                     (PP (IN at)
#                       (NP (PRP it)))
#                     (ADVP (RB yet))))))))
#         (CC but)
#         (S
#           (NP (PRP it))
#           (VP (VBZ is) (`` ``)
#             (PP (IN on)
#               (NP
#                 (NP (DT the) (NN top))
#                 (PP (IN of)
#                   (NP (DT the)))))))))
#     (VP (VBP stack) ('' ''))
#     (. .)))
# 2 weeks
# weeks
# the computer for repair
# the computer
# repair
# headquarters
# headquarters
# they
# they
# it
# it
# the top of the
# top
# the top
# the
# the
# ['(ROOT\n  (S\n    (NP (DT This) (NN machine))\n    (VP (VBZ delivers))\n    (. .)))']
# (ROOT
#   (S
#     (NP (DT This) (NN machine))
#     (VP (VBZ delivers))
#     (. .)))
# This machine
# ['(ROOT\n  (S (RB Then)\n    (S\n      (NP\n        (NP (CD 2))\n        (PP (IN of)\n          (NP (PRP$ my) (NNS nephews))))\n      (VP (VBD were)\n        (VP (VBG going)\n          (PP (IN into)\n            (NP (NN music))))))\n    (CC and)\n    (S\n      (NP (DT both))\n      (VP (VBD fell)\n        (PP (IN in)\n          (NP (NN love)))\n        (PP (IN with)\n          (NP\n            (NP (DT the) (NNP MacBook))\n            (NP (FW Pro))))))\n    (. .)))']
# (ROOT
#   (S (RB Then)
#     (S
#       (NP
#         (NP (CD 2))
#         (PP (IN of)
#           (NP (PRP$ my) (NNS nephews))))
#       (VP (VBD were)
#         (VP (VBG going)
#           (PP (IN into)
#             (NP (NN music))))))
#     (CC and)
#     (S
#       (NP (DT both))
#       (VP (VBD fell)
#         (PP (IN in)
#           (NP (NN love)))
#         (PP (IN with)
#           (NP
#             (NP (DT the) (NNP MacBook))
#             (NP (FW Pro))))))
#     (. .)))
# 2 of my nephews
# 2
# my nephews
# nephews
# music
# music
# both
# both
# love
# love
# the MacBook Pro
# Pro
# the MacBook
# MacBook
# Pro
# ['(ROOT\n  (S\n    (NP (PRP I))\n    (VP (VBP complain)\n      (ADVP (RB again)))\n    (: ...)))']
# (ROOT
#   (S
#     (NP (PRP I))
#     (VP (VBP complain)
#       (ADVP (RB again)))
#     (: ...)))
# I
# ['(ROOT\n  (S\n    (NP (DT This) (NN laptop))\n    (VP (VBZ is)\n      (ADJP (JJ insane)))\n    (. !!!)))']
# (ROOT
#   (S
#     (NP (DT This) (NN laptop))
#     (VP (VBZ is)
#       (ADJP (JJ insane)))
#     (. !!!)))
# This laptop
# ['(ROOT\n  (S\n    (SBAR (IN If)\n      (S\n        (NP (DT a) (NN website))\n        (ADVP (RB ever))\n        (VP\n          (VP (VBZ freezes))\n          (PRN (-LRB- -LRB-)\n            (SBAR\n              (WHNP (WDT which))\n              (S\n                (VP (VBZ is)\n                  (ADJP (JJ rare)))))\n            (-RRB- -RRB-)))))\n    (, ,)\n    (NP\n      (NP (PRP$ its))\n      (ADJP (RB really) (JJ easy)\n        (S\n          (VP (TO to)\n            (VP (VB force))))))\n    (VP (VB quit))\n    (. .)))']
# (ROOT
#   (S
#     (SBAR (IN If)
#       (S
#         (NP (DT a) (NN website))
#         (ADVP (RB ever))
#         (VP
#           (VP (VBZ freezes))
#           (PRN (-LRB- -LRB-)
#             (SBAR
#               (WHNP (WDT which))
#               (S
#                 (VP (VBZ is)
#                   (ADJP (JJ rare)))))
#             (-RRB- -RRB-)))))
#     (, ,)
#     (NP
#       (NP (PRP$ its))
#       (ADJP (RB really) (JJ easy)
#         (S
#           (VP (TO to)
#             (VP (VB force))))))
#     (VP (VB quit))
#     (. .)))
# a website
# website
# its really easy to force
# its
# its
# ['(ROOT\n  (S\n    (S\n      (NP (PRP It))\n      (VP (VBZ does)\n        (VP (VB run)\n          (ADJP\n            (NP (DT a) (JJ little))\n            (JJ warm)))))\n    (CC but)\n    (S\n      (NP (DT that))\n      (VP (VBZ is)\n        (NP (DT a) (JJ negligible) (NN concern))))\n    (. .)))']
# (ROOT
#   (S
#     (S
#       (NP (PRP It))
#       (VP (VBZ does)
#         (VP (VB run)
#           (ADJP
#             (NP (DT a) (JJ little))
#             (JJ warm)))))
#     (CC but)
#     (S
#       (NP (DT that))
#       (VP (VBZ is)
#         (NP (DT a) (JJ negligible) (NN concern))))
#     (. .)))
# It
# a little
# little
# that
# a negligible concern
# ['(ROOT\n  (S\n    (NP (PRP It))\n    (ADVP (RB rarely))\n    (VP\n      (VP (VBZ works))\n      (CC and)\n      (VP\n        (SBAR\n          (WHADVP (WRB when))\n          (S\n            (NP (PRP it))\n            (VP (VBZ does)\n              (SBAR\n                (S\n                  (NP (PRP it))\n                  (VP\n                    (VP (VBZ has))\n                    (PRN (: /)\n                      (S\n                        (NP (PRP it))\n                        (VP (VBZ is)\n                          (ADJP (RB incredibly) (JJ slow)))))))))))))\n    (. .)))']
# (ROOT
#   (S
#     (NP (PRP It))
#     (ADVP (RB rarely))
#     (VP
#       (VP (VBZ works))
#       (CC and)
#       (VP
#         (SBAR
#           (WHADVP (WRB when))
#           (S
#             (NP (PRP it))
#             (VP (VBZ does)
#               (SBAR
#                 (S
#                   (NP (PRP it))
#                   (VP
#                     (VP (VBZ has))
#                     (PRN (: /)
#                       (S
#                         (NP (PRP it))
#                         (VP (VBZ is)
#                           (ADJP (RB incredibly) (JJ slow)))))))))))))
#     (. .)))
# It
# it
# it
# it

# %%
from nltk.corpus import wordnet

morphy_tag = {'NN':wordnet.NOUN,'NNP':wordnet.NOUN,'JJR':wordnet.ADJ,'JJS':wordnet.ADJ,'VBN':wordnet.VERB,'VBG':wordnet.VERB,'VBP':wordnet.VERB,'VBZ':wordnet.VERB,'VBD':wordnet.VERB,'RB':wordnet.ADV,'VBG':wordnet.VERB,'RBS':wordnet.ADV,'RBR':wordnet.ADV,'RBS':wordnet.ADV}



 #ADJ, ADJ_SAT, ADV, NOUN, VERB = 'a', 's', 'r', 'n', 'v'
#}
print(head_word)
# Out:
# ['I', 'it', 'night', 'cord', 'me', 'life', 'laptop', 'problems', 'computer', 'guy', 'center', 'exchange', 'concern', 'team', 'sales', 'shop', 'netbook', 'netbooks', 'NB305-N410BL', 'day', 'presentation', 'seminar', 'lots', 'conference', 'town', 'people', 'prep', 'etc.', 'projector', 'quality', 'GUI', 'applications', 'Easy', 'much', 'laptops', 'Sad', 'son', 'features', 'more', 'iChat', 'Photobooth', 'band', 'PC', 'phone', 'they', 'nothing', 'problem', 'thing', 'light', 'dark', 'money', 'while', 'Fund', 'disappointment', 'model', 'ones', 'line', 'cards', 'processor', 'trade-off', 'you', 'hours', 'Asus', 'screen', 'battery', 'MacBooks', 'enclosure', 'edge', 'seal', 'con', 'area', 'mouse', 'gaming', 'work', 'one', 'They', 'place', 'Toshiba', 'any', 'repair', 'boy', 'this', 'advantage', 'company', 'commercials', 'there', 'things', 'Apple', 'way', 'suite', 'software', 'speed', 'side', 'time', 'Windows', 'expectation', 'that', 'devices', 'game', 'here', 'No', 'keyboard', 'issue', 'everything', 'all', 'droid', 'system', 'suggestion', 'office', 'mac', 'iPhone', 'pleasure', 'syncing', 'snap', 'bonus', 'HD', 'Monitor', 'eyes', 'business', 'machine', 'crashes', 'boot', 'dollars', 'service', 'luxury', 'sarcasm', '2', 'waste', 'It', 'experience', 'There', 'flaws', 'nickel', 'penny', 'dime', 'version', 'couple', 'months', ':-RRB-', 'years', 'virus', 'products', 'them', 'future', 'XL', 'price', 'some', 'attempts', 'clock', 'setup', 'techie', 'YOU', 'TALK', 'SERVICE', 'OUT', 'COUNTRY', 'thousands', 'needs', 'device', 'i', 'brand', 'warranty', 'experine', 'part', 'days', 'friends', 'thats', 'self', 'addict', 'these', 'reasons', 'pro', 'fan', 'desparation', 'number', 'priviledge', 'technician', 'card', 'trip', 'email', 'disc', 'windows', 'claims', 'files', 'Drivers', 'ok', 'BIOS', 'month', 'Support', 'This', 'shoulders', 'first', 'browser', 'Mac', 'defrags', 'itself', 'punds', 'program', 'sixteen', 'warrenty', 'help', 'purchase', 'Warranty', 'IT', 'Quality', 'Amazing', 'fact', '100', 'webcam', 'value', 'internet', 'vids', 'motherboard', 'charger', 'hardware', 'running', 'Best', 'something', 'weeks', 'headquarters', 'top', 'the', 'nephews', 'music', 'both', 'love', 'Pro', 'MacBook', 'website', 'its', 'little']

# %%
len(head_word)
# Out:
# 231

# %%
from stanfordcorenlp import StanfordCoreNLP as scn
sen="the food was best but the serving was poor"
nlp=scn('/home/vibha/Downloads/stanford-corenlp-full-2018-10-05')

def get_governor_words(sen):
    check_list=['amod','nsubj','dep','dboj']
    a=nlp.dependency_parse(sen)
    print(a)
    l=[]
    for i in a:
        if i[0] in check_list:
            l.append(i[2])
    return l
get_governor_words(sen)
# Out:
# [(u'ROOT', 0, 9), (u'det', 2, 1), (u'nsubj', 9, 2), (u'cop', 9, 3), (u'advmod', 5, 4), (u'cc', 9, 5), (u'det', 7, 6), (u'nsubj', 9, 7), (u'cop', 9, 8)]
# [2, 7]

# %%
from nltk import ne_chunk, pos_tag, word_tokenize
from nltk.tree import Tree

def get_continuous_chunks(text):
    chunked = ne_chunk(pos_tag(word_tokenize(text)))
    #print chunked
    continuous_chunk = []
    current_chunk = []
    for i in chunked:
        if type(i) == Tree:
            current_chunk.append(" ".join([token for token, pos in i.leaves()]))
        elif current_chunk:
            named_entity = " ".join(current_chunk)
            if named_entity not in continuous_chunk:
                continuous_chunk.append(named_entity)
                current_chunk = []
        else:
            continue
    return continuous_chunk

#print a

# %%
from nltk import word_tokenize
from nltk.corpus import wordnet as wn
import nltk
from nltk.chunk import ne_chunk

def noun_synsets(word):
    pos_list=[]
    a=wn.synsets(word)
#     print(a)
    for synset in a:
        b=synset.lemma_names()
        b=nltk.pos_tag(b)
        
        for i in b:
            if(i[1]=='NN'):
                pos_list.append(i[0])
    return pos_list

# %%
import re
from nltk.tree import Tree
import pandas as pd

df=pd.DataFrame(columns=['word'])
df['stopword']=0
df['pos_tag']=''
df['word_len']=0

for i in new_list[:100]:
    print(i)
    sen=i
    senten=i
    sen = [re.sub(r"[^a-zA-Z0-9]+", ' ', k) for k in sen.split("\n")]
    #print(sen)
    sen2=sen
    sen=word_tokenize(sen[0])
    from nltk.corpus import stopwords
    a=set(stopwords.words('english'))
    df_new=pd.DataFrame(sen,columns=['word'])
    #print(sen)
    df_new['stopword']=0
    df_new['pos_tag']=''
    df_new['word_len']=0
    for i in range(0,len(df_new)):
        if (df_new['word'][i]) in a:
            df_new['stopword'][i]=1
        else:
            df_new['stopword'][i]=0
        if(len(df_new['word'][i])>3):
            df_new['word_len'][i]=1
        else:
            df_new['word_len'][i]=0
    
    post_tag=nltk.pos_tag(sen
                     )
    pos=[]
    #df['pos']=""

    for i in range(0,len(post_tag)):
        
        pos.append(post_tag[i][1])

    df_new['pos_tag']=pos
    
    next_l=[]
    k=0
    for i in range(0,len(sen)-1):
    #printi
        next_l.append(sen[i+1])
    next_l.append("")
    df_new['next_words']=""
    df_new['next_words']=next_l

    df_new['prev_words']=""
    prev=[]
    prev.append(""
               )
    
    for i in range(1,len(sen)):
        prev.append(sen[i-1])
    df_new['prev_words']=prev
    df_new['pre_word_tag']=""
    df_new['post_word_tag']=""
    df_new['head_word']=0
    pos_pre=[]
    pos_pre.append("")
    pos_post=[]
    
    for i in range(0,len(post_tag)-1):
        pos_post.append(post_tag[i+1][1])
    pos_post.append("")
    for i in range(1,len(post_tag)):
        pos_pre.append(post_tag[i-1][1])

    df_new['pre_word_tag']=pos_pre
    df_new['post_word_tag']=pos_post
    
        
    df_new['ortho_features']=''
    for i in range(0,len(df_new)):
        if ((df_new['word'][i].istitle() == True) or (df_new['word'][i].isdigit()==True)):
            df_new['ortho_features'][i]=1
        else:
            df_new['ortho_features'][i]=0
            
    df_new['token_freq']=''
    for i in range(0,len(df_new)):
        df_new['token_freq'][i]=sen.count(df_new['word'][i])
        
    df_new['aspect']=0
    
    for i in range(0,len(df_new)):
        if (df_new['word'][i]) in head_word:
            #['word'][i]
            df_new['head_word'][i]=1
            #df_new['aspect'][i]=1
        else:
            df_new['head_word'][i]=0
            #df_new['head_word'][i]=0
            
    df_new['head_word_tag_new']=""
    for i in range(0,len(post_tag)):
        if(post_tag[i][0] in head_word):
            df_new['head_word_tag_new'][i]=post_tag[i][1]
        
    #relation
    #for i in range(0,len(df_new)):
        #if(df_new['pos_tag'][i]=='NN'):
            #df_new['aspect'][i]
    
    df_new['lematized_words']='NULL'
    lema=[]
    from nltk.stem import WordNetLemmatizer 
  
    lemmatizer = WordNetLemmatizer() 
    for i in range(0,len(sen)):
        c=post_tag[i][1]
        for name in morphy_tag.keys():
            if name == c:
                new=morphy_tag[name]
        lema.append(lemmatizer.lemmatize(post_tag[i][0],new))
    
    df_new['lematized_words']=lema
    chunked = ne_chunk(pos_tag(word_tokenize(senten)))
    #print chunked
    continuous_chunk = []
    current_chunk = []
    for i in chunked:
        if type(i) == Tree:
            current_chunk.append(" ".join([token for token, pos in i.leaves()]))
        elif current_chunk:
            named_entity = " ".join(current_chunk)
            if named_entity not in continuous_chunk:
                continuous_chunk.append(named_entity)
                current_chunk = []
        else:
            continue
    
    
    a=continuous_chunk
    df_new['ner']=0
    for x in a:
        df_new.loc[df_new.word==x,'ner']=1
    
    
    
    df = pd.concat([df, df_new])
print(df)
# Out:
# I charge it at night and skip taking the cord with me because of the good battery life.
# /home/vibha/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/vibha/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/vibha/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/vibha/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/vibha/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/vibha/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/vibha/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/vibha/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/vibha/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/vibha/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/vibha/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:148: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# I bought a HP Pavilion DV4-1222nr laptop and have had so many problems with the computer.
# The tech guy then said the service center does not do 1-to-1 exchange and I have to direct my concern to the "sales" team, which is the retail shop which I bought my netbook from.
# I investigated netbooks and saw the Toshiba NB305-N410BL.
# The other day I had a presentation to do for a seminar at a large conference in town- lots of people, little time to prep and have to set up a computer to a projector, etc.
# it is of high quality, has a killer GUI, is extremely stable, is highly expandable, is bundled with lots of very good applications, is easy to use, and is absolutely gorgeous.
# Easy to start up and does not overheat as much as other laptops.
# Sad very SAD.
# I even got my teenage son one, because of the features that it offers, like, iChat, Photobooth, garage band and more!
# Needless to say a PC that cannot support a cell phone is less than useless!
# Great laptop that offers many great features!
# they have done absolutely nothing to fix the computer problem.
#  One night I turned the freaking thing off after using it, the next day I turn it on, no GUI, screen all dark, power light steady, hard drive light steady and not flashing as it usually does.
# Still pretty pricey, but I have been putting off money for a while as a little Macbook Fund, and finally got to use it.
# My only disappointment with the 13" model is that they are the only ones in the MacBook Pro line up without an i5 or i7 processor and dual graphics cards, however the trade-off is that you achieve a longer battery life (of about 2 more hours).
# I took it back for an Asus and same thing- blue screen which required me to remove the battery to reset.
# In the shop, these MacBooks are encased in a soft rubber enclosure - so you will never know about the razor edge until you buy it, get it home, break the seal and use it (very clever con).
# However, the multi-touch gestures and large tracking area make having an external mouse unnecessary (unless you are gaming).
# Plus it is small and reasonably light so I can take it with me to and from work.
# I HATE this one.
# They were totally unconcerned that the computer was not correctly repaired in the first place.
# Toshiba does not send any one out unless you have paid extra to have the on site repair done.
# Oh, boy!
# But while this is one big advantage (as you may know from the company s recent commercials) there are other things to consider before going with Apple.
# I love the way the entire suite of software works together.
# The speed is incredible and I am more than satisfied.
# on the bright side at least I was not without my laptop for long this time!
# This laptop meets every expectation and Windows 7 is great!
# that has / that is how frustrating it was.
# I can barely use any usb devices because they will not stay connected properly.
# The one down side to it is that when I play a certin game on here, it tends to freeze up sometimes, but thats the only bad thing about this computer.
# -No backlit keyboard, but not an issue for me.
# When I finally had everything running with all my software installed I plugged in my droid to recharge and the system crashed.
# I cannot even turn it off.
# One suggestion I do have, is to not bother getting Microsoft office for the mac expecting it will work just like you knew it to on a PC.
# Pairing it with an iPhone is a pure pleasure - talk about painless syncing - used to take me forever - now it has / it is a snap.
# I shopped around before buying.
# I also got the added bonus of a 30" HD Monitor, which really helps to extend my screen and keep my eyes fresh!
# Would do business again.
# The machine is slow to boot up and occasionally crashes completely.
# After paying several hundred dollars for this service, it is frustrating that you cannot get help after hours.
# I have had the luxury (sarcasm) of owning 2 of these laptops.
# What a waste.
# It was a total Dhell experience that I will never repeat.
# There are a few flaws as well that I noticed.
# Completely worth every single penny dime and nickel.
# I tried to upgrade it to a newer version a couple of months ago and I still have the same problem.
# I did have to replace the battery once, but that was only a couple months ago and it has / it is been working perfect ever since.
# :) In the past four years I have had it I have never once gotten a virus.
# I love the operating system and the preloaded software.
# They were great in handling this problem, and I am looking forward in purchasing additonal products from them in the future.
# I have tried going back to XL but there still problems.
# The best thing about this laptop is the price along with some of the newer features.
# After numerous attempts of trying (including setting the clock in BIOS setup directly), I gave up(I am a techie).
# YOU WILL NOT BE ABLE TO TALK TO AN AMERICAN WARRANTY SERVICE IS OUT OF COUNTRY.

# %%
for i in new_list2[:1]:
    sen=i
    sen = [re.sub(r"[^a-zA-Z0-9]+", ' ', k) for k in sen.split("\n")]
    #print(sen)
    sen2=sen
    sen=word_tokenize(sen[0])
    post_tag=nltk.pos_tag(sen
                     )
    df_new['head_word_tag']=""
    for i in range(0,len(post_tag)):
    
        if(post_tag[i][0] in head_word):
            df_new['head_word_tag'][i]=post_tag[i][1]

    df = pd.concat([df, df_new])
# Out:
# /home/vibha/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /home/vibha/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:15: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   from ipykernel import kernelapp as app

# %%
df
# Out:
#    aspect  head_word head_word_tag_new lematized_words  ner next_words  \
# 0     0.0        0.0                               The  0.0      spicy
# 1     0.0        0.0                             spicy  0.0       tuna
# 2     0.0        0.0                              tuna  0.0       roll
# 3     0.0        1.0                NN            roll  0.0        was
# 4     0.0        0.0                                be  0.0    amazing
# 5     0.0        0.0                             amaze  0.0
#
#   ortho_features pos_tag post_word_tag pre_word_tag prev_words  stopword  \
# 0              1      DT            NN                                 0
# 1              0      NN            NN           DT        The         0
# 2              0      NN            NN           NN      spicy         0
# 3              0      NN           VBD           NN       tuna         0
# 4              0     VBD           VBG           NN       roll         1
# 5              0     VBG                        VBD        was         0
#
#   token_freq     word  word_len
# 0          1      The         0
# 1          1    spicy         1
# 2          1     tuna         1
# 3          1     roll         1
# 4          1      was         0
# 5          1  amazing         1

# %%
df.to_csv('ayushi_important.csv')

# %%
df=pd.read_csv("ayushi_important.csv")

# %%
df
# Out:
#             word  aspect  head_word head_word_tag_new lematized_words  ner  \
# 0              I       0          1               PRP               I    0
# 1         charge       0          0               NaN          charge    0
# 2             it       0          1               PRP              it    0
# 3             at       0          0               NaN              at    0
# 4          night       0          1                NN           night    0
# 5            and       0          0               NaN             and    0
# 6           skip       0          0               NaN            skip    0
# 7         taking       0          0               NaN            take    0
# 8            the       0          0               NaN             the    0
# 9           cord       1          1                NN            cord    0
# 10          with       0          0               NaN            with    0
# 11            me       0          1               PRP              me    0
# 12       because       0          0               NaN         because    0
# 13            of       0          0               NaN              of    0
# 14           the       0          0               NaN             the    0
# 15          good       0          0               NaN            good    0
# 16       battery       1          1                NN         battery    0
# 17          life       0          1                NN            life    0
# 18             I       0          1               PRP               I    0
# 19        bought       0          0               NaN             buy    0
# 20             a       0          0               NaN               a    0
# 21            HP       0          0               NaN              HP    0
# 22      Pavilion       0          0               NaN        Pavilion    0
# 23           DV4       0          0               NaN             DV4    0
# 24        1222nr       0          0               NaN          1222nr    0
# 25        laptop       0          1                NN          laptop    0
# 26           and       0          0               NaN             and    0
# 27          have       0          0               NaN            have    0
# 28           had       0          0               NaN            have    0
# 29            so       0          0               NaN              so    0
# ..           ...     ...        ...               ...             ...  ...
# 527        meets       0          0               NaN            meet    0
# 528        every       0          0               NaN           every    0
# 529  expectation       0          1                NN     expectation    0
# 530          and       0          0               NaN             and    0
# 531      Windows       1          1               NNP         Windows    0
# 532            7       0          0               NaN               7    0
# 533           is       0          0               NaN              be    0
# 534        great       0          0               NaN           great    0
# 535         that       0          0               NaN            that    0
# 536          has       0          0               NaN            have    0
# 537         that       0          0               NaN            that    0
# 538           is       0          0               NaN              be    0
# 539          how       0          0               NaN             how    0
# 540  frustrating       0          0               NaN       frustrate    0
# 541           it       0          1               PRP              it    0
# 542          was       0          0               NaN              be    0
# 543            I       0          1               PRP               I    0
# 544          can       0          0               NaN             can    0
# 545       barely       0          0               NaN          barely    0
# 546          use       0          0               NaN             use    0
# 547          any       0          0               NaN             any    0
# 548          usb       1          0               NaN             usb    0
# 549      devices       1          1               NNS         devices    0
# 550      because       0          0               NaN         because    0
# 551         they       0          1               PRP            they    0
# 552         will       0          0               NaN            will    0
# 553          not       0          0               NaN             not    0
# 554         stay       0          0               NaN            stay    0
# 555    connected       0          0               NaN         connect    0
# 556     properly       0          0               NaN        properly    0
#
#       next_words  ortho_features pos_tag post_word_tag pre_word_tag  \
# 0         charge               1     PRP           VBP          NaN
# 1             it               0     VBP           PRP          PRP
# 2             at               0     PRP            IN          VBP
# 3          night               0      IN            NN          PRP
# 4            and               0      NN            CC           IN
# 5           skip               0      CC            NN           NN
# 6         taking               0      NN           VBG           CC
# 7            the               0     VBG            DT           NN
# 8           cord               0      DT            NN          VBG
# 9           with               0      NN            IN           DT
# 10            me               0      IN           PRP           NN
# 11       because               0     PRP            IN           IN
# 12            of               0      IN            IN          PRP
# 13           the               0      IN            DT           IN
# 14          good               0      DT            JJ           IN
# 15       battery               0      JJ            NN           DT
# 16          life               0      NN            NN           JJ
# 17           NaN               0      NN           NaN           NN
# 18        bought               1     PRP           VBD          NaN
# 19             a               0     VBD            DT          PRP
# 20            HP               0      DT           NNP          VBD
# 21      Pavilion               0     NNP           NNP           DT
# 22           DV4               1     NNP           NNP          NNP
# 23        1222nr               0     NNP            CD          NNP
# 24        laptop               0      CD            NN          NNP
# 25           and               0      NN            CC           CD
# 26          have               0      CC           VBP           NN
# 27           had               0     VBP           VBN           CC
# 28            so               0     VBN            RB          VBP
# 29          many               0      RB            JJ          VBN
# ..           ...             ...     ...           ...          ...
# 527        every               0     NNS            DT           JJ
# 528  expectation               0      DT            NN          NNS
# 529          and               0      NN            CC           DT
# 530      Windows               0      CC           NNP           NN
# 531            7               1     NNP            CD           CC
# 532           is               1      CD           VBZ          NNP
# 533        great               0     VBZ            JJ           CD
# 534          NaN               0      JJ           NaN          VBZ
# 535          has               0      DT           VBZ          NaN
# 536         that               0     VBZ            DT           DT
# 537           is               0      DT           VBZ          VBZ
# 538          how               0     VBZ           WRB           DT
# 539  frustrating               0     WRB            JJ          VBZ
# 540           it               0      JJ           PRP          WRB
# 541          was               0     PRP           VBD           JJ
# 542          NaN               0     VBD           NaN          PRP
# 543          can               1     PRP            MD          NaN
# 544       barely               0      MD            RB          PRP
# 545          use               0      RB            VB           MD
# 546          any               0      VB            DT           RB
# 547          usb               0      DT            JJ           VB
# 548      devices               0      JJ           NNS           DT
# 549      because               0     NNS            IN           JJ
# 550         they               0      IN           PRP          NNS
# 551         will               0     PRP            MD           IN
# 552          not               0      MD            RB          PRP
# 553         stay               0      RB            VB           MD
# 554    connected               0      VB           VBN           RB
# 555     properly               0     VBN            RB           VB
# 556          NaN               0      RB           NaN          VBN
#
#       prev_words  stopword  token_freq  word_len
# 0            NaN         0           1         0
# 1              I         0           1         1
# 2         charge         1           1         0
# 3             it         1           1         0
# 4             at         0           1         1
# 5          night         1           1         0
# 6            and         0           1         1
# 7           skip         0           1         1
# 8         taking         1           2         0
# 9            the         0           1         1
# 10          cord         1           1         1
# 11          with         1           1         0
# 12            me         1           1         1
# 13       because         1           1         0
# 14            of         1           2         0
# 15           the         0           1         1
# 16          good         0           1         1
# 17       battery         0           1         1
# 18           NaN         0           1         0
# 19             I         0           1         1
# 20        bought         1           1         0
# 21             a         0           1         0
# 22            HP         0           1         1
# 23      Pavilion         0           1         0
# 24           DV4         0           1         1
# 25        1222nr         0           1         1
# 26        laptop         1           1         0
# 27           and         1           1         1
# 28          have         1           1         0
# 29           had         1           1         0
# ..           ...       ...         ...       ...
# 527       laptop         0           1         1
# 528        meets         0           1         1
# 529        every         0           1         1
# 530  expectation         1           1         0
# 531          and         0           1         1
# 532      Windows         0           1         0
# 533            7         1           1         0
# 534           is         0           1         1
# 535          NaN         1           2         1
# 536         that         1           1         0
# 537          has         1           2         1
# 538         that         1           1         0
# 539           is         1           1         0
# 540          how         0           1         1
# 541  frustrating         1           1         0
# 542           it         1           1         0
# 543          NaN         0           1         0
# 544            I         1           1         0
# 545          can         0           1         1
# 546       barely         0           1         0
# 547          use         1           1         0
# 548          any         0           1         0
# 549          usb         0           1         1
# 550      devices         1           1         1
# 551      because         1           1         1
# 552         they         1           1         1
# 553         will         1           1         0
# 554          not         0           1         1
# 555         stay         0           1         1
# 556    connected         0           1         1
#
# [557 rows x 15 columns]

# %%
y = df['aspect']
X = df.drop(['aspect'],axis=1)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.)

# %%
from sklearn.naive_bayes import MultinomialNB

nb = MultinomialNB().fit(X_train, y_train)

# %%
X_test='the spicy tuna roll was amazing'

# %%
y_pred = nb.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-e6f42dbace8e> in <module>()
# ----> 1 y_pred = nb.predict(X_test)
#
# /home/vibha/miniconda2/lib/python2.7/site-packages/sklearn/naive_bayes.pyc in predict(self, X)
#      64             Predicted target values for X
#      65         """
# ---> 66         jll = self._joint_log_likelihood(X)
#      67         return self.classes_[np.argmax(jll, axis=1)]
#      68
#
# /home/vibha/miniconda2/lib/python2.7/site-packages/sklearn/naive_bayes.pyc in _joint_log_likelihood(self, X)
#     728         check_is_fitted(self, "classes_")
#     729
# --> 730         X = check_array(X, accept_sparse='csr')
#     731         return (safe_sparse_dot(X, self.feature_log_prob_.T) +
#     732                 self.class_log_prior_)
#
# /home/vibha/miniconda2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     543                     "Reshape your data either using array.reshape(-1, 1) if "
#     544                     "your data has a single feature or array.reshape(1, -1) "
# --> 545                     "if it contains a single sample.".format(array))
#     546             # If input is 1D raise error
#     547             if array.ndim == 1:
#
# ValueError: Expected 2D array, got scalar array instead:
# array=the spicy tuna roll was amazing.
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
from sklearn import metrics

# %%
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.7619047619047619

# %%
cm=confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[118  33]
#  [  7  10]]

# %% [markdown]
# SVM

# %%
from sklearn import svm

# %%
model = svm.SVC(kernel='linear', C=1, gamma=1) 
# there is various option associated with it, like changing kernel, gamma and C value.Train the model using the training sets and check score
model.fit(X_train,y_train )
model.score(X_test, y_test)
#Predict Output
predicted= model.predict(X_test)

# %%
metrics.accuracy_score(y_test, predicted)
# Out:
# 0.8988095238095238

# %%
cm=confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[118  33]
#  [  7  10]]

# %%
df
# Out:
#    aspect  head_word head_word_tag_new lematized_words  ner next_words  \
# 0       0          0               NaN             The    0      spicy
# 1       0          0               NaN           spicy    0       tuna
# 2       1          0               NaN            tuna    0       roll
# 3       1          1                NN            roll    0        was
# 4       0          0               NaN              be    0    amazing
# 5       0          0               NaN           amaze    0        NaN
#
#    ortho_features pos_tag post_word_tag pre_word_tag prev_words  stopword  \
# 0               1      DT            NN          NaN        NaN         0
# 1               0      NN            NN           DT        The         0
# 2               0      NN            NN           NN      spicy         0
# 3               0      NN           VBD           NN       tuna         0
# 4               0     VBD           VBG           NN       roll         1
# 5               0     VBG           NaN          VBD        was         0
#
#    token_freq     word  word_len
# 0           1      The         0
# 1           1    spicy         1
# 2           1     tuna         1
# 3           1     roll         1
# 4           1      was         0
# 5           1  amazing         1

# %%
from sklearn.preprocessing import LabelEncoder
class MultiColumnLabelEncoder:
    def __init__(self,columns = None):
        self.columns = columns # array of column names to encode

    def fit(self,X,y=None):
        return self # not relevant here

    def transform(self,X):
        '''
        Transforms columns of X specified in self.columns using
        LabelEncoder(). If no columns specified, transforms all
        columns in X.
        '''
        output = X.copy()
        if self.columns is not None:
            for col in self.columns:
                output[col] = LabelEncoder().fit_transform(output[col])
        else:
            for colname,col in output.iteritems():
                output[colname] = LabelEncoder().fit_transform(col)
        return output

    def fit_transform(self,X,y=None):
        return self.fit(X,y).transform(X)

# %%
df=MultiColumnLabelEncoder(columns =['word', 'aspect', 'head_word', 'head_word_tag_new', 'lematized_words', 'ner', 'next_words', 'ortho_features', 'pos_tag', 'post_word_tag', 'pre_word_tag', 'prev_words', 'stopword', 'token_freq', 'word_len']).fit_transform(df)

# %%
df=df.fillna(0)

# %%
df
# Out:
#      word  aspect  head_word  head_word_tag_new  lematized_words  ner  \
# 0      16       0          1                 10               16    0
# 1      76       0          0                  0               73    0
# 2     150       0          1                 10              140    0
# 3      55       0          0                  0               53    0
# 4     183       0          1                  7              173    0
# 5      49       0          0                  0               48    0
# 6     240       0          0                  0              228    0
# 7     254       0          0                  0              241    0
# 8     260       0          0                  0              247    0
# 9      86       1          1                  7               83    0
# 10    296       0          0                  0              278    0
# 11    170       0          1                 10              160    0
# 12     60       0          0                  0               59    0
# 13    187       0          0                  0              177    0
# 14    260       0          0                  0              247    0
# 15    126       0          0                  0              121    0
# 16     59       1          1                  7               57    0
# 17    158       0          1                  7              148    0
# 18     16       0          1                 10               16    0
# 19     65       0          0                  0               68    0
# 20     40       0          0                  0               40    0
# 21     14       0          0                  0               14    0
# 22     28       0          0                  0               28    0
# 23      8       0          0                  0                8    0
# 24      1       0          0                  0                1    0
# 25    153       0          1                  7              143    0
# 26     49       0          0                  0               48    0
# 27    135       0          0                  0              127    0
# 28    132       0          0                  0              127    0
# 29    242       0          0                  0              230    0
# ..    ...     ...        ...                ...              ...  ...
# 527   171       0          0                  0              161    0
# 528   105       0          0                  0              100    0
# 529   108       0          1                  7              103    0
# 530    49       0          0                  0               48    0
# 531    39       1          1                  8               39    0
# 532     4       0          0                  0                4    0
# 533   149       0          0                  0               58    0
# 534   130       0          0                  0              124    0
# 535   259       0          0                  0              246    0
# 536   134       0          0                  0              127    0
# 537   259       0          0                  0              246    0
# 538   149       0          0                  0               58    0
# 539   141       0          0                  0              132    0
# 540   120       0          0                  0              115    0
# 541   150       0          1                 10              140    0
# 542   290       0          0                  0               58    0
# 543    16       0          1                 10               16    0
# 544    72       0          0                  0               69    0
# 545    58       0          0                  0               56    0
# 546   285       0          0                  0              270    0
# 547    50       0          0                  0               49    0
# 548   284       1          0                  0              269    0
# 549    90       1          1                  9               87    0
# 550    60       0          0                  0               59    0
# 551   264       0          1                 10              251    0
# 552   295       0          0                  0              277    0
# 553   185       0          0                  0              175    0
# 554   249       0          0                  0              237    0
# 555    84       0          0                  0               81    0
# 556   211       0          0                  0              201    0
#
#      next_words  ortho_features  pos_tag  post_word_tag  pre_word_tag  \
# 0            62               1       12             23             0
# 1           136               0       23             13            13
# 2            41               0       12              5            24
# 3           169               0        4             10            13
# 4            35               0        9              1             5
# 5           226               0        0             10            10
# 6           240               0        9             21             1
# 7           246               0       21              3            10
# 8            72               0        2             10            22
# 9           282               0        9              5             3
# 10          156               0        4             13            10
# 11           46               0       12              5             5
# 12          173               0        4              5            13
# 13          246               0        4              3             5
# 14          112               0        2              6             5
# 15           45               0        5             10             3
# 16          144               0        9             10             6
# 17            0               0        9              0            10
# 18           51               1       12             20             0
# 19           26               0       20              3            13
# 20           12               0        2             11            21
# 21           20               0       10             11             3
# 22            8               1       10             11            11
# 23            2               0       10              2            11
# 24          139               0        1             10            11
# 25           35               0        9              1             2
# 26          121               0        0             23            10
# 27          118               0       23             22             1
# 28          228               0       22             15            24
# 29          154               0       14              6            23
# ..          ...             ...      ...            ...           ...
# 527          91               0       11              3             6
# 528          94               0        2             10            12
# 529          35               0        9              1             3
# 530          25               0        0             11            10
# 531           5               1       10              2             1
# 532         135               1        1             24            11
# 533         116               0       24              6             2
# 534           0               0        5              0            25
# 535         120               0        2             24             0
# 536         245               0       24              3             3
# 537         135               0        2             24            25
# 538         127               0       24             27             3
# 539         106               0       27              6            25
# 540         136               0        5             13            28
# 541         276               0       12             20             6
# 542           0               0       20              0            13
# 543          58               1       12              9             0
# 544          44               0        8             15            13
# 545         271               0       14             19             9
# 546          36               0       19              3            15
# 547         270               0        2              6            20
# 548          76               0        5             12             3
# 549          46               0       11              5             6
# 550         250               0        4             13            12
# 551         281               0       12              9             5
# 552         171               0        8             15            13
# 553         235               0       14             19             9
# 554          70               0       19             22            15
# 555         197               0       22             15            20
# 556           0               0       14              0            23
#
#      prev_words  stopword  token_freq  word_len
# 0             0         0           0         0
# 1            16         0           0         1
# 2            73         1           0         0
# 3           142         1           0         0
# 4            53         0           0         1
# 5           174         1           0         0
# 6            47         0           0         1
# 7           226         0           0         1
# 8           240         1           1         0
# 9           246         0           0         1
# 10           82         1           0         1
# 11          280         1           0         0
# 12          161         1           0         1
# 13           58         1           0         0
# 14          178         1           1         0
# 15          246         0           0         1
# 16          120         0           0         1
# 17           57         0           0         1
# 18            0         0           0         0
# 19           16         0           0         1
# 20           63         1           0         0
# 21           38         0           0         0
# 22           14         0           0         1
# 23           27         0           0         0
# 24            8         0           0         1
# 25            2         0           0         1
# 26          145         1           0         0
# 27           47         1           0         1
# 28          128         1           0         0
# 29          125         1           0         0
# ..          ...       ...         ...       ...
# 527         145         0           0         1
# 528         162         0           0         1
# 529         100         0           0         1
# 530         103         1           0         0
# 531          47         0           0         1
# 532          37         0           0         0
# 533           5         1           0         0
# 534         141         0           0         1
# 535           0         1           1         1
# 536         245         1           0         0
# 537         127         1           1         1
# 538         245         1           0         0
# 539         141         1           0         0
# 540         133         0           0         1
# 541         115         1           0         0
# 542         142         1           0         0
# 543           0         0           0         0
# 544          16         1           0         0
# 545          69         0           0         1
# 546          56         0           0         0
# 547         270         1           0         0
# 548          48         0           0         0
# 549         269         0           0         1
# 550          86         1           0         1
# 551          58         1           0         1
# 552         250         1           0         1
# 553         279         1           0         0
# 554         176         0           0         1
# 555         235         0           0         1
# 556          80         0           0         1
#
# [557 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'word', 'aspect', 'head_word', 'head_word_tag_new', 'lematized_words', 'ner', 'next_words', 'ortho_features', 'pos_tag', 'post_word_tag', 'pre_word_tag', 'prev_words', 'stopword', 'token_freq', 'word_len'], dtype='object')

# %%
df
# Out:
#    aspect  head_word  head_word_tag_new  lematized_words  ner  next_words  \
# 0       0          0                  0                0    0           3
# 1       0          0                  0                4    0           4
# 2       1          0                  0                5    0           2
# 3       1          1                  1                3    0           5
# 4       0          0                  0                2    0           1
# 5       0          0                  0                1    0           0
#
#    ortho_features  pos_tag  post_word_tag  pre_word_tag  prev_words  stopword  \
# 0               1        0              1             0           0         0
# 1               0        1              1             1           1         0
# 2               0        1              1             2           3         0
# 3               0        1              2             2           4         0
# 4               0        2              3             2           2         1
# 5               0        3              0             3           5         0
#
#    token_freq  word  word_len
# 0           0     0         0
# 1           0     3         1
# 2           0     4         1
# 3           0     2         1
# 4           0     5         0
# 5           0     1         1

# %%
import os
p=os.popen("echo '"+"I charge it at night and skip taking the cord with me because of the very good battery life"+"'~/stanford-parser-2012-11-12/stanfordtemp.txt")
print(p)
parser_out = os.popen("~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt")
print(parser_out)
    
for relation in parser_out:
        
    print(relation)
# Out:
# <open file "echo 'I charge it at night and skip taking the cord with me because of the very good battery life'~/stanford-parser-2012-11-12/stanfordtemp.txt", mode 'r' at 0x7f1e1f606e40>
# <open file '~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt', mode 'r' at 0x7f1e1f606db0>
# (ROOT
#
#   (S
#
#     (NP (PRP I))
#
#     (VP
#
#       (VP (VBP charge)
#
#         (NP (PRP it))
#
#         (PP (IN at)
#
#           (NP (NN night))))
#
#       (CC and)
#
#       (VP (VB skip)
#
#         (S
#
#           (VP (VBG taking)
#
#             (NP (DT the) (NN cord))
#
#             (PP (IN with)
#
#               (NP
#
#                 (NP (PRP me))
#
#                 (PP (RB because) (IN of)
#
#                   (NP (DT the)
#
#                     (ADJP (RB not) (JJ good))
#
#                     (NN battery) (NN life)))))))))))
#
#
#
# nsubj(charge-2, I-1)
#
# nsubj(skip-7, I-1)
#
# root(ROOT-0, charge-2)
#
# dobj(charge-2, it-3)
#
# prep_at(charge-2, night-5)
#
# conj_and(charge-2, skip-7)
#
# xcomp(skip-7, taking-8)
#
# det(cord-10, the-9)
#
# dobj(taking-8, cord-10)
#
# prep_with(taking-8, me-12)
#
# det(life-19, the-15)
#
# neg(good-17, not-16)
#
# amod(life-19, good-17)
#
# nn(life-19, battery-18)
#
# prep_because_of(me-12, life-19)

# %%
def get_aspects(path):
    tree=ET.parse(path)
    root = tree.getroot()
    as_f=[]
    as_final=[]
    c=0
    for review in root.findall('./sentence'):
                as_f=[]
                new=review.attrib['id']
                print(new)
                if review.find('aspectTerms'):
                    for text_string in review.findall('aspectTerms'):
                        #print(text_string)
                        a=text_string.findall('aspectTerm')
                        #print(a)
                        for i in a:
                            id=i.attrib['term']
                            am=id.split(" ")
                            for c in am:
                                as_f.append(c)
                    as_final.append(as_f)
                            #print(id)
                         #   id=s.attrib['term']
                        #print(id)
#                         for s in a:
#                             print(s)
#                             if s is not None:
#                                 id=s.attrib['term']
#                                 #print(id)
#                                 am=id.split(" ")
#                                 for c in am:
#                                     #print(c)
#                                     as_f.append(c)
#                             print(as_f)
                        #as_final.append(as_f)
                else:
                    print("no")
                    as_f=[]
                    as_final.append(as_f)
                            
                    #print("ak")
#                 if text_string is not None:
#                     id=text_string.attrib['term']
#                     print id
#                 else:
#                     id=[]
                #print(text_string)
                #print("ayushi")
                #print(am)
#                 am=am.split(" ")
#                 print(am)
#                 for i in am:
#                     as_f.append(i)
#                 as_final.append(as_f)
                
#                 text_string=""
#                 opinion_inner_list=[]
                #or sent in review.findall('./sentences/sentence'):
                #print(sent)
                #ids=review.attrib['aspec]
                #print(ids)
#                 #id_list.append(ids)
#                 for i in review.findall('aspectTerm'):
#                     print(i)
#                     am=i.attrib['term']
#                     am=am.split(" ")
                    #print(am)
                    #print("ayushi")
#                     for i in am:
#                         new_list.append(i)
    
                    

    return as_f,as_final
as_f,as_final = get_aspects("/home/vibha/Laptops_Train.xml")
# Out:
# 2339
# 812
# no
# 1316
# 2328
# no
# 2193
# no
# 2005
# 2789
# 425
# no
# 76
# 747
# no
# 80
# 796
# no
# 917
# 1788
# no
# 338
# 1630
# 38
# 337
# 1505
# no
# 263
# no
# 1227
# no
# 1019
# no
# 1158
# no
# 1168
# no
# 2568
# 295
# 951
# no
# 2759
# 2055
# no
# 2980
# 2454
# no
# 1054
# 743
# 1155
# no
# 2587
# 2202
# 2799
# no
# 2227
# 2241
# no
# 92
# 1204
# 2026
# no
# 535
# no
# 478
# no
# 1690
# no
# 1789
# no
# 250
# no
# 325
# 324
# no
# 1574
# 1005
# no
# 989
# no
# 3073
# 1254
# 810
# 1346
# no
# 2383
# no
# 130
# 1253
# no
# 839
# 1473
# no
# 782
# no
# 696
# 2878
# no
# 226
# no
# 1652
# no
# 1030
# 1425
# 2861
# no
# 661
# 997
# 192
# no
# 463
# 2866
# no
# 935
# no
# 1193
# 2192
# no
# 147
# 1433
# 1669
# 2462
# 2719
# 1224
# 588
# no
# 2492
# 1541
# 3060
# 915
# 2050
# 460
# 1954
# no
# 1728
# no
# 620
# no
# 2423
# no
# 1781
# no
# 645
# no
# 2
# no
# 1524
# 2472
# no
# 803
# 2225
# 2644
# 1365
# 1555
# no
# 2199
# no
# 72
# no
# 1151
# no
# 2033
# 2113
# no
# 2271
# 1307
# no
# 2186
# no
# 103
# 1875
# no
# 1359
# no
# 2483
# no
# 2945
# no
# 197
# no
# 1149
# 163
# no
# 900
# 1649
# 2972
# no
# 446
# 1912
# 2752
# 270
# no
# 2646
# no
# 886
# no
# 2381
# 404
# 2772
# no
# 407
# 699
# no
# 1034
# no
# 1731
# 1863
# no
# 1186
# 1029
# no
# 1014
# no
# 2470
# 331
# 1073
# no
# 2788
# no
# 1057
# 1095
# 210
# no
# 1718
# 2770
# no
# 642
# no
# 471
# no
# 2923
# 3027
# 654
# 1340
# no
# 2638
# no
# 2099
# no
# 58
# no
# 2716
# no
# 2317
# no
# 1110
# 1488
# 488
# 1289
# 2985
# 2145
# no
# 1573
# 1928
# 704
# no
# 1099
# 1347
# 1408
# 1374
# 34
# no
# 2864
# 815
# no
# 2801
# no
# 1568
# no
# 30
# 362
# no
# 619
# no
# 708
# no
# 167
# no
# 474
# 1563
# no
# 172
# no
# 1396
# no
# 156
# 2095
# 46
# no
# 418
# no
# 1722
# 2004
# 2296
# 1514
# no
# 2699
# no
# 524
# no
# 155
# no
# 493
# 902
# 2433
# 1675
# 3000
# no
# 954
# no
# 609
# 50
# no
# 1265
# no
# 2150
# no
# 1777
# no
# 296
# 1585
# no
# 2444
# no
# 2335
# 1635
# no
# 1661
# no
# 2416
# 1471
# 1388
# no
# 715
# no
# 1901
# no
# 1427
# 2389
# no
# 2667
# no
# 1618
# no
# 1460
# no
# 2964
# no
# 911
# 2001
# 2465
# 2331
# 599
# 823
# 3006
# 1861
# no
# 1301
# no
# 788
# no
# 2056
# no
# 825
# no
# 1823
# no
# 2439
# no
# 2941
# 2776
# 1686
# 2091
# 727
# no
# 3001
# no
# 1259
# 2938
# 2574
# 2351
# 526
# 2891
# no
# 2717
# no
# 3020
# 2541
# 1069
# 1553
# 355
# no
# 602
# no
# 2502
# no
# 2874
# 2385
# 198
# no
# 211
# no
# 1654
# 3058
# 1937
# 104
# 419
# no
# 630
# no
# 694
# no
# 189
# no
# 2616
# no
# 1417
# 1045
# no
# 2886
# 2124
# 260
# 1296
# no
# 1172
# 2283
# no
# 2221
# 2480
# no
# 386
# 1357
# 185
# no
# 2605
# 717
# no
# 2369
# no
# 2579
# no
# 1742
# 2578
# 33
# no
# 942
# 2740
# 311
# 2402
# no
# 13
# 1852
# 2708
# 1566
# 2053
# no
# 540
# 878
# 2639
# no
# 2388
# 1940
# no
# 3074
# 1510
# no
# 2457
# no
# 2534
# 2185
# 2632
# 1772
# no
# 2675
# 1096
# no
# 2371
# no
# 2458
# no
# 2650
# no
# 392
# 1551
# 2698
# 2427
# no
# 1849
# no
# 340
# 2918
# 2939
# 1958
# 358
# 2064
# no
# 1355
# 3021
# 2415
# 2730
# no
# 2297
# no
# 2060
# no
# 2739
# no
# 2696
# 1352
# no
# 1827
# no
# 2916
# 2074
# no
# 229
# no
# 4
# 2260
# 199
# no
# 1376
# 936
# 1627
# no
# 2323
# 1804
# 595
# no
# 1426
# 2216
# no
# 1590
# no
# 1486
# no
# 138
# 1192
# 1439
# no
# 449
# no
# 137
# no
# 1691
# 877
# no
# 537
# 541
# 1291
# no
# 924
# no
# 3043
# 505
# 431
# no
# 569
# 3081
# 308
# 2796
# 2333
# 3049
# 2660
# 206
# 2138
# 2737
# no
# 2392
# 10
# no
# 85
# no
# 9
# 1218
# no
# 1867
# 2377
# 2438
# no
# 136
# no
# 2928
# 258
# no
# 2811
# 2137
# 1256
# 1770
# 2270
# 1424
# 2843
# 1239
# no
# 2471
# 1240
# no
# 2550
# 455
# 641
# no
# 2197
# no
# 1462
# no
# 949
# no
# 2924
# no
# 2496
# 1089
# 713
# 490
# 957
# no
# 2844
# no
# 2422
# 2540
# 2018
# 800
# no
# 2566
# no
# 1683
# no
# 2022
# 709
# no
# 1191
# 1950
# no
# 2007
# no
# 777
# 2775
# 1145
# no
# 1844
# 1989
# 2147
# no
# 1068
# 2030
# 2586
# no
# 128
# 2822
# no
# 1561
# 1890
# 2435
# 826
# no
# 2166
# 739
# no
# 371
# no
# 2969
# 896
# no
# 824
# 2896
# no
# 2754
# 309
# 816
# no
# 16
# 1984
# 837
# no
# 1588
# no
# 2943
# 2410
# no
# 2889
# no
# 1839
# 1375
# 899
# 2897
# no
# 2858
# 1338
# 2962
# 1785
# no
# 2110
# 2201
# no
# 139
# no
# 2582
# no
# 35
# 1041
# 1219
# no
# 231
# no
# 728
# no
# 1934
# no
# 1040
# 178
# no
# 379
# 2358
# no
# 1757
# 220
# 2790
# no
# 2370
# no
# 2919
# 698
# 1336
# 797
# no
# 2758
# no
# 146
# 432
# no
# 1969
# 2549
# 269
# no
# 469
# 2974
# 835
# 1898
# no
# 1962
# 306
# no
# 2838
# no
# 1666
# no
# 2876
# 2141
# 3040
# no
# 2034
# 2798
# no
# 1382
# no
# 2905
# no
# 2669
# 2895
# 2181
# 1529
# 2002
# no
# /home/vibha/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:11: FutureWarning: The behavior of this method will change in future versions.  Use specific 'len(elem)' or 'elem is not None' test instead.
#   # This is added back by InteractiveShellApp.init_path()
# 1752
# 672
# no
# 695
# 2291
# 2183
# no
# 658
# no
# 2286
# no
# 2481
# 1584
# no
# 1893
# 2649
# 783
# no
# 1889
# no
# 3072
# 1196
# 761
# 1736
# no
# 813
# no
# 1735
# no
# 2096
# 633
# no
# 714
# 1404
# no
# 862
# no
# 1023
# no
# 827
# no
# 923
# no
# 1973
# 2304
# 1313
# no
# 2276
# 3054
# no
# 1953
# 2755
# 184
# no
# 622
# no
# 744
# 1281
# no
# 1963
# 70
# 1611
# no
# 2342
# no
# 151
# 1319
# no
# 2850
# no
# 2556
# no
# 1734
# 1617
# 912
# no
# 1476
# 1623
# 451
# 1544
# no
# 149
# no
# 1222
# no
# 2956
# 720
# 740
# 2442
# no
# 2125
# no
# 2564
# 3016
# 806
# no
# 2778
# 2174
# 157
# no
# 1522
# no
# 2535
# no
# 1378
# 2999
# 1930
# no
# 222
# 2802
# no
# 1512
# no
# 1189
# 1356
# no
# 2070
# 2076
# 603
# no
# 1513
# no
# 1787
# no
# 930
# no
# 612
# 470
# no
# 1320
# no
# 2706
# 2997
# no
# 2954
# 1874
# 2834
# no
# 1546
# 1939
# no
# 2840
# no
# 484
# no
# 2003
# 1180
# 875
# no
# 809
# 799
# 1668
# 274
# 2128
# 2237
# no
# 2456
# 353
# 2290
# 1121
# no
# 134
# no
# 347
# 1813
# no
# 655
# 2510
# 1615
# no
# 844
# no
# 884
# 2785
# 2443
# 81
# 89
# no
# 2114
# 1670
# no
# 764
# 525
# no
# 435
# 914
# 177
# no
# 1776
# 330
# no
# 865
# no
# 1791
# no
# 549
# no
# 1212
# 2169
# no
# 2845
# 756
# 2600
# 2327
# no
# 3012
# no
# 1696
# 1479
# 2909
# 2937
# 1784
# no
# 453
# 439
# no
# 2925
# no
# 929
# no
# 2804
# no
# 2077
# 2622
# 1093
# no
# 225
# no
# 1100
# no
# 2523
# no
# 970
# 1935
# no
# 11
# no
# 2569
# no
# 3010
# no
# 1634
# no
# 2414
# 832
# 1205
# no
# 1064
# 2037
# no
# 1429
# no
# 2130
# 2626
# 1671
# no
# 1315
# 2756
# 548
# no
# 1446
# 168
# no
# 922
# 2797
# 2863
# 638
# no
# 2642
# no
# 1000
# no
# 200
# no
# 2887
# no
# 993
# no
# 2464
# no
# 1667
# no
# 416
# no
# 2041
# no
# 240
# 2135
# no
# 1393
# 2259
# no
# 1080
# 2695
# no
# 1506
# no
# 1837
# no
# 532
# 3047
# 921
# no
# 1733
# 2907
# no
# 1178
# no
# 2265
# no
# 119
# no
# 68
# no
# 2746
# no
# 282
# no
# 1532
# 2800
# no
# 1042
# no
# 640
# 2238
# 1907
# no
# 78
# no
# 891
# no
# 692
# no
# 1580
# 2817
# no
# 273
# 2679
# 415
# no
# 2046
# no
# 2450
# no
# 2170
# 2624
# 1822
# no
# 2374
# no
# 1896
# no
# 341
# no
# 2245
# no
# 1569
# 3064
# 2953
# 2129
# 2075
# 2180
# no
# 1362
# no
# 2710
# 1373
# 1370
# 1697
# no
# 276
# no
# 1287
# no
# 1929
# no
# 2365
# no
# 412
# no
# 2742
# no
# 1758
# 1257
# no
# 1908
# no
# 842
# 931
# 863
# no
# 2151
# no
# 36
# 2967
# 1732
# 1800
# no
# 1063
# 2615
# no
# 271
# 2478
# 523
# 1657
# 1674
# 472
# no
# 1143
# 2618
# no
# 1708
# no
# 2771
# no
# 2375
# no
# 203
# no
# 123
# no
# 2927
# 916
# no
# 2750
# no
# 1137
# no
# 2993
# 2453
# 2661
# no
# 2590
# no
# 515
# 2321
# no
# 2282
# no
# 1135
# no
# 1577
# no
# 2572
# 2387
# 2517
# 1967
# no
# 990
# 1414
# 664
# no
# 2484
# no
# 903
# 1609
# no
# 2354
# no
# 2979
# no
# 1759
# no
# 975
# no
# 2931
# no
# 2700
# no
# 1482
# no
# 1602
# 1233
# no
# 2231
# 2828
# 121
# no
# 2744
# no
# 1824
# 2460
# 2500
# 600
# no
# 497
# no
# 241
# no
# 557
# no
# 677
# 531
# no
# 1367
# no
# 2094
# no
# 1252
# 3007
# 1650
# 1229
# no
# 399
# no
# 1037
# 1620
# 1035
# no
# 201
# no
# 285
# 1260
# no
# 3035
# 840
# no
# 2511
# 895
# no
# 2275
# 1342
# no
# 1124
# 781
# 2987
# 2133
# 131
# no
# 1364
# 2787
# 948
# 2049
# 558
# no
# 1059
# no
# 767
# no
# 1990
# no
# 2366
# no
# 2988
# 1385
# 1646
# 88
# no
# 1270
# no
# 1834
# no
# 1451
# no
# 55
# no
# 2505
# 768
# 2559
# no
# 242
# no
# 2998
# no
# 2341
# no
# 2908
# no
# 214
# 1263
# 650
# no
# 2703
# no
# 142
# 2947
# 66
# no
# 2020
# 2451
# 605
# no
# 314
# 2777
# 1085
# 1906
# 124
# 2816
# no
# 1900
# no
# 732
# 3011
# 485
# no
# 1842
# 238
# no
# 205
# 1955
# no
# 1160
# no
# 2989
# no
# 1398
# 1372
# 467
# no
# 1400
# 47
# no
# 1066
# 1607
# no
# 910
# no
# 2379
# no
# 361
# no
# 344
# 1368
# no
# 2038
# no
# 1673
# no
# 2871
# 2530
# no
# 1603
# no
# 381
# no
# 312
# 2795
# 1865
# 1681
# no
# 2973
# 2612
# 1864
# no
# 2629
# no
# 2207
# no
# 249
# no
# 1283
# 1423
# 288
# no
# 256
# no
# 2280
# no
# 322
# no
# 1072
# 2826
# no
# 1390
# no
# 1739
# 2419
# 785
# no
# 82
# no
# 1549
# 2086
# 300
# 262
# no
# 2521
# no
# 2284
# no
# 851
# 1008
# 2261
# 2793
# no
# 291
# 1185
# no
# 1719
# no
# 391
# 1595
# 1150
# no
# 2362
# 116
# 2119
# no
# 2647
# 2108
# no
# 789
# no
# 570
# no
# 980
# 668
# 1106
# 140
# 1418
# 539
# no
# 621
# 2360
# 2397
# no
# 2449
# no
# 1126
# 1745
# 2205
# no
# 1065
# no
# 987
# no
# 363
# no
# 1276
# no
# 2911
# no
# 2714
# no
# 2900
# no
# 2177
# no
# 164
# no
# 39
# 3019
# 1517
# no
# 1090
# no
# 1678
# no
# 2469
# 2429
# no
# 1986
# 1088
# 678
# 417
# no
# 625
# 2035
# 636
# no
# 1808
# no
# 1921
# 1872
# 1413
# 369
# no
# 321
# no
# 2636
# 357
# 1230
# no
# 1006
# no
# 3075
# 216
# no
# 3045
# 1688
# no
# 2098
# no
# 1877
# no
# 129
# no
# 235
# 3055
# 2865
# 1300
# no
# 1197
# 2538
# no
# 1403
# no
# 2676
# 75
# no
# 2319
# 452
# 2498
# 2515
# 2320
# 2051
# no
# 1017
# no
# 971
# no
# 3083
# 1687
# no
# 2593
# 1507
# no
# 336
# 2391
# no
# 786
# no
# 1616
# 1062
# 1982
# no
# 2704
# 2930
# no
# 343
# no
# 1152
# 1868
# no
# 1353
# no
# 977
# no
# 2747
# 2102
# no
# 967
# 1774
# no
# 1685
# no
# 932
# no
# 2501
# 1873
# no
# 1753
# no
# 892
# no
# 1241
# no
# 135
# no
# 1801
# 2902
# 2062
# no
# 2656
# 652
# 170
# 665
# no
# 787
# no
# 814
# no
# 2047
# 3039
# no
# 1371
# no
# 2666
# 741
# 1748
# 774
# no
# 2246
# 1055
# no
# 401
# no
# 2032
# 1780
# no
# 150
# 1581
# no
# 302
# 204
# 2080
# 964
# no
# 2780
# 1105
# 1484
# 17
# no
# 2506
# 2281
# 1978
# no
# 2659
# no
# 2729
# no
# 572
# 2965
# no
# 731
# no
# 2522
# no
# 15
# 958
# no
# 1489
# 1303
# no
# 906
# no
# 1123
# no
# 730
# no
# 659
# 25
# 1043
# 97
# 42
# no
# 2209
# no
# 2855
# no
# 1493
# 2944
# 2298
# no
# 2031
# no
# 1655
# no
# 107
# 1170
# 2594
# 3034
# 2735
# 1348
# 675
# 243
# no
# 1538
# 48
# no
# 1495
# 2413
# 224
# no
# 2307
# 934
# no
# 2337
# 2448
# 2210
# 1244
# no
# 2476
# no
# 2243
# 1036
# 7
# 345
# no
# 560
# 685
# no
# 2495
# 1838
# no
# 1856
# 475
# 937
# 555
# 2300
# no
# 373
# no
# 1420
# 643
# no
# 2346
# 1326
# no
# 2951
# no
# 433
# 968
# 420
# no
# 1764
# 1860
# no
# 847
# no
# 2718
# 995
# 2219
# 607
# 802
# no
# 610
# 1608
# no
# 284
# no
# 1525
# no
# 3030
# 687
# 521
# no
# 64
# no
# 388
# 520
# 1835
# no
# 2610
# 1870
# no
# 2089
# no
# 2266
# 1998
# no
# 2623
# no
# 1503
# no
# 217
# no
# 2445
# no
# 960
# no
# 1710
# 2613
# no
# 1543
# 1895
# 1604
# 1698
# 3028
# no
# 2437
# 829
# no
# 2436
# 1968
# 1807
# no
# 673
# no
# 356
# 2486
# 1983
# 2637
# 2028
# no
# 2648
# no
# 2531
# 1798
# 1323
# no
# 1711
# no
# 2670
# no
# 334
# 1884
# no
# 2794
# no
# 1991
# no
# 1706
# 547
# 2688
# no
# 2977
# 1724
# 2592
# 365
# no
# 1651
# 533
# 2707
# 444
# 1792
# 2240
# no
# 1663
# no
# 1693
# no
# 1933
# 2126
# no
# 3041
# 1349
# 546
# no
# 2490
# 1713
# 1075
# 2509
# 1231
# no
# 966
# no
# 1274
# no
# 2155
# 377
# 2767
# no
# 913
# 1379
# 3024
# 567
# no
# 2159
# 1594
# no
# 869
# no
# 940
# 1828
# no
# 426
# no
# 2901
# 2645
# 3070
# no
# 738
# no
# 729
# no
# 2813
# 2063
# 651
# no
# 352
# no
# 1751
# no
# 2048
# no
# 3009
# no
# 2154
# 1428
# no
# 648
# 779
# 1022
# 2217
# no
# 1277
# no
# 1825
# no
# 876
# no
# 1009
# no
# 1079
# 227
# 2640
# no
# 749
# no
# 2732
# no
# 2655
# 2466
# 2382
# no
# 3084
# no
# 580
# no
# 855
# no
# 2213
# 2013
# no
# 2412
# no
# 2025
# no
# 2673
# 874
# no
# 2773
# 1589
# no
# 1107
# 2493
# no
# 2870
# 182
# no
# 1903
# no
# 244
# 307
# no
# 1871
# no
# 1183
# no
# 2132
# 69
# no
# 1360
# no
# 2059
# no
# 938
# 1692
# no
# 1114
# no
# 496
# 2015
# 1138
# 1695
# no
# 3068
# no
# 372
# no
# 41
# 2250
# 2654
# 2473
# no
# 745
# 2024
# no
# 1531
# 2768
# 589
# no
# 2738
# 1015
# 144
# 1938
# no
# 2305
# 3044
# 2115
# no
# 2709
# 51
# no
# 310
# 19
# 122
# no
# 408
# 2426
# 984
# 2117
# 1294
# no
# 1853
# no
# 2994
# 1324
# no
# 246
# 1539
# no
# 2869
# no
# 2536
# no
# 2765
# 1266
# no
# 1885
# 1952
# 1440
# 2949
# 1206
# 1461
# no
# 705
# no
# 1445
# no
# 109
# 1122
# no
# 1599
# 1050
# 1430
# 759
# no
# 1942
# 2978
# 2288
# 2702
# 215
# no
# 3036
# 2367
# no
# 209
# 1586
# no
# 2157
# 1337
# no
# 301
# 305
# no
# 1190
# 2178
# no
# 3025
# no
# 37
# no
# 2021
# 996
# no
# 791
# no
# 2906
# no
# 333
# 1436
# 2359
# 1637
# no
# 2981
# no
# 2839
# 1456
# no
# 3077
# 2042
# no
# 1988
# no
# 237
# 380
# no
# 994
# no
# 219
# 1024
# no
# 2532
# 669
# no
# 422
# no
# 1993
# 2497
# 888
# 1120
# 770
# no
# 1174
# 2072
# no
# 2100
# 1331
# no
# 60
# 1454
# 889
# no
# 2705
# 1498
# no
# 393
# no
# 2215
# no
# 718
# no
# 1177
# 438
# no
# 2330
# no
# 961
# 1914
# no
# 3026
# 2336
# 1605
# no
# 384
# no
# 2539
# 2853
# 2976
# 1782
# no
# 53
# no
# 2012
# no
# 1148
# no
# 1127
# 1843
# 410
# no
# 1128
# 849
# no
# 173
# no
# 1767
# 1887
# 1880
# 101
# 1033
# no
# 792
# 1927
# no
# 2278
# no
# 1330
# 1117
# no
# 2103
# no
# 3079
# 579
# no
# 973
# 1083
# no
# 2727
# 2791
# 1499
# no
# 161
# 1494
# 1545
# 1587
# 1236
# 1911
# 3052
# no
# 1161
# no
# 556
# no
# 1452
# no
# 1334
# no
# 275
# 191
# 2349
# 606
# no
# 1032
# no
# 1974
# no
# 2611
# 283
# no
# 2940
# 1840
# no
# 1249
# no
# 2915
# no
# 860
# no
# 2577
# 2933
# 457
# no
# 1208
# 2494
# 2807
# 12
# 2109
# no
# 765
# no
# 986
# 61
# 1790
# no
# 807
# no
# 2463
# 947
# no
# 1477
# no
# 2487
# 1638
# 3082
# 1157
# no
# 1251
# no
# 1909
# 3014
# no
# 518
# no
# 2512
# 2234
# 3002
# no
# 318
# no
# 405
# 1086
# 1500
# no
# 604
# no
# 893
# no
# 2504
# 2104
# no
# 2206
# no
# 74
# no
# 793
# 2662
# no
# 2726
# no
# 956
# 2044
# no
# 2516
# 2760
# 1597
# 126
# no
# 2404
# no
# 1329
# 1223
# no
# 3005
# no
# 2338
# 2948
# 117
# no
# 2027
# 2877
# no
# 853
# no
# 1833
# no
# 3053
# no
# 316
# no
# 2936
# 684
# 464
# 628
# no
# 596
# no
# 342
# no
# 2762
# 2440
# 1951
# no
# 2334
# no
# 1046
# 735
# 2176
# no
# 2821
# 1987
# 1386
# no
# 1354
# no
# 1830
# no
# 2428
# no
# 1327
# 54
# no
# 1886
# no
# 517
# no
# 1282
# no
# 2888
# no
# 1639
# 1288
# 2607
# no
# 1273
# no
# 2959
# 26
# 1194
# 264
# 798
# no
# 1862
# no
# 2214
# 1102
# no
# 985
# no
# 752
# no
# 2806
# 2356
# no
# 1221
# 529
# no
# 2527
# no
# 1237
# 2712
# no
# 2054
# no
# 359
# 2394
# no
# 1116
# no
# 1915
# no
# 2690
# 2713
# 1826
# no
# 2071
# 644
# no
# 1125
# no
# 186
# no
# 67
# no
# 1720
# no
# 2016
# no
# 40
# no
# 2348
# 1441
# 2860
# 2630
# no
# 2842
# no
# 91
# 944
# no
# 817
# 2683
# no
# 45
# no
# 1108
# no
# 465
# no
# 427
# 3085
# 1139
# 1591
# 1067
# 536
# 1946
# no
# 1434
# 1526
# no
# 2525
# no
# 293
# 2344
# no
# 3037
# no
# 2543
# no
# 1905
# no
# 2386
# 1981
# no
# 2881
# no
# 18
# 1621
# no
# 1610
# 998
# no
# 2292
# 2596
# 614
# 171
# 2753
# 3
# 1644
# no
# 332
# no
# 1641
# 1680
# no
# 1164
# no
# 2814
# 43
# 1056
# 2996
# 3022
# 1850
# 2184
# no
# 2368
# 2233
# 1465
# no
# 1468
# no
# 1613
# 510
# 2353
# 2563
# 2264
# no
# 2306
# 635
# no
# 2310
# no
# 2557
# no
# 2664
# no
# 187
# no
# 1622
# no
# 2608
# no
# 1432
# 102
# 2966
# 2211
# 2819
# 1633
# 1351
# 2544
# no
# 272
# no
# 2220
# 2165
# no
# 93
# no
# 2691
# no
# 2723
# 73
# 1082
# 1520
# no
# 2677
# 2588
# 3061
# no
# 2036
# no
# 223
# 1332
# 846
# 2127
# no
# 1081
# no
# 3067
# no
# 1455
# 716
# no
# 162
# 969
# 145
# 2721
# no
# 2187
# 1709
# no
# 959
# no
# 1820
# no
# 2812
# 2899
# 228
# no
# 1028
# 1762
# no
# 586
# no
# 1556
# no
# 1474
# no
# 1103
# no
# 87
# 551
# no
# 1997
# 873
# no
# 2548
# 953
# 1179
# 2399
# no
# 1431
# no
# 1672
# no
# 2957
# no
# 1876
# 660
# no
# 1847
# no
# 2992
# 1341
# no
# 2835
# no
# 559
# 1888
# 1738
# 374
# 1746
# 737
# no
# 450
# no
# 279
# 631
# no
# 79
# 974
# no
# 2302
# no
# 313
# 1851
# no
# 1694
# 174
# 2452
# 2751
# 1203
# no
# 591
# no
# 397
# no
# 2524
# 1598
# 267
# 1515
# no
# 2182
# 3051
# no
# 561
# 2591
# no
# 757
# no
# 2641
# no
# 154
# 1267
# no
# 1153
# no
# 766
# no
# 188
# no
# 1779
# no
# 2551
# no
# 100
# 1444
# 1796
# 753
# 411
# 988
# 1071
# 2830
# 2701
# 2968
# 1931
# no
# 1723
# 1704
# no
# 1091
# no
# 2942
# no
# 702
# no
# 483
# no
# 2198
# no
# 1957
# no
# 2118
# no
# 286
# 513
# no
# 3029
# no
# 1411
# 1956
# 1918
# no
# 1469
# 2833
# 118
# no
# 2325
# no
# 754
# no
# 3050
# no
# 3015
# no
# 2829
# no
# 674
# no
# 1217
# no
# 933
# no
# 298
# 442
# no
# 1447
# 1810
# 2191
# no
# 1419
# 1250
# no
# 2832
# no
# 1660
# 1848
# no
# 459
# 1144
# no
# 2513
# no
# 2884
# 2082
# 629
# no
# 2847
# no
# 1391
# 56
# no
# 2257
# 2617
# 2653
# 1763
# no
# 1760
# no
# 1275
# no
# 2674
# 519
# 57
# no
# 1534
# 2514
# no
# 105
# 3065
# 2520
# no
# 2057
# 251
# 2073
# 2890
# 180
# no
# 508
# 320
# no
# 2352
# 1923
# 1279
# no
# 2921
# no
# 1705
# no
# 2631
# 2903
# no
# 2851
# 2741
# 398
# 1750
# no
# 329
# 587
# no
# 2069
# 2081
# 2040
# no
# 553
# no
# 2546
# no
# 406
# 2852
# no
# 14
# 1076
# 2395
# 1562
# 2425
# no
# 2786
# 2724
# 385
# no
# 2079
# no
# 854
# 2116
# no
# 390
# no
# 2405
# no
# 253
# 1700
# no
# 1278
# no
# 881
# 1188
# no
# 486
# 1487
# 2508
# 864
# no
# 2571
# 1435
# 2748
# 350
# 303
# no
# 1306
# no
# 489
# no
# 2162
# no
# 481
# no
# 1925
# 2749
# 623
# no
# 1167
# no
# 1897
# no
# 769
# 3046
# 2190
# no
# 2685
# no
# 1971
# no
# 726
# no
# 289
# no
# 1855
# no
# 2803
# no
# 2017
# no
# 1133
# no
# 1596
# 2736
# 1916
# no
# 1919
# no
# 1047
# 762
# 113
# 2533
# no
# 2836
# 962
# no
# 1459
# 2188
# 2274
# 1343
# no
# 1002
# no
# 1699
# no
# 1941
# no
# 2303
# 2910
# no
# 77
# no
# 1314
# no
# 2499
# no
# 2868
# 169
# 2409
# 1119
# no
# 1322
# 1740
# 2014
# no
# 2239
# 367
# 335
# 1328
# no
# 2652
# no
# 1384
# no
# 2831
# no
# 3042
# 2263
# no
# 1481
# 2769
# no
# 2491
# 1648
# 236
# no
# 1869
# 2763
# 1264
# no
# 2882
# no
# 955
# no
# 750
# no
# 1653
# no
# 1466
# no
# 2810
# no
# 1457
# 1165
# no
# 763
# 1977
# 1945
# no
# 939
# no
# 1243
# no
# 1387
# no
# 2156
# 626
# 3056
# 1879
# 1806
# no
# 2121
# 2420
# 887
# no
# 2039
# no
# 3032
# no
# 2107
# 907
# 160
# 254
# no
# 2926
# 1632
# 710
# no
# 1271
# no
# 2142
# 348
# 703
# no
# 1377
# 2562
# no
# 992
# no
# 2167
# 2635
# no
# 2932
# 2904
# 850
# no
# 440
# 1882
# no
# 2671
# 1031
# no
# 414
# no
# 1286
# no
# 2092
# no
# 1812
# 2599
# no
# 573
# no
# 1198
# no
# 639
# 1272
# no
# 2311
# 2725
# 1147
# no
# 671
# 725
# no
# 175
# no
# 2580
# no
# 831
# 1816
# no
# 2269
# no
# 111
# 1564
# 1166
# no
# 6
# 98
# 656
# no
# 2396
# no
# 2584
# 492
# no
# 613
# 637
# 663
# no
# 2163
# no
# 1061
# 943
# no
# 1662
# no
# 2179
# no
# 574
# no
# 2309
# no
# 1226
# 1169
# no
# 2627
# 2743
# no
# 1980
# 1802
# no
# 885
# no
# 1537
# no
# 3059
# no
# 2558
# 1026
# 2694
# 1228
# 376
# no
# 776
# no
# 1232
# no
# 755
# 1640
# no
# 1947
# 2841
# no
# 3017
# 1836
# no
# 3069
# no
# 2441
# no
# 2604
# no
# 437
# no
# 3003
# no
# 319
# 1406
# 22
# 2576
# 1775
# 382
# no
# 538
# no
# 2279
# 20
# no
# 2917
# 550
# 883
# no
# 1004
# no
# 2068
# no
# 1405
# no
# 590
# no
# 3076
# 2403
# no
# 1768
# 2651
# no
# 565
# no
# 94
# no
# 1044
# no
# 1936
# 2859
# 2745
# 616
# no
# 2489
# 736
# no
# 2203
# 2986
# no
# 3063
# no
# 1053
# 593
# 354
# 65
# no
# 2010
# 950
# 2761
# 822
# 771
# 1642
# no
# 577
# 2247
# 1523
# no
# 2267
# 252
# no
# 683
# no
# 1932
# no
# 601
# no
# 945
# 2160
# 1501
# no
# 1333
# no
# 2222
# no
# 2254
# 290
# 1467
# 856
# no
# 608
# 1335
# no
# 255
# 1305
# no
# 395
# 1815
# no
# 1104
# 2922
# 1821
# no
# 689
# no
# 1200
# no
# 2398
# 2581
# 2361
# no
# 487
# no
# 801
# no
# 1766
# 2236
# 323
# no
# 1518
# no
# 1965
# no
# 294
# no
# 2136
# no
# 646
# no
# 28
# no
# 1717
# 2766
# 448
# 2681
# no
# 1225
# 2277
# no
# 1077
# no
# 2885
# no
# 2287
# no
# 207
# 1664
# no
# 2805
# 1819
# 3013
# no
# 904
# 1624
# no
# 2093
# 890
# 722
# 3066
# no
# 2432
# no
# 575
# 1629
# no
# 898
# no
# 281
# no
# 494
# 1310
# 1570
# 1020
# 1559
# no
# 982
# 2983
# no
# 528
# no
# 1783
# 2090
# 545
# no
# 564
# no
# 597
# 454
# 1321
# 2507
# 370
# no
# 84
# 2058
# no
# 742
# no
# 834
# 1449
# 576
# no
# 566
# 598
# no
# 983
# 1421
# no
# 2975
# 2684
# 918
# 1628
# no
# 2144
# 1298
# no
# 1361
# 748
# no
# 2784
# 794
# no
# 1805
# 2597
# 821
# 1027
# no
# 1737
# no
# 364
# no
# 441
# 1913
# 1793
# 378
# 1412
# 304
# no
# 473
# no
# 2678
# no
# 1677
# no
# 2963
# 568
# 1202
# 1829
# no
# 1944
# no
# 1579
# no
# 1220
# no
# 1679
# no
# 1463
# no
# 339
# no
# 562
# no
# 1491
# 1171
# 1727
# 181
# no
# 2503
# 3031
# 1516
# no
# 2970
# 1483
# 1084
# 120
# 1658
# 3004
# 2894
# 1448
# no
# 1716
# 2734
# 257
# no
# 176
# no
# 632
# no
# 1755
# no
# 686
# no
# 2315
# 2609
# no
# 1290
# no
# 1567
# 52
# no
# 1111
# no
# 387
# 2175
# no
# 8
# 1832
# no
# 403
# 2350
# 2078
# no
# 346
# no
# 1881
# no
# 1497
# 498
# no
# 280
# 2312
# no
# 402
# no
# 127
# no
# 1012
# 657
# 2418
# no
# 2764
# 2324
# no
# 2720
# no
# 2149
# 1475
# no
# 926
# 682
# 516
# no
# 871
# 691
# no
# 841
# no
# 1702
# no
# 1744
# 423
# no
# 773
# 1659
# 746
# 2475
# no
# 1358
# 108
# 1818
# 2253
# no
# 1112
# 1576
# 2467
# no
# 491
# no
# 1409
# 458
# 1530
# 1612
# 2273
# 2824
# 2519
# no
# 2045
# no
# 1725
# no
# 2934
# 624
# 2408
# 428
# no
# 2883
# no
# 221
# no
# 1557
# no
# 1246
# no
# 2984
# 819
# no
# 2565
# 2120
# no
# 1554
# no
# 1339
# no
# 1199
# no
# 909
# 2347
# 1470
# 1601
# 499
# no
# 1210
# no
# 1747
# 2920
# no
# 2537
# 2606
# no
# 2322
# 1129
# 2218
# no
# 239
# no
# 941
# 1154
# 1201
# 2158
# no
# 1558
# 2601
# no
# 462
# 2248
# 1097
# 148
# no
# 1308
# 838
# 649
# no
# 2528
# no
# 2477
# 2226
# 1994
# no
# 1453
# no
# 1181
# no
# 670
# 1051
# 2554
# no
# 1578
# no
# 2560
# no
# 2326
# no
# 2892
# no
# 1216
# 2152
# no
# 1074
# 268
# no
# 159
# no
# 1293
# no
# 2401
# 585
# no
# 421
# no
# 1684
# 627
# no
# 2680
# 1401
# 693
# no
# 3008
# no
# 1803
# 1140
# 2143
# 1778
# 1769
# 2447
# 477
# no
# 2390
# 1134
# no
# 1676
# 1866
# no
# 27
# 2619
# 31
# 317
# no
# 480
# no
# 2935
# 1369
# 1533
# no
# 2950
# no
# 3057
# 1536
# no
# 1001
# 830
# 2164
# no
# 2913
# 32
# 328
# no
# 1626
# 2067
# 1999
# no
# 2912
# no
# 1184
# 1571
# no
# 1238
# no
# 615
# no
# 2065
# 482
# no
# 1187
# 711
# 2846
# 1970
# no
# 1422
# no
# 2873
# 679
# no
# 653
# 1130
# 1902
# 1831
# no
# 1985
# 894
# no
# 292
# no
# 2295
# no
# 1730
# 1540
# 1794
# 2407
# 2827
# 2960
# 965
# no
# 1631
# no
# 1972
# 1345
# no
# 2867
# 592
# 1756
# no
# 2345
# no
# 1098
# no
# 2134
# 542
# 1363
# no
# 2373
# 44
# 1383
# 1846
# 578
# 59
# 1509
# no
# 1811
# 1132
# no
# 1809
# no
# 2229
# no
# 2313
# 3062
# 999
# no
# 2485
# 2848
# no
# 2862
# no
# 1443
# no
# 676
# 1743
# 125
# no
# 1325
# no
# 2308
# 2689
# 2995
# 1437
# no
# 1625
# 2971
# no
# 1242
# no
# 2364
# no
# 581
# 1891
# no
# 2872
# no
# 1176
# no
# 700
# 1381
# no
# 690
# no
# 2809
# 299
# no
# 1163
# 843
# 1490
# no
# 2625
# 2173
# 2682
# 1857
# no
# 447
# no
# 2066
# no
# 1397
# no
# 1817
# 248
# 836
# 1350
# no
# 1682
# 2019
# no
# 234
# no
# 2818
# no
# 2952
# 879
# 2289
# no
# 1592
# 780
# no
# 2101
# 166
# no
# 706
# 2468
# no
# 2482
# 1245
# no
# 522
# no
# 795
# 1714
# no
# 326
# 1458
# 805
# no
# 2084
# 1156
# no
# 503
# 277
# 2105
# 1416
# no
# 512
# no
# 1883
# no
# 1268
# 972
# no
# 2603
# 213
# 2621
# 2658
# no
# 2518
# 1312
# no
# 62
# 445
# 90
# 2434
# no
# 502
# no
# 1366
# 1975
# no
# 24
# no
# 1542
# 2195
# no
# 2343
# no
# 456
# 1892
# 1548
# 1547
# no
# 582
# 2856
# no
# 2958
# no
# 2875
# 901
# 2880
# 1395
# no
# 1010
# no
# 804
# no
# 1234
# no
# 2393
# 1261
# no
# 2837
# 1442
# no
# 2547
# 1070
# 21
# no
# 99
# 1480
# 3078
# 707
# no
# 897
# no
# 2009
# 963
# 86
# no
# 1645
# 2792
# 2575
# 571
# 2011
# 2161
# 3080
# 1464
# no
# 2446
# no
# 2542
# no
# 2262
# no
# 2583
# 2208
# 1118
# no
# 2526
# 396
# 2088
# 2061
# no
# 1094
# no
# 501
# no
# 1799
# 1013
# no
# 1521
# no
# 1052
# 1922
# 2251
# no
# 2715
# no
# 1115
# no
# 1214
# no
# 297
# no
# 1025
# no
# 2990
# 2555
# no
# 2384
# no
# 2929
# no
# 1262
# no
# 701
# 828
# 2411
# no
# 3023
# 2961
# 133
# no
# 1162
# no
# 2329
# 2000
# 2204
# no
# 1269
# no
# 1528
# 928
# no
# 772
# 1502
# 858
# 1173
# 1647
# 2488
# 1995
# 2820
# 2083
# 1060
# 261
# no
# 3038
# no
# 1814
# no
# 2782
# 468
# no
# 1092
# no
# 1280
# no
# 1478
# no
# 1235
# no
# 1773
# no
# 1854
# no
# 1511
# 563
# 2668
# 1535
# 2991
# 132
# 1011
# no
# 466
# no
# 208
# 2314
# 2552
# no
# 634
# 1926
# 880
# no
# 721
# no
# 2849
# no
# 360
# no
# 1572
# no
# 247
# no
# 2417
# 1715
# no
# 500
# 859
# 1504
# 2474
# no
# 158
# 2421
# no
# 2567
# no
# 1961
# no
# 2879
# 946
# no
# 1565
# 2854
# 2585
# 2692
# 1146
# no
# 413
# no
# 2634
# no
# 2232
# no
# 3018
# 49
# 2614
# no
# 981
# no
# 259
# 2774
# no
# 2256
# no
# 1550
# no
# 1721
# no
# 2146
# 1399
# 2400
# 1917
# no
# 1302
# 2815
# no
# 534
# 429
# 978
# no
# 2301
# 2087
# no
# 2378
# 2722
# 1058
# 2252
# 2781
# 927
# 2293
# no
# 424
# no
# 2316
# no
# 2008
# no
# 1726
# no
# 2779
# no
# 2955
# 2697
# 1575
# no
# 1007
# no
# 979
# no
# 2357
# 1087
# 2529
# 2111
# 71
# no
# 1619
# no
# 400
# 2628
# no
# 2212
# 2153
# 212
# no
# 443
# 511
# no
# 194
# 2620
# 1593
# no
# 83
# no
# 1299
# 366
# 2686
# 368
# no
# 784
# 647
# no
# 1496
# 2602
# 1450
# 1410
# 688
# no
# 2097
# 527
# no
# 2665
# no
# 1795
# 2230
# no
# 114
# no
# 2224
# no
# 3033
# no
# 1614
# 1003
# no
# 1392
# 680
# no
# 436
# no
# 697
# 1159
# 2757
# 232
# no
# 2122
# no
# 1508
# no
# 278
# 2783
# 327
# 2731
# 218
# no
# 5
# no
# 1749
# 820
# no
# 245
# 1979
# no
# 202
# no
# 1142
# 1211
# no
# 2294
# no
# 1583
# no
# 2372
# no
# 1438
# 1949
# no
# 2663
# no
# 952
# 1858
# 2235
# 2825
# no
# 514
# no
# 1048
# 1729
# no
# 1904
# no
# 1182
# 2455
# 1213
# 1394
# no
# 1924
# 2268
# no
# 2171
# 790
# no
# 552
# 1859
# no
# 2589
# no
# 2643
# no
# 733
# 870
# no
# 1910
# no
# 2029
# no
# 2242
# 2085
# 543
# 925
# 724
# no
# 2139
# no
# 1771
# 383
# no
# 2355
# no
# 2200
# no
# 723
# no
# 2043
# no
# 2258
# 1960
# 2006
# no
# 2223
# 23
# 2711
# 1899
# no
# 495
# no
# 1606
# 1018
# 1761
# no
# 554
# no
# 2728
# 1964
# 2808
# 775
# 2424
# 1689
# 1894
# no
# 1078
# 1492
# 808
# 1472
# 1038
# 818
# no
# 861
# no
# 544
# 1959
# 315
# 2573
# 1996
# 509
# no
# 1600
# 719
# 141
# 1920
# no
# 760
# no
# 193
# no
# 1016
# no
# 507
# no
# 1255
# 667
# 1992
# 2430
# 2406
# no
# 1021
# 1209
# no
# 1701
# 2570
# no
# 287
# no
# 681
# no
# 866
# no
# 1248
# no
# 2857
# no
# 266
# no
# 811
# 2693
# no
# 504
# 1845
# 434
# no
# 2479
# 1407
# 1113
# 1976
# no
# 1643
# no
# 2431
# 905
# 2196
# 1878
# 758
# 1131
# 2052
# no
# 1295
# 112
# 2123
# no
# 190
# no
# 2459
# no
# 1665
# no
# 1101
# 1948
# 2340
# no
# 115
# 196
# no
# 2332
# 2687
# no
# 2633
# no
# 845
# 1741
# no
# 2914
# 2318
# 153
# 3071
# no
# 1415
# 2946
# 1380
# no
# 833
# 2285
# no
# 2148
# no
# 2106
# 2595
# 584
# no
# 2244
# no
# 1966
# 991
# no
# 617
# 2168
# 1765
# 778
# 1215
# no
# 195
# no
# 1
# no
# 1707
# 530
# no
# 2553
# 1485
# 666
# no
# 2672
# 1258
# 375
# no
# 63
# 3048
# 1552
# 2598
# no
# 2112
# 461
# no
# 2823
# 2249
# no
# 1582
# 1141
# no
# 2140
# 1786
# no
# 2023
# no
# 351
# no
# 1389
# no
# 2545
# no
# 908
# 867
# no
# 2898
# 29
# 2561
# 2376
# no
# 1560
# no
# 2461
# no
# 1039
# 1519
# no
# 2380
# 2172
# no
# 349
# 2255
# no
# 1309
# 2299
# 712
# 872
# no
# 1109
# no
# 389
# no
# 506
# 1175
# 1049
# 233
# no
# 265
# 394
# 152
# 143
# no
# 1656
# no
# 1402
# no
# 1284
# 1317
# no
# 1636
# no
# 409
# no
# 2131
# no
# 2228
# no
# 1797
# 2272
# 479
# no
# 2657
# no
# 618
# no
# 1207
# no
# 848
# 734
# 230
# no
# 2194
# no
# 611
# no
# 1195
# no
# 2893
# no
# 1712
# no
# 2982
# no

# %%
as_final
# Out:
# [['cord', 'battery', 'life'],
#  [],
#  ['service', 'center', '"sales"', 'team', 'tech', 'guy'],
#  [],
#  [],
#  ['quality', 'GUI', 'applications', 'use'],
#  ['start', 'up'],
#  [],
#  ['features', 'iChat', 'Photobooth', 'garage', 'band'],
#  [],
#  ['features'],
#  [],
#  ['GUI', 'screen', 'power', 'light', 'hard', 'drive', 'ligh'],
#  [],
#  ['processor', 'graphics', 'cards', 'battery', 'life'],
#  ['battery'],
#  ['rubber', 'enclosure', 'edge'],
#  ['multi-touch',
#   'gestures',
#   'tracking',
#   'area',
#   'external',
#   'mouse',
#   'gaming'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['suite', 'of', 'software'],
#  ['speed'],
#  [],
#  ['Windows', '7'],
#  [],
#  ['usb', 'devices'],
#  [],
#  ['keyboard'],
#  ['software', 'system'],
#  [],
#  ['Microsoft', 'office', 'for', 'the', 'mac'],
#  ['syncing'],
#  [],
#  ['30"', 'HD', 'Monitor', 'screen'],
#  [],
#  ['boot', 'up'],
#  ['service'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['battery'],
#  [],
#  ['operating', 'system', 'preloaded', 'software'],
#  [],
#  [],
#  ['price', 'features'],
#  ['clock', 'in', 'BIOS', 'setup'],
#  ['WARRANTY', 'SERVICE'],
#  [],
#  [],
#  ['brand'],
#  [],
#  ['warranty'],
#  [],
#  [],
#  ['features'],
#  [],
#  [],
#  [],
#  ['fan'],
#  ['Customer',
#   'Service',
#   'number',
#   'warranty',
#   'talking',
#   'to',
#   'a',
#   'technician'],
#  [],
#  ['hard', 'disc', 'windows', 'drivers'],
#  ['Drivers', 'BIOS', 'update', 'system'],
#  [],
#  ['HP', 'Technical', 'Support'],
#  [],
#  [],
#  ['browser'],
#  [],
#  ['keyboard'],
#  ['virus', 'scan'],
#  ['9', 'punds'],
#  ['program'],
#  ['warrenty'],
#  ['Toshiba', 'Warranty'],
#  [],
#  ['Quality'],
#  ['webcam', 'value'],
#  ['internet', 'managing', 'personal', 'files'],
#  ['motherboard'],
#  ['system'],
#  ['charger', 'hardware'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['force', 'quit'],
#  [],
#  ['works'],
#  ['Windows', '7', 'VMWare', 'program'],
#  ['operating', 'system', 'runs', 'navigate', 'find', 'files'],
#  ['warrenty'],
#  [],
#  [],
#  [],
#  [],
#  ['extended', 'warranty'],
#  [],
#  ['memory', 'speed', 'performace'],
#  [],
#  [],
#  ['opening', 'my', 'Documents', 'folder'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['operating', 'systems'],
#  [],
#  ['charger'],
#  ['speed'],
#  [],
#  ['glass', 'touchpad'],
#  ['hard', 'drive', 'mother', 'board'],
#  ['external', 'speaker', 'sound'],
#  [],
#  [],
#  [],
#  ['battery', 'life'],
#  ['hardware'],
#  [],
#  ['shipping'],
#  [],
#  [],
#  ['Mac', 'software', 'Microsoft', 'software', 'use'],
#  [],
#  ['delete', '', 'key', 'editing'],
#  [],
#  [],
#  ['use', 'service', 'phone', 'assistance', 'genius', 'bar'],
#  ['battery',
#   'life',
#   'battery',
#   'life',
#   'gaming',
#   'movie',
#   'playing',
#   'web',
#   'browsing',
#   'word',
#   'editing'],
#  [],
#  [],
#  ['recovery', 'discs'],
#  ['Office', "Max's", '"Max', 'Assurance"'],
#  [],
#  ['iMac', 'backup', 'disc', 'USB'],
#  [],
#  [],
#  [],
#  ['battery', 'life'],
#  ['battery', 'timer'],
#  ['Temperatures', 'Core', 'Processing', 'Unit', 'temperatures'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['service'],
#  ['virus', 'protection', 'for', 'Mac'],
#  ['bluetooth'],
#  ['LG', 'notebook', 'service', 'center', 'hinge'],
#  ['games'],
#  [],
#  ['responds'],
#  ['motherboard', 'motherboard'],
#  [],
#  ['hardware'],
#  ['motherboard'],
#  ['use'],
#  ['representive', 'at', 'Microsoft', 'system', 'XP'],
#  [],
#  ['WIndows', '7', 'Vista'],
#  [],
#  [],
#  [],
#  ['Keyboard'],
#  [],
#  [],
#  [],
#  [],
#  ["Dell's", 'customer', 'disservice'],
#  [],
#  [],
#  [],
#  ['cooling', 'system', 'use'],
#  ['quad', 'core', 'I7'],
#  [],
#  [],
#  ['sales', 'associate'],
#  ['system', 'Windows', 'applications'],
#  ['virus', 'program'],
#  [],
#  [],
#  [],
#  [],
#  ['weighed', 'seven', 'pounds'],
#  ['battery'],
#  ['bag'],
#  ['color'],
#  [],
#  [],
#  ['keys', 'designed'],
#  [],
#  [],
#  [],
#  [],
#  ['style', 'speed'],
#  [],
#  [],
#  ['keyboard'],
#  [],
#  [],
#  ['mousepad'],
#  ['battery'],
#  [],
#  [],
#  [],
#  ['sales', 'service', 'DELL', 'SUPPORT'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['hard', 'drive', 'motherboard'],
#  ['speed', 'construction', 'quality', 'longevity', 'cost'],
#  ['keyboard', 'keys', 'configuration', 'of', '"extra', 'key"'],
#  ['touch', 'pad'],
#  ['use', 'security', 'pricetag'],
#  ['use', 'work'],
#  ['preloaded', 'software'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['webcam'],
#  ['vga', 'port', 'screen'],
#  ['battery', 'life'],
#  ['keys'],
#  [],
#  [],
#  ['software'],
#  ['volume', 'mouse'],
#  ['touchpad'],
#  ['boots', 'up'],
#  ['hard', 'drive'],
#  [],
#  [],
#  ['look', 'and', 'feel', 'standpoint'],
#  ['safari', 'safari', 'Mozzilla', 'firfox'],
#  ['Bluetooth', 'fingerprint', 'reader', 'driver', 'software'],
#  ['battery', 'speed', 'display'],
#  [],
#  [],
#  [],
#  ['delivery'],
#  ['battery', 'life', 'performance', 'memory'],
#  [],
#  [],
#  ['applications', 'Microsoft', 'office'],
#  ['Resolution', 'appearance', 'cooling', 'system', 'graphics', 'card'],
#  ['built-in', 'webcam', 'built-in', 'mic', 'cam', 'mic'],
#  ['Windows', 'Vista'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['board', 'connector', 'power', 'supply', 'warrenty', 'power', 'supply'],
#  [],
#  ['ethernet', 'works'],
#  ['drag', 'and', 'drop', 'feature'],
#  ['webcam'],
#  [],
#  ['sales', 'tax'],
#  [],
#  ['software', 'packages', 'iWork', 'GarageBand', 'iMovie'],
#  [],
#  ['screen', 'colors', 'resolution'],
#  ['monitor'],
#  [],
#  ['iTunes'],
#  [],
#  [],
#  [],
#  ['Size', 'external', 'monitor'],
#  ['base', 'installation', 'software'],
#  [],
#  ['manuf'],
#  ['camera'],
#  ['display'],
#  [],
#  ['AMD', 'Turin', 'processor', 'Intel'],
#  ['warranty'],
#  ['start', 'menu', 'navigate'],
#  ['bluray', 'read/write', 'drive'],
#  [],
#  ['service', 'tech'],
#  ['tech', 'store'],
#  [],
#  ['surface'],
#  [],
#  ['screen', 'keyboard'],
#  [],
#  [],
#  ['iLife', 'Snow', 'Leopard', 'X'],
#  ['price', 'tag'],
#  ['Mac', 'OS'],
#  [],
#  ['sound', 'output', 'quality'],
#  [],
#  [],
#  [],
#  [],
#  ['techie'],
#  ['use'],
#  ['Toshiba', 'online', 'help'],
#  [],
#  [],
#  ['service', 'life'],
#  ['ports', 'processor'],
#  ['price', 'look'],
#  ['keyboard', 'keys'],
#  ['screen'],
#  [],
#  ['quality'],
#  ['stock', 'screen'],
#  ['gray', 'color'],
#  [],
#  [],
#  [],
#  [],
#  ['volume', 'buttons'],
#  [],
#  [],
#  ['processor', 'computing'],
#  [],
#  [],
#  ['protector', 'key', 'pad'],
#  ['magnetic', 'plug-in', 'power', 'charging', 'power', 'cord'],
#  [],
#  ['XP', 'Vista'],
#  ['graphics', 'use'],
#  [],
#  ['Mac', 'OS', 'use'],
#  ['support'],
#  [],
#  ['Geek', 'Squad'],
#  [],
#  [],
#  [],
#  ['graphics', 'quality'],
#  ['Appleworks', 'browser'],
#  [],
#  [],
#  [],
#  ['paint', 'keyboard'],
#  [],
#  ['service', 'department'],
#  ['warrenty', 'warrentys'],
#  [],
#  [],
#  ['hard', 'disk'],
#  ['CD', 'drive', 'running'],
#  [],
#  ['screen', 'size', 'web', 'browsing'],
#  ['software', 'loads'],
#  ['trackpad', 'external', 'mouse', 'trackpad'],
#  ['games'],
#  ['features', 'human', 'interface'],
#  ['inbuilt', 'applications', 'Software'],
#  ['body'],
#  ['i5'],
#  ['antivirus', 'software', 'firewall'],
#  [],
#  ['price'],
#  [],
#  [],
#  ['Apple', 'team'],
#  [],
#  ['Vista', 'Vista', 'operating', 'system', 'Vista'],
#  ['video', 'chat', 'quality'],
#  [],
#  [],
#  ['mouse'],
#  [],
#  ['Fan', 'cooling', 'pad', 'feature'],
#  ['software'],
#  ['installation', 'time'],
#  ['power', 'storage', 'abilitiy'],
#  ['spotlight', 'search', 'feature'],
#  ['wireless', 'system', 'Windows', '7'],
#  ['quality'],
#  [],
#  ['battery', 'life', 'speed'],
#  [],
#  ['OS', 'OS'],
#  ['iTunes', 'program'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['gaming'],
#  ['battery'],
#  ['Apple', 'support', 'techs'],
#  ['adding', 'the', 'bluetooth'],
#  [],
#  [],
#  ['graphic', 'power', 'Adobe', 'Creative', 'apps'],
#  ['programs', 'use'],
#  ['materials'],
#  [],
#  [],
#  [],
#  ['software'],
#  [],
#  ['Tech', 'support', 'power', 'supply'],
#  [],
#  [],
#  ['POWER', 'SUPPLY'],
#  ['size'],
#  [],
#  ['warranty'],
#  ['Windows', 'XP', 'SP2'],
#  [],
#  ['Windows',
#   '7',
#   'Ultimate',
#   'Bluetooth',
#   'Fingerprint',
#   'reader',
#   'software'],
#  ['techs', 'at', 'HP'],
#  [],
#  ['video', 'card'],
#  [],
#  ['graphics', 'security'],
#  ['audio'],
#  ['keyboard'],
#  [],
#  ['runs'],
#  [],
#  [],
#  ['set', 'up'],
#  [],
#  ['screen'],
#  [],
#  ['word', 'processing', 'internet'],
#  ['trackpad'],
#  [],
#  ['battery', 'life', 'spec'],
#  ['HD', 'graphics', 'chip', 'components', 'DVD', 'burner'],
#  [],
#  [],
#  ['USB', 'ports'],
#  [],
#  [],
#  ['software'],
#  ['system'],
#  ['ran'],
#  [],
#  ['price', 'operation'],
#  ['brand'],
#  ['components', 'ground', 'loop', 'isolator', 'price', 'range', 'quality'],
#  [],
#  ['warranty'],
#  [],
#  [],
#  [],
#  ['leading', 'edge'],
#  ['bloatware'],
#  [],
#  [],
#  [],
#  [],
#  ['Maximum', 'sound'],
#  [],
#  ['windows', '7', 'Bootcamp'],
#  [],
#  ['price', 'action', 'pack', 'games', 'works'],
#  ['price'],
#  [],
#  [],
#  ['performance'],
#  ['twin', 'packing', 'functions'],
#  ['after', 'sales', 'support', 'look'],
#  [],
#  [],
#  ['display', 'screen'],
#  [],
#  ['acer', 'arcade'],
#  ['customer', 'support'],
#  [],
#  ['screen', 'cd', 'drive'],
#  ['runs'],
#  ['design'],
#  [],
#  ['size'],
#  [],
#  [],
#  [],
#  ['games', 'games'],
#  ['life'],
#  [],
#  ['warranty'],
#  [],
#  [],
#  [],
#  ['pad'],
#  ['value', 'price'],
#  ['system', 'performance', 'linux', 'based', 'os'],
#  ['use'],
#  [],
#  ['batteries', 'shipping', 'carton'],
#  [],
#  ['use'],
#  ['program'],
#  [],
#  [],
#  [],
#  ['virus', 'protection'],
#  [],
#  ['screen'],
#  ['processor', 'OSX', '16', 'graphics', 'hardware', 'software'],
#  [],
#  [],
#  ['Intel', 'Core', 'processors', 'HDMI', 'port'],
#  ['Internet', 'Explorer'],
#  ['staff'],
#  [],
#  [],
#  [],
#  ['price', 'premium', 'features'],
#  [],
#  ['product', 'and', 'help', 'aftermarket'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Microsoft', 'word'],
#  ['usb',
#   'ports',
#   'sd',
#   'memory',
#   'card',
#   'reader',
#   'sd',
#   'memory',
#   'car',
#   'expansion'],
#  [],
#  ['LaCie',
#   '2Big',
#   'external',
#   'drive',
#   'firewire',
#   '800',
#   'interface',
#   'Time',
#   'Machine'],
#  [],
#  ['sound'],
#  ['extra', 'features', 'windows', '7', 'home', 'premium'],
#  [],
#  [],
#  ['Acer', 'screen', 'USB', 'port', 'boot'],
#  [],
#  ['battery', 'life'],
#  ['fires', 'up'],
#  [],
#  [],
#  ['keyboard'],
#  [],
#  [],
#  [],
#  ['software'],
#  ['online', 'tutorial', 'videos'],
#  [],
#  ['image', 'soud'],
#  ['windows', 'boot', 'up', 'shut', 'down', 'windows'],
#  ['Mac', 'OS', 'use'],
#  [],
#  [],
#  [],
#  ['cost'],
#  ['Windows',
#   '7',
#   'Starter',
#   'Windows',
#   '7',
#   'Home',
#   'Premium',
#   'Windows',
#   '7',
#   'Professional'],
#  ['specifications'],
#  [],
#  [],
#  ['power', 'cords'],
#  ['multi-touch', 'features'],
#  [],
#  ['screen', 'clicking', 'buttons'],
#  ['battery', 'life'],
#  [],
#  [],
#  [],
#  ['Windows'],
#  ['wired', 'lan'],
#  [],
#  ['hard', 'reboot'],
#  [],
#  [],
#  ['hardware'],
#  [],
#  ['hard', 'drive'],
#  ['battery', 'life'],
#  [],
#  [],
#  [],
#  [],
#  ['Apple', 'care'],
#  [],
#  [],
#  ['font', 'Features'],
#  [],
#  ['programs', 'run'],
#  [u'plastic\xa0pieces'],
#  [],
#  ['2GB', 'RAM', 'stick'],
#  [],
#  [],
#  [],
#  ['Windows'],
#  ['Microsoft', 'Word', 'for', 'Mac'],
#  [],
#  ['WARRANTY', 'COMPANY'],
#  ['cusromer', 'service', 'center'],
#  ['size', 'weight'],
#  ['battery'],
#  ['aluminum', 'body'],
#  [],
#  ['watching', 'movies', 'playing'],
#  ['build', 'quality', 'performance'],
#  ['dock', 'program', 'program'],
#  [],
#  [],
#  ['working'],
#  [],
#  ['costing'],
#  ['price', 'i7'],
#  [],
#  [],
#  ['monitor'],
#  ['extended', 'warranty'],
#  ['Boots', 'up', 'runs'],
#  ['screen'],
#  [],
#  ['driver'],
#  [],
#  ['tech', 'support'],
#  [],
#  ['work'],
#  ['hard', 'drive'],
#  [],
#  ['twin', 'packing', 'functions'],
#  [],
#  [],
#  [],
#  [],
#  ['warranty'],
#  [],
#  ['performance', 'price'],
#  ['BIOS'],
#  ['design', 'tech', 'issues'],
#  [],
#  [],
#  ['size', 'space'],
#  ['service'],
#  ['memory', 'speed', 'priced'],
#  ['internet', 'speed'],
#  [],
#  ['programs',
#   'Garageband',
#   'Photo',
#   'Booth',
#   'iPhoto',
#   'iMovie',
#   'video-editing',
#   'movie-making',
#   'photo',
#   'management',
#   'music',
#   'Pages',
#   'Numbers',
#   'Keynote',
#   'school',
#   'or',
#   'office',
#   'use'],
#  [],
#  [],
#  [],
#  [],
#  ['screen', 'colors'],
#  ['value', 'price', 'value'],
#  [],
#  [],
#  [],
#  [],
#  ['web', 'cam', 'burn', "cd's"],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['17', 'inch', 'screen'],
#  ['support'],
#  [],
#  ['Bluetooth', 'Drivers/Applications', 'DVD', 'Launch', 'Manager'],
#  [],
#  [],
#  ['glass', 'screen'],
#  ['switchable', 'graphic', 'card', 'gaming'],
#  [],
#  ['service'],
#  ['battery', 'life'],
#  [],
#  ['technical', 'support'],
#  [],
#  ['BOOT', 'MGR'],
#  ['recovery', 'cd'],
#  ['price', 'features'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Skype'],
#  [],
#  ['mouse', 'buttons'],
#  [],
#  ['HDD', 'rails', 'hard', 'drive'],
#  [],
#  [],
#  [],
#  ['quality'],
#  ['staff'],
#  [],
#  ['Games'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['GarageBand'],
#  [],
#  [],
#  ['warranty', 'hard', 'drive'],
#  ['price'],
#  [],
#  [],
#  [],
#  [],
#  ['home', 'use', 'business', 'use'],
#  [],
#  ['virus', 'protection', 'updates'],
#  ['MS', 'Office', 'apps'],
#  [],
#  [],
#  [],
#  ['feature', 'Windows', 'games'],
#  ['battery', 'life'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['battery', 'life'],
#  ['price'],
#  ['Nortons', 'virus', 'scan'],
#  ['frame'],
#  ['features', 'use'],
#  [],
#  [],
#  ['loaded'],
#  ['Windows', '7', 'Vista', 'Vista', 'windows'],
#  ['Windows', 'XP', 'Vista'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['key', 'broad'],
#  [],
#  [],
#  ['warranty', 'repair', '"depot"'],
#  ['school', 'use'],
#  [],
#  [],
#  ['design'],
#  ['battery', 'life'],
#  ['programs'],
#  [],
#  ['Wireless'],
#  [],
#  ['battery', 'life', 'programs'],
#  ['trackpad', 'programs', 'navigating'],
#  ['speakers', 'subwoofer'],
#  ['built', 'in', 'camera'],
#  ['price'],
#  [],
#  ['warranty'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['left', 'mouse', 'key', 'costed'],
#  [],
#  [],
#  [],
#  ['speed', 'hard', 'drive', 'space'],
#  ['picture'],
#  [],
#  [],
#  ['extended', 'warranty', 'extended', 'warranties'],
#  [],
#  [],
#  [],
#  [],
#  ['battery'],
#  ['Screen', 'battery', 'life'],
#  ['appearance'],
#  [],
#  ['technical', 'service', 'for', 'dell'],
#  ['graphics', 'warranty'],
#  [],
#  [],
#  ['battery'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['case'],
#  [],
#  ['performance', 'price', 'look', 'applications'],
#  ['speed'],
#  [],
#  [],
#  ['tech', 'support'],
#  ['gaming', 'use'],
#  ['Photoshop'],
#  [],
#  [],
#  [],
#  [],
#  ['ram'],
#  [],
#  [],
#  [],
#  ['system', 'clock'],
#  ['RAM'],
#  ['securitysoftware'],
#  [],
#  [],
#  ['driver', 'updates'],
#  ['Windows'],
#  [],
#  [],
#  ['work'],
#  [],
#  ['works'],
#  [],
#  ['HD', 'HD', 'graphics', 'card'],
#  [],
#  ['built', 'in', 'camera'],
#  [],
#  ['DVD', 'burner'],
#  ['DVD', 'burner'],
#  ['works'],
#  ['15', 'inch'],
#  [],
#  ['Product', 'support'],
#  ['screen', 'use'],
#  ['casing', 'of', 'the', 'power', 'cord'],
#  ['internet', 'signals'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['price'],
#  ['right', 'speaker'],
#  ['price', 'tag', 'software', 'updates'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['multiple', 'page', 'viewer'],
#  ['shipped'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['Keyboard', 'use'],
#  ['warranty'],
#  [],
#  [],
#  ['quality'],
#  ['features'],
#  [],
#  ['recovery', 'disk'],
#  ['features'],
#  [],
#  ['programs', 'Office', 'Office', 'programs'],
#  ['wifi'],
#  ['TYPING'],
#  ['screen'],
#  ['temp'],
#  [],
#  [],
#  ['Windows', 'operating', 'system'],
#  ['OS', 'processor', 'speed', 'thunderbolt', 'port'],
#  [],
#  ['lcd', 'screen'],
#  [],
#  ['Images'],
#  [],
#  [],
#  [],
#  ['windows', 'vista', 'windows', 'xp'],
#  ['Vista',
#   'Adobe',
#   'Flash',
#   'player',
#   'Internet',
#   'Explore',
#   'Windows',
#   'update',
#   'update'],
#  [],
#  ['switch', 'switch'],
#  [],
#  ['4GB', 'stick', 'of', 'RAM'],
#  [],
#  [],
#  [],
#  [],
#  ['hardrive', 'touch', 'control', 'buttons', 'keyboard'],
#  [],
#  [],
#  [],
#  ['performance'],
#  [],
#  [],
#  [],
#  ['iLife',
#   'software',
#   'iPhoto',
#   'iMovie',
#   'iWeb',
#   'iTunes',
#   'GarageBand',
#   'runs'],
#  ['system', 'board'],
#  ['size', 'software', 'hardware'],
#  [],
#  ['memory', 'hard', 'drive', 'graphics'],
#  ['programs', 'navigation'],
#  [],
#  [],
#  [],
#  [],
#  ['hinge', 'LCD'],
#  ['DELL', 'Customer', 'Service'],
#  [],
#  [],
#  [],
#  [],
#  ['RMA', 'service'],
#  [],
#  [],
#  ['Design'],
#  ['keyboard'],
#  [],
#  [],
#  ['battery', 'life'],
#  ['screen/video', 'resolution', 'resolution'],
#  ['applications',
#   'Dreamweaver',
#   'Final',
#   'Cut',
#   'Pro',
#   '7',
#   'Photoshop',
#   'Safari',
#   'Firefox',
#   'MSN',
#   'Messenger'],
#  [],
#  [],
#  [],
#  ['warrenty'],
#  ['tech', 'support'],
#  ['Apple', 'applications', 'iPhoto'],
#  [],
#  ['gigs'],
#  [],
#  [],
#  ['memory', '17-inch', 'screen', 'DVD', 'CD', 'burners'],
#  ['web',
#   'browsing',
#   'uploading',
#   'photos',
#   'watching',
#   'movies',
#   'creating',
#   'presentations'],
#  [],
#  ['Quality', 'Display'],
#  ['weight', '12', 'cell', 'battery'],
#  [],
#  ['case'],
#  [],
#  [],
#  [],
#  ['power', 'adapter', 'plug'],
#  ['features', 'speakers'],
#  ['screen'],
#  ['TAB'],
#  ['extended', 'warrenty'],
#  [],
#  ['TFT', 'panel'],
#  ['Navigation', 'Windows', 'operating', 'systems'],
#  [],
#  [],
#  ['screen', 'screen', 'size', 'bulk'],
#  ['music', 'software', 'software', 'picture', 'video'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['combined', 'touch', 'pad', 'and', 'clicker'],
#  ['Unibody', 'construction'],
#  [],
#  [],
#  [],
#  ['value'],
#  [],
#  ['Windows', 'screen', 'hinges'],
#  ['BATTERY', 'STORAGE', 'LIFE', 'SERVICE'],
#  ['storage', 'ram'],
#  ...]

# %%
aspect_term=['battery']
for p in parses:
    for governor, dep, dependent in p.triples():
        if dep=='compound':
            print("yes")
            df2['feature']=dependent[0]+'-'+governor[0]
        print(governor[0], dep, dependent[0])

# %%
as_final
# Out:
# [['cord'],
#  ['battery', 'life'],
#  ['service', 'center'],
#  ['"sales"', 'team'],
#  ['tech', 'guy'],
#  ['quality'],
#  ['GUI'],
#  ['applications'],
#  ['use'],
#  ['start', 'up'],
#  ['features'],
#  ['iChat'],
#  ['Photobooth'],
#  ['garage', 'band'],
#  ['features'],
#  ['GUI'],
#  ['screen'],
#  ['power', 'light'],
#  ['hard', 'drive', 'ligh'],
#  ['processor'],
#  ['graphics', 'cards'],
#  ['battery', 'life'],
#  ['battery'],
#  ['rubber', 'enclosure'],
#  ['edge'],
#  ['multi-touch', 'gestures'],
#  ['tracking', 'area'],
#  ['external', 'mouse'],
#  ['gaming'],
#  ['suite', 'of', 'software'],
#  ['speed'],
#  ['Windows', '7'],
#  ['usb', 'devices'],
#  ['keyboard'],
#  ['software'],
#  ['system'],
#  ['Microsoft', 'office', 'for', 'the', 'mac'],
#  ['syncing'],
#  ['30"', 'HD', 'Monitor'],
#  ['screen'],
#  ['boot', 'up'],
#  ['service'],
#  ['battery'],
#  ['operating', 'system'],
#  ['preloaded', 'software'],
#  ['price'],
#  ['features'],
#  ['clock', 'in', 'BIOS', 'setup'],
#  ['WARRANTY', 'SERVICE'],
#  ['brand'],
#  ['warranty'],
#  ['features'],
#  ['fan'],
#  ['Customer', 'Service', 'number'],
#  ['warranty'],
#  ['talking', 'to', 'a', 'technician'],
#  ['hard', 'disc'],
#  ['windows'],
#  ['drivers'],
#  ['Drivers'],
#  ['BIOS', 'update'],
#  ['system'],
#  ['HP', 'Technical', 'Support'],
#  ['browser'],
#  ['keyboard'],
#  ['virus', 'scan'],
#  ['9', 'punds'],
#  ['program'],
#  ['warrenty'],
#  ['Toshiba', 'Warranty'],
#  ['Quality'],
#  ['webcam'],
#  ['value'],
#  ['internet'],
#  ['managing', 'personal', 'files'],
#  ['motherboard'],
#  ['system'],
#  ['charger'],
#  ['hardware'],
#  ['force', 'quit'],
#  ['works'],
#  ['Windows', '7'],
#  ['VMWare', 'program'],
#  ['operating', 'system'],
#  ['runs'],
#  ['navigate'],
#  ['find', 'files'],
#  ['warrenty'],
#  ['extended', 'warranty'],
#  ['memory'],
#  ['speed'],
#  ['performace'],
#  ['opening', 'my', 'Documents', 'folder'],
#  ['operating', 'systems'],
#  ['charger'],
#  ['speed'],
#  ['glass', 'touchpad'],
#  ['hard', 'drive'],
#  ['mother', 'board'],
#  ['external', 'speaker'],
#  ['sound'],
#  ['battery', 'life'],
#  ['hardware'],
#  ['shipping'],
#  ['Mac', 'software'],
#  ['Microsoft', 'software'],
#  ['use'],
#  ['delete', '', 'key'],
#  ['editing'],
#  ['use'],
#  ['service'],
#  ['phone', 'assistance'],
#  ['genius', 'bar'],
#  ['battery', 'life'],
#  ['battery', 'life'],
#  ['gaming'],
#  ['movie', 'playing'],
#  ['web', 'browsing'],
#  ['word', 'editing'],
#  ['recovery', 'discs'],
#  ['Office', "Max's", '"Max', 'Assurance"'],
#  ['iMac', 'backup', 'disc'],
#  ['USB'],
#  ['battery', 'life'],
#  ['battery', 'timer'],
#  ['Temperatures'],
#  ['Core', 'Processing', 'Unit', 'temperatures'],
#  ['service'],
#  ['virus', 'protection', 'for', 'Mac'],
#  ['bluetooth'],
#  ['LG', 'notebook', 'service', 'center'],
#  ['hinge'],
#  ['games'],
#  ['responds'],
#  ['motherboard'],
#  ['motherboard'],
#  ['hardware'],
#  ['motherboard'],
#  ['use'],
#  ['representive', 'at', 'Microsoft'],
#  ['system'],
#  ['XP'],
#  ['WIndows', '7'],
#  ['Vista'],
#  ['Keyboard'],
#  ["Dell's", 'customer', 'disservice'],
#  ['cooling', 'system'],
#  ['use'],
#  ['quad', 'core', 'I7'],
#  ['sales', 'associate'],
#  ['system'],
#  ['Windows', 'applications'],
#  ['virus', 'program'],
#  ['weighed'],
#  ['seven', 'pounds'],
#  ['battery'],
#  ['bag'],
#  ['color'],
#  ['keys'],
#  ['designed'],
#  ['style'],
#  ['speed'],
#  ['keyboard'],
#  ['mousepad'],
#  ['battery'],
#  ['sales'],
#  ['service'],
#  ['DELL', 'SUPPORT'],
#  ['hard', 'drive'],
#  ['motherboard'],
#  ['speed'],
#  ['construction', 'quality'],
#  ['longevity'],
#  ['cost'],
#  ['keyboard'],
#  ['keys'],
#  ['configuration', 'of', '"extra', 'key"'],
#  ['touch', 'pad'],
#  ['use'],
#  ['security'],
#  ['pricetag'],
#  ['use'],
#  ['work'],
#  ['preloaded', 'software'],
#  ['webcam'],
#  ['vga', 'port'],
#  ['screen'],
#  ['battery', 'life'],
#  ['keys'],
#  ['software'],
#  ['volume'],
#  ['mouse'],
#  ['touchpad'],
#  ['boots', 'up'],
#  ['hard', 'drive'],
#  ['look', 'and', 'feel', 'standpoint'],
#  ['safari'],
#  ['safari'],
#  ['Mozzilla', 'firfox'],
#  ['Bluetooth'],
#  ['fingerprint', 'reader', 'driver'],
#  ['software'],
#  ['battery'],
#  ['speed'],
#  ['display'],
#  ['delivery'],
#  ['battery', 'life'],
#  ['performance'],
#  ['memory'],
#  ['applications'],
#  ['Microsoft', 'office'],
#  ['Resolution'],
#  ['appearance'],
#  ['cooling', 'system'],
#  ['graphics', 'card'],
#  ['built-in', 'webcam'],
#  ['built-in', 'mic'],
#  ['cam'],
#  ['mic'],
#  ['Windows', 'Vista'],
#  ['board'],
#  ['connector'],
#  ['power', 'supply'],
#  ['warrenty'],
#  ['power', 'supply'],
#  ['ethernet'],
#  ['works'],
#  ['drag', 'and', 'drop', 'feature'],
#  ['webcam'],
#  ['sales', 'tax'],
#  ['software', 'packages'],
#  ['iWork'],
#  ['GarageBand'],
#  ['iMovie'],
#  ['screen'],
#  ['colors'],
#  ['resolution'],
#  ['monitor'],
#  ['iTunes'],
#  ['Size'],
#  ['external', 'monitor'],
#  ['base', 'installation'],
#  ['software'],
#  ['manuf'],
#  ['camera'],
#  ['display'],
#  ['AMD', 'Turin', 'processor'],
#  ['Intel'],
#  ['warranty'],
#  ['start', 'menu'],
#  ['navigate'],
#  ['bluray', 'read/write', 'drive'],
#  ['service', 'tech'],
#  ['tech', 'store'],
#  ['surface'],
#  ['screen'],
#  ['keyboard'],
#  ['iLife'],
#  ['Snow', 'Leopard', 'X'],
#  ['price', 'tag'],
#  ['Mac', 'OS'],
#  ['sound', 'output', 'quality'],
#  ['techie'],
#  ['use'],
#  ['Toshiba', 'online', 'help'],
#  ['service', 'life'],
#  ['ports'],
#  ['processor'],
#  ['price'],
#  ['look'],
#  ['keyboard'],
#  ['keys'],
#  ['screen'],
#  ['quality'],
#  ['stock', 'screen'],
#  ['gray', 'color'],
#  ['volume', 'buttons'],
#  ['processor'],
#  ['computing'],
#  ['protector'],
#  ['key', 'pad'],
#  ['magnetic', 'plug-in', 'power', 'charging', 'power', 'cord'],
#  ['XP'],
#  ['Vista'],
#  ['graphics'],
#  ['use'],
#  ['Mac', 'OS'],
#  ['use'],
#  ['support'],
#  ['Geek', 'Squad'],
#  ['graphics', 'quality'],
#  ['Appleworks'],
#  ['browser'],
#  ['paint'],
#  ['keyboard'],
#  ['service', 'department'],
#  ['warrenty'],
#  ['warrentys'],
#  ['hard', 'disk'],
#  ['CD', 'drive'],
#  ['running'],
#  ['screen', 'size'],
#  ['web', 'browsing'],
#  ['software'],
#  ['loads'],
#  ['trackpad'],
#  ['external', 'mouse'],
#  ['trackpad'],
#  ['games'],
#  ['features'],
#  ['human', 'interface'],
#  ['inbuilt', 'applications'],
#  ['Software'],
#  ['body'],
#  ['i5'],
#  ['antivirus', 'software'],
#  ['firewall'],
#  ['price'],
#  ['Apple', 'team'],
#  ['Vista'],
#  ['Vista'],
#  ['operating', 'system'],
#  ['Vista'],
#  ['video', 'chat'],
#  ['quality'],
#  ['mouse'],
#  ['Fan'],
#  ['cooling', 'pad'],
#  ['feature'],
#  ['software'],
#  ['installation', 'time'],
#  ['power'],
#  ['storage'],
#  ['abilitiy'],
#  ['spotlight', 'search'],
#  ['feature'],
#  ['wireless', 'system'],
#  ['Windows', '7'],
#  ['quality'],
#  ['battery', 'life'],
#  ['speed'],
#  ['OS'],
#  ['OS'],
#  ['iTunes'],
#  ['program'],
#  ['gaming'],
#  ['battery'],
#  ['Apple', 'support'],
#  ['techs'],
#  ['adding', 'the', 'bluetooth'],
#  ['graphic', 'power'],
#  ['Adobe', 'Creative', 'apps'],
#  ['programs'],
#  ['use'],
#  ['materials'],
#  ['software'],
#  ['Tech', 'support'],
#  ['power', 'supply'],
#  ['POWER', 'SUPPLY'],
#  ['size'],
#  ['warranty'],
#  ['Windows', 'XP', 'SP2'],
#  ['Windows', '7', 'Ultimate'],
#  ['Bluetooth'],
#  ['Fingerprint', 'reader'],
#  ['software'],
#  ['techs', 'at', 'HP'],
#  ['video', 'card'],
#  ['graphics'],
#  ['security'],
#  ['audio'],
#  ['keyboard'],
#  ['runs'],
#  ['set', 'up'],
#  ['screen'],
#  ['word', 'processing'],
#  ['internet'],
#  ['trackpad'],
#  ['battery', 'life'],
#  ['spec'],
#  ['HD'],
#  ['graphics', 'chip'],
#  ['components'],
#  ['DVD', 'burner'],
#  ['USB', 'ports'],
#  ['software'],
#  ['system'],
#  ['ran'],
#  ['price'],
#  ['operation'],
#  ['brand'],
#  ['components'],
#  ['ground', 'loop', 'isolator'],
#  ['price', 'range'],
#  ['quality'],
#  ['warranty'],
#  ['leading', 'edge'],
#  ['bloatware'],
#  ['Maximum', 'sound'],
#  ['windows', '7'],
#  ['Bootcamp'],
#  ['price'],
#  ['action', 'pack', 'games'],
#  ['works'],
#  ['price'],
#  ['performance'],
#  ['twin', 'packing'],
#  ['functions'],
#  ['after', 'sales', 'support'],
#  ['look'],
#  ['display', 'screen'],
#  ['acer', 'arcade'],
#  ['customer', 'support'],
#  ['screen'],
#  ['cd', 'drive'],
#  ['runs'],
#  ['design'],
#  ['size'],
#  ['games'],
#  ['games'],
#  ['life'],
#  ['warranty'],
#  ['pad'],
#  ['value'],
#  ['price'],
#  ['system', 'performance'],
#  ['linux', 'based', 'os'],
#  ['use'],
#  ['batteries'],
#  ['shipping', 'carton'],
#  ['use'],
#  ['program'],
#  ['virus', 'protection'],
#  ['screen'],
#  ['processor'],
#  ['OSX', '16'],
#  ['graphics'],
#  ['hardware'],
#  ['software'],
#  ['Intel', 'Core', 'processors'],
#  ['HDMI', 'port'],
#  ['Internet', 'Explorer'],
#  ['staff'],
#  ['price', 'premium'],
#  ['features'],
#  ['product', 'and', 'help', 'aftermarket'],
#  ['Microsoft', 'word'],
#  ['usb', 'ports'],
#  ['sd', 'memory', 'card', 'reader'],
#  ['sd', 'memory', 'car', 'expansion'],
#  ['LaCie', '2Big', 'external', 'drive'],
#  ['firewire', '800', 'interface'],
#  ['Time', 'Machine'],
#  ['sound'],
#  ['extra', 'features'],
#  ['windows', '7', 'home', 'premium'],
#  ['Acer', 'screen'],
#  ['USB', 'port'],
#  ['boot'],
#  ['battery', 'life'],
#  ['fires', 'up'],
#  ['keyboard'],
#  ['software'],
#  ['online', 'tutorial', 'videos'],
#  ['image'],
#  ['soud'],
#  ['windows'],
#  ['boot', 'up'],
#  ['shut', 'down'],
#  ['windows'],
#  ['Mac', 'OS'],
#  ['use'],
#  ['cost'],
#  ['Windows', '7', 'Starter'],
#  ['Windows', '7', 'Home', 'Premium'],
#  ['Windows', '7', 'Professional'],
#  ['specifications'],
#  ['power', 'cords'],
#  ['multi-touch', 'features'],
#  ['screen'],
#  ['clicking', 'buttons'],
#  ['battery', 'life'],
#  ['Windows'],
#  ['wired', 'lan'],
#  ['hard', 'reboot'],
#  ['hardware'],
#  ['hard', 'drive'],
#  ['battery', 'life'],
#  ['Apple', 'care'],
#  ['font'],
#  ['Features'],
#  ['programs'],
#  ['run'],
#  [u'plastic\xa0pieces'],
#  ['2GB', 'RAM', 'stick'],
#  ['Windows'],
#  ['Microsoft', 'Word', 'for', 'Mac'],
#  ['WARRANTY', 'COMPANY'],
#  ['cusromer', 'service', 'center'],
#  ['size'],
#  ['weight'],
#  ['battery'],
#  ['aluminum', 'body'],
#  ['watching', 'movies'],
#  ['playing'],
#  ['build', 'quality'],
#  ['performance'],
#  ['dock'],
#  ['program'],
#  ['program'],
#  ['working'],
#  ['costing'],
#  ['price'],
#  ['i7'],
#  ['monitor'],
#  ['extended', 'warranty'],
#  ['Boots', 'up'],
#  ['runs'],
#  ['screen'],
#  ['driver'],
#  ['tech', 'support'],
#  ['work'],
#  ['hard', 'drive'],
#  ['twin', 'packing'],
#  ['functions'],
#  ['warranty'],
#  ['performance'],
#  ['price'],
#  ['BIOS'],
#  ['design'],
#  ['tech', 'issues'],
#  ['size'],
#  ['space'],
#  ['service'],
#  ['memory'],
#  ['speed'],
#  ['priced'],
#  ['internet', 'speed'],
#  ['programs'],
#  ['Garageband'],
#  ['Photo', 'Booth'],
#  ['iPhoto'],
#  ['iMovie'],
#  ['video-editing'],
#  ['movie-making'],
#  ['photo', 'management'],
#  ['music'],
#  ['Pages'],
#  ['Numbers'],
#  ['Keynote'],
#  ['school', 'or', 'office', 'use'],
#  ['screen'],
#  ['colors'],
#  ['value'],
#  ['price'],
#  ['value'],
#  ['web', 'cam'],
#  ['burn', "cd's"],
#  ['17', 'inch', 'screen'],
#  ['support'],
#  ['Bluetooth'],
#  ['Drivers/Applications', 'DVD'],
#  ['Launch', 'Manager'],
#  ['glass', 'screen'],
#  ['switchable', 'graphic', 'card'],
#  ['gaming'],
#  ['service'],
#  ['battery', 'life'],
#  ['technical', 'support'],
#  ['BOOT', 'MGR'],
#  ['recovery', 'cd'],
#  ['price'],
#  ['features'],
#  ['Skype'],
#  ['mouse', 'buttons'],
#  ['HDD'],
#  ['rails'],
#  ['hard', 'drive'],
#  ['quality'],
#  ['staff'],
#  ['Games'],
#  ['GarageBand'],
#  ['warranty'],
#  ['hard', 'drive'],
#  ['price'],
#  ['home', 'use'],
#  ['business', 'use'],
#  ['virus', 'protection'],
#  ['updates'],
#  ['MS', 'Office', 'apps'],
#  ['feature'],
#  ['Windows'],
#  ['games'],
#  ['battery', 'life'],
#  ['battery', 'life'],
#  ['price'],
#  ['Nortons', 'virus', 'scan'],
#  ['frame'],
#  ['features'],
#  ['use'],
#  ['loaded'],
#  ['Windows', '7'],
#  ['Vista'],
#  ['Vista'],
#  ['windows'],
#  ['Windows', 'XP'],
#  ['Vista'],
#  ['key', 'broad'],
#  ['warranty'],
#  ['repair', '"depot"'],
#  ['school', 'use'],
#  ['design'],
#  ['battery', 'life'],
#  ['programs'],
#  ['Wireless'],
#  ['battery', 'life'],
#  ['programs'],
#  ['trackpad'],
#  ['programs'],
#  ['navigating'],
#  ['speakers'],
#  ['subwoofer'],
#  ['built', 'in', 'camera'],
#  ['price'],
#  ['warranty'],
#  ['left', 'mouse', 'key'],
#  ['costed'],
#  ['speed'],
#  ['hard', 'drive', 'space'],
#  ['picture'],
#  ['extended', 'warranty'],
#  ['extended', 'warranties'],
#  ['battery'],
#  ['Screen'],
#  ['battery', 'life'],
#  ['appearance'],
#  ['technical', 'service', 'for', 'dell'],
#  ['graphics'],
#  ['warranty'],
#  ['battery'],
#  ['case'],
#  ['performance'],
#  ['price'],
#  ['look'],
#  ['applications'],
#  ['speed'],
#  ['tech', 'support'],
#  ['gaming'],
#  ['use'],
#  ['Photoshop'],
#  ['ram'],
#  ['system', 'clock'],
#  ['RAM'],
#  ['securitysoftware'],
#  ['driver', 'updates'],
#  ['Windows'],
#  ['work'],
#  ['works'],
#  ['HD'],
#  ['HD'],
#  ['graphics', 'card'],
#  ['built', 'in', 'camera'],
#  ['DVD', 'burner'],
#  ['DVD', 'burner'],
#  ['works'],
#  ['15', 'inch'],
#  ['Product', 'support'],
#  ['screen'],
#  ['use'],
#  ['casing', 'of', 'the', 'power', 'cord'],
#  ['internet', 'signals'],
#  ['price'],
#  ['right', 'speaker'],
#  ['price', 'tag'],
#  ['software'],
#  ['updates'],
#  ['multiple', 'page', 'viewer'],
#  ['shipped'],
#  ['Keyboard'],
#  ['use'],
#  ['warranty'],
#  ['quality'],
#  ['features'],
#  ['recovery', 'disk'],
#  ['features'],
#  ['programs'],
#  ['Office'],
#  ['Office', 'programs'],
#  ['wifi'],
#  ['TYPING'],
#  ['screen'],
#  ['temp'],
#  ['Windows', 'operating', 'system'],
#  ['OS'],
#  ['processor', 'speed'],
#  ['thunderbolt', 'port'],
#  ['lcd', 'screen'],
#  ['Images'],
#  ['windows', 'vista'],
#  ['windows', 'xp'],
#  ['Vista'],
#  ['Adobe', 'Flash', 'player'],
#  ['Internet', 'Explore'],
#  ['Windows', 'update'],
#  ['update'],
#  ['switch'],
#  ['switch'],
#  ['4GB', 'stick', 'of', 'RAM'],
#  ['hardrive'],
#  ['touch', 'control', 'buttons'],
#  ['keyboard'],
#  ['performance'],
#  ['iLife', 'software'],
#  ['iPhoto'],
#  ['iMovie'],
#  ['iWeb'],
#  ['iTunes'],
#  ['GarageBand'],
#  ['runs'],
#  ['system', 'board'],
#  ['size'],
#  ['software'],
#  ['hardware'],
#  ['memory'],
#  ['hard', 'drive'],
#  ['graphics'],
#  ['programs'],
#  ['navigation'],
#  ['hinge'],
#  ['LCD'],
#  ['DELL', 'Customer', 'Service'],
#  ['RMA', 'service'],
#  ['Design'],
#  ['keyboard'],
#  ['battery', 'life'],
#  ['screen/video', 'resolution'],
#  ['resolution'],
#  ['applications'],
#  ['Dreamweaver'],
#  ['Final', 'Cut', 'Pro', '7'],
#  ['Photoshop'],
#  ['Safari'],
#  ['Firefox'],
#  ['MSN', 'Messenger'],
#  ['warrenty'],
#  ['tech', 'support'],
#  ['Apple', 'applications'],
#  ['iPhoto'],
#  ['gigs'],
#  ['memory'],
#  ['17-inch', 'screen'],
#  ['DVD'],
#  ['CD', 'burners'],
#  ['web', 'browsing'],
#  ['uploading', 'photos'],
#  ['watching', 'movies'],
#  ['creating', 'presentations'],
#  ['Quality', 'Display'],
#  ['weight'],
#  ['12', 'cell', 'battery'],
#  ['case'],
#  ['power', 'adapter', 'plug'],
#  ['features'],
#  ['speakers'],
#  ['screen'],
#  ['TAB'],
#  ['extended', 'warrenty'],
#  ['TFT', 'panel'],
#  ['Navigation'],
#  ['Windows', 'operating', 'systems'],
#  ['screen'],
#  ['screen', 'size'],
#  ['bulk'],
#  ['music', 'software'],
#  ['software'],
#  ['picture'],
#  ['video'],
#  ['combined', 'touch', 'pad', 'and', 'clicker'],
#  ['Unibody', 'construction'],
#  ['value'],
#  ['Windows'],
#  ['screen', 'hinges'],
#  ['BATTERY'],
#  ['STORAGE', 'LIFE'],
#  ['SERVICE'],
#  ['storage'],
#  ['ram'],
#  ['Nvidia', 'chipset'],
#  ['extended', 'warranty'],
#  ['Programs'],
#  ['CHARGE', 'TIME'],
#  ['size'],
#  ['consistancy'],
#  ['key', 'bindings'],
#  ['Keyboard'],
#  ['size'],
#  ['10-key'],
#  ['Fan'],
#  ['fan'],
#  ['screen'],
#  ['operating', 'system'],
#  ['processor'],
#  ['500gb', 'hard', 'drive'],
#  ['feature'],
#  ['tech', 'support'],
#  ['USB', 'output'],
#  ['wireless', 'mouse'],
#  ['size'],
#  ['screen'],
#  ['Windows'],
#  ['Linux'],
#  ['windows', 'disc'],
#  ['quality'],
#  ['touchpad'],
#  ['video', 'card'],
#  ['touch', 'pad'],
#  ['external', 'mouse'],
#  ['set', 'up'],
#  ['video'],
#  ['value'],
#  ['hard', 'drive'],
#  ['runs'],
#  ['loads'],
#  ['warranty'],
#  ['program'],
#  ['disk', 'throughput'],
#  ['spinning', 'beachball'],
#  ['wireless', 'internet', 'access'],
#  ['value'],
#  ['ran'],
#  ['battery'],
#  ['company'],
#  ['screen', 'resolutions'],
#  ['carry'],
#  ['keyboard'],
#  ['edges'],
#  ['programs'],
#  ['ILife'],
#  ['iPhotos'],
#  ['processor'],
#  ['fan'],
#  ['motherboard'],
#  ['built'],
#  ['performance'],
#  ['screen', 'resolution'],
#  ['Snow', 'Leopard'],
#  ['CPU'],
#  ['Office', 'Mac', 'applications'],
#  ['Word'],
#  ['Excel'],
#  ['spinning', 'wheel'],
#  ['pad'],
#  ['keyboard'],
#  ['screen'],
#  ['Windows', '7'],
#  ['programs'],
#  ['iLife'],
#  ['iWork'],
#  ['18.4"', 'screen'],
#  ['battery', 'life'],
#  ['regular', 'layout', 'keyboard'],
#  ['Runs'],
#  ['programs'],
#  ['windows'],
#  ['recovery', 'discs'],
#  ['Windows', '7', 'Starter'],
#  ['Support'],
#  ['warranty'],
#  ['online', 'chat', 'service'],
#  ['iPhoto'],
#  ['works'],
#  ['battery'],
#  ['quality'],
#  ['VHS'],
#  ['use'],
#  ['navigate'],
#  ['battery', 'life'],
#  ['battery'],
#  ['USB', 'ports'],
#  ['battery'],
#  ['design'],
#  ['quality'],
#  ['Mac', 'version', 'of', 'Microsoft', 'Office'],
#  ['starting-up', 'time'],
#  ['operates'],
#  ['touch', 'pad'],
#  ['touch', 'pad'],
#  ['pictures'],
#  ['transporting'],
#  ['gaming'],
#  ['network', 'capability'],
#  ['wifi', 'card'],
#  ['printer'],
#  ['use'],
#  ['OS', 'X'],
#  ['repair', 'service'],
#  ['customer', 'service', 'agents'],
#  ['Photoshop'],
#  ['AfterEffects', 'programs'],
#  ['runs'],
#  ['warrenty'],
#  ['look'],
#  ['dependability'],
#  ['company'],
#  ['warranty'],
#  ['features'],
#  ['mouse', 'button'],
#  ['performance'],
#  ['touchpad'],
#  ['buttons'],
#  ['programs'],
#  ['space'],
#  ['keyboard'],
#  ['battery'],
#  ['keyboard'],
#  ['battery', 'life'],
#  ['hard', 'drive'],
#  ['windows', '7'],
#  ['processor'],
#  ['applications'],
#  ['load'],
#  ['webpages'],
#  ['battery'],
#  ['boot'],
#  ['Windows'],
#  ['runs'],
#  ['OpenOffice'],
#  ['Firefox'],
#  ['price'],
#  ['quality'],
#  ['performance'],
#  ['battery', 'life'],
#  ['use'],
#  ['PRODUCT', 'KEY'],
#  ['specs'],
#  ['bluetooth'],
#  ['feature'],
#  ['one', 'touch', 'keys'],
#  ['battery', 'life'],
#  ['keyboard'],
#  ['speed'],
#  ['specs'],
#  ['price'],
#  ['Delivery'],
#  ['stability'],
#  ['Mac', 'software'],
#  ['operating', 'system'],
#  ['SATA', 'controller'],
#  ['video', 'editing'],
#  ['performance'],
#  ['mobile', 'video', 'editing'],
#  ['imovie', 'program'],
#  ['processor'],
#  ['ram'],
#  ['battery'],
#  ['price'],
#  ['designed'],
#  ['warranty'],
#  ['bluetooth', 'mouse'],
#  ['features'],
#  ['Keyboard'],
#  ['control', 'buttons'],
#  ['Screen'],
#  ['motherboard'],
#  ['motherboard'],
#  ['Processor'],
#  ['performance'],
#  ['motherboard'],
#  ['patches'],
#  ['speed'],
#  ['system', 'memory'],
#  ['radeon', '5850'],
#  ['DDR5'],
#  ['DDR3'],
#  ['programs'],
#  ['programs'],
#  ['speed'],
#  ['size'],
#  ['OS', '(Vista)'],
#  ['software'],
#  ['battery', 'life'],
#  ['battery', 'life'],
#  ['extended', 'warranty'],
#  ['features'],
#  ['programs'],
#  ['use'],
#  ['pop', 'up', 'windows'],
#  ['web', 'programming', 'software'],
#  ['pop', 'ups'],
#  ['Memory'],
#  ['3G', 'network'],
#  ['Web', 'access'],
#  ['screen'],
#  ['design', 'based', 'programs'],
#  ['Adobe', 'Creative', 'Suite'],
#  ['companies'],
#  ['customer', 'service'],
#  ['plug'],
#  ['HDD', 'cover'],
#  ['applications'],
#  ...]

# %%
import pandas as pd
df4=pd.read_csv("/home/vibha/parser.csv")

# %%
import xml.etree.ElementTree as ET
ak=[]
k=[]
c=0
path="/home/vibha/Laptops_Train.xml"
tree=ET.parse(path)
root = tree.getroot()
l=len(df4)
for i in range(0,l):
    s=df4.at[i,'VIBHA']
    x = s.replace('(',' ').replace(',',' ').replace('-',' ').replace(')',' ').split()
    print(x)
    if(x[0]!='ayushi'):
        #print x
        k.append(x)
        
    else:
        print(k)
        ak.append(k)
        k=[]
    
    
    #     if x[0]!="ayushi":
#         k.append(x)
#     ak.append(k)
# Out:
# ['nsubj', 'charge', '2', 'I', '1']
# ['root', 'ROOT', '0', 'charge', '2']
# ['dobj', 'charge', '2', 'it', '3']
# ['case', 'night', '5', 'at', '4']
# ['nmod', 'charge', '2', 'night', '5']
# ['cc', 'charge', '2', 'and', '6']
# ['conj', 'charge', '2', 'skip', '7']
# ['xcomp', 'skip', '7', 'taking', '8']
# ['det', 'cord', '10', 'the', '9']
# ['dobj', 'taking', '8', 'cord', '10']
# ['case', 'me', '12', 'with', '11']
# ['nmod', 'taking', '8', 'me', '12']
# ['case', 'life', '18', 'because', '13']
# ['mwe', 'because', '13', 'of', '14']
# ['det', 'life', '18', 'the', '15']
# ['amod', 'life', '18', 'good', '16']
# ['compound', 'life', '18', 'battery', '17']
# ['nmod', 'me', '12', 'life', '18']
# ['ayushi']
# [['nsubj', 'charge', '2', 'I', '1'], ['root', 'ROOT', '0', 'charge', '2'], ['dobj', 'charge', '2', 'it', '3'], ['case', 'night', '5', 'at', '4'], ['nmod', 'charge', '2', 'night', '5'], ['cc', 'charge', '2', 'and', '6'], ['conj', 'charge', '2', 'skip', '7'], ['xcomp', 'skip', '7', 'taking', '8'], ['det', 'cord', '10', 'the', '9'], ['dobj', 'taking', '8', 'cord', '10'], ['case', 'me', '12', 'with', '11'], ['nmod', 'taking', '8', 'me', '12'], ['case', 'life', '18', 'because', '13'], ['mwe', 'because', '13', 'of', '14'], ['det', 'life', '18', 'the', '15'], ['amod', 'life', '18', 'good', '16'], ['compound', 'life', '18', 'battery', '17'], ['nmod', 'me', '12', 'life', '18']]
# ['nsubj', 'bought', '3', 'I', '2']
# ['root', 'ROOT', '0', 'bought', '3']
# ['det', 'laptop', '8', 'a', '4']
# ['compound', 'laptop', '8', 'HP', '5']
# ['compound', 'laptop', '8', 'Pavilion', '6']
# ['compound', 'laptop', '8', 'DV4', '1222nr', '7']
# ['dobj', 'bought', '3', 'laptop', '8']
# ['cc', 'bought', '3', 'and', '9']
# ['aux', 'had', '11', 'have', '10']
# ['conj', 'bought', '3', 'had', '11']
# ['advmod', 'many', '13', 'so', '12']
# ['amod', 'problems', '14', 'many', '13']
# ['dobj', 'had', '11', 'problems', '14']
# ['case', 'computer', '17', 'with', '15']
# ['det', 'computer', '17', 'the', '16']
# ['nmod', 'problems', '14', 'computer', '17']
# ['ayushi']
# [['nsubj', 'bought', '3', 'I', '2'], ['root', 'ROOT', '0', 'bought', '3'], ['det', 'laptop', '8', 'a', '4'], ['compound', 'laptop', '8', 'HP', '5'], ['compound', 'laptop', '8', 'Pavilion', '6'], ['compound', 'laptop', '8', 'DV4', '1222nr', '7'], ['dobj', 'bought', '3', 'laptop', '8'], ['cc', 'bought', '3', 'and', '9'], ['aux', 'had', '11', 'have', '10'], ['conj', 'bought', '3', 'had', '11'], ['advmod', 'many', '13', 'so', '12'], ['amod', 'problems', '14', 'many', '13'], ['dobj', 'had', '11', 'problems', '14'], ['case', 'computer', '17', 'with', '15'], ['det', 'computer', '17', 'the', '16'], ['nmod', 'problems', '14', 'computer', '17']]

# %%
ak[0]
# Out:
# [['nsubj', 'charge', '2', 'I', '1'],
#  ['root', 'ROOT', '0', 'charge', '2'],
#  ['dobj', 'charge', '2', 'it', '3'],
#  ['case', 'night', '5', 'at', '4'],
#  ['nmod', 'charge', '2', 'night', '5'],
#  ['cc', 'charge', '2', 'and', '6'],
#  ['conj', 'charge', '2', 'skip', '7'],
#  ['xcomp', 'skip', '7', 'taking', '8'],
#  ['det', 'cord', '10', 'the', '9'],
#  ['dobj', 'taking', '8', 'cord', '10'],
#  ['case', 'me', '12', 'with', '11'],
#  ['nmod', 'taking', '8', 'me', '12'],
#  ['case', 'life', '18', 'because', '13'],
#  ['mwe', 'because', '13', 'of', '14'],
#  ['det', 'life', '18', 'the', '15'],
#  ['amod', 'life', '18', 'good', '16'],
#  ['compound', 'life', '18', 'battery', '17'],
#  ['nmod', 'me', '12', 'life', '18']]

# %%
df_final=pd.DataFrame(columns=['f','m','o'])

# %%
c=1
for i in ak:
    print i
# Out:
# [['nsubj', 'charge', '2', 'I', '1'], ['root', 'ROOT', '0', 'charge', '2'], ['dobj', 'charge', '2', 'it', '3'], ['case', 'night', '5', 'at', '4'], ['nmod', 'charge', '2', 'night', '5'], ['cc', 'charge', '2', 'and', '6'], ['conj', 'charge', '2', 'skip', '7'], ['xcomp', 'skip', '7', 'taking', '8'], ['det', 'cord', '10', 'the', '9'], ['dobj', 'taking', '8', 'cord', '10'], ['case', 'me', '12', 'with', '11'], ['nmod', 'taking', '8', 'me', '12'], ['case', 'life', '18', 'because', '13'], ['mwe', 'because', '13', 'of', '14'], ['det', 'life', '18', 'the', '15'], ['amod', 'life', '18', 'good', '16'], ['compound', 'life', '18', 'battery', '17'], ['nmod', 'me', '12', 'life', '18']]
# [['nsubj', 'bought', '3', 'I', '2'], ['root', 'ROOT', '0', 'bought', '3'], ['det', 'laptop', '8', 'a', '4'], ['compound', 'laptop', '8', 'HP', '5'], ['compound', 'laptop', '8', 'Pavilion', '6'], ['compound', 'laptop', '8', 'DV4', '1222nr', '7'], ['dobj', 'bought', '3', 'laptop', '8'], ['cc', 'bought', '3', 'and', '9'], ['aux', 'had', '11', 'have', '10'], ['conj', 'bought', '3', 'had', '11'], ['advmod', 'many', '13', 'so', '12'], ['amod', 'problems', '14', 'many', '13'], ['dobj', 'had', '11', 'problems', '14'], ['case', 'computer', '17', 'with', '15'], ['det', 'computer', '17', 'the', '16'], ['nmod', 'problems', '14', 'computer', '17']]

# %%
d=0
s=0
# for review in root.findall('./sentence/aspectTerms'):
#                 #print(c)
#                 text_string=""
#                 opinion_inner_list=[]
#                 #or sent in review.findall('./sentences/sentence'):
#                 #print(sent)
#                 #ids=review.attrib['aspec]
#                 #print(ids)
#                 #id_list.append(ids)
#                 for i in review.findall('aspectTerm'):
#                     #print(i)
#                     am=i.attrib['term']
#                     am=am.split(" ")
#                     print(am)
#                     for i in am:
#                         new_list.append(i)

from nltk import pos_tag,word_tokenize
for i in ak:
        #rint(i)
        t2=new_list[s]
        t2_pos=pos_tag(word_tokenize(t2))
        sen=t2.split(" ")
        for j in i:
            #print(j[0])
            for k in as_final:
            #print(k)
            #print("ak")
                for c in k:
                    if c in sen:
                        position=sen.index(c)
                    if t2_pos[position-2][1]=="JJ":
                        df_final.at[d,'o']=t2_pos[position-2][0]
                        
                    elif t2_pos[position-1][1]=="JJ":
                        df_final.at[d,'o']=t2_pos[position-1][0]
                    elif t2_pos[position+1][1]=="JJ":
                        df_final.at[d,'o']=t2_pos[position+1][0]
                    elif t2_pos[position-2][1]=="JJ":
                        df_final.at[d,'o']=t2_pos[position+2][0]
                    df_final.at[d,'f']=c
                    d=d+1
       
            
#             if((j[0]=='advmod') or (j[0]=='neg')):
#                 df_final.at[d,'m']=j[3]
        
        #print(t2)
#         for o in t2:
#             #print(o)
#             if(o[1]=='JJ'):
#                 #print(o[1])
#                 df_final.at[d,'o']=o[0]
        
                            
                            
        s=s+1

# %%
df_final

# %%
sen='I charge it at night and skip taking the cord with me because of the good battery life'

from nltk import word_tokenize

aspect_term=['battery']

sen=sen.split(" ")
l=[]
for i in ak[0]:
    if i[1] in aspect_term or i[3] in aspect_term:
        print(i[1])
        print(i[3])
#         print(i[0]+" "+sen[i[2]-1]+" "+sen[i[1]-1])
#         df2['feature']=sen[i[2]-1]+" "+sen[i[1]-1]
# Out:
# life
# battery

# %%
ak[0]
# Out:
# [['nsubj', 'charge', '2', 'I', '1'],
#  ['root', 'ROOT', '0', 'charge', '2'],
#  ['dobj', 'charge', '2', 'it', '3'],
#  ['case', 'night', '5', 'at', '4'],
#  ['nmod', 'charge', '2', 'night', '5'],
#  ['cc', 'charge', '2', 'and', '6'],
#  ['conj', 'charge', '2', 'skip', '7'],
#  ['xcomp', 'skip', '7', 'taking', '8'],
#  ['det', 'cord', '10', 'the', '9'],
#  ['dobj', 'taking', '8', 'cord', '10'],
#  ['case', 'me', '12', 'with', '11'],
#  ['nmod', 'taking', '8', 'me', '12'],
#  ['case', 'life', '18', 'because', '13'],
#  ['mwe', 'because', '13', 'of', '14'],
#  ['det', 'life', '18', 'the', '15'],
#  ['amod', 'life', '18', 'good', '16'],
#  ['compound', 'life', '18', 'battery', '17'],
#  ['nmod', 'me', '12', 'life', '18']]

# %%
df2=df2.add([1,0,0])

# %%
df2
# Out:
# Empty DataFrame
# Columns: [feature, modifier, opinion]
# Index: []

# %%
import xml.etree.ElementTree as ET
import nltk

def get_list(path):
    tree=ET.parse(path)
    root = tree.getroot()
    text_list = []
    id_list=[]
    new_list=[]
    sentences_list=[]
    opinion_list = []
    for review in root.findall('sentence'):
        print(review)
        text_string=""
        opinion_inner_list=[]
        #or sent in review.findall('./sentences/sentence'):
        #print(sent)
        ids=review.attrib['id']
        print(ids)
        id_list.append(ids)
        text_string= text_string+ " "+ review.find('text').text
        new_list.append(ids)
        sentences_list.append(review.find('text').text)
#             new_list.append(sent.find('text').text)
        
#         text_list.append(text_string)
#         for opinion in review.findall('./Opinions/Opinion'):
#             opinion_dict = {
#                 opinion.get('category').replace('#','_'): opinion.get('polarity')
#             }
#             opinion_inner_list.append(opinion_dict)
#         opinion_list.append(opinion_inner_list)
    return text_list,opinion_list,new_list,sentences_list
train_text_list,train_opinion_list,new_list,sentences_list = get_list("/home/vibha/Laptops_Train.xml")
# Out:
# <Element 'sentence' at 0x7f0bfeca7d90>
# 2339
# <Element 'sentence' at 0x7f0bfeca7ed0>
# 812
# <Element 'sentence' at 0x7f0bfeca7f50>
# 1316
# <Element 'sentence' at 0x7f0bfecaf110>
# 2328
# <Element 'sentence' at 0x7f0bfecaf190>
# 2193
# <Element 'sentence' at 0x7f0bfecaf210>
# 2005
# <Element 'sentence' at 0x7f0bfecaf3d0>
# 2789
# <Element 'sentence' at 0x7f0bfecaf4d0>
# 425
# <Element 'sentence' at 0x7f0bfecaf550>
# 76
# <Element 'sentence' at 0x7f0bfec9b0d0>
# 747
# <Element 'sentence' at 0x7f0bfecaf6d0>
# 80
# <Element 'sentence' at 0x7f0bfecaf7d0>
# 796
# <Element 'sentence' at 0x7f0bfecaf850>
# 917
# <Element 'sentence' at 0x7f0bfecaf9d0>
# 1788
# <Element 'sentence' at 0x7f0bfecafa90>
# 338
# <Element 'sentence' at 0x7f0bfecafc10>
# 1630
# <Element 'sentence' at 0x7f0bfecafd10>
# 38
# <Element 'sentence' at 0x7f0bfecafe50>
# 337
# <Element 'sentence' at 0x7f0bfec41090>
# 1505
# <Element 'sentence' at 0x7f0bfec41110>
# 263
# <Element 'sentence' at 0x7f0bfec41190>
# 1227
# <Element 'sentence' at 0x7f0bfec41210>
# 1019
# <Element 'sentence' at 0x7f0bfec41290>
# 1158
# <Element 'sentence' at 0x7f0bfec41310>
# 1168
# <Element 'sentence' at 0x7f0bfec41390>
# 2568
# <Element 'sentence' at 0x7f0bfec41490>
# 295
# <Element 'sentence' at 0x7f0bfec41590>
# 951
# <Element 'sentence' at 0x7f0bfec41610>
# 2759
# <Element 'sentence' at 0x7f0bfec41710>
# 2055
# <Element 'sentence' at 0x7f0bfec41790>
# 2980
# <Element 'sentence' at 0x7f0bfec41890>
# 2454
# <Element 'sentence' at 0x7f0bfec41910>
# 1054
# <Element 'sentence' at 0x7f0bfec41a10>
# 743
# <Element 'sentence' at 0x7f0bfec41b50>
# 1155
# <Element 'sentence' at 0x7f0bfec41c10>
# 2587
# <Element 'sentence' at 0x7f0bfec41d10>
# 2202
# <Element 'sentence' at 0x7f0bfec41e10>
# 2799
# <Element 'sentence' at 0x7f0bfec41e90>
# 2227
# <Element 'sentence' at 0x7f0bfec41fd0>
# 2241
# <Element 'sentence' at 0x7f0bfec4c0d0>
# 92
# <Element 'sentence' at 0x7f0bfec4c1d0>
# 1204
# <Element 'sentence' at 0x7f0bfec4c2d0>
# 2026
# <Element 'sentence' at 0x7f0bfec4c350>
# 535
# <Element 'sentence' at 0x7f0bfec4c3d0>
# 478
# <Element 'sentence' at 0x7f0bfec4c450>
# 1690
# <Element 'sentence' at 0x7f0bfec4c4d0>
# 1789
# <Element 'sentence' at 0x7f0bfec4c550>
# 250
# <Element 'sentence' at 0x7f0bfec4c5d0>
# 325
# <Element 'sentence' at 0x7f0bfec4c6d0>
# 324
# <Element 'sentence' at 0x7f0bfec4c750>
# 1574
# <Element 'sentence' at 0x7f0bfec4c890>
# 1005
# <Element 'sentence' at 0x7f0bfec4c910>
# 989
# <Element 'sentence' at 0x7f0bfec4c990>
# 3073
# <Element 'sentence' at 0x7f0bfec4cad0>
# 1254
# <Element 'sentence' at 0x7f0bfec4cbd0>
# 810
# <Element 'sentence' at 0x7f0bfec4ccd0>
# 1346
# <Element 'sentence' at 0x7f0bfec4cd50>
# 2383
# <Element 'sentence' at 0x7f0bfec4cdd0>
# 130
# <Element 'sentence' at 0x7f0bfec4ced0>
# 1253
# <Element 'sentence' at 0x7f0bfec4cf50>
# 839
# <Element 'sentence' at 0x7f0bfec57090>
# 1473
# <Element 'sentence' at 0x7f0bfec57110>
# 782
# <Element 'sentence' at 0x7f0bfec57190>
# 696
# <Element 'sentence' at 0x7f0bfec57290>
# 2878
# <Element 'sentence' at 0x7f0bfec57310>
# 226
# <Element 'sentence' at 0x7f0bfec57390>
# 1652
# <Element 'sentence' at 0x7f0bfec57410>
# 1030
# <Element 'sentence' at 0x7f0bfec57510>
# 1425
# <Element 'sentence' at 0x7f0bfec57710>
# 2861
# <Element 'sentence' at 0x7f0bfec57790>
# 661
# <Element 'sentence' at 0x7f0bfec57910>
# 997
# <Element 'sentence' at 0x7f0bfec57a90>
# 192
# <Element 'sentence' at 0x7f0bfec57b10>
# 463
# <Element 'sentence' at 0x7f0bfec57c50>
# 2866
# <Element 'sentence' at 0x7f0bfec57cd0>
# 935
# <Element 'sentence' at 0x7f0bfec57d50>
# 1193
# <Element 'sentence' at 0x7f0bfec57e50>
# 2192
# <Element 'sentence' at 0x7f0bfec57ed0>
# 147
# <Element 'sentence' at 0x7f0bfec63050>
# 1433
# <Element 'sentence' at 0x7f0bfec63150>
# 1669
# <Element 'sentence' at 0x7f0bfec63250>
# 2462
# <Element 'sentence' at 0x7f0bfec63350>
# 2719
# <Element 'sentence' at 0x7f0bfec63450>
# 1224
# <Element 'sentence' at 0x7f0bfec63550>
# 588
# <Element 'sentence' at 0x7f0bfec635d0>
# 2492
# <Element 'sentence' at 0x7f0bfec636d0>
# 1541
# <Element 'sentence' at 0x7f0bfec63810>
# 3060
# <Element 'sentence' at 0x7f0bfec63990>
# 915
# <Element 'sentence' at 0x7f0bfec63a90>
# 2050
# <Element 'sentence' at 0x7f0bfec63b90>
# 460
# <Element 'sentence' at 0x7f0bfec63cd0>
# 1954
# <Element 'sentence' at 0x7f0bfec63d50>
# 1728
# <Element 'sentence' at 0x7f0bfec63dd0>
# 620
# <Element 'sentence' at 0x7f0bfec63e50>
# 2423
# <Element 'sentence' at 0x7f0bfec63f10>
# 1781
# <Element 'sentence' at 0x7f0bfec63f90>
# 645
# <Element 'sentence' at 0x7f0bfec6f050>
# 2
# <Element 'sentence' at 0x7f0bfec6f110>
# 1524
# <Element 'sentence' at 0x7f0bfec6f210>
# 2472
# <Element 'sentence' at 0x7f0bfec6f290>
# 803
# <Element 'sentence' at 0x7f0bfec6f390>
# 2225
# <Element 'sentence' at 0x7f0bfec6f490>
# 2644
# <Element 'sentence' at 0x7f0bfec6f690>
# 1365
# <Element 'sentence' at 0x7f0bfec6f790>
# 1555
# <Element 'sentence' at 0x7f0bfec6f810>
# 2199
# <Element 'sentence' at 0x7f0bfec6f890>
# 72
# <Element 'sentence' at 0x7f0bfec6f910>
# 1151
# <Element 'sentence' at 0x7f0bfec6f990>
# 2033
# <Element 'sentence' at 0x7f0bfec6fa90>
# 2113
# <Element 'sentence' at 0x7f0bfec6fb10>
# 2271
# <Element 'sentence' at 0x7f0bfec6fc90>
# 1307
# <Element 'sentence' at 0x7f0bfec6fd10>
# 2186
# <Element 'sentence' at 0x7f0bfec6fd90>
# 103
# <Element 'sentence' at 0x7f0bfec6fed0>
# 1875
# <Element 'sentence' at 0x7f0bfec6ff50>
# 1359
# <Element 'sentence' at 0x7f0bfec6ffd0>
# 2483
# <Element 'sentence' at 0x7f0bfebf9090>
# 2945
# <Element 'sentence' at 0x7f0bfebf9110>
# 197
# <Element 'sentence' at 0x7f0bfebf9190>
# 1149
# <Element 'sentence' at 0x7f0bfebf9290>
# 163
# <Element 'sentence' at 0x7f0bfebf9310>
# 900
# <Element 'sentence' at 0x7f0bfebf9410>
# 1649
# <Element 'sentence' at 0x7f0bfebf9510>
# 2972
# <Element 'sentence' at 0x7f0bfebf9590>
# 446
# <Element 'sentence' at 0x7f0bfebf9690>
# 1912
# <Element 'sentence' at 0x7f0bfebf9810>
# 2752
# <Element 'sentence' at 0x7f0bfebf9950>
# 270
# <Element 'sentence' at 0x7f0bfebf99d0>
# 2646
# <Element 'sentence' at 0x7f0bfebf9a50>
# 886
# <Element 'sentence' at 0x7f0bfebf9ad0>
# 2381
# <Element 'sentence' at 0x7f0bfebf9bd0>
# 404
# <Element 'sentence' at 0x7f0bfebf9cd0>
# 2772
# <Element 'sentence' at 0x7f0bfebf9d50>
# 407
# <Element 'sentence' at 0x7f0bfebf9e50>
# 699
# <Element 'sentence' at 0x7f0bfebf9ed0>
# 1034
# <Element 'sentence' at 0x7f0bfebf9f50>
# 1731
# <Element 'sentence' at 0x7f0bfec05110>
# 1863
# <Element 'sentence' at 0x7f0bfec05190>
# 1186
# <Element 'sentence' at 0x7f0bfec052d0>
# 1029
# <Element 'sentence' at 0x7f0bfec05350>
# 1014
# <Element 'sentence' at 0x7f0bfec053d0>
# 2470
# <Element 'sentence' at 0x7f0bfec05590>
# 331
# <Element 'sentence' at 0x7f0bfec057d0>
# 1073
# <Element 'sentence' at 0x7f0bfec05850>
# 2788
# <Element 'sentence' at 0x7f0bfec058d0>
# 1057
# <Element 'sentence' at 0x7f0bfec05990>
# 1095
# <Element 'sentence' at 0x7f0bfec05ad0>
# 210
# <Element 'sentence' at 0x7f0bfec05b50>
# 1718
# <Element 'sentence' at 0x7f0bfec05c90>
# 2770
# <Element 'sentence' at 0x7f0bfec05d10>
# 642
# <Element 'sentence' at 0x7f0bfec05d90>
# 471
# <Element 'sentence' at 0x7f0bfec05e10>
# 2923
# <Element 'sentence' at 0x7f0bfec05f10>
# 3027
# <Element 'sentence' at 0x7f0bfec11050>
# 654
# <Element 'sentence' at 0x7f0bfec11190>
# 1340
# <Element 'sentence' at 0x7f0bfec11210>
# 2638
# <Element 'sentence' at 0x7f0bfec11290>
# 2099
# <Element 'sentence' at 0x7f0bfec11310>
# 58
# <Element 'sentence' at 0x7f0bfec11390>
# 2716
# <Element 'sentence' at 0x7f0bfec11410>
# 2317
# <Element 'sentence' at 0x7f0bfec11490>
# 1110
# <Element 'sentence' at 0x7f0bfec11590>
# 1488
# <Element 'sentence' at 0x7f0bfec116d0>
# 488
# <Element 'sentence' at 0x7f0bfec117d0>
# 1289
# <Element 'sentence' at 0x7f0bfec11950>
# 2985
# <Element 'sentence' at 0x7f0bfec11a50>
# 2145
# <Element 'sentence' at 0x7f0bfec11ad0>
# 1573
# <Element 'sentence' at 0x7f0bfec11bd0>
# 1928
# <Element 'sentence' at 0x7f0bfec11d10>
# 704
# <Element 'sentence' at 0x7f0bfec11d90>
# 1099
# <Element 'sentence' at 0x7f0bfec11e90>
# 1347
# <Element 'sentence' at 0x7f0bfec11f90>
# 1408
# <Element 'sentence' at 0x7f0bfec1c0d0>
# 1374
# <Element 'sentence' at 0x7f0bfec1c290>
# 34
# <Element 'sentence' at 0x7f0bfec1c310>
# 2864
# <Element 'sentence' at 0x7f0bfec1c450>
# 815
# <Element 'sentence' at 0x7f0bfec1c4d0>
# 2801
# <Element 'sentence' at 0x7f0bfec1c550>
# 1568
# <Element 'sentence' at 0x7f0bfec1c5d0>
# 30
# <Element 'sentence' at 0x7f0bfec1c6d0>
# 362
# <Element 'sentence' at 0x7f0bfec1c750>
# 619
# <Element 'sentence' at 0x7f0bfec1c7d0>
# 708
# <Element 'sentence' at 0x7f0bfec1c850>
# 167
# <Element 'sentence' at 0x7f0bfec1c8d0>
# 474
# <Element 'sentence' at 0x7f0bfec1ca10>
# 1563
# <Element 'sentence' at 0x7f0bfec1ca90>
# 172
# <Element 'sentence' at 0x7f0bfec1cb10>
# 1396
# <Element 'sentence' at 0x7f0bfec1cb90>
# 156
# <Element 'sentence' at 0x7f0bfec1ccd0>
# 2095
# <Element 'sentence' at 0x7f0bfec1cdd0>
# 46
# <Element 'sentence' at 0x7f0bfec1ce50>
# 418
# <Element 'sentence' at 0x7f0bfec1ced0>
# 1722
# <Element 'sentence' at 0x7f0bfec1cf90>
# 2004
# <Element 'sentence' at 0x7f0bfec29190>
# 2296
# <Element 'sentence' at 0x7f0bfec29290>
# 1514
# <Element 'sentence' at 0x7f0bfec29310>
# 2699
# <Element 'sentence' at 0x7f0bfec29390>
# 524
# <Element 'sentence' at 0x7f0bfec29410>
# 155
# <Element 'sentence' at 0x7f0bfec29490>
# 493
# <Element 'sentence' at 0x7f0bfec295d0>
# 902
# <Element 'sentence' at 0x7f0bfec296d0>
# 2433
# <Element 'sentence' at 0x7f0bfec297d0>
# 1675
# <Element 'sentence' at 0x7f0bfec29910>
# 3000
# <Element 'sentence' at 0x7f0bfec29990>
# 954
# <Element 'sentence' at 0x7f0bfec29a10>
# 609
# <Element 'sentence' at 0x7f0bfec29b50>
# 50
# <Element 'sentence' at 0x7f0bfec29bd0>
# 1265
# <Element 'sentence' at 0x7f0bfec29c50>
# 2150
# <Element 'sentence' at 0x7f0bfec29cd0>
# 1777
# <Element 'sentence' at 0x7f0bfec29d50>
# 296
# <Element 'sentence' at 0x7f0bfec29e90>
# 1585
# <Element 'sentence' at 0x7f0bfec29f10>
# 2444
# <Element 'sentence' at 0x7f0bfec29f90>
# 2335
# <Element 'sentence' at 0x7f0bfec330d0>
# 1635
# <Element 'sentence' at 0x7f0bfec33150>
# 1661
# <Element 'sentence' at 0x7f0bfec331d0>
# 2416
# <Element 'sentence' at 0x7f0bfec332d0>
# 1471
# <Element 'sentence' at 0x7f0bfec333d0>
# 1388
# <Element 'sentence' at 0x7f0bfec33450>
# 715
# <Element 'sentence' at 0x7f0bfec33510>
# 1901
# <Element 'sentence' at 0x7f0bfec33590>
# 1427
# <Element 'sentence' at 0x7f0bfec33710>
# 2389
# <Element 'sentence' at 0x7f0bfec337d0>
# 2667
# <Element 'sentence' at 0x7f0bfec33890>
# 1618
# <Element 'sentence' at 0x7f0bfec33910>
# 1460
# <Element 'sentence' at 0x7f0bfec33990>
# 2964
# <Element 'sentence' at 0x7f0bfec33a10>
# 911
# <Element 'sentence' at 0x7f0bfec33b50>
# 2001
# <Element 'sentence' at 0x7f0bfec33d50>
# 2465
# <Element 'sentence' at 0x7f0bfec33ed0>
# 2331
# <Element 'sentence' at 0x7f0bfec33fd0>
# 599
# <Element 'sentence' at 0x7f0bfebbf190>
# 823
# <Element 'sentence' at 0x7f0bfebbf2d0>
# 3006
# <Element 'sentence' at 0x7f0bfebbf410>
# 1861
# <Element 'sentence' at 0x7f0bfebbf490>
# 1301
# <Element 'sentence' at 0x7f0bfebbf510>
# 788
# <Element 'sentence' at 0x7f0bfebbf590>
# 2056
# <Element 'sentence' at 0x7f0bfebbf610>
# 825
# <Element 'sentence' at 0x7f0bfebbf690>
# 1823
# <Element 'sentence' at 0x7f0bfebbf710>
# 2439
# <Element 'sentence' at 0x7f0bfebbf790>
# 2941
# <Element 'sentence' at 0x7f0bfebbf890>
# 2776
# <Element 'sentence' at 0x7f0bfebbf9d0>
# 1686
# <Element 'sentence' at 0x7f0bfebbfad0>
# 2091
# <Element 'sentence' at 0x7f0bfebbfbd0>
# 727
# <Element 'sentence' at 0x7f0bfebbfc50>
# 3001
# <Element 'sentence' at 0x7f0bfebbfd10>
# 1259
# <Element 'sentence' at 0x7f0bfebbfe10>
# 2938
# <Element 'sentence' at 0x7f0bfebbff50>
# 2574
# <Element 'sentence' at 0x7f0bfebcc090>
# 2351
# <Element 'sentence' at 0x7f0bfebcc190>
# 526
# <Element 'sentence' at 0x7f0bfebcc290>
# 2891
# <Element 'sentence' at 0x7f0bfebcc310>
# 2717
# <Element 'sentence' at 0x7f0bfebcc390>
# 3020
# <Element 'sentence' at 0x7f0bfebcc4d0>
# 2541
# <Element 'sentence' at 0x7f0bfebcc610>
# 1069
# <Element 'sentence' at 0x7f0bfebcc810>
# 1553
# <Element 'sentence' at 0x7f0bfebcc990>
# 355
# <Element 'sentence' at 0x7f0bfebcca10>
# 602
# <Element 'sentence' at 0x7f0bfebcca90>
# 2502
# <Element 'sentence' at 0x7f0bfebccb10>
# 2874
# <Element 'sentence' at 0x7f0bfebccc10>
# 2385
# <Element 'sentence' at 0x7f0bfebccd90>
# 198
# <Element 'sentence' at 0x7f0bfebcce10>
# 211
# <Element 'sentence' at 0x7f0bfebcce90>
# 1654
# <Element 'sentence' at 0x7f0bfebccfd0>
# 3058
# <Element 'sentence' at 0x7f0bfebd81d0>
# 1937
# <Element 'sentence' at 0x7f0bfebd8390>
# 104
# <Element 'sentence' at 0x7f0bfebd8490>
# 419
# <Element 'sentence' at 0x7f0bfebd8510>
# 630
# <Element 'sentence' at 0x7f0bfebd8590>
# 694
# <Element 'sentence' at 0x7f0bfebd8610>
# 189
# <Element 'sentence' at 0x7f0bfebd8690>
# 2616
# <Element 'sentence' at 0x7f0bfebd8710>
# 1417
# <Element 'sentence' at 0x7f0bfebd8910>
# 1045
# <Element 'sentence' at 0x7f0bfebd8990>
# 2886
# <Element 'sentence' at 0x7f0bfebd8ad0>
# 2124
# <Element 'sentence' at 0x7f0bfebd8c10>
# 260
# <Element 'sentence' at 0x7f0bfebd8d10>
# 1296
# <Element 'sentence' at 0x7f0bfebd8d90>
# 1172
# <Element 'sentence' at 0x7f0bfebd8e90>
# 2283
# <Element 'sentence' at 0x7f0bfebd8f50>
# 2221
# <Element 'sentence' at 0x7f0bfebe4150>
# 2480
# <Element 'sentence' at 0x7f0bfebe41d0>
# 386
# <Element 'sentence' at 0x7f0bfebe4350>
# 1357
# <Element 'sentence' at 0x7f0bfebe4450>
# 185
# <Element 'sentence' at 0x7f0bfebe44d0>
# 2605
# <Element 'sentence' at 0x7f0bfebe45d0>
# 717
# <Element 'sentence' at 0x7f0bfebe4650>
# 2369
# <Element 'sentence' at 0x7f0bfebe46d0>
# 2579
# <Element 'sentence' at 0x7f0bfebe4750>
# 1742
# <Element 'sentence' at 0x7f0bfebe4890>
# 2578
# <Element 'sentence' at 0x7f0bfebe49d0>
# 33
# <Element 'sentence' at 0x7f0bfebe4a50>
# 942
# <Element 'sentence' at 0x7f0bfebe4b50>
# 2740
# <Element 'sentence' at 0x7f0bfebe4c50>
# 311
# <Element 'sentence' at 0x7f0bfebe4d50>
# 2402
# <Element 'sentence' at 0x7f0bfebe4dd0>
# 13
# <Element 'sentence' at 0x7f0bfebe4f10>
# 1852
# <Element 'sentence' at 0x7f0bfebf0050>
# 2708
# <Element 'sentence' at 0x7f0bfebf0190>
# 1566
# <Element 'sentence' at 0x7f0bfebf02d0>
# 2053
# <Element 'sentence' at 0x7f0bfebf0350>
# 540
# <Element 'sentence' at 0x7f0bfebf0450>
# 878
# <Element 'sentence' at 0x7f0bfebf0550>
# 2639
# <Element 'sentence' at 0x7f0bfebf05d0>
# 2388
# <Element 'sentence' at 0x7f0bfebf06d0>
# 1940
# <Element 'sentence' at 0x7f0bfebf0750>
# 3074
# <Element 'sentence' at 0x7f0bfebf0890>
# 1510
# <Element 'sentence' at 0x7f0bfebf0910>
# 2457
# <Element 'sentence' at 0x7f0bfebf0990>
# 2534
# <Element 'sentence' at 0x7f0bfebf0a90>
# 2185
# <Element 'sentence' at 0x7f0bfebf0c10>
# 2632
# <Element 'sentence' at 0x7f0bfebf0d10>
# 1772
# <Element 'sentence' at 0x7f0bfebf0d90>
# 2675
# <Element 'sentence' at 0x7f0bfebf0ed0>
# 1096
# <Element 'sentence' at 0x7f0bfebf0f90>
# 2371
# <Element 'sentence' at 0x7f0bfebf0fd0>
# 2458
# <Element 'sentence' at 0x7f0bfeb7b090>
# 2650
# <Element 'sentence' at 0x7f0bfeb7b110>
# 392
# <Element 'sentence' at 0x7f0bfeb7b210>
# 1551
# <Element 'sentence' at 0x7f0bfeb7b310>
# 2698
# <Element 'sentence' at 0x7f0bfeb7b410>
# 2427
# <Element 'sentence' at 0x7f0bfeb7b490>
# 1849
# <Element 'sentence' at 0x7f0bfeb7b510>
# 340
# <Element 'sentence' at 0x7f0bfeb7b610>
# 2918
# <Element 'sentence' at 0x7f0bfeb7b750>
# 2939
# <Element 'sentence' at 0x7f0bfeb7b890>
# 1958
# <Element 'sentence' at 0x7f0bfeb7b9d0>
# 358
# <Element 'sentence' at 0x7f0bfeb7bad0>
# 2064
# <Element 'sentence' at 0x7f0bfeb7bb50>
# 1355
# <Element 'sentence' at 0x7f0bfeb7bc50>
# 3021
# <Element 'sentence' at 0x7f0bfeb7bd50>
# 2415
# <Element 'sentence' at 0x7f0bfeb7be50>
# 2730
# <Element 'sentence' at 0x7f0bfeb7bed0>
# 2297
# <Element 'sentence' at 0x7f0bfeb7bf50>
# 2060
# <Element 'sentence' at 0x7f0bfeb7bfd0>
# 2739
# <Element 'sentence' at 0x7f0bfeb88090>
# 2696
# <Element 'sentence' at 0x7f0bfeb88150>
# 1352
# <Element 'sentence' at 0x7f0bfeb88210>
# 1827
# <Element 'sentence' at 0x7f0bfeb88290>
# 2916
# <Element 'sentence' at 0x7f0bfeb883d0>
# 2074
# <Element 'sentence' at 0x7f0bfeb88450>
# 229
# <Element 'sentence' at 0x7f0bfeb884d0>
# 4
# <Element 'sentence' at 0x7f0bfeb88610>
# 2260
# <Element 'sentence' at 0x7f0bfeb88710>
# 199
# <Element 'sentence' at 0x7f0bfeb88790>
# 1376
# <Element 'sentence' at 0x7f0bfeb888d0>
# 936
# <Element 'sentence' at 0x7f0bfeb88a10>
# 1627
# <Element 'sentence' at 0x7f0bfeb88a90>
# 2323
# <Element 'sentence' at 0x7f0bfeb88bd0>
# 1804
# <Element 'sentence' at 0x7f0bfeb88cd0>
# 595
# <Element 'sentence' at 0x7f0bfeb88d50>
# 1426
# <Element 'sentence' at 0x7f0bfeb88e50>
# 2216
# <Element 'sentence' at 0x7f0bfeb88ed0>
# 1590
# <Element 'sentence' at 0x7f0bfeb88f90>
# 1486
# <Element 'sentence' at 0x7f0bfeb94050>
# 138
# <Element 'sentence' at 0x7f0bfeb94150>
# 1192
# <Element 'sentence' at 0x7f0bfeb94290>
# 1439
# <Element 'sentence' at 0x7f0bfeb94310>
# 449
# <Element 'sentence' at 0x7f0bfeb943d0>
# 137
# <Element 'sentence' at 0x7f0bfeb94450>
# 1691
# <Element 'sentence' at 0x7f0bfeb94590>
# 877
# <Element 'sentence' at 0x7f0bfeb94610>
# 537
# <Element 'sentence' at 0x7f0bfeb94710>
# 541
# <Element 'sentence' at 0x7f0bfeb94850>
# 1291
# <Element 'sentence' at 0x7f0bfeb948d0>
# 924
# <Element 'sentence' at 0x7f0bfeb94950>
# 3043
# <Element 'sentence' at 0x7f0bfeb94a50>
# 505
# <Element 'sentence' at 0x7f0bfeb94b90>
# 431
# <Element 'sentence' at 0x7f0bfeb94c10>
# 569
# <Element 'sentence' at 0x7f0bfeb94d50>
# 3081
# <Element 'sentence' at 0x7f0bfeb94e90>
# 308
# <Element 'sentence' at 0x7f0bfeba2050>
# 2796
# <Element 'sentence' at 0x7f0bfeba2150>
# 2333
# <Element 'sentence' at 0x7f0bfeba2250>
# 3049
# <Element 'sentence' at 0x7f0bfeba2410>
# 2660
# <Element 'sentence' at 0x7f0bfeba2510>
# 206
# <Element 'sentence' at 0x7f0bfeba2610>
# 2138
# <Element 'sentence' at 0x7f0bfeba2750>
# 2737
# <Element 'sentence' at 0x7f0bfeba27d0>
# 2392
# <Element 'sentence' at 0x7f0bfeba28d0>
# 10
# <Element 'sentence' at 0x7f0bfeba2950>
# 85
# <Element 'sentence' at 0x7f0bfeba29d0>
# 9
# <Element 'sentence' at 0x7f0bfeba2ad0>
# 1218
# <Element 'sentence' at 0x7f0bfeba2b90>
# 1867
# <Element 'sentence' at 0x7f0bfeba2d50>
# 2377
# <Element 'sentence' at 0x7f0bfeba2e90>
# 2438
# <Element 'sentence' at 0x7f0bfeba2f10>
# 136
# <Element 'sentence' at 0x7f0bfeba2f90>
# 2928
# <Element 'sentence' at 0x7f0bfebad0d0>
# 258
# <Element 'sentence' at 0x7f0bfebad150>
# 2811
# <Element 'sentence' at 0x7f0bfebad2d0>
# 2137
# <Element 'sentence' at 0x7f0bfebad3d0>
# 1256
# <Element 'sentence' at 0x7f0bfebad4d0>
# 1770
# <Element 'sentence' at 0x7f0bfebad650>
# 2270
# <Element 'sentence' at 0x7f0bfebad790>
# 1424
# <Element 'sentence' at 0x7f0bfebad8d0>
# 2843
# <Element 'sentence' at 0x7f0bfebad9d0>
# 1239
# <Element 'sentence' at 0x7f0bfebada90>
# 2471
# <Element 'sentence' at 0x7f0bfebadbd0>
# 1240
# <Element 'sentence' at 0x7f0bfebadc50>
# 2550
# <Element 'sentence' at 0x7f0bfebadd90>
# 455
# <Element 'sentence' at 0x7f0bfebaded0>
# 641
# <Element 'sentence' at 0x7f0bfebadf50>
# 2197
# <Element 'sentence' at 0x7f0bfebadfd0>
# 1462
# <Element 'sentence' at 0x7f0bfeb38090>
# 949
# <Element 'sentence' at 0x7f0bfeb38150>
# 2924
# <Element 'sentence' at 0x7f0bfeb381d0>
# 2496
# <Element 'sentence' at 0x7f0bfeb38310>
# 1089
# <Element 'sentence' at 0x7f0bfeb38410>
# 713
# <Element 'sentence' at 0x7f0bfeb38550>
# 490
# <Element 'sentence' at 0x7f0bfeb38690>
# 957
# <Element 'sentence' at 0x7f0bfeb38710>
# 2844
# <Element 'sentence' at 0x7f0bfeb38790>
# 2422
# <Element 'sentence' at 0x7f0bfeb388d0>
# 2540
# <Element 'sentence' at 0x7f0bfeb38a10>
# 2018
# <Element 'sentence' at 0x7f0bfeb38b10>
# 800
# <Element 'sentence' at 0x7f0bfeb38b90>
# 2566
# <Element 'sentence' at 0x7f0bfeb38c10>
# 1683
# <Element 'sentence' at 0x7f0bfeb38c90>
# 2022
# <Element 'sentence' at 0x7f0bfeb38d90>
# 709
# <Element 'sentence' at 0x7f0bfeb38e10>
# 1191
# <Element 'sentence' at 0x7f0bfeb38f50>
# 1950
# <Element 'sentence' at 0x7f0bfeb38fd0>
# 2007
# <Element 'sentence' at 0x7f0bfeb44090>
# 777
# <Element 'sentence' at 0x7f0bfeb44190>
# 2775
# <Element 'sentence' at 0x7f0bfeb44290>
# 1145
# <Element 'sentence' at 0x7f0bfeb44310>
# 1844
# <Element 'sentence' at 0x7f0bfeb44410>
# 1989
# <Element 'sentence' at 0x7f0bfeb444d0>
# 2147
# <Element 'sentence' at 0x7f0bfeb44590>
# 1068
# <Element 'sentence' at 0x7f0bfeb44750>
# 2030
# <Element 'sentence' at 0x7f0bfeb44850>
# 2586
# <Element 'sentence' at 0x7f0bfeb448d0>
# 128
# <Element 'sentence' at 0x7f0bfeb449d0>
# 2822
# <Element 'sentence' at 0x7f0bfeb44a50>
# 1561
# <Element 'sentence' at 0x7f0bfeb44b90>
# 1890
# <Element 'sentence' at 0x7f0bfeb44c90>
# 2435
# <Element 'sentence' at 0x7f0bfeb44d90>
# 826
# <Element 'sentence' at 0x7f0bfeb44e10>
# 2166
# <Element 'sentence' at 0x7f0bfeb44f10>
# 739
# <Element 'sentence' at 0x7f0bfeb44f90>
# 371
# <Element 'sentence' at 0x7f0bfeb50050>
# 2969
# <Element 'sentence' at 0x7f0bfeb50150>
# 896
# <Element 'sentence' at 0x7f0bfeb501d0>
# 824
# <Element 'sentence' at 0x7f0bfeb502d0>
# 2896
# <Element 'sentence' at 0x7f0bfeb50350>
# 2754
# <Element 'sentence' at 0x7f0bfeb50490>
# 309
# <Element 'sentence' at 0x7f0bfeb50590>
# 816
# <Element 'sentence' at 0x7f0bfeb50610>
# 16
# <Element 'sentence' at 0x7f0bfeb50750>
# 1984
# <Element 'sentence' at 0x7f0bfeb50910>
# 837
# <Element 'sentence' at 0x7f0bfeb509d0>
# 1588
# <Element 'sentence' at 0x7f0bfeb50a50>
# 2943
# <Element 'sentence' at 0x7f0bfeb50b50>
# 2410
# <Element 'sentence' at 0x7f0bfeb50bd0>
# 2889
# <Element 'sentence' at 0x7f0bfeb50c90>
# 1839
# <Element 'sentence' at 0x7f0bfeb50d90>
# 1375
# <Element 'sentence' at 0x7f0bfeb50ed0>
# 899
# <Element 'sentence' at 0x7f0bfeb50fd0>
# 2897
# <Element 'sentence' at 0x7f0bfeb5c090>
# 2858
# <Element 'sentence' at 0x7f0bfeb5c1d0>
# 1338
# <Element 'sentence' at 0x7f0bfeb5c2d0>
# 2962
# <Element 'sentence' at 0x7f0bfeb5c4d0>
# 1785
# <Element 'sentence' at 0x7f0bfeb5c550>
# 2110
# <Element 'sentence' at 0x7f0bfeb5c650>
# 2201
# <Element 'sentence' at 0x7f0bfeb5c6d0>
# 139
# <Element 'sentence' at 0x7f0bfeb5c750>
# 2582
# <Element 'sentence' at 0x7f0bfeb5c7d0>
# 35
# <Element 'sentence' at 0x7f0bfeb5c8d0>
# 1041
# <Element 'sentence' at 0x7f0bfeb5ca10>
# 1219
# <Element 'sentence' at 0x7f0bfeb5ca90>
# 231
# <Element 'sentence' at 0x7f0bfeb5cb10>
# 728
# <Element 'sentence' at 0x7f0bfeb5cb90>
# 1934
# <Element 'sentence' at 0x7f0bfeb5cc10>
# 1040
# <Element 'sentence' at 0x7f0bfeb5cd10>
# 178
# <Element 'sentence' at 0x7f0bfeb5cd90>
# 379
# <Element 'sentence' at 0x7f0bfeb5ced0>
# 2358
# <Element 'sentence' at 0x7f0bfeb5cf50>
# 1757
# <Element 'sentence' at 0x7f0bfeb68110>
# 220
# <Element 'sentence' at 0x7f0bfeb68210>
# 2790
# <Element 'sentence' at 0x7f0bfeb68290>
# 2370
# <Element 'sentence' at 0x7f0bfeb68310>
# 2919
# <Element 'sentence' at 0x7f0bfeb68410>
# 698
# <Element 'sentence' at 0x7f0bfeb68550>
# 1336
# <Element 'sentence' at 0x7f0bfeb68690>
# 797
# <Element 'sentence' at 0x7f0bfeb68710>
# 2758
# <Element 'sentence' at 0x7f0bfeb68790>
# 146
# <Element 'sentence' at 0x7f0bfeb68850>
# 432
# <Element 'sentence' at 0x7f0bfeb68910>
# 1969
# <Element 'sentence' at 0x7f0bfeb68a10>
# 2549
# <Element 'sentence' at 0x7f0bfeb68b10>
# 269
# <Element 'sentence' at 0x7f0bfeb68bd0>
# 469
# <Element 'sentence' at 0x7f0bfeb68d10>
# 2974
# <Element 'sentence' at 0x7f0bfeb68e10>
# 835
# <Element 'sentence' at 0x7f0bfeb68f10>
# 1898
# <Element 'sentence' at 0x7f0bfeb68f90>
# 1962
# <Element 'sentence' at 0x7f0bfeaf60d0>
# 306
# <Element 'sentence' at 0x7f0bfeaf6150>
# 2838
# <Element 'sentence' at 0x7f0bfeaf61d0>
# 1666
# <Element 'sentence' at 0x7f0bfeaf6250>
# 2876
# <Element 'sentence' at 0x7f0bfeaf6390>
# 2141
# <Element 'sentence' at 0x7f0bfeaf6490>
# 3040
# <Element 'sentence' at 0x7f0bfeaf6510>
# 2034
# <Element 'sentence' at 0x7f0bfeaf6610>
# 2798
# <Element 'sentence' at 0x7f0bfeaf6690>
# 1382
# <Element 'sentence' at 0x7f0bfeaf6710>
# 2905
# <Element 'sentence' at 0x7f0bfeaf6790>
# 2669
# <Element 'sentence' at 0x7f0bfeaf6890>
# 2895
# <Element 'sentence' at 0x7f0bfeaf69d0>
# 2181
# <Element 'sentence' at 0x7f0bfeaf6ad0>
# 1529
# <Element 'sentence' at 0x7f0bfeaf6c10>
# 2002
# <Element 'sentence' at 0x7f0bfeaf6c90>
# 1752
# <Element 'sentence' at 0x7f0bfeaf6d90>
# 672
# <Element 'sentence' at 0x7f0bfeaf6e50>
# 695
# <Element 'sentence' at 0x7f0bfeaf6f90>
# 2291
# <Element 'sentence' at 0x7f0bfeb030d0>
# 2183
# <Element 'sentence' at 0x7f0bfeb03150>
# 658
# <Element 'sentence' at 0x7f0bfeb031d0>
# 2286
# <Element 'sentence' at 0x7f0bfeb03250>
# 2481
# <Element 'sentence' at 0x7f0bfeb03350>
# 1584
# <Element 'sentence' at 0x7f0bfeb033d0>
# 1893
# <Element 'sentence' at 0x7f0bfeb034d0>
# 2649
# <Element 'sentence' at 0x7f0bfeb036d0>
# 783
# <Element 'sentence' at 0x7f0bfeb03750>
# 1889
# <Element 'sentence' at 0x7f0bfeb037d0>
# 3072
# <Element 'sentence' at 0x7f0bfeb03950>
# 1196
# <Element 'sentence' at 0x7f0bfeb03a50>
# 761
# <Element 'sentence' at 0x7f0bfeb03b50>
# 1736
# <Element 'sentence' at 0x7f0bfeb03bd0>
# 813
# <Element 'sentence' at 0x7f0bfeb03c50>
# 1735
# <Element 'sentence' at 0x7f0bfeb03cd0>
# 2096
# <Element 'sentence' at 0x7f0bfeb03e10>
# 633
# <Element 'sentence' at 0x7f0bfeb03e90>
# 714
# <Element 'sentence' at 0x7f0bfeb03f90>
# 1404
# <Element 'sentence' at 0x7f0bfeb0e050>
# 862
# <Element 'sentence' at 0x7f0bfeb0e0d0>
# 1023
# <Element 'sentence' at 0x7f0bfeb0e150>
# 827
# <Element 'sentence' at 0x7f0bfeb0e1d0>
# 923
# <Element 'sentence' at 0x7f0bfeb0e250>
# 1973
# <Element 'sentence' at 0x7f0bfeb0e310>
# 2304
# <Element 'sentence' at 0x7f0bfeb0e550>
# 1313
# <Element 'sentence' at 0x7f0bfeb0e5d0>
# 2276
# <Element 'sentence' at 0x7f0bfeb0e7d0>
# 3054
# <Element 'sentence' at 0x7f0bfeb0e850>
# 1953
# <Element 'sentence' at 0x7f0bfeb0e950>
# 2755
# <Element 'sentence' at 0x7f0bfeb0ead0>
# 184
# <Element 'sentence' at 0x7f0bfeb0eb50>
# 622
# <Element 'sentence' at 0x7f0bfeb0ebd0>
# 744
# <Element 'sentence' at 0x7f0bfeb0ed50>
# 1281
# <Element 'sentence' at 0x7f0bfeb0edd0>
# 1963
# <Element 'sentence' at 0x7f0bfeb0eed0>
# 70
# <Element 'sentence' at 0x7f0bfeb0efd0>
# 1611
# <Element 'sentence' at 0x7f0bfeb19090>
# 2342
# <Element 'sentence' at 0x7f0bfeb19110>
# 151
# <Element 'sentence' at 0x7f0bfeb19250>
# 1319
# <Element 'sentence' at 0x7f0bfeb192d0>
# 2850
# <Element 'sentence' at 0x7f0bfeb19350>
# 2556
# <Element 'sentence' at 0x7f0bfeb193d0>
# 1734
# <Element 'sentence' at 0x7f0bfeb194d0>
# 1617
# <Element 'sentence' at 0x7f0bfeb19610>
# 912
# <Element 'sentence' at 0x7f0bfeb19690>
# 1476
# <Element 'sentence' at 0x7f0bfeb197d0>
# 1623
# <Element 'sentence' at 0x7f0bfeb19990>
# 451
# <Element 'sentence' at 0x7f0bfeb19ad0>
# 1544
# <Element 'sentence' at 0x7f0bfeb19b50>
# 149
# <Element 'sentence' at 0x7f0bfeb19bd0>
# 1222
# <Element 'sentence' at 0x7f0bfeb19c50>
# 2956
# <Element 'sentence' at 0x7f0bfeb19d50>
# 720
# <Element 'sentence' at 0x7f0bfeb19f50>
# 740
# <Element 'sentence' at 0x7f0bfeb26050>
# 2442
# <Element 'sentence' at 0x7f0bfeb26110>
# 2125
# <Element 'sentence' at 0x7f0bfeb26190>
# 2564
# <Element 'sentence' at 0x7f0bfeb26290>
# 3016
# <Element 'sentence' at 0x7f0bfeb263d0>
# 806
# <Element 'sentence' at 0x7f0bfeb26450>
# 2778
# <Element 'sentence' at 0x7f0bfeb26590>
# 2174
# <Element 'sentence' at 0x7f0bfeb26690>
# 157
# <Element 'sentence' at 0x7f0bfeb26710>
# 1522
# <Element 'sentence' at 0x7f0bfeb26790>
# 2535
# <Element 'sentence' at 0x7f0bfeb26810>
# 1378
# <Element 'sentence' at 0x7f0bfeb26910>
# 2999
# <Element 'sentence' at 0x7f0bfeb26a10>
# 1930
# <Element 'sentence' at 0x7f0bfeb26a90>
# 222
# <Element 'sentence' at 0x7f0bfeb26b90>
# 2802
# <Element 'sentence' at 0x7f0bfeb26c10>
# 1512
# <Element 'sentence' at 0x7f0bfeb26c90>
# 1189
# <Element 'sentence' at 0x7f0bfeb26d90>
# 1356
# <Element 'sentence' at 0x7f0bfeb26e10>
# 2070
# <Element 'sentence' at 0x7f0bfeb26f10>
# 2076
# <Element 'sentence' at 0x7f0bfeb31050>
# 603
# <Element 'sentence' at 0x7f0bfeb31110>
# 1513
# <Element 'sentence' at 0x7f0bfeb31190>
# 1787
# <Element 'sentence' at 0x7f0bfeb31210>
# 930
# <Element 'sentence' at 0x7f0bfeb31290>
# 612
# <Element 'sentence' at 0x7f0bfeb313d0>
# 470
# <Element 'sentence' at 0x7f0bfeb31450>
# 1320
# <Element 'sentence' at 0x7f0bfeb314d0>
# 2706
# <Element 'sentence' at 0x7f0bfeb31610>
# 2997
# <Element 'sentence' at 0x7f0bfeb31690>
# 2954
# <Element 'sentence' at 0x7f0bfeb317d0>
# 1874
# <Element 'sentence' at 0x7f0bfeb31910>
# 2834
# <Element 'sentence' at 0x7f0bfeb31990>
# 1546
# <Element 'sentence' at 0x7f0bfeb31a90>
# 1939
# <Element 'sentence' at 0x7f0bfeb31b10>
# 2840
# <Element 'sentence' at 0x7f0bfeb31b90>
# 484
# <Element 'sentence' at 0x7f0bfeb31c10>
# 2003
# <Element 'sentence' at 0x7f0bfeb31d10>
# 1180
# <Element 'sentence' at 0x7f0bfeb31e50>
# 875
# <Element 'sentence' at 0x7f0bfeb31ed0>
# 809
# <Element 'sentence' at 0x7f0bfeb31fd0>
# 799
# <Element 'sentence' at 0x7f0bfeabb150>
# 1668
# <Element 'sentence' at 0x7f0bfeabb290>
# 274
# <Element 'sentence' at 0x7f0bfeabb390>
# 2128
# <Element 'sentence' at 0x7f0bfeabb4d0>
# 2237
# <Element 'sentence' at 0x7f0bfeabb550>
# 2456
# <Element 'sentence' at 0x7f0bfeabb690>
# 353
# <Element 'sentence' at 0x7f0bfeabb7d0>
# 2290
# <Element 'sentence' at 0x7f0bfeabb950>
# 1121
# <Element 'sentence' at 0x7f0bfeabb9d0>
# 134
# <Element 'sentence' at 0x7f0bfeabba50>
# 347
# <Element 'sentence' at 0x7f0bfeabbb50>
# 1813
# <Element 'sentence' at 0x7f0bfeabbbd0>
# 655
# <Element 'sentence' at 0x7f0bfeabbcd0>
# 2510
# <Element 'sentence' at 0x7f0bfeabbe10>
# 1615
# <Element 'sentence' at 0x7f0bfeabbe90>
# 844
# <Element 'sentence' at 0x7f0bfeabbf10>
# 884
# <Element 'sentence' at 0x7f0bfeac9050>
# 2785
# <Element 'sentence' at 0x7f0bfeac9150>
# 2443
# <Element 'sentence' at 0x7f0bfeac9290>
# 81
# <Element 'sentence' at 0x7f0bfeac9390>
# 89
# <Element 'sentence' at 0x7f0bfeac9410>
# 2114
# <Element 'sentence' at 0x7f0bfeac9510>
# 1670
# <Element 'sentence' at 0x7f0bfeac9590>
# 764
# <Element 'sentence' at 0x7f0bfeac9690>
# 525
# <Element 'sentence' at 0x7f0bfeac9710>
# 435
# <Element 'sentence' at 0x7f0bfeac9810>
# 914
# <Element 'sentence' at 0x7f0bfeac9910>
# 177
# <Element 'sentence' at 0x7f0bfeac9990>
# 1776
# <Element 'sentence' at 0x7f0bfeac9ad0>
# 330
# <Element 'sentence' at 0x7f0bfeac9b50>
# 865
# <Element 'sentence' at 0x7f0bfeac9bd0>
# 1791
# <Element 'sentence' at 0x7f0bfeac9c50>
# 549
# <Element 'sentence' at 0x7f0bfeac9d10>
# 1212
# <Element 'sentence' at 0x7f0bfeac9e10>
# 2169
# <Element 'sentence' at 0x7f0bfeac9e90>
# 2845
# <Element 'sentence' at 0x7f0bfeac9fd0>
# 756
# <Element 'sentence' at 0x7f0bfead6110>
# 2600
# <Element 'sentence' at 0x7f0bfead6250>
# 2327
# <Element 'sentence' at 0x7f0bfead62d0>
# 3012
# <Element 'sentence' at 0x7f0bfead6390>
# 1696
# <Element 'sentence' at 0x7f0bfead64d0>
# 1479
# <Element 'sentence' at 0x7f0bfead65d0>
# 2909
# <Element 'sentence' at 0x7f0bfead6750>
# 2937
# <Element 'sentence' at 0x7f0bfead6810>
# 1784
# <Element 'sentence' at 0x7f0bfead68d0>
# 453
# <Element 'sentence' at 0x7f0bfead6d10>
# 439
# <Element 'sentence' at 0x7f0bfead6d90>
# 2925
# <Element 'sentence' at 0x7f0bfead6e10>
# 929
# <Element 'sentence' at 0x7f0bfead6e90>
# 2804
# <Element 'sentence' at 0x7f0bfead6f10>
# 2077
# <Element 'sentence' at 0x7f0bfeae0090>
# 2622
# <Element 'sentence' at 0x7f0bfeae0210>
# 1093
# <Element 'sentence' at 0x7f0bfeae02d0>
# 225
# <Element 'sentence' at 0x7f0bfeae0350>
# 1100
# <Element 'sentence' at 0x7f0bfeae0410>
# 2523
# <Element 'sentence' at 0x7f0bfeae0450>
# 970
# <Element 'sentence' at 0x7f0bfeae0590>
# 1935
# <Element 'sentence' at 0x7f0bfeae0610>
# 11
# <Element 'sentence' at 0x7f0bfeae06d0>
# 2569
# <Element 'sentence' at 0x7f0bfeae0750>
# 3010
# <Element 'sentence' at 0x7f0bfeae07d0>
# 1634
# <Element 'sentence' at 0x7f0bfeae0850>
# 2414
# <Element 'sentence' at 0x7f0bfeae0910>
# 832
# <Element 'sentence' at 0x7f0bfeae0a50>
# 1205
# <Element 'sentence' at 0x7f0bfeae0ad0>
# 1064
# <Element 'sentence' at 0x7f0bfeae0c50>
# 2037
# <Element 'sentence' at 0x7f0bfeae0d10>
# 1429
# <Element 'sentence' at 0x7f0bfeae0d90>
# 2130
# <Element 'sentence' at 0x7f0bfeae0e90>
# 2626
# <Element 'sentence' at 0x7f0bfeaed050>
# 1671
# <Element 'sentence' at 0x7f0bfeaed0d0>
# 1315
# <Element 'sentence' at 0x7f0bfeaed1d0>
# 2756
# <Element 'sentence' at 0x7f0bfeaed2d0>
# 548
# <Element 'sentence' at 0x7f0bfeaed390>
# 1446
# <Element 'sentence' at 0x7f0bfeaed490>
# 168
# <Element 'sentence' at 0x7f0bfeaed550>
# 922
# <Element 'sentence' at 0x7f0bfeaed650>
# 2797
# <Element 'sentence' at 0x7f0bfeaed750>
# 2863
# <Element 'sentence' at 0x7f0bfeaed890>
# 638
# <Element 'sentence' at 0x7f0bfeaed910>
# 2642
# <Element 'sentence' at 0x7f0bfeaed990>
# 1000
# <Element 'sentence' at 0x7f0bfeaeda10>
# 200
# <Element 'sentence' at 0x7f0bfeaeda90>
# 2887
# <Element 'sentence' at 0x7f0bfeaedb10>
# 993
# <Element 'sentence' at 0x7f0bfeaedb90>
# 2464
# <Element 'sentence' at 0x7f0bfeaedc10>
# 1667
# <Element 'sentence' at 0x7f0bfeaedc90>
# 416
# <Element 'sentence' at 0x7f0bfeaedd10>
# 2041
# <Element 'sentence' at 0x7f0bfeaedd90>
# 240
# <Element 'sentence' at 0x7f0bfeaede90>
# 2135
# <Element 'sentence' at 0x7f0bfeaedf10>
# 1393
# <Element 'sentence' at 0x7f0bfea79050>
# 2259
# <Element 'sentence' at 0x7f0bfea790d0>
# 1080
# <Element 'sentence' at 0x7f0bfea79250>
# 2695
# <Element 'sentence' at 0x7f0bfea792d0>
# 1506
# <Element 'sentence' at 0x7f0bfea79350>
# 1837
# <Element 'sentence' at 0x7f0bfea793d0>
# 532
# <Element 'sentence' at 0x7f0bfea794d0>
# 3047
# <Element 'sentence' at 0x7f0bfea795d0>
# 921
# <Element 'sentence' at 0x7f0bfea79650>
# 1733
# <Element 'sentence' at 0x7f0bfea79790>
# 2907
# <Element 'sentence' at 0x7f0bfea79810>
# 1178
# <Element 'sentence' at 0x7f0bfea79890>
# 2265
# <Element 'sentence' at 0x7f0bfea79910>
# 119
# <Element 'sentence' at 0x7f0bfea79990>
# 68
# <Element 'sentence' at 0x7f0bfea79a10>
# 2746
# <Element 'sentence' at 0x7f0bfea79a90>
# 282
# <Element 'sentence' at 0x7f0bfea79b10>
# 1532
# <Element 'sentence' at 0x7f0bfea79c10>
# 2800
# <Element 'sentence' at 0x7f0bfea79c90>
# 1042
# <Element 'sentence' at 0x7f0bfea79d10>
# 640
# <Element 'sentence' at 0x7f0bfea79e50>
# 2238
# <Element 'sentence' at 0x7f0bfea79f50>
# 1907
# <Element 'sentence' at 0x7f0bfea79fd0>
# 78
# <Element 'sentence' at 0x7f0bfea84090>
# 891
# <Element 'sentence' at 0x7f0bfea84110>
# 692
# <Element 'sentence' at 0x7f0bfea84190>
# 1580
# <Element 'sentence' at 0x7f0bfea842d0>
# 2817
# <Element 'sentence' at 0x7f0bfea84350>
# 273
# <Element 'sentence' at 0x7f0bfea84490>
# 2679
# <Element 'sentence' at 0x7f0bfea84550>
# 415
# <Element 'sentence' at 0x7f0bfea84610>
# 2046
# <Element 'sentence' at 0x7f0bfea846d0>
# 2450
# <Element 'sentence' at 0x7f0bfea84750>
# 2170
# <Element 'sentence' at 0x7f0bfea848d0>
# 2624
# <Element 'sentence' at 0x7f0bfea849d0>
# 1822
# <Element 'sentence' at 0x7f0bfea84a50>
# 2374
# <Element 'sentence' at 0x7f0bfea84ad0>
# 1896
# <Element 'sentence' at 0x7f0bfea84b50>
# 341
# <Element 'sentence' at 0x7f0bfea84bd0>
# 2245
# <Element 'sentence' at 0x7f0bfea84c50>
# 1569
# <Element 'sentence' at 0x7f0bfea84d50>
# 3064
# <Element 'sentence' at 0x7f0bfea84e50>
# 2953
# <Element 'sentence' at 0x7f0bfea84f50>
# 2129
# <Element 'sentence' at 0x7f0bfea90090>
# 2075
# <Element 'sentence' at 0x7f0bfea901d0>
# 2180
# <Element 'sentence' at 0x7f0bfea90250>
# 1362
# <Element 'sentence' at 0x7f0bfea902d0>
# 2710
# <Element 'sentence' at 0x7f0bfea90410>
# 1373
# <Element 'sentence' at 0x7f0bfea905d0>
# 1370
# <Element 'sentence' at 0x7f0bfea90710>
# 1697
# <Element 'sentence' at 0x7f0bfea907d0>
# 276
# <Element 'sentence' at 0x7f0bfea90850>
# 1287
# <Element 'sentence' at 0x7f0bfea90910>
# 1929
# <Element 'sentence' at 0x7f0bfea90990>
# 2365
# <Element 'sentence' at 0x7f0bfea90a10>
# 412
# <Element 'sentence' at 0x7f0bfea90a90>
# 2742
# <Element 'sentence' at 0x7f0bfea90b50>
# 1758
# <Element 'sentence' at 0x7f0bfea90c50>
# 1257
# <Element 'sentence' at 0x7f0bfea90cd0>
# 1908
# <Element 'sentence' at 0x7f0bfea90d50>
# 842
# <Element 'sentence' at 0x7f0bfea90e50>
# 931
# <Element 'sentence' at 0x7f0bfea90f90>
# 863
# <Element 'sentence' at 0x7f0bfea9c050>
# 2151
# <Element 'sentence' at 0x7f0bfea9c0d0>
# 36
# <Element 'sentence' at 0x7f0bfea9c1d0>
# 2967
# <Element 'sentence' at 0x7f0bfea9c2d0>
# 1732
# <Element 'sentence' at 0x7f0bfea9c3d0>
# 1800
# <Element 'sentence' at 0x7f0bfea9c450>
# 1063
# <Element 'sentence' at 0x7f0bfea9c550>
# 2615
# <Element 'sentence' at 0x7f0bfea9c5d0>
# 271
# <Element 'sentence' at 0x7f0bfea9c710>
# 2478
# <Element 'sentence' at 0x7f0bfea9c890>
# 523
# <Element 'sentence' at 0x7f0bfea9c9d0>
# 1657
# <Element 'sentence' at 0x7f0bfea9ca90>
# 1674
# <Element 'sentence' at 0x7f0bfea9cc10>
# 472
# <Element 'sentence' at 0x7f0bfea9cc90>
# 1143
# <Element 'sentence' at 0x7f0bfea9cd90>
# 2618
# <Element 'sentence' at 0x7f0bfea9ce10>
# 1708
# <Element 'sentence' at 0x7f0bfea9ce90>
# 2771
# <Element 'sentence' at 0x7f0bfea9cf10>
# 2375
# <Element 'sentence' at 0x7f0bfea9cf90>
# 203
# <Element 'sentence' at 0x7f0bfeaa7050>
# 123
# <Element 'sentence' at 0x7f0bfeaa70d0>
# 2927
# <Element 'sentence' at 0x7f0bfeaa7210>
# 916
# <Element 'sentence' at 0x7f0bfeaa7290>
# 2750
# <Element 'sentence' at 0x7f0bfeaa7350>
# 1137
# <Element 'sentence' at 0x7f0bfeaa73d0>
# 2993
# <Element 'sentence' at 0x7f0bfeaa7510>
# 2453
# <Element 'sentence' at 0x7f0bfeaa7610>
# 2661
# <Element 'sentence' at 0x7f0bfeaa7690>
# 2590
# <Element 'sentence' at 0x7f0bfeaa7710>
# 515
# <Element 'sentence' at 0x7f0bfeaa7850>
# 2321
# <Element 'sentence' at 0x7f0bfeaa78d0>
# 2282
# <Element 'sentence' at 0x7f0bfeaa7950>
# 1135
# <Element 'sentence' at 0x7f0bfeaa79d0>
# 1577
# <Element 'sentence' at 0x7f0bfeaa7a50>
# 2572
# <Element 'sentence' at 0x7f0bfeaa7b50>
# 2387
# <Element 'sentence' at 0x7f0bfeaa7c90>
# 2517
# <Element 'sentence' at 0x7f0bfeaa7d90>
# 1967
# <Element 'sentence' at 0x7f0bfeaa7e10>
# 990
# <Element 'sentence' at 0x7f0bfeaa7f50>
# 1414
# <Element 'sentence' at 0x7f0bfeab30d0>
# 664
# <Element 'sentence' at 0x7f0bfeab3150>
# 2484
# <Element 'sentence' at 0x7f0bfeab31d0>
# 903
# <Element 'sentence' at 0x7f0bfeab32d0>
# 1609
# <Element 'sentence' at 0x7f0bfeab3350>
# 2354
# <Element 'sentence' at 0x7f0bfeab33d0>
# 2979
# <Element 'sentence' at 0x7f0bfeab3450>
# 1759
# <Element 'sentence' at 0x7f0bfeab34d0>
# 975
# <Element 'sentence' at 0x7f0bfeab3550>
# 2931
# <Element 'sentence' at 0x7f0bfeab35d0>
# 2700
# <Element 'sentence' at 0x7f0bfeab3650>
# 1482
# <Element 'sentence' at 0x7f0bfeab36d0>
# 1602
# <Element 'sentence' at 0x7f0bfeab37d0>
# 1233
# <Element 'sentence' at 0x7f0bfeab3850>
# 2231
# <Element 'sentence' at 0x7f0bfeab3a10>
# 2828
# <Element 'sentence' at 0x7f0bfeab3b10>
# 121
# <Element 'sentence' at 0x7f0bfeab3b90>
# 2744
# <Element 'sentence' at 0x7f0bfeab3c10>
# 1824
# <Element 'sentence' at 0x7f0bfeab3d10>
# 2460
# <Element 'sentence' at 0x7f0bfeab3e50>
# 2500
# <Element 'sentence' at 0x7f0bfeab3f50>
# 600
# <Element 'sentence' at 0x7f0bfeab3fd0>
# 497
# <Element 'sentence' at 0x7f0bfea40090>
# 241
# <Element 'sentence' at 0x7f0bfea40110>
# 557
# <Element 'sentence' at 0x7f0bfea40190>
# 677
# <Element 'sentence' at 0x7f0bfea40290>
# 531
# <Element 'sentence' at 0x7f0bfea40310>
# 1367
# <Element 'sentence' at 0x7f0bfea40390>
# 2094
# <Element 'sentence' at 0x7f0bfea40410>
# 1252
# <Element 'sentence' at 0x7f0bfea40510>
# 3007
# <Element 'sentence' at 0x7f0bfea40610>
# 1650
# <Element 'sentence' at 0x7f0bfea40710>
# 1229
# <Element 'sentence' at 0x7f0bfea40790>
# 399
# <Element 'sentence' at 0x7f0bfea40810>
# 1037
# <Element 'sentence' at 0x7f0bfea408d0>
# 1620
# <Element 'sentence' at 0x7f0bfea40a10>
# 1035
# <Element 'sentence' at 0x7f0bfea40a90>
# 201
# <Element 'sentence' at 0x7f0bfea40b10>
# 285
# <Element 'sentence' at 0x7f0bfea40c10>
# 1260
# <Element 'sentence' at 0x7f0bfea40c90>
# 3035
# <Element 'sentence' at 0x7f0bfea40dd0>
# 840
# <Element 'sentence' at 0x7f0bfea40e50>
# 2511
# <Element 'sentence' at 0x7f0bfea40fd0>
# 895
# <Element 'sentence' at 0x7f0bfea4c090>
# 2275
# <Element 'sentence' at 0x7f0bfea4c150>
# 1342
# <Element 'sentence' at 0x7f0bfea4c210>
# 1124
# <Element 'sentence' at 0x7f0bfea4c310>
# 781
# <Element 'sentence' at 0x7f0bfea4c410>
# 2987
# <Element 'sentence' at 0x7f0bfea4c510>
# 2133
# <Element 'sentence' at 0x7f0bfea4c610>
# 131
# <Element 'sentence' at 0x7f0bfea4c690>
# 1364
# <Element 'sentence' at 0x7f0bfea4c750>
# 2787
# <Element 'sentence' at 0x7f0bfea4c8d0>
# 948
# <Element 'sentence' at 0x7f0bfea4ca10>
# 2049
# <Element 'sentence' at 0x7f0bfea4cb10>
# 558
# <Element 'sentence' at 0x7f0bfea4cb90>
# 1059
# <Element 'sentence' at 0x7f0bfea4cc10>
# 767
# <Element 'sentence' at 0x7f0bfea4cc90>
# 1990
# <Element 'sentence' at 0x7f0bfea4cd10>
# 2366
# <Element 'sentence' at 0x7f0bfea4cd90>
# 2988
# <Element 'sentence' at 0x7f0bfea4ce90>
# 1385
# <Element 'sentence' at 0x7f0bfea4cf90>
# 1646
# <Element 'sentence' at 0x7f0bfea57150>
# 88
# <Element 'sentence' at 0x7f0bfea571d0>
# 1270
# <Element 'sentence' at 0x7f0bfea57250>
# 1834
# <Element 'sentence' at 0x7f0bfea572d0>
# 1451
# <Element 'sentence' at 0x7f0bfea57350>
# 55
# <Element 'sentence' at 0x7f0bfea573d0>
# 2505
# <Element 'sentence' at 0x7f0bfea57510>
# 768
# <Element 'sentence' at 0x7f0bfea57610>
# 2559
# <Element 'sentence' at 0x7f0bfea57690>
# 242
# <Element 'sentence' at 0x7f0bfea57710>
# 2998
# <Element 'sentence' at 0x7f0bfea57790>
# 2341
# <Element 'sentence' at 0x7f0bfea57810>
# 2908
# <Element 'sentence' at 0x7f0bfea57890>
# 214
# <Element 'sentence' at 0x7f0bfea579d0>
# 1263
# <Element 'sentence' at 0x7f0bfea57ad0>
# 650
# <Element 'sentence' at 0x7f0bfea57b50>
# 2703
# <Element 'sentence' at 0x7f0bfea57bd0>
# 142
# <Element 'sentence' at 0x7f0bfea57cd0>
# 2947
# <Element 'sentence' at 0x7f0bfea57dd0>
# 66
# <Element 'sentence' at 0x7f0bfea57e50>
# 2020
# <Element 'sentence' at 0x7f0bfea57f50>
# 2451
# <Element 'sentence' at 0x7f0bfea65090>
# 605
# <Element 'sentence' at 0x7f0bfea65110>
# 314
# <Element 'sentence' at 0x7f0bfea65250>
# 2777
# <Element 'sentence' at 0x7f0bfea65390>
# 1085
# <Element 'sentence' at 0x7f0bfea65490>
# 1906
# <Element 'sentence' at 0x7f0bfea65590>
# 124
# <Element 'sentence' at 0x7f0bfea65690>
# 2816
# <Element 'sentence' at 0x7f0bfea65710>
# 1900
# <Element 'sentence' at 0x7f0bfea65790>
# 732
# <Element 'sentence' at 0x7f0bfea658d0>
# 3011
# <Element 'sentence' at 0x7f0bfea65a50>
# 485
# <Element 'sentence' at 0x7f0bfea65ad0>
# 1842
# <Element 'sentence' at 0x7f0bfea65bd0>
# 238
# <Element 'sentence' at 0x7f0bfea65c50>
# 205
# <Element 'sentence' at 0x7f0bfea65d90>
# 1955
# <Element 'sentence' at 0x7f0bfea65e10>
# 1160
# <Element 'sentence' at 0x7f0bfea65ed0>
# 2989
# <Element 'sentence' at 0x7f0bfea65f50>
# 1398
# <Element 'sentence' at 0x7f0bfea700d0>
# 1372
# <Element 'sentence' at 0x7f0bfea702d0>
# 467
# <Element 'sentence' at 0x7f0bfea70350>
# 1400
# <Element 'sentence' at 0x7f0bfea70490>
# 47
# <Element 'sentence' at 0x7f0bfea70510>
# 1066
# <Element 'sentence' at 0x7f0bfea70610>
# 1607
# <Element 'sentence' at 0x7f0bfea70690>
# 910
# <Element 'sentence' at 0x7f0bfea70710>
# 2379
# <Element 'sentence' at 0x7f0bfea70790>
# 361
# <Element 'sentence' at 0x7f0bfea70810>
# 344
# <Element 'sentence' at 0x7f0bfea709d0>
# 1368
# <Element 'sentence' at 0x7f0bfea70a50>
# 2038
# <Element 'sentence' at 0x7f0bfea70ad0>
# 1673
# <Element 'sentence' at 0x7f0bfea70b50>
# 2871
# <Element 'sentence' at 0x7f0bfea70c50>
# 2530
# <Element 'sentence' at 0x7f0bfea70cd0>
# 1603
# <Element 'sentence' at 0x7f0bfea70d50>
# 381
# <Element 'sentence' at 0x7f0bfea70dd0>
# 312
# <Element 'sentence' at 0x7f0bfe9fe090>
# 2795
# <Element 'sentence' at 0x7f0bfe9fe190>
# 1865
# <Element 'sentence' at 0x7f0bfe9fe310>
# 1681
# <Element 'sentence' at 0x7f0bfe9fe390>
# 2973
# <Element 'sentence' at 0x7f0bfe9fe510>
# 2612
# <Element 'sentence' at 0x7f0bfe9fe650>
# 1864
# <Element 'sentence' at 0x7f0bfe9fe6d0>
# 2629
# <Element 'sentence' at 0x7f0bfe9fe750>
# 2207
# <Element 'sentence' at 0x7f0bfe9fe7d0>
# 249
# <Element 'sentence' at 0x7f0bfe9fe850>
# 1283
# <Element 'sentence' at 0x7f0bfe9fe990>
# 1423
# <Element 'sentence' at 0x7f0bfe9fead0>
# 288
# <Element 'sentence' at 0x7f0bfe9feb50>
# 256
# <Element 'sentence' at 0x7f0bfe9febd0>
# 2280
# <Element 'sentence' at 0x7f0bfe9fec50>
# 322
# <Element 'sentence' at 0x7f0bfe9fecd0>
# 1072
# <Element 'sentence' at 0x7f0bfe9fedd0>
# 2826
# <Element 'sentence' at 0x7f0bfe9fee50>
# 1390
# <Element 'sentence' at 0x7f0bfe9feed0>
# 1739
# <Element 'sentence' at 0x7f0bfea09050>
# 2419
# <Element 'sentence' at 0x7f0bfea09150>
# 785
# <Element 'sentence' at 0x7f0bfea091d0>
# 82
# <Element 'sentence' at 0x7f0bfea09250>
# 1549
# <Element 'sentence' at 0x7f0bfea09350>
# 2086
# <Element 'sentence' at 0x7f0bfea094d0>
# 300
# <Element 'sentence' at 0x7f0bfea09750>
# 262
# <Element 'sentence' at 0x7f0bfea097d0>
# 2521
# <Element 'sentence' at 0x7f0bfea09850>
# 2284
# <Element 'sentence' at 0x7f0bfea098d0>
# 851
# <Element 'sentence' at 0x7f0bfea099d0>
# 1008
# <Element 'sentence' at 0x7f0bfea09ad0>
# 2261
# <Element 'sentence' at 0x7f0bfea09c10>
# 2793
# <Element 'sentence' at 0x7f0bfea09c90>
# 291
# <Element 'sentence' at 0x7f0bfea09d90>
# 1185
# <Element 'sentence' at 0x7f0bfea09e10>
# 1719
# <Element 'sentence' at 0x7f0bfea09ed0>
# 391
# <Element 'sentence' at 0x7f0bfea150d0>
# 1595
# <Element 'sentence' at 0x7f0bfea152d0>
# 1150
# <Element 'sentence' at 0x7f0bfea15350>
# 2362
# <Element 'sentence' at 0x7f0bfea15410>
# 116
# <Element 'sentence' at 0x7f0bfea15550>
# 2119
# <Element 'sentence' at 0x7f0bfea15610>
# 2647
# <Element 'sentence' at 0x7f0bfea15710>
# 2108
# <Element 'sentence' at 0x7f0bfea15790>
# 789
# <Element 'sentence' at 0x7f0bfea15810>
# 570
# <Element 'sentence' at 0x7f0bfea15890>
# 980
# <Element 'sentence' at 0x7f0bfea15990>
# 668
# <Element 'sentence' at 0x7f0bfea15ad0>
# 1106
# <Element 'sentence' at 0x7f0bfea15bd0>
# 140
# <Element 'sentence' at 0x7f0bfea15cd0>
# 1418
# <Element 'sentence' at 0x7f0bfea15dd0>
# 539
# <Element 'sentence' at 0x7f0bfea15e50>
# 621
# <Element 'sentence' at 0x7f0bfea15f50>
# 2360
# <Element 'sentence' at 0x7f0bfea22110>
# 2397
# <Element 'sentence' at 0x7f0bfea22190>
# 2449
# <Element 'sentence' at 0x7f0bfea22210>
# 1126
# <Element 'sentence' at 0x7f0bfea22390>
# 1745
# <Element 'sentence' at 0x7f0bfea22550>
# 2205
# <Element 'sentence' at 0x7f0bfea225d0>
# 1065
# <Element 'sentence' at 0x7f0bfea22650>
# 987
# <Element 'sentence' at 0x7f0bfea22710>
# 363
# <Element 'sentence' at 0x7f0bfea22750>
# 1276
# <Element 'sentence' at 0x7f0bfea227d0>
# 2911
# <Element 'sentence' at 0x7f0bfea22850>
# 2714
# <Element 'sentence' at 0x7f0bfea228d0>
# 2900
# <Element 'sentence' at 0x7f0bfea22950>
# 2177
# <Element 'sentence' at 0x7f0bfea229d0>
# 164
# <Element 'sentence' at 0x7f0bfea22a50>
# 39
# <Element 'sentence' at 0x7f0bfea22b50>
# 3019
# <Element 'sentence' at 0x7f0bfea22c90>
# 1517
# <Element 'sentence' at 0x7f0bfea22d10>
# 1090
# <Element 'sentence' at 0x7f0bfea22dd0>
# 1678
# <Element 'sentence' at 0x7f0bfea22e50>
# 2469
# <Element 'sentence' at 0x7f0bfea22f50>
# 2429
# <Element 'sentence' at 0x7f0bfea22fd0>
# 1986
# <Element 'sentence' at 0x7f0bfea2d150>
# 1088
# <Element 'sentence' at 0x7f0bfea2d2d0>
# 678
# <Element 'sentence' at 0x7f0bfea2d410>
# 417
# <Element 'sentence' at 0x7f0bfea2d490>
# 625
# <Element 'sentence' at 0x7f0bfea2d550>
# 2035
# <Element 'sentence' at 0x7f0bfea2d690>
# 636
# <Element 'sentence' at 0x7f0bfea2d710>
# 1808
# <Element 'sentence' at 0x7f0bfea2d790>
# 1921
# <Element 'sentence' at 0x7f0bfea2d890>
# 1872
# <Element 'sentence' at 0x7f0bfea2d990>
# 1413
# <Element 'sentence' at 0x7f0bfea2dad0>
# 369
# <Element 'sentence' at 0x7f0bfea2db50>
# 321
# <Element 'sentence' at 0x7f0bfea2dbd0>
# 2636
# <Element 'sentence' at 0x7f0bfea2dcd0>
# 357
# <Element 'sentence' at 0x7f0bfea2de10>
# 1230
# <Element 'sentence' at 0x7f0bfea2de90>
# 1006
# <Element 'sentence' at 0x7f0bfea2df10>
# 3075
# <Element 'sentence' at 0x7f0bfdfb8050>
# 216
# <Element 'sentence' at 0x7f0bfdfb80d0>
# 3045
# <Element 'sentence' at 0x7f0bfdfb8210>
# 1688
# <Element 'sentence' at 0x7f0bfdfb8290>
# 2098
# <Element 'sentence' at 0x7f0bfdfb8310>
# 1877
# <Element 'sentence' at 0x7f0bfdfb8390>
# 129
# <Element 'sentence' at 0x7f0bfdfb8410>
# 235
# <Element 'sentence' at 0x7f0bfdfb8550>
# 3055
# <Element 'sentence' at 0x7f0bfdfb8690>
# 2865
# <Element 'sentence' at 0x7f0bfdfb8790>
# 1300
# <Element 'sentence' at 0x7f0bfdfb8810>
# 1197
# <Element 'sentence' at 0x7f0bfdfb8910>
# 2538
# <Element 'sentence' at 0x7f0bfdfb8990>
# 1403
# <Element 'sentence' at 0x7f0bfdfb8a10>
# 2676
# <Element 'sentence' at 0x7f0bfdfb8b10>
# 75
# <Element 'sentence' at 0x7f0bfdfb8b90>
# 2319
# <Element 'sentence' at 0x7f0bfdfb8c50>
# 452
# <Element 'sentence' at 0x7f0bfdfb8e50>
# 2498
# <Element 'sentence' at 0x7f0bfdfb8f50>
# 2515
# <Element 'sentence' at 0x7f0bfdfc4090>
# 2320
# <Element 'sentence' at 0x7f0bfdfc4190>
# 2051
# <Element 'sentence' at 0x7f0bfdfc4210>
# 1017
# <Element 'sentence' at 0x7f0bfdfc4290>
# 971
# <Element 'sentence' at 0x7f0bfdfc4310>
# 3083
# <Element 'sentence' at 0x7f0bfdfc4410>
# 1687
# <Element 'sentence' at 0x7f0bfdfc4490>
# 2593
# <Element 'sentence' at 0x7f0bfdfc4590>
# 1507
# <Element 'sentence' at 0x7f0bfdfc4610>
# 336
# <Element 'sentence' at 0x7f0bfdfc46d0>
# 2391
# <Element 'sentence' at 0x7f0bfdfc4790>
# 786
# <Element 'sentence' at 0x7f0bfdfc4810>
# 1616
# <Element 'sentence' at 0x7f0bfdfc4910>
# 1062
# <Element 'sentence' at 0x7f0bfdfc4a10>
# 1982
# <Element 'sentence' at 0x7f0bfdfc4a90>
# 2704
# <Element 'sentence' at 0x7f0bfdfc4b90>
# 2930
# <Element 'sentence' at 0x7f0bfdfc4c10>
# 343
# <Element 'sentence' at 0x7f0bfdfc4c90>
# 1152
# <Element 'sentence' at 0x7f0bfdfc4dd0>
# 1868
# <Element 'sentence' at 0x7f0bfdfc4e50>
# 1353
# <Element 'sentence' at 0x7f0bfdfc4f10>
# 977
# <Element 'sentence' at 0x7f0bfdfc4f90>
# 2747
# <Element 'sentence' at 0x7f0bfdfcf110>
# 2102
# <Element 'sentence' at 0x7f0bfdfcf190>
# 967
# <Element 'sentence' at 0x7f0bfdfcf290>
# 1774
# <Element 'sentence' at 0x7f0bfdfcf310>
# 1685
# <Element 'sentence' at 0x7f0bfdfcf3d0>
# 932
# <Element 'sentence' at 0x7f0bfdfcf450>
# 2501
# <Element 'sentence' at 0x7f0bfdfcf550>
# 1873
# <Element 'sentence' at 0x7f0bfdfcf5d0>
# 1753
# <Element 'sentence' at 0x7f0bfdfcf690>
# 892
# <Element 'sentence' at 0x7f0bfdfcf710>
# 1241
# <Element 'sentence' at 0x7f0bfdfcf790>
# 135
# <Element 'sentence' at 0x7f0bfdfcf810>
# 1801
# <Element 'sentence' at 0x7f0bfdfcf950>
# 2902
# <Element 'sentence' at 0x7f0bfdfcfa90>
# 2062
# <Element 'sentence' at 0x7f0bfdfcfb10>
# 2656
# <Element 'sentence' at 0x7f0bfdfcfc10>
# 652
# <Element 'sentence' at 0x7f0bfdfcfd10>
# 170
# <Element 'sentence' at 0x7f0bfdfcfe10>
# 665
# <Element 'sentence' at 0x7f0bfdfcfe90>
# 787
# <Element 'sentence' at 0x7f0bfdfcff10>
# 814
# <Element 'sentence' at 0x7f0bfdfcff90>
# 2047
# <Element 'sentence' at 0x7f0bfdfdb0d0>
# 3039
# <Element 'sentence' at 0x7f0bfdfdb150>
# 1371
# <Element 'sentence' at 0x7f0bfdfdb210>
# 2666
# <Element 'sentence' at 0x7f0bfdfdb2d0>
# 741
# <Element 'sentence' at 0x7f0bfdfdb3d0>
# 1748
# <Element 'sentence' at 0x7f0bfdfdb510>
# 774
# <Element 'sentence' at 0x7f0bfdfdb590>
# 2246
# <Element 'sentence' at 0x7f0bfdfdb710>
# 1055
# <Element 'sentence' at 0x7f0bfdfdb790>
# 401
# <Element 'sentence' at 0x7f0bfdfdb810>
# 2032
# <Element 'sentence' at 0x7f0bfdfdb990>
# 1780
# <Element 'sentence' at 0x7f0bfdfdba10>
# 150
# <Element 'sentence' at 0x7f0bfdfdbb50>
# 1581
# <Element 'sentence' at 0x7f0bfdfdbbd0>
# 302
# <Element 'sentence' at 0x7f0bfdfdbcd0>
# 204
# <Element 'sentence' at 0x7f0bfdfdbdd0>
# 2080
# <Element 'sentence' at 0x7f0bfdfe7050>
# 964
# <Element 'sentence' at 0x7f0bfdfe7110>
# 2780
# <Element 'sentence' at 0x7f0bfdfe7250>
# 1105
# <Element 'sentence' at 0x7f0bfdfe7350>
# 1484
# <Element 'sentence' at 0x7f0bfdfe7450>
# 17
# <Element 'sentence' at 0x7f0bfdfe74d0>
# 2506
# ...
# 1235
# <Element 'sentence' at 0x7f0bfdb75410>
# 1773
# <Element 'sentence' at 0x7f0bfdb75490>
# 1854
# <Element 'sentence' at 0x7f0bfdb75510>
# 1511
# <Element 'sentence' at 0x7f0bfdb75610>
# 563
# <Element 'sentence' at 0x7f0bfdb75710>
# 2668
# <Element 'sentence' at 0x7f0bfdb75810>
# 1535
# <Element 'sentence' at 0x7f0bfdb759d0>
# 2991
# <Element 'sentence' at 0x7f0bfdb75ad0>
# 132
# <Element 'sentence' at 0x7f0bfdb75bd0>
# 1011
# <Element 'sentence' at 0x7f0bfdb75c50>
# 466
# <Element 'sentence' at 0x7f0bfdb75cd0>
# 208
# <Element 'sentence' at 0x7f0bfdb75dd0>
# 2314
# <Element 'sentence' at 0x7f0bfdb75ed0>
# 2552
# <Element 'sentence' at 0x7f0bfdb75f50>
# 634
# <Element 'sentence' at 0x7f0bfdb82090>
# 1926
# <Element 'sentence' at 0x7f0bfdb82210>
# 880
# <Element 'sentence' at 0x7f0bfdb82290>
# 721
# <Element 'sentence' at 0x7f0bfdb82310>
# 2849
# <Element 'sentence' at 0x7f0bfdb82390>
# 360
# <Element 'sentence' at 0x7f0bfdb82450>
# 1572
# <Element 'sentence' at 0x7f0bfdb824d0>
# 247
# <Element 'sentence' at 0x7f0bfdb82550>
# 2417
# <Element 'sentence' at 0x7f0bfdb82650>
# 1715
# <Element 'sentence' at 0x7f0bfdb826d0>
# 500
# <Element 'sentence' at 0x7f0bfdb82810>
# 859
# <Element 'sentence' at 0x7f0bfdb82910>
# 1504
# <Element 'sentence' at 0x7f0bfdb82a50>
# 2474
# <Element 'sentence' at 0x7f0bfdb82ad0>
# 158
# <Element 'sentence' at 0x7f0bfdb82bd0>
# 2421
# <Element 'sentence' at 0x7f0bfdb82c50>
# 2567
# <Element 'sentence' at 0x7f0bfdb82cd0>
# 1961
# <Element 'sentence' at 0x7f0bfdb82d90>
# 2879
# <Element 'sentence' at 0x7f0bfdb82e90>
# 946
# <Element 'sentence' at 0x7f0bfdb82f10>
# 1565
# <Element 'sentence' at 0x7f0bfdb8e050>
# 2854
# <Element 'sentence' at 0x7f0bfdb8e150>
# 2585
# <Element 'sentence' at 0x7f0bfdb8e2d0>
# 2692
# <Element 'sentence' at 0x7f0bfdb8e450>
# 1146
# <Element 'sentence' at 0x7f0bfdb8e4d0>
# 413
# <Element 'sentence' at 0x7f0bfdb8e550>
# 2634
# <Element 'sentence' at 0x7f0bfdb8e5d0>
# 2232
# <Element 'sentence' at 0x7f0bfdb8e650>
# 3018
# <Element 'sentence' at 0x7f0bfdb8e750>
# 49
# <Element 'sentence' at 0x7f0bfdb8e850>
# 2614
# <Element 'sentence' at 0x7f0bfdb8e8d0>
# 981
# <Element 'sentence' at 0x7f0bfdb8e950>
# 259
# <Element 'sentence' at 0x7f0bfdb8ea50>
# 2774
# <Element 'sentence' at 0x7f0bfdb8ead0>
# 2256
# <Element 'sentence' at 0x7f0bfdb8eb50>
# 1550
# <Element 'sentence' at 0x7f0bfdb8ebd0>
# 1721
# <Element 'sentence' at 0x7f0bfdb8ec50>
# 2146
# <Element 'sentence' at 0x7f0bfdb8ed90>
# 1399
# <Element 'sentence' at 0x7f0bfdb8ee90>
# 2400
# <Element 'sentence' at 0x7f0bfdb8efd0>
# 1917
# <Element 'sentence' at 0x7f0bfdb9c090>
# 1302
# <Element 'sentence' at 0x7f0bfdb9c190>
# 2815
# <Element 'sentence' at 0x7f0bfdb9c210>
# 534
# <Element 'sentence' at 0x7f0bfdb9c350>
# 429
# <Element 'sentence' at 0x7f0bfdb9c450>
# 978
# <Element 'sentence' at 0x7f0bfdb9c4d0>
# 2301
# <Element 'sentence' at 0x7f0bfdb9c5d0>
# 2087
# <Element 'sentence' at 0x7f0bfdb9c650>
# 2378
# <Element 'sentence' at 0x7f0bfdb9c750>
# 2722
# <Element 'sentence' at 0x7f0bfdb9c8d0>
# 1058
# <Element 'sentence' at 0x7f0bfdb9ca50>
# 2252
# <Element 'sentence' at 0x7f0bfdb9cb90>
# 2781
# <Element 'sentence' at 0x7f0bfdb9cc90>
# 927
# <Element 'sentence' at 0x7f0bfdb9cd90>
# 2293
# <Element 'sentence' at 0x7f0bfdb9ce10>
# 424
# <Element 'sentence' at 0x7f0bfdb9ce90>
# 2316
# <Element 'sentence' at 0x7f0bfdb9cf10>
# 2008
# <Element 'sentence' at 0x7f0bfdb9cf90>
# 1726
# <Element 'sentence' at 0x7f0bfdba9050>
# 2779
# <Element 'sentence' at 0x7f0bfdba90d0>
# 2955
# <Element 'sentence' at 0x7f0bfdba91d0>
# 2697
# <Element 'sentence' at 0x7f0bfdba9350>
# 1575
# <Element 'sentence' at 0x7f0bfdba93d0>
# 1007
# <Element 'sentence' at 0x7f0bfdba9450>
# 979
# <Element 'sentence' at 0x7f0bfdba94d0>
# 2357
# <Element 'sentence' at 0x7f0bfdba95d0>
# 1087
# <Element 'sentence' at 0x7f0bfdba96d0>
# 2529
# <Element 'sentence' at 0x7f0bfdba97d0>
# 2111
# <Element 'sentence' at 0x7f0bfdba98d0>
# 71
# <Element 'sentence' at 0x7f0bfdba9950>
# 1619
# <Element 'sentence' at 0x7f0bfdba99d0>
# 400
# <Element 'sentence' at 0x7f0bfdba9b50>
# 2628
# <Element 'sentence' at 0x7f0bfdba9bd0>
# 2212
# <Element 'sentence' at 0x7f0bfdba9cd0>
# 2153
# <Element 'sentence' at 0x7f0bfdba9dd0>
# 212
# <Element 'sentence' at 0x7f0bfdba9e90>
# 443
# <Element 'sentence' at 0x7f0bfdba9f90>
# 511
# <Element 'sentence' at 0x7f0bfdb35050>
# 194
# <Element 'sentence' at 0x7f0bfdb35150>
# 2620
# <Element 'sentence' at 0x7f0bfdb35250>
# 1593
# <Element 'sentence' at 0x7f0bfdb352d0>
# 83
# <Element 'sentence' at 0x7f0bfdb35350>
# 1299
# <Element 'sentence' at 0x7f0bfdb35450>
# 366
# <Element 'sentence' at 0x7f0bfdb35550>
# 2686
# <Element 'sentence' at 0x7f0bfdb35650>
# 368
# <Element 'sentence' at 0x7f0bfdb356d0>
# 784
# <Element 'sentence' at 0x7f0bfdb357d0>
# 647
# <Element 'sentence' at 0x7f0bfdb35850>
# 1496
# <Element 'sentence' at 0x7f0bfdb35a10>
# 2602
# <Element 'sentence' at 0x7f0bfdb35b50>
# 1450
# <Element 'sentence' at 0x7f0bfdb35cd0>
# 1410
# <Element 'sentence' at 0x7f0bfdb35dd0>
# 688
# <Element 'sentence' at 0x7f0bfdb35e50>
# 2097
# <Element 'sentence' at 0x7f0bfdb35f50>
# 527
# <Element 'sentence' at 0x7f0bfdb35fd0>
# 2665
# <Element 'sentence' at 0x7f0bfdb43090>
# 1795
# <Element 'sentence' at 0x7f0bfdb43190>
# 2230
# <Element 'sentence' at 0x7f0bfdb43210>
# 114
# <Element 'sentence' at 0x7f0bfdb43290>
# 2224
# <Element 'sentence' at 0x7f0bfdb43310>
# 3033
# <Element 'sentence' at 0x7f0bfdb43390>
# 1614
# <Element 'sentence' at 0x7f0bfdb434d0>
# 1003
# <Element 'sentence' at 0x7f0bfdb43550>
# 1392
# <Element 'sentence' at 0x7f0bfdb43650>
# 680
# <Element 'sentence' at 0x7f0bfdb436d0>
# 436
# <Element 'sentence' at 0x7f0bfdb43750>
# 697
# <Element 'sentence' at 0x7f0bfdb438d0>
# 1159
# <Element 'sentence' at 0x7f0bfdb439d0>
# 2757
# <Element 'sentence' at 0x7f0bfdb43b90>
# 232
# <Element 'sentence' at 0x7f0bfdb43c10>
# 2122
# <Element 'sentence' at 0x7f0bfdb43c90>
# 1508
# <Element 'sentence' at 0x7f0bfdb43d10>
# 278
# <Element 'sentence' at 0x7f0bfdb43e10>
# 2783
# <Element 'sentence' at 0x7f0bfdb43f10>
# 327
# <Element 'sentence' at 0x7f0bfdb51050>
# 2731
# <Element 'sentence' at 0x7f0bfdb511d0>
# 218
# <Element 'sentence' at 0x7f0bfdb51250>
# 5
# <Element 'sentence' at 0x7f0bfdb512d0>
# 1749
# <Element 'sentence' at 0x7f0bfdb514d0>
# 820
# <Element 'sentence' at 0x7f0bfdb51550>
# 245
# <Element 'sentence' at 0x7f0bfdb51650>
# 1979
# <Element 'sentence' at 0x7f0bfdb516d0>
# 202
# <Element 'sentence' at 0x7f0bfdb51750>
# 1142
# <Element 'sentence' at 0x7f0bfdb518d0>
# 1211
# <Element 'sentence' at 0x7f0bfdb51990>
# 2294
# <Element 'sentence' at 0x7f0bfdb51a10>
# 1583
# <Element 'sentence' at 0x7f0bfdb51a90>
# 2372
# <Element 'sentence' at 0x7f0bfdb51b10>
# 1438
# <Element 'sentence' at 0x7f0bfdb51d50>
# 1949
# <Element 'sentence' at 0x7f0bfdb51dd0>
# 2663
# <Element 'sentence' at 0x7f0bfdb51e50>
# 952
# <Element 'sentence' at 0x7f0bfdb51f50>
# 1858
# <Element 'sentence' at 0x7f0bfdb5f090>
# 2235
# <Element 'sentence' at 0x7f0bfdb5f210>
# 2825
# <Element 'sentence' at 0x7f0bfdb5f290>
# 514
# <Element 'sentence' at 0x7f0bfdb5f310>
# 1048
# <Element 'sentence' at 0x7f0bfdb5f610>
# 1729
# <Element 'sentence' at 0x7f0bfdb5f6d0>
# 1904
# <Element 'sentence' at 0x7f0bfdb5f750>
# 1182
# <Element 'sentence' at 0x7f0bfdb5f850>
# 2455
# <Element 'sentence' at 0x7f0bfdb5f990>
# 1213
# <Element 'sentence' at 0x7f0bfdb5fa50>
# 1394
# <Element 'sentence' at 0x7f0bfdb5fb10>
# 1924
# <Element 'sentence' at 0x7f0bfdb5fc50>
# 2268
# <Element 'sentence' at 0x7f0bfdb5fd10>
# 2171
# <Element 'sentence' at 0x7f0bfdb5fe50>
# 790
# <Element 'sentence' at 0x7f0bfdb5fed0>
# 552
# <Element 'sentence' at 0x7f0bfdb6d110>
# 1859
# <Element 'sentence' at 0x7f0bfdb6d1d0>
# 2589
# <Element 'sentence' at 0x7f0bfdb6d250>
# 2643
# <Element 'sentence' at 0x7f0bfdb6d2d0>
# 733
# <Element 'sentence' at 0x7f0bfdb6d3d0>
# 870
# <Element 'sentence' at 0x7f0bfdb6d450>
# 1910
# <Element 'sentence' at 0x7f0bfdb6d4d0>
# 2029
# <Element 'sentence' at 0x7f0bfdb6d550>
# 2242
# <Element 'sentence' at 0x7f0bfdb6d690>
# 2085
# <Element 'sentence' at 0x7f0bfdb6d790>
# 543
# <Element 'sentence' at 0x7f0bfdb6d890>
# 925
# <Element 'sentence' at 0x7f0bfdb6d990>
# 724
# <Element 'sentence' at 0x7f0bfdb6da10>
# 2139
# <Element 'sentence' at 0x7f0bfdb6da90>
# 1771
# <Element 'sentence' at 0x7f0bfdb6dbd0>
# 383
# <Element 'sentence' at 0x7f0bfdb6dc90>
# 2355
# <Element 'sentence' at 0x7f0bfdb6dd10>
# 2200
# <Element 'sentence' at 0x7f0bfdb6dd90>
# 723
# <Element 'sentence' at 0x7f0bfdb6de10>
# 2043
# <Element 'sentence' at 0x7f0bfdb6de90>
# 2258
# <Element 'sentence' at 0x7f0bfdb6df90>
# 1960
# <Element 'sentence' at 0x7f0bfdaf9110>
# 2006
# <Element 'sentence' at 0x7f0bfdaf9190>
# 2223
# <Element 'sentence' at 0x7f0bfdaf9290>
# 23
# <Element 'sentence' at 0x7f0bfdaf93d0>
# 2711
# <Element 'sentence' at 0x7f0bfdaf9550>
# 1899
# <Element 'sentence' at 0x7f0bfdaf95d0>
# 495
# <Element 'sentence' at 0x7f0bfdaf9650>
# 1606
# <Element 'sentence' at 0x7f0bfdaf97d0>
# 1018
# <Element 'sentence' at 0x7f0bfdaf98d0>
# 1761
# <Element 'sentence' at 0x7f0bfdaf9950>
# 554
# <Element 'sentence' at 0x7f0bfdaf99d0>
# 2728
# <Element 'sentence' at 0x7f0bfdaf9ad0>
# 1964
# <Element 'sentence' at 0x7f0bfdaf9c10>
# 2808
# <Element 'sentence' at 0x7f0bfdaf9ed0>
# 775
# <Element 'sentence' at 0x7f0bfdaf9fd0>
# 2424
# <Element 'sentence' at 0x7f0bfdb08110>
# 1689
# <Element 'sentence' at 0x7f0bfdb08210>
# 1894
# <Element 'sentence' at 0x7f0bfdb08290>
# 1078
# <Element 'sentence' at 0x7f0bfdb08390>
# 1492
# <Element 'sentence' at 0x7f0bfdb084d0>
# 808
# <Element 'sentence' at 0x7f0bfdb085d0>
# 1472
# <Element 'sentence' at 0x7f0bfdb086d0>
# 1038
# <Element 'sentence' at 0x7f0bfdb08810>
# 818
# <Element 'sentence' at 0x7f0bfdb08890>
# 861
# <Element 'sentence' at 0x7f0bfdb08910>
# 544
# <Element 'sentence' at 0x7f0bfdb08a50>
# 1959
# <Element 'sentence' at 0x7f0bfdb08b50>
# 315
# <Element 'sentence' at 0x7f0bfdb08c50>
# 2573
# <Element 'sentence' at 0x7f0bfdb08e10>
# 1996
# <Element 'sentence' at 0x7f0bfdb08f10>
# 509
# <Element 'sentence' at 0x7f0bfdb08f90>
# 1600
# <Element 'sentence' at 0x7f0bfdb14110>
# 719
# <Element 'sentence' at 0x7f0bfdb14290>
# 141
# <Element 'sentence' at 0x7f0bfdb143d0>
# 1920
# <Element 'sentence' at 0x7f0bfdb14450>
# 760
# <Element 'sentence' at 0x7f0bfdb14510>
# 193
# <Element 'sentence' at 0x7f0bfdb145d0>
# 1016
# <Element 'sentence' at 0x7f0bfdb14650>
# 507
# <Element 'sentence' at 0x7f0bfdb146d0>
# 1255
# <Element 'sentence' at 0x7f0bfdb147d0>
# 667
# <Element 'sentence' at 0x7f0bfdb14910>
# 1992
# <Element 'sentence' at 0x7f0bfdb14a50>
# 2430
# <Element 'sentence' at 0x7f0bfdb14b50>
# 2406
# <Element 'sentence' at 0x7f0bfdb14bd0>
# 1021
# <Element 'sentence' at 0x7f0bfdb14d10>
# 1209
# <Element 'sentence' at 0x7f0bfdb14d90>
# 1701
# <Element 'sentence' at 0x7f0bfdb14e90>
# 2570
# <Element 'sentence' at 0x7f0bfdb14f10>
# 287
# <Element 'sentence' at 0x7f0bfdb14f90>
# 681
# <Element 'sentence' at 0x7f0bfdb20050>
# 866
# <Element 'sentence' at 0x7f0bfdb200d0>
# 1248
# <Element 'sentence' at 0x7f0bfdb20190>
# 2857
# <Element 'sentence' at 0x7f0bfdb20210>
# 266
# <Element 'sentence' at 0x7f0bfdb202d0>
# 811
# <Element 'sentence' at 0x7f0bfdb203d0>
# 2693
# <Element 'sentence' at 0x7f0bfdb20450>
# 504
# <Element 'sentence' at 0x7f0bfdb20550>
# 1845
# <Element 'sentence' at 0x7f0bfdb20650>
# 434
# <Element 'sentence' at 0x7f0bfdb206d0>
# 2479
# <Element 'sentence' at 0x7f0bfdb20850>
# 1407
# <Element 'sentence' at 0x7f0bfdb20950>
# 1113
# <Element 'sentence' at 0x7f0bfdb20a90>
# 1976
# <Element 'sentence' at 0x7f0bfdb20b10>
# 1643
# <Element 'sentence' at 0x7f0bfdb20b90>
# 2431
# <Element 'sentence' at 0x7f0bfdb20c90>
# 905
# <Element 'sentence' at 0x7f0bfdb20d90>
# 2196
# <Element 'sentence' at 0x7f0bfdb20e90>
# 1878
# <Element 'sentence' at 0x7f0bfdb2f050>
# 758
# <Element 'sentence' at 0x7f0bfdb2f190>
# 1131
# <Element 'sentence' at 0x7f0bfdb2f2d0>
# 2052
# <Element 'sentence' at 0x7f0bfdb2f350>
# 1295
# <Element 'sentence' at 0x7f0bfdb2f490>
# 112
# <Element 'sentence' at 0x7f0bfdb2f590>
# 2123
# <Element 'sentence' at 0x7f0bfdb2f650>
# 190
# <Element 'sentence' at 0x7f0bfdb2f710>
# 2459
# <Element 'sentence' at 0x7f0bfdb2f790>
# 1665
# <Element 'sentence' at 0x7f0bfdb2f810>
# 1101
# <Element 'sentence' at 0x7f0bfdb2f950>
# 1948
# <Element 'sentence' at 0x7f0bfdb2fa10>
# 2340
# <Element 'sentence' at 0x7f0bfdb2fad0>
# 115
# <Element 'sentence' at 0x7f0bfdb2fc10>
# 196
# <Element 'sentence' at 0x7f0bfdb2fc90>
# 2332
# <Element 'sentence' at 0x7f0bfdb2fd90>
# 2687
# <Element 'sentence' at 0x7f0bfdb2fe10>
# 2633
# <Element 'sentence' at 0x7f0bfdb2fe90>
# 845
# <Element 'sentence' at 0x7f0bfdb2ff90>
# 1741
# <Element 'sentence' at 0x7f0bfdabb050>
# 2914
# <Element 'sentence' at 0x7f0bfdabb150>
# 2318
# <Element 'sentence' at 0x7f0bfdabb250>
# 153
# <Element 'sentence' at 0x7f0bfdabb350>
# 3071
# <Element 'sentence' at 0x7f0bfdabb3d0>
# 1415
# <Element 'sentence' at 0x7f0bfdabb4d0>
# 2946
# <Element 'sentence' at 0x7f0bfdabb5d0>
# 1380
# <Element 'sentence' at 0x7f0bfdabb650>
# 833
# <Element 'sentence' at 0x7f0bfdabb750>
# 2285
# <Element 'sentence' at 0x7f0bfdabb7d0>
# 2148
# <Element 'sentence' at 0x7f0bfdabb850>
# 2106
# <Element 'sentence' at 0x7f0bfdabb990>
# 2595
# <Element 'sentence' at 0x7f0bfdabba90>
# 584
# <Element 'sentence' at 0x7f0bfdabbb10>
# 2244
# <Element 'sentence' at 0x7f0bfdabbb90>
# 1966
# <Element 'sentence' at 0x7f0bfdabbc90>
# 991
# <Element 'sentence' at 0x7f0bfdabbd10>
# 617
# <Element 'sentence' at 0x7f0bfdabbe10>
# 2168
# <Element 'sentence' at 0x7f0bfdabbf10>
# 1765
# <Element 'sentence' at 0x7f0bfdacb090>
# 778
# <Element 'sentence' at 0x7f0bfdacb1d0>
# 1215
# <Element 'sentence' at 0x7f0bfdacb250>
# 195
# <Element 'sentence' at 0x7f0bfdacb2d0>
# 1
# <Element 'sentence' at 0x7f0bfdacb390>
# 1707
# <Element 'sentence' at 0x7f0bfdacb4d0>
# 530
# <Element 'sentence' at 0x7f0bfdacb550>
# 2553
# <Element 'sentence' at 0x7f0bfdacb690>
# 1485
# <Element 'sentence' at 0x7f0bfdacb7d0>
# 666
# <Element 'sentence' at 0x7f0bfdacb850>
# 2672
# <Element 'sentence' at 0x7f0bfdacb950>
# 1258
# <Element 'sentence' at 0x7f0bfdacbad0>
# 375
# <Element 'sentence' at 0x7f0bfdacbb50>
# 63
# <Element 'sentence' at 0x7f0bfdacbc50>
# 3048
# <Element 'sentence' at 0x7f0bfdacbd90>
# 1552
# <Element 'sentence' at 0x7f0bfdacbe90>
# 2598
# <Element 'sentence' at 0x7f0bfdacbf10>
# 2112
# <Element 'sentence' at 0x7f0bfdad8090>
# 461
# <Element 'sentence' at 0x7f0bfdad8110>
# 2823
# <Element 'sentence' at 0x7f0bfdad8210>
# 2249
# <Element 'sentence' at 0x7f0bfdad8290>
# 1582
# <Element 'sentence' at 0x7f0bfdad8410>
# 1141
# <Element 'sentence' at 0x7f0bfdad8490>
# 2140
# <Element 'sentence' at 0x7f0bfdad8590>
# 1786
# <Element 'sentence' at 0x7f0bfdad8610>
# 2023
# <Element 'sentence' at 0x7f0bfdad8690>
# 351
# <Element 'sentence' at 0x7f0bfdad8710>
# 1389
# <Element 'sentence' at 0x7f0bfdad8790>
# 2545
# <Element 'sentence' at 0x7f0bfdad8810>
# 908
# <Element 'sentence' at 0x7f0bfdad8910>
# 867
# <Element 'sentence' at 0x7f0bfdad8990>
# 2898
# <Element 'sentence' at 0x7f0bfdad8a90>
# 29
# <Element 'sentence' at 0x7f0bfdad8bd0>
# 2561
# <Element 'sentence' at 0x7f0bfdad8d50>
# 2376
# <Element 'sentence' at 0x7f0bfdad8dd0>
# 1560
# <Element 'sentence' at 0x7f0bfdad8e50>
# 2461
# <Element 'sentence' at 0x7f0bfdad8ed0>
# 1039
# <Element 'sentence' at 0x7f0bfdad8fd0>
# 1519
# <Element 'sentence' at 0x7f0bfdae6090>
# 2380
# <Element 'sentence' at 0x7f0bfdae61d0>
# 2172
# <Element 'sentence' at 0x7f0bfdae6250>
# 349
# <Element 'sentence' at 0x7f0bfdae6350>
# 2255
# <Element 'sentence' at 0x7f0bfdae63d0>
# 1309
# <Element 'sentence' at 0x7f0bfdae6510>
# 2299
# <Element 'sentence' at 0x7f0bfdae65d0>
# 712
# <Element 'sentence' at 0x7f0bfdae6710>
# 872
# <Element 'sentence' at 0x7f0bfdae6790>
# 1109
# <Element 'sentence' at 0x7f0bfdae6810>
# 389
# <Element 'sentence' at 0x7f0bfdae6890>
# 506
# <Element 'sentence' at 0x7f0bfdae6990>
# 1175
# <Element 'sentence' at 0x7f0bfdae6a90>
# 1049
# <Element 'sentence' at 0x7f0bfdae6b90>
# 233
# <Element 'sentence' at 0x7f0bfdae6c10>
# 265
# <Element 'sentence' at 0x7f0bfdae6d10>
# 394
# <Element 'sentence' at 0x7f0bfdae6ed0>
# 152
# <Element 'sentence' at 0x7f0bfdae6fd0>
# 143
# <Element 'sentence' at 0x7f0bfdaf40d0>
# 1656
# <Element 'sentence' at 0x7f0bfdaf4150>
# 1402
# <Element 'sentence' at 0x7f0bfdaf41d0>
# 1284
# <Element 'sentence' at 0x7f0bfdaf42d0>
# 1317
# <Element 'sentence' at 0x7f0bfdaf4350>
# 1636
# <Element 'sentence' at 0x7f0bfdaf43d0>
# 409
# <Element 'sentence' at 0x7f0bfdaf4450>
# 2131
# <Element 'sentence' at 0x7f0bfdaf44d0>
# 2228
# <Element 'sentence' at 0x7f0bfdaf4550>
# 1797
# <Element 'sentence' at 0x7f0bfdaf4650>
# 2272
# <Element 'sentence' at 0x7f0bfdaf48d0>
# 479
# <Element 'sentence' at 0x7f0bfdaf4950>
# 2657
# <Element 'sentence' at 0x7f0bfdaf49d0>
# 618
# <Element 'sentence' at 0x7f0bfdaf4a50>
# 1207
# <Element 'sentence' at 0x7f0bfdaf4b10>
# 848
# <Element 'sentence' at 0x7f0bfdaf4c50>
# 734
# <Element 'sentence' at 0x7f0bfdaf4d50>
# 230
# <Element 'sentence' at 0x7f0bfdaf4dd0>
# 2194
# <Element 'sentence' at 0x7f0bfdaf4e50>
# 611
# <Element 'sentence' at 0x7f0bfdaf4ed0>
# 1195
# <Element 'sentence' at 0x7f0bfdaf4f50>
# 2893
# <Element 'sentence' at 0x7f0bfdaf4fd0>
# 1712
# <Element 'sentence' at 0x7f0bfda82090>
# 2982

# %%
sentences_list[1]
# Out:
# 'I bought a HP Pavilion DV4-1222nr laptop and have had so many problems with the computer.'

# %%
def get_aspects_new(path):
    tree=ET.parse(path)
    root = tree.getroot()
    text_list = []
    id_list=[]
    new_list=[]
    sentences_list=[]
    opinion_list = []
    c=0
    for review in root.findall('./sentence/aspectTerms'):
                #print(c)
                text_string=""
                opinion_inner_list=[]
                #or sent in review.findall('./sentences/sentence'):
                #print(sent)
                #ids=review.attrib['aspec]
                #print(ids)
                #id_list.append(ids)
                for i in review.findall('aspectTerm'):
                    #print(i)
                    am=i.attrib['term']
                    am=am.split(" ")
                    print(am)
                    for i in am:
                        new_list.append(i)
    
                    

    return new_list
aspect_list = get_aspects_new("/home/vibha/Laptops_Train.xml")
# Out:
# ['cord']
# ['battery', 'life']
# ['service', 'center']
# ['"sales"', 'team']
# ['tech', 'guy']
# ['quality']
# ['GUI']
# ['applications']
# ['use']
# ['start', 'up']
# ['features']
# ['iChat']
# ['Photobooth']
# ['garage', 'band']
# ['features']
# ['GUI']
# ['screen']
# ['power', 'light']
# ['hard', 'drive', 'ligh']
# ['processor']
# ['graphics', 'cards']
# ['battery', 'life']
# ['battery']
# ['rubber', 'enclosure']
# ['edge']
# ['multi-touch', 'gestures']
# ['tracking', 'area']
# ['external', 'mouse']
# ['gaming']
# ['suite', 'of', 'software']
# ['speed']
# ['Windows', '7']
# ['usb', 'devices']
# ['keyboard']
# ['software']
# ['system']
# ['Microsoft', 'office', 'for', 'the', 'mac']
# ['syncing']
# ['30"', 'HD', 'Monitor']
# ['screen']
# ['boot', 'up']
# ['service']
# ['battery']
# ['operating', 'system']
# ['preloaded', 'software']
# ['price']
# ['features']
# ['clock', 'in', 'BIOS', 'setup']
# ['WARRANTY', 'SERVICE']
# ['brand']
# ['warranty']
# ['features']
# ['fan']
# ['Customer', 'Service', 'number']
# ['warranty']
# ['talking', 'to', 'a', 'technician']
# ['hard', 'disc']
# ['windows']
# ['drivers']
# ['Drivers']
# ['BIOS', 'update']
# ['system']
# ['HP', 'Technical', 'Support']
# ['browser']
# ['keyboard']
# ['virus', 'scan']
# ['9', 'punds']
# ['program']
# ['warrenty']
# ['Toshiba', 'Warranty']
# ['Quality']
# ['webcam']
# ['value']
# ['internet']
# ['managing', 'personal', 'files']
# ['motherboard']
# ['system']
# ['charger']
# ['hardware']
# ['force', 'quit']
# ['works']
# ['Windows', '7']
# ['VMWare', 'program']
# ['operating', 'system']
# ['runs']
# ['navigate']
# ['find', 'files']
# ['warrenty']
# ['extended', 'warranty']
# ['memory']
# ['speed']
# ['performace']
# ['opening', 'my', 'Documents', 'folder']
# ['operating', 'systems']
# ['charger']
# ['speed']
# ['glass', 'touchpad']
# ['hard', 'drive']
# ['mother', 'board']
# ['external', 'speaker']
# ['sound']
# ['battery', 'life']
# ['hardware']
# ['shipping']
# ['Mac', 'software']
# ['Microsoft', 'software']
# ['use']
# ['delete', '', 'key']
# ['editing']
# ['use']
# ['service']
# ['phone', 'assistance']
# ['genius', 'bar']
# ['battery', 'life']
# ['battery', 'life']
# ['gaming']
# ['movie', 'playing']
# ['web', 'browsing']
# ['word', 'editing']
# ['recovery', 'discs']
# ['Office', "Max's", '"Max', 'Assurance"']
# ['iMac', 'backup', 'disc']
# ['USB']
# ['battery', 'life']
# ['battery', 'timer']
# ['Temperatures']
# ['Core', 'Processing', 'Unit', 'temperatures']
# ['service']
# ['virus', 'protection', 'for', 'Mac']
# ['bluetooth']
# ['LG', 'notebook', 'service', 'center']
# ['hinge']
# ['games']
# ['responds']
# ['motherboard']
# ['motherboard']
# ['hardware']
# ['motherboard']
# ['use']
# ['representive', 'at', 'Microsoft']
# ['system']
# ['XP']
# ['WIndows', '7']
# ['Vista']
# ['Keyboard']
# ["Dell's", 'customer', 'disservice']
# ['cooling', 'system']
# ['use']
# ['quad', 'core', 'I7']
# ['sales', 'associate']
# ['system']
# ['Windows', 'applications']
# ['virus', 'program']
# ['weighed']
# ['seven', 'pounds']
# ['battery']
# ['bag']
# ['color']
# ['keys']
# ['designed']
# ['style']
# ['speed']
# ['keyboard']
# ['mousepad']
# ['battery']
# ['sales']
# ['service']
# ['DELL', 'SUPPORT']
# ['hard', 'drive']
# ['motherboard']
# ['speed']
# ['construction', 'quality']
# ['longevity']
# ['cost']
# ['keyboard']
# ['keys']
# ['configuration', 'of', '"extra', 'key"']
# ['touch', 'pad']
# ['use']
# ['security']
# ['pricetag']
# ['use']
# ['work']
# ['preloaded', 'software']
# ['webcam']
# ['vga', 'port']
# ['screen']
# ['battery', 'life']
# ['keys']
# ['software']
# ['volume']
# ['mouse']
# ['touchpad']
# ['boots', 'up']
# ['hard', 'drive']
# ['look', 'and', 'feel', 'standpoint']
# ['safari']
# ['safari']
# ['Mozzilla', 'firfox']
# ['Bluetooth']
# ['fingerprint', 'reader', 'driver']
# ['software']
# ['battery']
# ['speed']
# ['display']
# ['delivery']
# ['battery', 'life']
# ['performance']
# ['memory']
# ['applications']
# ['Microsoft', 'office']
# ['Resolution']
# ['appearance']
# ['cooling', 'system']
# ['graphics', 'card']
# ['built-in', 'webcam']
# ['built-in', 'mic']
# ['cam']
# ['mic']
# ['Windows', 'Vista']
# ['board']
# ['connector']
# ['power', 'supply']
# ['warrenty']
# ['power', 'supply']
# ['ethernet']
# ['works']
# ['drag', 'and', 'drop', 'feature']
# ['webcam']
# ['sales', 'tax']
# ['software', 'packages']
# ['iWork']
# ['GarageBand']
# ['iMovie']
# ['screen']
# ['colors']
# ['resolution']
# ['monitor']
# ['iTunes']
# ['Size']
# ['external', 'monitor']
# ['base', 'installation']
# ['software']
# ['manuf']
# ['camera']
# ['display']
# ['AMD', 'Turin', 'processor']
# ['Intel']
# ['warranty']
# ['start', 'menu']
# ['navigate']
# ['bluray', 'read/write', 'drive']
# ['service', 'tech']
# ['tech', 'store']
# ['surface']
# ['screen']
# ['keyboard']
# ['iLife']
# ['Snow', 'Leopard', 'X']
# ['price', 'tag']
# ['Mac', 'OS']
# ['sound', 'output', 'quality']
# ['techie']
# ['use']
# ['Toshiba', 'online', 'help']
# ['service', 'life']
# ['ports']
# ['processor']
# ['price']
# ['look']
# ['keyboard']
# ['keys']
# ['screen']
# ['quality']
# ['stock', 'screen']
# ['gray', 'color']
# ['volume', 'buttons']
# ['processor']
# ['computing']
# ['protector']
# ['key', 'pad']
# ['magnetic', 'plug-in', 'power', 'charging', 'power', 'cord']
# ['XP']
# ['Vista']
# ['graphics']
# ['use']
# ['Mac', 'OS']
# ['use']
# ['support']
# ['Geek', 'Squad']
# ['graphics', 'quality']
# ['Appleworks']
# ['browser']
# ['paint']
# ['keyboard']
# ['service', 'department']
# ['warrenty']
# ['warrentys']
# ['hard', 'disk']
# ['CD', 'drive']
# ['running']
# ['screen', 'size']
# ['web', 'browsing']
# ['software']
# ['loads']
# ['trackpad']
# ['external', 'mouse']
# ['trackpad']
# ['games']
# ['features']
# ['human', 'interface']
# ['inbuilt', 'applications']
# ['Software']
# ['body']
# ['i5']
# ['antivirus', 'software']
# ['firewall']
# ['price']
# ['Apple', 'team']
# ['Vista']
# ['Vista']
# ['operating', 'system']
# ['Vista']
# ['video', 'chat']
# ['quality']
# ['mouse']
# ['Fan']
# ['cooling', 'pad']
# ['feature']
# ['software']
# ['installation', 'time']
# ['power']
# ['storage']
# ['abilitiy']
# ['spotlight', 'search']
# ['feature']
# ['wireless', 'system']
# ['Windows', '7']
# ['quality']
# ['battery', 'life']
# ['speed']
# ['OS']
# ['OS']
# ['iTunes']
# ['program']
# ['gaming']
# ['battery']
# ['Apple', 'support']
# ['techs']
# ['adding', 'the', 'bluetooth']
# ['graphic', 'power']
# ['Adobe', 'Creative', 'apps']
# ['programs']
# ['use']
# ['materials']
# ['software']
# ['Tech', 'support']
# ['power', 'supply']
# ['POWER', 'SUPPLY']
# ['size']
# ['warranty']
# ['Windows', 'XP', 'SP2']
# ['Windows', '7', 'Ultimate']
# ['Bluetooth']
# ['Fingerprint', 'reader']
# ['software']
# ['techs', 'at', 'HP']
# ['video', 'card']
# ['graphics']
# ['security']
# ['audio']
# ['keyboard']
# ['runs']
# ['set', 'up']
# ['screen']
# ['word', 'processing']
# ['internet']
# ['trackpad']
# ['battery', 'life']
# ['spec']
# ['HD']
# ['graphics', 'chip']
# ['components']
# ['DVD', 'burner']
# ['USB', 'ports']
# ['software']
# ['system']
# ['ran']
# ['price']
# ['operation']
# ['brand']
# ['components']
# ['ground', 'loop', 'isolator']
# ['price', 'range']
# ['quality']
# ['warranty']
# ['leading', 'edge']
# ['bloatware']
# ['Maximum', 'sound']
# ['windows', '7']
# ['Bootcamp']
# ['price']
# ['action', 'pack', 'games']
# ['works']
# ['price']
# ['performance']
# ['twin', 'packing']
# ['functions']
# ['after', 'sales', 'support']
# ['look']
# ['display', 'screen']
# ['acer', 'arcade']
# ['customer', 'support']
# ['screen']
# ['cd', 'drive']
# ['runs']
# ['design']
# ['size']
# ['games']
# ['games']
# ['life']
# ['warranty']
# ['pad']
# ['value']
# ['price']
# ['system', 'performance']
# ['linux', 'based', 'os']
# ['use']
# ['batteries']
# ['shipping', 'carton']
# ['use']
# ['program']
# ['virus', 'protection']
# ['screen']
# ['processor']
# ['OSX', '16']
# ['graphics']
# ['hardware']
# ['software']
# ['Intel', 'Core', 'processors']
# ['HDMI', 'port']
# ['Internet', 'Explorer']
# ['staff']
# ['price', 'premium']
# ['features']
# ['product', 'and', 'help', 'aftermarket']
# ['Microsoft', 'word']
# ['usb', 'ports']
# ['sd', 'memory', 'card', 'reader']
# ['sd', 'memory', 'car', 'expansion']
# ['LaCie', '2Big', 'external', 'drive']
# ['firewire', '800', 'interface']
# ['Time', 'Machine']
# ['sound']
# ['extra', 'features']
# ['windows', '7', 'home', 'premium']
# ['Acer', 'screen']
# ['USB', 'port']
# ['boot']
# ['battery', 'life']
# ['fires', 'up']
# ['keyboard']
# ['software']
# ['online', 'tutorial', 'videos']
# ['image']
# ['soud']
# ['windows']
# ['boot', 'up']
# ['shut', 'down']
# ['windows']
# ['Mac', 'OS']
# ['use']
# ['cost']
# ['Windows', '7', 'Starter']
# ['Windows', '7', 'Home', 'Premium']
# ['Windows', '7', 'Professional']
# ['specifications']
# ['power', 'cords']
# ['multi-touch', 'features']
# ['screen']
# ['clicking', 'buttons']
# ['battery', 'life']
# ['Windows']
# ['wired', 'lan']
# ['hard', 'reboot']
# ['hardware']
# ['hard', 'drive']
# ['battery', 'life']
# ['Apple', 'care']
# ['font']
# ['Features']
# ['programs']
# ['run']
# [u'plastic\xa0pieces']
# ['2GB', 'RAM', 'stick']
# ['Windows']
# ['Microsoft', 'Word', 'for', 'Mac']
# ['WARRANTY', 'COMPANY']
# ['cusromer', 'service', 'center']
# ['size']
# ['weight']
# ['battery']
# ['aluminum', 'body']
# ['watching', 'movies']
# ['playing']
# ['build', 'quality']
# ['performance']
# ['dock']
# ['program']
# ['program']
# ['working']
# ['costing']
# ['price']
# ['i7']
# ['monitor']
# ['extended', 'warranty']
# ['Boots', 'up']
# ['runs']
# ['screen']
# ['driver']
# ['tech', 'support']
# ['work']
# ['hard', 'drive']
# ['twin', 'packing']
# ['functions']
# ['warranty']
# ['performance']
# ['price']
# ['BIOS']
# ['design']
# ['tech', 'issues']
# ['size']
# ['space']
# ['service']
# ['memory']
# ['speed']
# ['priced']
# ['internet', 'speed']
# ['programs']
# ['Garageband']
# ['Photo', 'Booth']
# ['iPhoto']
# ['iMovie']
# ['video-editing']
# ['movie-making']
# ['photo', 'management']
# ['music']
# ['Pages']
# ['Numbers']
# ['Keynote']
# ['school', 'or', 'office', 'use']
# ['screen']
# ['colors']
# ['value']
# ['price']
# ['value']
# ['web', 'cam']
# ['burn', "cd's"]
# ['17', 'inch', 'screen']
# ['support']
# ['Bluetooth']
# ['Drivers/Applications', 'DVD']
# ['Launch', 'Manager']
# ['glass', 'screen']
# ['switchable', 'graphic', 'card']
# ['gaming']
# ['service']
# ['battery', 'life']
# ['technical', 'support']
# ['BOOT', 'MGR']
# ['recovery', 'cd']
# ['price']
# ['features']
# ['Skype']
# ['mouse', 'buttons']
# ['HDD']
# ['rails']
# ['hard', 'drive']
# ['quality']
# ['staff']
# ['Games']
# ['GarageBand']
# ['warranty']
# ['hard', 'drive']
# ['price']
# ['home', 'use']
# ['business', 'use']
# ['virus', 'protection']
# ['updates']
# ['MS', 'Office', 'apps']
# ['feature']
# ['Windows']
# ['games']
# ['battery', 'life']
# ['battery', 'life']
# ['price']
# ['Nortons', 'virus', 'scan']
# ['frame']
# ['features']
# ['use']
# ['loaded']
# ['Windows', '7']
# ['Vista']
# ['Vista']
# ['windows']
# ['Windows', 'XP']
# ['Vista']
# ['key', 'broad']
# ['warranty']
# ['repair', '"depot"']
# ['school', 'use']
# ['design']
# ['battery', 'life']
# ['programs']
# ['Wireless']
# ['battery', 'life']
# ['programs']
# ['trackpad']
# ['programs']
# ['navigating']
# ['speakers']
# ['subwoofer']
# ['built', 'in', 'camera']
# ['price']
# ['warranty']
# ['left', 'mouse', 'key']
# ['costed']
# ['speed']
# ['hard', 'drive', 'space']
# ['picture']
# ['extended', 'warranty']
# ['extended', 'warranties']
# ['battery']
# ['Screen']
# ['battery', 'life']
# ['appearance']
# ['technical', 'service', 'for', 'dell']
# ['graphics']
# ['warranty']
# ['battery']
# ['case']
# ['performance']
# ['price']
# ['look']
# ['applications']
# ['speed']
# ['tech', 'support']
# ['gaming']
# ['use']
# ['Photoshop']
# ['ram']
# ['system', 'clock']
# ['RAM']
# ['securitysoftware']
# ['driver', 'updates']
# ['Windows']
# ['work']
# ['works']
# ['HD']
# ['HD']
# ['graphics', 'card']
# ['built', 'in', 'camera']
# ['DVD', 'burner']
# ['DVD', 'burner']
# ['works']
# ['15', 'inch']
# ['Product', 'support']
# ['screen']
# ['use']
# ['casing', 'of', 'the', 'power', 'cord']
# ['internet', 'signals']
# ['price']
# ['right', 'speaker']
# ['price', 'tag']
# ['software']
# ['updates']
# ['multiple', 'page', 'viewer']
# ['shipped']
# ['Keyboard']
# ['use']
# ['warranty']
# ['quality']
# ['features']
# ['recovery', 'disk']
# ['features']
# ['programs']
# ['Office']
# ['Office', 'programs']
# ['wifi']
# ['TYPING']
# ['screen']
# ['temp']
# ['Windows', 'operating', 'system']
# ['OS']
# ['processor', 'speed']
# ['thunderbolt', 'port']
# ['lcd', 'screen']
# ['Images']
# ['windows', 'vista']
# ['windows', 'xp']
# ['Vista']
# ['Adobe', 'Flash', 'player']
# ['Internet', 'Explore']
# ['Windows', 'update']
# ['update']
# ['switch']
# ['switch']
# ['4GB', 'stick', 'of', 'RAM']
# ['hardrive']
# ['touch', 'control', 'buttons']
# ['keyboard']
# ['performance']
# ['iLife', 'software']
# ['iPhoto']
# ['iMovie']
# ['iWeb']
# ['iTunes']
# ['GarageBand']
# ['runs']
# ['system', 'board']
# ['size']
# ['software']
# ['hardware']
# ['memory']
# ['hard', 'drive']
# ['graphics']
# ['programs']
# ['navigation']
# ['hinge']
# ['LCD']
# ['DELL', 'Customer', 'Service']
# ['RMA', 'service']
# ['Design']
# ['keyboard']
# ['battery', 'life']
# ['screen/video', 'resolution']
# ['resolution']
# ['applications']
# ['Dreamweaver']
# ['Final', 'Cut', 'Pro', '7']
# ['Photoshop']
# ['Safari']
# ['Firefox']
# ['MSN', 'Messenger']
# ['warrenty']
# ['tech', 'support']
# ['Apple', 'applications']
# ['iPhoto']
# ['gigs']
# ['memory']
# ['17-inch', 'screen']
# ['DVD']
# ['CD', 'burners']
# ['web', 'browsing']
# ['uploading', 'photos']
# ['watching', 'movies']
# ['creating', 'presentations']
# ['Quality', 'Display']
# ['weight']
# ['12', 'cell', 'battery']
# ['case']
# ['power', 'adapter', 'plug']
# ['features']
# ['speakers']
# ['screen']
# ['TAB']
# ['extended', 'warrenty']
# ['TFT', 'panel']
# ['Navigation']
# ['Windows', 'operating', 'systems']
# ['screen']
# ['screen', 'size']
# ['bulk']
# ['music', 'software']
# ['software']
# ['picture']
# ['video']
# ['combined', 'touch', 'pad', 'and', 'clicker']
# ['Unibody', 'construction']
# ['value']
# ['Windows']
# ['screen', 'hinges']
# ['BATTERY']
# ['STORAGE', 'LIFE']
# ['SERVICE']
# ['storage']
# ['ram']
# ['Nvidia', 'chipset']
# ['extended', 'warranty']
# ['Programs']
# ['CHARGE', 'TIME']
# ['size']
# ['consistancy']
# ['key', 'bindings']
# ['Keyboard']
# ['size']
# ['10-key']
# ['Fan']
# ['fan']
# ['screen']
# ['operating', 'system']
# ['processor']
# ['500gb', 'hard', 'drive']
# ['feature']
# ['tech', 'support']
# ['USB', 'output']
# ['wireless', 'mouse']
# ['size']
# ['screen']
# ['Windows']
# ['Linux']
# ['windows', 'disc']
# ['quality']
# ['touchpad']
# ['video', 'card']
# ['touch', 'pad']
# ['external', 'mouse']
# ['set', 'up']
# ['video']
# ['value']
# ['hard', 'drive']
# ['runs']
# ['loads']
# ['warranty']
# ['program']
# ['disk', 'throughput']
# ['spinning', 'beachball']
# ['wireless', 'internet', 'access']
# ['value']
# ['ran']
# ['battery']
# ['company']
# ['screen', 'resolutions']
# ['carry']
# ['keyboard']
# ['edges']
# ['programs']
# ['ILife']
# ['iPhotos']
# ['processor']
# ['fan']
# ['motherboard']
# ['built']
# ['performance']
# ['screen', 'resolution']
# ['Snow', 'Leopard']
# ['CPU']
# ['Office', 'Mac', 'applications']
# ['Word']
# ['Excel']
# ['spinning', 'wheel']
# ['pad']
# ['keyboard']
# ['screen']
# ['Windows', '7']
# ['programs']
# ['iLife']
# ['iWork']
# ['18.4"', 'screen']
# ['battery', 'life']
# ['regular', 'layout', 'keyboard']
# ['Runs']
# ['programs']
# ['windows']
# ['recovery', 'discs']
# ['Windows', '7', 'Starter']
# ['Support']
# ['warranty']
# ['online', 'chat', 'service']
# ['iPhoto']
# ['works']
# ['battery']
# ['quality']
# ['VHS']
# ['use']
# ['navigate']
# ['battery', 'life']
# ['battery']
# ['USB', 'ports']
# ['battery']
# ['design']
# ['quality']
# ['Mac', 'version', 'of', 'Microsoft', 'Office']
# ['starting-up', 'time']
# ['operates']
# ['touch', 'pad']
# ['touch', 'pad']
# ['pictures']
# ['transporting']
# ['gaming']
# ['network', 'capability']
# ['wifi', 'card']
# ['printer']
# ['use']
# ['OS', 'X']
# ['repair', 'service']
# ['customer', 'service', 'agents']
# ['Photoshop']
# ['AfterEffects', 'programs']
# ['runs']
# ['warrenty']
# ['look']
# ['dependability']
# ['company']
# ['warranty']
# ['features']
# ['mouse', 'button']
# ['performance']
# ['touchpad']
# ['buttons']
# ['programs']
# ['space']
# ['keyboard']
# ['battery']
# ['keyboard']
# ['battery', 'life']
# ['hard', 'drive']
# ['windows', '7']
# ['processor']
# ['applications']
# ['load']
# ['webpages']
# ['battery']
# ['boot']
# ['Windows']
# ['runs']
# ['OpenOffice']
# ['Firefox']
# ['price']
# ['quality']
# ['performance']
# ['battery', 'life']
# ['use']
# ['PRODUCT', 'KEY']
# ['specs']
# ['bluetooth']
# ['feature']
# ['one', 'touch', 'keys']
# ['battery', 'life']
# ['keyboard']
# ['speed']
# ['specs']
# ['price']
# ['Delivery']
# ['stability']
# ['Mac', 'software']
# ['operating', 'system']
# ['SATA', 'controller']
# ['video', 'editing']
# ['performance']
# ['mobile', 'video', 'editing']
# ['imovie', 'program']
# ['processor']
# ['ram']
# ['battery']
# ['price']
# ['designed']
# ['warranty']
# ['bluetooth', 'mouse']
# ['features']
# ['Keyboard']
# ['control', 'buttons']
# ['Screen']
# ['motherboard']
# ['motherboard']
# ['Processor']
# ['performance']
# ['motherboard']
# ['patches']
# ['speed']
# ['system', 'memory']
# ['radeon', '5850']
# ['DDR5']
# ['DDR3']
# ['programs']
# ['programs']
# ['speed']
# ['size']
# ['OS', '(Vista)']
# ['software']
# ['battery', 'life']
# ['battery', 'life']
# ['extended', 'warranty']
# ['features']
# ['programs']
# ['use']
# ['pop', 'up', 'windows']
# ['web', 'programming', 'software']
# ['pop', 'ups']
# ['Memory']
# ['3G', 'network']
# ['Web', 'access']
# ['screen']
# ['design', 'based', 'programs']
# ['Adobe', 'Creative', 'Suite']
# ['companies']
# ['customer', 'service']
# ['plug']
# ['HDD', 'cover']
# ['applications']
# ['design']
# ['keyboard']
# ['iphoto']
# ['program']
# ['screen']
# ['Spy', 'ware']
# ['Nortell']
# ['videocard']
# ['price']
# ['drivers']
# ['speakers']
# ['keyboard']
# ['use']
# ['Setting']
# ['screen', 'size']
# ['pixel', 'sizes']
# ['pre', 'installed', 'software', 'update']
# ['customer', 'services']
# ['toshiba', 'customer', 'services']
# ['space', 'bar']
# ['iPhotos']
# ['program']
# ['performing']
# ['software']
# ['software']
# ['booting']
# ['programs']
# ['iphoto']
# ['imail']
# ['imovie']
# ['software']
# ['use']
# ['transport']
# ['repair', 'depot']
# ['price']
# ['specs']
# ['cd', 'drive']
# ['hard', 'disk', 'capacity']
# ['Keys']
# ['trackpad']
# ['design']
# ['OS']
# ['shipping']
# ['gaming', 'look']
# ['gaming', 'performance']
# ['hard', 'drive']
# ['cost']
# ['volume', 'control']
# ['boot', 'up']
# ['shut', 'down']
# ['price']
# ['internet', 'connectivity']
# ['USB', 'wireless', 'card']
# ['sound']
# ['cost']
# ['discharges']
# ['compatibility']
# ['charging']
# ['stand']
# ['design']
# ['heat', 'sink']
# ['Webcam']
# ['trend', 'micro']
# ['antiviral', 'program']
# ['warrenty']
# ['plastic', 'piece']
# ['usb', 'port', 'wires']
# ['case', 'design']
# ['connection']
# ['pricing']
# ['built-in', 'wireless']
# ['screen', 'size']
# ['processing', 'power']
# ['applications']
# ['screen']
# ['programs']
# ['graphics']
# ['graphics']
# ['Vista']
# ['programs']
# ['install']
# [u'uninstall\xa0']
# ['screen']
# ['keyboard']
# ['mouse']
# ['noise']
# ['IWORKS']
# ['Itunes']
# ['MS', 'Office']
# ['performance']
# ['iWork']
# ['software']
# ['price']
# ['BIOS']
# ['Windows']
# ['application']
# ['OS', 'X']
# ['Boot', 'Camp']
# ['Windows']
# ['mousepad']
# ['Windows', '7']
# ['Applecare']
# ['extended', 'warranty']
# ['windows']
# ['programs']
# ['cad', 'programs']
# ['bootcamp']
# ['memory']
# ['operation']
# ['use']
# ['tutorials']
# ['mouse', 'pad']
# ['right', 'click', 'key']
# ['battery']
# ['full', 'charge']
# ['cordless', 'mouse']
# ['runs']
# ['Toshiba', 'tech', 'support']
# ['techs']
# ['charged']
# ['USB', 'ports']
# ['tech', 'support']
# ['online', 'chat']
# ['Keyboard']
# ['color']
# ['keyboard']
# ['speaker', 'grill']
# ['buttons']
# ['USB', 'ports']
# ['full', 'service']
# ['warranty']
# ['letter', 'A']
# ['after', 'sales', 'service.']
# ['software']
# ['works']
# ['recovey', 'disk']
# ['recovery', 'disk']
# ['speed']
# ['capacity']
# ['build']
# ['price']
# ['iTunes']
# ['portability']
# ['battery', 'life']
# ['quality']
# ['warranty', 'service', 'to', 'Toshiba']
# ['screens']
# ['space']
# ['downloads']
# ['customer', 'support']
# ['LED', 'backlit', 'display']
# ['aesthetics']
# ['Runs']
# ['screen', 'size']
# ['battery', 'life']
# ['graphics']
# ['connect', 'quality']
# ['screen']
# ['headphone']
# ['mic', 'jack']
# ['touch-pad']
# ['touch-pad']
# ['headphones']
# ['mic']
# ['price']
# ['warranty']
# ['memory']
# ['run']
# ['works']
# ['connection', 'with', 'the', 'internet']
# ['booting', 'up']
# ['shutting', 'down']
# ['battery', 'life']
# ['gaming']
# ['hard', 'drive']
# ['mother', 'board']
# ['system']
# ['OSX']
# ['features']
# ['use']
# ['screen']
# ['KEYS']
# ['KEYBOARD']
# ['KEYS']
# ['Features']
# ['Dashboard']
# ['return', 'policy']
# ['battery']
# ['portability']
# ['affordability']
# ['set', 'up']
# ['hook', 'to', 'my', 'wireless', 'network']
# ['aluminum', 'style']
# ['specs']
# ['nvidia', '9800']
# ['arm', 'piece']
# ['carry']
# ['battery']
# ['1-year-warranty']
# ['word']
# ['word', 'processer']
# ['keyboard']
# ['battery']
# ['hard', 'disk']
# ['battery']
# ['battery']
# ['performance', 'specs']
# ['features']
# ['quality', 'control']
# ['touch-mouse']
# ['numeric', 'pad']
# ['cover', 'for', 'the', 'DVD', 'drive']
# ['construction', 'quality']
# ['arm', 'velcro']
# ['software']
# ['LCD']
# ['2', 'GB', 'of', 'RAM']
# ['Windows', '7']
# ['programs']
# ['battery', 'life']
# ['versitility']
# ['Safari']
# ['Vista']
# ['program']
# ['hinge', 'design']
# ['screen']
# ['display']
# ['browsers']
# ['Runs']
# ['Charger']
# ['speakers']
# ['screen', 'graphics']
# ['clarity']
# ['sharpness']
# ['customer', 'support']
# ['performance']
# ['safety', 'feature']
# ['unibody', 'design']
# ['BOOTING', 'UP']
# ['one-year', 'warranty']
# ['cost']
# ['charge']
# ['battery']
# ['software']
# ['software']
# ['price']
# ['features']
# ['services']
# ['performance']
# ['speed']
# ['use']
# ['Bluetooth', '3']
# ['warrenty']
# ['fan', 'blade']
# ['internet', 'connection']
# ['external', 'harddrives']
# ['Windows', '7', 'Starter']
# ['functionality']
# ['value']
# ['simplicity']
# ['look']
# ['looking']
# ['use']
# ['Windows', '7', 'Starter']
# ['battery', 'life']
# ['battery']
# ['programs']
# ['keys']
# ['look']
# ['Windows']
# ['mouse', 'keys']
# ['features']
# ['use']
# ['drivers']
# ['Windows', '7', 'Ultimate']
# ['mute']
# ['color', 'reproduction']
# ['warranty']
# ['use']
# ['start', 'up']
# ['features']
# ['Sony', "'Certified'", 'technician']
# ['proprietary', 'software']
# ['Apple', 'Care', 'plan']
# ['cd', 'drive']
# ['video', 'games']
# ['programs']
# ['processor']
# ['memory']
# ['hard', 'drive']
# ['web', 'cam']
# ['screen']
# ['features']
# ['battery']
# ['graphics']
# ['trial', 'software']
# ['battery', 'life']
# ['webcam']
# ['Windows']
# ['motherboard']
# ['programs']
# ['loads']
# ['Graphics']
# ['internet', 'interfaces']
# ['black', 'keyboard']
# ['service']
# ['software', 'options']
# ['applications']
# ['features']
# ['functioning']
# ['programs']
# ['Office']
# ['works']
# ['service', 'center']
# ['port']
# ['battery']
# ['cooling', 'system']
# ['grafics', 'card']
# ['LED', 'backlit', 'screen.']
# ['8GB', 'RAM']
# ['instructions']
# ['operation']
# ['value']
# ['built']
# ['works']
# ['Screen']
# ['system']
# ['cost']
# ['cursor']
# ['software']
# ['operate']
# ['gadgets']
# ['Windows']
# ['hard', 'drive']
# ['disk', 'image']
# ['track', 'pad']
# ['track', 'pad']
# ['disc', 'drive']
# ['drive']
# ['drive']
# ['Appleworks']
# ['word', 'processing', 'program']
# ['size']
# ['Battery']
# ['battery']
# ['usage']
# ['speaker', 'grill']
# ['MacOSX']
# ['Windows', '7']
# ['dual-core']
# ['quad-core']
# ['22"', 'Monitor']
# ['graphics']
# ['programs']
# ['Garageband']
# ['default', 'background']
# ['Screen']
# ['keyboard']
# ['screen']
# ['island', 'backlit', 'keyboard']
# ['multi-touch', 'mouse']
# ['mouse']
# ['overpriced']
# ['OS']
# ['Windows']
# ['iWork']
# ['programs']
# ['Microsoft', 'Office']
# ['word', 'processing']
# ['spreadsheets']
# ['presentations']
# ['runs']
# ['warranty']
# ['built', 'it', 'web', 'cam']
# ['monitor']
# ['performed']
# ['navigate']
# ['graphics', 'cards']
# ['bluray', 'player']
# ['book']
# ['systems']
# ['internet']
# ['video', 'card']
# ['gaming']
# ['media']
# ['3', 'year', 'warranty,']
# ['thermal', 'paste']
# ['internals']
# ['customer', 'support']
# ['facial', 'recognition']
# ['windows', 'logon']
# ['Windows', 'Vista']
# ['online', 'service']
# ['recovery', 'DVDs']
# ['webcam']
# ['keyboard']
# ['carry']
# ['display']
# ['features']
# ['performance']
# ['display']
# ['memory']
# ['hard', 'drive']
# ['sound']
# ['fans']
# ['preformed']
# ['system']
# ['windows', 'OS']
# ['user', 'interface']
# ['warrenty']
# ['iDVD']
# ['program']
# ['program']
# ['hard', 'drive']
# ['battery']
# ['screen']
# ['works']
# ['word', 'processing']
# ['surfing']
# ['mouse', 'pad']
# ['buttons']
# ['graphics']
# ['play']
# ['work']
# ['Intel', 'i', 'processors']
# ['edge']
# ['edges']
# ['sound', 'quality', 'via', 'USB']
# ['battery', 'life']
# ['warranty']
# ['extended', 'life', 'battery']
# ['operating', 'system']
# ['Windows', 'XP', 'drivers']
# ['sound', 'card']
# ['Windows', '7']
# ['features']
# ['budget']
# ['motherboard']
# ['Google', 'Chrome']
# ['speakers']
# ['PRICE']
# ['screen']
# ['art', 'aspect']
# ['battery']
# ['surfing']
# ['pre-loaded', 'Norton', 'Firewall/Security', 'program']
# ['USB', 'connect']
# ['hard', 'drive']
# ['expense']
# ['cd', 'drive']
# ['multi-touch', 'trackpad']
# ['extended', 'warranties']
# ['cost']
# ['software']
# ['performance']
# ['System']
# ['quality']
# ['price']
# ['use']
# ['Apple', 'keyboard']
# ["PC's", 'keyboard']
# ['extended', 'warranty']
# ['RAM']
# ['hard', 'drive']
# ['power', 'cord']
# ['battery']
# ['power', 'supply']
# ['techies']
# ['Sony', 'Sonic', 'Stage', 'software']
# ['speakers']
# ['subwoofer']
# ['extended', 'life', 'battery']
# ['Docking', 'port']
# ['bluetooth', 'mouse']
# ['bluetooth', 'enabled']
# ['works']
# ['Keynote']
# ['Powerpoint', 'program']
# ['size']
# ['size']
# ['browser']
# ['carry']
# ['keyboard']
# ['keyboard']
# ['programs']
# ['drivers']
# ['space']
# ['customer', 'service', 'rep']
# ['genius', 'bar', 'staff)']
# ['fan']
# ['boot', 'up']
# ['graphics']
# ['non-dedicated', 'graphics', 'card']
# ['Mouse', 'Cable']
# ['mouse']
# ['RAM', 'slots']
# ['HDD', 'Bays']
# ['16GB', 'RAM', 'support']
# ['Wireless']
# ['ASUS', 'TECH', 'SUPPORT']
# ['screen']
# ['screen']
# ['display']
# ['mouse', 'on', 'the', 'pad']
# ['left', 'button']
# ['batteries']
# ['battery', 'life']
# ['built', 'in', 'tools']
# ['iTunes']
# ['size']
# ['quality']
# ['price']
# ['carry']
# ['programs']
# ['Leopard', 'running', 'system']
# ['LG', 'service', 'center']
# ['service', 'center']
# ['service']
# ['Material']
# ['Specs']
# ['performs']
# ['price']
# ['photo', 'booth']
# ['operating', 'system']
# ['user', 'interface']
# ['multi-touch', 'track', 'pad']
# ['Hard', 'disk']
# ['hard', 'disk', 'space']
# ['internal', 'hard', 'disk']
# ['connects', 'to', 'WIFI']
# ['applications']
# ['windows']
# ['screen']
# ['gaming']
# ['space']
# ['battery', 'life']
# ['charge']
# ['power', 'adapter']
# ['price']
# ['weight']
# ['mainboard']
# ['speed']
# ['hard', 'drive']
# ['500gb', 'external', 'hard', 'drive']
# ['wireless', 'card']
# ['operating', 'systems']
# ['keys']
# ['portability']
# ['accessories']
# ['warranty']
# ['sound']
# ['windows']
# ['system']
# ['size']
# ['games']
# ['playing', 'games']
# ['Windows']
# ['equipment']
# ['size']
# ['build']
# ['wt']
# ['battery', 'life']
# ['quality']
# ['Apple', 'navigation']
# ['apps']
# ['hard', 'drives']
# ['battery']
# ['built']
# ['runs']
# ['Sound', 'card']
# ['processing', 'power']
# ['battery', 'life']
# ['sized']
# ['Vista']
# ['keyboard']
# ['desktop', 'keyboard']
# ['display']
# ['mouse']
# ['warranty']
# ['keyboard']
# ['keyboard']
# ['battery', 'life']
# ['hard', 'drives']
# ['driver']
# ['drivers/applications', 'DVD']
# ['repair', 'depot']
# ['repair', 'depot']
# ['Operating', 'System']
# ['motherboards']
# ['costing']
# ['AC', 'plug']
# ['Peformance']
# ['price']
# ['shipping']
# ['BIOS']
# ['ports']
# ['O']
# ['use']
# ['hard', 'drives']
# ['use']
# ['MS', 'Office']
# ['shipping']
# ['price']
# ['budget']
# ['power']
# ['flexibility']
# ['HDMI', 'port']
# ['S-video', 'port']
# ['speakers']
# ['Battery']
# ['surfing', 'the', 'web']
# ['Iphoto']
# ['Senior', 'Tech']
# ['volume', 'wheel']
# ['sound', 'quality']
# ['features']
# ['price']
# ['manual']
# ['hard', 'drive']
# ['software']
# ['sensitivity']
# ['battery', 'life']
# ['battery']
# ['battery', 'life']
# ['case']
# ['core', 'applications']
# ['system']
# ['charge']
# ['cord']
# ['hook', 'up', 'to', 'other', 'wireless', 'networks']
# ['shift', 'key']
# ['rep']
# ['power']
# ['speed']
# ['programs']
# ['iLife']
# ['Microsoft', 'Office']
# ['portability']
# ['longevity']
# ['use']
# ['motherboard']
# ['fan']
# ['charged']
# ['price']
# ['price']
# ['keys']
# ['standard', 'os', 'cd']
# ['proprietary', 'hardware', 'drivers']
# ['battery']
# ['charge']
# ['delivery']
# ['programm']
# ['performance']
# ['battery', 'life']
# ['response']
# ['Internet', 'focused', 'activity']
# ['features']
# ['charges']
# ['size']
# ['look']
# ['feature']
# ['charge']
# ['iBook', 'backup']
# ['firewire', 'connectio']
# ['camera']
# ['specifications']
# ['display']
# ['repair', 'depot']
# ['keyboard', 'shortcuts']
# ['shortcuts']
# ['RAM']
# ['software']
# ['windows', 'media']
# ['price']
# ['warranty']
# ['replacement', 'charger']
# ['windows', 'system']
# ['cursor']
# ['mousepad']
# ['features']
# ['printer', 'software']
# ['power']
# ['memory']
# ['speed']
# ['seventeen', 'inch', 'screen']
# ['hinge']
# ['shipping']
# ['technician']
# ['DC', 'jack']
# ['DC', 'jack']
# ['power', 'brick']
# ['screen', 'quality']
# ['use']
# ['graphics']
# ['use']
# ['iLife', 'software']
# ['use']
# ['built-in', 'webcam']
# ['service', 'center']
# ['Word']
# ['Pages']
# ['applications']
# ['internet']
# ['gaming']
# ['17"', 'inch', 'screen']
# ['price-point']
# ['appearance']
# ['boots', 'up']
# ['runs']
# ['specifications']
# ['over', 'priced']
# ['battery', 'life']
# ['screen']
# ['price']
# ['batteries']
# ['price']
# ['MOTHERBOARD']
# ['speed']
# ['retail', 'price']
# ['Microsoft', 'Student', 'Edition']
# ['web', 'browsing']
# ['every', 'day', 'computing']
# ['functions']
# ['keys']
# ['LED', 'monitor']
# ['mother', 'board']
# ['hard', 'drive']
# ['design']
# ['battery']
# ['charge']
# ['memory']
# ['gaming']
# ['screen', 'size']
# ['tech', 'support']
# ['backlit', 'keys']
# ['screen']
# ['Safari', 'internet', 'browser']
# ['firefox']
# ['use']
# ['battery']
# ['support', 'line']
# ['Windows', '7', 'starter']
# ['Windows', '7']
# ['KEYBOARD', 'FUNCTION']
# ['DVD', 'drive']
# ['Garageband']
# ['microphone']
# ['Linux']
# ['security-prone', 'OS']
# ['performs']
# ['memory']
# ['hard', 'drive', 'space']
# ['firewire', 'cable', 'system']
# ['iBook']
# ['shipment']
# ['OS', 'X']
# ['quicklook']
# ['features']
# ['keyboard']
# ['design']
# ['colors']
# ['screen']
# ['mousepad']
# ['browsing']
# ['PhotoBooth']
# ['program']
# ['built-in', 'camera']
# ['software']
# ['shipping']
# ['Chrome']
# ['prices']
# ['price']
# ['external', 'dvd', 'drive']
# ['external', 'drive']
# ['PORTABILITY']
# ['PROCESSING']
# ['cooling', 'pad']
# ['Supplied', 'software']
# ['software']
# ['Windows']
# ['service']
# ['Garageband']
# ['apple', 'applications']
# ['bios']
# ['bios']
# ['extended', 'warranty']
# ['charging']
# ['charge']
# ['charge']
# ['shipped']
# ['Windows']
# ['kernal']
# ['display']
# ['battery', 'life']
# ['quality']
# ['hardrive']
# ['use']
# ['graphics']
# ['screen']
# ['upgraded', 'memory']
# ['applications']
# ['running']
# ['graphics']
# ['use']
# ['internet', 'speed']
# ['call', 'center']
# ['apps']
# ['programs']
# ['games']
# ['cords']
# ['screen']
# ['screen']
# ['OS']
# ['fan']
# ['edges']
# ['edges']
# ['carry']
# ['screen']
# ['size']
# ['weight']
# ['keyboard']
# ['disc', 'drive']
# ['hard', 'drive']
# ['power', 'supply']
# ['display']
# ['starts']
# ['boot', 'up']
# ['Pages']
# ['Keynotes']
# ['hard', 'drive']
# ['mother', 'board']
# ['dvd', 'drive']
# ['hinge']
# ['motherboard']
# ['port']
# ['plug']
# ['key', 'board']
# ['trackpad']
# ['power']
# ['ease']
# ['use']
# ['Touchpad']
# ['connection', 'card']
# ['warranty']
# ['warranty']
# ['4GB', 'of', 'RAM']
# ['8GB', 'of', 'RAM']
# ['game']
# ['Browsing']
# ['itunes']
# ['price']
# ['setup']
# ['motherboard']
# ['Toshiba', 'customer', 'services']
# ['Quality', 'Display']
# ['performance']
# ['quality']
# ['battery', 'life']
# ['internet', 'capabilities']
# ['High', 'definition', 'quality']
# ['Speakers']
# ['Beast', 'graphics']
# ['set', 'up']
# ['wall', 'charger']
# ['battery']
# ['Screen']
# ['battery', 'life']
# ['windows', 'vista', 'system']
# ['Function', 'keys']
# ['BIOS']
# ['Vista']
# ['Screen', 'size']
# ['push', 'button']
# ['lid']
# ['Pentium', '4']
# ['1', 'GB', 'ram']
# ['Windows']
# ['word', 'processor']
# ['interface', 'device']
# ['included', 'program']
# ['expese']
# ['Microsoft', 'Office', 'apps']
# ['internet', 'use']
# ['price']
# ['quality']
# ['games']
# ['aero']
# ['hard', 'drive']
# ['battery']
# ['screen']
# ['operation']
# ['screen']
# ['webcam']
# ['Skype']
# ['machined', 'aluminum', 'frame']
# ['keyboard']
# ['parallels', 'type', 'program']
# ['software']
# ['design']
# ['ATI', 'graphics', 'card']
# ['Intel', 'built-in', 'card']
# ['games']
# ['handle']
# ['operate']
# ['features']
# ['speed']
# ['power']
# ['power', 'supply', 'cord']
# ['Applecare', 'warranty', 'plan']
# ['13', 'inch']
# ['power', 'supply']
# ['screen']
# ['use']
# ['right', 'speaker']
# ['support']
# ['Final', 'Cut', 'Pro']
# ['runs']
# ['Mac', 'Snow', 'Leopard', 'O/S']
# ['Win', 'XP']
# ['Visa']
# ['Win7']
# ['use']
# ['Startup']
# ['shutdown']
# ['resume', 'from', 'sleep']
# ['screen']
# ['keyboard']
# ['fit']
# ['Windows']
# ['processor']
# ['graphics', 'card']
# ['size']
# ['external', 'keyboard']
# ['mouse']
# ['monitor']
# ['windows', '7', 'system']
# ['weight']
# ['size']
# ['wheel']
# ['service']
# ['flatline', 'keyboard']
# ['Speakers']
# ['windows', '7']
# ['ergonomics']
# ['connections']
# ['Applecare', 'tech', 'support']
# ['power', 'plug']
# ['resolution', 'on', 'the', 'screen']
# ['programs']
# ['iLife']
# ['iWork']
# ['gaming']
# ['delivery']
# ['value']
# ['Internet', 'Explorer']
# ['AC', 'power', 'port']
# ['running', 'system']
# ['programs']
# ['power', 'supply']
# ['power', 'supply']
# ['force']
# ['durability']
# ['Vista', 'Business']
# ['surf', 'the', 'web']
# ['size', 'of', 'the', 'screen']
# ['tote']
# ['work']
# ['use']
# ['battery']
# ['Win', '7']
# ['2GB', 'stick', 'of', 'memory']
# ['Norton']
# ['internet']
# ['command', 'prompt']
# ['software']
# ['speed']
# ['hard', 'drive']
# ['programming']
# ['iPhoto']
# ['Speakers']
# ['RAM']
# ['speakers']
# ['memory']
# ['Vista']
# ['Battery', 'life']
# ['price']
# ['battery']
# ['charge']
# ['charge']
# ['warrenty']
# ['hard', 'drive']
# ['Windows', '7', 'Starter']
# ['icon', 'list']
# ['desktop', 'icons']
# ['warranty']
# ['price']
# ['performance']
# ['built']
# ['look']
# ['apple', 'care']
# ['use']
# ['warranty']
# ['work']
# ['size']
# ['keyboard']
# ['functions']
# ['mouse']
# ['OS']
# ['run']
# ['screen']
# ['delivery', 'service']
# ['performance']
# ['picture', 'quality']
# ['use']
# ['i3', 'processor']
# ['fan']
# ['battery']
# ['charge']
# ['charge']
# ['mousepad']
# ['keys']
# ['casing']
# ['operating', 'system']
# ['resolution', 'of', 'the', 'screen']
# ['touchpad']
# ['battery', 'life']
# ['boot', 'up']
# ['charge']
# ['OS']
# ['screen', 'brightness']
# ['backlit', 'keyboard']
# ['look']
# ['cost']
# ['sound']
# ['SATA', 'controller']
# ['motherboard', 'chip']
# ['CPU']
# ['hard', 'drive']
# ['buttons']
# ['battery', 'life']
# ['battery']
# ['battery']
# ['size']
# ['weight']
# ['portability']
# ['battery', 'life']
# ['Windows', 'Vista', 'Home', 'Premium']
# ['1GB', 'of', 'RAM']
# ['display']
# ['brightness']
# ['electronic', 'fuzz', 'sound']
# ['headphone', 'jack']
# ['keyboard']
# ['quality']
# ['warranty']
# ['power', 'supply']
# ['gaming']
# ['graphics', 'editing']
# ['complex', 'data', 'analysis']
# ['costs']
# ['shipping']
# ['ram']
# ['performance']
# ['surf', 'the', 'web']
# ['hardcopy', 'manuel']
# ['drive']
# ['visual']
# ['priced']
# ['works']
# ['OS']
# ['keyboard']
# ['plate']
# ['mouse', 'command', 'buttons']
# ['features']
# ['speeds']
# ['touch', 'pad']
# ['size']
# ['features']
# ['lighted', 'keyboard']
# ['mouse', 'pad']
# ['Battery', 'life']
# ['operation', 'system']
# ['trackpad']
# ['Applications']
# ['hard', 'drive']
# ['Windows']
# ['Warrenty']
# ['agents']
# ['keyboard']
# ['three', 'year', 'warranty']
# ['extended', 'warranty']
# ['internet']
# ['RAM']
# ['memory']
# ['Nvidia', 'grafics', 'card']
# ['work']
# ['resolution']
# ['left', '"mouse"', 'button']
# ['keyboard']
# ['feature']
# ['type']
# ['casing']
# ['15"']
# ['17"']
# ['feel']
# ['hard', 'disc']
# ['virus', 'protection', 'programs', 'for', 'a', 'Mac']
# ['Screen']
# ['HDMI']
# ['graphics']
# ['wireless', 'switch']
# ['build', 'quality']
# ['technical', 'person']
# ['mouse']
# ['shipped']
# ['size']
# ['internet', 'connection']
# ['quality']
# ['performance']
# ['price']
# ['recovery', 'DVDs']
# ['driver/application', 'DVD']
# ['photo', 'detection', 'software']
# ['speakers']
# ['price']
# ['use']
# ['touchpad']
# ['screen']
# ['mouse', 'pointer']
# ['hardware']
# ['KEYBOARD']
# ['Windows']
# ['cost']
# ['quality']
# ['engineering', 'design']
# ['warranty']
# ['applications']
# ['screen']
# ['use']
# ['work']
# ['speakers']
# ['hinges']
# ['programs']
# ['work']
# ['Customer', 'Service']
# ['programs']
# ['Keynote']
# ['Pages']
# ['Numbers']
# ['expense']
# ['run']
# ['components']
# ['price']
# ['price']
# ['cd', 'drive']
# ['price']
# ['quality']
# ['quality']
# ['price']
# ['pointer']
# ['shipping']
# ['price']
# ['budget']
# ['life', 'span']
# ['design']
# ['looks']
# ['feel']
# ['my', 'toshiba', 'feature']
# ['layout']
# ['one', 'of', 'the', 'programs']
# ['use']
# ['Touchpad']
# ['USB']
# ['Touchpad']
# ['iwork']
# ['office']
# ['word', 'processor']
# ['windows']
# ['document', 'creation']
# ['battery']
# ['memory']
# ['memory', 'stick']
# ['memory', 'stick']
# ['keys']
# ['keyboard']
# ['button', 'below', 'the', 'mouse', 'pad']
# ['screen']
# ['paint']
# ['lightscribe']
# ['touchpad']
# ['applications']
# ['iphoto']
# ['photo', 'application']
# ['Bluetooth']
# ['Fingerprint', 'Reader']
# ['screen']
# ['Mic']
# ['Dual', 'touchpad', 'mode']
# ['USB', 'ports']
# ['Webcam']
# ['use']
# ['Runs']
# ['Word']
# ['17', 'ince', 'screen']
# ['screen']
# ['warranty', 'period']
# ['HD']
# ['drivers']
# ['Windows', 'update']
# ['OSX']
# ['Windows', 'XP']
# ['Features']
# ['Performance']
# ['Battery', 'Life']
# ['Price']
# ['Value']
# ['windows']
# ['graphics']
# ['system']
# ['WiFi']
# ['software']
# ['update', 'programs']
# ['navigate']
# ['Applications']
# ['MS', 'applications']
# ['Customer', 'Service']
# ['screen']
# ['carry']
# ['weight']
# ['applications']
# ['programs']
# ['Internet', 'tabs']
# ['noises']
# ['bottom', 'of', 'the', 'computer']
# ['repair', 'technician']
# ['software']
# ['carry']
# ['handle']
# ['Cords']
# ['power']
# ['headphones']
# ['mic']
# ['network', 'connection']
# ['setup']
# ['cords']
# ['cords']
# ['power', 'supply']
# ['Core2', 'Quad']
# ['battery', 'life']
# ['screen']
# ['screen']
# ['screen']
# ['applications']
# ['charger', 'unit']
# ['feel']
# ['Looks']
# ['signals']
# ['signal']
# ['feel']
# ['quality']
# ['memory']
# ['Windows', '7', 'Starter']
# ['Win', '7', 'Home']
# ['runs']
# ['drive']
# ['edges']
# ['incase', 'shells']
# ['keyboard']
# ['weight']
# ['use']
# ['shipping']
# ['repair', 'center']
# ['applications']
# ['battery']
# ['DVD', 'burner']
# ['power', 'supply']
# ['case']
# ['keyboard']
# ['keyboard', 'functions']
# ['iMovie']
# ['SERVICE', 'FACILITY']
# ['Customer', 'Service']
# ['warranty']
# ['programs']
# ['system']
# ['using', 'the', 'internet']
# ['buttons']
# ['safe', 'mode']
# ['18-inch']
# ['universal', 'charger']
# ['powerpoint']
# ['desktop', 'background']
# ["window's", '7', 'starter']
# ['function']
# ['IT', 'support', 'technicians']
# ['charger']
# ['hardware']
# ['customer', 'service', 'center']
# ['screen']
# ['videocard']
# ['shaped']
# ['satellite', 'card']
# ['battery', 'life']
# ['battery']
# ['touchpad']
# ['depot']
# ['Price']
# ['zooming']
# ['screen']
# ['sized']
# ['use']
# ['price']
# ['features']
# ['power']
# ['Keyboard']
# ['features']
# ['call', 'center']
# ['backlit', 'keyboard']
# ['memory']
# ['battery', 'life']
# ['service', 'rep']
# ['power', 'adapter']
# ['program']
# ['windows', 'movie', 'maker']
# ['hard', 'drive']
# ['antivirus', 'software']
# ['design']
# ['beauty']
# ['price']
# ['Garmin', 'GPS', 'software']
# ['Microsoft', 'Office', '2003']
# ['keyboard']
# ['staff']
# ['fan', 'noise']
# ['price']
# ['warranty']
# ['price']
# ['screen']
# ['battery', 'life']
# ['storage']
# ['apple', 'associates']
# ['screen']
# ['price']
# ['mousepad', 'sensitivity']
# ['iWork']
# ['MS', 'Office']
# ['MS', 'Office']
# ['Keyboard']
# ['mac', 'osx']
# ['operating', 'system']
# ['keyboard']
# ['hinge']
# ['motherboard']
# ['surfing', 'the', 'web']
# ['use']
# ['hard', 'drive']
# ['use']
# ['HDD', 'bay']
# ['tutorials']
# ['leather', 'carrying', 'case']
# ['keyboard']
# ['mouse']
# ['touch', 'pad']
# ['screen']
# ['commodity', 'hardwar']
# ['Paralles']
# ['Windows', 'XP', 'Professional']
# ['Windows', '7', 'Home', 'Premium']
# ['Windows', 'Server', 'Enterprise', '2003']
# ['Windows', 'Server', '2008', 'Enterprise']
# ['repair']
# ['repair']
# ['operating', 'system']

# %%
aspect_list
# Out:
# ['cord',
#  'battery',
#  'life',
#  'service',
#  'center',
#  '"sales"',
#  'team',
#  'tech',
#  'guy',
#  'quality',
#  'GUI',
#  'applications',
#  'use',
#  'start',
#  'up',
#  'features',
#  'iChat',
#  'Photobooth',
#  'garage',
#  'band',
#  'features',
#  'GUI',
#  'screen',
#  'power',
#  'light',
#  'hard',
#  'drive',
#  'ligh',
#  'processor',
#  'graphics',
#  'cards',
#  'battery',
#  'life',
#  'battery',
#  'rubber',
#  'enclosure',
#  'edge',
#  'multi-touch',
#  'gestures',
#  'tracking',
#  'area',
#  'external',
#  'mouse',
#  'gaming',
#  'suite',
#  'of',
#  'software',
#  'speed',
#  'Windows',
#  '7',
#  'usb',
#  'devices',
#  'keyboard',
#  'software',
#  'system',
#  'Microsoft',
#  'office',
#  'for',
#  'the',
#  'mac',
#  'syncing',
#  '30"',
#  'HD',
#  'Monitor',
#  'screen',
#  'boot',
#  'up',
#  'service',
#  'battery',
#  'operating',
#  'system',
#  'preloaded',
#  'software',
#  'price',
#  'features',
#  'clock',
#  'in',
#  'BIOS',
#  'setup',
#  'WARRANTY',
#  'SERVICE',
#  'brand',
#  'warranty',
#  'features',
#  'fan',
#  'Customer',
#  'Service',
#  'number',
#  'warranty',
#  'talking',
#  'to',
#  'a',
#  'technician',
#  'hard',
#  'disc',
#  'windows',
#  'drivers',
#  'Drivers',
#  'BIOS',
#  'update',
#  'system',
#  'HP',
#  'Technical',
#  'Support',
#  'browser',
#  'keyboard',
#  'virus',
#  'scan',
#  '9',
#  'punds',
#  'program',
#  'warrenty',
#  'Toshiba',
#  'Warranty',
#  'Quality',
#  'webcam',
#  'value',
#  'internet',
#  'managing',
#  'personal',
#  'files',
#  'motherboard',
#  'system',
#  'charger',
#  'hardware',
#  'force',
#  'quit',
#  'works',
#  'Windows',
#  '7',
#  'VMWare',
#  'program',
#  'operating',
#  'system',
#  'runs',
#  'navigate',
#  'find',
#  'files',
#  'warrenty',
#  'extended',
#  'warranty',
#  'memory',
#  'speed',
#  'performace',
#  'opening',
#  'my',
#  'Documents',
#  'folder',
#  'operating',
#  'systems',
#  'charger',
#  'speed',
#  'glass',
#  'touchpad',
#  'hard',
#  'drive',
#  'mother',
#  'board',
#  'external',
#  'speaker',
#  'sound',
#  'battery',
#  'life',
#  'hardware',
#  'shipping',
#  'Mac',
#  'software',
#  'Microsoft',
#  'software',
#  'use',
#  'delete',
#  '',
#  'key',
#  'editing',
#  'use',
#  'service',
#  'phone',
#  'assistance',
#  'genius',
#  'bar',
#  'battery',
#  'life',
#  'battery',
#  'life',
#  'gaming',
#  'movie',
#  'playing',
#  'web',
#  'browsing',
#  'word',
#  'editing',
#  'recovery',
#  'discs',
#  'Office',
#  "Max's",
#  '"Max',
#  'Assurance"',
#  'iMac',
#  'backup',
#  'disc',
#  'USB',
#  'battery',
#  'life',
#  'battery',
#  'timer',
#  'Temperatures',
#  'Core',
#  'Processing',
#  'Unit',
#  'temperatures',
#  'service',
#  'virus',
#  'protection',
#  'for',
#  'Mac',
#  'bluetooth',
#  'LG',
#  'notebook',
#  'service',
#  'center',
#  'hinge',
#  'games',
#  'responds',
#  'motherboard',
#  'motherboard',
#  'hardware',
#  'motherboard',
#  'use',
#  'representive',
#  'at',
#  'Microsoft',
#  'system',
#  'XP',
#  'WIndows',
#  '7',
#  'Vista',
#  'Keyboard',
#  "Dell's",
#  'customer',
#  'disservice',
#  'cooling',
#  'system',
#  'use',
#  'quad',
#  'core',
#  'I7',
#  'sales',
#  'associate',
#  'system',
#  'Windows',
#  'applications',
#  'virus',
#  'program',
#  'weighed',
#  'seven',
#  'pounds',
#  'battery',
#  'bag',
#  'color',
#  'keys',
#  'designed',
#  'style',
#  'speed',
#  'keyboard',
#  'mousepad',
#  'battery',
#  'sales',
#  'service',
#  'DELL',
#  'SUPPORT',
#  'hard',
#  'drive',
#  'motherboard',
#  'speed',
#  'construction',
#  'quality',
#  'longevity',
#  'cost',
#  'keyboard',
#  'keys',
#  'configuration',
#  'of',
#  '"extra',
#  'key"',
#  'touch',
#  'pad',
#  'use',
#  'security',
#  'pricetag',
#  'use',
#  'work',
#  'preloaded',
#  'software',
#  'webcam',
#  'vga',
#  'port',
#  'screen',
#  'battery',
#  'life',
#  'keys',
#  'software',
#  'volume',
#  'mouse',
#  'touchpad',
#  'boots',
#  'up',
#  'hard',
#  'drive',
#  'look',
#  'and',
#  'feel',
#  'standpoint',
#  'safari',
#  'safari',
#  'Mozzilla',
#  'firfox',
#  'Bluetooth',
#  'fingerprint',
#  'reader',
#  'driver',
#  'software',
#  'battery',
#  'speed',
#  'display',
#  'delivery',
#  'battery',
#  'life',
#  'performance',
#  'memory',
#  'applications',
#  'Microsoft',
#  'office',
#  'Resolution',
#  'appearance',
#  'cooling',
#  'system',
#  'graphics',
#  'card',
#  'built-in',
#  'webcam',
#  'built-in',
#  'mic',
#  'cam',
#  'mic',
#  'Windows',
#  'Vista',
#  'board',
#  'connector',
#  'power',
#  'supply',
#  'warrenty',
#  'power',
#  'supply',
#  'ethernet',
#  'works',
#  'drag',
#  'and',
#  'drop',
#  'feature',
#  'webcam',
#  'sales',
#  'tax',
#  'software',
#  'packages',
#  'iWork',
#  'GarageBand',
#  'iMovie',
#  'screen',
#  'colors',
#  'resolution',
#  'monitor',
#  'iTunes',
#  'Size',
#  'external',
#  'monitor',
#  'base',
#  'installation',
#  'software',
#  'manuf',
#  'camera',
#  'display',
#  'AMD',
#  'Turin',
#  'processor',
#  'Intel',
#  'warranty',
#  'start',
#  'menu',
#  'navigate',
#  'bluray',
#  'read/write',
#  'drive',
#  'service',
#  'tech',
#  'tech',
#  'store',
#  'surface',
#  'screen',
#  'keyboard',
#  'iLife',
#  'Snow',
#  'Leopard',
#  'X',
#  'price',
#  'tag',
#  'Mac',
#  'OS',
#  'sound',
#  'output',
#  'quality',
#  'techie',
#  'use',
#  'Toshiba',
#  'online',
#  'help',
#  'service',
#  'life',
#  'ports',
#  'processor',
#  'price',
#  'look',
#  'keyboard',
#  'keys',
#  'screen',
#  'quality',
#  'stock',
#  'screen',
#  'gray',
#  'color',
#  'volume',
#  'buttons',
#  'processor',
#  'computing',
#  'protector',
#  'key',
#  'pad',
#  'magnetic',
#  'plug-in',
#  'power',
#  'charging',
#  'power',
#  'cord',
#  'XP',
#  'Vista',
#  'graphics',
#  'use',
#  'Mac',
#  'OS',
#  'use',
#  'support',
#  'Geek',
#  'Squad',
#  'graphics',
#  'quality',
#  'Appleworks',
#  'browser',
#  'paint',
#  'keyboard',
#  'service',
#  'department',
#  'warrenty',
#  'warrentys',
#  'hard',
#  'disk',
#  'CD',
#  'drive',
#  'running',
#  'screen',
#  'size',
#  'web',
#  'browsing',
#  'software',
#  'loads',
#  'trackpad',
#  'external',
#  'mouse',
#  'trackpad',
#  'games',
#  'features',
#  'human',
#  'interface',
#  'inbuilt',
#  'applications',
#  'Software',
#  'body',
#  'i5',
#  'antivirus',
#  'software',
#  'firewall',
#  'price',
#  'Apple',
#  'team',
#  'Vista',
#  'Vista',
#  'operating',
#  'system',
#  'Vista',
#  'video',
#  'chat',
#  'quality',
#  'mouse',
#  'Fan',
#  'cooling',
#  'pad',
#  'feature',
#  'software',
#  'installation',
#  'time',
#  'power',
#  'storage',
#  'abilitiy',
#  'spotlight',
#  'search',
#  'feature',
#  'wireless',
#  'system',
#  'Windows',
#  '7',
#  'quality',
#  'battery',
#  'life',
#  'speed',
#  'OS',
#  'OS',
#  'iTunes',
#  'program',
#  'gaming',
#  'battery',
#  'Apple',
#  'support',
#  'techs',
#  'adding',
#  'the',
#  'bluetooth',
#  'graphic',
#  'power',
#  'Adobe',
#  'Creative',
#  'apps',
#  'programs',
#  'use',
#  'materials',
#  'software',
#  'Tech',
#  'support',
#  'power',
#  'supply',
#  'POWER',
#  'SUPPLY',
#  'size',
#  'warranty',
#  'Windows',
#  'XP',
#  'SP2',
#  'Windows',
#  '7',
#  'Ultimate',
#  'Bluetooth',
#  'Fingerprint',
#  'reader',
#  'software',
#  'techs',
#  'at',
#  'HP',
#  'video',
#  'card',
#  'graphics',
#  'security',
#  'audio',
#  'keyboard',
#  'runs',
#  'set',
#  'up',
#  'screen',
#  'word',
#  'processing',
#  'internet',
#  'trackpad',
#  'battery',
#  'life',
#  'spec',
#  'HD',
#  'graphics',
#  'chip',
#  'components',
#  'DVD',
#  'burner',
#  'USB',
#  'ports',
#  'software',
#  'system',
#  'ran',
#  'price',
#  'operation',
#  'brand',
#  'components',
#  'ground',
#  'loop',
#  'isolator',
#  'price',
#  'range',
#  'quality',
#  'warranty',
#  'leading',
#  'edge',
#  'bloatware',
#  'Maximum',
#  'sound',
#  'windows',
#  '7',
#  'Bootcamp',
#  'price',
#  'action',
#  'pack',
#  'games',
#  'works',
#  'price',
#  'performance',
#  'twin',
#  'packing',
#  'functions',
#  'after',
#  'sales',
#  'support',
#  'look',
#  'display',
#  'screen',
#  'acer',
#  'arcade',
#  'customer',
#  'support',
#  'screen',
#  'cd',
#  'drive',
#  'runs',
#  'design',
#  'size',
#  'games',
#  'games',
#  'life',
#  'warranty',
#  'pad',
#  'value',
#  'price',
#  'system',
#  'performance',
#  'linux',
#  'based',
#  'os',
#  'use',
#  'batteries',
#  'shipping',
#  'carton',
#  'use',
#  'program',
#  'virus',
#  'protection',
#  'screen',
#  'processor',
#  'OSX',
#  '16',
#  'graphics',
#  'hardware',
#  'software',
#  'Intel',
#  'Core',
#  'processors',
#  'HDMI',
#  'port',
#  'Internet',
#  'Explorer',
#  'staff',
#  'price',
#  'premium',
#  'features',
#  'product',
#  'and',
#  'help',
#  'aftermarket',
#  'Microsoft',
#  'word',
#  'usb',
#  'ports',
#  'sd',
#  'memory',
#  'card',
#  'reader',
#  'sd',
#  'memory',
#  'car',
#  'expansion',
#  'LaCie',
#  '2Big',
#  'external',
#  'drive',
#  'firewire',
#  '800',
#  'interface',
#  'Time',
#  'Machine',
#  'sound',
#  'extra',
#  'features',
#  'windows',
#  '7',
#  'home',
#  'premium',
#  'Acer',
#  'screen',
#  'USB',
#  'port',
#  'boot',
#  'battery',
#  'life',
#  'fires',
#  'up',
#  'keyboard',
#  'software',
#  'online',
#  'tutorial',
#  'videos',
#  'image',
#  'soud',
#  'windows',
#  'boot',
#  'up',
#  'shut',
#  'down',
#  'windows',
#  'Mac',
#  'OS',
#  'use',
#  'cost',
#  'Windows',
#  '7',
#  'Starter',
#  'Windows',
#  '7',
#  'Home',
#  'Premium',
#  'Windows',
#  '7',
#  'Professional',
#  'specifications',
#  'power',
#  'cords',
#  'multi-touch',
#  'features',
#  'screen',
#  'clicking',
#  'buttons',
#  'battery',
#  'life',
#  'Windows',
#  'wired',
#  'lan',
#  'hard',
#  'reboot',
#  'hardware',
#  'hard',
#  'drive',
#  'battery',
#  'life',
#  'Apple',
#  'care',
#  'font',
#  'Features',
#  'programs',
#  'run',
#  u'plastic\xa0pieces',
#  '2GB',
#  'RAM',
#  'stick',
#  'Windows',
#  'Microsoft',
#  'Word',
#  'for',
#  'Mac',
#  'WARRANTY',
#  'COMPANY',
#  'cusromer',
#  'service',
#  'center',
#  'size',
#  'weight',
#  'battery',
#  'aluminum',
#  'body',
#  'watching',
#  'movies',
#  'playing',
#  'build',
#  'quality',
#  'performance',
#  'dock',
#  'program',
#  'program',
#  'working',
#  'costing',
#  'price',
#  'i7',
#  'monitor',
#  'extended',
#  'warranty',
#  'Boots',
#  'up',
#  'runs',
#  'screen',
#  'driver',
#  'tech',
#  'support',
#  'work',
#  'hard',
#  'drive',
#  'twin',
#  'packing',
#  'functions',
#  'warranty',
#  'performance',
#  'price',
#  'BIOS',
#  'design',
#  'tech',
#  'issues',
#  'size',
#  'space',
#  'service',
#  'memory',
#  'speed',
#  'priced',
#  'internet',
#  'speed',
#  'programs',
#  'Garageband',
#  'Photo',
#  'Booth',
#  'iPhoto',
#  'iMovie',
#  'video-editing',
#  'movie-making',
#  'photo',
#  'management',
#  'music',
#  'Pages',
#  'Numbers',
#  'Keynote',
#  'school',
#  'or',
#  'office',
#  'use',
#  'screen',
#  'colors',
#  'value',
#  'price',
#  'value',
#  'web',
#  'cam',
#  'burn',
#  "cd's",
#  '17',
#  'inch',
#  'screen',
#  'support',
#  'Bluetooth',
#  'Drivers/Applications',
#  'DVD',
#  'Launch',
#  'Manager',
#  'glass',
#  'screen',
#  'switchable',
#  'graphic',
#  'card',
#  'gaming',
#  'service',
#  'battery',
#  'life',
#  'technical',
#  'support',
#  'BOOT',
#  'MGR',
#  'recovery',
#  'cd',
#  'price',
#  'features',
#  'Skype',
#  'mouse',
#  'buttons',
#  'HDD',
#  'rails',
#  'hard',
#  'drive',
#  'quality',
#  'staff',
#  'Games',
#  'GarageBand',
#  'warranty',
#  'hard',
#  'drive',
#  'price',
#  'home',
#  'use',
#  'business',
#  'use',
#  'virus',
#  'protection',
#  'updates',
#  'MS',
#  'Office',
#  'apps',
#  'feature',
#  'Windows',
#  'games',
#  'battery',
#  'life',
#  'battery',
#  'life',
#  'price',
#  'Nortons',
#  'virus',
#  'scan',
#  'frame',
#  'features',
#  'use',
#  'loaded',
#  'Windows',
#  '7',
#  'Vista',
#  'Vista',
#  'windows',
#  'Windows',
#  'XP',
#  'Vista',
#  'key',
#  'broad',
#  'warranty',
#  'repair',
#  '"depot"',
#  'school',
#  'use',
#  'design',
#  'battery',
#  'life',
#  'programs',
#  'Wireless',
#  'battery',
#  'life',
#  'programs',
#  'trackpad',
#  'programs',
#  'navigating',
#  'speakers',
#  'subwoofer',
#  'built',
#  'in',
#  'camera',
#  'price',
#  'warranty',
#  'left',
#  'mouse',
#  'key',
#  'costed',
#  'speed',
#  'hard',
#  'drive',
#  'space',
#  'picture',
#  'extended',
#  'warranty',
#  'extended',
#  'warranties',
#  'battery',
#  'Screen',
#  'battery',
#  'life',
#  'appearance',
#  'technical',
#  'service',
#  'for',
#  'dell',
#  'graphics',
#  'warranty',
#  'battery',
#  'case',
#  'performance',
#  'price',
#  'look',
#  'applications',
#  'speed',
#  'tech',
#  'support',
#  'gaming',
#  'use',
#  'Photoshop',
#  'ram',
#  'system',
#  'clock',
#  'RAM',
#  'securitysoftware',
#  'driver',
#  ...]

# %%
import pandas as pd
df2=pd.DataFrame(columns=['f','m','o'])

from nltk import word_tokenize,pos_tag

# %%
sen=word_tokenize(sen)
sen=pos_tag(sen)
print(sen)
# Out:
# [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('recommend', 'VB'), ('this', 'DT'), ('product', 'NN')]

# %%
d=0

for term in sen2:
    if term in aspect_list:
        df2.at[d,'f']=term

        for word in sen:

            if word[1]=='JJ' or word[1]=='JJR' or word[1]=='JJS':
                l=l.append(word[0])
                df2.at[d,'o']=l
                l=[]
            elif word[1]=='VB':
                df2.at[d,'o']=word[0]
            if word[1]=='RB':
                df2.at[d,'m']=word[0]
        d=d+1

# %% [markdown]
# ##

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
a_new=[]
for i in aspect_list:
    if i not in stop_words:
        a_new.append(i)

# %%
a_new
# Out:
# ['cord',
#  'battery',
#  'life',
#  'service',
#  'center',
#  '"sales"',
#  'team',
#  'tech',
#  'guy',
#  'quality',
#  'GUI',
#  'applications',
#  'use',
#  'start',
#  'features',
#  'iChat',
#  'Photobooth',
#  'garage',
#  'band',
#  'features',
#  'GUI',
#  'screen',
#  'power',
#  'light',
#  'hard',
#  'drive',
#  'ligh',
#  'processor',
#  'graphics',
#  'cards',
#  'battery',
#  'life',
#  'battery',
#  'rubber',
#  'enclosure',
#  'edge',
#  'multi-touch',
#  'gestures',
#  'tracking',
#  'area',
#  'external',
#  'mouse',
#  'gaming',
#  'suite',
#  'software',
#  'speed',
#  'Windows',
#  '7',
#  'usb',
#  'devices',
#  'keyboard',
#  'software',
#  'system',
#  'Microsoft',
#  'office',
#  'mac',
#  'syncing',
#  '30"',
#  'HD',
#  'Monitor',
#  'screen',
#  'boot',
#  'service',
#  'battery',
#  'operating',
#  'system',
#  'preloaded',
#  'software',
#  'price',
#  'features',
#  'clock',
#  'BIOS',
#  'setup',
#  'WARRANTY',
#  'SERVICE',
#  'brand',
#  'warranty',
#  'features',
#  'fan',
#  'Customer',
#  'Service',
#  'number',
#  'warranty',
#  'talking',
#  'technician',
#  'hard',
#  'disc',
#  'windows',
#  'drivers',
#  'Drivers',
#  'BIOS',
#  'update',
#  'system',
#  'HP',
#  'Technical',
#  'Support',
#  'browser',
#  'keyboard',
#  'virus',
#  'scan',
#  '9',
#  'punds',
#  'program',
#  'warrenty',
#  'Toshiba',
#  'Warranty',
#  'Quality',
#  'webcam',
#  'value',
#  'internet',
#  'managing',
#  'personal',
#  'files',
#  'motherboard',
#  'system',
#  'charger',
#  'hardware',
#  'force',
#  'quit',
#  'works',
#  'Windows',
#  '7',
#  'VMWare',
#  'program',
#  'operating',
#  'system',
#  'runs',
#  'navigate',
#  'find',
#  'files',
#  'warrenty',
#  'extended',
#  'warranty',
#  'memory',
#  'speed',
#  'performace',
#  'opening',
#  'Documents',
#  'folder',
#  'operating',
#  'systems',
#  'charger',
#  'speed',
#  'glass',
#  'touchpad',
#  'hard',
#  'drive',
#  'mother',
#  'board',
#  'external',
#  'speaker',
#  'sound',
#  'battery',
#  'life',
#  'hardware',
#  'shipping',
#  'Mac',
#  'software',
#  'Microsoft',
#  'software',
#  'use',
#  'delete',
#  '',
#  'key',
#  'editing',
#  'use',
#  'service',
#  'phone',
#  'assistance',
#  'genius',
#  'bar',
#  'battery',
#  'life',
#  'battery',
#  'life',
#  'gaming',
#  'movie',
#  'playing',
#  'web',
#  'browsing',
#  'word',
#  'editing',
#  'recovery',
#  'discs',
#  'Office',
#  "Max's",
#  '"Max',
#  'Assurance"',
#  'iMac',
#  'backup',
#  'disc',
#  'USB',
#  'battery',
#  'life',
#  'battery',
#  'timer',
#  'Temperatures',
#  'Core',
#  'Processing',
#  'Unit',
#  'temperatures',
#  'service',
#  'virus',
#  'protection',
#  'Mac',
#  'bluetooth',
#  'LG',
#  'notebook',
#  'service',
#  'center',
#  'hinge',
#  'games',
#  'responds',
#  'motherboard',
#  'motherboard',
#  'hardware',
#  'motherboard',
#  'use',
#  'representive',
#  'Microsoft',
#  'system',
#  'XP',
#  'WIndows',
#  '7',
#  'Vista',
#  'Keyboard',
#  "Dell's",
#  'customer',
#  'disservice',
#  'cooling',
#  'system',
#  'use',
#  'quad',
#  'core',
#  'I7',
#  'sales',
#  'associate',
#  'system',
#  'Windows',
#  'applications',
#  'virus',
#  'program',
#  'weighed',
#  'seven',
#  'pounds',
#  'battery',
#  'bag',
#  'color',
#  'keys',
#  'designed',
#  'style',
#  'speed',
#  'keyboard',
#  'mousepad',
#  'battery',
#  'sales',
#  'service',
#  'DELL',
#  'SUPPORT',
#  'hard',
#  'drive',
#  'motherboard',
#  'speed',
#  'construction',
#  'quality',
#  'longevity',
#  'cost',
#  'keyboard',
#  'keys',
#  'configuration',
#  '"extra',
#  'key"',
#  'touch',
#  'pad',
#  'use',
#  'security',
#  'pricetag',
#  'use',
#  'work',
#  'preloaded',
#  'software',
#  'webcam',
#  'vga',
#  'port',
#  'screen',
#  'battery',
#  'life',
#  'keys',
#  'software',
#  'volume',
#  'mouse',
#  'touchpad',
#  'boots',
#  'hard',
#  'drive',
#  'look',
#  'feel',
#  'standpoint',
#  'safari',
#  'safari',
#  'Mozzilla',
#  'firfox',
#  'Bluetooth',
#  'fingerprint',
#  'reader',
#  'driver',
#  'software',
#  'battery',
#  'speed',
#  'display',
#  'delivery',
#  'battery',
#  'life',
#  'performance',
#  'memory',
#  'applications',
#  'Microsoft',
#  'office',
#  'Resolution',
#  'appearance',
#  'cooling',
#  'system',
#  'graphics',
#  'card',
#  'built-in',
#  'webcam',
#  'built-in',
#  'mic',
#  'cam',
#  'mic',
#  'Windows',
#  'Vista',
#  'board',
#  'connector',
#  'power',
#  'supply',
#  'warrenty',
#  'power',
#  'supply',
#  'ethernet',
#  'works',
#  'drag',
#  'drop',
#  'feature',
#  'webcam',
#  'sales',
#  'tax',
#  'software',
#  'packages',
#  'iWork',
#  'GarageBand',
#  'iMovie',
#  'screen',
#  'colors',
#  'resolution',
#  'monitor',
#  'iTunes',
#  'Size',
#  'external',
#  'monitor',
#  'base',
#  'installation',
#  'software',
#  'manuf',
#  'camera',
#  'display',
#  'AMD',
#  'Turin',
#  'processor',
#  'Intel',
#  'warranty',
#  'start',
#  'menu',
#  'navigate',
#  'bluray',
#  'read/write',
#  'drive',
#  'service',
#  'tech',
#  'tech',
#  'store',
#  'surface',
#  'screen',
#  'keyboard',
#  'iLife',
#  'Snow',
#  'Leopard',
#  'X',
#  'price',
#  'tag',
#  'Mac',
#  'OS',
#  'sound',
#  'output',
#  'quality',
#  'techie',
#  'use',
#  'Toshiba',
#  'online',
#  'help',
#  'service',
#  'life',
#  'ports',
#  'processor',
#  'price',
#  'look',
#  'keyboard',
#  'keys',
#  'screen',
#  'quality',
#  'stock',
#  'screen',
#  'gray',
#  'color',
#  'volume',
#  'buttons',
#  'processor',
#  'computing',
#  'protector',
#  'key',
#  'pad',
#  'magnetic',
#  'plug-in',
#  'power',
#  'charging',
#  'power',
#  'cord',
#  'XP',
#  'Vista',
#  'graphics',
#  'use',
#  'Mac',
#  'OS',
#  'use',
#  'support',
#  'Geek',
#  'Squad',
#  'graphics',
#  'quality',
#  'Appleworks',
#  'browser',
#  'paint',
#  'keyboard',
#  'service',
#  'department',
#  'warrenty',
#  'warrentys',
#  'hard',
#  'disk',
#  'CD',
#  'drive',
#  'running',
#  'screen',
#  'size',
#  'web',
#  'browsing',
#  'software',
#  'loads',
#  'trackpad',
#  'external',
#  'mouse',
#  'trackpad',
#  'games',
#  'features',
#  'human',
#  'interface',
#  'inbuilt',
#  'applications',
#  'Software',
#  'body',
#  'i5',
#  'antivirus',
#  'software',
#  'firewall',
#  'price',
#  'Apple',
#  'team',
#  'Vista',
#  'Vista',
#  'operating',
#  'system',
#  'Vista',
#  'video',
#  'chat',
#  'quality',
#  'mouse',
#  'Fan',
#  'cooling',
#  'pad',
#  'feature',
#  'software',
#  'installation',
#  'time',
#  'power',
#  'storage',
#  'abilitiy',
#  'spotlight',
#  'search',
#  'feature',
#  'wireless',
#  'system',
#  'Windows',
#  '7',
#  'quality',
#  'battery',
#  'life',
#  'speed',
#  'OS',
#  'OS',
#  'iTunes',
#  'program',
#  'gaming',
#  'battery',
#  'Apple',
#  'support',
#  'techs',
#  'adding',
#  'bluetooth',
#  'graphic',
#  'power',
#  'Adobe',
#  'Creative',
#  'apps',
#  'programs',
#  'use',
#  'materials',
#  'software',
#  'Tech',
#  'support',
#  'power',
#  'supply',
#  'POWER',
#  'SUPPLY',
#  'size',
#  'warranty',
#  'Windows',
#  'XP',
#  'SP2',
#  'Windows',
#  '7',
#  'Ultimate',
#  'Bluetooth',
#  'Fingerprint',
#  'reader',
#  'software',
#  'techs',
#  'HP',
#  'video',
#  'card',
#  'graphics',
#  'security',
#  'audio',
#  'keyboard',
#  'runs',
#  'set',
#  'screen',
#  'word',
#  'processing',
#  'internet',
#  'trackpad',
#  'battery',
#  'life',
#  'spec',
#  'HD',
#  'graphics',
#  'chip',
#  'components',
#  'DVD',
#  'burner',
#  'USB',
#  'ports',
#  'software',
#  'system',
#  'ran',
#  'price',
#  'operation',
#  'brand',
#  'components',
#  'ground',
#  'loop',
#  'isolator',
#  'price',
#  'range',
#  'quality',
#  'warranty',
#  'leading',
#  'edge',
#  'bloatware',
#  'Maximum',
#  'sound',
#  'windows',
#  '7',
#  'Bootcamp',
#  'price',
#  'action',
#  'pack',
#  'games',
#  'works',
#  'price',
#  'performance',
#  'twin',
#  'packing',
#  'functions',
#  'sales',
#  'support',
#  'look',
#  'display',
#  'screen',
#  'acer',
#  'arcade',
#  'customer',
#  'support',
#  'screen',
#  'cd',
#  'drive',
#  'runs',
#  'design',
#  'size',
#  'games',
#  'games',
#  'life',
#  'warranty',
#  'pad',
#  'value',
#  'price',
#  'system',
#  'performance',
#  'linux',
#  'based',
#  'os',
#  'use',
#  'batteries',
#  'shipping',
#  'carton',
#  'use',
#  'program',
#  'virus',
#  'protection',
#  'screen',
#  'processor',
#  'OSX',
#  '16',
#  'graphics',
#  'hardware',
#  'software',
#  'Intel',
#  'Core',
#  'processors',
#  'HDMI',
#  'port',
#  'Internet',
#  'Explorer',
#  'staff',
#  'price',
#  'premium',
#  'features',
#  'product',
#  'help',
#  'aftermarket',
#  'Microsoft',
#  'word',
#  'usb',
#  'ports',
#  'sd',
#  'memory',
#  'card',
#  'reader',
#  'sd',
#  'memory',
#  'car',
#  'expansion',
#  'LaCie',
#  '2Big',
#  'external',
#  'drive',
#  'firewire',
#  '800',
#  'interface',
#  'Time',
#  'Machine',
#  'sound',
#  'extra',
#  'features',
#  'windows',
#  '7',
#  'home',
#  'premium',
#  'Acer',
#  'screen',
#  'USB',
#  'port',
#  'boot',
#  'battery',
#  'life',
#  'fires',
#  'keyboard',
#  'software',
#  'online',
#  'tutorial',
#  'videos',
#  'image',
#  'soud',
#  'windows',
#  'boot',
#  'shut',
#  'windows',
#  'Mac',
#  'OS',
#  'use',
#  'cost',
#  'Windows',
#  '7',
#  'Starter',
#  'Windows',
#  '7',
#  'Home',
#  'Premium',
#  'Windows',
#  '7',
#  'Professional',
#  'specifications',
#  'power',
#  'cords',
#  'multi-touch',
#  'features',
#  'screen',
#  'clicking',
#  'buttons',
#  'battery',
#  'life',
#  'Windows',
#  'wired',
#  'lan',
#  'hard',
#  'reboot',
#  'hardware',
#  'hard',
#  'drive',
#  'battery',
#  'life',
#  'Apple',
#  'care',
#  'font',
#  'Features',
#  'programs',
#  'run',
#  u'plastic\xa0pieces',
#  '2GB',
#  'RAM',
#  'stick',
#  'Windows',
#  'Microsoft',
#  'Word',
#  'Mac',
#  'WARRANTY',
#  'COMPANY',
#  'cusromer',
#  'service',
#  'center',
#  'size',
#  'weight',
#  'battery',
#  'aluminum',
#  'body',
#  'watching',
#  'movies',
#  'playing',
#  'build',
#  'quality',
#  'performance',
#  'dock',
#  'program',
#  'program',
#  'working',
#  'costing',
#  'price',
#  'i7',
#  'monitor',
#  'extended',
#  'warranty',
#  'Boots',
#  'runs',
#  'screen',
#  'driver',
#  'tech',
#  'support',
#  'work',
#  'hard',
#  'drive',
#  'twin',
#  'packing',
#  'functions',
#  'warranty',
#  'performance',
#  'price',
#  'BIOS',
#  'design',
#  'tech',
#  'issues',
#  'size',
#  'space',
#  'service',
#  'memory',
#  'speed',
#  'priced',
#  'internet',
#  'speed',
#  'programs',
#  'Garageband',
#  'Photo',
#  'Booth',
#  'iPhoto',
#  'iMovie',
#  'video-editing',
#  'movie-making',
#  'photo',
#  'management',
#  'music',
#  'Pages',
#  'Numbers',
#  'Keynote',
#  'school',
#  'office',
#  'use',
#  'screen',
#  'colors',
#  'value',
#  'price',
#  'value',
#  'web',
#  'cam',
#  'burn',
#  "cd's",
#  '17',
#  'inch',
#  'screen',
#  'support',
#  'Bluetooth',
#  'Drivers/Applications',
#  'DVD',
#  'Launch',
#  'Manager',
#  'glass',
#  'screen',
#  'switchable',
#  'graphic',
#  'card',
#  'gaming',
#  'service',
#  'battery',
#  'life',
#  'technical',
#  'support',
#  'BOOT',
#  'MGR',
#  'recovery',
#  'cd',
#  'price',
#  'features',
#  'Skype',
#  'mouse',
#  'buttons',
#  'HDD',
#  'rails',
#  'hard',
#  'drive',
#  'quality',
#  'staff',
#  'Games',
#  'GarageBand',
#  'warranty',
#  'hard',
#  'drive',
#  'price',
#  'home',
#  'use',
#  'business',
#  'use',
#  'virus',
#  'protection',
#  'updates',
#  'MS',
#  'Office',
#  'apps',
#  'feature',
#  'Windows',
#  'games',
#  'battery',
#  'life',
#  'battery',
#  'life',
#  'price',
#  'Nortons',
#  'virus',
#  'scan',
#  'frame',
#  'features',
#  'use',
#  'loaded',
#  'Windows',
#  '7',
#  'Vista',
#  'Vista',
#  'windows',
#  'Windows',
#  'XP',
#  'Vista',
#  'key',
#  'broad',
#  'warranty',
#  'repair',
#  '"depot"',
#  'school',
#  'use',
#  'design',
#  'battery',
#  'life',
#  'programs',
#  'Wireless',
#  'battery',
#  'life',
#  'programs',
#  'trackpad',
#  'programs',
#  'navigating',
#  'speakers',
#  'subwoofer',
#  'built',
#  'camera',
#  'price',
#  'warranty',
#  'left',
#  'mouse',
#  'key',
#  'costed',
#  'speed',
#  'hard',
#  'drive',
#  'space',
#  'picture',
#  'extended',
#  'warranty',
#  'extended',
#  'warranties',
#  'battery',
#  'Screen',
#  'battery',
#  'life',
#  'appearance',
#  'technical',
#  'service',
#  'dell',
#  'graphics',
#  'warranty',
#  'battery',
#  'case',
#  'performance',
#  'price',
#  'look',
#  'applications',
#  'speed',
#  'tech',
#  'support',
#  'gaming',
#  'use',
#  'Photoshop',
#  'ram',
#  'system',
#  'clock',
#  'RAM',
#  'securitysoftware',
#  'driver',
#  'updates',
#  'Windows',
#  'work',
#  'works',
#  'HD',
#  'HD',
#  'graphics',
#  'card',
#  'built',
#  'camera',
#  'DVD',
#  'burner',
#  'DVD',
#  'burner',
#  'works',
#  '15',
#  'inch',
#  'Product',
#  'support',
#  'screen',
#  'use',
#  'casing',
#  'power',
#  'cord',
#  'internet',
#  'signals',
#  'price',
#  'right',
#  ...]

# %%
df2.at[d,'f']=term

# %%
import pandas as pd
df2=pd.DataFrame(columns=['f','m','o'])

from nltk import word_tokenize,pos_tag

# %%
d=0
l=[]
for sen in sentences_list[0:1]:
    sen2=sen
    sen=word_tokenize(sen2)
    sen=pos_tag(sen)
    print(sen)
    for term in sen:
        if term[0] in a_new:
            #print term[0]+"hello"
            
            df2.at[d,'f']=term[0]
            l=[]
            for word in sen:
                #print word
                if word[1]=='JJ' or word[1]=='JJR' or word[1]=='JJ':
                    df2.at[d,'o']=word[0]
                elif word[1]=='VB':
                    df2.at[d,'o']=word[0]
                if word[1]=='RB':
                    l.append(word[0])
            print(l)
            df2.at[d,'m']=l
            d=d+1
# Out:
# [('I', 'PRP'), ('charge', 'VBP'), ('it', 'PRP'), ('at', 'IN'), ('night', 'NN'), ('and', 'CC'), ('skip', 'NN'), ('taking', 'VBG'), ('the', 'DT'), ('cord', 'NN'), ('with', 'IN'), ('me', 'PRP'), ('because', 'IN'), ('of', 'IN'), ('the', 'DT'), ('good', 'JJ'), ('battery', 'NN'), ('life', 'NN'), ('.', '.')]
# []
# []
# []
# []

# %%
df2
# Out:
#          f   m     o
# 0   charge  []  good
# 1     cord  []  good
# 2  battery  []  good
# 3     life  []  good
